# %%
reviewer_sites = [
#    'achoreviews',
#    'aftersound',
#    'animagus',
#    'arn',
#    'bedrock',
#    'bryaudioreviews',
#    'cammyfi',
#    'soundjedi',
#    'eplv',
#    'timmyv',
#    'harpo',
#    'hbb',
#    'cqtek',
#    'hobbytalk',
#    'ianfann',
    ('iemworld',False)
#    'jacstone',
#    'kr0mka',
#    'kurin',
#    'melatonin',
#    'nymz', 
#    'pw',
#    'recode',
#    'rg',
#    'shortbus',
#    'suporsalad',
#    'tgx78',
#    'vortexreviews',
#    'vsg',
#    'wdym',
#    'akros',
#    ('data_mrs', True)
     
]

print(f'Number of reviewer sites: {len(reviewer_sites)}')
# Out:
# Number of reviewer sites: 1

# %%
import re

def preprocess_and_convert_to_csv(input_file, output_file):
    with open(input_file, 'r', errors='replace') as infile, open(output_file, 'w') as outfile:
        outfile.write("X,Y\n")  # Write header
        for line in infile:
            if re.match(r'^\d', line):  # Check if the line starts with a digit
                if ',' in line:  # Check if the line is already in CSV format
                    outfile.write(line)
                else:
                    freq, spl, *_ = line.split()  # Extract frequency and SPL values
                    outfile.write(f"{freq},{spl}\n")  # Write to output file

# %%
import requests
from bs4 import BeautifulSoup
import os
import time
import random
from urllib.parse import unquote

for site_tuple in reviewer_sites:
    
    site, is_special_case = site_tuple
    
    if is_special_case:
        base_url = 'https://squig.link/data_mrs/'
    else:
        base_url = f'https://{site}.squig.link/data/'  

    # base_url = f'https://{site}.squig.link/data/'
    
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    'Referer': 'https://squig.link/'
    }

    response = requests.get(base_url, headers=headers)

    if response.status_code == 200:
        print('Successful connection.\n')
    else:
        print(f'Error: {response.status_code} {response.reason}')

    soup = BeautifulSoup(response.text, 'html.parser')

    links = soup.find_all('a')

    txt_links = [link.get('href') for link in links if link.get('href').endswith('.txt')]

    # Create folders for each reviewer site
    save_folder = f'output/txt/{site}'
    if not os.path.exists(save_folder):
        os.makedirs(save_folder)
    
    csv_save_folder = f'output/csv/{site}'
    if not os.path.exists(csv_save_folder):
        os.makedirs(csv_save_folder)
        
    for txt_link in txt_links:
        decoded_txt_link = unquote(txt_link)
        file_name = os.path.join(save_folder, decoded_txt_link)
        csv_file_name = os.path.join(csv_save_folder, decoded_txt_link.replace('.txt', '.csv'))

        with open(file_name, 'wb') as f:
            file_response = requests.get(base_url + txt_link, headers=headers)
            f.write(file_response.content)
        print(f'Downloaded {file_name}')

        preprocess_and_convert_to_csv(file_name, csv_file_name)
        print(f'Converted {file_name} to {csv_file_name}')

        time.sleep(0.5 + random.uniform(-0.25, 0.25))  # Delay for 1 second, plus a random value between -0.5 and 0.5 seconds
# Out:
# Successful connection.
#
# Downloaded output/txt/iemworld\1MORE Quad Driver L.txt
# Converted output/txt/iemworld\1MORE Quad Driver L.txt to output/csv/iemworld\1MORE Quad Driver L.csv
# Downloaded output/txt/iemworld\1MORE Quad Driver R.txt
# Converted output/txt/iemworld\1MORE Quad Driver R.txt to output/csv/iemworld\1MORE Quad Driver R.csv
# Downloaded output/txt/iemworld\1More Triple Driver (FOAM Eartips) L.txt
# Converted output/txt/iemworld\1More Triple Driver (FOAM Eartips) L.txt to output/csv/iemworld\1More Triple Driver (FOAM Eartips) L.csv
# Downloaded output/txt/iemworld\1More Triple Driver (FOAM Eartips) R.txt
# Converted output/txt/iemworld\1More Triple Driver (FOAM Eartips) R.txt to output/csv/iemworld\1More Triple Driver (FOAM Eartips) R.csv
# Downloaded output/txt/iemworld\1More Triple Driver (NO TIP on Coupler 8K peak disappeared FOAM) L.txt
# Converted output/txt/iemworld\1More Triple Driver (NO TIP on Coupler 8K peak disappeared FOAM) L.txt to output/csv/iemworld\1More Triple Driver (NO TIP on Coupler 8K peak disappeared FOAM) L.csv
# Downloaded output/txt/iemworld\1More Triple Driver (NO TIP on Coupler 8K peak disappeared FOAM) R.txt
# Converted output/txt/iemworld\1More Triple Driver (NO TIP on Coupler 8K peak disappeared FOAM) R.txt to output/csv/iemworld\1More Triple Driver (NO TIP on Coupler 8K peak disappeared FOAM) R.csv
# Downloaded output/txt/iemworld\1More Triple Driver (Orignal silicone Eartips) L.txt
# Converted output/txt/iemworld\1More Triple Driver (Orignal silicone Eartips) L.txt to output/csv/iemworld\1More Triple Driver (Orignal silicone Eartips) L.csv
# Downloaded output/txt/iemworld\1More Triple Driver (Orignal silicone Eartips) R.txt
# Converted output/txt/iemworld\1More Triple Driver (Orignal silicone Eartips) R.txt to output/csv/iemworld\1More Triple Driver (Orignal silicone Eartips) R.csv
# Downloaded output/txt/iemworld\7Hz Dioko L.txt
# Converted output/txt/iemworld\7Hz Dioko L.txt to output/csv/iemworld\7Hz Dioko L.csv
# Downloaded output/txt/iemworld\7Hz Dioko R.txt
# Converted output/txt/iemworld\7Hz Dioko R.txt to output/csv/iemworld\7Hz Dioko R.csv
# Downloaded output/txt/iemworld\7Hz ETERNAL L.txt
# Converted output/txt/iemworld\7Hz ETERNAL L.txt to output/csv/iemworld\7Hz ETERNAL L.csv
# Downloaded output/txt/iemworld\7Hz ETERNAL R.txt
# Converted output/txt/iemworld\7Hz ETERNAL R.txt to output/csv/iemworld\7Hz ETERNAL R.csv
# Downloaded output/txt/iemworld\7Hz Timeless (FINAL Tips) L.txt
# Converted output/txt/iemworld\7Hz Timeless (FINAL Tips) L.txt to output/csv/iemworld\7Hz Timeless (FINAL Tips) L.csv
# Downloaded output/txt/iemworld\7Hz Timeless (FINAL Tips) R.txt
# Converted output/txt/iemworld\7Hz Timeless (FINAL Tips) R.txt to output/csv/iemworld\7Hz Timeless (FINAL Tips) R.csv
# Downloaded output/txt/iemworld\7Hz Timeless (Foam Tips) L.txt
# Converted output/txt/iemworld\7Hz Timeless (Foam Tips) L.txt to output/csv/iemworld\7Hz Timeless (Foam Tips) L.csv
# Downloaded output/txt/iemworld\7Hz Timeless (Foam Tips) R.txt
# Converted output/txt/iemworld\7Hz Timeless (Foam Tips) R.txt to output/csv/iemworld\7Hz Timeless (Foam Tips) R.csv
# Downloaded output/txt/iemworld\7Hz Timeless (MoonDroop Tips) L.txt
# Converted output/txt/iemworld\7Hz Timeless (MoonDroop Tips) L.txt to output/csv/iemworld\7Hz Timeless (MoonDroop Tips) L.csv
# Downloaded output/txt/iemworld\7Hz Timeless (MoonDroop Tips) R.txt
# Converted output/txt/iemworld\7Hz Timeless (MoonDroop Tips) R.txt to output/csv/iemworld\7Hz Timeless (MoonDroop Tips) R.csv
# Downloaded output/txt/iemworld\7hz Zero (EJ07 FOAM Eartips) L.txt
# Converted output/txt/iemworld\7hz Zero (EJ07 FOAM Eartips) L.txt to output/csv/iemworld\7hz Zero (EJ07 FOAM Eartips) L.csv
# Downloaded output/txt/iemworld\7hz Zero (EJ07 FOAM Eartips) R.txt
# Converted output/txt/iemworld\7hz Zero (EJ07 FOAM Eartips) R.txt to output/csv/iemworld\7hz Zero (EJ07 FOAM Eartips) R.csv
# Downloaded output/txt/iemworld\7hz Zero (Final Eartips) L.txt
# Converted output/txt/iemworld\7hz Zero (Final Eartips) L.txt to output/csv/iemworld\7hz Zero (Final Eartips) L.csv
# Downloaded output/txt/iemworld\7hz Zero (Final Eartips) R.txt
# Converted output/txt/iemworld\7hz Zero (Final Eartips) R.txt to output/csv/iemworld\7hz Zero (Final Eartips) R.csv
# Downloaded output/txt/iemworld\7hz Zero (MoonDrop Eartips) L.txt
# Converted output/txt/iemworld\7hz Zero (MoonDrop Eartips) L.txt to output/csv/iemworld\7hz Zero (MoonDrop Eartips) L.csv
# Downloaded output/txt/iemworld\7hz Zero (MoonDrop Eartips) R.txt
# Converted output/txt/iemworld\7hz Zero (MoonDrop Eartips) R.txt to output/csv/iemworld\7hz Zero (MoonDrop Eartips) R.csv
# Downloaded output/txt/iemworld\7hz Zero (Red Orignal Eartips) L.txt
# Converted output/txt/iemworld\7hz Zero (Red Orignal Eartips) L.txt to output/csv/iemworld\7hz Zero (Red Orignal Eartips) L.csv
# Downloaded output/txt/iemworld\7hz Zero (Red Orignal Eartips) R.txt
# Converted output/txt/iemworld\7hz Zero (Red Orignal Eartips) R.txt to output/csv/iemworld\7hz Zero (Red Orignal Eartips) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t m15 (Foam) L.txt
# Converted output/txt/iemworld\64 Audio U6t m15 (Foam) L.txt to output/csv/iemworld\64 Audio U6t m15 (Foam) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t m15 (Foam) R.txt
# Converted output/txt/iemworld\64 Audio U6t m15 (Foam) R.txt to output/csv/iemworld\64 Audio U6t m15 (Foam) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t m15 (NO TIP on Coupler) L.txt
# Converted output/txt/iemworld\64 Audio U6t m15 (NO TIP on Coupler) L.txt to output/csv/iemworld\64 Audio U6t m15 (NO TIP on Coupler) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t m15 (NO TIP on Coupler) R.txt
# Converted output/txt/iemworld\64 Audio U6t m15 (NO TIP on Coupler) R.txt to output/csv/iemworld\64 Audio U6t m15 (NO TIP on Coupler) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t m15 (Silicon Tips) L.txt
# Converted output/txt/iemworld\64 Audio U6t m15 (Silicon Tips) L.txt to output/csv/iemworld\64 Audio U6t m15 (Silicon Tips) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t m15 (Silicon Tips) R.txt
# Converted output/txt/iemworld\64 Audio U6t m15 (Silicon Tips) R.txt to output/csv/iemworld\64 Audio U6t m15 (Silicon Tips) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t m15 (Silicon Tips WIDE) L.txt
# Converted output/txt/iemworld\64 Audio U6t m15 (Silicon Tips WIDE) L.txt to output/csv/iemworld\64 Audio U6t m15 (Silicon Tips WIDE) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t m15 (Silicon Tips WIDE) R.txt
# Converted output/txt/iemworld\64 Audio U6t m15 (Silicon Tips WIDE) R.txt to output/csv/iemworld\64 Audio U6t m15 (Silicon Tips WIDE) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t m20 (Foam) L.txt
# Converted output/txt/iemworld\64 Audio U6t m20 (Foam) L.txt to output/csv/iemworld\64 Audio U6t m20 (Foam) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t m20 (Foam) R.txt
# Converted output/txt/iemworld\64 Audio U6t m20 (Foam) R.txt to output/csv/iemworld\64 Audio U6t m20 (Foam) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t m20 (NO TIP on Coupler) L.txt
# Converted output/txt/iemworld\64 Audio U6t m20 (NO TIP on Coupler) L.txt to output/csv/iemworld\64 Audio U6t m20 (NO TIP on Coupler) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t m20 (NO TIP on Coupler) R.txt
# Converted output/txt/iemworld\64 Audio U6t m20 (NO TIP on Coupler) R.txt to output/csv/iemworld\64 Audio U6t m20 (NO TIP on Coupler) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t m20 (Silicon Tips) L.txt
# Converted output/txt/iemworld\64 Audio U6t m20 (Silicon Tips) L.txt to output/csv/iemworld\64 Audio U6t m20 (Silicon Tips) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t m20 (Silicon Tips) R.txt
# Converted output/txt/iemworld\64 Audio U6t m20 (Silicon Tips) R.txt to output/csv/iemworld\64 Audio U6t m20 (Silicon Tips) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t m20 (Silicon Tips WIDE) L.txt
# Converted output/txt/iemworld\64 Audio U6t m20 (Silicon Tips WIDE) L.txt to output/csv/iemworld\64 Audio U6t m20 (Silicon Tips WIDE) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t m20 (Silicon Tips WIDE) R.txt
# Converted output/txt/iemworld\64 Audio U6t m20 (Silicon Tips WIDE) R.txt to output/csv/iemworld\64 Audio U6t m20 (Silicon Tips WIDE) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t mx (Foam) L.txt
# Converted output/txt/iemworld\64 Audio U6t mx (Foam) L.txt to output/csv/iemworld\64 Audio U6t mx (Foam) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t mx (Foam) R.txt
# Converted output/txt/iemworld\64 Audio U6t mx (Foam) R.txt to output/csv/iemworld\64 Audio U6t mx (Foam) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t mx (NO TIP on Coupler) L.txt
# Converted output/txt/iemworld\64 Audio U6t mx (NO TIP on Coupler) L.txt to output/csv/iemworld\64 Audio U6t mx (NO TIP on Coupler) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t mx (NO TIP on Coupler) R.txt
# Converted output/txt/iemworld\64 Audio U6t mx (NO TIP on Coupler) R.txt to output/csv/iemworld\64 Audio U6t mx (NO TIP on Coupler) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t mx (Silicon Tips) L.txt
# Converted output/txt/iemworld\64 Audio U6t mx (Silicon Tips) L.txt to output/csv/iemworld\64 Audio U6t mx (Silicon Tips) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t mx (Silicon Tips) R.txt
# Converted output/txt/iemworld\64 Audio U6t mx (Silicon Tips) R.txt to output/csv/iemworld\64 Audio U6t mx (Silicon Tips) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t mx (Silicon Tips WIDE) L.txt
# Converted output/txt/iemworld\64 Audio U6t mx (Silicon Tips WIDE) L.txt to output/csv/iemworld\64 Audio U6t mx (Silicon Tips WIDE) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t mx (Silicon Tips WIDE) R.txt
# Converted output/txt/iemworld\64 Audio U6t mx (Silicon Tips WIDE) R.txt to output/csv/iemworld\64 Audio U6t mx (Silicon Tips WIDE) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t xx (Foam) L.txt
# Converted output/txt/iemworld\64 Audio U6t xx (Foam) L.txt to output/csv/iemworld\64 Audio U6t xx (Foam) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t xx (Foam) R.txt
# Converted output/txt/iemworld\64 Audio U6t xx (Foam) R.txt to output/csv/iemworld\64 Audio U6t xx (Foam) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t xx (NO TIP on Coupler) L.txt
# Converted output/txt/iemworld\64 Audio U6t xx (NO TIP on Coupler) L.txt to output/csv/iemworld\64 Audio U6t xx (NO TIP on Coupler) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t xx (NO TIP on Coupler) R.txt
# Converted output/txt/iemworld\64 Audio U6t xx (NO TIP on Coupler) R.txt to output/csv/iemworld\64 Audio U6t xx (NO TIP on Coupler) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t xx (Silicon Tips) L.txt
# Converted output/txt/iemworld\64 Audio U6t xx (Silicon Tips) L.txt to output/csv/iemworld\64 Audio U6t xx (Silicon Tips) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t xx (Silicon Tips) R.txt
# Converted output/txt/iemworld\64 Audio U6t xx (Silicon Tips) R.txt to output/csv/iemworld\64 Audio U6t xx (Silicon Tips) R.csv
# Downloaded output/txt/iemworld\64 Audio U6t xx (Silicon Tips WIDE) L.txt
# Converted output/txt/iemworld\64 Audio U6t xx (Silicon Tips WIDE) L.txt to output/csv/iemworld\64 Audio U6t xx (Silicon Tips WIDE) L.csv
# Downloaded output/txt/iemworld\64 Audio U6t xx (Silicon Tips WIDE) R.txt
# Converted output/txt/iemworld\64 Audio U6t xx (Silicon Tips WIDE) R.txt to output/csv/iemworld\64 Audio U6t xx (Silicon Tips WIDE) R.csv
# Downloaded output/txt/iemworld\64 Audio U12t (Filter 1) L.txt
# Converted output/txt/iemworld\64 Audio U12t (Filter 1) L.txt to output/csv/iemworld\64 Audio U12t (Filter 1) L.csv
# Downloaded output/txt/iemworld\64 Audio U12t (Filter 1) R.txt
# Converted output/txt/iemworld\64 Audio U12t (Filter 1) R.txt to output/csv/iemworld\64 Audio U12t (Filter 1) R.csv
# Downloaded output/txt/iemworld\64 Audio U12t (Filter 2) L.txt
# Converted output/txt/iemworld\64 Audio U12t (Filter 2) L.txt to output/csv/iemworld\64 Audio U12t (Filter 2) L.csv
# Downloaded output/txt/iemworld\64 Audio U12t (Filter 2) R.txt
# Converted output/txt/iemworld\64 Audio U12t (Filter 2) R.txt to output/csv/iemworld\64 Audio U12t (Filter 2) R.csv
# Downloaded output/txt/iemworld\64 Audio U12t (Filter 3) L.txt
# Converted output/txt/iemworld\64 Audio U12t (Filter 3) L.txt to output/csv/iemworld\64 Audio U12t (Filter 3) L.csv
# Downloaded output/txt/iemworld\64 Audio U12t (Filter 3) R.txt
# Converted output/txt/iemworld\64 Audio U12t (Filter 3) R.txt to output/csv/iemworld\64 Audio U12t (Filter 3) R.csv
# Downloaded output/txt/iemworld\64 Audio U12t (NO Filter) L.txt
# Converted output/txt/iemworld\64 Audio U12t (NO Filter) L.txt to output/csv/iemworld\64 Audio U12t (NO Filter) L.csv
# Downloaded output/txt/iemworld\64 Audio U12t (NO Filter) R.txt
# Converted output/txt/iemworld\64 Audio U12t (NO Filter) R.txt to output/csv/iemworld\64 Audio U12t (NO Filter) R.csv
# Downloaded output/txt/iemworld\AKG N400 L.txt
# Converted output/txt/iemworld\AKG N400 L.txt to output/csv/iemworld\AKG N400 L.csv
# Downloaded output/txt/iemworld\AKG N400 R.txt
# Converted output/txt/iemworld\AKG N400 R.txt to output/csv/iemworld\AKG N400 R.csv
# Downloaded output/txt/iemworld\AKG N5005 (BASS) L.txt
# Converted output/txt/iemworld\AKG N5005 (BASS) L.txt to output/csv/iemworld\AKG N5005 (BASS) L.csv
# Downloaded output/txt/iemworld\AKG N5005 (BASS) R.txt
# Converted output/txt/iemworld\AKG N5005 (BASS) R.txt to output/csv/iemworld\AKG N5005 (BASS) R.csv
# Downloaded output/txt/iemworld\AKG N5005 (HIGH) L.txt
# Converted output/txt/iemworld\AKG N5005 (HIGH) L.txt to output/csv/iemworld\AKG N5005 (HIGH) L.csv
# Downloaded output/txt/iemworld\AKG N5005 (HIGH) R.txt
# Converted output/txt/iemworld\AKG N5005 (HIGH) R.txt to output/csv/iemworld\AKG N5005 (HIGH) R.csv
# Downloaded output/txt/iemworld\AKG N5005 (MID HIGH) L.txt
# Converted output/txt/iemworld\AKG N5005 (MID HIGH) L.txt to output/csv/iemworld\AKG N5005 (MID HIGH) L.csv
# Downloaded output/txt/iemworld\AKG N5005 (MID HIGH) R.txt
# Converted output/txt/iemworld\AKG N5005 (MID HIGH) R.txt to output/csv/iemworld\AKG N5005 (MID HIGH) R.csv
# Downloaded output/txt/iemworld\AKG N5005 (REFERENCE) L.txt
# Converted output/txt/iemworld\AKG N5005 (REFERENCE) L.txt to output/csv/iemworld\AKG N5005 (REFERENCE) L.csv
# Downloaded output/txt/iemworld\AKG N5005 (REFERENCE) R.txt
# Converted output/txt/iemworld\AKG N5005 (REFERENCE) R.txt to output/csv/iemworld\AKG N5005 (REFERENCE) R.csv
# Downloaded output/txt/iemworld\AKG N5005 REF (NO TIP on Coupler 8K) L.txt
# Converted output/txt/iemworld\AKG N5005 REF (NO TIP on Coupler 8K) L.txt to output/csv/iemworld\AKG N5005 REF (NO TIP on Coupler 8K) L.csv
# Downloaded output/txt/iemworld\AKG N5005 REF (NO TIP on Coupler 8K) R.txt
# Converted output/txt/iemworld\AKG N5005 REF (NO TIP on Coupler 8K) R.txt to output/csv/iemworld\AKG N5005 REF (NO TIP on Coupler 8K) R.csv
# Downloaded output/txt/iemworld\Antdroid Target.txt
# Converted output/txt/iemworld\Antdroid Target.txt to output/csv/iemworld\Antdroid Target.csv
# Downloaded output/txt/iemworld\Apple AirPods Pro 2 (ANC Mode) L.txt
# Converted output/txt/iemworld\Apple AirPods Pro 2 (ANC Mode) L.txt to output/csv/iemworld\Apple AirPods Pro 2 (ANC Mode) L.csv
# Downloaded output/txt/iemworld\Apple AirPods Pro 2 (ANC Mode) R.txt
# Converted output/txt/iemworld\Apple AirPods Pro 2 (ANC Mode) R.txt to output/csv/iemworld\Apple AirPods Pro 2 (ANC Mode) R.csv
# Downloaded output/txt/iemworld\Apple AirPods Pro 2 (Transparency Mode) L.txt
# Converted output/txt/iemworld\Apple AirPods Pro 2 (Transparency Mode) L.txt to output/csv/iemworld\Apple AirPods Pro 2 (Transparency Mode) L.csv
# Downloaded output/txt/iemworld\Apple AirPods Pro 2 (Transparency Mode) R.txt
# Converted output/txt/iemworld\Apple AirPods Pro 2 (Transparency Mode) R.txt to output/csv/iemworld\Apple AirPods Pro 2 (Transparency Mode) R.csv
# Downloaded output/txt/iemworld\BLON Mini L.txt
# Converted output/txt/iemworld\BLON Mini L.txt to output/csv/iemworld\BLON Mini L.csv
# Downloaded output/txt/iemworld\BLON Mini R.txt
# Converted output/txt/iemworld\BLON Mini R.txt to output/csv/iemworld\BLON Mini R.csv
# Downloaded output/txt/iemworld\Bad Guy Target.txt
# Converted output/txt/iemworld\Bad Guy Target.txt to output/csv/iemworld\Bad Guy Target.csv
# Downloaded output/txt/iemworld\Banbeucmas Target.txt
# Converted output/txt/iemworld\Banbeucmas Target.txt to output/csv/iemworld\Banbeucmas Target.csv
# Downloaded output/txt/iemworld\CCA NRA L.txt
# Converted output/txt/iemworld\CCA NRA L.txt to output/csv/iemworld\CCA NRA L.csv
# Downloaded output/txt/iemworld\CCA NRA R.txt
# Converted output/txt/iemworld\CCA NRA R.txt to output/csv/iemworld\CCA NRA R.csv
# Downloaded output/txt/iemworld\Crinacle Target.txt
# Converted output/txt/iemworld\Crinacle Target.txt to output/csv/iemworld\Crinacle Target.csv
# Downloaded output/txt/iemworld\DUNU TITAN S L.txt
# Converted output/txt/iemworld\DUNU TITAN S L.txt to output/csv/iemworld\DUNU TITAN S L.csv
# Downloaded output/txt/iemworld\DUNU TITAN S R.txt
# Converted output/txt/iemworld\DUNU TITAN S R.txt to output/csv/iemworld\DUNU TITAN S R.csv
# Downloaded output/txt/iemworld\Diffuse Field Target.txt
# Converted output/txt/iemworld\Diffuse Field Target.txt to output/csv/iemworld\Diffuse Field Target.csv
# Downloaded output/txt/iemworld\Etymotic Target.txt
# Converted output/txt/iemworld\Etymotic Target.txt to output/csv/iemworld\Etymotic Target.csv
# Downloaded output/txt/iemworld\FIIO JD3 L.txt
# Converted output/txt/iemworld\FIIO JD3 L.txt to output/csv/iemworld\FIIO JD3 L.csv
# Downloaded output/txt/iemworld\FIIO JD3 R.txt
# Converted output/txt/iemworld\FIIO JD3 R.txt to output/csv/iemworld\FIIO JD3 R.csv
# Downloaded output/txt/iemworld\FIIO JH3 L.txt
# Converted output/txt/iemworld\FIIO JH3 L.txt to output/csv/iemworld\FIIO JH3 L.csv
# Downloaded output/txt/iemworld\FIIO JH3 R.txt
# Converted output/txt/iemworld\FIIO JH3 R.txt to output/csv/iemworld\FIIO JH3 R.csv
# Downloaded output/txt/iemworld\FIIO x Crinacle FHE Eclipse (Foam Eartips) L.txt
# Converted output/txt/iemworld\FIIO x Crinacle FHE Eclipse (Foam Eartips) L.txt to output/csv/iemworld\FIIO x Crinacle FHE Eclipse (Foam Eartips) L.csv
# Downloaded output/txt/iemworld\FIIO x Crinacle FHE Eclipse (Foam Eartips) R.txt
# Converted output/txt/iemworld\FIIO x Crinacle FHE Eclipse (Foam Eartips) R.txt to output/csv/iemworld\FIIO x Crinacle FHE Eclipse (Foam Eartips) R.csv
# Downloaded output/txt/iemworld\FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) L.txt
# Converted output/txt/iemworld\FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) L.txt to output/csv/iemworld\FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) L.csv
# Downloaded output/txt/iemworld\FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) R.txt
# Converted output/txt/iemworld\FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) R.txt to output/csv/iemworld\FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) R.csv
# Downloaded output/txt/iemworld\FINAL E1000 L.txt
# Converted output/txt/iemworld\FINAL E1000 L.txt to output/csv/iemworld\FINAL E1000 L.csv
# Downloaded output/txt/iemworld\FINAL E1000 R.txt
# Converted output/txt/iemworld\FINAL E1000 R.txt to output/csv/iemworld\FINAL E1000 R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (BAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (BAL Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (BAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (BAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (BAL Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (BAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (BASS Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (BASS Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (BASS Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (BASS Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (BASS Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (BASS Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (FINAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (FINAL Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (FINAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (FINAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (FINAL Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (FINAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (FOAM Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (FOAM Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (FOAM Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (FOAM Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (FOAM Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (FOAM Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (VOCAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (VOCAL Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (VOCAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Black Filter (VOCAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Black Filter (VOCAL Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Black Filter (VOCAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (BAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (BAL Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (BAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (BAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (BAL Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (BAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (BASS Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (BASS Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (BASS Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (BASS Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (BASS Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (BASS Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (FINAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (FINAL Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (FINAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (FINAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (FINAL Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (FINAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (FOAM Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (FOAM Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (FOAM Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (FOAM Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (FOAM Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (FOAM Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (VOCAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (VOCAL Teps) L.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (VOCAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FD3 : Red Filter (VOCAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FD3 : Red Filter (VOCAL Teps) R.txt to output/csv/iemworld\./Fiio FD3 : Red Filter (VOCAL Teps) R.csv
# Downloaded output/txt/iemworld\Fiio FH7 (Black) L.txt
# Converted output/txt/iemworld\Fiio FH7 (Black) L.txt to output/csv/iemworld\Fiio FH7 (Black) L.csv
# Downloaded output/txt/iemworld\Fiio FH7 (Black) R.txt
# Converted output/txt/iemworld\Fiio FH7 (Black) R.txt to output/csv/iemworld\Fiio FH7 (Black) R.csv
# Downloaded output/txt/iemworld\Fiio FH7 (Blue) L.txt
# Converted output/txt/iemworld\Fiio FH7 (Blue) L.txt to output/csv/iemworld\Fiio FH7 (Blue) L.csv
# Downloaded output/txt/iemworld\Fiio FH7 (Blue) R.txt
# Converted output/txt/iemworld\Fiio FH7 (Blue) R.txt to output/csv/iemworld\Fiio FH7 (Blue) R.csv
# Downloaded output/txt/iemworld\Fiio FH7 (Red) L.txt
# Converted output/txt/iemworld\Fiio FH7 (Red) L.txt to output/csv/iemworld\Fiio FH7 (Red) L.csv
# Downloaded output/txt/iemworld\Fiio FH7 (Red) R.txt
# Converted output/txt/iemworld\Fiio FH7 (Red) R.txt to output/csv/iemworld\Fiio FH7 (Red) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (BAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (BAL Teps) L.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (BAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (BAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (BAL Teps) R.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (BAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (BASS Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (BASS Teps) L.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (BASS Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (BASS Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (BASS Teps) R.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (BASS Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (BI FLING Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (BI FLING Teps) L.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (BI FLING Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (BI FLING Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (BI FLING Teps) R.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (BI FLING Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (FINAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (FINAL Teps) L.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (FINAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (FINAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (FINAL Teps) R.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (FINAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (FOAM Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (FOAM Teps) L.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (FOAM Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (FOAM Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (FOAM Teps) R.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (FOAM Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (SPIN Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (SPIN Teps) L.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (SPIN Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (SPIN Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (SPIN Teps) R.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (SPIN Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (VOCAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (VOCAL Teps) L.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (VOCAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : BASS Filter (VOCAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : BASS Filter (VOCAL Teps) R.txt to output/csv/iemworld\./Fiio FH9 : BASS Filter (VOCAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (BAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (BAL Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (BAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (BAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (BAL Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (BAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (BASS Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (BASS Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (BASS Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (BASS Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (BASS Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (BASS Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (BI FLING Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (BI FLING Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (BI FLING Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (BI FLING Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (BI FLING Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (BI FLING Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (FINAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (FINAL Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (FINAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (FINAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (FINAL Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (FINAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (FOAM Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (FOAM Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (FOAM Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (FOAM Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (FOAM Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (FOAM Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (SPIN Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (SPIN Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (SPIN Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (SPIN Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (SPIN Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (SPIN Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (VOCAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (VOCAL Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (VOCAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Balanced Filter (VOCAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Balanced Filter (VOCAL Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Balanced Filter (VOCAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (BAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (BAL Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (BAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (BAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (BAL Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (BAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (BASS Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (BASS Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (BASS Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (BASS Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (BASS Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (BASS Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (BI FLING Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (BI FLING Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (BI FLING Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (BI FLING Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (BI FLING Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (BI FLING Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (FINAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (FINAL Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (FINAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (FINAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (FINAL Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (FINAL Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (FOAM Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (FOAM Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (FOAM Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (FOAM Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (FOAM Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (FOAM Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (SPIN Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (SPIN Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (SPIN Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (SPIN Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (SPIN Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (SPIN Teps) R.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (VOCAL Teps) L.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (VOCAL Teps) L.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (VOCAL Teps) L.csv
# Downloaded output/txt/iemworld\./Fiio FH9 : Trble Filter (VOCAL Teps) R.txt
# Converted output/txt/iemworld\./Fiio FH9 : Trble Filter (VOCAL Teps) R.txt to output/csv/iemworld\./Fiio FH9 : Trble Filter (VOCAL Teps) R.csv
# Downloaded output/txt/iemworld\Free Field Target.txt
# Converted output/txt/iemworld\Free Field Target.txt to output/csv/iemworld\Free Field Target.csv
# Downloaded output/txt/iemworld\Harman Target.txt
# Converted output/txt/iemworld\Harman Target.txt to output/csv/iemworld\Harman Target.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Balanced tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Balanced tips) L.txt to output/csv/iemworld\Hidizs MS5 Balanced (Balanced tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Balanced tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Balanced tips) R.txt to output/csv/iemworld\Hidizs MS5 Balanced (Balanced tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Bass tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Bass tips) L.txt to output/csv/iemworld\Hidizs MS5 Balanced (Bass tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Bass tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Bass tips) R.txt to output/csv/iemworld\Hidizs MS5 Balanced (Bass tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Final E Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Final E Tips) L.txt to output/csv/iemworld\Hidizs MS5 Balanced (Final E Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Final E Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Final E Tips) R.txt to output/csv/iemworld\Hidizs MS5 Balanced (Final E Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (MoonDrop Spring Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (MoonDrop Spring Tips) L.txt to output/csv/iemworld\Hidizs MS5 Balanced (MoonDrop Spring Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (MoonDrop Spring Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (MoonDrop Spring Tips) R.txt to output/csv/iemworld\Hidizs MS5 Balanced (MoonDrop Spring Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (No Tip on Coupler 8K) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (No Tip on Coupler 8K) L.txt to output/csv/iemworld\Hidizs MS5 Balanced (No Tip on Coupler 8K) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (No Tip on Coupler 8K) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (No Tip on Coupler 8K) R.txt to output/csv/iemworld\Hidizs MS5 Balanced (No Tip on Coupler 8K) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (SoftEar UC Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (SoftEar UC Tips) L.txt to output/csv/iemworld\Hidizs MS5 Balanced (SoftEar UC Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (SoftEar UC Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (SoftEar UC Tips) R.txt to output/csv/iemworld\Hidizs MS5 Balanced (SoftEar UC Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Tripowin Foam) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Tripowin Foam) L.txt to output/csv/iemworld\Hidizs MS5 Balanced (Tripowin Foam) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Tripowin Foam) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Tripowin Foam) R.txt to output/csv/iemworld\Hidizs MS5 Balanced (Tripowin Foam) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Vocal Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Vocal Tips) L.txt to output/csv/iemworld\Hidizs MS5 Balanced (Vocal Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Vocal Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Vocal Tips) R.txt to output/csv/iemworld\Hidizs MS5 Balanced (Vocal Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Whizzer Easytips ET100AB) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Whizzer Easytips ET100AB) L.txt to output/csv/iemworld\Hidizs MS5 Balanced (Whizzer Easytips ET100AB) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Balanced (Whizzer Easytips ET100AB) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Balanced (Whizzer Easytips ET100AB) R.txt to output/csv/iemworld\Hidizs MS5 Balanced (Whizzer Easytips ET100AB) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Balanced tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Balanced tips) L.txt to output/csv/iemworld\Hidizs MS5 Bass (Balanced tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Balanced tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Balanced tips) R.txt to output/csv/iemworld\Hidizs MS5 Bass (Balanced tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Bass tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Bass tips) L.txt to output/csv/iemworld\Hidizs MS5 Bass (Bass tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Bass tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Bass tips) R.txt to output/csv/iemworld\Hidizs MS5 Bass (Bass tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Final E Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Final E Tips) L.txt to output/csv/iemworld\Hidizs MS5 Bass (Final E Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Final E Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Final E Tips) R.txt to output/csv/iemworld\Hidizs MS5 Bass (Final E Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (MoonDrop Spring Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (MoonDrop Spring Tips) L.txt to output/csv/iemworld\Hidizs MS5 Bass (MoonDrop Spring Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (MoonDrop Spring Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (MoonDrop Spring Tips) R.txt to output/csv/iemworld\Hidizs MS5 Bass (MoonDrop Spring Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (No Tip on Coupler 8K) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (No Tip on Coupler 8K) L.txt to output/csv/iemworld\Hidizs MS5 Bass (No Tip on Coupler 8K) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (No Tip on Coupler 8K) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (No Tip on Coupler 8K) R.txt to output/csv/iemworld\Hidizs MS5 Bass (No Tip on Coupler 8K) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (SoftEar UC Tips)L .txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (SoftEar UC Tips)L .txt to output/csv/iemworld\Hidizs MS5 Bass (SoftEar UC Tips)L .csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (SoftEar UC Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (SoftEar UC Tips) R.txt to output/csv/iemworld\Hidizs MS5 Bass (SoftEar UC Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Tripowin Foam) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Tripowin Foam) L.txt to output/csv/iemworld\Hidizs MS5 Bass (Tripowin Foam) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Tripowin Foam) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Tripowin Foam) R.txt to output/csv/iemworld\Hidizs MS5 Bass (Tripowin Foam) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Vocal Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Vocal Tips) L.txt to output/csv/iemworld\Hidizs MS5 Bass (Vocal Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Vocal Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Vocal Tips) R.txt to output/csv/iemworld\Hidizs MS5 Bass (Vocal Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Whizzer Easytips ET100AB) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Whizzer Easytips ET100AB) L.txt to output/csv/iemworld\Hidizs MS5 Bass (Whizzer Easytips ET100AB) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Bass (Whizzer Easytips ET100AB) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Bass (Whizzer Easytips ET100AB) R.txt to output/csv/iemworld\Hidizs MS5 Bass (Whizzer Easytips ET100AB) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Balanced tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Balanced tips) L.txt to output/csv/iemworld\Hidizs MS5 Treble (Balanced tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Balanced tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Balanced tips) R.txt to output/csv/iemworld\Hidizs MS5 Treble (Balanced tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Bass tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Bass tips) L.txt to output/csv/iemworld\Hidizs MS5 Treble (Bass tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Bass tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Bass tips) R.txt to output/csv/iemworld\Hidizs MS5 Treble (Bass tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Final E Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Final E Tips) L.txt to output/csv/iemworld\Hidizs MS5 Treble (Final E Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Final E Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Final E Tips) R.txt to output/csv/iemworld\Hidizs MS5 Treble (Final E Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (MoonDrop Spring Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (MoonDrop Spring Tips) L.txt to output/csv/iemworld\Hidizs MS5 Treble (MoonDrop Spring Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (MoonDrop Spring Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (MoonDrop Spring Tips) R.txt to output/csv/iemworld\Hidizs MS5 Treble (MoonDrop Spring Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (No Tip on Coupler 8K) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (No Tip on Coupler 8K) L.txt to output/csv/iemworld\Hidizs MS5 Treble (No Tip on Coupler 8K) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (No Tip on Coupler 8K) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (No Tip on Coupler 8K) R.txt to output/csv/iemworld\Hidizs MS5 Treble (No Tip on Coupler 8K) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (SoftEar UC Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (SoftEar UC Tips) L.txt to output/csv/iemworld\Hidizs MS5 Treble (SoftEar UC Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (SoftEar UC Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (SoftEar UC Tips) R.txt to output/csv/iemworld\Hidizs MS5 Treble (SoftEar UC Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Tripowin Foam) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Tripowin Foam) L.txt to output/csv/iemworld\Hidizs MS5 Treble (Tripowin Foam) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Tripowin Foam) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Tripowin Foam) R.txt to output/csv/iemworld\Hidizs MS5 Treble (Tripowin Foam) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Vocal Tips) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Vocal Tips) L.txt to output/csv/iemworld\Hidizs MS5 Treble (Vocal Tips) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Vocal Tips) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Vocal Tips) R.txt to output/csv/iemworld\Hidizs MS5 Treble (Vocal Tips) R.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Whizzer Easytips ET100AB) L.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Whizzer Easytips ET100AB) L.txt to output/csv/iemworld\Hidizs MS5 Treble (Whizzer Easytips ET100AB) L.csv
# Downloaded output/txt/iemworld\Hidizs MS5 Treble (Whizzer Easytips ET100AB) R.txt
# Converted output/txt/iemworld\Hidizs MS5 Treble (Whizzer Easytips ET100AB) R.txt to output/csv/iemworld\Hidizs MS5 Treble (Whizzer Easytips ET100AB) R.csv
# Downloaded output/txt/iemworld\Hisenior MEGA5P (FOAM Eartips) L.txt
# Converted output/txt/iemworld\Hisenior MEGA5P (FOAM Eartips) L.txt to output/csv/iemworld\Hisenior MEGA5P (FOAM Eartips) L.csv
# Downloaded output/txt/iemworld\Hisenior MEGA5P (FOAM Eartips) R.txt
# Converted output/txt/iemworld\Hisenior MEGA5P (FOAM Eartips) R.txt to output/csv/iemworld\Hisenior MEGA5P (FOAM Eartips) R.csv
# Downloaded output/txt/iemworld\Hisenior MEGA5P (NO TIP on Coupler 8K peak disappeared FOAM) L.txt
# Converted output/txt/iemworld\Hisenior MEGA5P (NO TIP on Coupler 8K peak disappeared FOAM) L.txt to output/csv/iemworld\Hisenior MEGA5P (NO TIP on Coupler 8K peak disappeared FOAM) L.csv
# Downloaded output/txt/iemworld\Hisenior MEGA5P (NO TIP on Coupler 8K peak disappeared FOAM) R.txt
# Converted output/txt/iemworld\Hisenior MEGA5P (NO TIP on Coupler 8K peak disappeared FOAM) R.txt to output/csv/iemworld\Hisenior MEGA5P (NO TIP on Coupler 8K peak disappeared FOAM) R.csv
# Downloaded output/txt/iemworld\Hisenior MEGA5P (Orignal silicone Eartips) L.txt
# Converted output/txt/iemworld\Hisenior MEGA5P (Orignal silicone Eartips) L.txt to output/csv/iemworld\Hisenior MEGA5P (Orignal silicone Eartips) L.csv
# Downloaded output/txt/iemworld\Hisenior MEGA5P (Orignal silicone Eartips) R.txt
# Converted output/txt/iemworld\Hisenior MEGA5P (Orignal silicone Eartips) R.txt to output/csv/iemworld\Hisenior MEGA5P (Orignal silicone Eartips) R.csv
# Downloaded output/txt/iemworld\Hisenior MEGA5P (Softears UC Eartips) L.txt
# Converted output/txt/iemworld\Hisenior MEGA5P (Softears UC Eartips) L.txt to output/csv/iemworld\Hisenior MEGA5P (Softears UC Eartips) L.csv
# Downloaded output/txt/iemworld\Hisenior MEGA5P (Softears UC Eartips) R.txt
# Converted output/txt/iemworld\Hisenior MEGA5P (Softears UC Eartips) R.txt to output/csv/iemworld\Hisenior MEGA5P (Softears UC Eartips) R.csv
# Downloaded output/txt/iemworld\IEM WORLD Target.txt
# Converted output/txt/iemworld\IEM WORLD Target.txt to output/csv/iemworld\IEM WORLD Target.csv
# Downloaded output/txt/iemworld\Innerfidelity ID Target.txt
# Converted output/txt/iemworld\Innerfidelity ID Target.txt to output/csv/iemworld\Innerfidelity ID Target.csv
# Downloaded output/txt/iemworld\KZ HBB DQ6S L.txt
# Converted output/txt/iemworld\KZ HBB DQ6S L.txt to output/csv/iemworld\KZ HBB DQ6S L.csv
# Downloaded output/txt/iemworld\KZ HBB DQ6S R.txt
# Converted output/txt/iemworld\KZ HBB DQ6S R.txt to output/csv/iemworld\KZ HBB DQ6S R.csv
# Downloaded output/txt/iemworld\KZ ZEX L.txt
# Converted output/txt/iemworld\KZ ZEX L.txt to output/csv/iemworld\KZ ZEX L.csv
# Downloaded output/txt/iemworld\KZ ZEX R.txt
# Converted output/txt/iemworld\KZ ZEX R.txt to output/csv/iemworld\KZ ZEX R.csv
# Downloaded output/txt/iemworld\MoonDrop CHU L.txt
# Converted output/txt/iemworld\MoonDrop CHU L.txt to output/csv/iemworld\MoonDrop CHU L.csv
# Downloaded output/txt/iemworld\MoonDrop CHU R.txt
# Converted output/txt/iemworld\MoonDrop CHU R.txt to output/csv/iemworld\MoonDrop CHU R.csv
# ...
# Downloaded output/txt/iemworld\TINHIFI T2 EVO R.txt
# Converted output/txt/iemworld\TINHIFI T2 EVO R.txt to output/csv/iemworld\TINHIFI T2 EVO R.csv
# Downloaded output/txt/iemworld\TINHIFI T2 L.txt
# Converted output/txt/iemworld\TINHIFI T2 L.txt to output/csv/iemworld\TINHIFI T2 L.csv
# Downloaded output/txt/iemworld\TINHIFI T2 R.txt
# Converted output/txt/iemworld\TINHIFI T2 R.txt to output/csv/iemworld\TINHIFI T2 R.csv
# Downloaded output/txt/iemworld\TRI Meteor L.txt
# Converted output/txt/iemworld\TRI Meteor L.txt to output/csv/iemworld\TRI Meteor L.csv
# Downloaded output/txt/iemworld\TRI Meteor R.txt
# Converted output/txt/iemworld\TRI Meteor R.txt to output/csv/iemworld\TRI Meteor R.csv
# Downloaded output/txt/iemworld\TRI STARSEA (00) L.txt
# Converted output/txt/iemworld\TRI STARSEA (00) L.txt to output/csv/iemworld\TRI STARSEA (00) L.csv
# Downloaded output/txt/iemworld\TRI STARSEA (00) R.txt
# Converted output/txt/iemworld\TRI STARSEA (00) R.txt to output/csv/iemworld\TRI STARSEA (00) R.csv
# Downloaded output/txt/iemworld\TRI STARSEA (01) L.txt
# Converted output/txt/iemworld\TRI STARSEA (01) L.txt to output/csv/iemworld\TRI STARSEA (01) L.csv
# Downloaded output/txt/iemworld\TRI STARSEA (01) R.txt
# Converted output/txt/iemworld\TRI STARSEA (01) R.txt to output/csv/iemworld\TRI STARSEA (01) R.csv
# Downloaded output/txt/iemworld\TRI STARSEA (10) L.txt
# Converted output/txt/iemworld\TRI STARSEA (10) L.txt to output/csv/iemworld\TRI STARSEA (10) L.csv
# Downloaded output/txt/iemworld\TRI STARSEA (10) R.txt
# Converted output/txt/iemworld\TRI STARSEA (10) R.txt to output/csv/iemworld\TRI STARSEA (10) R.csv
# Downloaded output/txt/iemworld\TRI STARSEA (11) L.txt
# Converted output/txt/iemworld\TRI STARSEA (11) L.txt to output/csv/iemworld\TRI STARSEA (11) L.csv
# Downloaded output/txt/iemworld\TRI STARSEA (11) R.txt
# Converted output/txt/iemworld\TRI STARSEA (11) R.txt to output/csv/iemworld\TRI STARSEA (11) R.csv
# Downloaded output/txt/iemworld\TRN MT3 L.txt
# Converted output/txt/iemworld\TRN MT3 L.txt to output/csv/iemworld\TRN MT3 L.csv
# Downloaded output/txt/iemworld\TRN MT3 R.txt
# Converted output/txt/iemworld\TRN MT3 R.txt to output/csv/iemworld\TRN MT3 R.csv
# Downloaded output/txt/iemworld\TRN ST2 L.txt
# Converted output/txt/iemworld\TRN ST2 L.txt to output/csv/iemworld\TRN ST2 L.csv
# Downloaded output/txt/iemworld\TRN ST2 R.txt
# Converted output/txt/iemworld\TRN ST2 R.txt to output/csv/iemworld\TRN ST2 R.csv
# Downloaded output/txt/iemworld\TRN TA1 L.txt
# Converted output/txt/iemworld\TRN TA1 L.txt to output/csv/iemworld\TRN TA1 L.csv
# Downloaded output/txt/iemworld\TRN TA1 MAX L.txt
# Converted output/txt/iemworld\TRN TA1 MAX L.txt to output/csv/iemworld\TRN TA1 MAX L.csv
# Downloaded output/txt/iemworld\TRN TA1 MAX R.txt
# Converted output/txt/iemworld\TRN TA1 MAX R.txt to output/csv/iemworld\TRN TA1 MAX R.csv
# Downloaded output/txt/iemworld\TRN TA1 R.txt
# Converted output/txt/iemworld\TRN TA1 R.txt to output/csv/iemworld\TRN TA1 R.csv
# Downloaded output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Final E Eartips) L.txt
# Converted output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Final E Eartips) L.txt to output/csv/iemworld\TRUTHEAR x Crinacle ZERO (Final E Eartips) L.csv
# Downloaded output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Final E Eartips) R.txt
# Converted output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Final E Eartips) R.txt to output/csv/iemworld\TRUTHEAR x Crinacle ZERO (Final E Eartips) R.csv
# Downloaded output/txt/iemworld\TRUTHEAR x Crinacle ZERO (MoonDrop Eartips) L.txt
# Converted output/txt/iemworld\TRUTHEAR x Crinacle ZERO (MoonDrop Eartips) L.txt to output/csv/iemworld\TRUTHEAR x Crinacle ZERO (MoonDrop Eartips) L.csv
# Downloaded output/txt/iemworld\TRUTHEAR x Crinacle ZERO (MoonDrop Eartips) R.txt
# Converted output/txt/iemworld\TRUTHEAR x Crinacle ZERO (MoonDrop Eartips) R.txt to output/csv/iemworld\TRUTHEAR x Crinacle ZERO (MoonDrop Eartips) R.csv
# Downloaded output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Foam Eartips) L.txt
# Converted output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Foam Eartips) L.txt to output/csv/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Foam Eartips) L.csv
# Downloaded output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Foam Eartips) R.txt
# Converted output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Foam Eartips) R.txt to output/csv/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Foam Eartips) R.csv
# Downloaded output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Silicone Eartips) L.txt
# Converted output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Silicone Eartips) L.txt to output/csv/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Silicone Eartips) L.csv
# Downloaded output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Silicone Eartips) R.txt
# Converted output/txt/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Silicone Eartips) R.txt to output/csv/iemworld\TRUTHEAR x Crinacle ZERO (Orignal Silicone Eartips) R.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (BGVP Memory Cotton) L.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (BGVP Memory Cotton) L.txt to output/csv/iemworld\ThieAudio Monarch MK2 (BGVP Memory Cotton) L.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (BGVP Memory Cotton) R.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (BGVP Memory Cotton) R.txt to output/csv/iemworld\ThieAudio Monarch MK2 (BGVP Memory Cotton) R.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (Final Eartips) L.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (Final Eartips) L.txt to output/csv/iemworld\ThieAudio Monarch MK2 (Final Eartips) L.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (Final Eartips) R.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (Final Eartips) R.txt to output/csv/iemworld\ThieAudio Monarch MK2 (Final Eartips) R.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (Foam Eartips) L.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (Foam Eartips) L.txt to output/csv/iemworld\ThieAudio Monarch MK2 (Foam Eartips) L.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (Foam Eartips) R.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (Foam Eartips) R.txt to output/csv/iemworld\ThieAudio Monarch MK2 (Foam Eartips) R.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 87dB FOAM) L.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 87dB FOAM) L.txt to output/csv/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 87dB FOAM) L.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 87dB FOAM) R.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 87dB FOAM) R.txt to output/csv/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 87dB FOAM) R.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 95dB FOAM) L.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 95dB FOAM) L.txt to output/csv/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 95dB FOAM) L.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 95dB FOAM) R.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 95dB FOAM) R.txt to output/csv/iemworld\ThieAudio Monarch MK2 (NO TIP on Coupler 8K peak disappeared 95dB FOAM) R.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (Orignal silicone Eartips) L.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (Orignal silicone Eartips) L.txt to output/csv/iemworld\ThieAudio Monarch MK2 (Orignal silicone Eartips) L.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (Orignal silicone Eartips) R.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (Orignal silicone Eartips) R.txt to output/csv/iemworld\ThieAudio Monarch MK2 (Orignal silicone Eartips) R.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (Softears UC Eartips) L.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (Softears UC Eartips) L.txt to output/csv/iemworld\ThieAudio Monarch MK2 (Softears UC Eartips) L.csv
# Downloaded output/txt/iemworld\ThieAudio Monarch MK2 (Softears UC Eartips) R.txt
# Converted output/txt/iemworld\ThieAudio Monarch MK2 (Softears UC Eartips) R.txt to output/csv/iemworld\ThieAudio Monarch MK2 (Softears UC Eartips) R.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (2 Filter Final Eartips) L.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (2 Filter Final Eartips) L.txt to output/csv/iemworld\Tripowin x HBB Olina (2 Filter Final Eartips) L.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (2 Filter Final Eartips) R.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (2 Filter Final Eartips) R.txt to output/csv/iemworld\Tripowin x HBB Olina (2 Filter Final Eartips) R.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (2 Filter Foam Eartips) L.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (2 Filter Foam Eartips) L.txt to output/csv/iemworld\Tripowin x HBB Olina (2 Filter Foam Eartips) L.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (2 Filter Foam Eartips) R.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (2 Filter Foam Eartips) R.txt to output/csv/iemworld\Tripowin x HBB Olina (2 Filter Foam Eartips) R.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (2 Filter MoonDrop Eartips) L.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (2 Filter MoonDrop Eartips) L.txt to output/csv/iemworld\Tripowin x HBB Olina (2 Filter MoonDrop Eartips) L.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (2 Filter MoonDrop Eartips) R.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (2 Filter MoonDrop Eartips) R.txt to output/csv/iemworld\Tripowin x HBB Olina (2 Filter MoonDrop Eartips) R.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (2 Filter Orignal Eartips) L.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (2 Filter Orignal Eartips) L.txt to output/csv/iemworld\Tripowin x HBB Olina (2 Filter Orignal Eartips) L.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (2 Filter Orignal Eartips) R.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (2 Filter Orignal Eartips) R.txt to output/csv/iemworld\Tripowin x HBB Olina (2 Filter Orignal Eartips) R.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (Final Eartips) L.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (Final Eartips) L.txt to output/csv/iemworld\Tripowin x HBB Olina (Final Eartips) L.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (Final Eartips) R.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (Final Eartips) R.txt to output/csv/iemworld\Tripowin x HBB Olina (Final Eartips) R.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (Foam Eartips) L.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (Foam Eartips) L.txt to output/csv/iemworld\Tripowin x HBB Olina (Foam Eartips) L.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (Foam Eartips) R.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (Foam Eartips) R.txt to output/csv/iemworld\Tripowin x HBB Olina (Foam Eartips) R.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (MoonDrop Eartips) L.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (MoonDrop Eartips) L.txt to output/csv/iemworld\Tripowin x HBB Olina (MoonDrop Eartips) L.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (MoonDrop Eartips) R.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (MoonDrop Eartips) R.txt to output/csv/iemworld\Tripowin x HBB Olina (MoonDrop Eartips) R.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (Orignal Eartips) L.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (Orignal Eartips) L.txt to output/csv/iemworld\Tripowin x HBB Olina (Orignal Eartips) L.csv
# Downloaded output/txt/iemworld\Tripowin x HBB Olina (Orignal Eartips) R.txt
# Converted output/txt/iemworld\Tripowin x HBB Olina (Orignal Eartips) R.txt to output/csv/iemworld\Tripowin x HBB Olina (Orignal Eartips) R.csv
# Downloaded output/txt/iemworld\Truthear HEXA (FINAL E Tips) L.txt
# Converted output/txt/iemworld\Truthear HEXA (FINAL E Tips) L.txt to output/csv/iemworld\Truthear HEXA (FINAL E Tips) L.csv
# Downloaded output/txt/iemworld\Truthear HEXA (FINAL E Tips) R.txt
# Converted output/txt/iemworld\Truthear HEXA (FINAL E Tips) R.txt to output/csv/iemworld\Truthear HEXA (FINAL E Tips) R.csv
# Downloaded output/txt/iemworld\Truthear HEXA (FOAM Eartips) L.txt
# Converted output/txt/iemworld\Truthear HEXA (FOAM Eartips) L.txt to output/csv/iemworld\Truthear HEXA (FOAM Eartips) L.csv
# Downloaded output/txt/iemworld\Truthear HEXA (FOAM Eartips) R.txt
# Converted output/txt/iemworld\Truthear HEXA (FOAM Eartips) R.txt to output/csv/iemworld\Truthear HEXA (FOAM Eartips) R.csv
# Downloaded output/txt/iemworld\Truthear HEXA (NO TIP on Coupler) L.txt
# Converted output/txt/iemworld\Truthear HEXA (NO TIP on Coupler) L.txt to output/csv/iemworld\Truthear HEXA (NO TIP on Coupler) L.csv
# Downloaded output/txt/iemworld\Truthear HEXA (NO TIP on Coupler) R.txt
# Converted output/txt/iemworld\Truthear HEXA (NO TIP on Coupler) R.txt to output/csv/iemworld\Truthear HEXA (NO TIP on Coupler) R.csv
# Downloaded output/txt/iemworld\Truthear HEXA (Softears UC Eartips) L.txt
# Converted output/txt/iemworld\Truthear HEXA (Softears UC Eartips) L.txt to output/csv/iemworld\Truthear HEXA (Softears UC Eartips) L.csv
# Downloaded output/txt/iemworld\Truthear HEXA (Softears UC Eartips) R.txt
# Converted output/txt/iemworld\Truthear HEXA (Softears UC Eartips) R.txt to output/csv/iemworld\Truthear HEXA (Softears UC Eartips) R.csv
# Downloaded output/txt/iemworld\Truthear HOLA (Foam Eartips) L.txt
# Converted output/txt/iemworld\Truthear HOLA (Foam Eartips) L.txt to output/csv/iemworld\Truthear HOLA (Foam Eartips) L.csv
# Downloaded output/txt/iemworld\Truthear HOLA (Foam Eartips) R.txt
# Converted output/txt/iemworld\Truthear HOLA (Foam Eartips) R.txt to output/csv/iemworld\Truthear HOLA (Foam Eartips) R.csv
# Downloaded output/txt/iemworld\Truthear HOLA (NO TIP on Coupler) L.txt
# Converted output/txt/iemworld\Truthear HOLA (NO TIP on Coupler) L.txt to output/csv/iemworld\Truthear HOLA (NO TIP on Coupler) L.csv
# Downloaded output/txt/iemworld\Truthear HOLA (NO TIP on Coupler) R.txt
# Converted output/txt/iemworld\Truthear HOLA (NO TIP on Coupler) R.txt to output/csv/iemworld\Truthear HOLA (NO TIP on Coupler) R.csv
# Downloaded output/txt/iemworld\Truthear HOLA (wide bore silicone tips) L.txt
# Converted output/txt/iemworld\Truthear HOLA (wide bore silicone tips) L.txt to output/csv/iemworld\Truthear HOLA (wide bore silicone tips) L.csv
# Downloaded output/txt/iemworld\Truthear HOLA (wide bore silicone tips) R.txt
# Converted output/txt/iemworld\Truthear HOLA (wide bore silicone tips) R.txt to output/csv/iemworld\Truthear HOLA (wide bore silicone tips) R.csv
# Downloaded output/txt/iemworld\Whizzer Kylin HE03D L.txt
# Converted output/txt/iemworld\Whizzer Kylin HE03D L.txt to output/csv/iemworld\Whizzer Kylin HE03D L.csv
# Downloaded output/txt/iemworld\Whizzer Kylin HE03D R.txt
# Converted output/txt/iemworld\Whizzer Kylin HE03D R.txt to output/csv/iemworld\Whizzer Kylin HE03D R.csv
# Downloaded output/txt/iemworld\ikko OH10 (Foam Eartips) L.txt
# Converted output/txt/iemworld\ikko OH10 (Foam Eartips) L.txt to output/csv/iemworld\ikko OH10 (Foam Eartips) L.csv
# Downloaded output/txt/iemworld\ikko OH10 (Foam Eartips) R.txt
# Converted output/txt/iemworld\ikko OH10 (Foam Eartips) R.txt to output/csv/iemworld\ikko OH10 (Foam Eartips) R.csv
# Downloaded output/txt/iemworld\ikko OH10 (NO TIP on Coupler) L.txt
# Converted output/txt/iemworld\ikko OH10 (NO TIP on Coupler) L.txt to output/csv/iemworld\ikko OH10 (NO TIP on Coupler) L.csv
# Downloaded output/txt/iemworld\ikko OH10 (NO TIP on Coupler) R.txt
# Converted output/txt/iemworld\ikko OH10 (NO TIP on Coupler) R.txt to output/csv/iemworld\ikko OH10 (NO TIP on Coupler) R.csv
