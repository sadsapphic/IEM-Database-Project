# %%
import os
import re
from collections import defaultdict

def extract_iem_name(file_name):
    # Remove special cases and channel indicators
    file_name = re.sub(r'\s*(L|R|Springtips|CP100\+|220ohm|Broken|Manufacturer Measurment)\s*', '', file_name, flags=re.IGNORECASE)
    
    # Remove file extension
    file_name = os.path.splitext(file_name)[0]
    
    # Normalize the IEM name
    return file_name.strip().lower()

reviewers = [
    'achoreviews', 'aftersound', 'animagus', 'arn', 'bedrock',
    'bryaudioreviews', 'cammyfi', 'soundjedi', 'eplv', 'timmyv',
    'harpo', 'hbb', 'cqtek', 'hobbytalk', 'ianfann',
    'iemworld', 'jacstone', 'kr0mka', 'kurin', 'melatonin',
    'nymz', 'pw', 'recode', 'rg', 'shortbus',
    'suporsalad', 'tgx78', 'vortexreviews', 'vsg', 'wdym',
    'akros', 'data_mrs'
]

grouped_data = defaultdict(list)

for reviewer in reviewers:
    directory = os.path.join("output", "csv", reviewer)
    
    for file_name in os.listdir(directory):
        # Group files with "target" in their name under the "target" group
        if 'target' in file_name.lower():
            iem_name = 'target'
        else:
            iem_name = extract_iem_name(file_name)
        
        # Add the file path and the reviewer to the grouped_data
        grouped_data[iem_name].append((os.path.join(directory, file_name), reviewer))

for iem, measurements in grouped_data.items():
    print(f"{iem}:")
    for measurement in measurements:
        print(f"  {measurement}")
# Out:
# 7hz dioko:
#   ('output\\csv\\achoreviews\\7Hz Dioko L.csv', 'achoreviews')
#   ('output\\csv\\bedrock\\7Hz Dioko L.csv', 'bedrock')
#   ('output\\csv\\bedrock\\7Hz Dioko R.csv', 'bedrock')
#   ('output\\csv\\timmyv\\7Hz Dioko L.csv', 'timmyv')
#   ('output\\csv\\timmyv\\7Hz Dioko R.csv', 'timmyv')
#   ('output\\csv\\hbb\\7Hz Dioko R.csv', 'hbb')
#   ('output\\csv\\hobbytalk\\7hz Dioko L.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\7hz Dioko R.csv', 'hobbytalk')
#   ('output\\csv\\ianfann\\7HZ DIOKO L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\7HZ DIOKO R.csv', 'ianfann')
#   ('output\\csv\\iemworld\\7Hz Dioko L.csv', 'iemworld')
#   ('output\\csv\\iemworld\\7Hz Dioko R.csv', 'iemworld')
#   ('output\\csv\\data_mrs\\7Hz Dioko L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\7Hz Dioko R.csv', 'data_mrs')
# 7hz etena:
#   ('output\\csv\\achoreviews\\7Hz Eternal L.csv', 'achoreviews')
#   ('output\\csv\\bedrock\\7Hz Eternal L.csv', 'bedrock')
#   ('output\\csv\\bedrock\\7Hz Eternal R.csv', 'bedrock')
#   ('output\\csv\\harpo\\7Hz Eternal R.csv', 'harpo')
#   ('output\\csv\\hbb\\7Hz Eternal R.csv', 'hbb')
#   ('output\\csv\\iemworld\\7Hz ETERNAL L.csv', 'iemworld')
#   ('output\\csv\\iemworld\\7Hz ETERNAL R.csv', 'iemworld')
#   ('output\\csv\\vortexreviews\\7hz Eternal L.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\7hz Eternal R.csv', 'vortexreviews')
#   ('output\\csv\\vsg\\7Hz Eternal L.csv', 'vsg')
#   ('output\\csv\\vsg\\7Hz Eternal R.csv', 'vsg')
# 7hzegato:
#   ('output\\csv\\achoreviews\\7Hz Legato L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\7HZ LEGATO L.csv', 'aftersound')
#   ('output\\csv\\aftersound\\7HZ LEGATO R.csv', 'aftersound')
#   ('output\\csv\\timmyv\\7Hz Legato L.csv', 'timmyv')
#   ('output\\csv\\timmyv\\7Hz Legato R.csv', 'timmyv')
#   ('output\\csv\\hbb\\7Hz Legato R.csv', 'hbb')
#   ('output\\csv\\cqtek\\7Hz Legato L.csv', 'cqtek')
#   ('output\\csv\\cqtek\\7Hz Legato R.csv', 'cqtek')
#   ('output\\csv\\ianfann\\7HZ LEGATO L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\7HZ LEGATO R.csv', 'ianfann')
#   ('output\\csv\\nymz\\7hz LEGATO L.csv', 'nymz')
#   ('output\\csv\\nymz\\7hz LEGATO R.csv', 'nymz')
#   ('output\\csv\\rg\\7hz Legato L.csv', 'rg')
#   ('output\\csv\\rg\\7hz Legato R.csv', 'rg')
#   ('output\\csv\\vortexreviews\\7hz Legato L.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\7hz Legato R.csv', 'vortexreviews')
#   ('output\\csv\\vsg\\7Hz Legato L.csv', 'vsg')
#   ('output\\csv\\vsg\\7Hz Legato R.csv', 'vsg')
# 7hz timeess:
#   ('output\\csv\\achoreviews\\7Hz Timeless L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\7HZ TIMELESS L.csv', 'aftersound')
#   ('output\\csv\\aftersound\\7HZ TIMELESS R.csv', 'aftersound')
#   ('output\\csv\\arn\\7Hz Timeless L.csv', 'arn')
#   ('output\\csv\\soundjedi\\7Hz Timeless L.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\7Hz Timeless R.csv', 'soundjedi')
#   ('output\\csv\\timmyv\\7Hz Timeless L.csv', 'timmyv')
#   ('output\\csv\\timmyv\\7Hz Timeless R.csv', 'timmyv')
#   ('output\\csv\\harpo\\7Hz Timeless R.csv', 'harpo')
#   ('output\\csv\\hobbytalk\\7hz Timeless L.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\7hz Timeless R.csv', 'hobbytalk')
#   ('output\\csv\\pw\\7Hz Timeless L.csv', 'pw')
#   ('output\\csv\\pw\\7Hz Timeless R.csv', 'pw')
#   ('output\\csv\\rg\\7Hz Timeless L.csv', 'rg')
#   ('output\\csv\\rg\\7Hz Timeless R.csv', 'rg')
#   ('output\\csv\\tgx78\\7hz Timeless L.csv', 'tgx78')
#   ('output\\csv\\tgx78\\7hz Timeless R.csv', 'tgx78')
#   ('output\\csv\\vortexreviews\\7hz Timeless L.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\7hz Timeless R.csv', 'vortexreviews')
#   ('output\\csv\\vsg\\7Hz Timeless L.csv', 'vsg')
#   ('output\\csv\\vsg\\7Hz Timeless R.csv', 'vsg')
#   ('output\\csv\\data_mrs\\7Hz Timeless L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\7Hz Timeless R.csv', 'data_mrs')
# 7hz zeo:
#   ('output\\csv\\achoreviews\\7Hz Zero L.csv', 'achoreviews')
#   ('output\\csv\\bedrock\\7Hz Zero L.csv', 'bedrock')
#   ('output\\csv\\bedrock\\7Hz Zero R.csv', 'bedrock')
#   ('output\\csv\\timmyv\\7Hz Zero L.csv', 'timmyv')
#   ('output\\csv\\timmyv\\7Hz Zero R.csv', 'timmyv')
#   ('output\\csv\\hbb\\7hz Zero R.csv', 'hbb')
#   ('output\\csv\\hobbytalk\\7hz Zero L.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\7hz Zero R.csv', 'hobbytalk')
#   ('output\\csv\\ianfann\\7HZ ZERO L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\7HZ ZERO R.csv', 'ianfann')
#   ('output\\csv\\data_mrs\\7Hz Zero L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\7Hz Zero R.csv', 'data_mrs')
# target:
#   ('output\\csv\\achoreviews\\Acho Reviews Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Antdroid Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Bad Guy Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Banbeucmas Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Crinacle Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Diffuse Field Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Etymotic Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Free Field Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Harman Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Innerfidelity ID Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Precogvision Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Rtings Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Sonarworks Target.csv', 'achoreviews')
#   ('output\\csv\\achoreviews\\Super Review Target.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\Antdroid Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Bad Guy Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Banbeucmas Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Crinacle Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Diffuse Field Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Etymotic Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Free Field Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Harman Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\IEF neutral Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Innerfidelity ID Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Innerfidelity Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Precogvision Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Rtings Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Sonarworks Target.csv', 'aftersound')
#   ('output\\csv\\aftersound\\Super Review Target.csv', 'aftersound')
#   ('output\\csv\\animagus\\Animagus Neutral Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Animagus Preference Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Antdroid Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Bad Guy Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Banbeucmas Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Crinacle Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Diffuse Field Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Etymotic Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Free Field Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Harman In Ear 2019 Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Harman In Room Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Harman Over Ear 2018 Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Harman Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Innerfidelity ID Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Precogvision Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Rtings Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Sonarworks Target.csv', 'animagus')
#   ('output\\csv\\animagus\\Super Review Target.csv', 'animagus')
#   ('output\\csv\\arn\\Antdroid Target.csv', 'arn')
#   ('output\\csv\\arn\\Bad Guy Target.csv', 'arn')
#   ('output\\csv\\arn\\Banbeucmas Target.csv', 'arn')
#   ('output\\csv\\arn\\Crinacle Target.csv', 'arn')
#   ('output\\csv\\arn\\Diffuse Field Target.csv', 'arn')
#   ('output\\csv\\arn\\Etymotic Target.csv', 'arn')
#   ('output\\csv\\arn\\Free Field Target.csv', 'arn')
#   ('output\\csv\\arn\\Harman Target.csv', 'arn')
#   ('output\\csv\\arn\\Harman V2 Target.csv', 'arn')
#   ('output\\csv\\arn\\Innerfidelity ID Target.csv', 'arn')
#   ('output\\csv\\arn\\Precogvision Target.csv', 'arn')
#   ('output\\csv\\arn\\Rtings Target.csv', 'arn')
#   ('output\\csv\\arn\\Sonarworks Target.csv', 'arn')
#   ('output\\csv\\arn\\Super Review Target.csv', 'arn')
#   ('output\\csv\\bedrock\\Antdroid Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Bad Guy Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Banbeucmas Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Crinacle Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Diffuse Field Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Etymotic Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Free Field Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Harman Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Innerfidelity ID Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Precogvision Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Rtings Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Sonarworks Target.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Super Review Target.csv', 'bedrock')
#   ('output\\csv\\bryaudioreviews\\Antdroid Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Bad Guy Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Banbeucmas Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Bry Audio Reviews Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Crinacle IEF-Neutral Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Crinacle Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Diffuse Field Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Etymotic Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Free Field Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Harman 2017 Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Harman 2019 Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Harman Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Innerfidelity ID Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Oratory1990 Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Precogvision Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Rtings Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Sonarworks Target.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Super Review Target.csv', 'bryaudioreviews')
#   ('output\\csv\\cammyfi\\Antdroid Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Bad Guy Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Banbeucmas Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\CammyFi Neutral Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\CammyFi Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Crinacle Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Diffuse Field Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Etymotic Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Free Field Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Harman IE 2019 v2 Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Harman Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Innerfidelity ID Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Kurin Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Precogvision Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Rtings Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Sonarworks Target.csv', 'cammyfi')
#   ('output\\csv\\cammyfi\\Super Review Target.csv', 'cammyfi')
#   ('output\\csv\\soundjedi\\Antdroid Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Bad Guy Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Banbeucmas Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Crinacle Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Diffuse Field Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Etymotic Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Free Field Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Harman Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Innerfidelity ID Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Precogvision Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Rtings Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Sonarworks Target.csv', 'soundjedi')
#   ('output\\csv\\soundjedi\\Super Review Target.csv', 'soundjedi')
#   ('output\\csv\\eplv\\Antdroid Target.csv', 'eplv')
#   ('output\\csv\\eplv\\AutoEQ Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Bad Guy Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Banbeucmas Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Diffuse Field Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Etymotic Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Free Field Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Harman Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Harman2019v2 Target.csv', 'eplv')
#   ('output\\csv\\eplv\\IEF Neutral Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Innerfidelity ID Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Old Crinacle Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Precogvision Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Rtings Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Sonarworks Target.csv', 'eplv')
#   ('output\\csv\\eplv\\Super Review Target.csv', 'eplv')
#   ('output\\csv\\timmyv\\Antdroid Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Bad Guy Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Banbeucmas Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Crinacle Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Diffuse Field Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Etymotic Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Free Field Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Harman Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\IEF Neutral Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Innerfidelity ID Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Nymz Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Precogvision Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Rtings Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Sonarworks Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Super Review Target.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Timmy Target.csv', 'timmyv')
#   ('output\\csv\\harpo\\Antdroid Target.csv', 'harpo')
#   ('output\\csv\\harpo\\AX Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Bad Guy 2022 Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Bad Guy Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Banbeucmas Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Crinacle Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Diffuse Field Target.csv', 'harpo')
#   ('output\\csv\\harpo\\EJ Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Etymotic Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Free Field Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Harman Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Harpo Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Harpo v3 Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Harpo v4 Target (11.03.2023 02-43-36).csv', 'harpo')
#   ('output\\csv\\harpo\\Harpo v4 Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Harpo_v2 Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Innerfidelity ID Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Precogvision Target.csv', 'harpo')
#   ('output\\csv\\harpo\\RikudouGoku Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Rtings Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Softears Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Sonarworks Target.csv', 'harpo')
#   ('output\\csv\\harpo\\Super Review Target.csv', 'harpo')
#   ('output\\csv\\harpo\\X Target.csv', 'harpo')
#   ('output\\csv\\hbb\\Antdroid Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Bad Guy 2022 Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Bad Guy Target v2.csv', 'hbb')
#   ('output\\csv\\hbb\\Bad Guy Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Crinacle Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Diffuse Field Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Etymotic Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Free Field Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Harman Target.csv', 'hbb')
#   ('output\\csv\\hbb\\IEF Target.csv', 'hbb')
#   ('output\\csv\\hbb\\MRS Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Precog Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Precog_broken Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Redeyes Target.csv', 'hbb')
#   ('output\\csv\\hbb\\RikudouGoku Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Rtings Target.csv', 'hbb')
#   ('output\\csv\\hbb\\Sonarworks Target.csv', 'hbb')
#   ('output\\csv\\cqtek\\Antdroid Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Bad Guy Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Banbeucmas Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Crinacle Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Diffuse Field Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Etymotic Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Free Field Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Harman Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Innerfidelity ID Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Precogvision Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Rtings Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Sonarworks Target.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Super Review Target.csv', 'cqtek')
#   ('output\\csv\\hobbytalk\\Antdroid Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Bad Guy Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Banbeucmas Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Diffuse Field Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Etymotic Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Free Field Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Harman IE 2019 Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Harman Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Hobby Talk Flat Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Hobby Talk Preference Target OG.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Hobby Talk Preference Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Honest Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\IEF Neutral Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\IEF OE Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Innerfidelity ID Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Precogvision Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Rtings Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Sonarworks Target.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\Super Review Target.csv', 'hobbytalk')
#   ('output\\csv\\ianfann\\Antdroid Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Bad Guy Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Banbeucmas Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Crinacle Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Diffuse Field Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Etymotic Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Free Field Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Harman 2017 Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Harman 2019 Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\IanFann-Target Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\IEF Neutral 2023 Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\IEF Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\IEF Target1.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Innerfidelity ID Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Precogvision Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Rtings Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Sonarworks Target.csv', 'ianfann')
#   ('output\\csv\\ianfann\\Super Review Target.csv', 'ianfann')
#   ('output\\csv\\iemworld\\Antdroid Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Bad Guy Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Banbeucmas Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Crinacle Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Diffuse Field Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Etymotic Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Free Field Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Harman Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\IEM WORLD Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Innerfidelity ID Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Precogvision Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Rtings Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Sonarworks Target.csv', 'iemworld')
#   ('output\\csv\\iemworld\\Super Review Target.csv', 'iemworld')
#   ('output\\csv\\jacstone\\Harman 2019 Target.csv', 'jacstone')
#   ('output\\csv\\jacstone\\IEF Neutral Target.csv', 'jacstone')
#   ('output\\csv\\jacstone\\nymz Target.csv', 'jacstone')
#   ('output\\csv\\jacstone\\Paul Wasabii Target.csv', 'jacstone')
#   ('output\\csv\\jacstone\\RikudouGoku Target.csv', 'jacstone')
#   ('output\\csv\\jacstone\\Sharur Target.csv', 'jacstone')
#   ('output\\csv\\kr0mka\\Antdroid Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Bad Guy Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Banbeucmas Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Crinacle Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Diffuse Field Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Etymotic Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Free Field Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Harman IE 2016 Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Harman IE 2017 v2 Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Harman IE 2019 v2 Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Innerfidelity ID Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\kr0mka Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Precogvision Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Rtings Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Sonarworks Target.csv', 'kr0mka')
#   ('output\\csv\\kr0mka\\Super Review Target.csv', 'kr0mka')
#   ('output\\csv\\kurin\\Antdroid Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Bad Guy 2022 Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Banbeucmas Target.csv', 'kurin')
#   ('output\\csv\\kurin\\CammyFi Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Coda Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Comfy Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Crinacle Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Diffuse Field Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Etymotic Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Flat Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Freeryder05v2 Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Harman IE 2016 Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Harman IE 2019 v2 Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Hobby Talk Preference Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Hobby Talk Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Kurin Target.csv', 'kurin')
#   ('output\\csv\\kurin\\markanini Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Moondrop Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Normative Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Objectively Neutral IE Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Olive-Welti Harman Bass Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Olive-Welti Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Oratory IE Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Precog Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Redeyes Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Rikudogoku Target.csv', 'kurin')
#   ('output\\csv\\kurin\\RikudouGoku Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Rtings Target.csv', 'kurin')
#   ('output\\csv\\kurin\\SEAP Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Sharur Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Srg0mes Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Super 22 Target.csv', 'kurin')
#   ('output\\csv\\kurin\\Timmy Target.csv', 'kurin')
#   ('output\\csv\\melatonin\\Antdroid Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Bad Guy Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Banbeucmas Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Crinacle Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Diffuse Field Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Etymotic Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Free Field Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Harman Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Innerfidelity ID Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Precogvision Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Rtings Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Sonarworks Target.csv', 'melatonin')
#   ('output\\csv\\melatonin\\Super Review Target.csv', 'melatonin')
#   ('output\\csv\\nymz\\Antdroid Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Bad Guy Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Banbeucmas Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Crinacle Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Diffuse Field Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Etymotic Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Free Field Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Harman 2019v2 Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Harman Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Innerfidelity ID Target.csv', 'nymz')
#   ('output\\csv\\nymz\\nymz Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Precogvision Target.csv', 'nymz')
#   ('output\\csv\\nymz\\RikudouGoku Target.csv', 'nymz')
#   ('output\\csv\\nymz\\RikudouGoku_Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Rtings Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Sonarworks Target.csv', 'nymz')
#   ('output\\csv\\nymz\\Super Review Target.csv', 'nymz')
#   ('output\\csv\\nymz\\tgx78 Target.csv', 'nymz')
#   ('output\\csv\\pw\\Antdroid Target.csv', 'pw')
#   ('output\\csv\\pw\\AutoEQ Target.csv', 'pw')
#   ('output\\csv\\pw\\Bad Guy Target.csv', 'pw')
#   ('output\\csv\\pw\\Banbeucmas Target.csv', 'pw')
#   ('output\\csv\\pw\\Crackhead Target.csv', 'pw')
#   ('output\\csv\\pw\\Crinacle Target.csv', 'pw')
#   ('output\\csv\\pw\\Diffuse Field Target.csv', 'pw')
#   ('output\\csv\\pw\\Etymotic Target.csv', 'pw')
#   ('output\\csv\\pw\\Free Field Target.csv', 'pw')
#   ('output\\csv\\pw\\Harman 2019v2 Target.csv', 'pw')
#   ('output\\csv\\pw\\Harman Target.csv', 'pw')
#   ('output\\csv\\pw\\Innerfidelity ID Target.csv', 'pw')
#   ('output\\csv\\pw\\Oratory1990 Target.csv', 'pw')
#   ('output\\csv\\pw\\PaulWasabii Target.csv', 'pw')
#   ('output\\csv\\pw\\Precogvision Target.csv', 'pw')
#   ('output\\csv\\pw\\Redeyes Target.csv', 'pw')
#   ('output\\csv\\pw\\RikudouGoku Target.csv', 'pw')
#   ('output\\csv\\pw\\Rtings Target.csv', 'pw')
#   ('output\\csv\\pw\\Sonarworks Target.csv', 'pw')
#   ('output\\csv\\pw\\Super Review Target.csv', 'pw')
#   ('output\\csv\\recode\\Antdroid Target.csv', 'recode')
#   ('output\\csv\\recode\\Bad Guy Target.csv', 'recode')
#   ('output\\csv\\recode\\Banbeucmas Target.csv', 'recode')
#   ('output\\csv\\recode\\Crinacle Neutral Target.csv', 'recode')
#   ('output\\csv\\recode\\Diffuse Field Target.csv', 'recode')
#   ('output\\csv\\recode\\Etymotic Target.csv', 'recode')
#   ('output\\csv\\recode\\Free Field Target.csv', 'recode')
#   ('output\\csv\\recode\\Harman 2017v2 Target.csv', 'recode')
#   ('output\\csv\\recode\\Harman Target.csv', 'recode')
#   ('output\\csv\\recode\\Innerfidelity ID Target.csv', 'recode')
#   ('output\\csv\\recode\\Precogvision Target.csv', 'recode')
#   ('output\\csv\\recode\\Recode Neutral Target.csv', 'recode')
#   ('output\\csv\\recode\\Recode Target.csv', 'recode')
#   ('output\\csv\\recode\\Recode Warm Neutral Target.csv', 'recode')
#   ('output\\csv\\recode\\Rtings Target.csv', 'recode')
#   ('output\\csv\\recode\\Sonarworks Target.csv', 'recode')
#   ('output\\csv\\recode\\Super Review Target.csv', 'recode')
#   ('output\\csv\\recode\\target 8.csv', 'recode')
#   ('output\\csv\\rg\\ALPHA 1.0 Target.csv', 'rg')
#   ('output\\csv\\rg\\Amelie Target.csv', 'rg')
#   ('output\\csv\\rg\\Antdroid Target.csv', 'rg')
#   ('output\\csv\\rg\\Bad Guy Target.csv', 'rg')
#   ('output\\csv\\rg\\Banbeucmas Target.csv', 'rg')
#   ('output\\csv\\rg\\Crackhead Target.csv', 'rg')
#   ('output\\csv\\rg\\Diffuse Field Target.csv', 'rg')
#   ('output\\csv\\rg\\DynamicEars Target.csv', 'rg')
#   ('output\\csv\\rg\\Etymotic Target.csv', 'rg')
#   ('output\\csv\\rg\\evasb Target.csv', 'rg')
#   ('output\\csv\\rg\\Free Field Target.csv', 'rg')
#   ('output\\csv\\rg\\Harman 2017v2 Target.csv', 'rg')
#   ('output\\csv\\rg\\Harman 2019v2 Target.csv', 'rg')
#   ('output\\csv\\rg\\Harpo Target.csv', 'rg')
#   ('output\\csv\\rg\\IEF Neutral 2020 Target.csv', 'rg')
#   ('output\\csv\\rg\\IEF Neutral 2023 Target.csv', 'rg')
#   ('output\\csv\\rg\\Innerfidelity ID Target.csv', 'rg')
#   ('output\\csv\\rg\\Lixeem Target.csv', 'rg')
#   ('output\\csv\\rg\\nymz Target.csv', 'rg')
#   ('output\\csv\\rg\\Precogvision Target.csv', 'rg')
#   ('output\\csv\\rg\\PW Target.csv', 'rg')
#   ('output\\csv\\rg\\Resolution Target.csv', 'rg')
#   ('output\\csv\\rg\\RikudouGoku Target.csv', 'rg')
#   ('output\\csv\\rg\\Rtings Target.csv', 'rg')
#   ('output\\csv\\rg\\Sonarworks Target.csv', 'rg')
#   ('output\\csv\\rg\\stakk Target.csv', 'rg')
#   ('output\\csv\\rg\\Super Bass Target.csv', 'rg')
#   ('output\\csv\\rg\\Super Review 2021 Target.csv', 'rg')
#   ('output\\csv\\rg\\Super Review 2022 Target.csv', 'rg')
#   ('output\\csv\\rg\\Talbot Target.csv', 'rg')
#   ('output\\csv\\rg\\tgx78 Target.csv', 'rg')
#   ('output\\csv\\rg\\TKSilver Target.csv', 'rg')
#   ('output\\csv\\shortbus\\Antdroid Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Bad Guy Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Banbeucmas Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Crinacle Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Diffuse Field Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Etymotic Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Free Field Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Harman Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Innerfidelity ID Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Precogvision Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Redeyes 1 Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Rtings Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Sonarworks Target.csv', 'shortbus')
#   ('output\\csv\\shortbus\\Super Review Target.csv', 'shortbus')
#   ('output\\csv\\suporsalad\\Antdroid Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Bad Guy Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Banbeucmas Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\DF Tilt 711 Ref Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Diffuse Field Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Etymotic Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Free Field Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Harman IEM Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Harman OE Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Harman Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\IEF Neutral 2020 Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\IEF Neutral 2023 Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Innerfidelity ID Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Kemar DF 1.3 Bass Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Kemar DF 1.3 Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Kemar DF Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Listener Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Precogvision Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Rtings Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Sonarworks Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Super Review Target.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\USound1V1 Oratory 1990 Target.csv', 'suporsalad')
#   ('output\\csv\\tgx78\\Antdroid Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Bad Guy Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Banbeucmas Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Crinacle Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Diffuse Field Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Etymotic Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Free Field Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Harman Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Innerfidelity ID Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Precogvision Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\RikudouGoku Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Rtings Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Sonarworks Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Super Review Target.csv', 'tgx78')
#   ('output\\csv\\tgx78\\Tgx78 Target.csv', 'tgx78')
#   ('output\\csv\\vortexreviews\\Antdroid Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Bad Guy Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Banbeucmas Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Crinacle Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Diffuse Field Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Etymotic Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Free Field Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Harman Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Innerfidelity ID Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Oratory1990 Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Precogvision Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\RikudouGoku Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Rtings Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Sonarworks Target.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Super Review Target.csv', 'vortexreviews')
#   ('output\\csv\\vsg\\Antdroid Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Bad Guy Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Banbeucmas Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Crinacle Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Diffuse Field Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Etymotic Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Free Field Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Harman 2018 Over-Ear Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Harman 2019 In-Ear Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Harman Combined Over-Ear Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Harman In-Ear Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Innerfidelity ID Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Precogvision Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Rtings Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Sonarworks Target.csv', 'vsg')
#   ('output\\csv\\vsg\\Super Review Target.csv', 'vsg')
#   ('output\\csv\\vsg\\VSG Target.csv', 'vsg')
#   ('output\\csv\\wdym\\Antdroid Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Bad Guy Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Banbeucmas Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Crinacle Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Diffuse Field Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Etymotic Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Free Field Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Harman Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Innerfidelity ID Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Precogvision Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Rtings Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Sonarworks Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Super Review Target.csv', 'wdym')
#   ('output\\csv\\wdym\\Wdym Target.csv', 'wdym')
#   ('output\\csv\\akros\\Antdroid Target.csv', 'akros')
#   ('output\\csv\\akros\\Bad Guy Target.csv', 'akros')
#   ('output\\csv\\akros\\Banbeucmas Target.csv', 'akros')
#   ('output\\csv\\akros\\Crinacle Target.csv', 'akros')
#   ('output\\csv\\akros\\Diffuse Field Target.csv', 'akros')
#   ('output\\csv\\akros\\Etymotic Target.csv', 'akros')
#   ('output\\csv\\akros\\Free Field Target.csv', 'akros')
#   ('output\\csv\\akros\\Harman Target.csv', 'akros')
#   ('output\\csv\\akros\\Innerfidelity ID Target.csv', 'akros')
#   ('output\\csv\\akros\\Precogvision Target.csv', 'akros')
#   ('output\\csv\\akros\\Rtings Target.csv', 'akros')
#   ('output\\csv\\akros\\Sonarworks Target.csv', 'akros')
#   ('output\\csv\\akros\\Super Review Target.csv', 'akros')
#   ('output\\csv\\data_mrs\\Antdroid Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Bad Guy Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Banbeucmas Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Crinacle 2023 Adjusted Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Crinacle Adjusted Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Crinacle Neutral 2023 Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Crinacle Neutral Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Crinacle Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Dent Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\dentReviews Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Diffuse Field Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Etymotic Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Ghost Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Harman Adjusted Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Harman Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\HBB Comp Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\HPDC 10dB Tilt 5128 DF 100Hz Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\HPDC 10dB Tilt 5128 DF Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\HPDC 10dB Tilt KEMAR DF 100Hz Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\HPDC 10dB Tilt KEMAR DF Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\HPDC 14dB Tilt 5128 DF 100Hz Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\HPDC 14dB Tilt 5128 DF Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\HPDC 14dB Tilt KEMAR DF 100Hz Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\HPDC 14dB Tilt KEMAR DF Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\IEC711 Comp Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\IEF Comp Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Moondrop Alice (EQ In-Ear Target) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Moondrop Alice (EQ In-Ear Target) R.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Moondrop Blessing 2 Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Precogvision Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\RikudouGoku Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Super 21 Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Super 22 Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Super Bass Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Super Review Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Working 001 Target.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Working 002 Target.csv', 'data_mrs')
# audeze isinex (spinfit):
#   ('output\\csv\\achoreviews\\Audeze iSine LX (Spinfit) L.csv', 'achoreviews')
# aune jaspe:
#   ('output\\csv\\achoreviews\\Aune Jasper L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\AUNE JASPER L.csv', 'aftersound')
#   ('output\\csv\\aftersound\\AUNE JASPER R.csv', 'aftersound')
#   ('output\\csv\\hbb\\Aune Jasper R.csv', 'hbb')
#   ('output\\csv\\data_mrs\\Aune Jasper L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Aune Jasper R.csv', 'data_mrs')
# bon b01:
#   ('output\\csv\\achoreviews\\Blon BL01 L.csv', 'achoreviews')
#   ('output\\csv\\bryaudioreviews\\BLON BL01 L.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\BLON BL01 R.csv', 'bryaudioreviews')
#   ('output\\csv\\pw\\BLON BL01 L.csv', 'pw')
# bon b03:
#   ('output\\csv\\achoreviews\\Blon BL03 L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\BLON BL03 R.csv', 'aftersound')
#   ('output\\csv\\bryaudioreviews\\BLON BL03 L.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\BLON BL03 R.csv', 'bryaudioreviews')
#   ('output\\csv\\timmyv\\Blon BL03 L.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Blon BL03 R.csv', 'timmyv')
#   ('output\\csv\\ianfann\\BLON BL03 L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\BLON BL03 R.csv', 'ianfann')
#   ('output\\csv\\suporsalad\\Blon BL03 L.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\Blon BL03 R.csv', 'suporsalad')
#   ('output\\csv\\data_mrs\\Blon BL03 L.csv', 'data_mrs')
# bon b05s:
#   ('output\\csv\\achoreviews\\Blon BL05s L.csv', 'achoreviews')
#   ('output\\csv\\pw\\BLON BL05S L.csv', 'pw')
# bon fat gi:
#   ('output\\csv\\achoreviews\\Blon Fat Girl L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\BLON FAT GIRL L.csv', 'aftersound')
#   ('output\\csv\\aftersound\\BLON FAT GIRL R.csv', 'aftersound')
#   ('output\\csv\\hbb\\BLON Fat Girl R.csv', 'hbb')
#   ('output\\csv\\ianfann\\BLON FAT GIRL L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\BLON FAT GIRL R.csv', 'ianfann')
#   ('output\\csv\\jacstone\\BLON Fat Girl L.csv', 'jacstone')
#   ('output\\csv\\jacstone\\BLON Fat Girl R.csv', 'jacstone')
#   ('output\\csv\\pw\\BLON Fat Girl L.csv', 'pw')
#   ('output\\csv\\pw\\BLON Fat Girl R.csv', 'pw')
#   ('output\\csv\\vortexreviews\\Blon Fat Girl L.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Blon Fat Girl R.csv', 'vortexreviews')
# bon t1:
#   ('output\\csv\\achoreviews\\Blon T1 L.csv', 'achoreviews')
# bon t3:
#   ('output\\csv\\achoreviews\\Blon T3 L.csv', 'achoreviews')
# bon z200:
#   ('output\\csv\\achoreviews\\Blon Z200 L.csv', 'achoreviews')
#   ('output\\csv\\arn\\BLON Z200 L.csv', 'arn')
#   ('output\\csv\\harpo\\Blon Z200 L.csv', 'harpo')
#   ('output\\csv\\harpo\\Blon Z200 R.csv', 'harpo')
#   ('output\\csv\\ianfann\\BLON Z200 L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\BLON Z200 R.csv', 'ianfann')
#   ('output\\csv\\pw\\BLON Z200 L.csv', 'pw')
#   ('output\\csv\\pw\\BLON Z200 R.csv', 'pw')
#   ('output\\csv\\vortexreviews\\Blon Z200 L.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Blon Z200 R.csv', 'vortexreviews')
# cca ca:
#   ('output\\csv\\achoreviews\\CCA CRA L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\CCA CRA L.csv', 'aftersound')
#   ('output\\csv\\aftersound\\CCA CRA R.csv', 'aftersound')
#   ('output\\csv\\eplv\\CCA CRA L.csv', 'eplv')
#   ('output\\csv\\eplv\\CCA CRA R.csv', 'eplv')
#   ('output\\csv\\harpo\\CCA CRA R.csv', 'harpo')
#   ('output\\csv\\hbb\\CCA CRA R.csv', 'hbb')
#   ('output\\csv\\hobbytalk\\CCA CRA L.csv', 'hobbytalk')
#   ('output\\csv\\hobbytalk\\CCA CRA R.csv', 'hobbytalk')
#   ('output\\csv\\ianfann\\CCA CRA L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\CCA CRA R.csv', 'ianfann')
#   ('output\\csv\\jacstone\\CCA CRA L.csv', 'jacstone')
#   ('output\\csv\\jacstone\\CCA CRA R.csv', 'jacstone')
#   ('output\\csv\\melatonin\\CCA CRA L.csv', 'melatonin')
#   ('output\\csv\\melatonin\\CCA CRA R.csv', 'melatonin')
#   ('output\\csv\\nymz\\CCA CRA L.csv', 'nymz')
#   ('output\\csv\\nymz\\CCA CRA R.csv', 'nymz')
#   ('output\\csv\\pw\\CCA CRA L.csv', 'pw')
#   ('output\\csv\\pw\\CCA CRA R.csv', 'pw')
#   ('output\\csv\\rg\\CCA CRA L.csv', 'rg')
#   ('output\\csv\\rg\\CCA CRA R.csv', 'rg')
#   ('output\\csv\\suporsalad\\CCA CRA L.csv', 'suporsalad')
#   ('output\\csv\\suporsalad\\CCA CRA R.csv', 'suporsalad')
#   ('output\\csv\\tgx78\\CCA CRA L.csv', 'tgx78')
#   ('output\\csv\\vortexreviews\\CCA CRA L.csv', 'vortexreviews')
#   ('output\\csv\\data_mrs\\CCA CRA L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\CCA CRA R.csv', 'data_mrs')
# cca ca pus:
#   ('output\\csv\\achoreviews\\CCA CRA Plus L.csv', 'achoreviews')
#   ('output\\csv\\timmyv\\CCA CRA Plus L.csv', 'timmyv')
#   ('output\\csv\\timmyv\\CCA CRA Plus R.csv', 'timmyv')
#   ('output\\csv\\pw\\CCA CRA Plus L.csv', 'pw')
#   ('output\\csv\\data_mrs\\CCA CRA Plus L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\CCA CRA Plus R.csv', 'data_mrs')
# ccz emead:
#   ('output\\csv\\achoreviews\\CCZ Emerald L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\CCZ EMERALD L.csv', 'aftersound')
#   ('output\\csv\\aftersound\\CCZ EMERALD R.csv', 'aftersound')
#   ('output\\csv\\eplv\\CCZ Emerald L.csv', 'eplv')
#   ('output\\csv\\eplv\\CCZ Emerald R.csv', 'eplv')
#   ('output\\csv\\melatonin\\CCZ emerald L.csv', 'melatonin')
#   ('output\\csv\\melatonin\\CCZ emerald R.csv', 'melatonin')
# ccz meody:
#   ('output\\csv\\achoreviews\\CCZ Melody L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\CCZ MELODY L.csv', 'aftersound')
#   ('output\\csv\\aftersound\\CCZ MELODY R.csv', 'aftersound')
#   ('output\\csv\\harpo\\CCZ Melody R.csv', 'harpo')
#   ('output\\csv\\ianfann\\CCZ MELODY L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\CCZ MELODY R.csv', 'ianfann')
#   ('output\\csv\\melatonin\\CCZ melody L.csv', 'melatonin')
#   ('output\\csv\\melatonin\\CCZ melody R.csv', 'melatonin')
#   ('output\\csv\\pw\\CCZ Melody L.csv', 'pw')
#   ('output\\csv\\vortexreviews\\CCZ Melody L.csv', 'vortexreviews')
# ccz waio:
#   ('output\\csv\\achoreviews\\CCZ Warrior L.csv', 'achoreviews')
#   ('output\\csv\\arn\\CCZ Warrior L.csv', 'arn')
#   ('output\\csv\\ianfann\\CCZ WARRIOR L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\CCZ WARRIOR R.csv', 'ianfann')
#   ('output\\csv\\pw\\CCZ Warrior L.csv', 'pw')
#   ('output\\csv\\pw\\CCZ Warrior R.csv', 'pw')
# ceest pandamon:
#   ('output\\csv\\achoreviews\\Celest Pandamon L.csv', 'achoreviews')
# dunu kima:
#   ('output\\csv\\achoreviews\\Dunu Kima L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\DUNU KIMA L.csv', 'aftersound')
#   ('output\\csv\\aftersound\\DUNU KIMA R.csv', 'aftersound')
#   ('output\\csv\\bedrock\\Dunu Kima L.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Dunu Kima R.csv', 'bedrock')
#   ('output\\csv\\timmyv\\Dunu Kima L.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Dunu Kima R.csv', 'timmyv')
#   ('output\\csv\\hbb\\Dunu Kima R.csv', 'hbb')
#   ('output\\csv\\cqtek\\Dunu Kima L.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Dunu Kima R.csv', 'cqtek')
#   ('output\\csv\\ianfann\\DUNU KIMA L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\DUNU KIMA R.csv', 'ianfann')
#   ('output\\csv\\nymz\\DUNU KIMA L.csv', 'nymz')
#   ('output\\csv\\nymz\\DUNU KIMA R.csv', 'nymz')
#   ('output\\csv\\vortexreviews\\Dunu Kima L.csv', 'vortexreviews')
#   ('output\\csv\\vortexreviews\\Dunu Kima R.csv', 'vortexreviews')
#   ('output\\csv\\vsg\\DUNU KIMA L.csv', 'vsg')
#   ('output\\csv\\vsg\\DUNU KIMA R.csv', 'vsg')
#   ('output\\csv\\data_mrs\\Dunu Kima L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Dunu Kima R.csv', 'data_mrs')
# dunu taos (pana+ ba) (ie600 foam tips):
#   ('output\\csv\\achoreviews\\Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv', 'achoreviews')
# dunu taos (pana+ ba):
#   ('output\\csv\\achoreviews\\Dunu Talos (Planar + BA) L.csv', 'achoreviews')
# dunu taos (panaony) (ie600 foam tips):
#   ('output\\csv\\achoreviews\\Dunu Talos (Planar Only) (IE600 Foam Tips) L.csv', 'achoreviews')
# dunu taos (panaony):
#   ('output\\csv\\achoreviews\\Dunu Talos (Planar Only) L.csv', 'achoreviews')
# dunu titan s (isoation):
#   ('output\\csv\\achoreviews\\Dunu Titan S (Isolation) L.csv', 'achoreviews')
# dunu titan s:
#   ('output\\csv\\achoreviews\\Dunu Titan S L.csv', 'achoreviews')
#   ('output\\csv\\aftersound\\DUNU TITAN S L.csv', 'aftersound')
#   ('output\\csv\\aftersound\\DUNU TITAN S R.csv', 'aftersound')
#   ('output\\csv\\arn\\DUNU Titan S L.csv', 'arn')
#   ('output\\csv\\arn\\DUNU Titan S R.csv', 'arn')
#   ('output\\csv\\bedrock\\Dunu Titan S L.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Dunu Titan S R.csv', 'bedrock')
#   ('output\\csv\\bryaudioreviews\\Dunu Titan S L.csv', 'bryaudioreviews')
#   ('output\\csv\\bryaudioreviews\\Dunu Titan S R.csv', 'bryaudioreviews')
#   ('output\\csv\\timmyv\\Dunu Titan S L.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Dunu Titan S R.csv', 'timmyv')
#   ('output\\csv\\hbb\\Dunu Titan S R.csv', 'hbb')
#   ('output\\csv\\cqtek\\Dunu Titan S L.csv', 'cqtek')
#   ('output\\csv\\cqtek\\Dunu Titan S R.csv', 'cqtek')
#   ('output\\csv\\ianfann\\DUNU TITAN S L.csv', 'ianfann')
#   ('output\\csv\\ianfann\\DUNU TITAN S R.csv', 'ianfann')
#   ('output\\csv\\iemworld\\DUNU TITAN S L.csv', 'iemworld')
#   ('output\\csv\\iemworld\\DUNU TITAN S R.csv', 'iemworld')
#   ('output\\csv\\nymz\\Dunu Titan S L.csv', 'nymz')
#   ('output\\csv\\nymz\\Dunu Titan S R.csv', 'nymz')
#   ('output\\csv\\rg\\Dunu Titan S L.csv', 'rg')
#   ('output\\csv\\rg\\Dunu Titan S R.csv', 'rg')
#   ('output\\csv\\vortexreviews\\Dunu Titan S L.csv', 'vortexreviews')
#   ('output\\csv\\vsg\\DUNU TITAN S L.csv', 'vsg')
#   ('output\\csv\\vsg\\DUNU TITAN S R.csv', 'vsg')
# dunu vukan:
#   ('output\\csv\\achoreviews\\Dunu Vulkan L.csv', 'achoreviews')
#   ('output\\csv\\bedrock\\Dunu Vulkan L.csv', 'bedrock')
#   ('output\\csv\\bedrock\\Dunu Vulkan R.csv', 'bedrock')
#   ('output\\csv\\timmyv\\Dunu Vulkan L.csv', 'timmyv')
#   ('output\\csv\\timmyv\\Dunu Vulkan R.csv', 'timmyv')
# ...
# sennheiseie 600 (sedna):
#   ('output\\csv\\data_mrs\\Sennheiser IE 600 (Sedna) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sennheiser IE 600 (Sedna) R.csv', 'data_mrs')
# sennheiseie 600 (spinfit):
#   ('output\\csv\\data_mrs\\Sennheiser IE 600 (Spinfit) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sennheiser IE 600 (Spinfit) R.csv', 'data_mrs')
# sennheiseie 600 (sping tips):
#   ('output\\csv\\data_mrs\\Sennheiser IE 600 (Spring tips) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sennheiser IE 600 (Spring tips) R.csv', 'data_mrs')
# sennheiseie 600:
#   ('output\\csv\\data_mrs\\Sennheiser IE 600 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sennheiser IE 600 R.csv', 'data_mrs')
# sennheiseie 900 (fake):
#   ('output\\csv\\data_mrs\\Sennheiser IE 900 (fake) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sennheiser IE 900 (fake) R.csv', 'data_mrs')
# sennheiseie 900 (fina):
#   ('output\\csv\\data_mrs\\Sennheiser IE 900 (Final) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sennheiser IE 900 (Final) R.csv', 'data_mrs')
# sennheiseie 900:
#   ('output\\csv\\data_mrs\\Sennheiser IE 900 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sennheiser IE 900 R.csv', 'data_mrs')
# sennheisemomentum tw3:
#   ('output\\csv\\data_mrs\\Sennheiser Momentum TW3 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sennheiser Momentum TW3 R.csv', 'data_mrs')
# sennheisemtw2 (he):
#   ('output\\csv\\data_mrs\\Sennheiser MTW2 (HE) L.csv', 'data_mrs')
# sennheisemtw2:
#   ('output\\csv\\data_mrs\\Sennheiser MTW2 L.csv', 'data_mrs')
# shaning me700ite:
#   ('output\\csv\\data_mrs\\Shanling ME700 Lite L.csv', 'data_mrs')
# shozy cp:
#   ('output\\csv\\data_mrs\\Shozy CP L.csv', 'data_mrs')
# shozyouge:
#   ('output\\csv\\data_mrs\\Shozy Rouge L.csv', 'data_mrs')
# simgot en700 po (moondop):
#   ('output\\csv\\data_mrs\\Simgot EN700 Pro (Moondrop) L.csv', 'data_mrs')
# simgot en700 po (tanchjim):
#   ('output\\csv\\data_mrs\\Simgot EN700 Pro (Tanchjim) L.csv', 'data_mrs')
# simgot en700 po:
#   ('output\\csv\\data_mrs\\Simgot EN700 Pro L.csv', 'data_mrs')
# softeas studio4:
#   ('output\\csv\\data_mrs\\Softears Studio4 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Softears Studio4 R.csv', 'data_mrs')
# softeas voume (appe + 126ohm):
#   ('output\\csv\\data_mrs\\Softears Volume (Apple + 126ohm) L.csv', 'data_mrs')
# softeas voume (appe + 15ohm):
#   ('output\\csv\\data_mrs\\Softears Volume (Apple + 15ohm) L.csv', 'data_mrs')
# softeas voume (appe + 36ohm):
#   ('output\\csv\\data_mrs\\Softears Volume (Apple + 36ohm) L.csv', 'data_mrs')
# softeas voume (appe + 75ohm):
#   ('output\\csv\\data_mrs\\Softears Volume (Apple + 75ohm) L.csv', 'data_mrs')
# softeas voume (appe donge):
#   ('output\\csv\\data_mrs\\Softears Volume (Apple dongle) L.csv', 'data_mrs')
# softeas voume (fiio q3):
#   ('output\\csv\\data_mrs\\Softears Volume (Fiio Q3) L.csv', 'data_mrs')
# softeas voume (qudeix):
#   ('output\\csv\\data_mrs\\Softears Volume (Qudelix) L.csv', 'data_mrs')
# sony ie-nw510n:
#   ('output\\csv\\data_mrs\\Sony IER-NW510N L.csv', 'data_mrs')
# sony ie-z1(s2 - sedna):
#   ('output\\csv\\data_mrs\\Sony IER-Z1R (S2 - Sedna) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sony IER-Z1R (S2 - Sedna) R.csv', 'data_mrs')
# sony ie-z1(s2 - symbio):
#   ('output\\csv\\data_mrs\\Sony IER-Z1R (S2 - Symbio) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sony IER-Z1R (S2 - Symbio) R.csv', 'data_mrs')
# sony ie-z1(s3):
#   ('output\\csv\\data_mrs\\Sony IER-Z1R (S3) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sony IER-Z1R (S3) R.csv', 'data_mrs')
# sony md-as800:
#   ('output\\csv\\data_mrs\\Sony MDR-AS800 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sony MDR-AS800 R.csv', 'data_mrs')
# sony md-ex15p (deep):
#   ('output\\csv\\data_mrs\\Sony MDR-EX15LP (deep) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sony MDR-EX15LP (deep) R.csv', 'data_mrs')
# sony mh1:
#   ('output\\csv\\data_mrs\\Sony MH1 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sony MH1 R.csv', 'data_mrs')
# sony mh755 (s2):
#   ('output\\csv\\data_mrs\\Sony MH755 (S2) L.csv', 'data_mrs')
# sony mh755 (s3):
#   ('output\\csv\\data_mrs\\Sony MH755 (S3) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sony MH755 (S3) R.csv', 'data_mrs')
# sony mh755 (vent bu tack):
#   ('output\\csv\\data_mrs\\Sony MH755 (vent Blu Tack) L.csv', 'data_mrs')
# sony mh755 cone:
#   ('output\\csv\\data_mrs\\Sony MH755 clone L.csv', 'data_mrs')
# sony wf-1000xm4 (ambient on):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (ambient on) L.csv', 'data_mrs')
# sony wf-1000xm4 (anc off):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (ANC off) L.csv', 'data_mrs')
# sony wf-1000xm4 (anc on):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (ANC on) L.csv', 'data_mrs')
# sony wf-1000xm4 (eq - bass boost):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (EQ - bass boost) L.csv', 'data_mrs')
# sony wf-1000xm4 (eq - bight):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (EQ - bright) L.csv', 'data_mrs')
# sony wf-1000xm4 (eq - custom):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (EQ - custom) L.csv', 'data_mrs')
# sony wf-1000xm4 (eq - excited):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (EQ - excited) L.csv', 'data_mrs')
# sony wf-1000xm4 (eq - meow):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (EQ - mellow) L.csv', 'data_mrs')
# sony wf-1000xm4 (eq -eaxed):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (EQ - relaxed) L.csv', 'data_mrs')
# sony wf-1000xm4 (eq - speech):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (EQ - speech) L.csv', 'data_mrs')
# sony wf-1000xm4 (eq - tebe boost):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (EQ - treble boost) L.csv', 'data_mrs')
# sony wf-1000xm4 (eq - voca):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (EQ - vocal) L.csv', 'data_mrs')
# sony wf-1000xm4 (finae-type):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (Final E-type) L.csv', 'data_mrs')
# sony wf-1000xm4 (fw 1.1.15):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (fw 1.1.15) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - ambient on):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - ambient on) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - anc off):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - ANC off) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - anc on):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - ANC on) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - eq - bass boost):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - EQ - bass boost) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - eq - bight):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - EQ - bright) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - eq - excited):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - EQ - excited) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - eq - meow):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - EQ - mellow) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - eq -eaxed):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - EQ - relaxed) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - eq - speech):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - EQ - speech) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - eq - tebe boost):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - EQ - treble boost) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - eq - voca):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - EQ - vocal) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - finae-type):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - Final E-type) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - fw 1.1.15):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - fw 1.1.15) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - fw 1.2.6):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - fw 1.2.6) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - ms config):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - MRS config) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - sednaight shot):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - Sedna Light Short) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - spinfit):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - SpinFit) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - tanchjim apb):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - Tanchjim APB) L.csv', 'data_mrs')
# sony wf-1000xm4 (max - xm3 siicone):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (max - XM3 silicone) L.csv', 'data_mrs')
# sony wf-1000xm4 (ms config):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (MRS config) L.csv', 'data_mrs')
# sony wf-1000xm4 (sednaight shot):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (Sedna Light Short) L.csv', 'data_mrs')
# sony wf-1000xm4 (spinfit):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (SpinFit) L.csv', 'data_mrs')
# sony wf-1000xm4 (tanchjim apb):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (Tanchjim APB) L.csv', 'data_mrs')
# sony wf-1000xm4 (xm3 siicone):
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 (XM3 silicone) L.csv', 'data_mrs')
# sony wf-1000xm4:
#   ('output\\csv\\data_mrs\\Sony WF-1000XM4 L.csv', 'data_mrs')
# sony xba-n3 (s2):
#   ('output\\csv\\data_mrs\\Sony XBA-N3 (S2) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Sony XBA-N3 (S2) R.csv', 'data_mrs')
# status audio iem-2x:
#   ('output\\csv\\data_mrs\\Status Audio IEM-2X L.csv', 'data_mrs')
# symphonium meteo(canjam):
#   ('output\\csv\\data_mrs\\Symphonium Meteor (CanJam) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Symphonium Meteor (CanJam) R.csv', 'data_mrs')
# symphonium meteo(inveted):
#   ('output\\csv\\data_mrs\\Symphonium Meteor (inverted) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Symphonium Meteor (inverted) R.csv', 'data_mrs')
# tanchjim daing (depth 1):
#   ('output\\csv\\data_mrs\\Tanchjim Darling (depth 1) L.csv', 'data_mrs')
# tanchjim daing (depth 2):
#   ('output\\csv\\data_mrs\\Tanchjim Darling (depth 2) L.csv', 'data_mrs')
# tanchjim hana (finae):
#   ('output\\csv\\data_mrs\\Tanchjim Hana (Final E) L.csv', 'data_mrs')
# tanchjim hana (sednaight):
#   ('output\\csv\\data_mrs\\Tanchjim Hana (Sedna Light) L.csv', 'data_mrs')
# tanchjim oa (s2 - fiteess - taped):
#   ('output\\csv\\data_mrs\\Tanchjim Ola (s2 - filterless - taped) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Tanchjim Ola (s2 - filterless - taped) R.csv', 'data_mrs')
# tanchjim oa (s2 - fiteess):
#   ('output\\csv\\data_mrs\\Tanchjim Ola (s2 - filterless) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Tanchjim Ola (s2 - filterless) R.csv', 'data_mrs')
# tanchjim oa (vent bu tack):
#   ('output\\csv\\data_mrs\\Tanchjim Ola (vent Blu Tack) L.csv', 'data_mrs')
# tanchjim oa (vent tanchjim fite):
#   ('output\\csv\\data_mrs\\Tanchjim Ola (vent Tanchjim filter) L.csv', 'data_mrs')
# tanchjim pism (tebe tips):
#   ('output\\csv\\data_mrs\\Tanchjim Prism (treble tips) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Tanchjim Prism (treble tips) R.csv', 'data_mrs')
# tangzu wu heyday:
#   ('output\\csv\\data_mrs\\Tangzu Wu Heyday L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Tangzu Wu Heyday R.csv', 'data_mrs')
# tansio miai spak (010):
#   ('output\\csv\\data_mrs\\Tansio Mirai Spark (010) L.csv', 'data_mrs')
# tansio miai spak (110):
#   ('output\\csv\\data_mrs\\Tansio Mirai Spark (110) L.csv', 'data_mrs')
# tansio miai spak (111):
#   ('output\\csv\\data_mrs\\Tansio Mirai Spark (111) L.csv', 'data_mrs')
# tenhz 3ba:
#   ('output\\csv\\data_mrs\\Tenhz 3BA L.csv', 'data_mrs')
# tenhz p4 po:
#   ('output\\csv\\data_mrs\\Tenhz P4 Pro L.csv', 'data_mrs')
# tfz t2 gaaxy:
#   ('output\\csv\\data_mrs\\TFZ T2 Galaxy L.csv', 'data_mrs')
# thieaudioegacy 4 (sping):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 4 (Spring) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 4 (Spring) R.csv', 'data_mrs')
# thieaudioegacy 4 (switch on):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 4 (switch on) L.csv', 'data_mrs')
# thieaudioegacy 4:
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 4 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 4 R.csv', 'data_mrs')
# thieaudioegacy 5 (126 ohm):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 5 (126 ohm) L.csv', 'data_mrs')
# thieaudioegacy 5 (15 ohm):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 5 (15 ohm) L.csv', 'data_mrs')
# thieaudioegacy 5 (36 ohm):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 5 (36 ohm) L.csv', 'data_mrs')
# thieaudioegacy 5 (75 ohm):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 5 (75 ohm) L.csv', 'data_mrs')
# thieaudioegacy 5 (s1 seized):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 5 (S1 seized) L.csv', 'data_mrs')
# thieaudioegacy 5 (s1):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 5 (S1) L.csv', 'data_mrs')
# thieaudioegacy 5 (s2 15ohm):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 5 (S2 15ohm) L.csv', 'data_mrs')
# thieaudioegacy 5 (s2):
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 5 (S2) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\ThieAudio Legacy 5 (S2) R.csv', 'data_mrs')
# thieaudio monach mkii (s2 - sping tips):
#   ('output\\csv\\data_mrs\\ThieAudio Monarch MkII (S2 - Spring tips) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\ThieAudio Monarch MkII (S2 - Spring tips) R.csv', 'data_mrs')
# thieaudio monach mkii (s2):
#   ('output\\csv\\data_mrs\\ThieAudio Monarch MkII (S2) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\ThieAudio Monarch MkII (S2) R.csv', 'data_mrs')
# thinksoundain3:
#   ('output\\csv\\data_mrs\\Thinksound Rain3 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Thinksound Rain3 R.csv', 'data_mrs')
# tin hifi c2 mech waio:
#   ('output\\csv\\data_mrs\\Tin Hifi C2 Mech Warrior L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Tin Hifi C2 Mech Warrior R.csv', 'data_mrs')
# tin hifi c5:
#   ('output\\csv\\data_mrs\\Tin Hifi C5 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Tin Hifi C5 R.csv', 'data_mrs')
# tin hifi p1 (vent bocked):
#   ('output\\csv\\data_mrs\\Tin Hifi P1 (vent blocked) L.csv', 'data_mrs')
# tin hifi t2 evo:
#   ('output\\csv\\data_mrs\\Tin Hifi T2 Evo L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Tin Hifi T2 Evo R.csv', 'data_mrs')
# tin hifi t2:
#   ('output\\csv\\data_mrs\\Tin Hifi T2 L.csv', 'data_mrs')
# tin hifi t2 pus (sednaight):
#   ('output\\csv\\data_mrs\\Tin Hifi T2 Plus (Sedna Light) L.csv', 'data_mrs')
# tin hifi t2 po (compy):
#   ('output\\csv\\data_mrs\\Tin Hifi T2 Pro (Comply) L.csv', 'data_mrs')
# tin hifi t2 po (white gi+ compy):
#   ('output\\csv\\data_mrs\\Tin Hifi T2 Pro (white grill + Comply) L.csv', 'data_mrs')
# tin hifi t2 po:
#   ('output\\csv\\data_mrs\\Tin Hifi T2 Pro L.csv', 'data_mrs')
# tin hifi t5 (compy waxguad):
#   ('output\\csv\\data_mrs\\Tin Hifi T5 (Comply Waxguard) L.csv', 'data_mrs')
# tin hifi t5:
#   ('output\\csv\\data_mrs\\Tin Hifi T5 L.csv', 'data_mrs')
# tipowin oina (s2):
#   ('output\\csv\\data_mrs\\Tripowin Olina (S2) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Tripowin Olina (S2) R.csv', 'data_mrs')
# tn im1:
#   ('output\\csv\\data_mrs\\TRN IM1 L.csv', 'data_mrs')
# tn v30:
#   ('output\\csv\\data_mrs\\TRN V30 L.csv', 'data_mrs')
# tutheahexa (s2 - aiocked):
#   ('output\\csv\\data_mrs\\Truthear Hexa (S2 - airlocked) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Truthear Hexa (S2 - airlocked) R.csv', 'data_mrs')
# tutheahexa (s2):
#   ('output\\csv\\data_mrs\\Truthear Hexa (S2) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Truthear Hexa (S2) R.csv', 'data_mrs')
# tutheazeo (s2 deep):
#   ('output\\csv\\data_mrs\\Truthear Zero (S2 deep) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Truthear Zero (S2 deep) R.csv', 'data_mrs')
# tutheazeo (s2):
#   ('output\\csv\\data_mrs\\Truthear Zero (S2) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Truthear Zero (S2) R.csv', 'data_mrs')
# ucoteche-2:
#   ('output\\csv\\data_mrs\\Ucotech RE-2 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Ucotech RE-2 R.csv', 'data_mrs')
# vision eas ve7:
#   ('output\\csv\\data_mrs\\Vision Ears VE7 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Vision Ears VE7 R.csv', 'data_mrs')
# vsonic g07 (bass):
#   ('output\\csv\\data_mrs\\Vsonic GR07 (Bass) L.csv', 'data_mrs')
# vsonic g07:
#   ('output\\csv\\data_mrs\\Vsonic GR07 L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Vsonic GR07 R.csv', 'data_mrs')
# vsonic vs7:
#   ('output\\csv\\data_mrs\\Vsonic VS7 L.csv', 'data_mrs')
# whizzekyin:
#   ('output\\csv\\data_mrs\\Whizzer Kylin L.csv', 'data_mrs')
# xenns mangid tea 2 (s2):
#   ('output\\csv\\data_mrs\\Xenns Mangird Tea 2 (S2) L.csv', 'data_mrs')
#   ('output\\csv\\data_mrs\\Xenns Mangird Tea 2 (S2) R.csv', 'data_mrs')
# yinfu md51:
#   ('output\\csv\\data_mrs\\Yinfu MD51 L.csv', 'data_mrs')

# %%
import os
import re
from collections import defaultdict

def normalize_iem_name(name):
    name = re.sub(r'\s+', ' ', name)  # Remove extra whitespaces
    name = re.sub(r'\([^)]*\)', '', name)  # Remove content within parentheses
    name = re.sub(r'\d+ohm', '', name)  # Remove impedance information
    name = re.sub(r'[RrLl]\.csv$', '', name)  # Remove channel and .csv info
    name = name.strip().lower()  # Convert to lowercase and remove leading/trailing spaces
    return name

def match_special_cases(name):
    if 'target' in name.lower():
        return 'target'
    if 'broken' in name.lower():
        return 'broken'
    return None

base_path = 'output/csv'
reviewers = [
    'achoreviews', 'aftersound', 'animagus', 'arn', 'bedrock', 'bryaudioreviews', 'cammyfi',
    'soundjedi', 'eplv', 'timmyv', 'harpo', 'hbb', 'cqtek', 'hobbytalk', 'ianfann', 'iemworld',
    'jacstone', 'kr0mka', 'kurin', 'melatonin', 'nymz', 'pw', 'recode', 'rg', 'shortbus',
    'suporsalad', 'tgx78', 'vortexreviews', 'vsg', 'wdym', 'akros', 'data_mrs'
]

iem_data = defaultdict(lambda: defaultdict(list))

for reviewer in reviewers:
    reviewer_path = os.path.join(base_path, reviewer)
    
    for file_name in os.listdir(reviewer_path):
        special_case = match_special_cases(file_name)
        
        if special_case:
            iem_data[special_case][reviewer].append(file_name)
        else:
            iem_name = normalize_iem_name(file_name)
            iem_data[iem_name][reviewer].append(file_name)

# Print the grouped data
for iem_name, reviewer_data in iem_data.items():
    print(f"\nIEM: {iem_name}")
    for reviewer, file_names in reviewer_data.items():
        print(f"\n  Reviewer: {reviewer}")
        for file_name in file_names:
            print(f"    {file_name}")
# Out:
# IEM: 7hz dioko
#
#   Reviewer: achoreviews
#     7Hz Dioko L.csv
#
#   Reviewer: bedrock
#     7Hz Dioko L.csv
#     7Hz Dioko R.csv
#
#   Reviewer: timmyv
#     7Hz Dioko L.csv
#     7Hz Dioko R.csv
#
#   Reviewer: hbb
#     7Hz Dioko R.csv
#
#   Reviewer: hobbytalk
#     7hz Dioko L.csv
#     7hz Dioko R.csv
#
#   Reviewer: ianfann
#     7HZ DIOKO (bass mod) L.csv
#     7HZ DIOKO (bass mod) R.csv
#     7HZ DIOKO L.csv
#     7HZ DIOKO R.csv
#
#   Reviewer: iemworld
#     7Hz Dioko L.csv
#     7Hz Dioko R.csv
#
#   Reviewer: data_mrs
#     7Hz Dioko (post-op) L.csv
#     7Hz Dioko (post-op) R.csv
#     7Hz Dioko (pre-op) L.csv
#     7Hz Dioko (pre-op) R.csv
#     7Hz Dioko L.csv
#     7Hz Dioko R.csv
#
# IEM: 7hz eternal
#
#   Reviewer: achoreviews
#     7Hz Eternal L.csv
#
#   Reviewer: bedrock
#     7Hz Eternal L.csv
#     7Hz Eternal R.csv
#
#   Reviewer: harpo
#     7Hz Eternal R.csv
#
#   Reviewer: hbb
#     7Hz Eternal R.csv
#
#   Reviewer: iemworld
#     7Hz ETERNAL L.csv
#     7Hz ETERNAL R.csv
#
#   Reviewer: vortexreviews
#     7hz Eternal L.csv
#     7hz Eternal R.csv
#
#   Reviewer: vsg
#     7Hz Eternal L.csv
#     7Hz Eternal R.csv
#
# IEM: 7hz legato
#
#   Reviewer: achoreviews
#     7Hz Legato L.csv
#
#   Reviewer: aftersound
#     7HZ LEGATO L.csv
#     7HZ LEGATO R.csv
#
#   Reviewer: timmyv
#     7Hz Legato L.csv
#     7Hz Legato R.csv
#
#   Reviewer: hbb
#     7Hz Legato R.csv
#
#   Reviewer: cqtek
#     7Hz Legato L.csv
#     7Hz Legato R.csv
#
#   Reviewer: ianfann
#     7HZ LEGATO L.csv
#     7HZ LEGATO R.csv
#
#   Reviewer: nymz
#     7hz LEGATO L.csv
#     7hz LEGATO R.csv
#
#   Reviewer: rg
#     7hz Legato (250 mesh) L.csv
#     7hz Legato (3 outer vent blutack) L.csv
#     7hz Legato (500 mesh) L.csv
#     7hz Legato (inner vent blutack) L.csv
#     7hz Legato L.csv
#     7hz Legato R.csv
#
#   Reviewer: vortexreviews
#     7hz Legato L.csv
#     7hz Legato R.csv
#
#   Reviewer: vsg
#     7Hz Legato L.csv
#     7Hz Legato R.csv
#
# IEM: 7hz timeless
#
#   Reviewer: achoreviews
#     7Hz Timeless L.csv
#
#   Reviewer: aftersound
#     7HZ TIMELESS L.csv
#     7HZ TIMELESS R.csv
#
#   Reviewer: arn
#     7Hz Timeless L.csv
#
#   Reviewer: soundjedi
#     7Hz Timeless L.csv
#     7Hz Timeless R.csv
#
#   Reviewer: timmyv
#     7Hz Timeless L.csv
#     7Hz Timeless R.csv
#
#   Reviewer: harpo
#     7Hz Timeless R.csv
#
#   Reviewer: hbb
#     7Hz Timeless (no filter) R.csv
#
#   Reviewer: hobbytalk
#     7hz Timeless L.csv
#     7hz Timeless R.csv
#
#   Reviewer: iemworld
#     7Hz Timeless (FINAL Tips) L.csv
#     7Hz Timeless (FINAL Tips) R.csv
#     7Hz Timeless (Foam Tips) L.csv
#     7Hz Timeless (Foam Tips) R.csv
#     7Hz Timeless (MoonDroop Tips) L.csv
#     7Hz Timeless (MoonDroop Tips) R.csv
#
#   Reviewer: pw
#     7Hz Timeless L.csv
#     7Hz Timeless R.csv
#
#   Reviewer: rg
#     7Hz Timeless (350 Mesh, stock tuning foam sideways, Super Thin HS Foam inner vent) L.csv
#     7Hz Timeless (350 Mesh, stock tuning foam, Super Thin HS Foam inner vent) L.csv
#     7Hz Timeless (Sony Import Foam) L.csv
#     7Hz Timeless (Sony Import Foam, Super Thin HS Foam inner vent) L.csv
#     7Hz Timeless (Tanchjim Filter, stock tuning foam sideways, Super Thin HS Foam inner vent) L.csv
#     7Hz Timeless L.csv
#     7Hz Timeless R.csv
#
#   Reviewer: tgx78
#     7hz Timeless L.csv
#     7hz Timeless R.csv
#
#   Reviewer: vortexreviews
#     7hz Timeless L.csv
#     7hz Timeless R.csv
#
#   Reviewer: vsg
#     7Hz Timeless L.csv
#     7Hz Timeless R.csv
#
#   Reviewer: data_mrs
#     7Hz Timeless (S2) L.csv
#     7Hz Timeless (S2) R.csv
#     7Hz Timeless L.csv
#     7Hz Timeless R.csv
#
# IEM: 7hz zero
#
#   Reviewer: achoreviews
#     7Hz Zero L.csv
#
#   Reviewer: bedrock
#     7Hz Zero L.csv
#     7Hz Zero R.csv
#
#   Reviewer: timmyv
#     7Hz Zero L.csv
#     7Hz Zero R.csv
#
#   Reviewer: hbb
#     7hz Zero R.csv
#
#   Reviewer: hobbytalk
#     7hz Zero L.csv
#     7hz Zero R.csv
#
#   Reviewer: ianfann
#     7HZ ZERO L.csv
#     7HZ ZERO R.csv
#
#   Reviewer: iemworld
#     7hz Zero (EJ07 FOAM Eartips) L.csv
#     7hz Zero (EJ07 FOAM Eartips) R.csv
#     7hz Zero (Final Eartips) L.csv
#     7hz Zero (Final Eartips) R.csv
#     7hz Zero (MoonDrop Eartips) L.csv
#     7hz Zero (MoonDrop Eartips) R.csv
#     7hz Zero (Red Orignal Eartips) L.csv
#     7hz Zero (Red Orignal Eartips) R.csv
#
#   Reviewer: data_mrs
#     7Hz Zero L.csv
#     7Hz Zero R.csv
#
# IEM: target
#
#   Reviewer: achoreviews
#     Acho Reviews Target.csv
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: aftersound
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     IEF neutral Target.csv
#     Innerfidelity ID Target.csv
#     Innerfidelity Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: animagus
#     Animagus Neutral Target.csv
#     Animagus Preference Target.csv
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman In Ear 2019 Target.csv
#     Harman In Room Target.csv
#     Harman Over Ear 2018 Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: arn
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Harman V2 Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: bedrock
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: bryaudioreviews
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Bry Audio Reviews Target.csv
#     Crinacle IEF-Neutral Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman 2017 Target.csv
#     Harman 2019 Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Oratory1990 Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: cammyfi
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     CammyFi Neutral Target.csv
#     CammyFi Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman IE 2019 v2 Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Kurin Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: soundjedi
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: eplv
#     Antdroid Target.csv
#     AutoEQ Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Harman2019v2 Target.csv
#     IEF Neutral Target.csv
#     Innerfidelity ID Target.csv
#     Old Crinacle Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: timmyv
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     IEF Neutral Target.csv
#     Innerfidelity ID Target.csv
#     Nymz Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#     Timmy Target.csv
#
#   Reviewer: harpo
#     Antdroid Target.csv
#     AX Target.csv
#     Bad Guy 2022 Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     EJ Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Harpo Target.csv
#     Harpo v3 Target.csv
#     Harpo v4 Target (11.03.2023 02-43-36).csv
#     Harpo v4 Target.csv
#     Harpo_v2 Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     RikudouGoku Target.csv
#     Rtings Target.csv
#     Softears Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#     X Target.csv
#
#   Reviewer: hbb
#     Antdroid Target.csv
#     Bad Guy 2022 Target.csv
#     Bad Guy Target v2.csv
#     Bad Guy Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     IEF Target.csv
#     MRS Target.csv
#     Precog Target.csv
#     Precog_broken Target.csv
#     Redeyes Target.csv
#     RikudouGoku Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#
#   Reviewer: cqtek
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: hobbytalk
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman IE 2019 Target.csv
#     Harman Target.csv
#     Hobby Talk Flat Target.csv
#     Hobby Talk Preference Target OG.csv
#     Hobby Talk Preference Target.csv
#     Honest Target.csv
#     IEF Neutral Target.csv
#     IEF OE Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: ianfann
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman 2017 Target.csv
#     Harman 2019 Target.csv
#     IanFann-Target Target.csv
#     IEF Neutral 2023 Target.csv
#     IEF Target.csv
#     IEF Target1.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: iemworld
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     IEM WORLD Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: jacstone
#     Harman 2019 Target.csv
#     IEF Neutral Target.csv
#     nymz Target.csv
#     Paul Wasabii Target.csv
#     RikudouGoku Target.csv
#     Sharur Target.csv
#
#   Reviewer: kr0mka
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman IE 2016 Target.csv
#     Harman IE 2017 v2 Target.csv
#     Harman IE 2019 v2 Target.csv
#     Innerfidelity ID Target.csv
#     kr0mka Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: kurin
#     Antdroid Target.csv
#     Bad Guy 2022 Target.csv
#     Banbeucmas Target.csv
#     CammyFi Target.csv
#     Coda Target.csv
#     Comfy Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Flat Target.csv
#     Freeryder05v2 Target.csv
#     Harman IE 2016 Target.csv
#     Harman IE 2019 v2 Target.csv
#     Hobby Talk Preference Target.csv
#     Hobby Talk Target.csv
#     Kurin Target.csv
#     markanini Target.csv
#     Moondrop Target.csv
#     Normative Target.csv
#     Objectively Neutral IE Target.csv
#     Olive-Welti Harman Bass Target.csv
#     Olive-Welti Target.csv
#     Oratory IE Target.csv
#     Precog Target.csv
#     Redeyes Target.csv
#     Rikudogoku Target.csv
#     RikudouGoku Target.csv
#     Rtings Target.csv
#     SEAP Target.csv
#     Sharur Target.csv
#     Srg0mes Target.csv
#     Super 22 Target.csv
#     Timmy Target.csv
#
#   Reviewer: melatonin
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: nymz
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman 2019v2 Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     nymz Target.csv
#     Precogvision Target.csv
#     RikudouGoku Target.csv
#     RikudouGoku_Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#     tgx78 Target.csv
#
#   Reviewer: pw
#     Antdroid Target.csv
#     AutoEQ Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crackhead Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman 2019v2 Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Oratory1990 Target.csv
#     PaulWasabii Target.csv
#     Precogvision Target.csv
#     Redeyes Target.csv
#     RikudouGoku Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: recode
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Neutral Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman 2017v2 Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Recode Neutral Target.csv
#     Recode Target.csv
#     Recode Warm Neutral Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#     target 8.csv
#
#   Reviewer: rg
#     ALPHA 1.0 Target.csv
#     Amelie Target.csv
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crackhead Target.csv
#     Diffuse Field Target.csv
#     DynamicEars Target.csv
#     Etymotic Target.csv
#     evasb Target.csv
#     Free Field Target.csv
#     Harman 2017v2 Target.csv
#     Harman 2019v2 Target.csv
#     Harpo Target.csv
#     IEF Neutral 2020 Target.csv
#     IEF Neutral 2023 Target.csv
#     Innerfidelity ID Target.csv
#     Lixeem Target.csv
#     nymz Target.csv
#     Precogvision Target.csv
#     PW Target.csv
#     Resolution Target.csv
#     RikudouGoku Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     stakk Target.csv
#     Super Bass Target.csv
#     Super Review 2021 Target.csv
#     Super Review 2022 Target.csv
#     Talbot Target.csv
#     tgx78 Target.csv
#     TKSilver Target.csv
#
#   Reviewer: shortbus
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Redeyes 1 Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: suporsalad
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     DF Tilt 711 Ref Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman IEM Target.csv
#     Harman OE Target.csv
#     Harman Target.csv
#     IEF Neutral 2020 Target.csv
#     IEF Neutral 2023 Target.csv
#     Innerfidelity ID Target.csv
#     Kemar DF 1.3 Bass Target.csv
#     Kemar DF 1.3 Target.csv
#     Kemar DF Target.csv
#     Listener Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#     USound1V1 Oratory 1990 Target.csv
#
#   Reviewer: tgx78
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     RikudouGoku Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#     Tgx78 Target.csv
#
#   Reviewer: vortexreviews
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Oratory1990 Target.csv
#     Precogvision Target.csv
#     RikudouGoku Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: vsg
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman 2018 Over-Ear Target.csv
#     Harman 2019 In-Ear Target.csv
#     Harman Combined Over-Ear Target.csv
#     Harman In-Ear Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#     VSG Target.csv
#
#   Reviewer: wdym
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#     Wdym Target.csv
#
#   Reviewer: akros
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Free Field Target.csv
#     Harman Target.csv
#     Innerfidelity ID Target.csv
#     Precogvision Target.csv
#     Rtings Target.csv
#     Sonarworks Target.csv
#     Super Review Target.csv
#
#   Reviewer: data_mrs
#     Antdroid Target.csv
#     Bad Guy Target.csv
#     Banbeucmas Target.csv
#     Crinacle 2023 Adjusted Target.csv
#     Crinacle Adjusted Target.csv
#     Crinacle Neutral 2023 Target.csv
#     Crinacle Neutral Target.csv
#     Crinacle Target.csv
#     Dent Target.csv
#     dentReviews Target.csv
#     Diffuse Field Target.csv
#     Etymotic Target.csv
#     Ghost Target.csv
#     Harman Adjusted Target.csv
#     Harman Target.csv
#     HBB Comp Target.csv
#     HPDC 10dB Tilt 5128 DF 100Hz Target.csv
#     HPDC 10dB Tilt 5128 DF Target.csv
#     HPDC 10dB Tilt KEMAR DF 100Hz Target.csv
#     HPDC 10dB Tilt KEMAR DF Target.csv
#     HPDC 14dB Tilt 5128 DF 100Hz Target.csv
#     HPDC 14dB Tilt 5128 DF Target.csv
#     HPDC 14dB Tilt KEMAR DF 100Hz Target.csv
#     HPDC 14dB Tilt KEMAR DF Target.csv
#     IEC711 Comp Target.csv
#     IEF Comp Target.csv
#     Moondrop Alice (EQ In-Ear Target) L.csv
#     Moondrop Alice (EQ In-Ear Target) R.csv
#     Moondrop Blessing 2 Target.csv
#     Precogvision Target.csv
#     RikudouGoku Target.csv
#     Super 21 Target.csv
#     Super 22 Target.csv
#     Super Bass Target.csv
#     Super Review Target.csv
#     Working 001 Target.csv
#     Working 002 Target.csv
#
# IEM: audeze isine lx
#
#   Reviewer: achoreviews
#     Audeze iSine LX (Spinfit) L.csv
#
# IEM: aune jasper
#
#   Reviewer: achoreviews
#     Aune Jasper L.csv
#
#   Reviewer: aftersound
#     AUNE JASPER L.csv
#     AUNE JASPER R.csv
#
#   Reviewer: hbb
#     Aune Jasper R.csv
#
#   Reviewer: data_mrs
#     Aune Jasper (Tanchjim filter) L.csv
#     Aune Jasper (Tanchjim filter) R.csv
#     Aune Jasper L.csv
#     Aune Jasper R.csv
#
# IEM: blon bl01
#
#   Reviewer: achoreviews
#     Blon BL01 L.csv
#
#   Reviewer: bryaudioreviews
#     BLON BL01 L.csv
#     BLON BL01 R.csv
#
#   Reviewer: pw
#     BLON BL01 L.csv
#
# IEM: blon bl03
#
#   Reviewer: achoreviews
#     Blon BL03 L.csv
#
#   Reviewer: aftersound
#     BLON BL03 R.csv
#
#   Reviewer: bryaudioreviews
#     BLON BL03 L.csv
#     BLON BL03 R.csv
#
#   Reviewer: timmyv
#     Blon BL03 L.csv
#     Blon BL03 R.csv
#
#   Reviewer: ianfann
#     BLON BL03 L.csv
#     BLON BL03 R.csv
#
#   Reviewer: suporsalad
#     Blon BL03 L.csv
#     Blon BL03 R.csv
#
#   Reviewer: data_mrs
#     Blon BL03 L.csv
#
# IEM: blon bl05s
#
#   Reviewer: achoreviews
#     Blon BL05s L.csv
#
#   Reviewer: pw
#     BLON BL05S L.csv
#
# IEM: blon fat girl
#
#   Reviewer: achoreviews
#     Blon Fat Girl L.csv
#
#   Reviewer: aftersound
#     BLON FAT GIRL L.csv
#     BLON FAT GIRL R.csv
#
#   Reviewer: hbb
#     BLON Fat Girl R.csv
#
#   Reviewer: ianfann
#     BLON FAT GIRL L.csv
#     BLON FAT GIRL R.csv
#
#   Reviewer: jacstone
#     BLON Fat Girl L.csv
#     BLON Fat Girl R.csv
#
#   Reviewer: pw
#     BLON Fat Girl L.csv
#     BLON Fat Girl R.csv
#
#   Reviewer: vortexreviews
#     Blon Fat Girl L.csv
#     Blon Fat Girl R.csv
#
# IEM: blon t1
#
#   Reviewer: achoreviews
#     Blon T1 L.csv
#
# IEM: blon t3
#
#   Reviewer: achoreviews
#     Blon T3 L.csv
#
# IEM: blon z200
#
#   Reviewer: achoreviews
#     Blon Z200 L.csv
#
#   Reviewer: arn
#     BLON Z200 L.csv
#
#   Reviewer: harpo
#     Blon Z200 L.csv
#     Blon Z200 R.csv
#
#   Reviewer: ianfann
#     BLON Z200 L.csv
#     BLON Z200 R.csv
#
#   Reviewer: pw
#     BLON Z200 L.csv
#     BLON Z200 R.csv
#
#   Reviewer: vortexreviews
#     Blon Z200 L.csv
#     Blon Z200 R.csv
#
# IEM: cca cra
#
#   Reviewer: achoreviews
#     CCA CRA L.csv
#
#   Reviewer: aftersound
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: eplv
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: harpo
#     CCA CRA R.csv
#
#   Reviewer: hbb
#     CCA CRA R.csv
#
#   Reviewer: hobbytalk
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: ianfann
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: jacstone
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: melatonin
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: nymz
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: pw
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: rg
#     CCA CRA (1dividedby4 Foam) L.csv
#     CCA CRA (1dividedby8 Foam) L.csv
#     CCA CRA (200 Mesh) L.csv
#     CCA CRA (350 Mesh) L.csv
#     CCA CRA (500 Mesh + 200 Paper Filter) L.csv
#     CCA CRA (500 Mesh + 250 Paper Filter) L.csv
#     CCA CRA (500 Mesh + 300 Paper Filter + High-Density Tuning Foam) L.csv
#     CCA CRA (500 Mesh + 300 Paper Filter) L.csv
#     CCA CRA (500 Mesh + 350 Paper Filter) L.csv
#     CCA CRA (500 Mesh + 500 Paper Filter) L.csv
#     CCA CRA (500 Mesh + High-Density Tuning Foam) L.csv
#     CCA CRA (500 Mesh + Sony General Foam) L.csv
#     CCA CRA (500 Mesh + Y1 Paper Filter) L.csv
#     CCA CRA (500 Mesh + Y3 Paper Filter) L.csv
#     CCA CRA (500 Mesh + Y6 Paper Filter) L.csv
#     CCA CRA (500 Mesh) L.csv
#     CCA CRA (Filterless + 2 High-Density Tuning Foams) L.csv
#     CCA CRA (Filterless + High-Density Tuning Foams) L.csv
#     CCA CRA (Filterless) L.csv
#     CCA CRA (Nylon filter) L.csv
#     CCA CRA (Sony General Foam) L.csv
#     CCA CRA (Sony Import Foam) L.csv
#     CCA CRA (Tanchjim Filter) L.csv
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: suporsalad
#     CCA CRA L.csv
#     CCA CRA R.csv
#
#   Reviewer: tgx78
#     CCA CRA L.csv
#
#   Reviewer: vortexreviews
#     CCA CRA L.csv
#
#   Reviewer: data_mrs
#     CCA CRA L.csv
#     CCA CRA R.csv
#
# IEM: cca cra plus
#
#   Reviewer: achoreviews
#     CCA CRA Plus L.csv
#
#   Reviewer: timmyv
#     CCA CRA Plus L.csv
#     CCA CRA Plus R.csv
#
#   Reviewer: pw
#     CCA CRA Plus L.csv
#
#   Reviewer: data_mrs
#     CCA CRA Plus L.csv
#     CCA CRA Plus R.csv
#
# IEM: ccz emerald
#
#   Reviewer: achoreviews
#     CCZ Emerald L.csv
#
#   Reviewer: aftersound
#     CCZ EMERALD L.csv
#     CCZ EMERALD R.csv
#
#   Reviewer: eplv
#     CCZ Emerald L.csv
#     CCZ Emerald R.csv
#
#   Reviewer: melatonin
#     CCZ emerald L.csv
#     CCZ emerald R.csv
#
# IEM: ccz melody
#
#   Reviewer: achoreviews
#     CCZ Melody L.csv
#
#   Reviewer: aftersound
#     CCZ MELODY L.csv
#     CCZ MELODY R.csv
#
#   Reviewer: harpo
#     CCZ Melody R.csv
#
#   Reviewer: ianfann
#     CCZ MELODY L.csv
#     CCZ MELODY R.csv
#
#   Reviewer: melatonin
#     CCZ melody L.csv
#     CCZ melody R.csv
#
#   Reviewer: pw
#     CCZ Melody L.csv
#
#   Reviewer: vortexreviews
#     CCZ Melody L.csv
#
# IEM: ccz warrior
#
#   Reviewer: achoreviews
#     CCZ Warrior L.csv
#
#   Reviewer: arn
#     CCZ Warrior L.csv
#
#   Reviewer: ianfann
#     CCZ WARRIOR L.csv
#     CCZ WARRIOR R.csv
#
#   Reviewer: pw
#     CCZ Warrior L.csv
#     CCZ Warrior R.csv
#
# IEM: celest pandamon
#
#   Reviewer: achoreviews
#     Celest Pandamon L.csv
#
# IEM: dunu kima
#
#   Reviewer: achoreviews
#     Dunu Kima L.csv
#
#   Reviewer: aftersound
#     DUNU KIMA L.csv
#     DUNU KIMA R.csv
#
#   Reviewer: bedrock
#     Dunu Kima L.csv
#     Dunu Kima R.csv
#
#   Reviewer: timmyv
#     Dunu Kima L.csv
#     Dunu Kima R.csv
#
#   Reviewer: hbb
#     Dunu Kima R.csv
#
#   Reviewer: cqtek
#     Dunu Kima L.csv
#     Dunu Kima R.csv
#
#   Reviewer: ianfann
#     DUNU KIMA L.csv
#     DUNU KIMA R.csv
#
#   Reviewer: nymz
#     DUNU KIMA L.csv
#     DUNU KIMA R.csv
#
#   Reviewer: vortexreviews
#     Dunu Kima L.csv
#     Dunu Kima R.csv
#
#   Reviewer: vsg
#     DUNU KIMA L.csv
#     DUNU KIMA R.csv
#
#   Reviewer: data_mrs
#     Dunu Kima L.csv
#     Dunu Kima R.csv
#
# IEM: dunu talos
#
#   Reviewer: achoreviews
#     Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv
#     Dunu Talos (Planar + BA) L.csv
#     Dunu Talos (Planar Only) (IE600 Foam Tips) L.csv
#     Dunu Talos (Planar Only) L.csv
#
#   Reviewer: animagus
#     Dunu Talos (ON) L.csv
#     Dunu Talos (ON) R.csv
#     Dunu Talos L.csv
#     Dunu Talos R.csv
#
#   Reviewer: bedrock
#     Dunu Talos (Switch Off) L.csv
#     Dunu Talos (Switch Off) R.csv
#     Dunu Talos (Switch On) L.csv
#     Dunu Talos (Switch On) R.csv
#
#   Reviewer: timmyv
#     Dunu Talos (Hybrid) L.csv
#     Dunu Talos (Hybrid) R.csv
#     Dunu Talos (Planar) L.csv
#     Dunu Talos (Planar) R.csv
#
#   Reviewer: hbb
#     Dunu Talos R.csv
#
#   Reviewer: nymz
#     DUNU TALOS L.csv
#     DUNU TALOS R.csv
#
#   Reviewer: pw
#     DUNU Talos L.csv
#     DUNU Talos R.csv
#
#   Reviewer: data_mrs
#     Dunu Talos (on) L.csv
#     Dunu Talos (on) R.csv
#     Dunu Talos (S2 off) L.csv
#     Dunu Talos (S2 off) R.csv
#     Dunu Talos (S2 on) L.csv
#     Dunu Talos (S2 on) R.csv
#     Dunu Talos L.csv
#     Dunu Talos R.csv
#
# IEM: dunu titan s
#
#   Reviewer: achoreviews
#     Dunu Titan S (Isolation) L.csv
#     Dunu Titan S L.csv
#
#   Reviewer: aftersound
#     DUNU TITAN S L.csv
#     DUNU TITAN S R.csv
#
#   Reviewer: arn
#     DUNU Titan S L.csv
#     DUNU Titan S R.csv
#
#   Reviewer: bedrock
#     Dunu Titan S L.csv
#     Dunu Titan S R.csv
#
#   Reviewer: bryaudioreviews
#     Dunu Titan S L.csv
#     Dunu Titan S R.csv
#
#   Reviewer: timmyv
#     Dunu Titan S L.csv
#     Dunu Titan S R.csv
#
#   Reviewer: hbb
#     Dunu Titan S R.csv
#
#   Reviewer: cqtek
#     Dunu Titan S L.csv
#     Dunu Titan S R.csv
#
#   Reviewer: ianfann
#     DUNU TITAN S L.csv
#     DUNU TITAN S R.csv
#
#   Reviewer: iemworld
#     DUNU TITAN S L.csv
#     DUNU TITAN S R.csv
#
#   Reviewer: nymz
#     Dunu Titan S L.csv
#     Dunu Titan S R.csv
#
#   Reviewer: rg
#     Dunu Titan S (500 Mesh) L.csv
#     Dunu Titan S (Tanchjim Filter) L.csv
#     Dunu Titan S (Y3 Paper Filter) L.csv
#     Dunu Titan S (Y6 Paper Filter) L.csv
#     Dunu Titan S L.csv
#     Dunu Titan S R.csv
#
#   Reviewer: vortexreviews
#     Dunu Titan S L.csv
#
#   Reviewer: vsg
#     DUNU TITAN S L.csv
#     DUNU TITAN S R.csv
#
#   Reviewer: data_mrs
#     Dunu Titan S (pre) L.csv
#     Dunu Titan S (pre) R.csv
#
# IEM: dunu vulkan
#
#   Reviewer: achoreviews
#     Dunu Vulkan L.csv
#
#   Reviewer: bedrock
#     Dunu Vulkan L.csv
#     Dunu Vulkan R.csv
#
#   Reviewer: timmyv
#     Dunu Vulkan L.csv
#     Dunu Vulkan R.csv
#
#   Reviewer: harpo
#     Dunu Vulkan L.csv
#     Dunu Vulkan R.csv
#
#   Reviewer: hbb
#     Dunu Vulkan R.csv
#
#   Reviewer: nymz
#     DUNU Vulkan L.csv
#     DUNU Vulkan R.csv
#
#   Reviewer: rg
#     Dunu VULKAN L.csv
#     Dunu VULKAN R.csv
#
#   Reviewer: vsg
#     DUNU VULKAN L.csv
#     DUNU VULKAN R.csv
#
#   Reviewer: data_mrs
#     Dunu Vulkan (S2 + red) R.csv
#     Dunu Vulkan (S2) L.csv
#     Dunu Vulkan (S2) R.csv
#     Dunu Vulkan L.csv
#     Dunu Vulkan R.csv
#
# IEM: effect audio axiom
#
#   Reviewer: achoreviews
#     Effect Audio Axiom L.csv
#
#   Reviewer: vsg
#     Effect Audio Axiom L.csv
#     Effect Audio Axiom R.csv
#
#   Reviewer: data_mrs
#     Effect Audio Axiom L.csv
#     Effect Audio Axiom R.csv
#
# IEM: fiio fhe eclipse
#
#   Reviewer: achoreviews
#     Fiio FHE Eclipse L.csv
#
# IEM: final audio e500
#
#   Reviewer: achoreviews
#     Final Audio E500 L.csv
#
#   Reviewer: rg
#     Final Audio E500 L.csv
#     Final Audio E500 R.csv
#
# IEM: hidition violet
#
#   Reviewer: achoreviews
#     Hidition Violet L.csv
#
#   Reviewer: soundjedi
#     Hidition Violet L.csv
#     Hidition Violet R.csv
#
#   Reviewer: cqtek
#     Hidition Violet L.csv
#
#   Reviewer: data_mrs
#     Hidition Violet L.csv
#
# IEM: hifiman re600s v2
#
#   Reviewer: achoreviews
#     Hifiman RE600s v2 L.csv
#
# IEM: hifiman svanar
#
#   Reviewer: achoreviews
#     Hifiman Svanar L.csv
#
#   Reviewer: vsg
#     HIFIMAN Svanar L.csv
#     HIFIMAN Svanar R.csv
#
# IEM: hifiman tws800
#
#   Reviewer: achoreviews
#     Hifiman TWS800 L.csv
#
#   Reviewer: ianfann
#     HIFIMAN TWS800 L.csv
#     HIFIMAN TWS800 R.csv
#
#   Reviewer: vsg
#     HIFIMAN TWS800 L.csv
#     HIFIMAN TWS800 R.csv
#
# IEM: hz sound heart mirror pro
#
#   Reviewer: achoreviews
#     HZ Sound Heart Mirror Pro L.csv
#
#   Reviewer: ianfann
#     HZ SOUND HEART MIRROR PRO L.csv
#     HZ SOUND HEART MIRROR PRO R.csv
#
# IEM: ikko opal oh02
#
#   Reviewer: achoreviews
#     Ikko Opal OH02 L.csv
#
# IEM: itk unknown
#
#   Reviewer: achoreviews
#     ITK Unknown L.csv
#
# IEM: joyodio shine
#
#   Reviewer: achoreviews
#     Joyodio Shine (0000) L.csv
#     Joyodio Shine (0010) L.csv
#     Joyodio Shine (0100) L.csv
#     Joyodio Shine (0110) L.csv
#     Joyodio Shine (1000) L.csv
#     Joyodio Shine (1010) L.csv
#     Joyodio Shine (1100) L.csv
#     Joyodio Shine (1110) L.csv
#
# IEM: kbear lark
#
#   Reviewer: achoreviews
#     KBEAR Lark (S1) L.csv
#     KBEAR Lark (S2) L.csv
#
#   Reviewer: bedrock
#     KBEAR Lark L.csv
#     KBEAR Lark R.csv
#
#   Reviewer: eplv
#     KBEAR Lark L.csv
#     KBEAR Lark R.csv
#
#   Reviewer: cqtek
#     KBEAR Lark L.csv
#     KBEAR Lark R.csv
#
#   Reviewer: melatonin
#     KBEAR Lark L.csv
#     KBEAR Lark R.csv
#
# IEM: kbear little q
#
#   Reviewer: achoreviews
#     KBEAR Little Q L.csv
#
#   Reviewer: arn
#     KBEAR Little Q L.csv
#
#   Reviewer: bryaudioreviews
#     KBEar Little Q L.csv
#     KBEar Little Q R.csv
#
#   Reviewer: ianfann
#     KBEAR LITTLE Q L.csv
#     KBEAR LITTLE Q R.csv
#
# IEM: kbear qinglong
#
#   Reviewer: achoreviews
#     KBEAR Qinglong L.csv
#
#   Reviewer: aftersound
#     KBEAR QINGLONG L.csv
#     KBEAR QINGLONG R.csv
#
#   Reviewer: arn
#     KBEAR Qinglong L.csv
#     KBEAR Qinglong R.csv
#
#   Reviewer: ianfann
#     KBEAR QINGLONG L.csv
#     KBEAR QINGLONG R.csv
#
# IEM: kbear robin
#
#   Reviewer: achoreviews
#     KBEAR Robin L.csv
#
#   Reviewer: cqtek
#     KBEAR Robin L.csv
#     KBEAR Robin R.csv
#
#   Reviewer: melatonin
#     KBEAR Robin L.csv
#     KBEAR Robin R.csv
#
#   Reviewer: pw
#     KBEAR Robin L.csv
#
#   Reviewer: rg
#     KBEAR Robin L.csv
#     KBEAR Robin R.csv
#
# IEM: kinera bd005 pro
#
#   Reviewer: achoreviews
#     Kinera BD005 Pro L.csv
#
#   Reviewer: aftersound
#     KINERA BD005 PRO R.csv
#
#   Reviewer: bedrock
#     Kinera BD005 Pro L.csv
#     Kinera BD005 Pro R.csv
#
# IEM: kiwi ears cadenza
#
#   Reviewer: achoreviews
#     Kiwi Ears Cadenza L.csv
#
#   Reviewer: aftersound
#     KIWI EARS CADENZA L.csv
#     KIWI EARS CADENZA R.csv
#
#   Reviewer: arn
#     Kiwi Ears CADENZA L.csv
#     Kiwi Ears CADENZA R.csv
#
#   Reviewer: bedrock
#     Kiwi Ears Cadenza L.csv
#     Kiwi Ears Cadenza R.csv
#
#   Reviewer: cammyfi
#     Kiwi Ears Cadenza L.csv
#     Kiwi Ears Cadenza R.csv
#
#   Reviewer: harpo
#     Kiwi Ears Cadenza R.csv
#
#   Reviewer: hbb
#     Kiwi Ears Cadenza R.csv
#
#   Reviewer: hobbytalk
#     Kiwi Ears Cadenza L.csv
#     Kiwi Ears Cadenza R.csv
#
#   Reviewer: vortexreviews
#     Kiwi Ears Cadenza L.csv
#     Kiwi Ears Cadenza R.csv
#
#   Reviewer: data_mrs
#     Kiwi Ears Cadenza L.csv
#     Kiwi Ears Cadenza R.csv
#
# IEM: kiwi ears orchestra lite
#
#   Reviewer: achoreviews
#     Kiwi Ears Orchestra Lite L.csv
#
#   Reviewer: bedrock
#     Kiwi Ears Orchestra Lite L.csv
#     Kiwi Ears Orchestra Lite R.csv
#
#   Reviewer: nymz
#     Kiwi Ears Orchestra Lite L.csv
#     Kiwi Ears Orchestra Lite R.csv
#
#   Reviewer: pw
#     Kiwi Ears Orchestra Lite L.csv
#     Kiwi Ears Orchestra Lite R.csv
#
#   Reviewer: rg
#     Kiwi Ears Orchestra Lite (2.5mm 500 mesh on green bore) L.csv
#     Kiwi Ears Orchestra Lite (2.5mm 500 mesh on white bore) L.csv
#     Kiwi Ears Orchestra Lite (2.5mm 500 mesh on yellow bore) L.csv
#     Kiwi Ears Orchestra Lite (25ohm) L.csv
#     Kiwi Ears Orchestra Lite L.csv
#     Kiwi Ears Orchestra Lite R.csv
#
#   Reviewer: vortexreviews
#     Kiwi Ears Orchestra Lite L.csv
#     Kiwi Ears Orchestra Lite R.csv
#
#   Reviewer: vsg
#     Kiwi Ears Orchestra Lite L.csv
#     Kiwi Ears Orchestra Lite R.csv
#
#   Reviewer: data_mrs
#     Kiwi Ears Orchestra Lite L.csv
#     Kiwi Ears Orchestra Lite R.csv
#
# IEM: koss keb90
#
#   Reviewer: achoreviews
#     Koss KEB90 L.csv
#
#   Reviewer: hobbytalk
#     KOSS KEB90 L.csv
#     KOSS KEB90 R.csv
#
#   Reviewer: data_mrs
#     Koss KEB90 L.csv
#     Koss KEB90 R.csv
#
# IEM: kz as16 pro
#
#   Reviewer: achoreviews
#     KZ AS16 Pro L.csv
#
#   Reviewer: aftersound
#     KZ AS16 PRO L.csv
#     KZ AS16 PRO R.csv
#
#   Reviewer: hbb
#     KZ AS16 Pro R.csv
#
#   Reviewer: ianfann
#     KZ AS16 PRO L.csv
#     KZ AS16 PRO R.csv
#
#   Reviewer: melatonin
#     KZ AS16 Pro L.csv
#     KZ AS16 Pro R.csv
#
#   Reviewer: pw
#     KZ AS16 Pro 25ohm L.csv
#     KZ AS16 Pro L.csv
#     KZ AS16 Pro R.csv
#
#   Reviewer: vortexreviews
#     KZ AS16 Pro L.csv
#     KZ AS16 Pro R.csv
#
# IEM: kz ate
#
#   Reviewer: achoreviews
#     KZ ATE L.csv
#
#   Reviewer: data_mrs
#     KZ ATE L.csv
#     KZ ATE R.csv
#
# IEM: kz dq6
#
#   Reviewer: achoreviews
#     KZ DQ6 L.csv
#
#   Reviewer: aftersound
#     KZ DQ6 R.csv
#
#   Reviewer: eplv
#     KZ DQ6 L.csv
#     KZ DQ6 R.csv
#
#   Reviewer: hbb
#     KZ DQ6 R.csv
#
#   Reviewer: ianfann
#     KZ DQ6 L.csv
#     KZ DQ6 R.csv
#
#   Reviewer: jacstone
#     KZ DQ6 L.csv
#     KZ DQ6 R.csv
#
#   Reviewer: melatonin
#     KZ DQ6 L.csv
#     KZ DQ6 R.csv
#
#   Reviewer: nymz
#     KZ DQ6 L.csv
#     KZ DQ6 R.csv
#
#   Reviewer: pw
#     KZ DQ6 L.csv
#
#   Reviewer: rg
#     KZ DQ6 (1dividedby16 foam) L.csv
#     KZ DQ6 (Hana Filter) L.csv
#     KZ DQ6 (High-Density Tuning Foam + cotton filter) L.csv
#     KZ DQ6 (High-Density Tuning Foam) L.csv
#     KZ DQ6 (Low-Density Tuning Foam) L.csv
#     KZ DQ6 (Micropore Tape Mod) L.csv
#     KZ DQ6 (Micropore tape+ 1dividedby16foam Mod) L.csv
#     KZ DQ6 (Micropore Tips) L.csv
#     KZ DQ6 (Micropore+ 1dividedby16foam Tips) L.csv
#     KZ DQ6 (O2 Filter) L.csv
#     KZ DQ6 (Sony Import Foam) L.csv
#     KZ DQ6 L.csv
#
#   Reviewer: vortexreviews
#     KZ DQ6 R.csv
#
#   Reviewer: data_mrs
#     KZ DQ6 (Tanchjim filter) L.csv
#     KZ DQ6 (Tanchjim filter) R.csv
#     KZ DQ6 L.csv
#     KZ DQ6 R.csv
#
# IEM: kz dq6s
#
#   Reviewer: achoreviews
#     KZ DQ6s L.csv
#
#   Reviewer: aftersound
#     KZ DQ6S L.csv
#     KZ DQ6S R.csv
#
#   Reviewer: bedrock
#     KZ DQ6S L.csv
#     KZ DQ6S R.csv
#
#   Reviewer: harpo
#     KZ DQ6S R.csv
#
#   Reviewer: ianfann
#     KZ DQ6S L.csv
#     KZ DQ6S R.csv
#
#   Reviewer: jacstone
#     KZ DQ6S L.csv
#     KZ DQ6S R.csv
#
#   Reviewer: melatonin
#     KZ DQ6s L.csv
#     KZ DQ6s R.csv
#
#   Reviewer: nymz
#     KZ DQ6s L.csv
#     KZ DQ6s R.csv
#
#   Reviewer: pw
#     KZ DQ6S L.csv
#     KZ DQ6S R.csv
#
#   Reviewer: rg
#     KZ DQ6S L.csv
#     KZ DQ6S R.csv
#
# IEM: kz dqs
#
#   Reviewer: achoreviews
#     KZ DQS L.csv
#
#   Reviewer: ianfann
#     KZ DQS L.csv
#     KZ DQS R.csv
#
#   Reviewer: pw
#     KZ DQS L.csv
#     KZ DQS R.csv
#
#   Reviewer: vortexreviews
#     KZ DQS R.csv
#
# IEM: kz ed16
#
#   Reviewer: achoreviews
#     KZ ED16 L.csv
#
# IEM: kz edx
#
#   Reviewer: achoreviews
#     KZ EDX L.csv
#
#   Reviewer: aftersound
#     KZ EDX R.csv
#
#   Reviewer: eplv
#     KZ EDX L.csv
#     KZ EDX R.csv
#
#   Reviewer: jacstone
#     KZ EDX L.csv
#     KZ EDX R.csv
#
#   Reviewer: melatonin
#     KZ EDX L.csv
#     KZ EDX R.csv
#
#   Reviewer: pw
#     KZ EDX L.csv
#
#   Reviewer: vortexreviews
#     KZ EDX L.csv
#     KZ EDX R.csv
#
# IEM: kz edx pro
#
#   Reviewer: achoreviews
#     KZ EDX Pro L.csv
#
#   Reviewer: aftersound
#     KZ EDX PRO L.csv
#     KZ EDX PRO R.csv
#
#   Reviewer: hbb
#     KZ EDX PRO R.csv
#
#   Reviewer: jacstone
#     KZ EDX PRO L.csv
#     KZ EDX PRO R.csv
#
#   Reviewer: melatonin
#     KZ EDX Pro L.csv
#     KZ EDX Pro R.csv
#
#   Reviewer: pw
#     KZ EDX Pro L.csv
#     KZ EDX Pro R.csv
#
#   Reviewer: rg
#     KZ EDX Pro (2 Low-Density Tuning Foams) L.csv
#     KZ EDX Pro (High-Density Tuning Foam) L.csv
#     KZ EDX Pro (Low-Density Tuning Foam) L.csv
#     KZ EDX Pro L.csv
#     KZ EDX Pro R.csv
#
#   Reviewer: vortexreviews
#     KZ EDX Pro L.csv
#
#   Reviewer: data_mrs
#     KZ EDX Pro L.csv
#     KZ EDX Pro R.csv
#
# IEM: kz pr1
#
#   Reviewer: achoreviews
#     KZ PR1 L.csv
#
#   Reviewer: timmyv
#     KZ PR1 L.csv
#     KZ PR1 R.csv
#
#   Reviewer: hbb
#     KZ PR1 R.csv
#
#   Reviewer: ianfann
#     KZ PR1 L.csv
#     KZ PR1 R.csv
#
# IEM: kz zax
#
#   Reviewer: achoreviews
#     KZ ZAX L.csv
#
#   Reviewer: hbb
#     KZ ZAX R.csv
#
#   Reviewer: melatonin
#     KZ ZAX L.csv
#     KZ ZAX R.csv
#
#   Reviewer: pw
#     KZ ZAX L.csv
#
#   Reviewer: vortexreviews
#     KZ ZAX L.csv
#
# IEM: kz zes
#
#   Reviewer: achoreviews
#     KZ ZES L.csv
#
#   Reviewer: aftersound
#     KZ ZES L.csv
#     KZ ZES R.csv
#
#   Reviewer: ianfann
#     KZ ZES L.csv
#     KZ ZES R.csv
#
#   Reviewer: pw
#     KZ ZES L.csv
#
#   Reviewer: rg
#     KZ ZES L.csv
#     KZ ZES R.csv
#
#   Reviewer: vortexreviews
#     KZ ZES L.csv
#     KZ ZES R.csv
#
# IEM: kz zex
#
#   Reviewer: achoreviews
#     KZ ZEX L.csv
#
#   Reviewer: bryaudioreviews
#     KZ ZEX L.csv
#     KZ ZEX R.csv
#
#   Reviewer: hbb
#     KZ ZEX R.csv
#
#   Reviewer: ianfann
#     KZ ZEX L.csv
#     KZ ZEX R.csv
#
#   Reviewer: iemworld
#     KZ ZEX L.csv
#     KZ ZEX R.csv
#
#   Reviewer: jacstone
#     KZ ZEX L.csv
#     KZ ZEX R.csv
#
#   Reviewer: melatonin
#     KZ ZEX L.csv
#     KZ ZEX R.csv
#
#   Reviewer: suporsalad
#     KZ ZEX L.csv
#     KZ ZEX R.csv
#
#   Reviewer: tgx78
#     KZ ZEX L.csv
#
#   Reviewer: vortexreviews
#     KZ ZEX L.csv
#
#   Reviewer: data_mrs
#     KZ ZEX (vent blocked) L.csv
#     KZ ZEX L.csv
#     KZ ZEX R.csv
#
# IEM: kz zex pro
#
#   Reviewer: achoreviews
#     KZ ZEX Pro L.csv
#
#   Reviewer: aftersound
#     KZ ZEX PRO L.csv
#     KZ ZEX PRO R.csv
#
#   Reviewer: hbb
#     KZ ZEX PRO R.csv
#
#   Reviewer: ianfann
#     KZ ZEX PRO L.csv
#     KZ ZEX PRO R.csv
#
#   Reviewer: jacstone
#     KZ ZEX PRO L.csv
#     KZ ZEX PRO R.csv
#
#   Reviewer: pw
#     KZ ZEX Pro L.csv
#     KZ ZEX Pro R.csv
#
#   Reviewer: rg
#     KZ ZEX Pro (30ohm) L.csv
#     KZ ZEX Pro L.csv
#     KZ ZEX Pro R.csv
#
#   Reviewer: tgx78
#     KZ Zex Pro L.csv
#     KZ Zex Pro R.csv
#
#   Reviewer: vortexreviews
#     KZ ZEX Pro L.csv
#     KZ ZEX Pro R.csv
#
#   Reviewer: data_mrs
#     KZ ZEX Pro L.csv
#     KZ ZEX Pro R.csv
#
# IEM: kz zs10 pro
#
#   Reviewer: achoreviews
#     KZ ZS10 Pro L.csv
#
#   Reviewer: aftersound
#     KZ ZS10 PRO R.csv
#
#   Reviewer: eplv
#     KZ ZS10 Pro L.csv
#     KZ ZS10 Pro R.csv
#
#   Reviewer: timmyv
#     KZ ZS10 PRO L.csv
#     KZ ZS10 PRO R.csv
#
#   Reviewer: ianfann
#     KZ ZS10 PRO L.csv
#     KZ ZS10 PRO R.csv
#
#   Reviewer: jacstone
#     KZ ZS10 PRO L.csv
#     KZ ZS10 PRO R.csv
#
#   Reviewer: melatonin
#     KZ ZS10 Pro L.csv
#     KZ ZS10 Pro R.csv
#
#   Reviewer: pw
#     KZ ZS10 Pro L.csv
#
#   Reviewer: data_mrs
#     KZ ZS10 Pro L.csv
#
# IEM: kz zsn
#
#   Reviewer: achoreviews
#     KZ ZSN L.csv
#
#   Reviewer: eplv
#     KZ ZSN L.csv
#     KZ ZSN R.csv
#
#   Reviewer: hbb
#     KZ ZSN R.csv
#
#   Reviewer: melatonin
#     KZ ZSN L.csv
#     KZ ZSN R.csv
#
#   Reviewer: pw
#     KZ ZSN L.csv
#
# IEM: kz zsn pro
#
#   Reviewer: achoreviews
#     KZ ZSN Pro L.csv
#
#   Reviewer: aftersound
#     KZ ZSN PRO L.csv
#     KZ ZSN PRO R.csv
#
#   Reviewer: melatonin
#     KZ ZSN Pro L.csv
#     KZ ZSN Pro R.csv
#
#   Reviewer: pw
#     KZ ZSN Pro L.csv
#
#   Reviewer: data_mrs
#     KZ ZSN Pro (1-8 foam) L.csv
#     KZ ZSN Pro (Blessing 2 filter) L.csv
#     KZ ZSN Pro (Starfield filter) L.csv
#     KZ ZSN Pro (Tanchjim filter) L.csv
#     KZ ZSN Pro L.csv
#
# IEM: kz zsn pro x
#
#   Reviewer: achoreviews
#     KZ ZSN Pro X L.csv
#
#   Reviewer: aftersound
#     KZ ZSN PRO X R.csv
#
#   Reviewer: bryaudioreviews
#     KZ ZSN Pro X L.csv
#     KZ ZSN Pro X R.csv
#
#   Reviewer: hbb
#     KZ ZSN Pro X R.csv
#
#   Reviewer: melatonin
#     KZ ZSN Pro X L.csv
#     KZ ZSN Pro X R.csv
#
#   Reviewer: pw
#     KZ ZSN Pro X L.csv
#
# IEM: kz zst x
#
#   Reviewer: achoreviews
#     KZ ZST X L.csv
#
#   Reviewer: aftersound
#     KZ ZST X R.csv
#
#   Reviewer: hbb
#     KZ ZST X R.csv
#
#   Reviewer: melatonin
#     KZ ZST X L.csv
#     KZ ZST X R.csv
#
#   Reviewer: vortexreviews
#     KZ ZST X L.csv
#
# IEM: kz zvx
#
#   Reviewer: achoreviews
#     KZ ZVX L.csv
#
#   Reviewer: aftersound
#     KZ ZVX L.csv
#     KZ ZVX R.csv
#
#   Reviewer: timmyv
#     KZ ZVX L.csv
#     KZ ZVX R.csv
#
#   Reviewer: harpo
#     KZ ZVX R.csv
#
#   Reviewer: hbb
#     Kz Zvx R.csv
#
#   Reviewer: ianfann
#     KZ ZVX L.csv
#     KZ ZVX R.csv
#
#   Reviewer: pw
#     KZ ZVX 25ohm L.csv
#     KZ ZVX L.csv
#
# IEM: letshuoer d13
#
#   Reviewer: achoreviews
#     Letshuoer D13 (Gold Filter) L.csv
#     Letshuoer D13 (Silver Filter) L.csv
#
#   Reviewer: bedrock
#     Letshuoer D13 (Gold) L.csv
#     Letshuoer D13 (Gold) R.csv
#     Letshuoer D13 (Silver) L.csv
#     Letshuoer D13 (Silver) R.csv
#
#   Reviewer: hobbytalk
#     LETSHUOER D13 L.csv
#     LETSHUOER D13 R.csv
#
#   Reviewer: ianfann
#     LETSHUOER D13 (TREBLE NOZZLE) L.csv
#     LETSHUOER D13 (TREBLE NOZZLE) R.csv
#     LETSHUOER D13 L.csv
#     LETSHUOER D13 R.csv
#
#   Reviewer: vortexreviews
#     LETSHUOER D13 R.csv
#
#   Reviewer: data_mrs
#     Letshuoer D13 (gold) L.csv
#     Letshuoer D13 (gold) R.csv
#     Letshuoer D13 (pre-prod - nozzle A) L.csv
#     Letshuoer D13 (pre-prod - nozzle A) R.csv
#     Letshuoer D13 (pre-prod - nozzle B) L.csv
#     Letshuoer D13 (pre-prod - nozzle B) R.csv
#     Letshuoer D13 (silver) L.csv
#     Letshuoer D13 (silver) R.csv
#
# IEM: letshuoer s12
#
#   Reviewer: achoreviews
#     Letshuoer S12 (S1) L.csv
#     Letshuoer S12 (S2) L.csv
#
#   Reviewer: arn
#     LETSHUOER S12 L.csv
#
#   Reviewer: soundjedi
#     LetShuoer S12 L.csv
#     LetShuoer S12 R.csv
#
#   Reviewer: eplv
#     LETSHUOER S12 L.csv
#     LETSHUOER S12 R.csv
#
#   Reviewer: timmyv
#     Letshuoer S12 L.csv
#     Letshuoer S12 R.csv
#
#   Reviewer: harpo
#     Letshuoer S12 R.csv
#
#   Reviewer: cqtek
#     LetShuoer S12 L.csv
#     LetShuoer S12 R.csv
#
#   Reviewer: melatonin
#     LETSHUOER S12 R.csv
#
#   Reviewer: vortexreviews
#     LETSHUOER S12 L.csv
#     LETSHUOER S12 R.csv
#
#   Reviewer: vsg
#     LETSHUOER S12 L.csv
#     LETSHUOER S12 R.csv
#
#   Reviewer: data_mrs
#     Letshuoer S12 (front vent blocked) L.csv
#     Letshuoer S12 (post) L.csv
#     Letshuoer S12 (post) R.csv
#     Letshuoer S12 (prepro) L.csv
#     Letshuoer S12 (prepro) R.csv
#     Letshuoer S12 (top vent blocked) L.csv
#     Letshuoer S12 L.csv
#     Letshuoer S12 R.csv
#
# IEM: lz a4 pro nzblk fiblk
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzBlk FiBlk L.csv
#
# IEM: lz a4 pro nzblk fiblu
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzBlk FiBlu L.csv
#
# IEM: lz a4 pro nzblk fired
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzBlk FiRed L.csv
#
# IEM: lz a4 pro nzblu fiblk
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzBlu FiBlk L.csv
#
# IEM: lz a4 pro nzblu fiblu
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzBlu FiBlu L.csv
#
# IEM: lz a4 pro nzblu fired
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzBlu FiRed L.csv
#
# IEM: lz a4 pro nzred fiblk
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzRed FiBlk L.csv
#
# IEM: lz a4 pro nzred fiblu
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzRed FiBlu L.csv
#
# IEM: lz a4 pro nzred fired
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzRed FiRed L.csv
#
# IEM: lz a4 pro nzsil fiblk
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzSil FiBlk L.csv
#
# IEM: lz a4 pro nzsil fiblu
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzSil FiBlu L.csv
#
# IEM: lz a4 pro nzsil fired
#
#   Reviewer: achoreviews
#     LZ A4 Pro NzSil FiRed L.csv
#
# IEM: meze audio advar
#
#   Reviewer: achoreviews
#     Meze Audio Advar L.csv
#
# IEM: moondrop aria
#
#   Reviewer: achoreviews
#     Moondrop Aria L.csv
#
#   Reviewer: aftersound
#     MOONDROP ARIA (OLD) L.csv
#     MOONDROP ARIA (OLD) R.csv
#     MOONDROP ARIA L.csv
#     MOONDROP ARIA R.csv
#
#   Reviewer: animagus
#     Moondrop Aria L.csv
#     Moondrop Aria R.csv
#
#   Reviewer: bedrock
#     Moondrop Aria L.csv
#     Moondrop Aria R.csv
#
#   Reviewer: bryaudioreviews
#     Moondrop Aria L.csv
#     Moondrop Aria R.csv
#
#   Reviewer: timmyv
#     Moondrop Aria L.csv
#     Moondrop Aria R.csv
#
#   Reviewer: harpo
#     Moondrop Aria R.csv
#
#   Reviewer: hbb
#     Moondrop Aria R.csv
#
#   Reviewer: ianfann
#     MOONDROP ARIA L.csv
#     MOONDROP ARIA R.csv
#
#   Reviewer: pw
#     Moondrop Aria L.csv
#     Moondrop Aria R.csv
#
#   Reviewer: vortexreviews
#     Moondrop Aria L.csv
#
#   Reviewer: vsg
#     Moondrop Aria L.csv
#     Moondrop Aria R.csv
#
#   Reviewer: data_mrs
#     Moondrop Aria L.csv
#
# IEM: moondrop blessing 2 dusk
#
#   Reviewer: achoreviews
#     Moondrop Blessing 2 Dusk (Spinfit) L.csv
#
#   Reviewer: cqtek
#     Moondrop Blessing 2 Dusk L.csv
#     Moondrop Blessing 2 Dusk R.csv
#
#   Reviewer: iemworld
#     Moondrop Blessing 2 Dusk (BGVP Foam) L.csv
#     Moondrop Blessing 2 Dusk (BGVP Foam) R.csv
#     Moondrop Blessing 2 Dusk (FINAL EARTIPS) L.csv
#     Moondrop Blessing 2 Dusk (FINAL EARTIPS) R.csv
#     Moondrop Blessing 2 Dusk (NO TIP on Coupler 8K) L.csv
#     Moondrop Blessing 2 Dusk (NO TIP on Coupler 8K) R.csv
#     Moondrop Blessing 2 Dusk (ORIGNAL SILICON) L.csv
#     Moondrop Blessing 2 Dusk (ORIGNAL SILICON) R.csv
#     Moondrop Blessing 2 Dusk (SOFTEAR UC EARTIPS) R.csv
#     Moondrop Blessing 2 Dusk (Tripowin Foam) L.csv
#     Moondrop Blessing 2 Dusk (Tripowin Foam) R.csv
#
#   Reviewer: data_mrs
#     Moondrop Blessing 2 Dusk (Precog) L.csv
#     Moondrop Blessing 2 Dusk L.csv
#
# IEM: moondrop chu
#
#   Reviewer: achoreviews
#     Moondrop Chu L.csv
#
#   Reviewer: aftersound
#     MOONDROP CHU L.csv
#     MOONDROP CHU R.csv
#
#   Reviewer: arn
#     Moondrop Chu L.csv
#
#   Reviewer: bedrock
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
#   Reviewer: cammyfi
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
#   Reviewer: eplv
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
#   Reviewer: timmyv
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
#   Reviewer: harpo
#     Moondrop Chu R.csv
#
#   Reviewer: hbb
#     Moondrop CHU R.csv
#
#   Reviewer: hobbytalk
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
#   Reviewer: ianfann
#     MOONDROP CHU (MOD) L.csv
#     MOONDROP CHU (MOD) R.csv
#     MOONDROP CHU (SF 145) L.csv
#     MOONDROP CHU (SF 145) R.csv
#     MOONDROP CHU (SPRING TIPS) L.csv
#     MOONDROP CHU (SPRING TIPS) R.csv
#     MOONDROP CHU L.csv
#     MOONDROP CHU R.csv
#
#   Reviewer: iemworld
#     MoonDrop CHU L.csv
#     MoonDrop CHU R.csv
#
#   Reviewer: jacstone
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
#   Reviewer: nymz
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
#   Reviewer: pw
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
#   Reviewer: suporsalad
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
#   Reviewer: vortexreviews
#     Moondrop Chu R.csv
#
#   Reviewer: vsg
#     Moondrop CHU L.csv
#     Moondrop CHU R.csv
#
#   Reviewer: data_mrs
#     Moondrop Chu (Tanchjim filter) L.csv
#     Moondrop Chu (Tanchjim filter) R.csv
#     Moondrop Chu (vent - BluTack) L.csv
#     Moondrop Chu (vent - BluTack) R.csv
#     Moondrop Chu (vent - Tanchjim) L.csv
#     Moondrop Chu (vent - Tanchjim) R.csv
#     Moondrop Chu L.csv
#     Moondrop Chu R.csv
#
# IEM: moondrop nekocake
#
#   Reviewer: achoreviews
#     Moondrop Nekocake (Balanced + ANC) L.csv
#     Moondrop Nekocake (Balanced) L.csv
#     Moondrop Nekocake (Classic) L.csv
#     Moondrop Nekocake (Nobass) L.csv
#     Moondrop Nekocake (Wennebostel) L.csv
#     Moondrop Nekocake (X-Dynamic) L.csv
#
#   Reviewer: aftersound
#     MOONDROP NEKOCAKE L.csv
#     MOONDROP NEKOCAKE R.csv
#
#   Reviewer: vsg
#     MOONDROP NEKOCAKE L.csv
#     MOONDROP NEKOCAKE R.csv
#
#   Reviewer: data_mrs
#     Moondrop Nekocake (ANC off) L.csv
#     Moondrop Nekocake (ANC off) R.csv
#     Moondrop Nekocake (ANC on) L.csv
#     Moondrop Nekocake (ANC on) R.csv
#     Moondrop Nekocake (Classic ANC) L.csv
#     Moondrop Nekocake (Dynamic ANC) L.csv
#     Moondrop Nekocake (Nobass ANC) L.csv
#     Moondrop Nekocake (Wennebostel ANC) L.csv
#
# IEM: moondrop quarks
#
#   Reviewer: achoreviews
#     Moondrop Quarks L.csv
#
#   Reviewer: aftersound
#     MOONDROP QUARKS L.csv
#     MOONDROP QUARKS R.csv
#
#   Reviewer: bedrock
#     Moondrop Quarks L.csv
#     Moondrop Quarks R.csv
#
#   Reviewer: eplv
#     Moondrop Quarks L.csv
#     Moondrop Quarks R.csv
#
#   Reviewer: hobbytalk
#     Moondrop Quarks (S2) L.csv
# ...
#
# IEM: campfire audio pathfinder
#
#   Reviewer: data_mrs
#     Campfire Audio Pathfinder L.csv
#     Campfire Audio Pathfinder R.csv
#
# IEM: cayin fantasy
#
#   Reviewer: data_mrs
#     Cayin Fantasy L.csv
#
# IEM: co-donguri shizuku
#
#   Reviewer: data_mrs
#     Co-Donguri Shizuku L.csv
#
# IEM: colorfly quintet
#
#   Reviewer: data_mrs
#     Colorfly Quintet L.csv
#     Colorfly Quintet R.csv
#
# IEM: custom art fibae 7 unlimited
#
#   Reviewer: data_mrs
#     Custom Art Fibae 7 Unlimited L.csv
#     Custom Art Fibae 7 Unlimited R.csv
#
# IEM: dunu est 112 og
#
#   Reviewer: data_mrs
#     Dunu EST 112 OG L.csv
#
# IEM: dunu sa3
#
#   Reviewer: data_mrs
#     Dunu SA3 L.csv
#
# IEM: dunu vulka
#
#   Reviewer: data_mrs
#     Dunu Vulka (S2 + red) L.csv
#
# IEM: earfun free pro oluv edition
#
#   Reviewer: data_mrs
#     EarFun Free Pro Oluv Edition (ANC) L.csv
#     EarFun Free Pro Oluv Edition L.csv
#
# IEM: empire ears bravado mkii
#
#   Reviewer: data_mrs
#     Empire Ears Bravado mkII L.csv
#
# IEM: empire ears esr mkii
#
#   Reviewer: data_mrs
#     Empire Ears ESR mkII L.csv
#
# IEM: empire ears valkyrie mkii
#
#   Reviewer: data_mrs
#     Empire Ears Valkyrie mkII L.csv
#
# IEM: etymotic er4s
#
#   Reviewer: data_mrs
#     Etymotic ER4S L.csv
#     Etymotic ER4S R.csv
#
# IEM: etymotic er4xr
#
#   Reviewer: data_mrs
#     Etymotic ER4XR (2F) L.csv
#     Etymotic ER4XR (foam) L.csv
#     Etymotic ER4XR L.csv
#
# IEM: etymotic erx
#
#   Reviewer: data_mrs
#     Etymotic ERX (brown) L.csv
#     Etymotic ERX (brown) R.csv
#     Etymotic ERX L.csv
#     Etymotic ERX R.csv
#
# IEM: etymotic ety kids
#
#   Reviewer: data_mrs
#     Etymotic ETY Kids L.csv
#
# IEM: etymotic mk5
#
#   Reviewer: data_mrs
#     Etymotic MK5 L.csv
#
# IEM: etyotic er2xr
#
#   Reviewer: data_mrs
#     Etyotic ER2XR (S2) L.csv
#
# IEM: fiio fa1
#
#   Reviewer: data_mrs
#     Fiio FA1 L.csv
#
# IEM: fiio fd7
#
#   Reviewer: data_mrs
#     Fiio FD7 (40 hrs) L.csv
#     Fiio FD7 (40 hrs) R.csv
#     Fiio FD7 (balanced) L.csv
#     Fiio FD7 (balanced) R.csv
#     Fiio FD7 (bass + SpinFit) L.csv
#     Fiio FD7 (bass + SpinFit) R.csv
#     Fiio FD7 (bass) L.csv
#     Fiio FD7 (bass) R.csv
#     Fiio FD7 (treble) L.csv
#     Fiio FD7 (treble) R.csv
#     Fiio FD7 L.csv
#     Fiio FD7 R.csv
#
# IEM: fiio fh7s
#
#   Reviewer: data_mrs
#     Fiio FH7S (bass) L.csv
#     Fiio FH7S (bass) R.csv
#     Fiio FH7S (treble) L.csv
#     Fiio FH7S (treble) R.csv
#     Fiio FH7S L.csv
#     Fiio FH7S R.csv
#
# IEM: final b3
#
#   Reviewer: data_mrs
#     Final B3 (E-type) L.csv
#     Final B3 (TWS) L.csv
#
# IEM: final vr3000
#
#   Reviewer: data_mrs
#     Final VR3000 L.csv
#
# IEM: flc 8p
#
#   Reviewer: data_mrs
#     FLC 8P (gold-black-gunmetal) L.csv
#     FLC 8P (gold-black-red) L.csv
#     FLC 8P (gold-gray-gunmetal) L.csv
#     FLC 8P (gold-white-gunmetal) L.csv
#     FLC 8P (gold-white-transparent) L.csv
#     FLC 8P (green-gray-gunmetal) L.csv
#     FLC 8P (gunmetal-black-gunmetal) L.csv
#     FLC 8P (gunmetal-gray-gunmetal) L.csv
#     FLC 8P (silver-gray-gunmetal) L.csv
#
# IEM: flc dd31
#
#   Reviewer: data_mrs
#     FLC DD31 L.csv
#
# IEM: gs audio gd3c
#
#   Reviewer: data_mrs
#     GS Audio GD3C L.csv
#     GS Audio GD3C R.csv
#
# IEM: harmonicdyne pd1
#
#   Reviewer: data_mrs
#     HarmonicDyne PD1 L.csv
#     HarmonicDyne PD1 R.csv
#
# IEM: haylou gt1
#
#   Reviewer: data_mrs
#     Haylou GT1 L.csv
#
# IEM: haylou gt2
#
#   Reviewer: data_mrs
#     Haylou GT2 L.csv
#     Haylou GT2 R.csv
#
# IEM: hiby crystal6 ii
#
#   Reviewer: data_mrs
#     Hiby Crystal6 II L.csv
#     Hiby Crystal6 II R.csv
#
# IEM: hiby crystal6
#
#   Reviewer: data_mrs
#     Hiby Crystal6 L.csv
#
# IEM: hifiman bolt
#
#   Reviewer: data_mrs
#     Hifiman Bolt L.csv
#
# IEM: ibasso it01x
#
#   Reviewer: data_mrs
#     iBasso IT01X (S2) L.csv
#     iBasso IT01X (S2) R.csv
#     iBasso IT01X L.csv
#     iBasso IT01X R.csv
#
# IEM: ikko oh1
#
#   Reviewer: data_mrs
#     Ikko OH1 L.csv
#
# IEM: jh audio layla
#
#   Reviewer: data_mrs
#     JH Audio Layla (max) L.csv
#     JH Audio Layla (max) R.csv
#     JH Audio Layla (min) L.csv
#     JH Audio Layla (min) R.csv
#
# IEM: jvc fwx1
#
#   Reviewer: data_mrs
#     JVC FWX1 L.csv
#     JVC FWX1 R.csv
#
# IEM: jvc fx7
#
#   Reviewer: data_mrs
#     JVC FX7 L.csv
#     JVC FX7 R.csv
#
# IEM: kinera sif
#
#   Reviewer: data_mrs
#     Kinera Sif L.csv
#
# IEM: kiwi ears orchestra
#
#   Reviewer: data_mrs
#     Kiwi Ears Orchestra (E-type TWS) L.csv
#     Kiwi Ears Orchestra (E-type TWS) R.csv
#     Kiwi Ears Orchestra (Sedna Short) L.csv
#     Kiwi Ears Orchestra (Sedna Short) R.csv
#     Kiwi Ears Orchestra L.csv
#     Kiwi Ears Orchestra R.csv
#
# IEM: kz
#
#   Reviewer: data_mrs
#     KZ (avg) L.csv
#
# IEM: letshuoer ej07m kinda lava
#
#   Reviewer: data_mrs
#     Letshuoer EJ07M Kinda Lava (modded) L.csv
#     Letshuoer EJ07M Kinda Lava (modded) R.csv
#     Letshuoer EJ07M Kinda Lava L.csv
#     Letshuoer EJ07M Kinda Lava R.csv
#
# IEM: letshuoer singer
#
#   Reviewer: data_mrs
#     Letshuoer Singer L.csv
#
# IEM: lg hbs800
#
#   Reviewer: data_mrs
#     LG HBS800 (ANC off) L.csv
#     LG HBS800 (ANC off) R.csv
#     LG HBS800 (ANC on) L.csv
#     LG HBS800 (ANC on) R.csv
#     LG HBS800 L.csv
#     LG HBS800 R.csv
#
# IEM: magaosi k3
#
#   Reviewer: data_mrs
#     Magaosi K3 (F0) L.csv
#     Magaosi K3 (F0) R.csv
#     Magaosi K3 (F1) L.csv
#     Magaosi K3 (F1) R.csv
#     Magaosi K3 (F2) L.csv
#     Magaosi K3 (F2) R.csv
#     Magaosi K3 L.csv
#
# IEM: magaosi k5
#
#   Reviewer: data_mrs
#     Magaosi K5 (15 ohm + IEMatch+ ultra) L.csv
#     Magaosi K5 (15 ohm + IEMatch+) L.csv
#     Magaosi K5 (15 ohm) L.csv
#     Magaosi K5 L.csv
#
# IEM: mee audio m6 pro 2g
#
#   Reviewer: data_mrs
#     MEE Audio M6 Pro 2G L.csv
#
# IEM: meizu live
#
#   Reviewer: data_mrs
#     Meizu Live (black) L.csv
#     Meizu Live (blue) L.csv
#     Meizu Live (white) L.csv
#
# IEM: mi true wireless earbuds basic 2
#
#   Reviewer: data_mrs
#     Mi True Wireless Earbuds Basic 2 L.csv
#
# IEM: mim dark magician revised
#
#   Reviewer: data_mrs
#     MiM Dark Magician Revised L.csv
#     MiM Dark Magician Revised R.csv
#
# IEM: moondrop alice
#
#   Reviewer: data_mrs
#     Moondrop Alice (0.1.9) L.csv
#     Moondrop Alice (0.1.9) R.csv
#     Moondrop Alice (2.0.1 + E-type) L.csv
#     Moondrop Alice (2.0.1 + E-type) R.csv
#     Moondrop Alice (2.0.1) L.csv
#     Moondrop Alice (2.0.1) R.csv
#     Moondrop Alice (EQ Austria) L.csv
#     Moondrop Alice (EQ Austria) R.csv
#     Moondrop Alice (EQ Berlin) L.csv
#     Moondrop Alice (EQ Berlin) R.csv
#     Moondrop Alice (EQ Brooklyn) L.csv
#     Moondrop Alice (EQ Brooklyn) R.csv
#     Moondrop Alice (EQ Hokkaido) L.csv
#     Moondrop Alice (EQ Hokkaido) R.csv
#     Moondrop Alice (EQ Munich) L.csv
#     Moondrop Alice (EQ Munich) R.csv
#     Moondrop Alice (EQ PEQ default) L.csv
#     Moondrop Alice (EQ PEQ default) R.csv
#     Moondrop Alice (EQ Tokyo) L.csv
#     Moondrop Alice (EQ Tokyo) R.csv
#     Moondrop Alice (EQ Vienna) L.csv
#     Moondrop Alice (EQ Vienna) R.csv
#     Moondrop Alice (EQ Wennebostel) L.csv
#     Moondrop Alice (EQ Wennebostel) R.csv
#     Moondrop Alice L.csv
#     Moondrop Alice R.csv
#
# IEM: moondrop solis
#
#   Reviewer: data_mrs
#     Moondrop Solis L.csv
#     Moondrop Solis R.csv
#
# IEM: moondrop solis s2
#
#   Reviewer: data_mrs
#     Moondrop Solis S2 L.csv
#     Moondrop Solis S2 R.csv
#
# IEM: moondrop the droplet
#
#   Reviewer: data_mrs
#     Moondrop The Droplet L.csv
#     Moondrop The Droplet R.csv
#
# IEM: nothing ear 2
#
#   Reviewer: data_mrs
#     Nothing Ear 2 (balanced) L.csv
#     Nothing Ear 2 (balanced) R.csv
#     Nothing Ear 2 (more bass) L.csv
#     Nothing Ear 2 (more bass) R.csv
#     Nothing Ear 2 (more treble) L.csv
#     Nothing Ear 2 (more treble) R.csv
#     Nothing Ear 2 (personalized B) L.csv
#     Nothing Ear 2 (personalized B) R.csv
#     Nothing Ear 2 (personalized) L.csv
#     Nothing Ear 2 (personalized) R.csv
#     Nothing Ear 2 (treble -6) L.csv
#     Nothing Ear 2 (treble -6) R.csv
#     Nothing Ear 2 (voice) L.csv
#     Nothing Ear 2 (voice) R.csv
#     Nothing Ear 2 L.csv
#     Nothing Ear 2 R.csv
#
# IEM: openaudio mercury
#
#   Reviewer: data_mrs
#     OpenAudio Mercury L.csv
#     OpenAudio Mercury R.csv
#
# IEM: oriolus 2nd gen
#
#   Reviewer: data_mrs
#     Oriolus 2nd Gen L.csv
#
# IEM: philips she3590pk
#
#   Reviewer: data_mrs
#     Philips SHE3590PK L.csv
#
# IEM: phonak audeo pfe 112
#
#   Reviewer: data_mrs
#     Phonak Audeo PFE 112 L.csv
#     Phonak Audeo PFE 112 R.csv
#
# IEM: pre-prod 03
#
#   Reviewer: data_mrs
#     Pre-Prod 03 (nozzle A) L.csv
#     Pre-Prod 03 (nozzle A) R.csv
#     Pre-Prod 03 (nozzle B) L.csv
#     Pre-Prod 03 (nozzle B) R.csv
#
# IEM: prisma audio azul
#
#   Reviewer: data_mrs
#     Prisma Audio Azul (E-type) L.csv
#     Prisma Audio Azul (S2) L.csv
#     Prisma Audio Azul (S2) R.csv
#     Prisma Audio Azul (Sedna) L.csv
#     Prisma Audio Azul (SpinFit) L.csv
#     Prisma Audio Azul (Spiral Dot) L.csv
#     Prisma Audio Azul L.csv
#
# IEM: qdc anole v14
#
#   Reviewer: data_mrs
#     QDC Anole V14 (0000) L.csv
#     QDC Anole V14 (0001) L.csv
#     QDC Anole V14 (0010) L.csv
#     QDC Anole V14 (0100) L.csv
#     QDC Anole V14 (1000) L.csv
#
# IEM: qdc neptune
#
#   Reviewer: data_mrs
#     QDC Neptune L.csv
#
# IEM: qdc uranus
#
#   Reviewer: data_mrs
#     QDC Uranus L.csv
#
# IEM: radius hp-nef11
#
#   Reviewer: data_mrs
#     Radius HP-NEF11 L.csv
#     Radius HP-NEF11 R.csv
#
# IEM: samsung earphones
#
#   Reviewer: data_mrs
#     Samsung Earphones (2019) L.csv
#     Samsung Earphones L.csv
#
# IEM: samsung galaxy buds2 pro
#
#   Reviewer: data_mrs
#     Samsung Galaxy Buds2 Pro (ANC off) L.csv
#     Samsung Galaxy Buds2 Pro (ANC off) R.csv
#     Samsung Galaxy Buds2 Pro (bass boost) L.csv
#     Samsung Galaxy Buds2 Pro (bass boost) R.csv
#     Samsung Galaxy Buds2 Pro (clear) L.csv
#     Samsung Galaxy Buds2 Pro (clear) R.csv
#     Samsung Galaxy Buds2 Pro (dynamic) L.csv
#     Samsung Galaxy Buds2 Pro (dynamic) R.csv
#     Samsung Galaxy Buds2 Pro (normal) L.csv
#     Samsung Galaxy Buds2 Pro (normal) R.csv
#     Samsung Galaxy Buds2 Pro (soft) L.csv
#     Samsung Galaxy Buds2 Pro (soft) R.csv
#     Samsung Galaxy Buds2 Pro (treble boost) L.csv
#     Samsung Galaxy Buds2 Pro (treble boost) R.csv
#
# IEM: sennheiser ie 200
#
#   Reviewer: data_mrs
#     Sennheiser IE 200 (Azla Max) L.csv
#     Sennheiser IE 200 (Azla Max) R.csv
#     Sennheiser IE 200 (D1) L.csv
#     Sennheiser IE 200 (D1) R.csv
#     Sennheiser IE 200 (D2) L.csv
#     Sennheiser IE 200 (D2) R.csv
#     Sennheiser IE 200 (Spiral Dot) L.csv
#     Sennheiser IE 200 (Spiral Dot) R.csv
#     Sennheiser IE 200 (UC tips) L.csv
#     Sennheiser IE 200 (UC tips) R.csv
#
# IEM: sennheiser ie 300
#
#   Reviewer: data_mrs
#     Sennheiser IE 300 (AutoEQ) L.csv
#     Sennheiser IE 300 (Final E) L.csv
#     Sennheiser IE 300 (Sedna Light) L.csv
#     Sennheiser IE 300 L.csv
#
# IEM: sennheiser ie 40 pro
#
#   Reviewer: data_mrs
#     Sennheiser IE 40 Pro L.csv
#
# IEM: sennheiser ie 600
#
#   Reviewer: data_mrs
#     Sennheiser IE 600 (E-type shallow) L.csv
#     Sennheiser IE 600 (E-type shallow) R.csv
#     Sennheiser IE 600 (E-type) L.csv
#     Sennheiser IE 600 (E-type) R.csv
#     Sennheiser IE 600 (foam) L.csv
#     Sennheiser IE 600 (foam) R.csv
#     Sennheiser IE 600 (Sedna) L.csv
#     Sennheiser IE 600 (Sedna) R.csv
#     Sennheiser IE 600 (Spinfit) L.csv
#     Sennheiser IE 600 (Spinfit) R.csv
#     Sennheiser IE 600 (Spring tips) L.csv
#     Sennheiser IE 600 (Spring tips) R.csv
#     Sennheiser IE 600 L.csv
#     Sennheiser IE 600 R.csv
#
# IEM: sennheiser ie 900
#
#   Reviewer: data_mrs
#     Sennheiser IE 900 (fake) L.csv
#     Sennheiser IE 900 (fake) R.csv
#     Sennheiser IE 900 (Final) L.csv
#     Sennheiser IE 900 (Final) R.csv
#     Sennheiser IE 900 L.csv
#     Sennheiser IE 900 R.csv
#
# IEM: sennheiser momentum tw3
#
#   Reviewer: data_mrs
#     Sennheiser Momentum TW3 L.csv
#     Sennheiser Momentum TW3 R.csv
#
# IEM: sennheiser mtw2
#
#   Reviewer: data_mrs
#     Sennheiser MTW2 (HE) L.csv
#     Sennheiser MTW2 L.csv
#
# IEM: shanling me700 lite
#
#   Reviewer: data_mrs
#     Shanling ME700 Lite L.csv
#
# IEM: shozy cp
#
#   Reviewer: data_mrs
#     Shozy CP L.csv
#
# IEM: shozy rouge
#
#   Reviewer: data_mrs
#     Shozy Rouge L.csv
#
# IEM: simgot en700 pro
#
#   Reviewer: data_mrs
#     Simgot EN700 Pro (Moondrop) L.csv
#     Simgot EN700 Pro (Tanchjim) L.csv
#     Simgot EN700 Pro L.csv
#
# IEM: softears studio4
#
#   Reviewer: data_mrs
#     Softears Studio4 L.csv
#     Softears Studio4 R.csv
#
# IEM: sony ier-nw510n
#
#   Reviewer: data_mrs
#     Sony IER-NW510N L.csv
#
# IEM: sony mdr-as800
#
#   Reviewer: data_mrs
#     Sony MDR-AS800 L.csv
#     Sony MDR-AS800 R.csv
#
# IEM: sony mh1
#
#   Reviewer: data_mrs
#     Sony MH1 L.csv
#     Sony MH1 R.csv
#
# IEM: sony mh755 clone
#
#   Reviewer: data_mrs
#     Sony MH755 clone L.csv
#
# IEM: sony wf-1000xm4
#
#   Reviewer: data_mrs
#     Sony WF-1000XM4 (ambient on) L.csv
#     Sony WF-1000XM4 (ANC off) L.csv
#     Sony WF-1000XM4 (ANC on) L.csv
#     Sony WF-1000XM4 (EQ - bass boost) L.csv
#     Sony WF-1000XM4 (EQ - bright) L.csv
#     Sony WF-1000XM4 (EQ - custom) L.csv
#     Sony WF-1000XM4 (EQ - excited) L.csv
#     Sony WF-1000XM4 (EQ - mellow) L.csv
#     Sony WF-1000XM4 (EQ - relaxed) L.csv
#     Sony WF-1000XM4 (EQ - speech) L.csv
#     Sony WF-1000XM4 (EQ - treble boost) L.csv
#     Sony WF-1000XM4 (EQ - vocal) L.csv
#     Sony WF-1000XM4 (Final E-type) L.csv
#     Sony WF-1000XM4 (fw 1.1.15) L.csv
#     Sony WF-1000XM4 (max - ambient on) L.csv
#     Sony WF-1000XM4 (max - ANC off) L.csv
#     Sony WF-1000XM4 (max - ANC on) L.csv
#     Sony WF-1000XM4 (max - EQ - bass boost) L.csv
#     Sony WF-1000XM4 (max - EQ - bright) L.csv
#     Sony WF-1000XM4 (max - EQ - excited) L.csv
#     Sony WF-1000XM4 (max - EQ - mellow) L.csv
#     Sony WF-1000XM4 (max - EQ - relaxed) L.csv
#     Sony WF-1000XM4 (max - EQ - speech) L.csv
#     Sony WF-1000XM4 (max - EQ - treble boost) L.csv
#     Sony WF-1000XM4 (max - EQ - vocal) L.csv
#     Sony WF-1000XM4 (max - Final E-type) L.csv
#     Sony WF-1000XM4 (max - fw 1.1.15) L.csv
#     Sony WF-1000XM4 (max - fw 1.2.6) L.csv
#     Sony WF-1000XM4 (max - MRS config) L.csv
#     Sony WF-1000XM4 (max - Sedna Light Short) L.csv
#     Sony WF-1000XM4 (max - SpinFit) L.csv
#     Sony WF-1000XM4 (max - Tanchjim APB) L.csv
#     Sony WF-1000XM4 (max - XM3 silicone) L.csv
#     Sony WF-1000XM4 (MRS config) L.csv
#     Sony WF-1000XM4 (Sedna Light Short) L.csv
#     Sony WF-1000XM4 (SpinFit) L.csv
#     Sony WF-1000XM4 (Tanchjim APB) L.csv
#     Sony WF-1000XM4 (XM3 silicone) L.csv
#     Sony WF-1000XM4 L.csv
#
# IEM: status audio iem-2x
#
#   Reviewer: data_mrs
#     Status Audio IEM-2X L.csv
#
# IEM: tanchjim darling
#
#   Reviewer: data_mrs
#     Tanchjim Darling (depth 1) L.csv
#     Tanchjim Darling (depth 2) L.csv
#
# IEM: tangzu wu heyday
#
#   Reviewer: data_mrs
#     Tangzu Wu Heyday L.csv
#     Tangzu Wu Heyday R.csv
#
# IEM: tansio mirai spark
#
#   Reviewer: data_mrs
#     Tansio Mirai Spark (010) L.csv
#     Tansio Mirai Spark (110) L.csv
#     Tansio Mirai Spark (111) L.csv
#
# IEM: tenhz 3ba
#
#   Reviewer: data_mrs
#     Tenhz 3BA L.csv
#
# IEM: tenhz p4 pro
#
#   Reviewer: data_mrs
#     Tenhz P4 Pro L.csv
#
# IEM: tfz t2 galaxy
#
#   Reviewer: data_mrs
#     TFZ T2 Galaxy L.csv
#
# IEM: thieaudio legacy 4
#
#   Reviewer: data_mrs
#     ThieAudio Legacy 4 (Spring) L.csv
#     ThieAudio Legacy 4 (Spring) R.csv
#     ThieAudio Legacy 4 (switch on) L.csv
#     ThieAudio Legacy 4 L.csv
#     ThieAudio Legacy 4 R.csv
#
# IEM: thinksound rain3
#
#   Reviewer: data_mrs
#     Thinksound Rain3 L.csv
#     Thinksound Rain3 R.csv
#
# IEM: tin hifi c2 mech warrior
#
#   Reviewer: data_mrs
#     Tin Hifi C2 Mech Warrior L.csv
#     Tin Hifi C2 Mech Warrior R.csv
#
# IEM: tin hifi c5
#
#   Reviewer: data_mrs
#     Tin Hifi C5 L.csv
#     Tin Hifi C5 R.csv
#
# IEM: tin hifi t2 evo
#
#   Reviewer: data_mrs
#     Tin Hifi T2 Evo L.csv
#     Tin Hifi T2 Evo R.csv
#
# IEM: tin hifi t2
#
#   Reviewer: data_mrs
#     Tin Hifi T2 L.csv
#
# IEM: tin hifi t2 pro
#
#   Reviewer: data_mrs
#     Tin Hifi T2 Pro (Comply) L.csv
#     Tin Hifi T2 Pro (white grill + Comply) L.csv
#     Tin Hifi T2 Pro L.csv
#
# IEM: tin hifi t5
#
#   Reviewer: data_mrs
#     Tin Hifi T5 (Comply Waxguard) L.csv
#     Tin Hifi T5 L.csv
#
# IEM: trn im1
#
#   Reviewer: data_mrs
#     TRN IM1 L.csv
#
# IEM: trn v30
#
#   Reviewer: data_mrs
#     TRN V30 L.csv
#
# IEM: ucotech re-2
#
#   Reviewer: data_mrs
#     Ucotech RE-2 L.csv
#     Ucotech RE-2 R.csv
#
# IEM: vision ears ve7
#
#   Reviewer: data_mrs
#     Vision Ears VE7 L.csv
#     Vision Ears VE7 R.csv
#
# IEM: vsonic gr07
#
#   Reviewer: data_mrs
#     Vsonic GR07 (Bass) L.csv
#     Vsonic GR07 L.csv
#     Vsonic GR07 R.csv
#
# IEM: vsonic vs7
#
#   Reviewer: data_mrs
#     Vsonic VS7 L.csv
#
# IEM: whizzer kylin
#
#   Reviewer: data_mrs
#     Whizzer Kylin L.csv
#
# IEM: yinfu md51
#
#   Reviewer: data_mrs
#     Yinfu MD51 L.csv

# %%
import os
import re
from collections import defaultdict

def clean_iem_name(name):
    name = re.sub(r'\(.*?\)|\d+ohm|L|R|Springtips|CP100\+|Manufacturer|Measurment|Broken|[\._]', '', name, flags=re.IGNORECASE)
    name = name.strip().lower()
    return name

def get_reviewer_files(reviewer):
    path = f'output/csv/{reviewer}'
    return [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

def main():
    reviewers = [
        'achoreviews', 'aftersound', 'animagus', 'arn', 'bedrock', 'bryaudioreviews', 'cammyfi', 'soundjedi', 'eplv',
        'timmyv', 'harpo', 'hbb', 'cqtek', 'hobbytalk', 'ianfann', 'iemworld', 'jacstone', 'kr0mka', 'kurin',
        'melatonin', 'nymz', 'pw', 'recode', 'rg', 'shortbus', 'suporsalad', 'tgx78', 'vortexreviews', 'vsg', 'wdym',
        'akros', 'data_mrs'
    ]

    iem_groups = defaultdict(lambda: defaultdict(list))

    for reviewer in reviewers:
        files = get_reviewer_files(reviewer)
        for file in files:
            if "target" in file.lower():
                iem_groups["target"][reviewer].append(file)
            else:
                iem_name = clean_iem_name(file)
                iem_groups[iem_name][reviewer].append(file)

    for iem, reviewers_files in iem_groups.items():
        print(f"{iem}:")
        for reviewer, files in reviewers_files.items():
            print(f"  {reviewer}: {files}")
        print()

if __name__ == "__main__":
    main()
# Out:
# 7hz dioko csv:
#   achoreviews: ['7Hz Dioko L.csv']
#   bedrock: ['7Hz Dioko L.csv', '7Hz Dioko R.csv']
#   timmyv: ['7Hz Dioko L.csv', '7Hz Dioko R.csv']
#   hbb: ['7Hz Dioko R.csv']
#   hobbytalk: ['7hz Dioko L.csv', '7hz Dioko R.csv']
#   ianfann: ['7HZ DIOKO L.csv', '7HZ DIOKO R.csv']
#   iemworld: ['7Hz Dioko L.csv', '7Hz Dioko R.csv']
#   data_mrs: ['7Hz Dioko L.csv', '7Hz Dioko R.csv']
#
# 7hz etena csv:
#   achoreviews: ['7Hz Eternal L.csv']
#   bedrock: ['7Hz Eternal L.csv', '7Hz Eternal R.csv']
#   harpo: ['7Hz Eternal R.csv']
#   hbb: ['7Hz Eternal R.csv']
#   iemworld: ['7Hz ETERNAL L.csv', '7Hz ETERNAL R.csv']
#   vortexreviews: ['7hz Eternal L.csv', '7hz Eternal R.csv']
#   vsg: ['7Hz Eternal L.csv', '7Hz Eternal R.csv']
#
# 7hz egato csv:
#   achoreviews: ['7Hz Legato L.csv']
#   aftersound: ['7HZ LEGATO L.csv', '7HZ LEGATO R.csv']
#   timmyv: ['7Hz Legato L.csv', '7Hz Legato R.csv']
#   hbb: ['7Hz Legato R.csv']
#   cqtek: ['7Hz Legato L.csv', '7Hz Legato R.csv']
#   ianfann: ['7HZ LEGATO L.csv', '7HZ LEGATO R.csv']
#   nymz: ['7hz LEGATO L.csv', '7hz LEGATO R.csv']
#   rg: ['7hz Legato L.csv', '7hz Legato R.csv']
#   vortexreviews: ['7hz Legato L.csv', '7hz Legato R.csv']
#   vsg: ['7Hz Legato L.csv', '7Hz Legato R.csv']
#
# 7hz timeess csv:
#   achoreviews: ['7Hz Timeless L.csv']
#   aftersound: ['7HZ TIMELESS L.csv', '7HZ TIMELESS R.csv']
#   arn: ['7Hz Timeless L.csv']
#   soundjedi: ['7Hz Timeless L.csv', '7Hz Timeless R.csv']
#   timmyv: ['7Hz Timeless L.csv', '7Hz Timeless R.csv']
#   harpo: ['7Hz Timeless R.csv']
#   hobbytalk: ['7hz Timeless L.csv', '7hz Timeless R.csv']
#   pw: ['7Hz Timeless L.csv', '7Hz Timeless R.csv']
#   rg: ['7Hz Timeless L.csv', '7Hz Timeless R.csv']
#   tgx78: ['7hz Timeless L.csv', '7hz Timeless R.csv']
#   vortexreviews: ['7hz Timeless L.csv', '7hz Timeless R.csv']
#   vsg: ['7Hz Timeless L.csv', '7Hz Timeless R.csv']
#   data_mrs: ['7Hz Timeless L.csv', '7Hz Timeless R.csv']
#
# 7hz zeo csv:
#   achoreviews: ['7Hz Zero L.csv']
#   bedrock: ['7Hz Zero L.csv', '7Hz Zero R.csv']
#   timmyv: ['7Hz Zero L.csv', '7Hz Zero R.csv']
#   hbb: ['7hz Zero R.csv']
#   hobbytalk: ['7hz Zero L.csv', '7hz Zero R.csv']
#   ianfann: ['7HZ ZERO L.csv', '7HZ ZERO R.csv']
#   data_mrs: ['7Hz Zero L.csv', '7Hz Zero R.csv']
#
# target:
#   achoreviews: ['Acho Reviews Target.csv', 'Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   aftersound: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'IEF neutral Target.csv', 'Innerfidelity ID Target.csv', 'Innerfidelity Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   animagus: ['Animagus Neutral Target.csv', 'Animagus Preference Target.csv', 'Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman In Ear 2019 Target.csv', 'Harman In Room Target.csv', 'Harman Over Ear 2018 Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   arn: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Harman V2 Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   bedrock: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   bryaudioreviews: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Bry Audio Reviews Target.csv', 'Crinacle IEF-Neutral Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman 2017 Target.csv', 'Harman 2019 Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Oratory1990 Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   cammyfi: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'CammyFi Neutral Target.csv', 'CammyFi Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman IE 2019 v2 Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Kurin Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   soundjedi: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   eplv: ['Antdroid Target.csv', 'AutoEQ Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Harman2019v2 Target.csv', 'IEF Neutral Target.csv', 'Innerfidelity ID Target.csv', 'Old Crinacle Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   timmyv: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'IEF Neutral Target.csv', 'Innerfidelity ID Target.csv', 'Nymz Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv', 'Timmy Target.csv']
#   harpo: ['Antdroid Target.csv', 'AX Target.csv', 'Bad Guy 2022 Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'EJ Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Harpo Target.csv', 'Harpo v3 Target.csv', 'Harpo v4 Target (11.03.2023 02-43-36).csv', 'Harpo v4 Target.csv', 'Harpo_v2 Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'RikudouGoku Target.csv', 'Rtings Target.csv', 'Softears Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv', 'X Target.csv']
#   hbb: ['Antdroid Target.csv', 'Bad Guy 2022 Target.csv', 'Bad Guy Target v2.csv', 'Bad Guy Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'IEF Target.csv', 'MRS Target.csv', 'Precog Target.csv', 'Precog_broken Target.csv', 'Redeyes Target.csv', 'RikudouGoku Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv']
#   cqtek: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   hobbytalk: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman IE 2019 Target.csv', 'Harman Target.csv', 'Hobby Talk Flat Target.csv', 'Hobby Talk Preference Target OG.csv', 'Hobby Talk Preference Target.csv', 'Honest Target.csv', 'IEF Neutral Target.csv', 'IEF OE Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   ianfann: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman 2017 Target.csv', 'Harman 2019 Target.csv', 'IanFann-Target Target.csv', 'IEF Neutral 2023 Target.csv', 'IEF Target.csv', 'IEF Target1.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   iemworld: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'IEM WORLD Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   jacstone: ['Harman 2019 Target.csv', 'IEF Neutral Target.csv', 'nymz Target.csv', 'Paul Wasabii Target.csv', 'RikudouGoku Target.csv', 'Sharur Target.csv']
#   kr0mka: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman IE 2016 Target.csv', 'Harman IE 2017 v2 Target.csv', 'Harman IE 2019 v2 Target.csv', 'Innerfidelity ID Target.csv', 'kr0mka Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   kurin: ['Antdroid Target.csv', 'Bad Guy 2022 Target.csv', 'Banbeucmas Target.csv', 'CammyFi Target.csv', 'Coda Target.csv', 'Comfy Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Flat Target.csv', 'Freeryder05v2 Target.csv', 'Harman IE 2016 Target.csv', 'Harman IE 2019 v2 Target.csv', 'Hobby Talk Preference Target.csv', 'Hobby Talk Target.csv', 'Kurin Target.csv', 'markanini Target.csv', 'Moondrop Target.csv', 'Normative Target.csv', 'Objectively Neutral IE Target.csv', 'Olive-Welti Harman Bass Target.csv', 'Olive-Welti Target.csv', 'Oratory IE Target.csv', 'Precog Target.csv', 'Redeyes Target.csv', 'Rikudogoku Target.csv', 'RikudouGoku Target.csv', 'Rtings Target.csv', 'SEAP Target.csv', 'Sharur Target.csv', 'Srg0mes Target.csv', 'Super 22 Target.csv', 'Timmy Target.csv']
#   melatonin: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   nymz: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman 2019v2 Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'nymz Target.csv', 'Precogvision Target.csv', 'RikudouGoku Target.csv', 'RikudouGoku_Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv', 'tgx78 Target.csv']
#   pw: ['Antdroid Target.csv', 'AutoEQ Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crackhead Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman 2019v2 Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Oratory1990 Target.csv', 'PaulWasabii Target.csv', 'Precogvision Target.csv', 'Redeyes Target.csv', 'RikudouGoku Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   recode: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Neutral Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman 2017v2 Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Recode Neutral Target.csv', 'Recode Target.csv', 'Recode Warm Neutral Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv', 'target 8.csv']
#   rg: ['ALPHA 1.0 Target.csv', 'Amelie Target.csv', 'Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crackhead Target.csv', 'Diffuse Field Target.csv', 'DynamicEars Target.csv', 'Etymotic Target.csv', 'evasb Target.csv', 'Free Field Target.csv', 'Harman 2017v2 Target.csv', 'Harman 2019v2 Target.csv', 'Harpo Target.csv', 'IEF Neutral 2020 Target.csv', 'IEF Neutral 2023 Target.csv', 'Innerfidelity ID Target.csv', 'Lixeem Target.csv', 'nymz Target.csv', 'Precogvision Target.csv', 'PW Target.csv', 'Resolution Target.csv', 'RikudouGoku Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'stakk Target.csv', 'Super Bass Target.csv', 'Super Review 2021 Target.csv', 'Super Review 2022 Target.csv', 'Talbot Target.csv', 'tgx78 Target.csv', 'TKSilver Target.csv']
#   shortbus: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Redeyes 1 Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   suporsalad: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'DF Tilt 711 Ref Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman IEM Target.csv', 'Harman OE Target.csv', 'Harman Target.csv', 'IEF Neutral 2020 Target.csv', 'IEF Neutral 2023 Target.csv', 'Innerfidelity ID Target.csv', 'Kemar DF 1.3 Bass Target.csv', 'Kemar DF 1.3 Target.csv', 'Kemar DF Target.csv', 'Listener Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv', 'USound1V1 Oratory 1990 Target.csv']
#   tgx78: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'RikudouGoku Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv', 'Tgx78 Target.csv']
#   vortexreviews: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Oratory1990 Target.csv', 'Precogvision Target.csv', 'RikudouGoku Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   vsg: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman 2018 Over-Ear Target.csv', 'Harman 2019 In-Ear Target.csv', 'Harman Combined Over-Ear Target.csv', 'Harman In-Ear Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv', 'VSG Target.csv']
#   wdym: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv', 'Wdym Target.csv']
#   akros: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Free Field Target.csv', 'Harman Target.csv', 'Innerfidelity ID Target.csv', 'Precogvision Target.csv', 'Rtings Target.csv', 'Sonarworks Target.csv', 'Super Review Target.csv']
#   data_mrs: ['Antdroid Target.csv', 'Bad Guy Target.csv', 'Banbeucmas Target.csv', 'Crinacle 2023 Adjusted Target.csv', 'Crinacle Adjusted Target.csv', 'Crinacle Neutral 2023 Target.csv', 'Crinacle Neutral Target.csv', 'Crinacle Target.csv', 'Dent Target.csv', 'dentReviews Target.csv', 'Diffuse Field Target.csv', 'Etymotic Target.csv', 'Ghost Target.csv', 'Harman Adjusted Target.csv', 'Harman Target.csv', 'HBB Comp Target.csv', 'HPDC 10dB Tilt 5128 DF 100Hz Target.csv', 'HPDC 10dB Tilt 5128 DF Target.csv', 'HPDC 10dB Tilt KEMAR DF 100Hz Target.csv', 'HPDC 10dB Tilt KEMAR DF Target.csv', 'HPDC 14dB Tilt 5128 DF 100Hz Target.csv', 'HPDC 14dB Tilt 5128 DF Target.csv', 'HPDC 14dB Tilt KEMAR DF 100Hz Target.csv', 'HPDC 14dB Tilt KEMAR DF Target.csv', 'IEC711 Comp Target.csv', 'IEF Comp Target.csv', 'Moondrop Alice (EQ In-Ear Target) L.csv', 'Moondrop Alice (EQ In-Ear Target) R.csv', 'Moondrop Blessing 2 Target.csv', 'Precogvision Target.csv', 'RikudouGoku Target.csv', 'Super 21 Target.csv', 'Super 22 Target.csv', 'Super Bass Target.csv', 'Super Review Target.csv', 'Working 001 Target.csv', 'Working 002 Target.csv']
#
# audeze isine x  csv:
#   achoreviews: ['Audeze iSine LX (Spinfit) L.csv']
#
# aune jaspe csv:
#   achoreviews: ['Aune Jasper L.csv']
#   aftersound: ['AUNE JASPER L.csv', 'AUNE JASPER R.csv']
#   hbb: ['Aune Jasper R.csv']
#   data_mrs: ['Aune Jasper L.csv', 'Aune Jasper R.csv']
#
# bon b01 csv:
#   achoreviews: ['Blon BL01 L.csv']
#   bryaudioreviews: ['BLON BL01 L.csv', 'BLON BL01 R.csv']
#   pw: ['BLON BL01 L.csv']
#
# bon b03 csv:
#   achoreviews: ['Blon BL03 L.csv']
#   aftersound: ['BLON BL03 R.csv']
#   bryaudioreviews: ['BLON BL03 L.csv', 'BLON BL03 R.csv']
#   timmyv: ['Blon BL03 L.csv', 'Blon BL03 R.csv']
#   ianfann: ['BLON BL03 L.csv', 'BLON BL03 R.csv']
#   suporsalad: ['Blon BL03 L.csv', 'Blon BL03 R.csv']
#   data_mrs: ['Blon BL03 L.csv']
#
# bon b05s csv:
#   achoreviews: ['Blon BL05s L.csv']
#   pw: ['BLON BL05S L.csv']
#
# bon fat gi csv:
#   achoreviews: ['Blon Fat Girl L.csv']
#   aftersound: ['BLON FAT GIRL L.csv', 'BLON FAT GIRL R.csv']
#   hbb: ['BLON Fat Girl R.csv']
#   ianfann: ['BLON FAT GIRL L.csv', 'BLON FAT GIRL R.csv']
#   jacstone: ['BLON Fat Girl L.csv', 'BLON Fat Girl R.csv']
#   pw: ['BLON Fat Girl L.csv', 'BLON Fat Girl R.csv']
#   vortexreviews: ['Blon Fat Girl L.csv', 'Blon Fat Girl R.csv']
#
# bon t1 csv:
#   achoreviews: ['Blon T1 L.csv']
#
# bon t3 csv:
#   achoreviews: ['Blon T3 L.csv']
#
# bon z200 csv:
#   achoreviews: ['Blon Z200 L.csv']
#   arn: ['BLON Z200 L.csv']
#   harpo: ['Blon Z200 L.csv', 'Blon Z200 R.csv']
#   ianfann: ['BLON Z200 L.csv', 'BLON Z200 R.csv']
#   pw: ['BLON Z200 L.csv', 'BLON Z200 R.csv']
#   vortexreviews: ['Blon Z200 L.csv', 'Blon Z200 R.csv']
#
# cca ca csv:
#   achoreviews: ['CCA CRA L.csv']
#   aftersound: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   eplv: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   harpo: ['CCA CRA R.csv']
#   hbb: ['CCA CRA R.csv']
#   hobbytalk: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   ianfann: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   jacstone: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   melatonin: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   nymz: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   pw: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   rg: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   suporsalad: ['CCA CRA L.csv', 'CCA CRA R.csv']
#   tgx78: ['CCA CRA L.csv']
#   vortexreviews: ['CCA CRA L.csv']
#   data_mrs: ['CCA CRA L.csv', 'CCA CRA R.csv']
#
# cca ca pus csv:
#   achoreviews: ['CCA CRA Plus L.csv']
#   timmyv: ['CCA CRA Plus L.csv', 'CCA CRA Plus R.csv']
#   pw: ['CCA CRA Plus L.csv']
#   data_mrs: ['CCA CRA Plus L.csv', 'CCA CRA Plus R.csv']
#
# ccz emead csv:
#   achoreviews: ['CCZ Emerald L.csv']
#   aftersound: ['CCZ EMERALD L.csv', 'CCZ EMERALD R.csv']
#   eplv: ['CCZ Emerald L.csv', 'CCZ Emerald R.csv']
#   melatonin: ['CCZ emerald L.csv', 'CCZ emerald R.csv']
#
# ccz meody csv:
#   achoreviews: ['CCZ Melody L.csv']
#   aftersound: ['CCZ MELODY L.csv', 'CCZ MELODY R.csv']
#   harpo: ['CCZ Melody R.csv']
#   ianfann: ['CCZ MELODY L.csv', 'CCZ MELODY R.csv']
#   melatonin: ['CCZ melody L.csv', 'CCZ melody R.csv']
#   pw: ['CCZ Melody L.csv']
#   vortexreviews: ['CCZ Melody L.csv']
#
# ccz waio csv:
#   achoreviews: ['CCZ Warrior L.csv']
#   arn: ['CCZ Warrior L.csv']
#   ianfann: ['CCZ WARRIOR L.csv', 'CCZ WARRIOR R.csv']
#   pw: ['CCZ Warrior L.csv', 'CCZ Warrior R.csv']
#
# ceest pandamon csv:
#   achoreviews: ['Celest Pandamon L.csv']
#
# dunu kima csv:
#   achoreviews: ['Dunu Kima L.csv']
#   aftersound: ['DUNU KIMA L.csv', 'DUNU KIMA R.csv']
#   bedrock: ['Dunu Kima L.csv', 'Dunu Kima R.csv']
#   timmyv: ['Dunu Kima L.csv', 'Dunu Kima R.csv']
#   hbb: ['Dunu Kima R.csv']
#   cqtek: ['Dunu Kima L.csv', 'Dunu Kima R.csv']
#   ianfann: ['DUNU KIMA L.csv', 'DUNU KIMA R.csv']
#   nymz: ['DUNU KIMA L.csv', 'DUNU KIMA R.csv']
#   vortexreviews: ['Dunu Kima L.csv', 'Dunu Kima R.csv']
#   vsg: ['DUNU KIMA L.csv', 'DUNU KIMA R.csv']
#   data_mrs: ['Dunu Kima L.csv', 'Dunu Kima R.csv']
#
# dunu taos   csv:
#   achoreviews: ['Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv', 'Dunu Talos (Planar Only) (IE600 Foam Tips) L.csv']
#
# dunu taos  csv:
#   achoreviews: ['Dunu Talos (Planar + BA) L.csv', 'Dunu Talos (Planar Only) L.csv']
#   animagus: ['Dunu Talos (ON) L.csv', 'Dunu Talos (ON) R.csv']
#   bedrock: ['Dunu Talos (Switch Off) L.csv', 'Dunu Talos (Switch Off) R.csv', 'Dunu Talos (Switch On) L.csv', 'Dunu Talos (Switch On) R.csv']
#   timmyv: ['Dunu Talos (Hybrid) L.csv', 'Dunu Talos (Hybrid) R.csv', 'Dunu Talos (Planar) L.csv', 'Dunu Talos (Planar) R.csv']
#   data_mrs: ['Dunu Talos (on) L.csv', 'Dunu Talos (on) R.csv', 'Dunu Talos (S2 off) L.csv', 'Dunu Talos (S2 off) R.csv', 'Dunu Talos (S2 on) L.csv', 'Dunu Talos (S2 on) R.csv']
#
# dunu titan s  csv:
#   achoreviews: ['Dunu Titan S (Isolation) L.csv']
#   rg: ['Dunu Titan S (500 Mesh) L.csv', 'Dunu Titan S (Tanchjim Filter) L.csv', 'Dunu Titan S (Y3 Paper Filter) L.csv', 'Dunu Titan S (Y6 Paper Filter) L.csv']
#   data_mrs: ['Dunu Titan S (pre) L.csv', 'Dunu Titan S (pre) R.csv']
#
# dunu titan s csv:
#   achoreviews: ['Dunu Titan S L.csv']
#   aftersound: ['DUNU TITAN S L.csv', 'DUNU TITAN S R.csv']
#   arn: ['DUNU Titan S L.csv', 'DUNU Titan S R.csv']
#   bedrock: ['Dunu Titan S L.csv', 'Dunu Titan S R.csv']
#   bryaudioreviews: ['Dunu Titan S L.csv', 'Dunu Titan S R.csv']
#   timmyv: ['Dunu Titan S L.csv', 'Dunu Titan S R.csv']
#   hbb: ['Dunu Titan S R.csv']
#   cqtek: ['Dunu Titan S L.csv', 'Dunu Titan S R.csv']
#   ianfann: ['DUNU TITAN S L.csv', 'DUNU TITAN S R.csv']
#   iemworld: ['DUNU TITAN S L.csv', 'DUNU TITAN S R.csv']
#   nymz: ['Dunu Titan S L.csv', 'Dunu Titan S R.csv']
#   rg: ['Dunu Titan S L.csv', 'Dunu Titan S R.csv']
#   vortexreviews: ['Dunu Titan S L.csv']
#   vsg: ['DUNU TITAN S L.csv', 'DUNU TITAN S R.csv']
#
# dunu vukan csv:
#   achoreviews: ['Dunu Vulkan L.csv']
#   bedrock: ['Dunu Vulkan L.csv', 'Dunu Vulkan R.csv']
#   timmyv: ['Dunu Vulkan L.csv', 'Dunu Vulkan R.csv']
#   harpo: ['Dunu Vulkan L.csv', 'Dunu Vulkan R.csv']
#   hbb: ['Dunu Vulkan R.csv']
#   nymz: ['DUNU Vulkan L.csv', 'DUNU Vulkan R.csv']
#   rg: ['Dunu VULKAN L.csv', 'Dunu VULKAN R.csv']
#   vsg: ['DUNU VULKAN L.csv', 'DUNU VULKAN R.csv']
#   data_mrs: ['Dunu Vulkan L.csv', 'Dunu Vulkan R.csv']
#
# effect audio axiom csv:
#   achoreviews: ['Effect Audio Axiom L.csv']
#   vsg: ['Effect Audio Axiom L.csv', 'Effect Audio Axiom R.csv']
#   data_mrs: ['Effect Audio Axiom L.csv', 'Effect Audio Axiom R.csv']
#
# fiio fhe ecipse csv:
#   achoreviews: ['Fiio FHE Eclipse L.csv']
#
# fina audio e500 csv:
#   achoreviews: ['Final Audio E500 L.csv']
#   rg: ['Final Audio E500 L.csv', 'Final Audio E500 R.csv']
#
# hidition vioet csv:
#   achoreviews: ['Hidition Violet L.csv']
#   soundjedi: ['Hidition Violet L.csv', 'Hidition Violet R.csv']
#   cqtek: ['Hidition Violet L.csv']
#   data_mrs: ['Hidition Violet L.csv']
#
# hifiman e600s v2 csv:
#   achoreviews: ['Hifiman RE600s v2 L.csv']
#
# hifiman svana csv:
#   achoreviews: ['Hifiman Svanar L.csv']
#   vsg: ['HIFIMAN Svanar L.csv', 'HIFIMAN Svanar R.csv']
#
# hifiman tws800 csv:
#   achoreviews: ['Hifiman TWS800 L.csv']
#   ianfann: ['HIFIMAN TWS800 L.csv', 'HIFIMAN TWS800 R.csv']
#   vsg: ['HIFIMAN TWS800 L.csv', 'HIFIMAN TWS800 R.csv']
#
# hz sound heat mio po csv:
#   achoreviews: ['HZ Sound Heart Mirror Pro L.csv']
#   ianfann: ['HZ SOUND HEART MIRROR PRO L.csv', 'HZ SOUND HEART MIRROR PRO R.csv']
#
# ikko opa oh02 csv:
#   achoreviews: ['Ikko Opal OH02 L.csv']
#
# itk unknown csv:
#   achoreviews: ['ITK Unknown L.csv']
#
# joyodio shine  csv:
#   achoreviews: ['Joyodio Shine (0000) L.csv', 'Joyodio Shine (0010) L.csv', 'Joyodio Shine (0100) L.csv', 'Joyodio Shine (0110) L.csv', 'Joyodio Shine (1000) L.csv', 'Joyodio Shine (1010) L.csv', 'Joyodio Shine (1100) L.csv', 'Joyodio Shine (1110) L.csv']
#
# kbea ak  csv:
#   achoreviews: ['KBEAR Lark (S1) L.csv', 'KBEAR Lark (S2) L.csv']
#
# kbea itte q csv:
#   achoreviews: ['KBEAR Little Q L.csv']
#   arn: ['KBEAR Little Q L.csv']
#   bryaudioreviews: ['KBEar Little Q L.csv', 'KBEar Little Q R.csv']
#   ianfann: ['KBEAR LITTLE Q L.csv', 'KBEAR LITTLE Q R.csv']
#
# kbea qingong csv:
#   achoreviews: ['KBEAR Qinglong L.csv']
#   aftersound: ['KBEAR QINGLONG L.csv', 'KBEAR QINGLONG R.csv']
#   arn: ['KBEAR Qinglong L.csv', 'KBEAR Qinglong R.csv']
#   ianfann: ['KBEAR QINGLONG L.csv', 'KBEAR QINGLONG R.csv']
#
# kbea obin csv:
#   achoreviews: ['KBEAR Robin L.csv']
#   cqtek: ['KBEAR Robin L.csv', 'KBEAR Robin R.csv']
#   melatonin: ['KBEAR Robin L.csv', 'KBEAR Robin R.csv']
#   pw: ['KBEAR Robin L.csv']
#   rg: ['KBEAR Robin L.csv', 'KBEAR Robin R.csv']
#
# kinea bd005 po csv:
#   achoreviews: ['Kinera BD005 Pro L.csv']
#   aftersound: ['KINERA BD005 PRO R.csv']
#   bedrock: ['Kinera BD005 Pro L.csv', 'Kinera BD005 Pro R.csv']
#
# kiwi eas cadenza csv:
#   achoreviews: ['Kiwi Ears Cadenza L.csv']
#   aftersound: ['KIWI EARS CADENZA L.csv', 'KIWI EARS CADENZA R.csv']
#   arn: ['Kiwi Ears CADENZA L.csv', 'Kiwi Ears CADENZA R.csv']
#   bedrock: ['Kiwi Ears Cadenza L.csv', 'Kiwi Ears Cadenza R.csv']
#   cammyfi: ['Kiwi Ears Cadenza L.csv', 'Kiwi Ears Cadenza R.csv']
#   harpo: ['Kiwi Ears Cadenza R.csv']
#   hbb: ['Kiwi Ears Cadenza R.csv']
#   hobbytalk: ['Kiwi Ears Cadenza L.csv', 'Kiwi Ears Cadenza R.csv']
#   vortexreviews: ['Kiwi Ears Cadenza L.csv', 'Kiwi Ears Cadenza R.csv']
#   data_mrs: ['Kiwi Ears Cadenza L.csv', 'Kiwi Ears Cadenza R.csv']
#
# kiwi eas ochesta ite csv:
#   achoreviews: ['Kiwi Ears Orchestra Lite L.csv']
#   bedrock: ['Kiwi Ears Orchestra Lite L.csv', 'Kiwi Ears Orchestra Lite R.csv']
#   nymz: ['Kiwi Ears Orchestra Lite L.csv', 'Kiwi Ears Orchestra Lite R.csv']
#   pw: ['Kiwi Ears Orchestra Lite L.csv', 'Kiwi Ears Orchestra Lite R.csv']
#   rg: ['Kiwi Ears Orchestra Lite L.csv', 'Kiwi Ears Orchestra Lite R.csv']
#   vortexreviews: ['Kiwi Ears Orchestra Lite L.csv', 'Kiwi Ears Orchestra Lite R.csv']
#   vsg: ['Kiwi Ears Orchestra Lite L.csv', 'Kiwi Ears Orchestra Lite R.csv']
#   data_mrs: ['Kiwi Ears Orchestra Lite L.csv', 'Kiwi Ears Orchestra Lite R.csv']
#
# koss keb90 csv:
#   achoreviews: ['Koss KEB90 L.csv']
#   hobbytalk: ['KOSS KEB90 L.csv', 'KOSS KEB90 R.csv']
#   data_mrs: ['Koss KEB90 L.csv', 'Koss KEB90 R.csv']
#
# kz as16 po csv:
#   achoreviews: ['KZ AS16 Pro L.csv']
#   aftersound: ['KZ AS16 PRO L.csv', 'KZ AS16 PRO R.csv']
#   hbb: ['KZ AS16 Pro R.csv']
#   ianfann: ['KZ AS16 PRO L.csv', 'KZ AS16 PRO R.csv']
#   melatonin: ['KZ AS16 Pro L.csv', 'KZ AS16 Pro R.csv']
#   pw: ['KZ AS16 Pro L.csv', 'KZ AS16 Pro R.csv']
#   vortexreviews: ['KZ AS16 Pro L.csv', 'KZ AS16 Pro R.csv']
#
# kz ate csv:
#   achoreviews: ['KZ ATE L.csv']
#   data_mrs: ['KZ ATE L.csv', 'KZ ATE R.csv']
#
# kz dq6 csv:
#   achoreviews: ['KZ DQ6 L.csv']
#   aftersound: ['KZ DQ6 R.csv']
#   eplv: ['KZ DQ6 L.csv', 'KZ DQ6 R.csv']
#   hbb: ['KZ DQ6 R.csv']
#   ianfann: ['KZ DQ6 L.csv', 'KZ DQ6 R.csv']
#   jacstone: ['KZ DQ6 L.csv', 'KZ DQ6 R.csv']
#   melatonin: ['KZ DQ6 L.csv', 'KZ DQ6 R.csv']
#   nymz: ['KZ DQ6 L.csv', 'KZ DQ6 R.csv']
#   pw: ['KZ DQ6 L.csv']
#   rg: ['KZ DQ6 L.csv']
#   vortexreviews: ['KZ DQ6 R.csv']
#   data_mrs: ['KZ DQ6 L.csv', 'KZ DQ6 R.csv']
#
# kz dq6s csv:
#   achoreviews: ['KZ DQ6s L.csv']
#   aftersound: ['KZ DQ6S L.csv', 'KZ DQ6S R.csv']
#   bedrock: ['KZ DQ6S L.csv', 'KZ DQ6S R.csv']
#   harpo: ['KZ DQ6S R.csv']
#   ianfann: ['KZ DQ6S L.csv', 'KZ DQ6S R.csv']
#   jacstone: ['KZ DQ6S L.csv', 'KZ DQ6S R.csv']
#   melatonin: ['KZ DQ6s L.csv', 'KZ DQ6s R.csv']
#   nymz: ['KZ DQ6s L.csv', 'KZ DQ6s R.csv']
#   pw: ['KZ DQ6S L.csv', 'KZ DQ6S R.csv']
#   rg: ['KZ DQ6S L.csv', 'KZ DQ6S R.csv']
#
# kz dqs csv:
#   achoreviews: ['KZ DQS L.csv']
#   ianfann: ['KZ DQS L.csv', 'KZ DQS R.csv']
#   pw: ['KZ DQS L.csv', 'KZ DQS R.csv']
#   vortexreviews: ['KZ DQS R.csv']
#
# kz ed16 csv:
#   achoreviews: ['KZ ED16 L.csv']
#
# kz edx csv:
#   achoreviews: ['KZ EDX L.csv']
#   aftersound: ['KZ EDX R.csv']
#   eplv: ['KZ EDX L.csv', 'KZ EDX R.csv']
#   jacstone: ['KZ EDX L.csv', 'KZ EDX R.csv']
#   melatonin: ['KZ EDX L.csv', 'KZ EDX R.csv']
#   pw: ['KZ EDX L.csv']
#   vortexreviews: ['KZ EDX L.csv', 'KZ EDX R.csv']
#
# kz edx po csv:
#   achoreviews: ['KZ EDX Pro L.csv']
#   aftersound: ['KZ EDX PRO L.csv', 'KZ EDX PRO R.csv']
#   hbb: ['KZ EDX PRO R.csv']
#   jacstone: ['KZ EDX PRO L.csv', 'KZ EDX PRO R.csv']
#   melatonin: ['KZ EDX Pro L.csv', 'KZ EDX Pro R.csv']
#   pw: ['KZ EDX Pro L.csv', 'KZ EDX Pro R.csv']
#   rg: ['KZ EDX Pro L.csv', 'KZ EDX Pro R.csv']
#   vortexreviews: ['KZ EDX Pro L.csv']
#   data_mrs: ['KZ EDX Pro L.csv', 'KZ EDX Pro R.csv']
#
# kz p1 csv:
#   achoreviews: ['KZ PR1 L.csv']
#   timmyv: ['KZ PR1 L.csv', 'KZ PR1 R.csv']
#   hbb: ['KZ PR1 R.csv']
#   ianfann: ['KZ PR1 L.csv', 'KZ PR1 R.csv']
#
# kz zax csv:
#   achoreviews: ['KZ ZAX L.csv']
#   hbb: ['KZ ZAX R.csv']
#   melatonin: ['KZ ZAX L.csv', 'KZ ZAX R.csv']
#   pw: ['KZ ZAX L.csv']
#   vortexreviews: ['KZ ZAX L.csv']
#
# kz zes csv:
#   achoreviews: ['KZ ZES L.csv']
#   aftersound: ['KZ ZES L.csv', 'KZ ZES R.csv']
#   ianfann: ['KZ ZES L.csv', 'KZ ZES R.csv']
#   pw: ['KZ ZES L.csv']
#   rg: ['KZ ZES L.csv', 'KZ ZES R.csv']
#   vortexreviews: ['KZ ZES L.csv', 'KZ ZES R.csv']
#
# kz zex csv:
#   achoreviews: ['KZ ZEX L.csv']
#   bryaudioreviews: ['KZ ZEX L.csv', 'KZ ZEX R.csv']
#   hbb: ['KZ ZEX R.csv']
#   ianfann: ['KZ ZEX L.csv', 'KZ ZEX R.csv']
#   iemworld: ['KZ ZEX L.csv', 'KZ ZEX R.csv']
#   jacstone: ['KZ ZEX L.csv', 'KZ ZEX R.csv']
#   melatonin: ['KZ ZEX L.csv', 'KZ ZEX R.csv']
#   suporsalad: ['KZ ZEX L.csv', 'KZ ZEX R.csv']
#   tgx78: ['KZ ZEX L.csv']
#   vortexreviews: ['KZ ZEX L.csv']
#   data_mrs: ['KZ ZEX L.csv', 'KZ ZEX R.csv']
#
# kz zex po csv:
#   achoreviews: ['KZ ZEX Pro L.csv']
#   aftersound: ['KZ ZEX PRO L.csv', 'KZ ZEX PRO R.csv']
#   hbb: ['KZ ZEX PRO R.csv']
#   ianfann: ['KZ ZEX PRO L.csv', 'KZ ZEX PRO R.csv']
#   jacstone: ['KZ ZEX PRO L.csv', 'KZ ZEX PRO R.csv']
#   pw: ['KZ ZEX Pro L.csv', 'KZ ZEX Pro R.csv']
#   rg: ['KZ ZEX Pro L.csv', 'KZ ZEX Pro R.csv']
#   tgx78: ['KZ Zex Pro L.csv', 'KZ Zex Pro R.csv']
#   vortexreviews: ['KZ ZEX Pro L.csv', 'KZ ZEX Pro R.csv']
#   data_mrs: ['KZ ZEX Pro L.csv', 'KZ ZEX Pro R.csv']
#
# kz zs10 po csv:
#   achoreviews: ['KZ ZS10 Pro L.csv']
#   aftersound: ['KZ ZS10 PRO R.csv']
#   eplv: ['KZ ZS10 Pro L.csv', 'KZ ZS10 Pro R.csv']
#   timmyv: ['KZ ZS10 PRO L.csv', 'KZ ZS10 PRO R.csv']
#   ianfann: ['KZ ZS10 PRO L.csv', 'KZ ZS10 PRO R.csv']
#   jacstone: ['KZ ZS10 PRO L.csv', 'KZ ZS10 PRO R.csv']
#   melatonin: ['KZ ZS10 Pro L.csv', 'KZ ZS10 Pro R.csv']
#   pw: ['KZ ZS10 Pro L.csv']
#   data_mrs: ['KZ ZS10 Pro L.csv']
#
# kz zsn csv:
#   achoreviews: ['KZ ZSN L.csv']
#   eplv: ['KZ ZSN L.csv', 'KZ ZSN R.csv']
#   hbb: ['KZ ZSN R.csv']
#   melatonin: ['KZ ZSN L.csv', 'KZ ZSN R.csv']
#   pw: ['KZ ZSN L.csv']
#
# kz zsn po csv:
#   achoreviews: ['KZ ZSN Pro L.csv']
#   aftersound: ['KZ ZSN PRO L.csv', 'KZ ZSN PRO R.csv']
#   melatonin: ['KZ ZSN Pro L.csv', 'KZ ZSN Pro R.csv']
#   pw: ['KZ ZSN Pro L.csv']
#   data_mrs: ['KZ ZSN Pro L.csv']
#
# kz zsn po x csv:
#   achoreviews: ['KZ ZSN Pro X L.csv']
#   aftersound: ['KZ ZSN PRO X R.csv']
#   bryaudioreviews: ['KZ ZSN Pro X L.csv', 'KZ ZSN Pro X R.csv']
#   hbb: ['KZ ZSN Pro X R.csv']
#   melatonin: ['KZ ZSN Pro X L.csv', 'KZ ZSN Pro X R.csv']
#   pw: ['KZ ZSN Pro X L.csv']
#
# kz zst x csv:
#   achoreviews: ['KZ ZST X L.csv']
#   aftersound: ['KZ ZST X R.csv']
#   hbb: ['KZ ZST X R.csv']
#   melatonin: ['KZ ZST X L.csv', 'KZ ZST X R.csv']
#   vortexreviews: ['KZ ZST X L.csv']
#
# kz zvx csv:
#   achoreviews: ['KZ ZVX L.csv']
#   aftersound: ['KZ ZVX L.csv', 'KZ ZVX R.csv']
#   timmyv: ['KZ ZVX L.csv', 'KZ ZVX R.csv']
#   harpo: ['KZ ZVX R.csv']
#   hbb: ['Kz Zvx R.csv']
#   ianfann: ['KZ ZVX L.csv', 'KZ ZVX R.csv']
#   pw: ['KZ ZVX L.csv']
#
# etshuoe d13  csv:
#   achoreviews: ['Letshuoer D13 (Gold Filter) L.csv', 'Letshuoer D13 (Silver Filter) L.csv']
#   bedrock: ['Letshuoer D13 (Gold) L.csv', 'Letshuoer D13 (Gold) R.csv', 'Letshuoer D13 (Silver) L.csv', 'Letshuoer D13 (Silver) R.csv']
#   ianfann: ['LETSHUOER D13 (TREBLE NOZZLE) L.csv', 'LETSHUOER D13 (TREBLE NOZZLE) R.csv']
#   data_mrs: ['Letshuoer D13 (gold) L.csv', 'Letshuoer D13 (gold) R.csv', 'Letshuoer D13 (pre-prod - nozzle A) L.csv', 'Letshuoer D13 (pre-prod - nozzle A) R.csv', 'Letshuoer D13 (pre-prod - nozzle B) L.csv', 'Letshuoer D13 (pre-prod - nozzle B) R.csv', 'Letshuoer D13 (silver) L.csv', 'Letshuoer D13 (silver) R.csv']
#
# etshuoe s12  csv:
#   achoreviews: ['Letshuoer S12 (S1) L.csv', 'Letshuoer S12 (S2) L.csv']
#   data_mrs: ['Letshuoer S12 (front vent blocked) L.csv', 'Letshuoer S12 (post) L.csv', 'Letshuoer S12 (post) R.csv', 'Letshuoer S12 (prepro) L.csv', 'Letshuoer S12 (prepro) R.csv', 'Letshuoer S12 (top vent blocked) L.csv']
#
# z a4 po nzbk fibk csv:
#   achoreviews: ['LZ A4 Pro NzBlk FiBlk L.csv']
#
# z a4 po nzbk fibu csv:
#   achoreviews: ['LZ A4 Pro NzBlk FiBlu L.csv']
#
# z a4 po nzbk fied csv:
#   achoreviews: ['LZ A4 Pro NzBlk FiRed L.csv']
#
# z a4 po nzbu fibk csv:
#   achoreviews: ['LZ A4 Pro NzBlu FiBlk L.csv']
#
# z a4 po nzbu fibu csv:
#   achoreviews: ['LZ A4 Pro NzBlu FiBlu L.csv']
#
# z a4 po nzbu fied csv:
#   achoreviews: ['LZ A4 Pro NzBlu FiRed L.csv']
#
# z a4 po nzed fibk csv:
#   achoreviews: ['LZ A4 Pro NzRed FiBlk L.csv']
#
# z a4 po nzed fibu csv:
#   achoreviews: ['LZ A4 Pro NzRed FiBlu L.csv']
#
# z a4 po nzed fied csv:
#   achoreviews: ['LZ A4 Pro NzRed FiRed L.csv']
#
# z a4 po nzsi fibk csv:
#   achoreviews: ['LZ A4 Pro NzSil FiBlk L.csv']
#
# z a4 po nzsi fibu csv:
#   achoreviews: ['LZ A4 Pro NzSil FiBlu L.csv']
#
# z a4 po nzsi fied csv:
#   achoreviews: ['LZ A4 Pro NzSil FiRed L.csv']
#
# meze audio adva csv:
#   achoreviews: ['Meze Audio Advar L.csv']
#
# moondop aia csv:
#   achoreviews: ['Moondrop Aria L.csv']
#   aftersound: ['MOONDROP ARIA L.csv', 'MOONDROP ARIA R.csv']
#   animagus: ['Moondrop Aria L.csv', 'Moondrop Aria R.csv']
#   bedrock: ['Moondrop Aria L.csv', 'Moondrop Aria R.csv']
#   bryaudioreviews: ['Moondrop Aria L.csv', 'Moondrop Aria R.csv']
#   timmyv: ['Moondrop Aria L.csv', 'Moondrop Aria R.csv']
#   harpo: ['Moondrop Aria R.csv']
#   hbb: ['Moondrop Aria R.csv']
#   ianfann: ['MOONDROP ARIA L.csv', 'MOONDROP ARIA R.csv']
#   pw: ['Moondrop Aria L.csv', 'Moondrop Aria R.csv']
#   vortexreviews: ['Moondrop Aria L.csv']
#   vsg: ['Moondrop Aria L.csv', 'Moondrop Aria R.csv']
#   data_mrs: ['Moondrop Aria L.csv']
#
# moondop bessing 2 dusk  csv:
#   achoreviews: ['Moondrop Blessing 2 Dusk (Spinfit) L.csv']
#   iemworld: ['Moondrop Blessing 2 Dusk (BGVP Foam) L.csv', 'Moondrop Blessing 2 Dusk (BGVP Foam) R.csv', 'Moondrop Blessing 2 Dusk (FINAL EARTIPS) L.csv', 'Moondrop Blessing 2 Dusk (FINAL EARTIPS) R.csv', 'Moondrop Blessing 2 Dusk (NO TIP on Coupler 8K) L.csv', 'Moondrop Blessing 2 Dusk (NO TIP on Coupler 8K) R.csv', 'Moondrop Blessing 2 Dusk (ORIGNAL SILICON) L.csv', 'Moondrop Blessing 2 Dusk (ORIGNAL SILICON) R.csv', 'Moondrop Blessing 2 Dusk (SOFTEAR UC EARTIPS) R.csv', 'Moondrop Blessing 2 Dusk (Tripowin Foam) L.csv', 'Moondrop Blessing 2 Dusk (Tripowin Foam) R.csv']
#   data_mrs: ['Moondrop Blessing 2 Dusk (Precog) L.csv']
#
# moondop chu csv:
#   achoreviews: ['Moondrop Chu L.csv']
#   aftersound: ['MOONDROP CHU L.csv', 'MOONDROP CHU R.csv']
#   arn: ['Moondrop Chu L.csv']
#   bedrock: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#   cammyfi: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#   eplv: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#   timmyv: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#   harpo: ['Moondrop Chu R.csv']
#   hbb: ['Moondrop CHU R.csv']
#   hobbytalk: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#   ianfann: ['MOONDROP CHU L.csv', 'MOONDROP CHU R.csv']
#   iemworld: ['MoonDrop CHU L.csv', 'MoonDrop CHU R.csv']
#   jacstone: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#   nymz: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#   pw: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#   suporsalad: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#   vortexreviews: ['Moondrop Chu R.csv']
#   vsg: ['Moondrop CHU L.csv', 'Moondrop CHU R.csv']
#   data_mrs: ['Moondrop Chu L.csv', 'Moondrop Chu R.csv']
#
# moondop nekocake  csv:
#   achoreviews: ['Moondrop Nekocake (Balanced + ANC) L.csv', 'Moondrop Nekocake (Balanced) L.csv', 'Moondrop Nekocake (Classic) L.csv', 'Moondrop Nekocake (Nobass) L.csv', 'Moondrop Nekocake (Wennebostel) L.csv', 'Moondrop Nekocake (X-Dynamic) L.csv']
#   data_mrs: ['Moondrop Nekocake (ANC off) L.csv', 'Moondrop Nekocake (ANC off) R.csv', 'Moondrop Nekocake (ANC on) L.csv', 'Moondrop Nekocake (ANC on) R.csv', 'Moondrop Nekocake (Classic ANC) L.csv', 'Moondrop Nekocake (Dynamic ANC) L.csv', 'Moondrop Nekocake (Nobass ANC) L.csv', 'Moondrop Nekocake (Wennebostel ANC) L.csv']
#
# moondop quaks csv:
#   achoreviews: ['Moondrop Quarks L.csv']
#   aftersound: ['MOONDROP QUARKS L.csv', 'MOONDROP QUARKS R.csv']
#   bedrock: ['Moondrop Quarks L.csv', 'Moondrop Quarks R.csv']
#   eplv: ['Moondrop Quarks L.csv', 'Moondrop Quarks R.csv']
#   hobbytalk: ['Moondrop Quarks L.csv', 'Moondrop Quarks R.csv']
#   rg: ['Moondrop Quarks L.csv', 'Moondrop Quarks R.csv']
#   suporsalad: ['Moondrop Quarks L.csv', 'Moondrop Quarks R.csv']
#   vortexreviews: ['Moondrop Quarks L.csv', 'Moondrop Quarks R.csv']
#   data_mrs: ['Moondrop Quarks L.csv', 'Moondrop Quarks R.csv']
#
# moondop ssp csv:
#   achoreviews: ['Moondrop SSP L.csv']
#   aftersound: ['MOONDROP SSP L.csv', 'MOONDROP SSP R.csv']
#   bedrock: ['Moondrop SSP L.csv', 'Moondrop SSP R.csv']
#   eplv: ['Moondrop SSP L.csv', 'Moondrop SSP R.csv']
#   cqtek: ['Moondrop SSP L.csv', 'Moondrop SSP R.csv']
#   data_mrs: ['Moondrop SSP L.csv']
#
# moondop ss csv:
#   achoreviews: ['Moondrop SSR L.csv']
#   aftersound: ['MOONDROP SSR L.csv', 'MOONDROP SSR R.csv']
#   bedrock: ['Moondrop SSR L.csv', 'Moondrop SSR R.csv']
#   bryaudioreviews: ['Moondrop SSR L.csv', 'Moondrop SSR R.csv']
#   harpo: ['Moondrop SSR R.csv']
#   hbb: ['Moondrop ssr R.csv']
#   cqtek: ['Moondrop SSR L.csv', 'Moondrop SSR R.csv']
#   nymz: ['Moondrop SSR L.csv', 'Moondrop SSR R.csv']
#   data_mrs: ['Moondrop SSR L.csv']
#
# moondop stafied csv:
#   achoreviews: ['Moondrop Starfield L.csv']
#   timmyv: ['Moondrop Starfield L.csv', 'Moondrop Starfield R.csv']
#   hbb: ['Moondrop Starfield R.csv']
#   suporsalad: ['Moondrop Starfield L.csv', 'Moondrop Starfield R.csv']
#   data_mrs: ['Moondrop Starfield L.csv']
#
# nf audio nm2 csv:
#   achoreviews: ['NF Audio NM2 L.csv']
#   cqtek: ['NF AUDIO NM2 L.csv', 'NF AUDIO NM2 R.csv']
#   ianfann: ['NF AUDIO NM2 L.csv', 'NF AUDIO NM2 R.csv']
#   tgx78: ['NF Audio NM2 L.csv']
#   vortexreviews: ['NF Audio NM2 L.csv', 'NF Audio NM2 R.csv']
#   data_mrs: ['NF Audio NM2 L.csv', 'NF Audio NM2 R.csv']
#
# nicehck topguy csv:
#   achoreviews: ['NiceHCK Topguy L.csv']
#   hbb: ['NiceHck Topguy R.csv']
#   cqtek: ['NiceHCK Topguy L.csv', 'NiceHCK Topguy R.csv']
#   melatonin: ['NICEHCK Topguy L.csv', 'NICEHCK Topguy R.csv']
#   data_mrs: ['NiceHCK Topguy L.csv', 'NiceHCK Topguy R.csv']
#
# openheat esin csv:
#   achoreviews: ['Openheart Resin L.csv']
#   tgx78: ['Openheart Resin R.csv']
#   vortexreviews: ['Openheart Resin L.csv']
#
# pussound aego csv:
#   achoreviews: ['Plussound Allegro L.csv']
#   soundjedi: ['PlusSound Allegro L.csv', 'PlusSound Allegro R.csv']
#
# qkz ck5 csv:
#   achoreviews: ['QKZ CK5 L.csv']
#
# qkz x hbb khan csv:
#   achoreviews: ['QKZ x HBB Khan L.csv']
#   aftersound: ['QKZ X HBB KHAN L.csv', 'QKZ X HBB KHAN R.csv']
#   timmyv: ['QKZ x HBB Khan L.csv', 'QKZ x HBB Khan R.csv']
#   cqtek: ['QKZ x HBB Khan L.csv', 'QKZ x HBB Khan R.csv']
#   hobbytalk: ['QKZ X HBB KHAN L.csv', 'QKZ X HBB KHAN R.csv']
#   ianfann: ['QKZ X HBB KHAN L.csv', 'QKZ X HBB KHAN R.csv']
#   nymz: ['QKZ x HBB Khan L.csv', 'QKZ x HBB Khan R.csv']
#   pw: ['QKZ x HBB Khan L.csv']
#   vortexreviews: ['QKZ x HBB Khan L.csv']
#
# qkz x hbb csv:
#   achoreviews: ['QKZ x HBB L.csv']
#   aftersound: ['QKZ X HBB L.csv', 'QKZ X HBB R.csv']
#   arn: ['QKZ x HBB L.csv']
#   timmyv: ['QKZ x HBB L.csv', 'QKZ x HBB R.csv']
#   hbb: ['QKZ X Hbb R.csv']
#   hobbytalk: ['QKZ x HBB L.csv', 'QKZ x HBB R.csv']
#   ianfann: ['QKZ X HBB L.csv', 'QKZ X HBB R.csv']
#   iemworld: ['QKZ X HBB L.csv', 'QKZ X HBB R.csv']
#   melatonin: ['QKZ x HBB R.csv']
#   nymz: ['QKZ x HBB L.csv', 'QKZ x HBB R.csv']
#   vortexreviews: ['QKZ x HBB L.csv', 'QKZ x HBB R.csv']
#   data_mrs: ['QKZ x HBB L.csv', 'QKZ x HBB R.csv']
#
# qoa gimet csv:
#   achoreviews: ['QOA Gimlet L.csv']
#   aftersound: ['QOA GIMLET L.csv', 'QOA GIMLET R.csv']
#   arn: ['QoA Gimlet L.csv', 'QoA Gimlet R.csv']
#   pw: ['QoA Gimlet L.csv', 'QoA Gimlet R.csv']
#
# eecho sg01 csv:
#   achoreviews: ['Reecho SG01 L.csv']
#
# eecho sg03 csv:
#   achoreviews: ['Reecho SG03 L.csv']
#
# seeaudio yume midnight csv:
#   achoreviews: ['SeeAudio Yume Midnight L.csv']
#   aftersound: ['SEEAUDIO YUME MIDNIGHT L.csv', 'SEEAUDIO YUME MIDNIGHT R.csv']
#   jacstone: ['SeeAudio Yume Midnight L.csv', 'SeeAudio Yume Midnight R.csv']
#   data_mrs: ['SeeAudio Yume Midnight L.csv', 'SeeAudio Yume Midnight R.csv']
#
# seek ea aiship csv:
#   achoreviews: ['Seek Real Airship L.csv']
#   hbb: ['SEEK Real Airship R.csv']
#   ianfann: ['SEEK REAL AIRSHIP L.csv', 'SEEK REAL AIRSHIP R.csv']
#   vortexreviews: ['Seek Real Airship L.csv', 'Seek Real Airship R.csv']
#
# sennheise ie600  csv:
#   achoreviews: ['Sennheiser IE600 (Stock Foam) L.csv', 'Sennheiser IE600 (Stock Silicone) L.csv']
#   iemworld: ['Sennheiser IE600 (Foam Eartips) L.csv', 'Sennheiser IE600 (Foam Eartips) R.csv', 'Sennheiser IE600 (NO TIP on Coupler) L.csv', 'Sennheiser IE600 (NO TIP on Coupler) R.csv']
#
# sennheise ie600 csv:
#   achoreviews: ['Sennheiser IE600 L.csv']
#   aftersound: ['SENNHEISER IE600 L.csv', 'SENNHEISER IE600 R.csv']
#   animagus: ['Sennheiser IE600 L.csv']
#   soundjedi: ['Sennheiser IE600 L.csv', 'Sennheiser IE600 R.csv']
#   timmyv: ['Sennheiser IE600 L.csv', 'Sennheiser IE600 R.csv']
#   hbb: ['Sennheiser IE600 R.csv']
#   hobbytalk: ['Sennheiser IE600 L.csv', 'Sennheiser IE600 R.csv']
#
# simgot ea500  csv:
#   achoreviews: ['Simgot EA500 (black) L.csv', 'Simgot EA500 (red) L.csv']
#   timmyv: ['Simgot EA500 (Black) L.csv', 'Simgot EA500 (Black) R.csv', 'Simgot EA500 (Red) L.csv', 'Simgot EA500 (Red) R.csv']
#
# sony mh755 csv:
#   achoreviews: ['Sony MH755 L.csv']
#   aftersound: ['SONY MH755 L.csv', 'SONY MH755 R.csv']
#   bryaudioreviews: ['Sony MH755 L.csv', 'Sony MH755 R.csv']
#   hbb: ['Sony MH755 R.csv']
#   nymz: ['Sony MH755 L.csv', 'Sony MH755 R.csv']
#   pw: ['Sony MH755 L.csv']
#   rg: ['Sony MH755 L.csv']
#   tgx78: ['Sony MH755 R.csv']
#   data_mrs: ['Sony MH755 L.csv']
#
# stauss and wagne em205 csv:
#   achoreviews: ['Strauss and Wagner EM205 L.csv']
#
# symphonium heios csv:
#   achoreviews: ['Symphonium Helios L.csv']
#   aftersound: ['SYMPHONIUM HELIOS L.csv', 'SYMPHONIUM HELIOS R.csv']
#   soundjedi: ['Symphonium Helios L.csv', 'Symphonium Helios R.csv']
#   timmyv: ['Symphonium Helios L.csv', 'Symphonium Helios R.csv']
#   nymz: ['Symphonium Helios L.csv', 'Symphonium Helios R.csv']
#   tgx78: ['Symphonium Helios L.csv', 'Symphonium Helios R.csv']
#   vsg: ['Symphonium Helios L.csv', 'Symphonium Helios R.csv']
#   data_mrs: ['Symphonium Helios L.csv', 'Symphonium Helios R.csv']
#
# t foce yuan i csv:
#   achoreviews: ['T Force Yuan Li L.csv']
#
# tanchjim oa csv:
#   achoreviews: ['Tanchjim Ola L.csv']
#   arn: ['Tanchjim Ola L.csv']
#   bedrock: ['Tanchjim Ola L.csv', 'Tanchjim Ola R.csv']
#   bryaudioreviews: ['Tanchjim OLA L.csv', 'Tanchjim OLA R.csv']
#   timmyv: ['Tanchjim Ola L.csv', 'Tanchjim Ola R.csv']
#   harpo: ['Tanchjim Ola R.csv']
#   hbb: ['Tanchjim OLA R.csv']
#   ianfann: ['TANCHJIM OLA L.csv', 'TANCHJIM OLA R.csv']
#   iemworld: ['TANCHJIM OLA L.csv', 'TANCHJIM OLA R.csv']
#   pw: ['Tanchjim Ola L.csv', 'Tanchjim Ola R.csv']
#   suporsalad: ['Tanchjim Ola L.csv', 'Tanchjim Ola R.csv']
#   vortexreviews: ['Tanchjim Ola R.csv']
#   data_mrs: ['Tanchjim Ola L.csv', 'Tanchjim Ola R.csv']
#
# tanchjim tanya csv:
#   achoreviews: ['Tanchjim Tanya L.csv']
#   aftersound: ['TANCHJIM TANYA L.csv', 'TANCHJIM TANYA R.csv']
#   bedrock: ['Tanchjim Tanya L.csv', 'Tanchjim Tanya R.csv']
#   bryaudioreviews: ['Tanchjim Tanya L.csv', 'Tanchjim Tanya R.csv']
#   cammyfi: ['Tanchjim Tanya L.csv', 'Tanchjim Tanya R.csv']
#   eplv: ['Tanchjim Tanya L.csv', 'Tanchjim Tanya R.csv']
#   harpo: ['Tanchjim Tanya R.csv']
#   pw: ['Tanchjim Tanya L.csv']
#   rg: ['Tanchjim Tanya L.csv', 'Tanchjim Tanya R.csv']
#   tgx78: ['Tanchjim Tanya L.csv']
#   akros: ['Tanchjim Tanya L.csv']
#   data_mrs: ['Tanchjim Tanya L.csv']
#
# tanchjim zeo csv:
#   achoreviews: ['Tanchjim Zero L.csv']
#   arn: ['Tanchjim Zero L.csv']
#   bryaudioreviews: ['Tanchjim Zero L.csv', 'Tanchjim Zero R.csv']
#   cammyfi: ['Tanchjim Zero L.csv', 'Tanchjim Zero R.csv']
#   eplv: ['Tanchjim ZERO L.csv', 'Tanchjim ZERO R.csv']
#   timmyv: ['Tanchjim Zero L.csv', 'Tanchjim Zero R.csv']
#   ianfann: ['TANCHJIM ZERO L.csv', 'TANCHJIM ZERO R.csv']
#   jacstone: ['Tanchjim ZERO L.csv', 'Tanchjim ZERO R.csv']
#   suporsalad: ['Tanchjim Zero L.csv', 'Tanchjim Zero R.csv']
#   data_mrs: ['Tanchjim Zero L.csv', 'Tanchjim Zero R.csv']
#
# tangzu shimin i csv:
#   achoreviews: ['Tangzu Shimin Li L.csv']
#   aftersound: ['TANGZU SHIMIN LI L.csv', 'TANGZU SHIMIN LI R.csv']
#   arn: ['TANGZU Shimin Li L.csv']
#   jacstone: ['TangZu Shimin Li L.csv', 'TangZu Shimin Li R.csv']
#   vortexreviews: ['Tangzu Shimin Li L.csv', 'Tangzu Shimin Li R.csv']
#
# tangzu wan e sg csv:
#   achoreviews: ['Tangzu Wan Er SG L.csv']
#
# thieaudio egacy 2 csv:
#   achoreviews: ['Thieaudio Legacy 2 L.csv']
#   bedrock: ['Thieaudio Legacy 2 L.csv', 'Thieaudio Legacy 2 R.csv']
#   vsg: ['ThieAudio Legacy 2 L.csv', 'ThieAudio Legacy 2 R.csv']
#   data_mrs: ['ThieAudio Legacy 2 L.csv']
#
# tin c2 mech waio csv:
#   achoreviews: ['Tin C2 Mech Warrior L.csv']
#   aftersound: ['TIN C2 MECH WARRIOR L.csv']
#
# tin c3 csv:
#   achoreviews: ['Tin C3 L.csv']
#
# tin t1 pus csv:
#   achoreviews: ['Tin T1 Plus L.csv']
#
# tin t1s csv:
#   achoreviews: ['Tin T1S L.csv']
#
# tin t2 dc csv:
#   achoreviews: ['Tin T2 DLC L.csv']
#
# tin t2 csv:
#   achoreviews: ['Tin T2 L.csv']
#
# tin t2 pus csv:
#   achoreviews: ['Tin T2 Plus L.csv']
#   timmyv: ['Tin T2 Plus L.csv', 'Tin T2 Plus R.csv']
#
# tin t3 buds csv:
#   achoreviews: ['Tin T3 Buds L.csv']
#
# tin t3 pus csv:
#   achoreviews: ['Tin T3 Plus L.csv']
#   bryaudioreviews: ['Tin T3 Plus L.csv', 'Tin T3 Plus R.csv']
#
# tin t4 pus csv:
#   achoreviews: ['Tin T4 Plus L.csv']
#
# tipsy ttomso pine stone sea csv:
#   achoreviews: ['Tipsy TTROMSO Pine Stone Sea L.csv']
#
# tkzk ouanos csv:
#   achoreviews: ['TKZK Ouranos L.csv']
#   timmyv: ['TKZK Ouranos L.csv', 'TKZK Ouranos R.csv']
#   cqtek: ['TKZK Ouranos L.csv', 'TKZK Ouranos R.csv']
#   ianfann: ['TKZK OURANOS L.csv', 'TKZK OURANOS R.csv']
#   pw: ['TKZK Ouranos L.csv', 'TKZK Ouranos R.csv']
#
# ti i one csv:
#   achoreviews: ['Tri i One L.csv']
#   cqtek: ['TRI i ONE L.csv', 'TRI i ONE R.csv']
#
# ti meteo csv:
#   achoreviews: ['Tri Meteor L.csv']
#   aftersound: ['TRI METEOR L.csv', 'TRI METEOR R.csv']
#   animagus: ['TRI Meteor L.csv', 'TRI Meteor R.csv']
#   bryaudioreviews: ['Tri Meteor L.csv', 'Tri Meteor R.csv']
#   harpo: ['TRI Meteor L.csv']
#   cqtek: ['Tri Meteor L.csv', 'Tri Meteor R.csv']
#   ianfann: ['TRI METEOR L.csv', 'TRI METEOR R.csv']
#   iemworld: ['TRI Meteor L.csv', 'TRI Meteor R.csv']
#   pw: ['TRI Meteor L.csv']
#
# ti x hbb kai csv:
#   achoreviews: ['Tri x HBB KAI L.csv']
#   arn: ['TRI x HBB KAI L.csv']
#   harpo: ['TRI x HBB Kai L.csv', 'TRI x HBB Kai R.csv']
#   hbb: ['TRI X HBB KAI R.csv']
#   vortexreviews: ['TRI X HBB KAI L.csv', 'TRI X HBB KAI R.csv']
#
# tipowin cencibe csv:
#   achoreviews: ['Tripowin Cencibel L.csv']
#   harpo: ['Tripowin Cencibel R.csv']
#   ianfann: ['TRIPOWIN CENCIBEL L.csv', 'TRIPOWIN CENCIBEL R.csv']
#   nymz: ['Tripowin Cencibel L.csv', 'Tripowin Cencibel R.csv']
#   data_mrs: ['Tripowin Cencibel L.csv', 'Tripowin Cencibel R.csv']
#
# tipowin ea csv:
#   achoreviews: ['Tripowin Lea L.csv']
#   timmyv: ['Tripowin Lea L.csv', 'Tripowin Lea R.csv']
#   harpo: ['Tripowin Lea L.csv']
#   hbb: ['Tripowin Lea R.csv']
#   ianfann: ['TRIPOWIN LEA L.csv', 'TRIPOWIN LEA R.csv']
#   jacstone: ['Tripowin Lea L.csv', 'Tripowin Lea R.csv']
#   melatonin: ['TRIPOWIN Lea L.csv', 'TRIPOWIN Lea R.csv']
#   nymz: ['Tripowin Lea L.csv', 'Tripowin Lea R.csv']
# ...
#   data_mrs: ['KZ ZEX (vent blocked) L.csv']
#
# kz zsn po  csv:
#   data_mrs: ['KZ ZSN Pro (1-8 foam) L.csv', 'KZ ZSN Pro (Blessing 2 filter) L.csv', 'KZ ZSN Pro (Starfield filter) L.csv', 'KZ ZSN Pro (Tanchjim filter) L.csv']
#
# etshuoe ej07m kinda ava  csv:
#   data_mrs: ['Letshuoer EJ07M Kinda Lava (modded) L.csv', 'Letshuoer EJ07M Kinda Lava (modded) R.csv']
#
# etshuoe ej07m kinda ava csv:
#   data_mrs: ['Letshuoer EJ07M Kinda Lava L.csv', 'Letshuoer EJ07M Kinda Lava R.csv']
#
# etshuoe singe csv:
#   data_mrs: ['Letshuoer Singer L.csv']
#
# g hbs800  csv:
#   data_mrs: ['LG HBS800 (ANC off) L.csv', 'LG HBS800 (ANC off) R.csv', 'LG HBS800 (ANC on) L.csv', 'LG HBS800 (ANC on) R.csv']
#
# g hbs800 csv:
#   data_mrs: ['LG HBS800 L.csv', 'LG HBS800 R.csv']
#
# magaosi k3  csv:
#   data_mrs: ['Magaosi K3 (F0) L.csv', 'Magaosi K3 (F0) R.csv', 'Magaosi K3 (F1) L.csv', 'Magaosi K3 (F1) R.csv', 'Magaosi K3 (F2) L.csv', 'Magaosi K3 (F2) R.csv']
#
# magaosi k3 csv:
#   data_mrs: ['Magaosi K3 L.csv']
#
# magaosi k5  csv:
#   data_mrs: ['Magaosi K5 (15 ohm + IEMatch+ ultra) L.csv', 'Magaosi K5 (15 ohm + IEMatch+) L.csv', 'Magaosi K5 (15 ohm) L.csv']
#
# magaosi k5 csv:
#   data_mrs: ['Magaosi K5 L.csv']
#
# mee audio m6 po 2g csv:
#   data_mrs: ['MEE Audio M6 Pro 2G L.csv']
#
# meizu ive  csv:
#   data_mrs: ['Meizu Live (black) L.csv', 'Meizu Live (blue) L.csv', 'Meizu Live (white) L.csv']
#
# mi tue wieess eabuds basic 2 csv:
#   data_mrs: ['Mi True Wireless Earbuds Basic 2 L.csv']
#
# mim dak magician evised csv:
#   data_mrs: ['MiM Dark Magician Revised L.csv', 'MiM Dark Magician Revised R.csv']
#
# moondop aice  csv:
#   data_mrs: ['Moondrop Alice (0.1.9) L.csv', 'Moondrop Alice (0.1.9) R.csv', 'Moondrop Alice (2.0.1 + E-type) L.csv', 'Moondrop Alice (2.0.1 + E-type) R.csv', 'Moondrop Alice (2.0.1) L.csv', 'Moondrop Alice (2.0.1) R.csv', 'Moondrop Alice (EQ Austria) L.csv', 'Moondrop Alice (EQ Austria) R.csv', 'Moondrop Alice (EQ Berlin) L.csv', 'Moondrop Alice (EQ Berlin) R.csv', 'Moondrop Alice (EQ Brooklyn) L.csv', 'Moondrop Alice (EQ Brooklyn) R.csv', 'Moondrop Alice (EQ Hokkaido) L.csv', 'Moondrop Alice (EQ Hokkaido) R.csv', 'Moondrop Alice (EQ Munich) L.csv', 'Moondrop Alice (EQ Munich) R.csv', 'Moondrop Alice (EQ PEQ default) L.csv', 'Moondrop Alice (EQ PEQ default) R.csv', 'Moondrop Alice (EQ Tokyo) L.csv', 'Moondrop Alice (EQ Tokyo) R.csv', 'Moondrop Alice (EQ Vienna) L.csv', 'Moondrop Alice (EQ Vienna) R.csv', 'Moondrop Alice (EQ Wennebostel) L.csv', 'Moondrop Alice (EQ Wennebostel) R.csv']
#
# moondop aice csv:
#   data_mrs: ['Moondrop Alice L.csv', 'Moondrop Alice R.csv']
#
# moondop aia snow  csv:
#   data_mrs: ['Moondrop Aria Snow (Spring) L.csv', 'Moondrop Aria Snow (Spring) R.csv']
#
# moondop bessing 2  csv:
#   data_mrs: ['Moondrop Blessing 2 (E-type) L.csv', 'Moondrop Blessing 2 (Moondrop filter) L.csv', 'Moondrop Blessing 2 (Precog) L.csv']
#
# moondop iumination  csv:
#   data_mrs: ['Moondrop Illumination (filter removed) L.csv', 'Moondrop Illumination (Final E) L.csv', 'Moondrop Illumination (Final TWS) L.csv', 'Moondrop Illumination (Moondrop Foam) L.csv', 'Moondrop Illumination (S2) L.csv', 'Moondrop Illumination (Sedna Light) L.csv', 'Moondrop Illumination (Spiral Dots) L.csv']
#
# moondop s8  csv:
#   data_mrs: ['Moondrop S8 (Precog) L.csv', 'Moondrop S8 (S2) L.csv', 'Moondrop S8 (S2) R.csv']
#
# moondop sois csv:
#   data_mrs: ['Moondrop Solis L.csv', 'Moondrop Solis R.csv']
#
# moondop sois s2 csv:
#   data_mrs: ['Moondrop Solis S2 L.csv', 'Moondrop Solis S2 R.csv']
#
# moondop spaks  csv:
#   data_mrs: ['Moondrop Sparks (1.1.2) L.csv', 'Moondrop Sparks (1.1.4) L.csv', 'Moondrop Sparks (1.1.5) L.csv', 'Moondrop Sparks (1.1.7) L.csv', 'Moondrop Sparks (1.1.9 - balanced) L.csv', 'Moondrop Sparks (1.1.9 - basshead) L.csv', 'Moondrop Sparks (1.1.9 - David Xu) L.csv', 'Moondrop Sparks (1.1.9 - no bass) L.csv', 'Moondrop Sparks (1.1.9 - studio) L.csv', 'Moondrop Sparks (1.1.9 - Wennebostel) L.csv']
#
# moondop ssp  csv:
#   data_mrs: ['Moondrop SSP (vent blocked) L.csv']
#
# moondop ss  csv:
#   data_mrs: ['Moondrop SSR (deep) L.csv', 'Moondrop SSR (deep) R.csv', 'Moondrop SSR (Final E) L.csv', 'Moondrop SSR (micro pore) L.csv', 'Moondrop SSR (OS100) L.csv', 'Moondrop SSR (OS200) L.csv', 'Moondrop SSR (OS300) L.csv', 'Moondrop SSR (S2 + Tanchjim filter) L.csv', 'Moondrop SSR (S2 - AutoEQ) L.csv', 'Moondrop SSR (S2) L.csv', 'Moondrop SSR (S3) L.csv', 'Moondrop SSR (S4) L.csv', 'Moondrop SSR (S4) R.csv', 'Moondrop SSR (Sedna) L.csv', 'Moondrop SSR (vent blocked) L.csv']
#
# moondop stadust  csv:
#   data_mrs: ['Moondrop Stardust (S2) L.csv', 'Moondrop Stardust (S2) R.csv', 'Moondrop Stardust (S3) L.csv', 'Moondrop Stardust (S3) R.csv', 'Moondrop Stardust (S4) L.csv', 'Moondrop Stardust (S4) R.csv']
#
# moondop the dopet csv:
#   data_mrs: ['Moondrop The Droplet L.csv', 'Moondrop The Droplet R.csv']
#
# nf audio na2+  csv:
#   data_mrs: ['NF Audio NA2+ (balanced tips) L.csv', 'NF Audio NA2+ (Etype tips) L.csv', 'NF Audio NA2+ (Tanchjim filter) L.csv']
#
# nothing ea 2  csv:
#   data_mrs: ['Nothing Ear 2 (balanced) L.csv', 'Nothing Ear 2 (balanced) R.csv', 'Nothing Ear 2 (more bass) L.csv', 'Nothing Ear 2 (more bass) R.csv', 'Nothing Ear 2 (more treble) L.csv', 'Nothing Ear 2 (more treble) R.csv', 'Nothing Ear 2 (personalized B) L.csv', 'Nothing Ear 2 (personalized B) R.csv', 'Nothing Ear 2 (personalized) L.csv', 'Nothing Ear 2 (personalized) R.csv', 'Nothing Ear 2 (treble -6) L.csv', 'Nothing Ear 2 (treble -6) R.csv', 'Nothing Ear 2 (voice) L.csv', 'Nothing Ear 2 (voice) R.csv']
#
# nothing ea 2 csv:
#   data_mrs: ['Nothing Ear 2 L.csv', 'Nothing Ear 2 R.csv']
#
# openaudio mecuy csv:
#   data_mrs: ['OpenAudio Mercury L.csv', 'OpenAudio Mercury R.csv']
#
# oious 2nd gen csv:
#   data_mrs: ['Oriolus 2nd Gen L.csv']
#
# phiips she3590pk csv:
#   data_mrs: ['Philips SHE3590PK L.csv']
#
# phonak audeo pfe 112 csv:
#   data_mrs: ['Phonak Audeo PFE 112 L.csv', 'Phonak Audeo PFE 112 R.csv']
#
# pe-pod 03  csv:
#   data_mrs: ['Pre-Prod 03 (nozzle A) L.csv', 'Pre-Prod 03 (nozzle A) R.csv', 'Pre-Prod 03 (nozzle B) L.csv', 'Pre-Prod 03 (nozzle B) R.csv']
#
# pisma audio azu  csv:
#   data_mrs: ['Prisma Audio Azul (E-type) L.csv', 'Prisma Audio Azul (S2) L.csv', 'Prisma Audio Azul (S2) R.csv', 'Prisma Audio Azul (Sedna) L.csv', 'Prisma Audio Azul (SpinFit) L.csv', 'Prisma Audio Azul (Spiral Dot) L.csv']
#
# pisma audio azu csv:
#   data_mrs: ['Prisma Audio Azul L.csv']
#
# qdc anoe v14  csv:
#   data_mrs: ['QDC Anole V14 (0000) L.csv', 'QDC Anole V14 (0001) L.csv', 'QDC Anole V14 (0010) L.csv', 'QDC Anole V14 (0100) L.csv', 'QDC Anole V14 (1000) L.csv']
#
# qdc anoe vx  csv:
#   data_mrs: ['QDC Anole VX (000) L.csv', 'QDC Anole VX (001) L.csv', 'QDC Anole VX (010) L.csv', 'QDC Anole VX (100) L.csv', 'QDC Anole VX (S2 000) L.csv', 'QDC Anole VX (S2 000) R.csv']
#
# qdc neptune csv:
#   data_mrs: ['QDC Neptune L.csv']
#
# qdc uanus csv:
#   data_mrs: ['QDC Uranus L.csv']
#
# adius hp-nef11 csv:
#   data_mrs: ['Radius HP-NEF11 L.csv', 'Radius HP-NEF11 R.csv']
#
# samsung eaphones  csv:
#   data_mrs: ['Samsung Earphones (2019) L.csv']
#
# samsung eaphones csv:
#   data_mrs: ['Samsung Earphones L.csv']
#
# samsung gaaxy buds2 po  csv:
#   data_mrs: ['Samsung Galaxy Buds2 Pro (ANC off) L.csv', 'Samsung Galaxy Buds2 Pro (ANC off) R.csv', 'Samsung Galaxy Buds2 Pro (bass boost) L.csv', 'Samsung Galaxy Buds2 Pro (bass boost) R.csv', 'Samsung Galaxy Buds2 Pro (clear) L.csv', 'Samsung Galaxy Buds2 Pro (clear) R.csv', 'Samsung Galaxy Buds2 Pro (dynamic) L.csv', 'Samsung Galaxy Buds2 Pro (dynamic) R.csv', 'Samsung Galaxy Buds2 Pro (normal) L.csv', 'Samsung Galaxy Buds2 Pro (normal) R.csv', 'Samsung Galaxy Buds2 Pro (soft) L.csv', 'Samsung Galaxy Buds2 Pro (soft) R.csv', 'Samsung Galaxy Buds2 Pro (treble boost) L.csv', 'Samsung Galaxy Buds2 Pro (treble boost) R.csv']
#
# seeaudio yume midnight  csv:
#   data_mrs: ['SeeAudio Yume Midnight (126ohm) L.csv', 'SeeAudio Yume Midnight (15ohm) L.csv', 'SeeAudio Yume Midnight (36ohm) L.csv', 'SeeAudio Yume Midnight (75ohm) L.csv', 'SeeAudio Yume Midnight (S2) L.csv', 'SeeAudio Yume Midnight (S2) R.csv']
#
# sennheise ie 200  csv:
#   data_mrs: ['Sennheiser IE 200 (Azla Max) L.csv', 'Sennheiser IE 200 (Azla Max) R.csv', 'Sennheiser IE 200 (D1) L.csv', 'Sennheiser IE 200 (D1) R.csv', 'Sennheiser IE 200 (D2) L.csv', 'Sennheiser IE 200 (D2) R.csv', 'Sennheiser IE 200 (Spiral Dot) L.csv', 'Sennheiser IE 200 (Spiral Dot) R.csv', 'Sennheiser IE 200 (UC tips) L.csv', 'Sennheiser IE 200 (UC tips) R.csv']
#
# sennheise ie 300  csv:
#   data_mrs: ['Sennheiser IE 300 (AutoEQ) L.csv', 'Sennheiser IE 300 (Final E) L.csv', 'Sennheiser IE 300 (Sedna Light) L.csv']
#
# sennheise ie 300 csv:
#   data_mrs: ['Sennheiser IE 300 L.csv']
#
# sennheise ie 40 po csv:
#   data_mrs: ['Sennheiser IE 40 Pro L.csv']
#
# sennheise ie 600  csv:
#   data_mrs: ['Sennheiser IE 600 (E-type shallow) L.csv', 'Sennheiser IE 600 (E-type shallow) R.csv', 'Sennheiser IE 600 (E-type) L.csv', 'Sennheiser IE 600 (E-type) R.csv', 'Sennheiser IE 600 (foam) L.csv', 'Sennheiser IE 600 (foam) R.csv', 'Sennheiser IE 600 (Sedna) L.csv', 'Sennheiser IE 600 (Sedna) R.csv', 'Sennheiser IE 600 (Spinfit) L.csv', 'Sennheiser IE 600 (Spinfit) R.csv', 'Sennheiser IE 600 (Spring tips) L.csv', 'Sennheiser IE 600 (Spring tips) R.csv']
#
# sennheise ie 600 csv:
#   data_mrs: ['Sennheiser IE 600 L.csv', 'Sennheiser IE 600 R.csv']
#
# sennheise ie 900  csv:
#   data_mrs: ['Sennheiser IE 900 (fake) L.csv', 'Sennheiser IE 900 (fake) R.csv', 'Sennheiser IE 900 (Final) L.csv', 'Sennheiser IE 900 (Final) R.csv']
#
# sennheise ie 900 csv:
#   data_mrs: ['Sennheiser IE 900 L.csv', 'Sennheiser IE 900 R.csv']
#
# sennheise momentum tw3 csv:
#   data_mrs: ['Sennheiser Momentum TW3 L.csv', 'Sennheiser Momentum TW3 R.csv']
#
# sennheise mtw2  csv:
#   data_mrs: ['Sennheiser MTW2 (HE) L.csv']
#
# sennheise mtw2 csv:
#   data_mrs: ['Sennheiser MTW2 L.csv']
#
# shaning me700 ite csv:
#   data_mrs: ['Shanling ME700 Lite L.csv']
#
# shozy cp csv:
#   data_mrs: ['Shozy CP L.csv']
#
# shozy ouge csv:
#   data_mrs: ['Shozy Rouge L.csv']
#
# simgot en700 po  csv:
#   data_mrs: ['Simgot EN700 Pro (Moondrop) L.csv', 'Simgot EN700 Pro (Tanchjim) L.csv']
#
# simgot en700 po csv:
#   data_mrs: ['Simgot EN700 Pro L.csv']
#
# softeas studio4 csv:
#   data_mrs: ['Softears Studio4 L.csv', 'Softears Studio4 R.csv']
#
# sony ie-nw510n csv:
#   data_mrs: ['Sony IER-NW510N L.csv']
#
# sony ie-z1  csv:
#   data_mrs: ['Sony IER-Z1R (S2 - Sedna) L.csv', 'Sony IER-Z1R (S2 - Sedna) R.csv', 'Sony IER-Z1R (S2 - Symbio) L.csv', 'Sony IER-Z1R (S2 - Symbio) R.csv', 'Sony IER-Z1R (S3) L.csv', 'Sony IER-Z1R (S3) R.csv']
#
# sony md-as800 csv:
#   data_mrs: ['Sony MDR-AS800 L.csv', 'Sony MDR-AS800 R.csv']
#
# sony md-ex15p  csv:
#   data_mrs: ['Sony MDR-EX15LP (deep) L.csv', 'Sony MDR-EX15LP (deep) R.csv']
#
# sony mh1 csv:
#   data_mrs: ['Sony MH1 L.csv', 'Sony MH1 R.csv']
#
# sony mh755  csv:
#   data_mrs: ['Sony MH755 (S2) L.csv', 'Sony MH755 (S3) L.csv', 'Sony MH755 (S3) R.csv', 'Sony MH755 (vent Blu Tack) L.csv']
#
# sony mh755 cone csv:
#   data_mrs: ['Sony MH755 clone L.csv']
#
# sony wf-1000xm4  csv:
#   data_mrs: ['Sony WF-1000XM4 (ambient on) L.csv', 'Sony WF-1000XM4 (ANC off) L.csv', 'Sony WF-1000XM4 (ANC on) L.csv', 'Sony WF-1000XM4 (EQ - bass boost) L.csv', 'Sony WF-1000XM4 (EQ - bright) L.csv', 'Sony WF-1000XM4 (EQ - custom) L.csv', 'Sony WF-1000XM4 (EQ - excited) L.csv', 'Sony WF-1000XM4 (EQ - mellow) L.csv', 'Sony WF-1000XM4 (EQ - relaxed) L.csv', 'Sony WF-1000XM4 (EQ - speech) L.csv', 'Sony WF-1000XM4 (EQ - treble boost) L.csv', 'Sony WF-1000XM4 (EQ - vocal) L.csv', 'Sony WF-1000XM4 (Final E-type) L.csv', 'Sony WF-1000XM4 (fw 1.1.15) L.csv', 'Sony WF-1000XM4 (max - ambient on) L.csv', 'Sony WF-1000XM4 (max - ANC off) L.csv', 'Sony WF-1000XM4 (max - ANC on) L.csv', 'Sony WF-1000XM4 (max - EQ - bass boost) L.csv', 'Sony WF-1000XM4 (max - EQ - bright) L.csv', 'Sony WF-1000XM4 (max - EQ - excited) L.csv', 'Sony WF-1000XM4 (max - EQ - mellow) L.csv', 'Sony WF-1000XM4 (max - EQ - relaxed) L.csv', 'Sony WF-1000XM4 (max - EQ - speech) L.csv', 'Sony WF-1000XM4 (max - EQ - treble boost) L.csv', 'Sony WF-1000XM4 (max - EQ - vocal) L.csv', 'Sony WF-1000XM4 (max - Final E-type) L.csv', 'Sony WF-1000XM4 (max - fw 1.1.15) L.csv', 'Sony WF-1000XM4 (max - fw 1.2.6) L.csv', 'Sony WF-1000XM4 (max - MRS config) L.csv', 'Sony WF-1000XM4 (max - Sedna Light Short) L.csv', 'Sony WF-1000XM4 (max - SpinFit) L.csv', 'Sony WF-1000XM4 (max - Tanchjim APB) L.csv', 'Sony WF-1000XM4 (max - XM3 silicone) L.csv', 'Sony WF-1000XM4 (MRS config) L.csv', 'Sony WF-1000XM4 (Sedna Light Short) L.csv', 'Sony WF-1000XM4 (SpinFit) L.csv', 'Sony WF-1000XM4 (Tanchjim APB) L.csv', 'Sony WF-1000XM4 (XM3 silicone) L.csv']
#
# sony wf-1000xm4 csv:
#   data_mrs: ['Sony WF-1000XM4 L.csv']
#
# sony xba-n3  csv:
#   data_mrs: ['Sony XBA-N3 (S2) L.csv', 'Sony XBA-N3 (S2) R.csv']
#
# status audio iem-2x csv:
#   data_mrs: ['Status Audio IEM-2X L.csv']
#
# symphonium meteo  csv:
#   data_mrs: ['Symphonium Meteor (CanJam) L.csv', 'Symphonium Meteor (CanJam) R.csv', 'Symphonium Meteor (inverted) L.csv', 'Symphonium Meteor (inverted) R.csv']
#
# tanchjim daing  csv:
#   data_mrs: ['Tanchjim Darling (depth 1) L.csv', 'Tanchjim Darling (depth 2) L.csv']
#
# tanchjim oa  csv:
#   data_mrs: ['Tanchjim Ola (s2 - filterless - taped) L.csv', 'Tanchjim Ola (s2 - filterless - taped) R.csv', 'Tanchjim Ola (s2 - filterless) L.csv', 'Tanchjim Ola (s2 - filterless) R.csv', 'Tanchjim Ola (vent Blu Tack) L.csv', 'Tanchjim Ola (vent Tanchjim filter) L.csv']
#
# tangzu wu heyday csv:
#   data_mrs: ['Tangzu Wu Heyday L.csv', 'Tangzu Wu Heyday R.csv']
#
# tansio miai spak  csv:
#   data_mrs: ['Tansio Mirai Spark (010) L.csv', 'Tansio Mirai Spark (110) L.csv', 'Tansio Mirai Spark (111) L.csv']
#
# tenhz 3ba csv:
#   data_mrs: ['Tenhz 3BA L.csv']
#
# tenhz p4 po csv:
#   data_mrs: ['Tenhz P4 Pro L.csv']
#
# tfz t2 gaaxy csv:
#   data_mrs: ['TFZ T2 Galaxy L.csv']
#
# thieaudio egacy 4  csv:
#   data_mrs: ['ThieAudio Legacy 4 (Spring) L.csv', 'ThieAudio Legacy 4 (Spring) R.csv', 'ThieAudio Legacy 4 (switch on) L.csv']
#
# thieaudio egacy 4 csv:
#   data_mrs: ['ThieAudio Legacy 4 L.csv', 'ThieAudio Legacy 4 R.csv']
#
# thieaudio egacy 5  csv:
#   data_mrs: ['ThieAudio Legacy 5 (126 ohm) L.csv', 'ThieAudio Legacy 5 (15 ohm) L.csv', 'ThieAudio Legacy 5 (36 ohm) L.csv', 'ThieAudio Legacy 5 (75 ohm) L.csv', 'ThieAudio Legacy 5 (S1 seized) L.csv', 'ThieAudio Legacy 5 (S1) L.csv', 'ThieAudio Legacy 5 (S2 15ohm) L.csv', 'ThieAudio Legacy 5 (S2) L.csv', 'ThieAudio Legacy 5 (S2) R.csv']
#
# thieaudio monach mkii  csv:
#   data_mrs: ['ThieAudio Monarch MkII (S2 - Spring tips) L.csv', 'ThieAudio Monarch MkII (S2 - Spring tips) R.csv', 'ThieAudio Monarch MkII (S2) L.csv', 'ThieAudio Monarch MkII (S2) R.csv']
#
# thinksound ain3 csv:
#   data_mrs: ['Thinksound Rain3 L.csv', 'Thinksound Rain3 R.csv']
#
# tin hifi c2 mech waio csv:
#   data_mrs: ['Tin Hifi C2 Mech Warrior L.csv', 'Tin Hifi C2 Mech Warrior R.csv']
#
# tin hifi c5 csv:
#   data_mrs: ['Tin Hifi C5 L.csv', 'Tin Hifi C5 R.csv']
#
# tin hifi p1  csv:
#   data_mrs: ['Tin Hifi P1 (vent blocked) L.csv']
#
# tin hifi t2 evo csv:
#   data_mrs: ['Tin Hifi T2 Evo L.csv', 'Tin Hifi T2 Evo R.csv']
#
# tin hifi t2 csv:
#   data_mrs: ['Tin Hifi T2 L.csv']
#
# tin hifi t2 pus  csv:
#   data_mrs: ['Tin Hifi T2 Plus (Sedna Light) L.csv']
#
# tin hifi t2 po  csv:
#   data_mrs: ['Tin Hifi T2 Pro (Comply) L.csv', 'Tin Hifi T2 Pro (white grill + Comply) L.csv']
#
# tin hifi t2 po csv:
#   data_mrs: ['Tin Hifi T2 Pro L.csv']
#
# tin hifi t5  csv:
#   data_mrs: ['Tin Hifi T5 (Comply Waxguard) L.csv']
#
# tin hifi t5 csv:
#   data_mrs: ['Tin Hifi T5 L.csv']
#
# tn im1 csv:
#   data_mrs: ['TRN IM1 L.csv']
#
# tn v30 csv:
#   data_mrs: ['TRN V30 L.csv']
#
# ucotech e-2 csv:
#   data_mrs: ['Ucotech RE-2 L.csv', 'Ucotech RE-2 R.csv']
#
# vision eas ve7 csv:
#   data_mrs: ['Vision Ears VE7 L.csv', 'Vision Ears VE7 R.csv']
#
# vsonic g07  csv:
#   data_mrs: ['Vsonic GR07 (Bass) L.csv']
#
# vsonic g07 csv:
#   data_mrs: ['Vsonic GR07 L.csv', 'Vsonic GR07 R.csv']
#
# vsonic vs7 csv:
#   data_mrs: ['Vsonic VS7 L.csv']
#
# whizze kyin csv:
#   data_mrs: ['Whizzer Kylin L.csv']
#
# xenns mangid tea 2  csv:
#   data_mrs: ['Xenns Mangird Tea 2 (S2) L.csv', 'Xenns Mangird Tea 2 (S2) R.csv']
#
# yinfu md51 csv:
#   data_mrs: ['Yinfu MD51 L.csv']
