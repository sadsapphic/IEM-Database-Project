# %%
import os
import re
import pandas as pd

# %%
reviewers = [
    'achoreviews',
    'aftersound',
    'animagus',
    'arn',
    'bedrock',
    'bryaudioreviews',
    'cammyfi',
    'soundjedi',
    'eplv',
    'timmyv',
    'harpo',
    'hbb',
    'cqtek',
    'hobbytalk',
    'ianfann',
    'iemworld',
    'jacstone',
    'kr0mka',
    'kurin',
    'melatonin',
    'nymz', 
    'pw',
    'recode',
    'rg',
    'shortbus',
    'suporsalad',
    'tgx78',
    'vortexreviews',
    'vsg',
    'wdym',
    'akros',
    'data_mrs'
]

# %%
def read_iem_list(file_path):
    with open(file_path, 'r') as f:
        content = f.read()

    iem_list = {}
    pattern = re.compile(r"'(.*?)' : \[(.*?)\]")
    matches = pattern.findall(content)

    for iem, variations in matches:
        iem = iem.strip()
        variations = [v.strip() for v in variations.split(',')]
        iem_list[iem] = variations

    return iem_list

# Read the iem_list from the .txt file
iem_list = read_iem_list('IEM Lists/output.txt')

# %%
def get_csv_files():
    csv_files = []
    for reviewer in reviewers:
        path = os.path.join("output/csv", reviewer)
        for file in os.listdir(path):
            if file.endswith(".csv"):
                csv_files.append(os.path.join(path, file))
    return csv_files

# %%
def process_filename(filename):
    # Remove file extension
    filename = os.path.splitext(filename)[0]
    
    # Convert to lowercase
    filename = filename.lower()
    
    # Remove text in brackets (round, square, and curly)
    filename = re.sub(r'(\[.*?\]|\{.*?\}|\(.*?\))', '', filename)
    
    # Remove trailing L or R
    filename = re.sub(r'[lr]$', '', filename)
    
    # Strip leading and trailing whitespaces
    filename = filename.strip()

    return filename

# %% [markdown]
# Strict group_by_iem, only uses the name variations

# %%
#def group_by_iem(csv_files):
#    grouped_files = {}
#
#    for filepath in csv_files:
#        filename = os.path.basename(filepath)
#        processed_name = process_filename(filename)
#        
#        for iem, variations in iem_list.items():
#            if processed_name in variations:
#                if iem not in grouped_files:
#                    grouped_files[iem] = []
#                grouped_files[iem].append(filepath)
#                break
#
#    return grouped_files

# %% [markdown]
# improved less strict grouping, still some errors

# %%
#def group_by_iem(csv_files):
#    grouped_files = {}
#
#    for filepath in csv_files:
#        filename = os.path.basename(filepath)
#        processed_name = process_filename(filename)
#        
#        for iem, variations in iem_list.items():
#            for variation in variations:
#                if processed_name == variation or processed_name.startswith(variation + ' '):
#                    if iem not in grouped_files:
#                        grouped_files[iem] = []
#                    grouped_files[iem].append(filepath)
#                    break
#            else:
#                continue
#            break
#
#    return grouped_files

# %%
#mport re
#
#ef group_by_iem(csv_files):
#   grouped_files = {}
#
#   # Sort the variations in descending order of their length
#   for iem in iem_list:
#       iem_list[iem].sort(key=len, reverse=True)
#
#   for filepath in csv_files:
#       filename = os.path.basename(filepath)
#       processed_name = process_filename(filename)
#       
#       for iem, variations in iem_list.items():
#           for variation in variations:
#               # Use regex to match the beginning of the processed file name
#               if re.match(f"^{variation}( |$)", processed_name):
#                   if iem not in grouped_files:
#                       grouped_files[iem] = []
#                   grouped_files[iem].append(filepath)
#                   break
#           else:
#               continue
#           break
#
#   return grouped_files
#

# %% [markdown]
# This one looks good :3

# %%
#def group_by_iem(csv_files):
#    grouped_files = {}
#
#    # Sort the variations and IEM list keys in descending order of their length
#    # This is to ensure that the longest variation is matched first
#    for iem in iem_list:
#        iem_list[iem].sort(key=len, reverse=True)
#
#    sorted_iem_list = sorted(iem_list.keys(), key=len, reverse=True)
#
#    for filepath in csv_files:
#        filename = os.path.basename(filepath)
#        processed_name = process_filename(filename)
#
#        # Iterate through the sorted IEM list keys
#        for iem_key in sorted_iem_list:
#            variations = iem_list[iem_key]
#
#            for variation in variations:
#                # Use regex to match the beginning of the processed file name
#                if re.match(f"^{variation}( |$)", processed_name):
#                    if iem_key not in grouped_files:
#                        grouped_files[iem_key] = []
#                    grouped_files[iem_key].append(filepath)
#                    break
#            else:
#                continue
#            break
#
#    return grouped_files
#

# %%
def group_by_iem(csv_files):
    grouped_files = {}

    # Sort the variations in descending order of their length
    for iem in iem_list:
        iem_list[iem].sort(key=len, reverse=True)

    # Sort the IEM list keys by their length in descending order
    sorted_iem_list = sorted(iem_list.keys(), key=len, reverse=True)

    for filepath in csv_files:
        filename = os.path.basename(filepath)
        processed_name = process_filename(filename)

        # Iterate through the sorted IEM list keys
        for iem_key in sorted_iem_list:
            variations = iem_list[iem_key]

            for variation in variations:
                # Use regex to match the beginning of the processed file name
                if re.match(f"^{variation}( |$)", processed_name):
                    if iem_key not in grouped_files:
                        grouped_files[iem_key] = []
                    grouped_files[iem_key].append(filepath)
                    break
            else:
                continue
            break

    # Sort the final dictionary alphabetically (case-insensitive) by the keys
    sorted_grouped_files = {key: grouped_files[key] for key in sorted(grouped_files, key=lambda k: k.lower())}

    return sorted_grouped_files

# %%
def create_iem_dicts(grouped_files):
    iem_dicts = []
    for iem, files in grouped_files.items():
        iem_dict = {'IEM': iem, 'Files': files}
        iem_dicts.append(iem_dict)
    return iem_dicts

csv_files = get_csv_files()
grouped_files = group_by_iem(csv_files)
iem_dicts = create_iem_dicts(grouped_files)

print(iem_dicts)
# Out:
# [{'IEM': '1Custom Apex Ti', 'Files': ['output/csv\\recode\\apexti L.csv', 'output/csv\\recode\\apexti R.csv']}, {'IEM': '1Custom PM01', 'Files': ['output/csv\\hobbytalk\\1 Custom PM-01 L.csv', 'output/csv\\hobbytalk\\1 Custom PM-01 R.csv']}, {'IEM': '1MORE ColorBuds 2', 'Files': ['output/csv\\vsg\\1MORE ColorBuds 2 L.csv', 'output/csv\\vsg\\1MORE ColorBuds 2 R.csv']}, {'IEM': '1MORE ComfoBuds Pro', 'Files': ['output/csv\\eplv\\1More ComfoBudsPro L.csv', 'output/csv\\eplv\\1More ComfoBudsProOff L.csv', 'output/csv\\eplv\\1More ComfoBudsProOff R.csv']}, {'IEM': '1MORE Evo', 'Files': ['output/csv\\vsg\\1MORE EVO L.csv', 'output/csv\\vsg\\1MORE EVO R.csv']}, {'IEM': '1MORE Piston Classic', 'Files': ['output/csv\\eplv\\1More PistonClassic L.csv', 'output/csv\\eplv\\1More PistonClassic R.csv']}, {'IEM': '1MORE Quad Driver', 'Files': ['output/csv\\iemworld\\1MORE Quad Driver L.csv', 'output/csv\\iemworld\\1MORE Quad Driver R.csv', 'output/csv\\kurin\\Oratory 1MORE Quad Driver L.csv']}, {'IEM': '1MORE Single Driver', 'Files': ['output/csv\\kurin\\Oratory 1MORE Single Driver L.csv']}, {'IEM': '1MORE Triple Driver', 'Files': ['output/csv\\iemworld\\1More Triple Driver (FOAM Eartips) L.csv', 'output/csv\\iemworld\\1More Triple Driver (FOAM Eartips) R.csv', 'output/csv\\iemworld\\1More Triple Driver (NO TIP on Coupler 8K peak disappeared FOAM) L.csv', 'output/csv\\iemworld\\1More Triple Driver (NO TIP on Coupler 8K peak disappeared FOAM) R.csv', 'output/csv\\iemworld\\1More Triple Driver (Orignal silicone Eartips) L.csv', 'output/csv\\iemworld\\1More Triple Driver (Orignal silicone Eartips) R.csv', 'output/csv\\kurin\\Oratory 1MORE Triple Driver LTNG L.csv']}, {'IEM': '4-Acoustic Harmonie', 'Files': ['output/csv\\aftersound\\4ACOUSTIC HARMONIE R.csv', 'output/csv\\recode\\2p L.csv', 'output/csv\\recode\\2p R.csv']}, {'IEM': '4-Acoustic Melodie', 'Files': ['output/csv\\recode\\melodie L.csv', 'output/csv\\recode\\melodie R.csv']}, {'IEM': '4-Acoustic Symphonie', 'Files': ['output/csv\\aftersound\\4ACOUSTIC SYMPHONIE 1 ON R.csv', 'output/csv\\aftersound\\4ACOUSTIC SYMPHONIE 2 ON R.csv', 'output/csv\\aftersound\\4ACOUSTIC SYMPHONIE 3 ON R.csv', 'output/csv\\aftersound\\4ACOUSTIC SYMPHONIE ALL OFF R.csv', 'output/csv\\aftersound\\4ACOUSTIC SYMPHONIE ALL ON R.csv', 'output/csv\\recode\\4p L.csv', 'output/csv\\recode\\4p R.csv']}, {'IEM': '4-Acoustic Unison', 'Files': ['output/csv\\aftersound\\4ACOUSTIC UNISON L.csv', 'output/csv\\aftersound\\4ACOUSTIC UNISON R.csv']}, {'IEM': '55Hz J1234s', 'Files': ['output/csv\\hbb\\J1234s R.csv']}, {'IEM': '55Hz J1s', 'Files': ['output/csv\\hbb\\J1b R.csv', 'output/csv\\hbb\\J1s R.csv']}, {'IEM': '55Hz J2b', 'Files': ['output/csv\\hbb\\J2b R.csv']}, {'IEM': '55Hz J2s', 'Files': ['output/csv\\hbb\\J2s R.csv']}, {'IEM': '55Hz J3b', 'Files': ['output/csv\\hbb\\J3b R.csv']}, {'IEM': '55Hz J3s', 'Files': ['output/csv\\hbb\\J3s R.csv']}, {'IEM': '55Hz J4b', 'Files': ['output/csv\\hbb\\J4b R.csv']}, {'IEM': '55Hz J4s', 'Files': ['output/csv\\hbb\\J4s R.csv']}, {'IEM': '64 Audio A12t', 'Files': ['output/csv\\kurin\\Oratory 64 Audio A12t (m15 Apex module) L.csv', 'output/csv\\kurin\\Oratory T64 Audio A12t (m20 Apex module) L.csv']}, {'IEM': '64 Audio Duo', 'Files': ['output/csv\\hbb\\64 Audio Duo R.csv', 'output/csv\\tgx78\\64Audio Duo R.csv', 'output/csv\\vsg\\64 Audio Duo L.csv', 'output/csv\\vsg\\64 Audio Duo R.csv', 'output/csv\\data_mrs\\64 Audio Duo L.csv', 'output/csv\\data_mrs\\64 Audio Duo R.csv']}, {'IEM': '64 Audio Fourte', 'Files': ['output/csv\\soundjedi\\64 Audio Fourte L.csv', 'output/csv\\soundjedi\\64 Audio Fourte R.csv', 'output/csv\\data_mrs\\64 Audio Fourte L.csv']}, {'IEM': '64 Audio Fourte Blanc', 'Files': ['output/csv\\data_mrs\\64 Audio Fourte Blanc L.csv', 'output/csv\\data_mrs\\64 Audio Fourte Blanc R.csv']}, {'IEM': '64 Audio Fourte Noir', 'Files': ['output/csv\\soundjedi\\64 Audio Fourte Noir L.csv', 'output/csv\\soundjedi\\64 Audio Fourte Noir R.csv']}, {'IEM': '64 Audio N8', 'Files': [' ...

# %%
# Count the total number of files
total_files = len(csv_files)

# Count the total number of groups (IEMs)
total_groups = len(iem_dicts)

# Count the total number of files in groups
files_in_groups = sum([len(d['Files']) for d in iem_dicts])

# Calculate the total number of files not in groups
files_not_in_groups = total_files - files_in_groups

# Calculate the average number of files per group
avg_files_per_group = files_in_groups / total_groups

# %%
# Print the stats
print(f"Total number of files: {total_files}")
print(f"Total number of groups: {total_groups}")
print(f"Total number of files in groups: {files_in_groups}")
print(f"Total number of files not in groups: {files_not_in_groups}")
print(f"Average number of files per group: {avg_files_per_group:.2f}")
# Out:
# Total number of files: 9882
# Total number of groups: 1266
# Total number of files in groups: 7406
# Total number of files not in groups: 2476
# Average number of files per group: 5.85

# %%
# Find and print the file paths of files not in groups
grouped_file_paths = [file for d in iem_dicts for file in d['Files']]
files_not_grouped = [file for file in csv_files if file not in grouped_file_paths]

print("\nFiles not in groups:\n")
for file in files_not_grouped:
    print(file)
# Out:
# Files not in groups:
#
# output/csv\achoreviews\Innerfidelity ID Target.csv
# output/csv\achoreviews\Precogvision Target.csv
# output/csv\achoreviews\Rtings Target.csv
# output/csv\achoreviews\Simgot EA500 (black) L.csv
# output/csv\achoreviews\Simgot EA500 (red) L.csv
# output/csv\achoreviews\Sonarworks Target.csv
# output/csv\achoreviews\Strauss and Wagner EM205 L.csv
# output/csv\achoreviews\Super Review Target.csv
# output/csv\achoreviews\T Force Yuan Li L.csv
# output/csv\achoreviews\Tanchjim Ola L.csv
# output/csv\achoreviews\Tanchjim Tanya L.csv
# output/csv\achoreviews\Tanchjim Zero L.csv
# output/csv\achoreviews\Tangzu Shimin Li L.csv
# output/csv\achoreviews\Tangzu Wan Er SG L.csv
# output/csv\achoreviews\Thieaudio Legacy 2 L.csv
# output/csv\achoreviews\Tin C2 Mech Warrior L.csv
# output/csv\achoreviews\Tin C3 L.csv
# output/csv\achoreviews\Tin T1 Plus L.csv
# output/csv\achoreviews\Tin T1S L.csv
# output/csv\achoreviews\Tin T2 DLC L.csv
# output/csv\achoreviews\Tin T2 L.csv
# output/csv\achoreviews\Tin T2 Plus L.csv
# output/csv\achoreviews\Tin T3 Buds L.csv
# output/csv\achoreviews\Tin T3 Plus L.csv
# output/csv\achoreviews\Tin T4 Plus L.csv
# output/csv\achoreviews\Tipsy TTROMSO Pine Stone Sea L.csv
# output/csv\achoreviews\TKZK Ouranos L.csv
# output/csv\achoreviews\Tri i One L.csv
# output/csv\achoreviews\Tri Meteor L.csv
# output/csv\achoreviews\Tri x HBB KAI L.csv
# output/csv\achoreviews\Tripowin Cencibel L.csv
# output/csv\achoreviews\Tripowin Lea L.csv
# output/csv\achoreviews\Tripowin Rhombus L.csv
# output/csv\achoreviews\TRN MT1 L.csv
# output/csv\achoreviews\TRN ST5 L.csv
# output/csv\achoreviews\TRN TA1 L.csv
# output/csv\achoreviews\TRN TA1 Max L.csv
# output/csv\achoreviews\TRN Xuanwu L.csv
# output/csv\achoreviews\Unique Melody Mest Mk2 L.csv
# output/csv\achoreviews\Urbanfun YBF-ISS014 (S1) L.csv
# output/csv\achoreviews\Urbanfun YBF-ISS014 (S2) L.csv
# output/csv\achoreviews\Venture Electronics Grand Duke L.csv
# output/csv\achoreviews\z_Isolation Comparison Free Field L.csv
# output/csv\aftersound\CCA CRA+ L.csv
# output/csv\aftersound\CCA CRA+ R.csv
# output/csv\aftersound\DRESSAGE 6+1 L.csv
# output/csv\aftersound\DRESSAGE 6+1 R.csv
# output/csv\aftersound\IEF neutral Target.csv
# output/csv\aftersound\IEF neutral.csv
# output/csv\aftersound\Innerfidelity ID Target.csv
# output/csv\aftersound\Innerfidelity Target.csv
# output/csv\aftersound\MR LEE 5+2 L.csv
# output/csv\aftersound\MR LEE 5+2 R.csv
# output/csv\aftersound\Precogvision Target.csv
# output/csv\aftersound\Rtings Target.csv
# output/csv\aftersound\SIMGOT EA500 CLASSIC L.csv
# output/csv\aftersound\SIMGOT EA500 CLASSIC R.csv
# output/csv\aftersound\SIMGOT EA500 HARMAN L.csv
# output/csv\aftersound\SIMGOT EA500 HARMAN R.csv
# output/csv\aftersound\SIMGOT EM2 ROLTION L.csv
# output/csv\aftersound\SIMGOT EM2 ROLTION R.csv
# output/csv\aftersound\SKALD S11 R.csv
# output/csv\aftersound\SMABAT NCO L.csv
# output/csv\aftersound\SMABAT NCO R.csv
# output/csv\aftersound\Sonarworks Target.csv
# output/csv\aftersound\SONY IER M9 L.csv
# output/csv\aftersound\SONY IER M9 R.csv
# output/csv\aftersound\SONY IER Z1R L.csv
# output/csv\aftersound\SONY IER Z1R R.csv
# output/csv\aftersound\Super Review Target.csv
# output/csv\aftersound\T-FORCE YUAN LI (PRE FINAL) L.csv
# output/csv\aftersound\T-FORCE YUAN LI (PRE FINAL) R.csv
# output/csv\aftersound\T-FORCE YUAN LI L.csv
# output/csv\aftersound\T-FORCE YUAN LI R.csv
# output/csv\aftersound\TAGO T3-02 L.csv
# output/csv\aftersound\TAGO T3-02 R.csv
# output/csv\aftersound\TANCHJIM OXYGEN L.csv
# output/csv\aftersound\TANCHJIM OXYGEN R.csv
# output/csv\aftersound\TANCHJIM TANYA L.csv
# output/csv\aftersound\TANCHJIM TANYA R.csv
# output/csv\aftersound\TANGZU SHIMIN LI ENCOUNTER R.csv
# output/csv\aftersound\TANGZU SHIMIN LI L.csv
# output/csv\aftersound\TANGZU SHIMIN LI R.csv
# output/csv\aftersound\TANGZU WAN ER L.csv
# output/csv\aftersound\TANGZU WAN ER R.csv
# output/csv\aftersound\TFZ ESSENCE R.csv
# output/csv\aftersound\TFZ ESSENCE.csv
# output/csv\aftersound\THHIFI FACE RED L.csv
# output/csv\aftersound\THHIFI FACE RED R.csv
# output/csv\aftersound\THIEAUDIO LEGACY 3 1 ON R.csv
# output/csv\aftersound\THIEAUDIO LEGACY 3 2 ON R.csv
# output/csv\aftersound\THIEAUDIO LEGACY 3 ALL ON R.csv
# output/csv\aftersound\THIEAUDIO LEGACY 3 OFF L.csv
# output/csv\aftersound\THIEAUDIO LEGACY 3 OFF R.csv
# output/csv\aftersound\THIEAUDIO LEGACY 4 1 ON R.csv
# output/csv\aftersound\THIEAUDIO LEGACY 4 2 ON R.csv
# output/csv\aftersound\THIEAUDIO LEGACY 4 ALL ON R.csv
# output/csv\aftersound\THIEAUDIO LEGACY 4 OFF R.csv
# output/csv\aftersound\THIEAUDIO LEGACY 5 L.csv
# output/csv\aftersound\THIEAUDIO LEGACY 5 R.csv
# output/csv\aftersound\TIN BUDS 3 L.csv
# output/csv\aftersound\TIN BUDS 3 R.csv
# output/csv\aftersound\TIN C2 MECH WARRIOR L.csv
# output/csv\aftersound\TIN C2 MECH WARROR R.csv
# output/csv\aftersound\TIN P2 R.csv
# output/csv\aftersound\TIN T2 2PIN L.csv
# output/csv\aftersound\TIN T2 2PIN R.csv
# output/csv\aftersound\TIN T2 EVO L.csv
# output/csv\aftersound\TIN T2 EVO R.csv
# output/csv\aftersound\TIN T2PLUS R.csv
# output/csv\aftersound\TIN T3PLUS L.csv
# output/csv\aftersound\TIN T3PLUS R.csv
# output/csv\aftersound\TIN T5 L.csv
# output/csv\aftersound\TIN T5 R.csv
# output/csv\aftersound\TKZK WAVE L.csv
# output/csv\aftersound\TKZK WAVE R.csv
# output/csv\aftersound\TRI METEOR L.csv
# output/csv\aftersound\TRI METEOR R.csv
# output/csv\aftersound\TRI STAR RIVER 1 ON R.csv
# output/csv\aftersound\TRI STAR RIVER 2 ON R.csv
# output/csv\aftersound\TRI STAR RIVER ALL OFF L.csv
# output/csv\aftersound\TRI STAR RIVER ALL OFF R.csv
# output/csv\aftersound\TRI STAR RIVER ALL ON R.csv
# output/csv\aftersound\TRIPOWIN TC01 R.csv
# output/csv\aftersound\TRN BA5 L.csv
# output/csv\aftersound\TRN BA5 R.csv
# output/csv\aftersound\TRN CS1 L.csv
# output/csv\aftersound\TRN CS1 R.csv
# output/csv\aftersound\TRN KIRIN (ATMOSPHERIC FILTER) L.csv
# output/csv\aftersound\TRN KIRIN (ATMOSPHERIC FILTER) R.csv
# output/csv\aftersound\TRN KIRIN (REFERENCE FILTER) L.csv
# output/csv\aftersound\TRN KIRIN (REFERENCE FILTER) R.csv
# output/csv\aftersound\TRN KIRIN (TRANSPARENCY FILTER) L.csv
# output/csv\aftersound\TRN KIRIN (TRANSPARENCY FILTER) R.csv
# output/csv\aftersound\TRN MT1 L.csv
# output/csv\aftersound\TRN MT1 R.csv
# output/csv\aftersound\TRN MT3 L.csv
# output/csv\aftersound\TRN MT3 R.csv
# output/csv\aftersound\TRN V80 L.csv
# output/csv\aftersound\TRN V80 R.csv
# output/csv\aftersound\TRUTHEAR HOLA L.csv
# output/csv\aftersound\TRUTHEAR HOLA R.csv
# output/csv\aftersound\UNIQUE MELODY MENTOR L.csv
# output/csv\aftersound\UNIQUE MELODY MENTOR R.csv
# output/csv\aftersound\UNIQUE MELODY MEST L.csv
# output/csv\aftersound\UNIQUE MELODY MEST MK2 L.csv
# output/csv\aftersound\UNIQUE MELODY MEST MK2 R.csv
# output/csv\aftersound\UNIQUE MELODY MEST R.csv
# output/csv\aftersound\VE AZURE L.csv
# output/csv\aftersound\VE AZURE R.csv
# output/csv\aftersound\VIDO EARBUD L.csv
# output/csv\aftersound\VIDO EARBUD R.csv
# output/csv\aftersound\WEMLIK MISTY 1 R.csv
# output/csv\aftersound\WEMLIK MISTY 2 R.csv
# output/csv\aftersound\WHIZZER HE01 L.csv
# output/csv\aftersound\WHIZZER HE01 R.csv
# output/csv\aftersound\WILLSOUND DEWA COPPER L.csv
# output/csv\aftersound\WILLSOUND DEWA COPPER R.csv
# output/csv\aftersound\WILLSOUND DEWA SILVER L.csv
# output/csv\aftersound\WILLSOUND DEWA SILVER R.csv
# output/csv\aftersound\XUANERJI X01 R.csv
# output/csv\aftersound\YANYIN MAHINA L.csv
# output/csv\aftersound\YANYIN MAHINA R.csv
# output/csv\aftersound\YANYIN MAHINA S2 L.csv
# output/csv\aftersound\YANYIN MAHINA S2 R.csv
# output/csv\aftersound\ZHULINNIAO JINGHONG L.csv
# output/csv\aftersound\ZHULINNIAO JINGHONG R.csv
# output/csv\animagus\DROP x Etymotic ERX R.csv
# output/csv\animagus\Harman In Ear 2019 Target.csv
# output/csv\animagus\Harman In Room Target.csv
# output/csv\animagus\Harman Over Ear 2018 Target.csv
# output/csv\animagus\Innerfidelity ID Target.csv
# output/csv\animagus\Precogvision Target.csv
# output/csv\animagus\Rtings Target.csv
# output/csv\animagus\Sonarworks Target.csv
# output/csv\animagus\Super Review Target.csv
# output/csv\animagus\Tanchjim Hana 2021 L.csv
# output/csv\animagus\Tanchjim Hana 2021 R.csv
# output/csv\animagus\Tanchjim Prism (Small Bore) R.csv
# output/csv\animagus\Tanchjim Prism (Wide Bore) R.csv
# output/csv\animagus\THHiFi Character (Small bore) L.csv
# output/csv\animagus\THHiFi Character (Small bore) R.csv
# output/csv\animagus\THHiFi Character (Wide bore) L.csv
# output/csv\animagus\THHiFi Character (Wide bore) R.csv
# output/csv\animagus\THHiFi Face Red (Small Bore) L.csv
# output/csv\animagus\THHiFi Face Red (Small Bore) R.csv
# output/csv\animagus\THHiFi Face Red (Wide bore) L.csv
# output/csv\animagus\THHiFi Face Red (Wide bore) R.csv
# output/csv\animagus\TRI Meteor L.csv
# output/csv\animagus\TRI Meteor R.csv
# output/csv\animagus\TRI Starlight R.csv
# output/csv\animagus\TRI Starsea (00) L.csv
# output/csv\animagus\TRI Starsea (00) R.csv
# output/csv\animagus\TRI Starsea (01) L.csv
# output/csv\animagus\TRI Starsea (01) R.csv
# output/csv\animagus\TRI Starsea (10) L.csv
# output/csv\animagus\TRI Starsea (10) R.csv
# output/csv\animagus\TRI Starsea (11) L.csv
# output/csv\animagus\TRI Starsea (11) R.csv
# output/csv\animagus\UE UE18+ Pro (2nd Gen) L.csv
# output/csv\animagus\UE UE18+ Pro (2nd Gen) R.csv
# output/csv\animagus\Vision Ears VE8 L.csv
# output/csv\arn\Enco X2 EQ Classic L.csv
# output/csv\arn\Enco X2 EQ Punchy L.csv
# output/csv\arn\Enco X2 EQ Real L.csv
# output/csv\arn\Enco X2 EQ Simple & Clear L.csv
# output/csv\arn\Harman V2 Target.csv
# output/csv\arn\Innerfidelity ID Target.csv
# output/csv\arn\Precogvision Target.csv
# output/csv\arn\Rtings Target.csv
# output/csv\arn\Sonarworks Target.csv
# output/csv\arn\Super Review Target.csv
# output/csv\arn\T4 Plus L.csv
# output/csv\arn\T4 Plus R.csv
# output/csv\arn\Tanchjim Ola L.csv
# output/csv\arn\Tanchjim Zero L.csv
# output/csv\arn\TANGZU Shimin Li L.csv
# output/csv\arn\TANGZU WAN-ER S.G L.csv
# output/csv\arn\TINHiFi Buds 3 L.csv
# output/csv\arn\TinHiFi C2 L.csv
# output/csv\arn\TinHiFi C2 R.csv
# output/csv\arn\TinHiFi C3 R.csv
# output/csv\arn\TINHiFi C5 L.csv
# output/csv\arn\TINHiFi C5 R.csv
# output/csv\arn\TINHiFi P1 Plus L.csv
# output/csv\arn\TINHiFi T1S L.csv
# output/csv\arn\TINHiFi T2 DLC L.csv
# output/csv\arn\Tipsy TTROMSO L.csv
# output/csv\arn\TRI i3 Pro L.csv
# output/csv\arn\TRI x HBB KAI L.csv
# output/csv\arn\Tripowin Leá L.csv
# output/csv\arn\TRN Bax L.csv
# output/csv\arn\TRN Kirin Atmospheric L.csv
# output/csv\arn\TRN Kirin Reference L.csv
# output/csv\arn\TRN Kirin Transparency L.csv
# output/csv\arn\TRN MT1 Pro L.csv
# output/csv\arn\TRN ST5 L.csv
# output/csv\arn\TRN Xuanwu L.csv
# output/csv\arn\TRN Xuanwu R.csv
# output/csv\arn\Trurhear HOLA L.csv
# output/csv\arn\Trurhear HOLA R.csv
# output/csv\arn\VE Bonus IE L.csv
# output/csv\arn\Whizzer BS1 L.csv
# output/csv\arn\Whizzer HE01 L.csv
# output/csv\arn\Whizzer HE03D L.csv
# output/csv\bedrock\CCA CRA+ L.csv
# output/csv\bedrock\CCA CRA+ R.csv
# output/csv\bedrock\Innerfidelity ID Target.csv
# output/csv\bedrock\Precogvision Target.csv
# output/csv\bedrock\Rtings Target.csv
# output/csv\bedrock\Simgot EM1 L.csv
# output/csv\bedrock\Simgot EM1 R.csv
# output/csv\bedrock\Sonarworks Target.csv
# output/csv\bedrock\Super Review Target.csv
# output/csv\bedrock\Tanchjim Ola L.csv
# output/csv\bedrock\Tanchjim Ola R.csv
# output/csv\bedrock\Tanchjim Tanya L.csv
# output/csv\bedrock\Tanchjim Tanya R.csv
# output/csv\bedrock\Thieaudio Legacy 2 L.csv
# output/csv\bedrock\Thieaudio Legacy 2 R.csv
# output/csv\bedrock\Thieaudio Voyager 3 (00) L.csv
# output/csv\bedrock\Thieaudio Voyager 3 (00) R.csv
# output/csv\bedrock\Thieaudio Voyager 3 (02) L.csv
# output/csv\bedrock\Thieaudio Voyager 3 (02) R.csv
# output/csv\bedrock\Thieaudio Voyager 3 (10) L.csv
# output/csv\bedrock\Thieaudio Voyager 3 (10) R.csv
# output/csv\bedrock\Thieaudio Voyager 3 (12) L.csv
# output/csv\bedrock\Thieaudio Voyager 3 (12) R.csv
# output/csv\bedrock\TinHiFi C2 L.csv
# output/csv\bedrock\TinHiFi C2 R.csv
# output/csv\bedrock\TinHiFi C3 L.csv
# output/csv\bedrock\TinHiFi C3 R.csv
# output/csv\bedrock\TinHiFi C5 L.csv
# output/csv\bedrock\TinHiFi C5 R.csv
# output/csv\bedrock\TinHiFi T1S L.csv
# output/csv\bedrock\TinHiFi T1S R.csv
# output/csv\bedrock\TinHiFi T2 DLC L.csv
# output/csv\bedrock\TinHiFi T2 DLC R.csv
# output/csv\bedrock\TinHiFi T2 Plus L.csv
# output/csv\bedrock\TinHiFi T2 Plus R.csv
# output/csv\bedrock\TinHiFi T3 Plus L.csv
# output/csv\bedrock\TinHiFi T3 Plus R.csv
# output/csv\bedrock\TinHiFi T4 Plus L.csv
# output/csv\bedrock\TinHiFi T4 Plus R.csv
# output/csv\bedrock\TinHiFi T5 L.csv
# output/csv\bedrock\TinHiFi T5 R.csv
# output/csv\bedrock\TRN BA8 L.csv
# output/csv\bedrock\TRN BA8 R.csv
# output/csv\bedrock\TRN STM (Blue) L.csv
# output/csv\bedrock\TRN STM (Blue) R.csv
# output/csv\bedrock\TRN STM (Gold) L.csv
# output/csv\bedrock\TRN STM (Gold) R.csv
# output/csv\bedrock\TRN STM (Red) L.csv
# output/csv\bedrock\TRN STM (Red) R.csv
# output/csv\bedrock\TRN V90S L.csv
# output/csv\bedrock\TRN V90S R.csv
# output/csv\bedrock\TRN VX L.csv
# output/csv\bedrock\TRN VX R.csv
# output/csv\bedrock\Truthear Hola L.csv
# output/csv\bedrock\Truthear Hola R.csv
# output/csv\bedrock\UiiSii CM5 L.csv
# output/csv\bedrock\UiiSii CM5 R.csv
# output/csv\bedrock\Yinyoo Ash L.csv
# output/csv\bedrock\Yinyoo Ash R.csv
# output/csv\bedrock\Yinyoo V2 L.csv
# output/csv\bedrock\Yinyoo V2 R.csv
# output/csv\bryaudioreviews\Harman 2017 Target.csv
# output/csv\bryaudioreviews\Harman 2019 Target.csv
# output/csv\bryaudioreviews\Innerfidelity ID Target.csv
# output/csv\bryaudioreviews\Oratory1990 Target.csv
# output/csv\bryaudioreviews\Precogvision Target.csv
# output/csv\bryaudioreviews\Rtings Target.csv
# output/csv\bryaudioreviews\Sonarworks Target.csv
# output/csv\bryaudioreviews\Sony IER M7 L.csv
# output/csv\bryaudioreviews\Sony IER M7 R.csv
# output/csv\bryaudioreviews\Sony MH1c L.csv
# output/csv\bryaudioreviews\Sony MH1c R.csv
# output/csv\bryaudioreviews\Strauss em205 L.csv
# output/csv\bryaudioreviews\Strauss em205 R.csv
# output/csv\bryaudioreviews\Super Review Target.csv
# output/csv\bryaudioreviews\Tanchjim Hana21 L.csv
# output/csv\bryaudioreviews\Tanchjim Hana21 R.csv
# output/csv\bryaudioreviews\Tanchjim OLA L.csv
# output/csv\bryaudioreviews\Tanchjim OLA R.csv
# output/csv\bryaudioreviews\Tanchjim Oxygen L.csv
# output/csv\bryaudioreviews\Tanchjim Oxygen R.csv
# output/csv\bryaudioreviews\Tanchjim Tanya L.csv
# output/csv\bryaudioreviews\Tanchjim Tanya R.csv
# output/csv\bryaudioreviews\Tanchjim Zero L.csv
# output/csv\bryaudioreviews\Tanchjim Zero R.csv
# output/csv\bryaudioreviews\TForce Yuan Li L.csv
# output/csv\bryaudioreviews\TForce Yuan Li Modded L.csv
# output/csv\bryaudioreviews\TForce Yuan Li Modded R.csv
# output/csv\bryaudioreviews\TForce Yuan Li R.csv
# output/csv\bryaudioreviews\Tin Hifi C3 L.csv
# output/csv\bryaudioreviews\Tin Hifi C3 R.csv
# output/csv\bryaudioreviews\Tin T3 Plus L.csv
# output/csv\bryaudioreviews\Tin T3 Plus R.csv
# output/csv\bryaudioreviews\TKZK Wave L.csv
# output/csv\bryaudioreviews\TKZK Wave R.csv
# output/csv\bryaudioreviews\Tri i3 Pro L.csv
# output/csv\bryaudioreviews\Tri i3 Pro R.csv
# output/csv\bryaudioreviews\Tri Meteor L.csv
# output/csv\bryaudioreviews\Tri Meteor R.csv
# output/csv\bryaudioreviews\Tri Star River Bass L.csv
# output/csv\bryaudioreviews\Tri Star River Bass R.csv
# output/csv\bryaudioreviews\Tri Star River Natural L.csv
# output/csv\bryaudioreviews\Tri Star River Natural R.csv
# output/csv\bryaudioreviews\Tri Star River Pop L.csv
# output/csv\bryaudioreviews\Tri Star River Pop R.csv
# output/csv\bryaudioreviews\Tri Star River Treble L.csv
# output/csv\bryaudioreviews\Tri Star River Treble R.csv
# output/csv\bryaudioreviews\TRN BA8 L.csv
# output/csv\bryaudioreviews\TRN BA8 R.csv
# output/csv\bryaudioreviews\TRN M10 L.csv
# output/csv\bryaudioreviews\TRN M10 R.csv
# output/csv\bryaudioreviews\TRN MT1 L.csv
# output/csv\bryaudioreviews\TRN MT1 R.csv
# output/csv\bryaudioreviews\TRN STM L.csv
# output/csv\bryaudioreviews\TRN STM R.csv
# output/csv\bryaudioreviews\TRN TA L.csv
# output/csv\bryaudioreviews\TRN TA R.csv
# output/csv\bryaudioreviews\TRN TA1 L.csv
# output/csv\bryaudioreviews\TRN TA1 R.csv
# output/csv\bryaudioreviews\TRN TA2 L.csv
# output/csv\bryaudioreviews\TRN TA2 R.csv
# output/csv\bryaudioreviews\TRN V90 L.csv
# output/csv\bryaudioreviews\TRN V90 R.csv
# output/csv\bryaudioreviews\TRN VX L.csv
# output/csv\bryaudioreviews\TRN VX Pro L.csv
# output/csv\bryaudioreviews\TRN VX Pro R.csv
# output/csv\bryaudioreviews\TRN VX R.csv
# output/csv\bryaudioreviews\TRN X7 L.csv
# output/csv\bryaudioreviews\TRN X7 R.csv
# output/csv\bryaudioreviews\Truthear HOLA L.csv
# output/csv\bryaudioreviews\Truthear HOLA R.csv
# output/csv\bryaudioreviews\Yuan Li FINAL L.csv
# output/csv\bryaudioreviews\Yuan Li FINAL R.csv
# output/csv\cammyfi\Harman IE 2019 v2 Target.csv
# output/csv\cammyfi\Innerfidelity ID Target.csv
# output/csv\cammyfi\Kurin Target.csv
# output/csv\cammyfi\Precogvision Target.csv
# output/csv\cammyfi\Rtings Target.csv
# output/csv\cammyfi\Skullcandy Dime L.csv
# output/csv\cammyfi\Skullcandy Dime R.csv
# output/csv\cammyfi\Sonarworks Target.csv
# output/csv\cammyfi\Sony MDR-EX15AP L.csv
# output/csv\cammyfi\Sony MDR-EX15AP R.csv
# output/csv\cammyfi\Super Review Target.csv
# output/csv\cammyfi\T160 L.csv
# output/csv\cammyfi\T160 R.csv
# output/csv\cammyfi\Tanchjim Ola Bass L.csv
# output/csv\cammyfi\Tanchjim Ola Bass R.csv
# output/csv\cammyfi\Tanchjim Tanya L.csv
# output/csv\cammyfi\Tanchjim Tanya R.csv
# output/csv\cammyfi\Tanchjim Zero L.csv
# output/csv\cammyfi\Tanchjim Zero R.csv
# output/csv\cammyfi\Tri Kai L.csv
# output/csv\cammyfi\Tri Kai R.csv
# output/csv\cammyfi\Waner L.csv
# output/csv\cammyfi\Waner R.csv
# output/csv\cammyfi\ZAR L.csv
# output/csv\cammyfi\ZAR R.csv
# output/csv\cammyfi\Zetian Wu L.csv
# output/csv\cammyfi\Zetian Wu R.csv
# output/csv\soundjedi\Innerfidelity ID Target.csv
# output/csv\soundjedi\Precogvision Target.csv
# output/csv\soundjedi\Rtings Target.csv
# output/csv\soundjedi\Sonarworks Target.csv
# output/csv\soundjedi\Subtonic Storm 004 L.csv
# output/csv\soundjedi\Subtonic Storm 004 R.csv
# output/csv\soundjedi\Super Review Target.csv
# output/csv\soundjedi\Symphonium Triton L.csv
# output/csv\soundjedi\Symphonium Triton R.csv
# output/csv\soundjedi\ThieAudio L9 L.csv
# output/csv\soundjedi\ThieAudio L9 R.csv
# output/csv\soundjedi\ThieAudio Prestige Deep L.csv
# output/csv\soundjedi\ThieAudio Prestige Deep R.csv
# output/csv\soundjedi\ThieAudio Prestige L.csv
# output/csv\soundjedi\ThieAudio Prestige R.csv
# output/csv\soundjedi\ThieAudio V16 L.csv
# output/csv\soundjedi\ThieAudio V16 R.csv
# output/csv\soundjedi\Tripowin x HBB Olina L.csv
# output/csv\soundjedi\Tripowin x HBB Olina R.csv
# output/csv\soundjedi\Unique Melody Fabled Sound L.csv
# output/csv\soundjedi\Unique Melody Fabled Sound R.csv
# output/csv\soundjedi\Unique Melody MEST Indigo L.csv
# output/csv\soundjedi\Unique Melody MEST Indigo R.csv
# output/csv\soundjedi\Unique Melody MEST MKII  L.csv
# output/csv\soundjedi\Unique Melody MEST MKII  R.csv
# output/csv\soundjedi\Unique Melody MEST MKII L.csv
# output/csv\soundjedi\Unique Melody MEST MKII R.csv
# output/csv\soundjedi\Vision Ears Phonix L.csv
# output/csv\soundjedi\Vision Ears Phonix R.csv
# output/csv\soundjedi\Vision Ears VE8 L.csv
# output/csv\soundjedi\Vision Ears VE8 R.csv
# output/csv\soundjedi\Westone Mach 60 L.csv
# output/csv\soundjedi\Westone Mach 60 R.csv
# output/csv\soundjedi\Xenns Mangird Tea2 L.csv
# output/csv\soundjedi\Xenns Mangird Tea2 R.csv
# output/csv\soundjedi\YanYin Mahina L.csv
# output/csv\soundjedi\YanYin Mahina R.csv
# output/csv\eplv\Audiosense DT300+36 L.csv
# output/csv\eplv\Audiosense DT300+36 R.csv
# output/csv\eplv\Audiosense DT300+75 L.csv
# output/csv\eplv\Audiosense DT300+75 R.csv
# output/csv\eplv\CCZ CoffeeBean L.csv
# output/csv\eplv\CCZ CoffeeBean R.csv
# output/csv\eplv\Harman2019v2 Target.csv
# output/csv\eplv\IEF Neutral Target.csv
# output/csv\eplv\Innerfidelity ID Target.csv
# output/csv\eplv\KBEAR NEON+100Ohm L.csv
# output/csv\eplv\KBEAR NEON+100Ohm R.csv
# output/csv\eplv\KZ ESX9 L.csv
# output/csv\eplv\KZ ESX9 R.csv
# output/csv\eplv\KZ ZS79 L.csv
# output/csv\eplv\KZ ZS79 R.csv
# output/csv\eplv\Old Crinacle Target.csv
# output/csv\eplv\Precogvision Target.csv
# output/csv\eplv\Rtings Target.csv
# output/csv\eplv\Shuoer TAPE9 L.csv
# output/csv\eplv\Shuoer TAPE9 R.csv
# output/csv\eplv\SIMGOT EM2R9 L.csv
# output/csv\eplv\SIMGOT EM2R9 R.csv
# output/csv\eplv\Sonarworks Target.csv
# output/csv\eplv\Soundpeats MiniPro L.csv
# output/csv\eplv\Soundpeats MiniPro R.csv
# output/csv\eplv\Soundpeats T3Off L.csv
# output/csv\eplv\Soundpeats T3Off R.csv
# output/csv\eplv\Soundpeats T3On L.csv
# output/csv\eplv\Soundpeats T3On R.csv
# output/csv\eplv\Super Review Target.csv
# output/csv\eplv\Tanchjim Tanya L.csv
# output/csv\eplv\Tanchjim Tanya R.csv
# output/csv\eplv\Tanchjim ZERO L.csv
# output/csv\eplv\Tanchjim ZERO R.csv
# output/csv\eplv\TANGZU ShiminLi L.csv
# output/csv\eplv\TANGZU ShiminLi R.csv
# output/csv\eplv\TFZ BALANCE19 L.csv
# output/csv\eplv\TFZ BALANCE19 R.csv
# output/csv\eplv\TIMMKOO C6109 L.csv
# output/csv\eplv\TIMMKOO C6109 R.csv
# output/csv\eplv\TinHiFi C2 L.csv
# output/csv\eplv\TinHiFi C2 R.csv
# output/csv\eplv\TinHiFi T1S9 L.csv
# output/csv\eplv\TinHiFi T1S9 R.csv
# output/csv\eplv\TinHiFi T2Plus L.csv
# output/csv\eplv\TinHiFi T2Plus R.csv
# output/csv\eplv\TinHiFi T39 L.csv
# output/csv\eplv\TinHiFi T39 R.csv
# output/csv\eplv\TinHiFi T3pro9 L.csv
# output/csv\eplv\TinHiFi T3pro9 R.csv
# output/csv\eplv\TinHiFi T59 L.csv
# output/csv\eplv\TinHiFi T59 R.csv
# output/csv\eplv\TRIPOWIN Leá L.csv
# output/csv\eplv\TRIPOWIN Leá R.csv
# output/csv\eplv\Tripowin TC019 L.csv
# output/csv\eplv\Tripowin TC019 R.csv
# output/csv\eplv\TRN BA15 L.csv
# output/csv\eplv\TRN BA15 R.csv
# output/csv\eplv\TRN BA59 L.csv
# output/csv\eplv\TRN BA59 R.csv
# output/csv\eplv\TRN BA8 L.csv
# output/csv\eplv\TRN BA8 R.csv
# output/csv\eplv\TRN M10 L.csv
# output/csv\eplv\TRN M10 R.csv
# output/csv\eplv\TRN MT3 L.csv
# output/csv\eplv\TRN MT3 R.csv
# output/csv\eplv\TRN TA1 L.csv
# output/csv\eplv\TRN TA1 R.csv
# output/csv\eplv\TRN V809 L.csv
# output/csv\eplv\TRN V809 R.csv
# output/csv\eplv\TRN V90 L.csv
# output/csv\eplv\TRN V90 R.csv
# output/csv\eplv\TRN V90S L.csv
# output/csv\eplv\TRN V90S R.csv
# output/csv\eplv\TRN VX9 L.csv
# output/csv\eplv\TRN VX9 R.csv
# output/csv\eplv\TRN VXpro9 L.csv
# output/csv\eplv\TRN VXpro9 R.csv
# output/csv\eplv\TTR Co-DonguriBrass9 L.csv
# output/csv\eplv\TTR Co-DonguriBrass9 R.csv
# output/csv\eplv\TTR Co-DonguriShizuku L.csv
# output/csv\eplv\TTR Co-DonguriShizuku R.csv
# output/csv\eplv\TTR Co-DonguriShizuku9 L.csv
# output/csv\eplv\TTR Co-DonguriShizuku9 R.csv
# output/csv\eplv\UNCJC iRock9 L.csv
# output/csv\eplv\UNCJC iRock9 R.csv
# output/csv\eplv\UrbanUtility UEHE-EP2 L.csv
# output/csv\eplv\UrbanUtility UEHE-EP2 R.csv
# output/csv\eplv\Yinyoo ASH L.csv
# output/csv\eplv\Yinyoo ASH R.csv
# output/csv\eplv\Yinyoo Pro L.csv
# output/csv\eplv\Yinyoo Pro R.csv
# output/csv\eplv\ZERO CarboTenore L.csv
# output/csv\eplv\ZERO CarboTenore R.csv
# output/csv\eplv\ZERO ZircoPezzo L.csv
# output/csv\eplv\ZERO ZircoPezzo R.csv
# output/csv\timmyv\Aful Soloist L.csv
# output/csv\timmyv\Aful Soloist R.csv
# output/csv\timmyv\Agent 007 L.csv
# output/csv\timmyv\Agent 007 R.csv
# output/csv\timmyv\Agent 008 L.csv
# output/csv\timmyv\Agent 008 R.csv
# output/csv\timmyv\DKM L.csv
# output/csv\timmyv\DKM R.csv
# output/csv\timmyv\HBB Olina SE L.csv
# output/csv\timmyv\HBB Olina SE R.csv
# output/csv\timmyv\IEF Neutral Target.csv
# output/csv\timmyv\Innerfidelity ID Target.csv
# output/csv\timmyv\KND L.csv
# output/csv\timmyv\KND R.csv
# output/csv\timmyv\Nymz Target.csv
# output/csv\timmyv\Precogvision Target.csv
# output/csv\timmyv\Rtings Target.csv
# output/csv\timmyv\Simgot EA500 (Black) L.csv
# output/csv\timmyv\Simgot EA500 (Black) R.csv
# output/csv\timmyv\Simgot EA500 (Deep).csv
# output/csv\timmyv\Simgot EA500 (Red) L.csv
# output/csv\timmyv\Simgot EA500 (Red) R.csv
# output/csv\timmyv\Softears S4 L.csv
# output/csv\timmyv\Softears S4 R.csv
# output/csv\timmyv\Sonarworks Target.csv
# output/csv\timmyv\Super Review Target.csv
# output/csv\timmyv\Tanchjim Hana 2021 L.csv
# output/csv\timmyv\Tanchjim Hana 2021 R.csv
# output/csv\timmyv\Tanchjim Ola Bass L.csv
# output/csv\timmyv\Tanchjim Ola Bass R.csv
# output/csv\timmyv\Tanchjim Ola L.csv
# output/csv\timmyv\Tanchjim Ola R.csv
# output/csv\timmyv\Tanchjim Oxygen L.csv
# output/csv\timmyv\Tanchjim Oxygen R.csv
# output/csv\timmyv\Tanchjim Zero L.csv
# output/csv\timmyv\Tanchjim Zero R.csv
# output/csv\timmyv\Tangzu Encounter L.csv
# output/csv\timmyv\Tangzu Encounter R.csv
# output/csv\timmyv\Tangzu Heydey L.csv
# output/csv\timmyv\Tangzu Heydey R.csv
# output/csv\timmyv\Tangzu Waner L.csv
# output/csv\timmyv\Tangzu Waner R.csv
# output/csv\timmyv\THC L.csv
# output/csv\timmyv\THC R.csv
# output/csv\timmyv\Thieaudio Clair L.csv
# output/csv\timmyv\Thieaudio Clair R.csv
# output/csv\timmyv\Thieaudio L2 L.csv
# output/csv\timmyv\Thieaudio L2 R.csv
# output/csv\timmyv\Thieaudio L3 (00) L.csv
# output/csv\timmyv\Thieaudio L3 (00)R.csv
# output/csv\timmyv\Thieaudio L3 (02) L.csv
# output/csv\timmyv\Thieaudio L3 (02) R.csv
# output/csv\timmyv\Thieaudio L3 (10) L.csv
# output/csv\timmyv\Thieaudio L3 (10) R.csv
# output/csv\timmyv\Thieaudio L3 (12) L.csv
# output/csv\timmyv\Thieaudio L3 (12) R.csv
# output/csv\timmyv\Thieaudio L4 (00) L.csv
# output/csv\timmyv\Thieaudio L4 (00) R.csv
# output/csv\timmyv\Thieaudio L4 (02) L.csv
# output/csv\timmyv\Thieaudio L4 (02) R.csv
# output/csv\timmyv\Thieaudio L4 (10) L.csv
# output/csv\timmyv\Thieaudio L4 (10) R.csv
# output/csv\timmyv\Thieaudio L4 (12) L.csv
# output/csv\timmyv\Thieaudio L4 (12) R.csv
# output/csv\timmyv\Thieaudio L5 L.csv
# output/csv\timmyv\Thieaudio L5 R.csv
# output/csv\timmyv\Thieaudio Prestige L.csv
# output/csv\timmyv\Thieaudio Prestige R.csv
# output/csv\timmyv\Timmy Target.csv
# output/csv\timmyv\Tin P1 L.csv
# output/csv\timmyv\Tin P1 Max L.csv
# output/csv\timmyv\Tin P1 Max R.csv
# output/csv\timmyv\Tin P1 R.csv
# output/csv\timmyv\Tin T2 Plus L.csv
# output/csv\timmyv\Tin T2 Plus R.csv
# output/csv\timmyv\Tin T5 L.csv
# output/csv\timmyv\Tin T5 R.csv
# output/csv\timmyv\TinHifi C2 L.csv
# output/csv\timmyv\TinHifi C2 R.csv
# output/csv\timmyv\TinHifi C3 L.csv
# output/csv\timmyv\TinHifi C3 R.csv
# output/csv\timmyv\TinHifi C5 L.csv
# output/csv\timmyv\TinHifi C5 R.csv
# output/csv\timmyv\TinHifi T2 DLC L.csv
# output/csv\timmyv\TinHifi T2 DLC R.csv
# output/csv\timmyv\TinHifi T3+ L.csv
# output/csv\timmyv\TinHifi T3+ R.csv
# output/csv\timmyv\TinHifi T4 L.csv
# output/csv\timmyv\TinHifi T4 Plus L.csv
# output/csv\timmyv\TinHifi T4 Plus R.csv
# output/csv\timmyv\TinHifi T4 Pluss L.csv
# output/csv\timmyv\TinHifi T4 Pluss R.csv
# output/csv\timmyv\TinHifi T4 R.csv
# output/csv\timmyv\TKZK Ouranos L.csv
# output/csv\timmyv\TKZK Ouranos R.csv
# output/csv\timmyv\TKZK Ouranos2 L.csv
# output/csv\timmyv\TKZK Ouranos2 R.csv
# output/csv\timmyv\TRI Kai L.csv
# output/csv\timmyv\TRI Kai R.csv
# output/csv\timmyv\TRI Starsea (00) L.csv
# output/csv\timmyv\TRI Starsea (00) R.csv
# output/csv\timmyv\TRI Starsea (02) L.csv
# output/csv\timmyv\TRI Starsea (02) R.csv
# output/csv\timmyv\TRI Starsea (10) L.csv
# output/csv\timmyv\TRI Starsea (10) R.csv
# output/csv\timmyv\TRI Starsea (12) L.csv
# output/csv\timmyv\TRI Starsea (12) R.csv
# output/csv\timmyv\Tripowin Lea L.csv
# output/csv\timmyv\Tripowin Lea R.csv
# output/csv\timmyv\Tripowin Mele L.csv
# output/csv\timmyv\Tripowin Mele R.csv
# output/csv\timmyv\Tripowin TC01 L.csv
# output/csv\timmyv\Tripowin TC01 R.csv
# output/csv\timmyv\TRN Kirin L.csv
# output/csv\timmyv\TRN Kirin R.csv
# output/csv\timmyv\TRN TA3 L.csv
# output/csv\timmyv\TRN TA3 R.csv
# output/csv\timmyv\Truthears Hexa L.csv
# output/csv\timmyv\Truthears Hexa R.csv
# output/csv\timmyv\Truthears Hola L.csv
# output/csv\timmyv\Truthears Hola R.csv
# output/csv\timmyv\Truthears Zero L.csv
# output/csv\timmyv\Truthears Zero R.csv
# output/csv\timmyv\TZ Shimin Li L.csv
# output/csv\timmyv\TZ Shimin Li R.csv
# output/csv\timmyv\TZ Yuan Li L.csv
# output/csv\timmyv\TZ Yuan Li R.csv
# output/csv\timmyv\UM 3DT L.csv
# output/csv\timmyv\UM 3DT R.csv
# output/csv\timmyv\UM McBeth L.csv
# output/csv\timmyv\UM McBeth R.csv
# output/csv\timmyv\UM Mest MK1 L.csv
# output/csv\timmyv\UM Mest MK1 R.csv
# output/csv\timmyv\Whizzer HE1 L.csv
# output/csv\timmyv\Whizzer HE1 R.csv
# output/csv\timmyv\Xenns Top L.csv
# output/csv\timmyv\Xenns Top R.csv
# output/csv\timmyv\Yanyin Mahina  R.csv
# output/csv\timmyv\Yanyin Mahina L.csv
# output/csv\timmyv\Yanyin Mahina R.csv
# output/csv\timmyv\Yanyin Moonlight L.csv
# output/csv\timmyv\Yanyin Moonlight R.csv
# output/csv\harpo\Enco X2 - Punchy R.csv
# output/csv\harpo\Enco X2 - Real R.csv
# output/csv\harpo\Enco X2 - Simple and Clear R.csv
# output/csv\harpo\Harpo Target.csv
# output/csv\harpo\Harpo v3 Target.csv
# output/csv\harpo\Harpo v4 Target (11.03.2023 02-43-36).csv
# output/csv\harpo\Harpo v4 Target.csv
# output/csv\harpo\Harpo_v2 Target.csv
# output/csv\harpo\Innerfidelity ID Target.csv
# output/csv\harpo\Precogvision Target.csv
# output/csv\harpo\RikudouGoku Target.csv
# output/csv\harpo\Rtings Target.csv
# output/csv\harpo\Simgot EA500 R.csv
# output/csv\harpo\Softears Target.csv
# output/csv\harpo\Sonarworks Target.csv
# output/csv\harpo\Sony MDR-XB41EX R.csv
# output/csv\harpo\Soundcore Liberty 3 Pro R.csv
# output/csv\harpo\StageSound Stage Magic Plus L.csv
# output/csv\harpo\Super Review Target.csv
# output/csv\harpo\Tanchjim Ola R.csv
# output/csv\harpo\Tanchjim Tanya R.csv
# output/csv\harpo\Tangzu Waner R.csv
# output/csv\harpo\TForce Yuan Li L.csv
# output/csv\harpo\TFZ T2 Pro R.csv
# output/csv\harpo\Tin T2+ R.csv
# output/csv\harpo\Tipsy Tromso L.csv
# output/csv\harpo\TRI I3 Pro L.csv
# output/csv\harpo\TRI I3 Pro R.csv
# output/csv\harpo\TRI Meteor L.csv
# output/csv\harpo\TRI x HBB Kai L.csv
# output/csv\harpo\TRI x HBB Kai R.csv
# output/csv\harpo\Tripowin Cencibel 2x filter mod R.csv
# output/csv\harpo\Tripowin Cencibel R.csv
# output/csv\harpo\Tripowin Lea L.csv
# output/csv\harpo\Tripowin Mele L.csv
# output/csv\harpo\TRN MT3 R.csv
# output/csv\harpo\TRN ST5 L.csv
# output/csv\harpo\TRN ST5 R.csv
# output/csv\harpo\TRN V80 R.csv
# output/csv\harpo\Truthear Hola R.csv
# output/csv\harpo\UiiSii BA-T6 R.csv
# output/csv\harpo\v4 R.csv
# output/csv\harpo\Volume 01-23 R.csv
# output/csv\harpo\Whizzer BS1 L.csv
# output/csv\harpo\Whizzer BS1 R.csv
# output/csv\harpo\X Target.csv
# output/csv\harpo\XINHS Erasmus L.csv
# output/csv\harpo\XINHS Erasmus R.csv
# output/csv\hbb\55Hz 03xx R.csv
# output/csv\hbb\55Hz 1 R.csv
# output/csv\hbb\55Hz 350 R.csv
# output/csv\hbb\55Hz 3D R.csv
# output/csv\hbb\55Hz B R.csv
# output/csv\hbb\55Hz Eki fil fo R.csv
# output/csv\hbb\55Hz Eki R.csv
# output/csv\hbb\55Hz eki tune R.csv
# output/csv\hbb\55Hz Fo R.csv
# output/csv\hbb\55Hz Hbb M R.csv
# output/csv\hbb\55Hz HBB Maka R.csv
# output/csv\hbb\55Hz Hok R.csv
# output/csv\hbb\55Hz Mystery R.csv
# output/csv\hbb\55Hz No Damp R.csv
# output/csv\hbb\55HZ OS R.csv
# output/csv\hbb\55Hz Osummer R.csv
# output/csv\hbb\55Hz Osun Sil R.csv
# output/csv\hbb\55Hz P1 Foam R.csv
# output/csv\hbb\55Hz P1 Sil R.csv
# output/csv\hbb\55Hz P2 R.csv
# output/csv\hbb\55Hz QK R.csv
# output/csv\hbb\55Hz Qkz Foa R.csv
# output/csv\hbb\55Hz Qkz Sil R.csv
# output/csv\hbb\55Hz R R.csv
# output/csv\hbb\55Hz Secretz 429 R.csv
# output/csv\hbb\55Hz See R.csv
# output/csv\hbb\55Hz Sil R.csv
# output/csv\hbb\55Hz Ss R.csv
# output/csv\hbb\55Hz ST R.csv
# output/csv\hbb\55Hz T R.csv
# output/csv\hbb\55Hz X HBB KAI R.csv
# output/csv\hbb\7Hz Sample Med R.csv
# output/csv\hbb\7Hz Sample R.csv
# output/csv\hbb\7Hz Sample Shal R.csv
# output/csv\hbb\7Hz Sample Shal.csv
# output/csv\hbb\Aful New R.csv
# output/csv\hbb\BLON aa R.csv
# output/csv\hbb\Bonus IE PRO R.csv
# output/csv\hbb\Du B R.csv
# output/csv\hbb\Edifier NeoBuds Pro R.csv
# output/csv\hbb\Foam And 450 R.csv
# output/csv\hbb\Goldpla Filt 2 R.csv
# output/csv\hbb\Graph x R.csv
# output/csv\hbb\Harmonicdyne New R.csv
# output/csv\hbb\HBB 1 R.csv
# output/csv\hbb\HBB Audio X R.csv
# output/csv\hbb\Hifiman HEseV2 R.csv
# output/csv\hbb\IEF Target.csv
# output/csv\hbb\Indigo R.csv
# output/csv\hbb\MRS Target.csv
# output/csv\hbb\NF Audio N2+ R.csv
# output/csv\hbb\Precog Target.csv
# output/csv\hbb\Precog_broken Target.csv
# output/csv\hbb\Redeyes Target.csv
# output/csv\hbb\RikudouGoku Target.csv
# output/csv\hbb\Rtings Target.csv
# output/csv\hbb\Secret T 422 R.csv
# output/csv\hbb\Secret T 422.csv
# output/csv\hbb\Shuoer KL 3 R.csv
# output/csv\hbb\Shuoer SB S12 R.csv
# output/csv\hbb\Simgot 2000 Blue R.csv
# output/csv\hbb\Simgot Ea 500 R.csv
# output/csv\hbb\Simgot Ea2000 R.csv
# output/csv\hbb\Simgot Ea2000 Stock R.csv
# output/csv\hbb\Simgot Ea2000 Tuning Foam R.csv
# output/csv\hbb\Simgot EN1000 R.csv
# output/csv\hbb\Simgot EW100 R.csv
# output/csv\hbb\Simphonio Rx 10 R.csv
# output/csv\hbb\Simphoniom Helious R.csv
# output/csv\hbb\Sivga P2 R.csv
# output/csv\hbb\Softears RSV5 R.csv
# output/csv\hbb\Sonarworks Target.csv
# output/csv\hbb\Sony EX1000 R.csv
# output/csv\hbb\Sony EX800 Taped Vent R.csv
# output/csv\hbb\Sony EX800ST R.csv
# output/csv\hbb\Sony IER Z1R R.csv
# output/csv\hbb\Sony N3ap R.csv
# output/csv\hbb\Sony Xb90ex R.csv
# output/csv\hbb\Sony Xba Z5 R.csv
# output/csv\hbb\Sony-Xba-Z5-R.csv
# output/csv\hbb\T Force Yuan Li Final R.csv
# output/csv\hbb\T20 Mod 3 R.csv
# output/csv\hbb\T20 Mod1 R.csv
# output/csv\hbb\T20 Raw R.csv
# output/csv\hbb\T50RP MKIII R.csv
# output/csv\hbb\T60RP MkIII R.csv
# output/csv\hbb\Tanchjim 02 R.csv
# output/csv\hbb\Tanchjim Hana V2 R.csv
# output/csv\hbb\Tanchjim OLA R.csv
# output/csv\hbb\Tanchjim Oxygen O2.csv
# output/csv\hbb\Tanchjim Oxygen R.csv
# output/csv\hbb\Tanchjim Prism R.csv
# output/csv\hbb\Tangzu Fo R.csv
# output/csv\hbb\Tangzu Heyday Wu R.csv
# output/csv\hbb\Tangzu R R.csv
# output/csv\hbb\Tangzu Shiminli Encounter R.csv
# output/csv\hbb\Tangzu Wan Er R.csv
# output/csv\hbb\Tangzu Z R.csv
# output/csv\hbb\Tangzu Zetian R.csv
# output/csv\hbb\Tansio Mirai 5 R.csv
# output/csv\hbb\Tansio Mirai LAND R.csv
# output/csv\hbb\Tansio Mirai Sands 020 R.csv
# output/csv\hbb\TForce Yuan Li R.csv
# output/csv\hbb\TFZ King 2 R.csv
# output/csv\hbb\TFZ King RS R.csv
# output/csv\hbb\TFZ LIVE 3 R.csv
# output/csv\hbb\TFZ Live X R.csv
# output/csv\hbb\TH Hifi Face Red R.csv
# output/csv\hbb\Thie Or r R.csv
# output/csv\hbb\Thieaudio Ghost R.csv
# output/csv\hbb\Thieaudio L2 R.csv
# output/csv\hbb\Thieaudio L3 R.csv
# output/csv\hbb\Thieaudio L4 R.csv
# output/csv\hbb\Thieaudio L5 R.csv
# output/csv\hbb\Thieaudio L9 R.csv
# output/csv\hbb\Thieaudio Prestige R.csv
# output/csv\hbb\Thieaudio V14 R.csv
# output/csv\hbb\THOR Mojinhor R.csv
# output/csv\hbb\Tinhifi C3 R.csv
# output/csv\hbb\Tinhifi C5 R.csv
# output/csv\hbb\Tinhifi Meca C2 R.csv
# output/csv\hbb\Tinhifi P1 Max R.csv
# output/csv\hbb\Tinhifi P1 Plus R.csv
# output/csv\hbb\Tinhifi P2 R.csv
# output/csv\hbb\Tinhifi T1S R.csv
# output/csv\hbb\Tinhifi T2 + R.csv
# output/csv\hbb\Tinhifi T2 Evo R.csv
# output/csv\hbb\Tinhifi T2+ No Filter R.csv
# output/csv\hbb\Tinhifi T2D Silicon R.csv
# output/csv\hbb\Tinhifi T3 Plus R.csv
# output/csv\hbb\Tinhifi T4 R.csv
# output/csv\hbb\Tinhifi T4+ R.csv
# output/csv\hbb\Tinhifi T5 R.csv
# output/csv\hbb\Tinhifi T5S R.csv
# output/csv\hbb\Tipsy Dunmer R.csv
# output/csv\hbb\Tipsy TTROMS R.csv
# output/csv\hbb\Toneking P10 R.csv
# output/csv\hbb\TRI I3 Pro R.csv
# output/csv\hbb\TRI I3 R.csv
# output/csv\hbb\TRI I4 R.csv
# output/csv\hbb\TRI ione Mic 2 R.csv
# output/csv\hbb\Tri ione R.csv
# output/csv\hbb\TRI Starlight R.csv
# output/csv\hbb\TRI Starsea R.csv
# output/csv\hbb\TRI Starshine R.csv
# output/csv\hbb\TRI X HBB Kai 2 R.csv
# output/csv\hbb\TRI X HBB KAI R.csv
# output/csv\hbb\Tri Xhbbkai R.csv
# output/csv\hbb\Trihbk R.csv
# output/csv\hbb\Tripowin A R.csv
# output/csv\hbb\Tripowin Black 2 R.csv
# output/csv\hbb\Tripowin Black R.csv
# output/csv\hbb\Tripowin H1 R (1).csv
# output/csv\hbb\Tripowin H1 R.csv
# output/csv\hbb\Tripowin Lea R.csv
# output/csv\hbb\Tripowin R.csv
# output/csv\hbb\Tripowin Silver R.csv
# output/csv\hbb\Tripowin X Hbb Loki R(1).csv
# output/csv\hbb\Tripowin X Hbb Loki R.csv
# output/csv\hbb\Tripowin X Hbb Makaha R.csv
# output/csv\hbb\Tripowin X HBB Mele Blue R.csv
# output/csv\hbb\Tripowin X HBB Olina A R.csv
# output/csv\hbb\Tripowin X HBB Olina B R.csv
# output/csv\hbb\Tripowin X HBB Olina Silicon R.csv
# output/csv\hbb\Tripowin XHBB Olina Foam R.csv
# output/csv\hbb\Tripowin Xhbb Olina Foamz R.csv
# output/csv\hbb\Tripowin Xs L R.csv
# output/csv\hbb\TRN BA 5 R.csv
# output/csv\hbb\TRN BA8 R.csv
# output/csv\hbb\TRN Bax R.csv
# output/csv\hbb\TRN Kirin Atmospheric R.csv
# output/csv\hbb\TRN MT1 R.csv
# output/csv\hbb\TRN MT3 R.csv
# output/csv\hbb\Trn Mt4 R.csv
# output/csv\hbb\TRN Reference R.csv
# output/csv\hbb\TRN ST5 R.csv
# output/csv\hbb\TRN TA1 Max R.csv
# output/csv\hbb\TRN Transparency R.csv
# output/csv\hbb\TRN V90 R.csv
# output/csv\hbb\TRN VX PRO R.csv
# output/csv\hbb\TRN X6 R.csv
# output/csv\hbb\TRN Xuanwu R.csv
# output/csv\hbb\Truthear Hola R.csv
# output/csv\hbb\Truthear X Crinacle Zero R.csv
# output/csv\hbb\TRZR Ouranos R.csv
# output/csv\hbb\TSMR 8 Bass R.csv
# output/csv\hbb\TSMR 8 Mids R.csv
# output/csv\hbb\TSMR Space R.csv
# output/csv\hbb\Unique Melody Maven Pro R.csv
# output/csv\hbb\Unique Melody MEST Indigo R.csv
# output/csv\hbb\Unique Melody MEXT R.csv
# output/csv\hbb\Urbanfun Ybf R.csv
# output/csv\hbb\VE Bonus IE R.csv
# output/csv\hbb\VENTURE BIE R.csv
# output/csv\hbb\VENTURE IE Mod R.csv
# output/csv\hbb\Yan Mahina 2 R.csv
# output/csv\hbb\Yan Ult 2 R.csv
# output/csv\hbb\Yan Ult 3 R.csv
# output/csv\hbb\Yanyin Aladdin R.csv
# output/csv\hbb\Yanyin Canon 000 R.csv
# output/csv\hbb\Yanyin Canon 001 R.csv
# output/csv\hbb\Yanyin Canon 010 R.csv
# output/csv\hbb\Yanyin Canon 100 R.csv
# output/csv\hbb\Yanyin Canon Dip 1 R.csv
# output/csv\hbb\Yanyin Canon Dip 2 R.csv
# output/csv\hbb\Yanyin Canon Dip 3 R.csv
# output/csv\hbb\Yanyin Canon R.csv
# output/csv\hbb\Yanyin M R.csv
# output/csv\hbb\Yanyin Moonlight R.csv
# output/csv\hbb\Yanyin Rosemary 00 R.csv
# output/csv\hbb\Yanyin Rosemary 01 R.csv
# output/csv\hbb\Yanyin Rosemary 10 R.csv
# output/csv\hbb\Yanyin Rosemary 11 R.csv
# output/csv\hbb\Yanyin Sample 2 R.csv
# output/csv\hbb\Yanyin Ult 1 R.csv
# output/csv\hbb\Yanyin X HBB Final R.csv
# output/csv\hbb\Yanyin X HBB Mahina R.csv
# output/csv\hbb\YBF R.csv
# output/csv\cqtek\Innerfidelity ID Target.csv
# output/csv\cqtek\NF AUDIO NA2+ L.csv
# output/csv\cqtek\NF AUDIO NA2+ R.csv
# output/csv\cqtek\NF AUDIO NM2+ L.csv
# output/csv\cqtek\NF AUDIO NM2+ R.csv
# output/csv\cqtek\Precogvision Target.csv
# output/csv\cqtek\Rtings Target.csv
# output/csv\cqtek\Smabat M0 L.csv
# output/csv\cqtek\Smabat M0 R.csv
# output/csv\cqtek\Smabat M0+Super Point L.csv
# output/csv\cqtek\Smabat M0+Super Point R.csv
# output/csv\cqtek\Smabat M2 PRO L.csv
# output/csv\cqtek\Smabat M2 PRO R.csv
# output/csv\cqtek\Smabat M2s Pro L.csv
# output/csv\cqtek\Smabat M2s Pro R.csv
# output/csv\cqtek\Smabat M2s+Gold L.csv
# output/csv\cqtek\Smabat M2s+Gold R.csv
# output/csv\cqtek\Smabat M4 BA L.csv
# output/csv\cqtek\Smabat M4 BA R.csv
# output/csv\cqtek\Smabat ST-10S L.csv
# output/csv\cqtek\Smabat ST-10S R.csv
# output/csv\cqtek\Smabat X1 -H L.csv
# output/csv\cqtek\Smabat X1 -H R.csv
# output/csv\cqtek\Smabat X1 L.csv
# output/csv\cqtek\Smabat X1 R.csv
# output/csv\cqtek\Sonarworks Target.csv
# output/csv\cqtek\SoundMagic T60BT L.csv
# output/csv\cqtek\SoundMagic T60BT R.csv
# output/csv\cqtek\Super Review Target.csv
# output/csv\cqtek\SuperTFZ Force King L.csv
# output/csv\cqtek\SuperTFZ Force King R.csv
# output/csv\cqtek\SuperTFZ Force1 L.csv
# output/csv\cqtek\SuperTFZ Force1 R.csv
# output/csv\cqtek\SWD2LE.csv
# output/csv\cqtek\Symphonium Audio Helios_r L.csv
# output/csv\cqtek\Symphonium Audio Helios_r R.csv
# output/csv\cqtek\Tanchjim Cora L.csv
# output/csv\cqtek\Tanchjim Cora R.csv
# output/csv\cqtek\TFZ Live 1 L.csv
# output/csv\cqtek\TFZ Live 1 R.csv
# output/csv\cqtek\TFZ Live 3 L.csv
# output/csv\cqtek\TFZ Live 3 R.csv
# output/csv\cqtek\TFZ Live X L.csv
# output/csv\cqtek\TFZ Live X R.csv
# output/csv\cqtek\TFZ My Love 4 L.csv
# output/csv\cqtek\TFZ My Love 4 R.csv
# output/csv\cqtek\TFZ My Love III L.csv
# output/csv\cqtek\TFZ My Love III R.csv
# output/csv\cqtek\TFZ No.3 L.csv
# output/csv\cqtek\TFZ No.3 R.csv
# output/csv\cqtek\TFZ T2 Pro L.csv
# output/csv\cqtek\TFZ T2 Pro R.csv
# output/csv\cqtek\TFZ Tequila 1 R.csv
# output/csv\cqtek\TFZ Tequila Pro L.csv
# output/csv\cqtek\TFZ Tequila Pro R.csv
# output/csv\cqtek\Tin HiFi P2 L.csv
# output/csv\cqtek\Tin HiFi P2 R.csv
# output/csv\cqtek\Tin HiFi T1 Plus L.csv
# output/csv\cqtek\Tin HiFi T1 Plus R.csv
# output/csv\cqtek\Tin HiFi T4 L.csv
# output/csv\cqtek\Tin HiFi T4 R.csv
# output/csv\cqtek\TinHiFi C2 L.csv
# output/csv\cqtek\TinHiFi C2 R.csv
# output/csv\cqtek\TinHiFi C3 L.csv
# output/csv\cqtek\TinHiFi C3 R.csv
# output/csv\cqtek\TinHiFi P1 MAX Giant Panda L.csv
# output/csv\cqtek\TinHiFi P1 MAX Giant Panda R.csv
# output/csv\cqtek\TinHiFi P1 MAX L.csv
# output/csv\cqtek\TinHiFi P1 MAX R.csv
# output/csv\cqtek\TinHiFi T2 DLC L.csv
# output/csv\cqtek\TinHiFi T2 DLC R.csv
# output/csv\cqtek\TinHiFi T4 Plus L.csv
# output/csv\cqtek\TinHiFi T4 Plus R.csv
# output/csv\cqtek\TKZK Ouranos L.csv
# output/csv\cqtek\TKZK Ouranos R.csv
# output/csv\cqtek\TRI i ONE L.csv
# output/csv\cqtek\TRI i ONE R.csv
# output/csv\cqtek\TRI KAI x HBB L.csv
# output/csv\cqtek\TRI KAI x HBB R.csv
# output/csv\cqtek\Tri Meteor L.csv
# output/csv\cqtek\Tri Meteor R.csv
# output/csv\cqtek\TRN Kirin Atmospheric L.csv
# output/csv\cqtek\TRN Kirin Atmospheric R.csv
# output/csv\cqtek\TRN Kirin Reference L.csv
# output/csv\cqtek\TRN Kirin Reference R.csv
# output/csv\cqtek\TRN Kirin Transparency L.csv
# output/csv\cqtek\TRN Kirin Transparency R.csv
# output/csv\cqtek\Tronsmart Apollo Bold CLASSIC R.csv
# output/csv\cqtek\Tronsmart Apollo Bold JAZZ R.csv
# output/csv\cqtek\Tronsmart Apollo Bold L.csv
# output/csv\cqtek\Tronsmart Apollo Bold POP R.csv
# output/csv\cqtek\Tronsmart Apollo Bold R.csv
# output/csv\cqtek\Tronsmart Apollo Bold ROCK R.csv
# output/csv\cqtek\Tronsmart Onyx Prime L.csv
# output/csv\cqtek\Tronsmart Onyx Prime R.csv
# output/csv\cqtek\Yanyin Aladdin L.csv
# output/csv\cqtek\Yanyin Aladdin R.csv
# output/csv\hobbytalk\Harman IE 2019 Target.csv
# output/csv\hobbytalk\Hobby Talk Flat Target.csv
# output/csv\hobbytalk\Hobby Talk Preference Target OG.csv
# output/csv\hobbytalk\Hobby Talk Preference Target.csv
# output/csv\hobbytalk\Honest Target.csv
# output/csv\hobbytalk\IEF Neutral Target.csv
# output/csv\hobbytalk\IEF OE Target.csv
# output/csv\hobbytalk\Innerfidelity ID Target.csv
# output/csv\hobbytalk\Lypertek Z3 2.0 L.csv
# output/csv\hobbytalk\Lypertek Z3 2.0 R.csv
# output/csv\hobbytalk\Precogvision Target.csv
# output/csv\hobbytalk\RAPTGO x HBB HOOK-X 75 L.csv
# output/csv\hobbytalk\RAPTGO x HBB HOOK-X 75 R.csv
# output/csv\hobbytalk\RAPTGO x HBB HOOK-X L.csv
# output/csv\hobbytalk\RAPTGO x HBB HOOK-X R.csv
# output/csv\hobbytalk\RAPTGO x HBB HOOK-X S2 L.csv
# output/csv\hobbytalk\RAPTGO x HBB HOOK-X S2 R.csv
# output/csv\hobbytalk\Rtings Target.csv
# output/csv\hobbytalk\Simgot EA500 Black L.csv
# output/csv\hobbytalk\Simgot EA500 Black R.csv
# output/csv\hobbytalk\Simgot EA500 L.csv
# output/csv\hobbytalk\Simgot EA500 R.csv
# output/csv\hobbytalk\Simgot EA500 Red L.csv
# output/csv\hobbytalk\Simgot EA500 Red R.csv
# output/csv\hobbytalk\Sonarworks Target.csv
# output/csv\hobbytalk\Soundpeats Capsule3 Pro L.csv
# output/csv\hobbytalk\Soundpeats Capsule3 Pro R.csv
# output/csv\hobbytalk\Soundpeats Free2 Classic L.csv
# output/csv\hobbytalk\Soundpeats Free2 Classic R.csv
# output/csv\hobbytalk\Soundpeats Opera05 L.csv
# output/csv\hobbytalk\Soundpeats Opera05 R.csv
# output/csv\hobbytalk\Super Review Target.csv
# output/csv\hobbytalk\TANCHJIM OLA BASS L.csv
# output/csv\hobbytalk\TANCHJIM OLA BASS R.csv
# output/csv\hobbytalk\Tanchjim Zero DSP L.csv
# output/csv\hobbytalk\Tanchjim Zero DSP R.csv
# output/csv\hobbytalk\TANGZU Shimin Li Encounter L.csv
# output/csv\hobbytalk\TANGZU Shimin Li Encounter R.csv
# output/csv\hobbytalk\TANGZU Waner L.csv
# output/csv\hobbytalk\TANGZU Waner R.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu L.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu R.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu Tape L.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu Tape R.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu XBASS L.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu XBASS R.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu XBASS XSPACE L.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu XBASS XSPACE R.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu XSPACE L.csv
# output/csv\hobbytalk\TANGZU x HBB Zetian Wu XSPACE R.csv
# output/csv\hobbytalk\TinHiFi C2 L.csv
# output/csv\hobbytalk\TinHiFi C2 R.csv
# output/csv\hobbytalk\TinHiFi C3 L.csv
# output/csv\hobbytalk\TinHiFi C3 R.csv
# output/csv\hobbytalk\TinHiFi P1 Max L.csv
# output/csv\hobbytalk\TinHiFi P1 Max R.csv
# output/csv\hobbytalk\TinHiFi P1 Max Tape Mod L.csv
# output/csv\hobbytalk\TinHiFi P1 Max Tape Mod R.csv
# output/csv\hobbytalk\TinHiFi T2 DLC L.csv
# output/csv\hobbytalk\TinHiFi T2 DLC R.csv
# output/csv\hobbytalk\TinHiFi T4 Plus Deep Fit L.csv
# output/csv\hobbytalk\TinHiFi T4 Plus Deep Fit R.csv
# output/csv\hobbytalk\TinHiFi T4 Plus L.csv
# output/csv\hobbytalk\TinHiFi T4 Plus R.csv
# output/csv\hobbytalk\TLC Socl300 L.csv
# output/csv\hobbytalk\TLC Socl300 R.csv
# output/csv\hobbytalk\TRI KAI L.csv
# output/csv\hobbytalk\TRI KAI R.csv
# output/csv\hobbytalk\TRI Star River II L.csv
# output/csv\hobbytalk\TRI Star River II R.csv
# output/csv\hobbytalk\TRI Star River IO L.csv
# output/csv\hobbytalk\TRI Star River IO R.csv
# output/csv\hobbytalk\TRI Star River L.csv
# output/csv\hobbytalk\TRI Star River OI L.csv
# output/csv\hobbytalk\TRI Star River OI R.csv
# output/csv\hobbytalk\TRI Star River R.csv
# output/csv\hobbytalk\Truthear HOLA L.csv
# output/csv\hobbytalk\Truthear HOLA R.csv
# output/csv\hobbytalk\Unknown Amazon IEM L.csv
# output/csv\hobbytalk\Unknown Amazon IEM R.csv
# output/csv\hobbytalk\VE Bonus IE L.csv
# output/csv\hobbytalk\VE Bonus IE R.csv
# output/csv\hobbytalk\Westone UM2 L.csv
# output/csv\hobbytalk\Westone UM2 R.csv
# output/csv\hobbytalk\X2 Sport L.csv
# output/csv\hobbytalk\X2 Sport R.csv
# output/csv\hobbytalk\Zhulinniao Jinghong L.csv
# output/csv\hobbytalk\Zhulinniao Jinghong R.csv
# output/csv\ianfann\CCA CRA+ (STOCK TIPS) L.csv
# output/csv\ianfann\CCA CRA+ (STOCK TIPS) R.csv
# output/csv\ianfann\CCA CRA+ L.csv
# output/csv\ianfann\CCA CRA+ R.csv
# output/csv\ianfann\Harman 2017 Target.csv
# output/csv\ianfann\Harman 2019 Target.csv
# output/csv\ianfann\IanFann-Target Target.csv
# output/csv\ianfann\ianfann.csv
# output/csv\ianfann\IEF Neutral 2023 Target.csv
# output/csv\ianfann\IEF Target.csv
# output/csv\ianfann\IEF Target1.csv
# output/csv\ianfann\Innerfidelity ID Target.csv
# output/csv\ianfann\Precogvision Target.csv
# output/csv\ianfann\Rtings Target.csv
# output/csv\ianfann\SIMGOT EA2000 C3A035 L.csv
# output/csv\ianfann\SIMGOT EA2000 C3A035 R.csv
# output/csv\ianfann\SIMGOT EA2000 N3A000 L.csv
# output/csv\ianfann\SIMGOT EA2000 N3A000 R.csv
# output/csv\ianfann\SIMGOT EA2000 N4A000 L.csv
# output/csv\ianfann\SIMGOT EA2000 N4A000 R.csv
# output/csv\ianfann\SIMGOT EA500 BLUE L.csv
# output/csv\ianfann\SIMGOT EA500 BLUE R.csv
# output/csv\ianfann\SIMGOT EA500 RED L.csv
# output/csv\ianfann\SIMGOT EA500 RED R.csv
# output/csv\ianfann\SIMGOT EN1000 C3A035 L.csv
# output/csv\ianfann\SIMGOT EN1000 C3A035 R.csv
# output/csv\ianfann\SIMGOT EN1000 C3A045 L.csv
# output/csv\ianfann\SIMGOT EN1000 C3A045 R.csv
# output/csv\ianfann\SIMGOT EN1000 N3A000 L.csv
# output/csv\ianfann\SIMGOT EN1000 N3A000 R.csv
# output/csv\ianfann\SIMGOT EW100P L.csv
# output/csv\ianfann\SIMGOT EW100P R.csv
# output/csv\ianfann\Sonarworks Target.csv
# output/csv\ianfann\SOUNDPEATS CAPSULE3 PRO L.csv
# output/csv\ianfann\SOUNDPEATS CAPSULE3 PRO R.csv
# output/csv\ianfann\SOUNDPEATS LIFE TWS L.csv
# output/csv\ianfann\SOUNDPEATS LIFE TWS R.csv
# output/csv\ianfann\SOUNDPEATS MINI PRO HS L.csv
# output/csv\ianfann\SOUNDPEATS MINI PRO HS R.csv
# output/csv\ianfann\SOUNDPEATS OPERA 05 L.csv
# output/csv\ianfann\SOUNDPEATS OPERA 05 R.csv
# output/csv\ianfann\Super Review Target.csv
# output/csv\ianfann\TANCHJIM OLA L.csv
# output/csv\ianfann\TANCHJIM OLA R.csv
# output/csv\ianfann\TANCHJIM ZERO L.csv
# output/csv\ianfann\TANCHJIM ZERO R.csv
# output/csv\ianfann\TANGZU SHIMINLI L.csv
# output/csv\ianfann\TANGZU SHIMINLI R.csv
# output/csv\ianfann\TANGZU WANER L.csv
# output/csv\ianfann\TANGZU WANER R.csv
# output/csv\ianfann\TANGZU ZETIANWU HAYDAY L.csv
# output/csv\ianfann\TANGZU ZETIANWU HAYDAY R.csv
# output/csv\ianfann\TANGZU ZETIANWU L.csv
# output/csv\ianfann\TANGZU ZETIANWU R.csv
# output/csv\ianfann\THHIFI CHARACTER L.csv
# output/csv\ianfann\THHIFI CHARACTER R.csv
# output/csv\ianfann\THIEAUDIO GHOST L.csv
# output/csv\ianfann\THIEAUDIO GHOST R.csv
# output/csv\ianfann\TINHIFI C2 L.csv
# output/csv\ianfann\TINHIFI C2 R.csv
# output/csv\ianfann\TINHIFI C3 L.csv
# output/csv\ianfann\TINHIFI C3 R.csv
# output/csv\ianfann\TINHIFI C5 L.csv
# output/csv\ianfann\TINHIFI C5 R.csv
# output/csv\ianfann\TINHIFI T1S L.csv
# output/csv\ianfann\TINHIFI T1S R.csv
# output/csv\ianfann\TINHIFI T2 DLC L.csv
# output/csv\ianfann\TINHIFI T2 DLC R.csv
# output/csv\ianfann\TINHIFI T3+ L.csv
# output/csv\ianfann\TINHIFI T3+ R.csv
# output/csv\ianfann\TINHIFI T4+ L.csv
# ...
# output/csv\vortexreviews\Simgot EA500 Red R.csv
# output/csv\vortexreviews\Sonarworks Target.csv
# output/csv\vortexreviews\Soundpeats Capsule3 Pro L.csv
# output/csv\vortexreviews\Soundpeats Capsule3 Pro R.csv
# output/csv\vortexreviews\Soundpeats Free2 Classic L.csv
# output/csv\vortexreviews\Soundpeats Life L.csv
# output/csv\vortexreviews\Soundpeats Life R.csv
# output/csv\vortexreviews\Soundpeats Mini Pro HS L.csv
# output/csv\vortexreviews\Soundpeats Mini Pro HS R.csv
# output/csv\vortexreviews\Soundpeats Mini Pro L.csv
# output/csv\vortexreviews\Soundpeats Mini Pro R.csv
# output/csv\vortexreviews\Soundpeats Opera05 L.csv
# output/csv\vortexreviews\Soundpeats Opera05 R.csv
# output/csv\vortexreviews\Super Review Target.csv
# output/csv\vortexreviews\SuperEQ Q2 Pro R.csv
# output/csv\vortexreviews\Symphonium Audio Meteor L.csv
# output/csv\vortexreviews\Symphonium Audio Meteor R.csv
# output/csv\vortexreviews\Symphonium Audio Triton L.csv
# output/csv\vortexreviews\Symphonium Audio Triton R.csv
# output/csv\vortexreviews\Tanchjim Ola R.csv
# output/csv\vortexreviews\Tangzu Shimin Li L.csv
# output/csv\vortexreviews\Tangzu Shimin Li R.csv
# output/csv\vortexreviews\Tangzu Wan'er L.csv
# output/csv\vortexreviews\Tangzu Wan'er R.csv
# output/csv\vortexreviews\Tangzu x HBB Wu Heyday L.csv
# output/csv\vortexreviews\Tangzu x HBB Wu Heyday R.csv
# output/csv\vortexreviews\Tangzu Ze Tian Wu L.csv
# output/csv\vortexreviews\Tangzu Ze Tian Wu R.csv
# output/csv\vortexreviews\TFZ Live 3 R.csv
# output/csv\vortexreviews\TFZ My Love Edition 2021 L.csv
# output/csv\vortexreviews\ThieAudio V16 L.csv
# output/csv\vortexreviews\ThieAudio V16 R.csv
# output/csv\vortexreviews\THOR Mjölnir MKII L.csv
# output/csv\vortexreviews\THOR Mjölnir MKII R.csv
# output/csv\vortexreviews\Tin Hifi C2 L.csv
# output/csv\vortexreviews\Tin Hifi C2 R.csv
# output/csv\vortexreviews\Tin Hifi C3 L.csv
# output/csv\vortexreviews\Tin Hifi T1 Plus R.csv
# output/csv\vortexreviews\Tin Hifi T1S L.csv
# output/csv\vortexreviews\Tin Hifi Tin Buds 3 L.csv
# output/csv\vortexreviews\TKZK Wave L.csv
# output/csv\vortexreviews\TKZK Wave R.csv
# output/csv\vortexreviews\Tozo Golden X1 L.csv
# output/csv\vortexreviews\Tozo Golden X1 R.csv
# output/csv\vortexreviews\TRI i3 Pro L.csv
# output/csv\vortexreviews\TRI i3 Pro R.csv
# output/csv\vortexreviews\TRI X HBB KAI L.csv
# output/csv\vortexreviews\TRI X HBB KAI R.csv
# output/csv\vortexreviews\Tripowin Lea' R.csv
# output/csv\vortexreviews\Tripowin TC01 L.csv
# output/csv\vortexreviews\Tripowin TC01 R.csv
# output/csv\vortexreviews\Tripowin X HBB Mele R.csv
# output/csv\vortexreviews\Tripowin X HBB Olina Double Filter L.csv
# output/csv\vortexreviews\Tripowin X HBB Olina Double Filter R.csv
# output/csv\vortexreviews\Tripowin X HBB Olina L.csv
# output/csv\vortexreviews\Tripowin X HBB Olina R.csv
# output/csv\vortexreviews\TRN BAX L.csv
# output/csv\vortexreviews\TRN BAX R.csv
# output/csv\vortexreviews\TRN CS1 L.csv
# output/csv\vortexreviews\TRN H2 L.csv
# output/csv\vortexreviews\TRN MT1 L.csv
# output/csv\vortexreviews\TRN MT3 L.csv
# output/csv\vortexreviews\TRN MT3 R.csv
# output/csv\vortexreviews\TRN Rosefinch L.csv
# output/csv\vortexreviews\TRN Rosefinch R.csv
# output/csv\vortexreviews\TRN ST2 R.csv
# output/csv\vortexreviews\TRN ST5 L.csv
# output/csv\vortexreviews\TRN ST5 R.csv
# output/csv\vortexreviews\TRN TA1 L.csv
# output/csv\vortexreviews\TRN TA1 Max L.csv
# output/csv\vortexreviews\TRN TA1 Max R.csv
# output/csv\vortexreviews\TRN TA1 R.csv
# output/csv\vortexreviews\TRN VX Pro L.csv
# output/csv\vortexreviews\TRN VX Pro R.csv
# output/csv\vortexreviews\TRN Xuanwu L.csv
# output/csv\vortexreviews\TRN Xuanwu R.csv
# output/csv\vortexreviews\Truthear Hola L.csv
# output/csv\vortexreviews\Truthear Hola R.csv
# output/csv\vortexreviews\Venture Electronics Bonus IE Pro R.csv
# output/csv\vortexreviews\Venture Electronics Bonus IE R.csv
# output/csv\vsg\Cambridge Audio Melomania 1+ L.csv
# output/csv\vsg\Cambridge Audio Melomania 1+ R.csv
# output/csv\vsg\Drop + Dan Clark Audio Aeon Closed X 1-notch white filter L.csv
# output/csv\vsg\Drop + Dan Clark Audio Aeon Closed X L.csv
# output/csv\vsg\Drop + Dan Clark Audio Aeon Closed X R.csv
# output/csv\vsg\Harman 2018 Over-Ear Target.csv
# output/csv\vsg\Harman 2019 In-Ear Target.csv
# output/csv\vsg\Harman Combined Over-Ear Target.csv
# output/csv\vsg\Harman In-Ear Target.csv
# output/csv\vsg\HarmonicDyne P.D.1 L.csv
# output/csv\vsg\HarmonicDyne P.D.1 R.csv
# output/csv\vsg\Hear+Hi Acuity Duo L.csv
# output/csv\vsg\Hear+Hi Acuity Duo R.csv
# output/csv\vsg\HIFIMAN HE-R10P Bluemini L.csv
# output/csv\vsg\HIFIMAN HE-R10P Bluemini R.csv
# output/csv\vsg\HIFIMAN HE-R10P L.csv
# output/csv\vsg\HIFIMAN HE-R10P R.csv
# output/csv\vsg\Innerfidelity ID Target.csv
# output/csv\vsg\Precogvision Target.csv
# output/csv\vsg\Rtings Target.csv
# output/csv\vsg\Sivga Oriole L.csv
# output/csv\vsg\Sivga Oriole R.csv
# output/csv\vsg\Sivga Phoenix L.csv
# output/csv\vsg\Sivga Phoenix R.csv
# output/csv\vsg\Sivga Robin (SV021) L.csv
# output/csv\vsg\Sivga Robin (SV021) R.csv
# output/csv\vsg\Sivga SV023 L.csv
# output/csv\vsg\Sivga SV023 R.csv
# output/csv\vsg\Sonarworks Target.csv
# output/csv\vsg\Super Review Target.csv
# output/csv\vsg\Tanchjim New HANA 2021 Bass L.csv
# output/csv\vsg\Tanchjim New HANA 2021 Bass R.csv
# output/csv\vsg\Tanchjim New HANA 2021 Treble L.csv
# output/csv\vsg\Tanchjim New HANA 2021 Treble R.csv
# output/csv\vsg\TangZu Audio Shimin Li L.csv
# output/csv\vsg\TangZu Audio Shimin Li R.csv
# output/csv\vsg\TangZu Audio WanEr SG L.csv
# output/csv\vsg\TangZu Audio WanEr SG R.csv
# output/csv\vsg\TangZu Audio Zetian Wu L.csv
# output/csv\vsg\TangZu Audio Zetian Wu R.csv
# output/csv\vsg\Technics AZ70 L.csv
# output/csv\vsg\Technics AZ70 R.csv
# output/csv\vsg\ThieAudio Ghost L.csv
# output/csv\vsg\ThieAudio Ghost R.csv
# output/csv\vsg\ThieAudio Legacy 2 L.csv
# output/csv\vsg\ThieAudio Legacy 2 R.csv
# output/csv\vsg\ThieAudio Legacy 5 L.csv
# output/csv\vsg\ThieAudio Legacy 5 R.csv
# output/csv\vsg\ThieAudio Prestige L.csv
# output/csv\vsg\ThieAudio Prestige R.csv
# output/csv\vsg\ThieAudio Wraith L.csv
# output/csv\vsg\ThieAudio Wraith Pad A L.csv
# output/csv\vsg\ThieAudio Wraith Pad A R.csv
# output/csv\vsg\ThieAudio Wraith Pad B L.csv
# output/csv\vsg\ThieAudio Wraith Pad B R.csv
# output/csv\vsg\ThieAudio Wraith R.csv
# output/csv\vsg\TinHiFi C5 prototype L.csv
# output/csv\vsg\TinHiFi C5 prototype R.csv
# output/csv\vsg\TinHiFi P1 Max L.csv
# output/csv\vsg\TinHiFi P1 Max Prototype L.csv
# output/csv\vsg\TinHiFi P1 Max Prototype R.csv
# output/csv\vsg\TinHiFi P1 Max R.csv
# output/csv\vsg\TinHiFi T2 Evo L.csv
# output/csv\vsg\TinHiFi T2 Evo R.csv
# output/csv\vsg\TinHiFi T5 L.csv
# output/csv\vsg\TinHiFi T5 R.csv
# output/csv\vsg\Tripowin Lea L.csv
# output/csv\vsg\Tripowin Lea R.csv
# output/csv\vsg\Tripowin TC-01 L.csv
# output/csv\vsg\Tripowin TC-01 R.csv
# output/csv\vsg\Tripowin x HBB Olina L.csv
# output/csv\vsg\Tripowin x HBB Olina R.csv
# output/csv\vsg\Tripowin x HBB Olina SE L.csv
# output/csv\vsg\Tripowin x HBB Olina SE R.csv
# output/csv\vsg\Tronsmart Apollo Air+ L.csv
# output/csv\vsg\Tronsmart Apollo Air+ R.csv
# output/csv\vsg\Truthear HOLA L.csv
# output/csv\vsg\Truthear HOLA R.csv
# output/csv\vsg\Truthear HOLA wide bore L.csv
# output/csv\vsg\Truthear HOLA wide bore R.csv
# output/csv\vsg\Truthear x Crinacle Zero L.csv
# output/csv\vsg\Truthear x Crinacle Zero R.csv
# output/csv\vsg\UA Complimentary 1 L.csv
# output/csv\vsg\UA Complimentary 1 R.csv
# output/csv\vsg\UA Complimentary 2 L.csv
# output/csv\vsg\UA Complimentary 2 R.csv
# output/csv\vsg\Ugreen HiTune T3 L.csv
# output/csv\vsg\Ugreen HiTune T3 R.csv
# output/csv\vsg\VSG Target.csv
# output/csv\vsg\Westone MACH 10 L.csv
# output/csv\vsg\Westone MACH 10 R.csv
# output/csv\vsg\Westone MACH 20 L.csv
# output/csv\vsg\Westone MACH 20 R.csv
# output/csv\vsg\Westone MACH 30 L.csv
# output/csv\vsg\Westone MACH 30 R.csv
# output/csv\vsg\Westone MACH 40 L.csv
# output/csv\vsg\Westone MACH 40 R.csv
# output/csv\vsg\Westone MACH 50 L.csv
# output/csv\vsg\Westone MACH 50 R.csv
# output/csv\vsg\Westone MACH 60 L.csv
# output/csv\vsg\Westone MACH 60 R.csv
# output/csv\vsg\Westone MACH 70 L.csv
# output/csv\vsg\Westone MACH 70 R.csv
# output/csv\vsg\Westone MACH 80 L.csv
# output/csv\vsg\Westone MACH 80 R.csv
# output/csv\vsg\XENNS Mangird Tea 2 L.csv
# output/csv\vsg\XENNS Mangird Tea 2 R.csv
# output/csv\vsg\XENNS Mangird Tea L.csv
# output/csv\vsg\XENNS Mangird Tea R.csv
# output/csv\vsg\XENNS Mangird Top L.csv
# output/csv\vsg\XENNS Mangird Top R.csv
# output/csv\vsg\XENNS UP L.csv
# output/csv\vsg\XENNS UP R.csv
# output/csv\vsg\XENNS UP Sample 2 L.csv
# output/csv\vsg\XENNS UP Sample 2 R.csv
# output/csv\vsg\Yanyin Canon all switches L.csv
# output/csv\vsg\Yanyin Canon all switches R.csv
# output/csv\vsg\Yanyin Canon bass switch L.csv
# output/csv\vsg\Yanyin Canon bass switch R.csv
# output/csv\vsg\Yanyin Canon mids switch L.csv
# output/csv\vsg\Yanyin Canon mids switch R.csv
# output/csv\vsg\Yanyin Canon no switches L.csv
# output/csv\vsg\Yanyin Canon no switches R.csv
# output/csv\vsg\Yanyin Canon treble switch L.csv
# output/csv\vsg\Yanyin Canon treble switch R.csv
# output/csv\vsg\Zephone Tiger L.csv
# output/csv\vsg\Zephone Tiger R.csv
# output/csv\wdym\Innerfidelity ID Target.csv
# output/csv\wdym\Precogvision Target.csv
# output/csv\wdym\Rtings Target.csv
# output/csv\wdym\Sonarworks Target.csv
# output/csv\wdym\Sparks (Basshead Tuning) L.csv
# output/csv\wdym\Sparks (Stock Tuning) L.csv
# output/csv\wdym\Super Review Target.csv
# output/csv\wdym\Wdym Target.csv
# output/csv\akros\Innerfidelity ID Target.csv
# output/csv\akros\Precogvision Target.csv
# output/csv\akros\Rtings Target.csv
# output/csv\akros\Sonarworks Target.csv
# output/csv\akros\Super Review Target.csv
# output/csv\akros\Tanchjim Tanya L.csv
# output/csv\akros\test L.csv
# output/csv\data_mrs\Harman Adjusted Target.csv
# output/csv\data_mrs\HBB Comp Target.csv
# output/csv\data_mrs\HPDC 10dB Tilt 5128 DF 100Hz Target.csv
# output/csv\data_mrs\HPDC 10dB Tilt 5128 DF Target.csv
# output/csv\data_mrs\HPDC 10dB Tilt KEMAR DF 100Hz Target.csv
# output/csv\data_mrs\HPDC 10dB Tilt KEMAR DF Target.csv
# output/csv\data_mrs\HPDC 14dB Tilt 5128 DF 100Hz Target.csv
# output/csv\data_mrs\HPDC 14dB Tilt 5128 DF Target.csv
# output/csv\data_mrs\HPDC 14dB Tilt KEMAR DF 100Hz Target.csv
# output/csv\data_mrs\HPDC 14dB Tilt KEMAR DF Target.csv
# output/csv\data_mrs\IEC711 Comp Target.csv
# output/csv\data_mrs\IEF Comp Target.csv
# output/csv\data_mrs\KZ (avg) L.csv
# output/csv\data_mrs\NF Audio NA2+ (balanced tips) L.csv
# output/csv\data_mrs\NF Audio NA2+ (Etype tips) L.csv
# output/csv\data_mrs\NF Audio NA2+ (Tanchjim filter) L.csv
# output/csv\data_mrs\NF Audio NA2+ L.csv
# output/csv\data_mrs\Precogvision Target.csv
# output/csv\data_mrs\RikudouGoku Target.csv
# output/csv\data_mrs\Simgot EN700 Pro (Moondrop) L.csv
# output/csv\data_mrs\Simgot EN700 Pro (Tanchjim) L.csv
# output/csv\data_mrs\Simgot EN700 Pro L.csv
# output/csv\data_mrs\Softears Studio4 L.csv
# output/csv\data_mrs\Softears Studio4 R.csv
# output/csv\data_mrs\Sony IER-NW510N L.csv
# output/csv\data_mrs\Sony MDR-AS800 L.csv
# output/csv\data_mrs\Sony MDR-AS800 R.csv
# output/csv\data_mrs\Sony MH1 L.csv
# output/csv\data_mrs\Sony MH1 R.csv
# output/csv\data_mrs\Status Audio IEM-2X L.csv
# output/csv\data_mrs\Super 21 Target.csv
# output/csv\data_mrs\Super 22 Target.csv
# output/csv\data_mrs\Super Bass Target.csv
# output/csv\data_mrs\Super Review Target.csv
# output/csv\data_mrs\Symphonium Triton L.csv
# output/csv\data_mrs\Symphonium Triton R.csv
# output/csv\data_mrs\Tanchjim Darling (depth 1) L.csv
# output/csv\data_mrs\Tanchjim Darling (depth 2) L.csv
# output/csv\data_mrs\Tanchjim Echo L.csv
# output/csv\data_mrs\Tanchjim Echo R.csv
# output/csv\data_mrs\Tanchjim Hana (Final E) L.csv
# output/csv\data_mrs\Tanchjim Hana (Sedna Light) L.csv
# output/csv\data_mrs\Tanchjim Hana 2021 L.csv
# output/csv\data_mrs\Tanchjim Hana L.csv
# output/csv\data_mrs\Tanchjim Ola (s2 - filterless - taped) L.csv
# output/csv\data_mrs\Tanchjim Ola (s2 - filterless - taped) R.csv
# output/csv\data_mrs\Tanchjim Ola (s2 - filterless) L.csv
# output/csv\data_mrs\Tanchjim Ola (s2 - filterless) R.csv
# output/csv\data_mrs\Tanchjim Ola (vent Blu Tack) L.csv
# output/csv\data_mrs\Tanchjim Ola (vent Tanchjim filter) L.csv
# output/csv\data_mrs\Tanchjim Ola L.csv
# output/csv\data_mrs\Tanchjim Ola R.csv
# output/csv\data_mrs\Tanchjim Oxygen L.csv
# output/csv\data_mrs\Tanchjim Prism (treble tips) L.csv
# output/csv\data_mrs\Tanchjim Prism (treble tips) R.csv
# output/csv\data_mrs\Tanchjim Prism L.csv
# output/csv\data_mrs\Tanchjim Prism R.csv
# output/csv\data_mrs\Tanchjim Tanya L.csv
# output/csv\data_mrs\Tanchjim Zero L.csv
# output/csv\data_mrs\Tanchjim Zero R.csv
# output/csv\data_mrs\Tangzu Waner L.csv
# output/csv\data_mrs\Tangzu Waner R.csv
# output/csv\data_mrs\Tangzu Wu Heyday L.csv
# output/csv\data_mrs\Tangzu Wu Heyday R.csv
# output/csv\data_mrs\Tangzu Ze Tian Wu L.csv
# output/csv\data_mrs\Tangzu Ze Tian Wu R.csv
# output/csv\data_mrs\Tansio Mirai Spark (010) L.csv
# output/csv\data_mrs\Tansio Mirai Spark (110) L.csv
# output/csv\data_mrs\Tansio Mirai Spark (111) L.csv
# output/csv\data_mrs\Tenhz 3BA L.csv
# output/csv\data_mrs\Tenhz P4 Pro L.csv
# output/csv\data_mrs\TFZ No.3 L.csv
# output/csv\data_mrs\ThieAudio Legacy 2 L.csv
# output/csv\data_mrs\ThieAudio Legacy 4 (Spring) L.csv
# output/csv\data_mrs\ThieAudio Legacy 4 (Spring) R.csv
# output/csv\data_mrs\ThieAudio Legacy 4 (switch on) L.csv
# output/csv\data_mrs\ThieAudio Legacy 4 L.csv
# output/csv\data_mrs\ThieAudio Legacy 4 R.csv
# output/csv\data_mrs\ThieAudio Legacy 5 (126 ohm) L.csv
# output/csv\data_mrs\ThieAudio Legacy 5 (15 ohm) L.csv
# output/csv\data_mrs\ThieAudio Legacy 5 (36 ohm) L.csv
# output/csv\data_mrs\ThieAudio Legacy 5 (75 ohm) L.csv
# output/csv\data_mrs\ThieAudio Legacy 5 (S1 seized) L.csv
# output/csv\data_mrs\ThieAudio Legacy 5 (S1) L.csv
# output/csv\data_mrs\ThieAudio Legacy 5 (S2 15ohm) L.csv
# output/csv\data_mrs\ThieAudio Legacy 5 (S2) L.csv
# output/csv\data_mrs\ThieAudio Legacy 5 (S2) R.csv
# output/csv\data_mrs\ThieAudio Legacy 5 L.csv
# output/csv\data_mrs\ThieAudio Legacy 5 R.csv
# output/csv\data_mrs\Thinksound Rain3 L.csv
# output/csv\data_mrs\Thinksound Rain3 R.csv
# output/csv\data_mrs\Tin Hifi C2 Mech Warrior L.csv
# output/csv\data_mrs\Tin Hifi C2 Mech Warrior R.csv
# output/csv\data_mrs\Tin Hifi C3 L.csv
# output/csv\data_mrs\Tin Hifi C3 R.csv
# output/csv\data_mrs\Tin Hifi C5 L.csv
# output/csv\data_mrs\Tin Hifi C5 R.csv
# output/csv\data_mrs\Tin Hifi T4 L.csv
# output/csv\data_mrs\Tin Hifi T4 Plus L.csv
# output/csv\data_mrs\Tin Hifi T4 Plus R.csv
# output/csv\data_mrs\Tin Hifi T5 (Comply Waxguard) L.csv
# output/csv\data_mrs\Tin Hifi T5 L.csv
# output/csv\data_mrs\Tin Hifi Tin Buds 3 L.csv
# output/csv\data_mrs\Tin Hifi Tin Buds 3 R.csv
# output/csv\data_mrs\Tripowin Cencibel L.csv
# output/csv\data_mrs\Tripowin Cencibel R.csv
# output/csv\data_mrs\Tripowin Lea L.csv
# output/csv\data_mrs\Tripowin Lea R.csv
# output/csv\data_mrs\Tripowin Mele L.csv
# output/csv\data_mrs\Tripowin Mele R.csv
# output/csv\data_mrs\Tripowin Rhombus L.csv
# output/csv\data_mrs\Tripowin Rhombus R.csv
# output/csv\data_mrs\TRN IM1 L.csv
# output/csv\data_mrs\TRN V30 L.csv
# output/csv\data_mrs\TRN V90 L.csv
# output/csv\data_mrs\Truthear Hola L.csv
# output/csv\data_mrs\Truthear Hola R.csv
# output/csv\data_mrs\Ucotech RE-2 L.csv
# output/csv\data_mrs\Ucotech RE-2 R.csv
# output/csv\data_mrs\Unique Melody MEST L.csv
# output/csv\data_mrs\Unique Melody MEST mkII L.csv
# output/csv\data_mrs\Unique Melody MEST mkII R.csv
# output/csv\data_mrs\Unique Melody MEST R.csv
# output/csv\data_mrs\Vision Ears VE7 L.csv
# output/csv\data_mrs\Vision Ears VE7 R.csv
# output/csv\data_mrs\Vision Ears VE8 L.csv
# output/csv\data_mrs\Vsonic GR07 (Bass) L.csv
# output/csv\data_mrs\Vsonic GR07 L.csv
# output/csv\data_mrs\Vsonic GR07 R.csv
# output/csv\data_mrs\Whizzer Kylin L.csv
# output/csv\data_mrs\Working 001 Target.csv
# output/csv\data_mrs\Working 002 Target.csv
# output/csv\data_mrs\Xenns Mangird Tea 2 (S2) L.csv
# output/csv\data_mrs\Xenns Mangird Tea 2 (S2) R.csv
# output/csv\data_mrs\Xenns Mangird Tea 2 L.csv
# output/csv\data_mrs\Xenns Mangird Tea 2 R.csv
# output/csv\data_mrs\Xenns Mangird Tea L.csv
# output/csv\data_mrs\Yanyin Mahina L.csv
# output/csv\data_mrs\Yanyin Mahina R.csv
# output/csv\data_mrs\Yinfu MD51 L.csv
# output/csv\data_mrs\Yinyoo V2 L.csv

# %%
# Create a dataframe from the list of dictionaries
iem_dicts_df = pd.DataFrame(iem_dicts)

# %%
iem_dicts_df
# Out:
#                           IEM  \
# 0             1Custom Apex Ti
# 1                1Custom PM01
# 2           1MORE ColorBuds 2
# 3         1MORE ComfoBuds Pro
# 4                   1MORE Evo
# ...                       ...
# 1261  Xingshenglong DIY E3000
# 1262  Xingshenglong DIY E4000
# 1263            XINHS Erasmus
# 1264             Yanyin Canon
# 1265          YU9 Audio U-556
#
#                                                   Files
# 0     [output/csv\recode\apexti L.csv, output/csv\re...
# 1     [output/csv\hobbytalk\1 Custom PM-01 L.csv, ou...
# 2     [output/csv\vsg\1MORE ColorBuds 2 L.csv, outpu...
# 3     [output/csv\eplv\1More ComfoBudsPro L.csv, out...
# 4     [output/csv\vsg\1MORE EVO L.csv, output/csv\vs...
# ...                                                 ...
# 1261  [output/csv\eplv\DIY E3000 L.csv, output/csv\e...
# 1262  [output/csv\eplv\DIY E4000 L.csv, output/csv\e...
# 1263  [output/csv\harpo\Erasmus 00 R.csv, output/csv...
# 1264                     [output/csv\tgx78\Canon L.csv]
# 1265  [output/csv\kr0mka\556 L.csv, output/csv\kr0mk...
#
# [1266 rows x 2 columns]

# %%
iem_dicts_df.to_csv('output/iem_dicts.csv', index=False)
