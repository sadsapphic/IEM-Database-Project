# %%
import os
from collections import defaultdict
from fuzzywuzzy import fuzz
import re
import pandas as pd

# %%
# List of reviewers
reviewers = [
    'achoreviews',
    'aftersound',
    'animagus',
    'arn',
    'bedrock',
    'bryaudioreviews',
    'cammyfi',
    'soundjedi',
    'eplv',
    'timmyv',
    'harpo',
    'hbb',
    'cqtek',
    'hobbytalk',
    'ianfann',
    'iemworld',
    'jacstone',
    'kr0mka',
    'kurin',
    'melatonin',
    'nymz', 
    'pw',
    'recode',
    'rg',
    'shortbus',
    'suporsalad',
    'tgx78',
    'vortexreviews',
    'vsg',
    'wdym',
    'akros',
    'data_mrs'
]

# %%
def remove_channel_suffix(file_name):
    file_name = file_name.lower()
    file_name = re.sub(r'\(.*?\)', '', file_name)  # Remove content in brackets
    file_name = file_name.strip()  # Remove leading and trailing spaces

    if " l.csv" in file_name:
        file_name = file_name.replace(" l.csv", ".csv")
    elif " r.csv" in file_name:
        file_name = file_name.replace(" r.csv", ".csv")

    return file_name.strip()  # Remove any extra spaces after channel suffix removal

# %%
def group_files_by_iem(files, threshold=100):
    groups = defaultdict(list)
    added_files = set()

    # Create a special "target" group
    target_group = "target"

    for file1 in files:
        modified_file1 = remove_channel_suffix(file1)

        # Check if the file name contains "target"
        if "target" in file1.lower():
            if file1 not in added_files:
                groups[target_group].append(file1)
                added_files.add(file1)
            continue

        if file1 not in added_files:
            groups[file1].append(file1)
            added_files.add(file1)

        for file2 in files:
            if file2 not in added_files:
                modified_file2 = remove_channel_suffix(file2)
                similarity = fuzz.token_set_ratio(modified_file1, modified_file2)

                # If the similarity score is above the threshold, add the file to the group
                if similarity >= threshold:
                    groups[file1].append(file2)
                    added_files.add(file2)
                # If the similarity score is between 95 and the threshold, compare only the IEM part
                elif 99 <= similarity < threshold:
                    iem1 = re.sub(r'[^a-zA-Z0-9]', '', modified_file1.split()[1]) if len(modified_file1.split()) > 1 else ''
                    iem2 = re.sub(r'[^a-zA-Z0-9]', '', modified_file2.split()[1]) if len(modified_file2.split()) > 1 else ''
                    iem_similarity = fuzz.token_set_ratio(iem1, iem2)
                    
                    if iem_similarity >= threshold:
                        groups[file1].append(file2)
                        added_files.add(file2)

    return groups

# %%
# Gather all file names
all_files = []

# %%
for reviewer in reviewers:
    reviewer_path = f'output/csv/{reviewer}'

    if os.path.exists(reviewer_path):
        files = os.listdir(reviewer_path)
        all_files.extend([(reviewer, file) for file in files])

# %%
# Group files by IEM
grouped_files = group_files_by_iem([file for _, file in all_files])

# %%
print(f"Total number of files: {len(all_files)}")
print(f"Total number of groups: {len(grouped_files)}")
print(f"Total number of files in groups: {sum([len(files) for files in grouped_files.values()])}")
print(f"Total number of files not in groups: {len(all_files) - sum([len(files) for files in grouped_files.values()])}")
print(f"\nAvg number of files per group: {sum([len(files) for files in grouped_files.values()]) / len(grouped_files)}")
# Out:
# Total number of files: 9882
# Total number of groups: 2356
# Total number of files in groups: 7668
# Total number of files not in groups: 2214
#
# Avg number of files per group: 3.2546689303904923

# %%
# Print grouped files
for representative, files in grouped_files.items():
    print(f"{representative}:")
    for file in files:
        reviewers_with_file = [reviewer for reviewer, f in all_files if f == file]
        print(f"  {file} - {', '.join(reviewers_with_file)}")
    print()
# Out:
# 7Hz Dioko L.csv:
#   7Hz Dioko L.csv - achoreviews, bedrock, timmyv, iemworld, data_mrs
#   7HZ SALNOTES DIOKO L.csv - aftersound
#   7HZ SALNOTES DIOKO R.csv - aftersound
#   7Hz Salnotes Dioko L.csv - arn, pw
#   7Hz Dioko R.csv - bedrock, timmyv, hbb, iemworld, data_mrs
#   7hz Dioko L.csv - hobbytalk
#   7hz Dioko R.csv - hobbytalk
#   7HZ DIOKO (bass mod) L.csv - ianfann
#   7HZ DIOKO (bass mod) R.csv - ianfann
#   7HZ DIOKO L.csv - ianfann
#   7HZ DIOKO R.csv - ianfann
#   Dioko L.csv - kr0mka
#   Dioko R.csv - kr0mka
#   Resolve 7Hz Salnotes Dioko Gras L.csv - kurin
#   7hz Salnotes Dioko L.csv - nymz
#   7hz Salnotes Dioko R.csv - nymz
#   7Hz Salnotes Dioko R.csv - pw
#   7Hz Salnotes Dioko TapedVent L.csv - pw
#   7hz x Crinacle Dioko L.csv - vortexreviews
#   7hz x Crinacle Dioko R.csv - vortexreviews
#   7hz x Crinacle Dioko Updated L.csv - vortexreviews
#   7hz x Crinacle Dioko Updated R.csv - vortexreviews
#   7Hz x Crinacle Salnotes Dioko L.csv - vsg
#   7Hz x Crinacle Salnotes Dioko R.csv - vsg
#   7Hz Dioko (post-op) L.csv - data_mrs
#   7Hz Dioko (post-op) R.csv - data_mrs
#   7Hz Dioko (pre-op) L.csv - data_mrs
#   7Hz Dioko (pre-op) R.csv - data_mrs
#
# 7Hz Eternal L.csv:
#   7Hz Eternal L.csv - achoreviews, bedrock, vsg
#   7Hz Eternal R.csv - bedrock, harpo, hbb, vsg
#   7Hz ETERNAL L.csv - iemworld
#   7Hz ETERNAL R.csv - iemworld
#   7hz Eternal L.csv - vortexreviews
#   7hz Eternal R.csv - vortexreviews
#
# 7Hz Legato L.csv:
#   7Hz Legato L.csv - achoreviews, timmyv, cqtek, vsg
#   7HZ LEGATO L.csv - aftersound, ianfann
#   7HZ LEGATO R.csv - aftersound, ianfann
#   7Hz Legato R.csv - timmyv, hbb, cqtek, vsg
#   7hz LEGATO L.csv - nymz
#   7hz LEGATO R.csv - nymz
#   7hz Legato (250 mesh) L.csv - rg
#   7hz Legato (3 outer vent blutack) L.csv - rg
#   7hz Legato (500 mesh) L.csv - rg
#   7hz Legato (inner vent blutack) L.csv - rg
#   7hz Legato L.csv - rg, vortexreviews
#   7hz Legato R.csv - rg, vortexreviews
#
# 7Hz Timeless L.csv:
#   7Hz Timeless L.csv - achoreviews, arn, soundjedi, timmyv, pw, rg, vsg, data_mrs
#   7HZ TIMELESS AE L.csv - aftersound, ianfann
#   7HZ TIMELESS AE R.csv - aftersound, ianfann
#   7HZ TIMELESS L.csv - aftersound
#   7HZ TIMELESS R.csv - aftersound
#   7HZ TIMELESS S2 L.csv - aftersound
#   7HZ TIMELESS S2 R.csv - aftersound
#   7Hz Timeless R.csv - soundjedi, timmyv, harpo, pw, rg, vsg, data_mrs
#   7Hz Timeless AE L.csv - timmyv
#   7Hz Timeless AE R.csv - timmyv, hbb
#   7Hz Timeless (no filter) R.csv - hbb
#   7hz Timeless L.csv - hobbytalk, tgx78, vortexreviews
#   7hz Timeless R.csv - hobbytalk, tgx78, vortexreviews
#   7hz Timeless Tape Mod L.csv - hobbytalk
#   7hz Timeless Tape Mod R.csv - hobbytalk
#   7HZ TIMELESS OG L.csv - ianfann
#   7HZ TIMELESS OG R.csv - ianfann
#   7Hz Timeless (FINAL Tips) L.csv - iemworld
#   7Hz Timeless (FINAL Tips) R.csv - iemworld
#   7Hz Timeless (Foam Tips) L.csv - iemworld
#   7Hz Timeless (Foam Tips) R.csv - iemworld
#   7Hz Timeless (MoonDroop Tips) L.csv - iemworld
#   7Hz Timeless (MoonDroop Tips) R.csv - iemworld
#   Timeless L.csv - kr0mka
#   Timeless R.csv - kr0mka
#   Oratory 7Hz Timeless L.csv - kurin
#   7hz Timeless AE L.csv - nymz
#   7hz Timeless AE R.csv - nymz
#   7Hz Timeless S2 25ohm R.csv - pw
#   7Hz Timeless S2 75ohm R.csv - pw
#   7Hz Timeless S2 L.csv - pw
#   7Hz Timeless S2 MPBack L.csv - pw
#   7Hz Timeless S2 MPFront L.csv - pw
#   7Hz Timeless S2 R.csv - pw
#   7Hz Timeless (350 Mesh, stock tuning foam sideways, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (350 Mesh, stock tuning foam, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (Sony Import Foam) L.csv - rg
#   7Hz Timeless (Sony Import Foam, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (Tanchjim Filter, stock tuning foam sideways, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (S2) L.csv - data_mrs
#   7Hz Timeless (S2) R.csv - data_mrs
#
# 7Hz Zero L.csv:
#   7Hz Zero L.csv - achoreviews, bedrock, timmyv, data_mrs
#   7HZ SALNOTES ZERO L.csv - aftersound
#   7HZ SALNOTES ZERO R.csv - aftersound
#   7Hz Salnotes Zero L.csv - arn, pw
#   7Hz Zero R.csv - bedrock, timmyv, data_mrs
#   7Hz Salnotes Zero R.csv - harpo, pw
#   7hz Zero R.csv - hbb, hobbytalk
#   7hz Zero L.csv - hobbytalk
#   7hz Zero Tape L.csv - hobbytalk
#   7hz Zero Tape R.csv - hobbytalk
#   7HZ ZERO L.csv - ianfann
#   7HZ ZERO MECHA L.csv - ianfann
#   7HZ ZERO MECHA R.csv - ianfann
#   7HZ ZERO R.csv - ianfann
#   7hz Zero (EJ07 FOAM Eartips) L.csv - iemworld
#   7hz Zero (EJ07 FOAM Eartips) R.csv - iemworld
#   7hz Zero (Final Eartips) L.csv - iemworld
#   7hz Zero (Final Eartips) R.csv - iemworld
#   7hz Zero (MoonDrop Eartips) L.csv - iemworld
#   7hz Zero (MoonDrop Eartips) R.csv - iemworld
#   7hz Zero (Red Orignal Eartips) L.csv - iemworld
#   7hz Zero (Red Orignal Eartips) R.csv - iemworld
#   7Hz ZERO S1 L.csv - jacstone
#   7Hz ZERO S1 R.csv - jacstone
#   Oratory 7Hz Salnotes Zero L.csv - kurin
#   Resolve 7hz salnotes zero Gras L.csv - kurin
#   7hz Salnotes Zero L.csv - nymz, vortexreviews
#   7hz Salnotes Zero R.csv - nymz, vortexreviews
#   7hz Salnotes Zero S2 L.csv - nymz
#   7hz Salnotes Zero S2 R.csv - nymz
#   7Hz Salnotes Zero NoGrill L.csv - pw
#   7Hz Salnotes Zero Tape 500Damper R.csv - pw
#   7Hz Salnotes Zero Tape R.csv - pw
#   7Hz Salnotes Zero v2 L.csv - pw
#   7Hz Salnotes Zero v2 R.csv - pw
#   zero L.csv - recode
#   zero R.csv - recode
#
# target:
#   Acho Reviews Target.csv - achoreviews
#   Antdroid Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Bad Guy Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Banbeucmas Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Crinacle Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, timmyv, harpo, hbb, cqtek, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, shortbus, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Diffuse Field Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Etymotic Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Free Field Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Harman Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, iemworld, melatonin, nymz, pw, recode, shortbus, suporsalad, tgx78, vortexreviews, wdym, akros, data_mrs
#   Innerfidelity ID Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Precogvision Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Rtings Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Sonarworks Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Super Review Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   IEF neutral Target.csv - aftersound
#   Innerfidelity Target.csv - aftersound
#   Animagus Neutral Target.csv - animagus
#   Animagus Preference Target.csv - animagus
#   Harman In Ear 2019 Target.csv - animagus
#   Harman In Room Target.csv - animagus
#   Harman Over Ear 2018 Target.csv - animagus
#   Harman V2 Target.csv - arn
#   Bry Audio Reviews Target.csv - bryaudioreviews
#   Harman 2017 Target.csv - bryaudioreviews, ianfann
#   Harman 2019 Target.csv - bryaudioreviews, ianfann, jacstone
#   Oratory1990 Target.csv - bryaudioreviews, pw, vortexreviews
#   CammyFi Neutral Target.csv - cammyfi
#   CammyFi Target.csv - cammyfi, kurin
#   Harman IE 2019 v2 Target.csv - cammyfi, kr0mka, kurin
#   Kurin Target.csv - cammyfi, kurin
#   AutoEQ Target.csv - eplv, pw
#   Harman2019v2 Target.csv - eplv
#   Old Crinacle Target.csv - eplv
#   Nymz Target.csv - timmyv
#   Timmy Target.csv - timmyv, kurin
#   AX Target.csv - harpo
#   Bad Guy 2022 Target.csv - harpo, hbb, kurin
#   EJ Target.csv - harpo
#   Harpo Target.csv - harpo, rg
#   Harpo v3 Target.csv - harpo
#   Harpo v4 Target (11.03.2023 02-43-36).csv - harpo
#   Harpo v4 Target.csv - harpo
#   Harpo_v2 Target.csv - harpo
#   RikudouGoku Target.csv - harpo, hbb, jacstone, kurin, nymz, pw, rg, tgx78, vortexreviews, data_mrs
#   Softears Target.csv - harpo
#   X Target.csv - harpo
#   Bad Guy Target v2.csv - hbb
#   IEF Target.csv - hbb, ianfann
#   MRS Target.csv - hbb
#   Precog Target.csv - hbb, kurin
#   Precog_broken Target.csv - hbb
#   Redeyes Target.csv - hbb, kurin, pw
#   Harman IE 2019 Target.csv - hobbytalk
#   Hobby Talk Flat Target.csv - hobbytalk
#   Hobby Talk Preference Target OG.csv - hobbytalk
#   Hobby Talk Preference Target.csv - hobbytalk, kurin
#   Honest Target.csv - hobbytalk
#   IEF OE Target.csv - hobbytalk
#   IanFann-Target Target.csv - ianfann
#   IEF Target1.csv - ianfann
#   IEM WORLD Target.csv - iemworld
#   nymz Target.csv - jacstone, nymz, rg
#   Paul Wasabii Target.csv - jacstone
#   Sharur Target.csv - jacstone, kurin
#   Harman IE 2016 Target.csv - kr0mka, kurin
#   Harman IE 2017 v2 Target.csv - kr0mka
#   kr0mka Target.csv - kr0mka
#   Coda Target.csv - kurin
#   Comfy Target.csv - kurin
#   Flat Target.csv - kurin
#   Freeryder05v2 Target.csv - kurin
#   Hobby Talk Target.csv - kurin
#   markanini Target.csv - kurin
#   Moondrop Target.csv - kurin
#   Normative Target.csv - kurin
#   Objectively Neutral IE Target.csv - kurin
#   Olive-Welti Harman Bass Target.csv - kurin
#   Olive-Welti Target.csv - kurin
#   Oratory IE Target.csv - kurin
#   Rikudogoku Target.csv - kurin
#   SEAP Target.csv - kurin
#   Srg0mes Target.csv - kurin
#   Super 22 Target.csv - kurin, data_mrs
#   Harman 2019v2 Target.csv - nymz, pw, rg
#   RikudouGoku_Target.csv - nymz
#   tgx78 Target.csv - nymz, rg
#   Crackhead Target.csv - pw, rg
#   PaulWasabii Target.csv - pw
#   Crinacle Neutral Target.csv - recode, data_mrs
#   Harman 2017v2 Target.csv - recode, rg
#   Recode Neutral Target.csv - recode
#   Recode Target.csv - recode
#   Recode Warm Neutral Target.csv - recode
#   target 8.csv - recode
#   ALPHA 1.0 Target.csv - rg
#   Amelie Target.csv - rg
#   DynamicEars Target.csv - rg
#   evasb Target.csv - rg
#   Lixeem Target.csv - rg
#   PW Target.csv - rg
#   Resolution Target.csv - rg
#   stakk Target.csv - rg
#   Super Bass Target.csv - rg, data_mrs
#   Super Review 2021 Target.csv - rg
#   Super Review 2022 Target.csv - rg
#   Talbot Target.csv - rg
#   TKSilver Target.csv - rg
#   Redeyes 1 Target.csv - shortbus
#   DF Tilt 711 Ref Target.csv - suporsalad
#   Harman IEM Target.csv - suporsalad
#   Harman OE Target.csv - suporsalad
#   Kemar DF 1.3 Bass Target.csv - suporsalad
#   Kemar DF 1.3 Target.csv - suporsalad
#   Kemar DF Target.csv - suporsalad
#   Listener Target.csv - suporsalad
#   USound1V1 Oratory 1990 Target.csv - suporsalad
#   Tgx78 Target.csv - tgx78
#   Harman 2018 Over-Ear Target.csv - vsg
#   Harman 2019 In-Ear Target.csv - vsg
#   Harman Combined Over-Ear Target.csv - vsg
#   Harman In-Ear Target.csv - vsg
#   VSG Target.csv - vsg
#   Wdym Target.csv - wdym
#   Crinacle 2023 Adjusted Target.csv - data_mrs
#   Crinacle Adjusted Target.csv - data_mrs
#   Crinacle Neutral 2023 Target.csv - data_mrs
#   Dent Target.csv - data_mrs
#   dentReviews Target.csv - data_mrs
#   Ghost Target.csv - data_mrs
#   Harman Adjusted Target.csv - data_mrs
#   HBB Comp Target.csv - data_mrs
#   HPDC 10dB Tilt 5128 DF 100Hz Target.csv - data_mrs
#   HPDC 10dB Tilt 5128 DF Target.csv - data_mrs
#   HPDC 10dB Tilt KEMAR DF 100Hz Target.csv - data_mrs
#   HPDC 10dB Tilt KEMAR DF Target.csv - data_mrs
#   HPDC 14dB Tilt 5128 DF 100Hz Target.csv - data_mrs
#   HPDC 14dB Tilt 5128 DF Target.csv - data_mrs
#   HPDC 14dB Tilt KEMAR DF 100Hz Target.csv - data_mrs
#   HPDC 14dB Tilt KEMAR DF Target.csv - data_mrs
#   IEC711 Comp Target.csv - data_mrs
#   IEF Comp Target.csv - data_mrs
#   Super 21 Target.csv - data_mrs
#   Working 001 Target.csv - data_mrs
#   Working 002 Target.csv - data_mrs
#
# Audeze iSine LX (Spinfit) L.csv:
#   Audeze iSine LX (Spinfit) L.csv - achoreviews
#
# Aune Jasper L.csv:
#   Aune Jasper L.csv - achoreviews, data_mrs
#   AUNE JASPER L.csv - aftersound
#   AUNE JASPER R.csv - aftersound
#   Aune Jasper R.csv - hbb, data_mrs
#   Aune Jasper (Tanchjim filter) L.csv - data_mrs
#   Aune Jasper (Tanchjim filter) R.csv - data_mrs
#
# Blon BL01 L.csv:
#   Blon BL01 L.csv - achoreviews
#   BLON BL01 L.csv - bryaudioreviews, pw
#   BLON BL01 R.csv - bryaudioreviews
#
# Blon BL03 L.csv:
#   Blon BL03 L.csv - achoreviews, timmyv, suporsalad, data_mrs
#   BLON BL03 R.csv - aftersound, bryaudioreviews, ianfann
#   BLON BL03 L.csv - bryaudioreviews, ianfann
#   Blon BL03 R.csv - timmyv, suporsalad
#   BLON BL03 Filter L.csv - pw
#   BLON BL03 Stock L.csv - pw
#
# Blon BL05s L.csv:
#   Blon BL05s L.csv - achoreviews
#   BLON BL05S L.csv - pw
#
# Blon Fat Girl L.csv:
#   Blon Fat Girl L.csv - achoreviews, vortexreviews
#   BLON FAT GIRL L.csv - aftersound, ianfann
#   BLON FAT GIRL R.csv - aftersound, ianfann
#   BLON Fat Girl R.csv - hbb, jacstone, pw
#   BLON Fat Girl L.csv - jacstone, pw
#   Blon Fat Girl R.csv - vortexreviews
#
# Blon T1 L.csv:
#   Blon T1 L.csv - achoreviews
#
# Blon T3 L.csv:
#   Blon T3 L.csv - achoreviews
#
# Blon Z200 L.csv:
#   Blon Z200 L.csv - achoreviews, harpo, vortexreviews
#   BLON Z200 L.csv - arn, ianfann, pw
#   Blon Z200 R.csv - harpo, vortexreviews
#   BLON Z200 R.csv - ianfann, pw
#
# CCA CRA L.csv:
#   CCA CRA L.csv - achoreviews, aftersound, eplv, hobbytalk, ianfann, jacstone, melatonin, nymz, pw, rg, suporsalad, tgx78, vortexreviews, data_mrs
#   CCA CRA Plus L.csv - achoreviews, timmyv, pw, data_mrs
#   CCA CRA R.csv - aftersound, eplv, harpo, hbb, hobbytalk, ianfann, jacstone, melatonin, nymz, pw, rg, suporsalad, data_mrs
#   CCA CRA S2 L.csv - aftersound, nymz, rg, tgx78
#   CCA CRA S2 R.csv - aftersound, nymz, rg, tgx78
#   CCA CRA+ L.csv - aftersound, bedrock, ianfann, jacstone, melatonin, nymz, rg, vortexreviews
#   CCA CRA+ R.csv - aftersound, bedrock, ianfann, jacstone, melatonin, nymz, rg, vortexreviews
#   CCA CRA Plus R.csv - timmyv, data_mrs
#   CCA CRA + R.csv - hbb
#   CCA CRA+ (STOCK TIPS) L.csv - ianfann
#   CCA CRA+ (STOCK TIPS) R.csv - ianfann
#   CRA L.csv - kr0mka
#   CRA R.csv - kr0mka
#   CCA CRA EQ3 R.csv - nymz
#   CCA CRA Plus Tape L.csv - pw
#   CCA CRA Plus Vent L.csv - pw
#   CCA CRA Plus Vent R.csv - pw
#   CCA CRA (1dividedby4 Foam) L.csv - rg
#   CCA CRA (1dividedby8 Foam) L.csv - rg
#   CCA CRA (200 Mesh) L.csv - rg
#   CCA CRA (350 Mesh) L.csv - rg
#   CCA CRA (500 Mesh + 200 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 250 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 300 Paper Filter + High-Density Tuning Foam) L.csv - rg
#   CCA CRA (500 Mesh + 300 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 350 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 500 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + High-Density Tuning Foam) L.csv - rg
#   CCA CRA (500 Mesh + Sony General Foam) L.csv - rg
#   CCA CRA (500 Mesh + Y1 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + Y3 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + Y6 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh) L.csv - rg
#   CCA CRA (Filterless + 2 High-Density Tuning Foams) L.csv - rg
#   CCA CRA (Filterless + High-Density Tuning Foams) L.csv - rg
#   CCA CRA (Filterless) L.csv - rg
#   CCA CRA (Nylon filter) L.csv - rg
#   CCA CRA (Sony General Foam) L.csv - rg
#   CCA CRA (Sony Import Foam) L.csv - rg
#   CCA CRA (Tanchjim Filter) L.csv - rg
#   CCA CRA+ (Stock Filter + 350 Mesh) L.csv - rg
#   CCA CRA EQ L.csv - tgx78
#   CCA CRA Mod R.csv - tgx78
#
# CCZ Emerald L.csv:
#   CCZ Emerald L.csv - achoreviews, eplv
#   CCZ EMERALD L.csv - aftersound
#   CCZ EMERALD R.csv - aftersound
#   CCZ Emerald R.csv - eplv
#   CCZ emerald L.csv - melatonin
#   CCZ emerald R.csv - melatonin
#
# CCZ Melody L.csv:
#   CCZ Melody L.csv - achoreviews, pw, vortexreviews
#   CCZ MELODY L.csv - aftersound, ianfann
#   CCZ MELODY R.csv - aftersound, ianfann
#   CCZ Melody R.csv - harpo
#   CCZ melody L.csv - melatonin
#   CCZ melody R.csv - melatonin
#
# CCZ Warrior L.csv:
#   CCZ Warrior L.csv - achoreviews, arn, pw
#   CCZ WARRIOR L.csv - ianfann
#   CCZ WARRIOR R.csv - ianfann
#   CCZ Warrior R.csv - pw
#
# Celest Pandamon L.csv:
#   Celest Pandamon L.csv - achoreviews
#   Kinera Celest Pandamon L.csv - arn, cqtek, vortexreviews
#   Kinera Celest Pandamon R.csv - arn, cqtek, vortexreviews
#
# Dunu Kima L.csv:
#   Dunu Kima L.csv - achoreviews, bedrock, timmyv, cqtek, vortexreviews, data_mrs
#   DUNU KIMA L.csv - aftersound, ianfann, nymz, vsg
#   DUNU KIMA R.csv - aftersound, ianfann, nymz, vsg
#   Dunu Kima R.csv - bedrock, timmyv, hbb, cqtek, vortexreviews, data_mrs
#
# Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv:
#   Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv - achoreviews
#   Dunu Talos (Planar + BA) L.csv - achoreviews
#   Dunu Talos (Planar Only) (IE600 Foam Tips) L.csv - achoreviews
#   Dunu Talos (Planar Only) L.csv - achoreviews
#   DUNU TALOS OFF L.csv - aftersound
#   DUNU TALOS OFF R.csv - aftersound
#   DUNU TALOS ON L.csv - aftersound
#   DUNU TALOS ON R.csv - aftersound
#   Dunu Talos (ON) L.csv - animagus
#   Dunu Talos (ON) R.csv - animagus
#   Dunu Talos L.csv - animagus, data_mrs
#   Dunu Talos R.csv - animagus, hbb, data_mrs
#   DUNU Talos Planar L.csv - arn
#   DUNU Talos Planar+BA L.csv - arn
#   Dunu Talos (Switch Off) L.csv - bedrock
#   Dunu Talos (Switch Off) R.csv - bedrock
#   Dunu Talos (Switch On) L.csv - bedrock
#   Dunu Talos (Switch On) R.csv - bedrock
#   Dunu Talos (Hybrid) L.csv - timmyv
#   Dunu Talos (Hybrid) R.csv - timmyv
#   Dunu Talos (Planar) L.csv - timmyv
#   Dunu Talos (Planar) R.csv - timmyv
#   Dunu Talos BA R.csv - hbb
#   DUNU TALOS PLANAR MODE L.csv - ianfann
#   DUNU TALOS PLANAR MODE R.csv - ianfann
#   DUNU TALOS PLANAR+BA L.csv - ianfann
#   DUNU TALOS PLANAR+BA R.csv - ianfann
#   DUNU TALOS Hybrid L.csv - nymz, vsg
#   DUNU TALOS Hybrid R.csv - nymz, vsg
#   DUNU TALOS L.csv - nymz
#   DUNU TALOS R.csv - nymz
#   DUNU Talos L.csv - pw
#   DUNU Talos R.csv - pw
#   DUNU TALOS Hybrid mode L.csv - vsg
#   DUNU TALOS Hybrid mode R.csv - vsg
#   DUNU TALOS Planar L.csv - vsg
#   DUNU TALOS Planar mode L.csv - vsg
#   DUNU TALOS Planar mode R.csv - vsg
#   DUNU TALOS Planar R.csv - vsg
#   Dunu Talos (on) L.csv - data_mrs
#   Dunu Talos (on) R.csv - data_mrs
#   Dunu Talos (S2 off) L.csv - data_mrs
#   Dunu Talos (S2 off) R.csv - data_mrs
#   Dunu Talos (S2 on) L.csv - data_mrs
#   Dunu Talos (S2 on) R.csv - data_mrs
#
# Dunu Titan S (Isolation) L.csv:
#   Dunu Titan S (Isolation) L.csv - achoreviews
#   Dunu Titan S L.csv - achoreviews, bedrock, bryaudioreviews, timmyv, cqtek, nymz, rg, vortexreviews
#   DUNU TITAN S L.csv - aftersound, ianfann, iemworld, vsg
#   DUNU TITAN S R.csv - aftersound, ianfann, iemworld, vsg
#   DUNU Titan S L.csv - arn
#   DUNU Titan S R.csv - arn
#   Dunu Titan S R.csv - bedrock, bryaudioreviews, timmyv, hbb, cqtek, nymz, rg
#   Resolve Dunu Titan S Foam Gras L.csv - kurin
#   Resolve Dunu Titan S Foam Silicone L.csv - kurin
#   DUNU Titan L.csv - pw
#   DUNU Titan R.csv - pw
#   Dunu Titan S (500 Mesh) L.csv - rg
#   Dunu Titan S (Tanchjim Filter) L.csv - rg
#   Dunu Titan S (Y3 Paper Filter) L.csv - rg
#   Dunu Titan S (Y6 Paper Filter) L.csv - rg
#   DUNU TITAN S pre-production L.csv - vsg
#   DUNU TITAN S pre-production R.csv - vsg
#   Dunu Titan S (pre) L.csv - data_mrs
#   Dunu Titan S (pre) R.csv - data_mrs
#
# Dunu Vulkan L.csv:
#   Dunu Vulkan L.csv - achoreviews, bedrock, timmyv, harpo, data_mrs
#   Dunu Vulkan R.csv - bedrock, timmyv, harpo, hbb, data_mrs
#   DUNU Vulkan L.csv - nymz
#   DUNU Vulkan R.csv - nymz
#   Dunu VULKAN L.csv - rg
#   Dunu VULKAN R.csv - rg
#   DUNU VULKAN L.csv - vsg
#   DUNU VULKAN R.csv - vsg
#   Dunu Vulkan (S2 + red) R.csv - data_mrs
#   Dunu Vulkan (S2) L.csv - data_mrs
#   Dunu Vulkan (S2) R.csv - data_mrs
#
# Effect Audio Axiom L.csv:
#   Effect Audio Axiom L.csv - achoreviews, vsg, data_mrs
#   Effect Audio Axiom R.csv - vsg, data_mrs
#
# Fiio FHE Eclipse L.csv:
#   Fiio FHE Eclipse L.csv - achoreviews
#   FiiO FHE L.csv - timmyv, melatonin
#   FiiO FHE R.csv - timmyv, melatonin
#   FIIO x Crinacle FHE Eclipse (Foam Eartips) L.csv - iemworld
#   FIIO x Crinacle FHE Eclipse (Foam Eartips) R.csv - iemworld
#   FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) L.csv - iemworld
#   FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) R.csv - iemworld
#   Fiio FHE (franken) L.csv - data_mrs
#   Fiio FHE (franken) R.csv - data_mrs
#   Fiio FHE (S2) L.csv - data_mrs
#   Fiio FHE (S2) R.csv - data_mrs
#   Fiio FHE L.csv - data_mrs
#   Fiio FHE R.csv - data_mrs
#
# Final Audio E500 L.csv:
#   Final Audio E500 L.csv - achoreviews, rg
#   final E500 L.csv - eplv
#   final E500 R.csv - eplv
#   Oratory Final Audio E500 L.csv - kurin
#   Final E500 L.csv - pw, akros, data_mrs
#   Final Audio E500 R.csv - rg
#
# Hidition Violet L.csv:
#   Hidition Violet L.csv - achoreviews, soundjedi, cqtek, data_mrs
#   Hidition Violet R.csv - soundjedi
#
# Hifiman RE600s v2 L.csv:
#   Hifiman RE600s v2 L.csv - achoreviews
#
# Hifiman Svanar L.csv:
#   Hifiman Svanar L.csv - achoreviews
#   HIFIMAN Svanar L.csv - vsg
#   HIFIMAN Svanar R.csv - vsg
#   HIFIMAN Svanar S2 L.csv - vsg
#   HIFIMAN Svanar S2 R.csv - vsg
#   HIFIMAN Svanar S3 L.csv - vsg
#   HIFIMAN Svanar S3 R.csv - vsg
#
# Hifiman TWS800 L.csv:
#   Hifiman TWS800 L.csv - achoreviews
#   HIFIMAN TWS800 L.csv - ianfann, vsg
#   HIFIMAN TWS800 R.csv - ianfann, vsg
#
# HZ Sound Heart Mirror Pro L.csv:
#   HZ Sound Heart Mirror Pro L.csv - achoreviews
#   Heart Mirror Pro L.csv - arn
#   Heart Mirror L.csv - bryaudioreviews
#   Heart Mirror R.csv - bryaudioreviews
#   HZ sound pro R.csv - hbb
#   HZ SOUND HEART MIRROR L.csv - ianfann
#   HZ SOUND HEART MIRROR PRO L.csv - ianfann
#   HZ SOUND HEART MIRROR PRO R.csv - ianfann
#   HZ SOUND HEART MIRROR R.csv - ianfann
#
# Ikko Opal OH02 L.csv:
#   Ikko Opal OH02 L.csv - achoreviews
#
# ITK Unknown L.csv:
#   ITK Unknown L.csv - achoreviews
#
# Joyodio Shine (0000) L.csv:
#   Joyodio Shine (0000) L.csv - achoreviews
#   Joyodio Shine (0010) L.csv - achoreviews
#   Joyodio Shine (0100) L.csv - achoreviews
#   Joyodio Shine (0110) L.csv - achoreviews
#   Joyodio Shine (1000) L.csv - achoreviews
#   Joyodio Shine (1010) L.csv - achoreviews
#   Joyodio Shine (1100) L.csv - achoreviews
#   Joyodio Shine (1110) L.csv - achoreviews
#   JOYODIO SHINE 1 ON R.csv - aftersound
#   JOYODIO SHINE 2 ON R.csv - aftersound
#   JOYODIO SHINE 3 ON R.csv - aftersound
#   JOYODIO SHINE 4 ON R.csv - aftersound
#   JOYODIO SHINE ALL OFF L.csv - aftersound
#   JOYODIO SHINE ALL OFF R.csv - aftersound
#   JOYODIO SHINE ALL ON R.csv - aftersound
#   Joyodio Shine 0000 L.csv - cqtek
#   Joyodio Shine 0000 R.csv - cqtek
#   Joyodio Shine 0001 L.csv - cqtek
#   Joyodio Shine 0001 R.csv - cqtek
#   Joyodio Shine 0011 L.csv - cqtek
#   Joyodio Shine 0011 R.csv - cqtek
#   Joyodio Shine 0111 L.csv - cqtek
#   Joyodio Shine 0111 R.csv - cqtek
#   Joyodio Shine 1000 L.csv - cqtek
#   Joyodio Shine 1000 R.csv - cqtek
#   Joyodio Shine 1001 L.csv - cqtek
#   Joyodio Shine 1001 R.csv - cqtek
#   Joyodio Shine 1010 L.csv - cqtek
#   Joyodio Shine 1010 R.csv - cqtek
#   Joyodio Shine 1011 L.csv - cqtek
#   Joyodio Shine 1011 R.csv - cqtek
#   Joyodio Shine 1100 L.csv - cqtek
#   Joyodio Shine 1100 R.csv - cqtek
#   Joyodio Shine 1110 L.csv - cqtek
#   Joyodio Shine 1110 R.csv - cqtek
#   Joyodio Shine 1111 L.csv - cqtek
#   Joyodio Shine 1111 R.csv - cqtek
#   JOYODIO SHINE CLASSICAL L.csv - ianfann
#   JOYODIO SHINE CLASSICAL R.csv - ianfann
#   JOYODIO SHINE HIFI L.csv - ianfann
#   JOYODIO SHINE HIFI R.csv - ianfann
#   JOYODIO SHINE POP L.csv - ianfann
#   JOYODIO SHINE POP R.csv - ianfann
#   JOYODIO SHINE RNB ROCK L.csv - ianfann
#   JOYODIO SHINE RNB ROCK R.csv - ianfann
#   JOYODIO SHINE STANDARD L.csv - ianfann
#   JOYODIO SHINE STANDARD R.csv - ianfann
#   Joyodio Shine Classical R.csv - vortexreviews
#   Joyodio Shine HIFI R.csv - vortexreviews
#   Joyodio Shine POP R.csv - vortexreviews
#   Joyodio Shine R&B Rock R.csv - vortexreviews
#   Joyodio Shine Standard R.csv - vortexreviews
#
# KBEAR Lark (S1) L.csv:
#   KBEAR Lark (S1) L.csv - achoreviews
#   KBEAR Lark (S2) L.csv - achoreviews
#   KBEAR Lark L.csv - bedrock, eplv, cqtek, melatonin
#   KBEAR Lark R.csv - bedrock, eplv, cqtek, melatonin
#
# KBEAR Little Q L.csv:
#   KBEAR Little Q L.csv - achoreviews, arn
#   KBEar Little Q L.csv - bryaudioreviews
#   KBEar Little Q R.csv - bryaudioreviews
#   Kbear Q R.csv - hbb
#   KBEAR LITTLE Q L.csv - ianfann
#   KBEAR LITTLE Q R.csv - ianfann
#
# KBEAR Qinglong L.csv:
#   KBEAR Qinglong L.csv - achoreviews, arn
#   KBEAR QINGLONG L.csv - aftersound, ianfann
#   KBEAR QINGLONG R.csv - aftersound, ianfann
#   KBEAR Qinglong R.csv - arn
#
# KBEAR Robin L.csv:
#   KBEAR Robin L.csv - achoreviews, cqtek, melatonin, pw, rg
#   KBEAR Robin R.csv - cqtek, melatonin, rg
#
# Kinera BD005 Pro L.csv:
#   Kinera BD005 Pro L.csv - achoreviews, bedrock
#   KINERA BD005 PRO R.csv - aftersound
#   Kinera BD005 Pro R.csv - bedrock
#   Kinera BD005 R.csv - hbb
#
# Kiwi Ears Cadenza L.csv:
#   Kiwi Ears Cadenza L.csv - achoreviews, bedrock, cammyfi, hobbytalk, vortexreviews, data_mrs
#   KIWI EARS CADENZA L.csv - aftersound
#   KIWI EARS CADENZA R.csv - aftersound
#   Kiwi Ears CADENZA L.csv - arn
#   Kiwi Ears CADENZA R.csv - arn
#   Kiwi Ears Cadenza R.csv - bedrock, cammyfi, harpo, hbb, hobbytalk, vortexreviews, data_mrs
#   Kiwi Cadenza L.csv - timmyv
#   Kiwi Cadenza R.csv - timmyv
#   Kiwi Ears R.csv - hbb
#
# Kiwi Ears Orchestra Lite L.csv:
#   Kiwi Ears Orchestra Lite L.csv - achoreviews, bedrock, nymz, pw, rg, vortexreviews, vsg, data_mrs
#   Kiwi Ears Orchestra Lite R.csv - bedrock, nymz, pw, rg, vortexreviews, vsg, data_mrs
#   Kiwi Orchestra L.csv - timmyv
#   Kiwi Orchestra Lite L.csv - timmyv
#   Kiwi Orchestra Lite R.csv - timmyv
#   Kiwi Orchestra R.csv - timmyv
#   Kiwi Ears Orchestra Lite (2.5mm 500 mesh on green bore) L.csv - rg
#   Kiwi Ears Orchestra Lite (2.5mm 500 mesh on white bore) L.csv - rg
#   Kiwi Ears Orchestra Lite (2.5mm 500 mesh on yellow bore) L.csv - rg
#   Kiwi Ears Orchestra Lite (25ohm) L.csv - rg
#   Kiwi Ears Orchestra Lite deep fit L.csv - vsg
#   Kiwi Ears Orchestra Lite deep fit R.csv - vsg
#   Kiwi Ears Orchestra (E-type TWS) L.csv - data_mrs
#   Kiwi Ears Orchestra (E-type TWS) R.csv - data_mrs
#   Kiwi Ears Orchestra (Sedna Short) L.csv - data_mrs
#   Kiwi Ears Orchestra (Sedna Short) R.csv - data_mrs
#   Kiwi Ears Orchestra L.csv - data_mrs
#   Kiwi Ears Orchestra R.csv - data_mrs
#
# Koss KEB90 L.csv:
#   Koss KEB90 L.csv - achoreviews, data_mrs
#   KOSS KEB90 L.csv - hobbytalk
#   KOSS KEB90 R.csv - hobbytalk
#   Koss KEB90 R.csv - data_mrs
#
# KZ AS16 Pro L.csv:
#   KZ AS16 Pro L.csv - achoreviews, melatonin, pw, vortexreviews
#   KZ AS16 PRO L.csv - aftersound, ianfann
#   KZ AS16 PRO R.csv - aftersound, ianfann
#   KZ AS16 L.csv - eplv, melatonin
#   KZ AS16 R.csv - eplv, melatonin
#   KZ AS16 Pro R.csv - hbb, melatonin, pw, vortexreviews
#   KZ AS16 Pro 200Ω R.csv - melatonin
#   KZ AS16 Pro 30Ω R.csv - melatonin
#   KZ AS16 Pro 75Ω R.csv - melatonin
#   KZ AS16 Pro 25ohm L.csv - pw
#   KZ AS16 Pro BTX L.csv - pw
#   KZ AS16 Pro TK2 L.csv - pw
#   KZ (avg) L.csv - data_mrs
#
# KZ ATE L.csv:
#   KZ ATE L.csv - achoreviews, data_mrs
#   Oratory KZ ATE L.csv - kurin
#   KZ ATE R.csv - data_mrs
#
# KZ DQ6 L.csv:
#   KZ DQ6 L.csv - achoreviews, eplv, ianfann, jacstone, melatonin, nymz, pw, rg, data_mrs
#   KZ DQ6 R.csv - aftersound, eplv, hbb, ianfann, jacstone, melatonin, nymz, vortexreviews, data_mrs
#   KZ DQ6 5 R.csv - hbb
#   KZ DQ6 R Xf R.csv - hbb
#   KZ DQ6 X HBB R.csv - hbb
#   KZ DQ6 X R.csv - hbb
#   KZ DQ6 X2 R.csv - hbb
#   KZ DQ6 X5 R.csv - hbb
#   KZ DQ6 Xl R.csv - hbb
#   KZ DQ6 (1dividedby16 foam) L.csv - rg
#   KZ DQ6 (Hana Filter) L.csv - rg
#   KZ DQ6 (High-Density Tuning Foam + cotton filter) L.csv - rg
#   KZ DQ6 (High-Density Tuning Foam) L.csv - rg
#   KZ DQ6 (Low-Density Tuning Foam) L.csv - rg
#   KZ DQ6 (Micropore Tape Mod) L.csv - rg
#   KZ DQ6 (Micropore tape+ 1dividedby16foam Mod) L.csv - rg
#   KZ DQ6 (Micropore Tips) L.csv - rg
#   KZ DQ6 (Micropore+ 1dividedby16foam Tips) L.csv - rg
#   KZ DQ6 (O2 Filter) L.csv - rg
#   KZ DQ6 (Sony Import Foam) L.csv - rg
#   KZ DQ6 (Tanchjim filter) L.csv - data_mrs
#   KZ DQ6 (Tanchjim filter) R.csv - data_mrs
#
# KZ DQ6s L.csv:
#   KZ DQ6s L.csv - achoreviews, melatonin, nymz
#   KZ DQ6S L.csv - aftersound, bedrock, ianfann, jacstone, pw, rg
#   KZ DQ6S R.csv - aftersound, bedrock, harpo, ianfann, jacstone, pw, rg
#   KZ HBB DQ6S L.csv - iemworld
#   KZ HBB DQ6S R.csv - iemworld
#   KZ DQ6s R.csv - melatonin, nymz
#   KZ x HBB DQ6S L.csv - vortexreviews, vsg
#   KZ x HBB DQ6S R.csv - vortexreviews, vsg
#
# KZ DQS L.csv:
#   KZ DQS L.csv - achoreviews, ianfann, pw
#   KZ DQS R.csv - ianfann, pw, vortexreviews
#
# KZ ED16 L.csv:
#   KZ ED16 L.csv - achoreviews
#
# KZ EDX L.csv:
#   KZ EDX L.csv - achoreviews, eplv, jacstone, melatonin, pw, vortexreviews
#   KZ EDX Pro L.csv - achoreviews, melatonin, pw, rg, vortexreviews, data_mrs
#   KZ EDX PRO L.csv - aftersound, jacstone
#   KZ EDX PRO R.csv - aftersound, hbb, jacstone
#   KZ EDX R.csv - aftersound, eplv, jacstone, melatonin, vortexreviews
#   KZ EDX ULTRA L.csv - aftersound, ianfann
#   KZ EDX ULTRA R.csv - aftersound, ianfann
#   KZ EDX Ultra L.csv - jacstone, pw, rg, vortexreviews
#   KZ EDX Ultra R.csv - jacstone, pw, rg, vortexreviews
#   KZ EDX Pro R.csv - melatonin, pw, rg, data_mrs
#   KZ EDX Pro (2 Low-Density Tuning Foams) L.csv - rg
#   KZ EDX Pro (High-Density Tuning Foam) L.csv - rg
#   KZ EDX Pro (Low-Density Tuning Foam) L.csv - rg
#
# KZ PR1 L.csv:
#   KZ PR1 L.csv - achoreviews, timmyv, ianfann
#   KZ PR1 HiFi L.csv - arn
#   KZ PR1 HiFi R.csv - arn
#   KZ PR1 Pro L.csv - arn, pw, data_mrs
#   KZ PR1 Pro R.csv - arn, pw, data_mrs
#   KZ PR1 R.csv - timmyv, hbb, ianfann
#   KZ PR1 Balanced L.csv - harpo
#   KZ PR1 PRO L.csv - ianfann
#   KZ PR1 PRO R.csv - ianfann
#   KZ PR1 STOCK TIPS L.csv - ianfann
#   KZ PR1 STOCK TIPS R.csv - ianfann
#   KZ PR1 Balanced version R.csv - melatonin
#   KZ PR1 HiFi version form R.csv - melatonin
#   KZ PR1 HiFi version R.csv - melatonin
#   KZ PR1 Hifi L.csv - vortexreviews
#   KZ PR1 Hifi R.csv - vortexreviews
#
# KZ ZAX L.csv:
#   KZ ZAX L.csv - achoreviews, melatonin, pw, vortexreviews
#   KZ ZAX R.csv - hbb, melatonin
#
# KZ ZES L.csv:
#   KZ ZES L.csv - achoreviews, aftersound, ianfann, pw, rg, vortexreviews
#   KZ ZES R.csv - aftersound, ianfann, rg, vortexreviews
#
# KZ ZEX L.csv:
#   KZ ZEX L.csv - achoreviews, bryaudioreviews, ianfann, iemworld, jacstone, melatonin, suporsalad, tgx78, vortexreviews, data_mrs
#   KZ ZEX Pro L.csv - achoreviews, pw, rg, vortexreviews, data_mrs
#   KZ ZEX PRO L.csv - aftersound, ianfann, jacstone
#   KZ ZEX PRO R.csv - aftersound, hbb, ianfann, jacstone
#   KZ ZEX R.csv - bryaudioreviews, hbb, ianfann, iemworld, jacstone, melatonin, suporsalad, data_mrs
#   Resolve KZ Zex Pro CRN Gras L.csv - kurin
#   KZ ZEX Pro R.csv - pw, rg, vortexreviews, data_mrs
#   KZ ZEX Pro Taped L.csv - pw
#   KZ ZEX Stock L.csv - pw
#   KZ ZEX Taped L.csv - pw
#   KZ ZEX Pro (30ohm) L.csv - rg
#   KZ Zex Pro L.csv - tgx78
#   KZ Zex Pro R.csv - tgx78
#   KZ ZEX (vent blocked) L.csv - data_mrs
#
# KZ ZEX Pro L.csv:
#   ZEX Pro L.csv - kr0mka
#   ZEX Pro R.csv - kr0mka
#
# KZ ZS10 Pro L.csv:
#   KZ ZS10 Pro L.csv - achoreviews, eplv, melatonin, pw, data_mrs
#   KZ ZS10 PRO R.csv - aftersound, timmyv, ianfann, jacstone
#   KZ ZS10 Pro R.csv - eplv, melatonin
#   KZ ZS10 PRO L.csv - timmyv, ianfann, jacstone
#   KZ ZS10 PRO Foam R.csv - hbb
#   KZ ZS10 PRO X Sil R.csv - hbb
#   KZ ZS10 PRO X L.csv - ianfann
#   KZ ZS10 PRO X R.csv - ianfann
#   ZS10 L.csv - kr0mka
#   ZS10 Pro L.csv - kr0mka
#   ZS10 Pro R.csv - kr0mka
#   ZS10 R.csv - kr0mka
#   KZ ZS10 L.csv - melatonin, data_mrs
#   KZ ZS10 Pro NEW L.csv - melatonin
#   KZ ZS10 Pro NEW R.csv - melatonin
#   KZ ZS10 R.csv - melatonin
#   KZ ZS10 Pro X L.csv - vortexreviews, data_mrs
#   KZ ZS10 Pro X R.csv - vortexreviews, data_mrs
#
# KZ ZSN L.csv:
#   KZ ZSN L.csv - achoreviews, eplv, melatonin, pw
#   KZ ZSN Pro L.csv - achoreviews, melatonin, pw, data_mrs
#   KZ ZSN Pro X L.csv - achoreviews, bryaudioreviews, melatonin, pw
#   KZ ZSN PRO L.csv - aftersound
#   KZ ZSN PRO R.csv - aftersound
#   KZ ZSN PRO X R.csv - aftersound
#   KZ ZSN Pro X R.csv - bryaudioreviews, hbb, melatonin
#   KZ ZSN R.csv - eplv, hbb, melatonin
#   Oratory KZ ZSN Pro L.csv - kurin
#   KZ ZSN Pro R.csv - melatonin
#   KZ ZSN PRO X BROKEN R.csv - nymz
#   KZ ZSN PRO X OK L.csv - nymz
#   KZ ZSN Pro Xv2 L.csv - pw
#   KZ ZSN Prov2 L.csv - pw
#   KZ ZSN Pro (1-8 foam) L.csv - data_mrs
#   KZ ZSN Pro (Blessing 2 filter) L.csv - data_mrs
#   KZ ZSN Pro (Starfield filter) L.csv - data_mrs
#   KZ ZSN Pro (Tanchjim filter) L.csv - data_mrs
#
# KZ ZST X L.csv:
#   KZ ZST X L.csv - achoreviews, melatonin, vortexreviews
#   KZ ZST X R.csv - aftersound, hbb, melatonin
#   KZ ZST R.csv - hbb, melatonin
#   KZ ZST L.csv - melatonin, pw
#
# KZ ZVX L.csv:
#   KZ ZVX L.csv - achoreviews, aftersound, timmyv, ianfann, pw
#   KZ ZVX FINAL TIPS L.csv - aftersound
#   KZ ZVX FINAL TIPS R.csv - aftersound
#   KZ ZVX R.csv - aftersound, timmyv, harpo, ianfann
#   Kz Zvx R.csv - hbb
#   KZ ZVX 25ohm L.csv - pw
#   KZ ZVX IEMatch L.csv - pw
#   KZ ZVX MP L.csv - pw
#
# Letshuoer D13 (Gold Filter) L.csv:
#   Letshuoer D13 (Gold Filter) L.csv - achoreviews
#   Letshuoer D13 (Silver Filter) L.csv - achoreviews
#   Letshuoer D13 (Gold) L.csv - bedrock
#   Letshuoer D13 (Gold) R.csv - bedrock
#   Letshuoer D13 (Silver) L.csv - bedrock
#   Letshuoer D13 (Silver) R.csv - bedrock
#   LETSHUOER D13 Gold Nozzle R.csv - harpo
#   LETSHUOER D13 Olina Filter mod R.csv - harpo
#   LETSHUOER D13 Silver Nozzle R.csv - harpo
#   LetShuoer D13 Gold L.csv - cqtek, pw
#   LetShuoer D13 Gold R.csv - cqtek, pw
#   LetShuoer D13 Silver L.csv - cqtek, pw
#   LetShuoer D13 Silver R.csv - cqtek, pw
#   LETSHUOER D13 2nd Nozzle L.csv - hobbytalk
#   LETSHUOER D13 2nd Nozzle R.csv - hobbytalk
#   LETSHUOER D13 L.csv - hobbytalk, ianfann
#   LETSHUOER D13 MBP L.csv - hobbytalk
#   LETSHUOER D13 MBP R.csv - hobbytalk
#   LETSHUOER D13 R.csv - hobbytalk, ianfann, vortexreviews
#   LETSHUOER D13 Stock Nozzle L.csv - hobbytalk
#   LETSHUOER D13 Stock Nozzle R.csv - hobbytalk
#   LETSHUOER D13 (TREBLE NOZZLE) L.csv - ianfann
#   LETSHUOER D13 (TREBLE NOZZLE) R.csv - ianfann
#   LETSHUOER D13 TREBLE R.csv - vortexreviews
#   LETSHUOER D13 gold nozzle L.csv - vsg
#   LETSHUOER D13 gold nozzle R.csv - vsg
#   LETSHUOER D13 silver nozzle L.csv - vsg
#   LETSHUOER D13 silver nozzle R.csv - vsg
#   Letshuoer D13 (gold) L.csv - data_mrs
#   Letshuoer D13 (gold) R.csv - data_mrs
#   Letshuoer D13 (pre-prod - nozzle A) L.csv - data_mrs
#   Letshuoer D13 (pre-prod - nozzle A) R.csv - data_mrs
#   Letshuoer D13 (pre-prod - nozzle B) L.csv - data_mrs
#   Letshuoer D13 (pre-prod - nozzle B) R.csv - data_mrs
#   Letshuoer D13 (silver) L.csv - data_mrs
#   Letshuoer D13 (silver) R.csv - data_mrs
#
# Letshuoer S12 (S1) L.csv:
#   Letshuoer S12 (S1) L.csv - achoreviews
#   Letshuoer S12 (S2) L.csv - achoreviews
#   LETSHUOER S12 L.csv - arn, eplv, vortexreviews, vsg
#   Letshuoer S12 PRO L.csv - cammyfi
#   Letshuoer S12 PRO R.csv - cammyfi
#   Letshuoer S12 PRO Vents Blocked 300 Damping L.csv - cammyfi
#   Letshuoer S12 PRO Vents Blocked L.csv - cammyfi
#   LetShuoer S12 L.csv - soundjedi, cqtek
#   LetShuoer S12 R.csv - soundjedi, cqtek
#   LETSHUOER S12 R.csv - eplv, melatonin, vortexreviews, vsg
#   Letshuoer S12 L.csv - timmyv, data_mrs
#   Letshuoer S12 Pro L.csv - timmyv
#   Letshuoer S12 Pro R.csv - timmyv
#   Letshuoer S12 R.csv - timmyv, harpo, data_mrs
#   LetShuoer S12 Pro L.csv - cqtek
#   LetShuoer S12 Pro R.csv - cqtek
#   LETSHUOER S12 PRO L.csv - hobbytalk, ianfann, vortexreviews
#   LETSHUOER S12 PRO R.csv - hobbytalk, ianfann, vortexreviews
#   LETSHUOER S12 Foam R.csv - melatonin
#   S12 L.csv - shortbus
#   Letshuoer S12 (front vent blocked) L.csv - data_mrs
#   Letshuoer S12 (post) L.csv - data_mrs
#   Letshuoer S12 (post) R.csv - data_mrs
#   Letshuoer S12 (prepro) L.csv - data_mrs
#   Letshuoer S12 (prepro) R.csv - data_mrs
#   Letshuoer S12 (top vent blocked) L.csv - data_mrs
#
# LZ A4 Pro NzBlk FiBlk L.csv:
#   LZ A4 Pro NzBlk FiBlk L.csv - achoreviews
#   LZ A4 PRO R.csv - hbb
#   LZ A4 Pro (A7 Gold F + Black V) L.csv - rg
#   LZ A4 Pro (A7 Red F + Black V) L.csv - rg
#   LZ A4 Pro (Black F + Black V) L.csv - rg
#   LZ A4 Pro (Black F + Blue V) L.csv - rg
#   LZ A4 Pro (Black F + Red V) L.csv - rg
#   LZ A4 Pro (Blue F + Black V) L.csv - rg
#   LZ A4 Pro (Blue F + Blue V) L.csv - rg
#   LZ A4 Pro (Blue F + Red V) L.csv - rg
#   LZ A4 Pro (Gold F + Black V) L.csv - rg
#   LZ A4 Pro (Gold F + Blue V) L.csv - rg
#   LZ A4 Pro (Gold F + Red V) L.csv - rg
#   LZ A4 Pro (Red F + Black V) L.csv - rg
#   LZ A4 Pro (Red F + Blue V) L.csv - rg
#   LZ A4 Pro (Red F + Red V) L.csv - rg
#
# LZ A4 Pro NzBlk FiBlu L.csv:
#   LZ A4 Pro NzBlk FiBlu L.csv - achoreviews
#
# LZ A4 Pro NzBlk FiRed L.csv:
#   LZ A4 Pro NzBlk FiRed L.csv - achoreviews
#
# LZ A4 Pro NzBlu FiBlk L.csv:
#   LZ A4 Pro NzBlu FiBlk L.csv - achoreviews
#
# LZ A4 Pro NzBlu FiBlu L.csv:
#   LZ A4 Pro NzBlu FiBlu L.csv - achoreviews
#
# LZ A4 Pro NzBlu FiRed L.csv:
#   LZ A4 Pro NzBlu FiRed L.csv - achoreviews
#
# LZ A4 Pro NzRed FiBlk L.csv:
#   LZ A4 Pro NzRed FiBlk L.csv - achoreviews
#
# LZ A4 Pro NzRed FiBlu L.csv:
#   LZ A4 Pro NzRed FiBlu L.csv - achoreviews
#
# LZ A4 Pro NzRed FiRed L.csv:
#   LZ A4 Pro NzRed FiRed L.csv - achoreviews
#
# LZ A4 Pro NzSil FiBlk L.csv:
#   LZ A4 Pro NzSil FiBlk L.csv - achoreviews
#
# LZ A4 Pro NzSil FiBlu L.csv:
#   LZ A4 Pro NzSil FiBlu L.csv - achoreviews
#
# LZ A4 Pro NzSil FiRed L.csv:
#   LZ A4 Pro NzSil FiRed L.csv - achoreviews
#
# Meze Audio Advar L.csv:
#   Meze Audio Advar L.csv - achoreviews
#
# Moondrop Aria L.csv:
#   Moondrop Aria L.csv - achoreviews, animagus, bedrock, bryaudioreviews, timmyv, pw, vortexreviews, vsg, data_mrs
#   MOONDROP ARIA (OLD) L.csv - aftersound
#   MOONDROP ARIA (OLD) R.csv - aftersound
#   MOONDROP ARIA L.csv - aftersound, ianfann
#   MOONDROP ARIA R.csv - aftersound, ianfann
#   Moondrop Aria R.csv - animagus, bedrock, bryaudioreviews, timmyv, harpo, hbb, pw, vsg
#   Moondrop Aria Snow Edition L.csv - animagus
#   Moondrop Aria Snow Edition R.csv - animagus
#   Moondrop Aria Snow L.csv - timmyv, pw, data_mrs
#   Moondrop Aria Snow R.csv - timmyv, hbb, pw, data_mrs
#   MOONDROP ARIA SNOW L.csv - ianfann
#   MOONDROP ARIA SNOW R.csv - ianfann
#   Moondrop Aria S1 L.csv - jacstone
#   Moondrop Aria S1 R.csv - jacstone
#   Moondrop Aria S2 L.csv - jacstone
#   Moondrop Aria S2 R.csv - jacstone
#   Aria L.csv - kr0mka
#   Aria R.csv - kr0mka
#   Moondrop Aria Snow MP L.csv - pw
#   Moondrop Aria Snow NoFoam L.csv - pw
#   Moondrop Aria Snow NoFoam MP L.csv - pw
#   MOONDROP Aria Snow Edition L.csv - vsg
#   MOONDROP Aria Snow Edition R.csv - vsg
#   ARIA L.csv - akros
#   Moondrop Aria Snow (Spring) L.csv - data_mrs
#   Moondrop Aria Snow (Spring) R.csv - data_mrs
#
# Moondrop Blessing 2 Dusk (Spinfit) L.csv:
#   Moondrop Blessing 2 Dusk (Spinfit) L.csv - achoreviews
#   MOONDROP BLESSING 2 L.csv - aftersound
#   MOONDROP BLESSING 2 R.csv - aftersound
#   Moondrop Dusk R.csv - hbb
#   Moondrop Blessing 2 Dusk L.csv - cqtek, data_mrs
#   Moondrop Blessing 2 Dusk R.csv - cqtek
#   Moondrop Blessing 2 Dusk (BGVP Foam) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (BGVP Foam) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (FINAL EARTIPS) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (FINAL EARTIPS) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (NO TIP on Coupler 8K) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (NO TIP on Coupler 8K) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (ORIGNAL SILICON) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (ORIGNAL SILICON) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (SOFTEAR UC EARTIPS) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (SOFTEAR UC EARTIPS)C L.csv - iemworld
#   Moondrop Blessing 2 Dusk (Tripowin Foam) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (Tripowin Foam) R.csv - iemworld
#   Moondrop Blessing 2 Dusk S1 L.csv - jacstone
#   Moondrop Blessing 2 Dusk S1 R.csv - jacstone
#   Moondrop Blessing 2 Dusk S2 L.csv - jacstone
#   Moondrop Blessing 2 Dusk S2 R.csv - jacstone
#   Dusk L.csv - kr0mka
#   Dusk R.csv - kr0mka
#   Oratory Moondrop Blessing 2 Dusk L.csv - kurin
#   Moondrop Blessing 2 L.csv - nymz, rg, data_mrs
#   Moondrop Blessing 2 R.csv - nymz, data_mrs
#   dusk L.csv - recode
#   dusk R.csv - recode
#   Blessing 2 Dusk L.csv - wdym
#   Moondrop Blessing 2 (E-type) L.csv - data_mrs
#   Moondrop Blessing 2 (Moondrop filter) L.csv - data_mrs
#   Moondrop Blessing 2 (Precog) L.csv - data_mrs
#   Moondrop Blessing 2 Dusk (Precog) L.csv - data_mrs
#
# Moondrop Chu L.csv:
#   Moondrop Chu L.csv - achoreviews, arn, bedrock, cammyfi, eplv, timmyv, hobbytalk, jacstone, nymz, pw, suporsalad, data_mrs
#   MOONDROP CHU L.csv - aftersound, ianfann
#   MOONDROP CHU R.csv - aftersound, ianfann
#   Moondrop Chu R.csv - bedrock, cammyfi, eplv, timmyv, harpo, hobbytalk, jacstone, nymz, pw, suporsalad, vortexreviews, data_mrs
#   Moondrop CHU 2 R.csv - hbb
#   Moondrop Chu 3 R.csv - hbb
#   Moondrop CHU R.csv - hbb, vsg
#   MOONDROP CHU (MOD) L.csv - ianfann
#   MOONDROP CHU (MOD) R.csv - ianfann
#   MOONDROP CHU (SF 145) L.csv - ianfann
#   MOONDROP CHU (SF 145) R.csv - ianfann
#   MOONDROP CHU (SPRING TIPS) L.csv - ianfann
#   MOONDROP CHU (SPRING TIPS) R.csv - ianfann
#   MOONDROP CHU BASS MOD L.csv - ianfann
#   MOONDROP CHU BASS MOD R.csv - ianfann
#   MoonDrop CHU L.csv - iemworld
#   MoonDrop CHU R.csv - iemworld
#   Chu L.csv - kr0mka
#   Chu R.csv - kr0mka
#   Oratory Moondrop Chu L.csv - kurin
#   Moondrop Chu Tanya L.csv - nymz, pw
#   Moondrop Chu Tanya R.csv - nymz
#   Moondrop Chu MP L.csv - pw
#   chu L.csv - recode
#   chu R.csv - recode
#   Moondrop CHU L.csv - vsg
#   Moondrop Chu (Tanchjim filter) L.csv - data_mrs
#   Moondrop Chu (Tanchjim filter) R.csv - data_mrs
#   Moondrop Chu (vent - BluTack) L.csv - data_mrs
#   Moondrop Chu (vent - BluTack) R.csv - data_mrs
#   Moondrop Chu (vent - Tanchjim) L.csv - data_mrs
#   Moondrop Chu (vent - Tanchjim) R.csv - data_mrs
#
# Moondrop Nekocake (Balanced + ANC) L.csv:
#   Moondrop Nekocake (Balanced + ANC) L.csv - achoreviews
#   Moondrop Nekocake (Balanced) L.csv - achoreviews
#   Moondrop Nekocake (Classic) L.csv - achoreviews
#   Moondrop Nekocake (Nobass) L.csv - achoreviews
#   Moondrop Nekocake (Wennebostel) L.csv - achoreviews
#   Moondrop Nekocake (X-Dynamic) L.csv - achoreviews
#   MOONDROP NEKOCAKE L.csv - aftersound, vsg
#   MOONDROP NEKOCAKE R.csv - aftersound, vsg
#   Moondrop Nekocake (ANC off) L.csv - data_mrs
#   Moondrop Nekocake (ANC off) R.csv - data_mrs
#   Moondrop Nekocake (ANC on) L.csv - data_mrs
#   Moondrop Nekocake (ANC on) R.csv - data_mrs
#   Moondrop Nekocake (Classic ANC) L.csv - data_mrs
#   Moondrop Nekocake (Dynamic ANC) L.csv - data_mrs
#   Moondrop Nekocake (Nobass ANC) L.csv - data_mrs
#   Moondrop Nekocake (Wennebostel ANC) L.csv - data_mrs
#
# Moondrop Quarks L.csv:
#   Moondrop Quarks L.csv - achoreviews, bedrock, eplv, hobbytalk, rg, suporsalad, vortexreviews, data_mrs
#   MOONDROP QUARKS L.csv - aftersound
#   MOONDROP QUARKS R.csv - aftersound
#   Moondrop Quarks R.csv - bedrock, eplv, hobbytalk, rg, suporsalad, vortexreviews, data_mrs
#   Moondrop Quarks DSP L.csv - cammyfi, harpo, hobbytalk, nymz, suporsalad, vsg, data_mrs
#   Moondrop Quarks DSP R.csv - cammyfi, hobbytalk, nymz, suporsalad, vsg, data_mrs
#   Moondrop Quarks Dsp R.csv - hbb
#   Moondrop Quarks (S2) L.csv - hobbytalk
#   Moondrop Quarks (S2) R.csv - hobbytalk
#   Moondrop Quarks (S3) L.csv - hobbytalk
#   Moondrop Quarks (S3) R.csv - hobbytalk
#   Moondrop Quarks DSP 77db L.csv - hobbytalk
#   Moondrop Quarks DSP 77db R.csv - hobbytalk
#   Moondrop Quarks DSP Stock Tips L.csv - hobbytalk
#   Moondrop Quarks DSP Stock Tips R.csv - hobbytalk
#   Moondrop Quarks DSP Ultra Deep L.csv - hobbytalk
#   Moondrop Quarks DSP Ultra Deep R.csv - hobbytalk
#   MOONDROP QUARKS DSP L.csv - ianfann
#   MOONDROP QUARKS DSP R.csv - ianfann
#   MoonDrop Quarks DSP L.csv - iemworld
#   MoonDrop Quarks DSP R.csv - iemworld
#   Oratory Moondrop Quarks L.csv - kurin
#
# Moondrop SSP L.csv:
#   Moondrop SSP L.csv - achoreviews, bedrock, eplv, cqtek, data_mrs
#   MOONDROP SSP L.csv - aftersound
#   MOONDROP SSP R.csv - aftersound
#   Moondrop SSP R.csv - bedrock, eplv, cqtek
#   ssp L.csv - recode
#   ssp R.csv - recode
#   Moondrop SSP (vent blocked) L.csv - data_mrs
#
# Moondrop SSR L.csv:
#   Moondrop SSR L.csv - achoreviews, bedrock, bryaudioreviews, cqtek, nymz, data_mrs
#   MOONDROP SSR L.csv - aftersound
#   MOONDROP SSR R.csv - aftersound
#   Moondrop SSR R.csv - bedrock, bryaudioreviews, harpo, cqtek, nymz
#   Moondrop ssr R.csv - hbb
#   ssr L.csv - recode
#   ssr R.csv - recode
#   Moondrop SSR (deep) L.csv - data_mrs
#   Moondrop SSR (deep) R.csv - data_mrs
#   Moondrop SSR (Final E) L.csv - data_mrs
#   Moondrop SSR (micro pore) L.csv - data_mrs
#   Moondrop SSR (OS100) L.csv - data_mrs
#   Moondrop SSR (OS200) L.csv - data_mrs
#   Moondrop SSR (OS300) L.csv - data_mrs
#   Moondrop SSR (S2 + Tanchjim filter) L.csv - data_mrs
#   Moondrop SSR (S2 - AutoEQ) L.csv - data_mrs
#   Moondrop SSR (S2) L.csv - data_mrs
#   Moondrop SSR (S3) L.csv - data_mrs
#   Moondrop SSR (S4) L.csv - data_mrs
#   Moondrop SSR (S4) R.csv - data_mrs
#   Moondrop SSR (Sedna) L.csv - data_mrs
#   Moondrop SSR (vent blocked) L.csv - data_mrs
#
# Moondrop Starfield L.csv:
#   Moondrop Starfield L.csv - achoreviews, timmyv, suporsalad, data_mrs
#   Moondrop  Starfield L.csv - timmyv
#   Moondrop  Starfield R.csv - timmyv
#   Moondrop Starfield R.csv - timmyv, hbb, suporsalad
#   Oratory Moondrop Starfield L.csv - kurin
#
# NF Audio NM2 L.csv:
#   NF Audio NM2 L.csv - achoreviews, tgx78, vortexreviews, data_mrs
#   NF AUDIO NM2 L.csv - cqtek, ianfann
#   NF AUDIO NM2 R.csv - cqtek, ianfann
#   NF AUDIO NM2+ L.csv - cqtek
#   NF AUDIO NM2+ R.csv - cqtek
#   NF Audio NM2 R.csv - vortexreviews, data_mrs
#
# NiceHCK Topguy L.csv:
#   NiceHCK Topguy L.csv - achoreviews, cqtek, data_mrs
#   NiceHck Topguy R.csv - hbb
#   NiceHCK Topguy R.csv - cqtek, data_mrs
#   NICEHCK Topguy L.csv - melatonin
#   NICEHCK Topguy R.csv - melatonin
#
# Openheart Resin L.csv:
#   Openheart Resin L.csv - achoreviews, vortexreviews
#   Openheart Resin R.csv - tgx78
#
# Plussound Allegro L.csv:
#   Plussound Allegro L.csv - achoreviews
#   PlusSound Allegro L.csv - soundjedi
#   PlusSound Allegro R.csv - soundjedi
#
# QKZ CK5 L.csv:
#   QKZ CK5 L.csv - achoreviews
#
# QKZ x HBB Khan L.csv:
#   QKZ x HBB Khan L.csv - achoreviews, timmyv, cqtek, nymz, pw, vortexreviews
#   QKZ x HBB L.csv - achoreviews, arn, timmyv, hobbytalk, nymz, vortexreviews, data_mrs
#   QKZ QKZ X HBB L.csv - aftersound
#   QKZ QKZ X HBB R.csv - aftersound
#   QKZ X HBB KHAN L.csv - aftersound, hobbytalk, ianfann
#   QKZ X HBB KHAN R.csv - aftersound, hobbytalk, ianfann
#   QKZ X HBB L.csv - aftersound, ianfann, iemworld
#   QKZ X HBB R.csv - aftersound, ianfann, iemworld
#   QKZ Khan L.csv - arn, jacstone
#   QKZ Khan R.csv - arn, jacstone
#   QKZ x HBB Khan R.csv - timmyv, cqtek, nymz
#   QKZ x HBB R.csv - timmyv, hobbytalk, melatonin, nymz, vortexreviews, data_mrs
#   QKZ HBB R.csv - hbb
#   QKZ X Hbb R.csv - hbb
#   QKZ X HBB KHAN 75ohm L.csv - hobbytalk
# ...
#   HIFIMAN HE-R10D L.csv - vsg
#   HIFIMAN HE-R10D R.csv - vsg
#
# HIFIMAN HE-R10P Bluemini L.csv:
#   HIFIMAN HE-R10P Bluemini L.csv - vsg
#   HIFIMAN HE-R10P Bluemini R.csv - vsg
#   HIFIMAN HE-R10P L.csv - vsg
#   HIFIMAN HE-R10P R.csv - vsg
#
# HIFIMAN HE-R9 Bluemini L.csv:
#   HIFIMAN HE-R9 Bluemini L.csv - vsg
#   HIFIMAN HE-R9 Bluemini R.csv - vsg
#   HIFIMAN HE-R9 L.csv - vsg
#   HIFIMAN HE-R9 R.csv - vsg
#
# HIFIMAN HE1000se L.csv:
#   HIFIMAN HE1000se L.csv - vsg
#   HIFIMAN HE1000se R.csv - vsg
#
# HIFIMAN RE2000 Pro Gold L.csv:
#   HIFIMAN RE2000 Pro Gold L.csv - vsg
#   HIFIMAN RE2000 Pro Gold R.csv - vsg
#
# HIFIMAN Shangri-La Jr L.csv:
#   HIFIMAN Shangri-La Jr L.csv - vsg
#   HIFIMAN Shangri-La Jr R.csv - vsg
#
# HIFIMAN Shangri-La Sr L.csv:
#   HIFIMAN Shangri-La Sr L.csv - vsg
#   HIFIMAN Shangri-La Sr R.csv - vsg
#
# iBasso SR3 L.csv:
#   iBasso SR3 L.csv - vsg
#   iBasso SR3 R.csv - vsg
#   iBasso SR3 spare pads L.csv - vsg
#   iBasso SR3 spare pads R.csv - vsg
#
# JQ 4Upro L.csv:
#   JQ 4Upro L.csv - vsg
#   JQ 4Upro R.csv - vsg
#
# Kinera YH802 ANC L.csv:
#   Kinera YH802 ANC L.csv - vsg
#   Kinera YH802 L.csv - vsg
#   Kinera YH802 R.csv - vsg
#
# Kinera YH802 L.csv:
#   Kinera YH802 Transparency L.csv - vsg
#
# Lypertek PurePlay Z5 Ambient L.csv:
#   Lypertek PurePlay Z5 Ambient L.csv - vsg
#   Lypertek PurePlay Z5 L.csv - vsg
#   Lypertek PurePlay Z5 R.csv - vsg
#
# Lypertek PurePlay Z5 ANC L.csv:
#   Lypertek PurePlay Z5 ANC L.csv - vsg
#
# Lypertek PurePlay Z7 L.csv:
#   Lypertek PurePlay Z7 L.csv - vsg
#   Lypertek PurePlay Z7 R.csv - vsg
#
# Mackie MP-320 L.csv:
#   Mackie MP-320 L.csv - vsg
#   Mackie MP-320 R.csv - vsg
#
# Mackie MP-460 L.csv:
#   Mackie MP-460 L.csv - vsg
#   Mackie MP-460 R.csv - vsg
#
# Meze 99 Neo Dekoni L.csv:
#   Meze 99 Neo Dekoni L.csv - vsg
#   Meze 99 Neo Dekoni R.csv - vsg
#   Meze 99 Neo L.csv - vsg
#   Meze 99 Neo R.csv - vsg
#
# Meze Liric L.csv:
#   Meze Liric L.csv - vsg
#   Meze Liric R.csv - vsg
#
# Monoprice M1070C Lambskin L.csv:
#   Monoprice M1070C Lambskin L.csv - vsg
#   Monoprice M1070C Lambskin R.csv - vsg
#
# Monoprice M1070C Velour L.csv:
#   Monoprice M1070C Velour L.csv - vsg
#   Monoprice M1070C Velour R.csv - vsg
#
# Monoprice Monolith M-TWE L.csv:
#   Monoprice Monolith M-TWE L.csv - vsg
#   Monoprice Monolith M-TWE R.csv - vsg
#
# Moondrop VOID L.csv:
#   Moondrop VOID L.csv - vsg
#   Moondrop VOID R.csv - vsg
#   Moondrop VOID S1 L.csv - vsg
#   Moondrop VOID S1 R.csv - vsg
#   Moondrop VOID S2 L.csv - vsg
#   Moondrop VOID S2 R.csv - vsg
#
# Nectar HiveX (No Sponge Insert) L.csv:
#   Nectar HiveX (No Sponge Insert) L.csv - vsg
#   Nectar HiveX (No Sponge Insert) R.csv - vsg
#   Nectar HiveX (Sponge Insert) L.csv - vsg
#   Nectar HiveX (Sponge Insert) R.csv - vsg
#
# Noble Audio Viking Ragnar L.csv:
#   Noble Audio Viking Ragnar L.csv - vsg
#   Noble Audio Viking Ragnar R.csv - vsg
#
# Ovidius RX-100 L.csv:
#   Ovidius RX-100 L.csv - vsg
#   Ovidius RX-100 R.csv - vsg
#
# Ovidius TX-901 L.csv:
#   Ovidius TX-901 L.csv - vsg
#   Ovidius TX-901 R.csv - vsg
#
# Padmate PaMu Z1 L.csv:
#   Padmate PaMu Z1 L.csv - vsg
#   Padmate PaMu Z1 R.csv - vsg
#
# Peacock Flight L.csv:
#   Peacock Flight L.csv - vsg
#   Peacock Flight R.csv - vsg
#
# Philips Fidelio X2HR L.csv:
#   Philips Fidelio X2HR L.csv - vsg
#   Philips Fidelio X2HR R.csv - vsg
#
# Philips Fidelio X3 L.csv:
#   Philips Fidelio X3 L.csv - vsg
#   Philips Fidelio X3 R.csv - vsg
#
# Sennheiser CX True Wireless L.csv:
#   Sennheiser CX True Wireless L.csv - vsg
#   Sennheiser CX True Wireless R.csv - vsg
#
# Sennheiser HD 598 L.csv:
#   Sennheiser HD 598 L.csv - vsg
#   Sennheiser HD 598 R.csv - vsg
#
# Sennheiser x Drop HD 6XX L.csv:
#   Sennheiser x Drop HD 6XX L.csv - vsg
#   Sennheiser x Drop HD 6XX R.csv - vsg
#
# Sivga Oriole L.csv:
#   Sivga Oriole L.csv - vsg
#   Sivga Oriole R.csv - vsg
#
# Sivga Phoenix L.csv:
#   Sivga Phoenix L.csv - vsg
#   Sivga Phoenix R.csv - vsg
#
# Sivga Robin (SV021) L.csv:
#   Sivga Robin (SV021) L.csv - vsg
#   Sivga Robin (SV021) R.csv - vsg
#
# Sivga SV023 L.csv:
#   Sivga SV023 L.csv - vsg
#   Sivga SV023 R.csv - vsg
#
# Technics AZ70 L.csv:
#   Technics AZ70 L.csv - vsg
#   Technics AZ70 R.csv - vsg
#
# ThieAudio Wraith L.csv:
#   ThieAudio Wraith L.csv - vsg
#   ThieAudio Wraith Pad A L.csv - vsg
#   ThieAudio Wraith Pad A R.csv - vsg
#   ThieAudio Wraith Pad B L.csv - vsg
#   ThieAudio Wraith Pad B R.csv - vsg
#   ThieAudio Wraith R.csv - vsg
#
# Tronsmart Apollo Air+ L.csv:
#   Tronsmart Apollo Air+ L.csv - vsg
#   Tronsmart Apollo Air+ R.csv - vsg
#
# UA Complimentary 1 L.csv:
#   UA Complimentary 1 L.csv - vsg
#   UA Complimentary 1 R.csv - vsg
#
# UA Complimentary 2 L.csv:
#   UA Complimentary 2 L.csv - vsg
#   UA Complimentary 2 R.csv - vsg
#
# Ugreen HiTune T3 L.csv:
#   Ugreen HiTune T3 L.csv - vsg
#   Ugreen HiTune T3 R.csv - vsg
#
# Westone MACH 10 L.csv:
#   Westone MACH 10 L.csv - vsg
#   Westone MACH 10 R.csv - vsg
#
# Westone MACH 20 L.csv:
#   Westone MACH 20 L.csv - vsg
#   Westone MACH 20 R.csv - vsg
#
# Westone MACH 30 L.csv:
#   Westone MACH 30 L.csv - vsg
#   Westone MACH 30 R.csv - vsg
#
# Westone MACH 40 L.csv:
#   Westone MACH 40 L.csv - vsg
#   Westone MACH 40 R.csv - vsg
#
# Westone MACH 50 L.csv:
#   Westone MACH 50 L.csv - vsg
#   Westone MACH 50 R.csv - vsg
#
# Westone MACH 70 L.csv:
#   Westone MACH 70 L.csv - vsg
#   Westone MACH 70 R.csv - vsg
#
# Westone MACH 80 L.csv:
#   Westone MACH 80 L.csv - vsg
#   Westone MACH 80 R.csv - vsg
#
# Zephone Tiger L.csv:
#   Zephone Tiger L.csv - vsg
#   Zephone Tiger R.csv - vsg
#
# 710 Btnc (Active, ANC off) L.csv:
#   710 Btnc (Active, ANC off) L.csv - wdym
#   710 Btnc (Active, ANC on) L.csv - wdym
#   710 Btnc (Passive) L.csv - wdym
#
# Elegia (Stock Pads) L.csv:
#   Elegia (Stock Pads) L.csv - wdym
#
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) L.csv:
#   Elex (Dekoni Elite Fenestrated Sheepskin Pads) L.csv - wdym
#   Elex (Elear Pads) L.csv - wdym
#   Elex (Stock Pads) L.csv - wdym
#   Elex (Utopia Pads) L.csv - wdym
#
# test L.csv:
#   test L.csv - akros
#
# 64 Audio Nio (Fir black) L.csv:
#   64 Audio Nio (Fir black) L.csv - data_mrs
#   64 Audio Nio (Fir black) R.csv - data_mrs
#   64 Audio Nio (Fir red) L.csv - data_mrs
#   64 Audio Nio (Fir red) R.csv - data_mrs
#   64 Audio Nio (m12) L.csv - data_mrs
#   64 Audio Nio (m12) R.csv - data_mrs
#   64 Audio Nio (m15) L.csv - data_mrs
#   64 Audio Nio (m15) R.csv - data_mrs
#   64 Audio Nio (m20) L.csv - data_mrs
#   64 Audio Nio (m20) R.csv - data_mrs
#   64 Audio Nio (mX) L.csv - data_mrs
#   64 Audio Nio (mX) R.csv - data_mrs
#   64 Audio Nio (S1 - m15) L.csv - data_mrs
#   64 Audio Nio (S1 - m20) L.csv - data_mrs
#   64 Audio Nio (S1 - mX) L.csv - data_mrs
#
# Akoustyx R-120 L.csv:
#   Akoustyx R-120 L.csv - data_mrs
#
# Akoustyx S-6 (S2) L.csv:
#   Akoustyx S-6 (S2) L.csv - data_mrs
#   Akoustyx S-6 (S2) R.csv - data_mrs
#   Akoustyx S-6 (Tanchjim) L.csv - data_mrs
#   Akoustyx S-6 (Tanchjim) R.csv - data_mrs
#   Akoustyx S-6 L.csv - data_mrs
#   Akoustyx S-6 R.csv - data_mrs
#
# Brainwavz Koel L.csv:
#   Brainwavz Koel L.csv - data_mrs
#
# Campfire Audio Andromeda 2019 L.csv:
#   Campfire Audio Andromeda 2019 L.csv - data_mrs
#
# Campfire Audio Ara L.csv:
#   Campfire Audio Ara L.csv - data_mrs
#   Campfire Audio Ara R.csv - data_mrs
#
# Campfire Audio Dorado 2020 L.csv:
#   Campfire Audio Dorado 2020 L.csv - data_mrs
#   Campfire Audio Dorado 2020 R.csv - data_mrs
#
# Campfire Audio Pathfinder L.csv:
#   Campfire Audio Pathfinder L.csv - data_mrs
#   Campfire Audio Pathfinder R.csv - data_mrs
#
# Cayin Fantasy L.csv:
#   Cayin Fantasy L.csv - data_mrs
#
# Co-Donguri Shizuku L.csv:
#   Co-Donguri Shizuku L.csv - data_mrs
#
# Colorfly Quintet L.csv:
#   Colorfly Quintet L.csv - data_mrs
#   Colorfly Quintet R.csv - data_mrs
#
# Dunu SA3 L.csv:
#   Dunu SA3 L.csv - data_mrs
#
# Dunu Vulka (S2 + red) L.csv:
#   Dunu Vulka (S2 + red) L.csv - data_mrs
#
# Empire Ears Bravado mkII L.csv:
#   Empire Ears Bravado mkII L.csv - data_mrs
#
# Empire Ears ESR mkII L.csv:
#   Empire Ears ESR mkII L.csv - data_mrs
#
# Empire Ears Valkyrie mkII L.csv:
#   Empire Ears Valkyrie mkII L.csv - data_mrs
#
# Etymotic ER4S L.csv:
#   Etymotic ER4S L.csv - data_mrs
#   Etymotic ER4S R.csv - data_mrs
#
# Etymotic ETY Kids L.csv:
#   Etymotic ETY Kids L.csv - data_mrs
#
# Etymotic MK5 L.csv:
#   Etymotic MK5 L.csv - data_mrs
#
# Etyotic ER2XR (S2) L.csv:
#   Etyotic ER2XR (S2) L.csv - data_mrs
#
# Fiio FA1 L.csv:
#   Fiio FA1 L.csv - data_mrs
#
# FLC 8P (gold-black-gunmetal) L.csv:
#   FLC 8P (gold-black-gunmetal) L.csv - data_mrs
#   FLC 8P (gold-black-red) L.csv - data_mrs
#   FLC 8P (gold-gray-gunmetal) L.csv - data_mrs
#   FLC 8P (gold-white-gunmetal) L.csv - data_mrs
#   FLC 8P (gold-white-transparent) L.csv - data_mrs
#   FLC 8P (green-gray-gunmetal) L.csv - data_mrs
#   FLC 8P (gunmetal-black-gunmetal) L.csv - data_mrs
#   FLC 8P (gunmetal-gray-gunmetal) L.csv - data_mrs
#   FLC 8P (silver-gray-gunmetal) L.csv - data_mrs
#
# FLC DD31 L.csv:
#   FLC DD31 L.csv - data_mrs
#
# GS Audio GD3C L.csv:
#   GS Audio GD3C L.csv - data_mrs
#   GS Audio GD3C R.csv - data_mrs
#
# HarmonicDyne PD1 L.csv:
#   HarmonicDyne PD1 L.csv - data_mrs
#   HarmonicDyne PD1 R.csv - data_mrs
#
# Haylou GT1 L.csv:
#   Haylou GT1 L.csv - data_mrs
#
# Haylou GT2 L.csv:
#   Haylou GT2 L.csv - data_mrs
#   Haylou GT2 R.csv - data_mrs
#
# Hiby Crystal6 II L.csv:
#   Hiby Crystal6 II L.csv - data_mrs
#   Hiby Crystal6 II R.csv - data_mrs
#   Hiby Crystal6 L.csv - data_mrs
#
# Hifiman Bolt L.csv:
#   Hifiman Bolt L.csv - data_mrs
#
# iBasso IT01X (S2) L.csv:
#   iBasso IT01X (S2) L.csv - data_mrs
#   iBasso IT01X (S2) R.csv - data_mrs
#   iBasso IT01X L.csv - data_mrs
#   iBasso IT01X R.csv - data_mrs
#
# JH Audio Layla (max) L.csv:
#   JH Audio Layla (max) L.csv - data_mrs
#   JH Audio Layla (max) R.csv - data_mrs
#   JH Audio Layla (min) L.csv - data_mrs
#   JH Audio Layla (min) R.csv - data_mrs
#
# JVC FWX1 L.csv:
#   JVC FWX1 L.csv - data_mrs
#   JVC FWX1 R.csv - data_mrs
#
# JVC FX7 L.csv:
#   JVC FX7 L.csv - data_mrs
#   JVC FX7 R.csv - data_mrs
#
# Kinera Sif L.csv:
#   Kinera Sif L.csv - data_mrs
#
# Letshuoer Singer L.csv:
#   Letshuoer Singer L.csv - data_mrs
#
# LG HBS800 (ANC off) L.csv:
#   LG HBS800 (ANC off) L.csv - data_mrs
#   LG HBS800 (ANC off) R.csv - data_mrs
#   LG HBS800 (ANC on) L.csv - data_mrs
#   LG HBS800 (ANC on) R.csv - data_mrs
#   LG HBS800 L.csv - data_mrs
#   LG HBS800 R.csv - data_mrs
#
# Magaosi K3 (F0) L.csv:
#   Magaosi K3 (F0) L.csv - data_mrs
#   Magaosi K3 (F0) R.csv - data_mrs
#   Magaosi K3 (F1) L.csv - data_mrs
#   Magaosi K3 (F1) R.csv - data_mrs
#   Magaosi K3 (F2) L.csv - data_mrs
#   Magaosi K3 (F2) R.csv - data_mrs
#   Magaosi K3 L.csv - data_mrs
#
# Magaosi K5 (15 ohm + IEMatch+ ultra) L.csv:
#   Magaosi K5 (15 ohm + IEMatch+ ultra) L.csv - data_mrs
#   Magaosi K5 (15 ohm + IEMatch+) L.csv - data_mrs
#   Magaosi K5 (15 ohm) L.csv - data_mrs
#   Magaosi K5 L.csv - data_mrs
#
# MEE Audio M6 Pro 2G L.csv:
#   MEE Audio M6 Pro 2G L.csv - data_mrs
#
# Meizu Live (black) L.csv:
#   Meizu Live (black) L.csv - data_mrs
#   Meizu Live (blue) L.csv - data_mrs
#   Meizu Live (white) L.csv - data_mrs
#
# Mi True Wireless Earbuds Basic 2 L.csv:
#   Mi True Wireless Earbuds Basic 2 L.csv - data_mrs
#
# Moondrop Solis L.csv:
#   Moondrop Solis L.csv - data_mrs
#   Moondrop Solis R.csv - data_mrs
#   Moondrop Solis S2 L.csv - data_mrs
#   Moondrop Solis S2 R.csv - data_mrs
#
# Nothing Ear 2 (balanced) L.csv:
#   Nothing Ear 2 (balanced) L.csv - data_mrs
#   Nothing Ear 2 (balanced) R.csv - data_mrs
#   Nothing Ear 2 (more bass) L.csv - data_mrs
#   Nothing Ear 2 (more bass) R.csv - data_mrs
#   Nothing Ear 2 (more treble) L.csv - data_mrs
#   Nothing Ear 2 (more treble) R.csv - data_mrs
#   Nothing Ear 2 (personalized B) L.csv - data_mrs
#   Nothing Ear 2 (personalized B) R.csv - data_mrs
#   Nothing Ear 2 (personalized) L.csv - data_mrs
#   Nothing Ear 2 (personalized) R.csv - data_mrs
#   Nothing Ear 2 (treble -6) L.csv - data_mrs
#   Nothing Ear 2 (treble -6) R.csv - data_mrs
#   Nothing Ear 2 (voice) L.csv - data_mrs
#   Nothing Ear 2 (voice) R.csv - data_mrs
#   Nothing Ear 2 L.csv - data_mrs
#   Nothing Ear 2 R.csv - data_mrs
#
# OpenAudio Mercury L.csv:
#   OpenAudio Mercury L.csv - data_mrs
#   OpenAudio Mercury R.csv - data_mrs
#
# Oriolus 2nd Gen L.csv:
#   Oriolus 2nd Gen L.csv - data_mrs
#
# Philips SHE3590PK L.csv:
#   Philips SHE3590PK L.csv - data_mrs
#
# Phonak Audeo PFE 112 L.csv:
#   Phonak Audeo PFE 112 L.csv - data_mrs
#   Phonak Audeo PFE 112 R.csv - data_mrs
#
# Pre-Prod 03 (nozzle A) L.csv:
#   Pre-Prod 03 (nozzle A) L.csv - data_mrs
#   Pre-Prod 03 (nozzle A) R.csv - data_mrs
#   Pre-Prod 03 (nozzle B) L.csv - data_mrs
#   Pre-Prod 03 (nozzle B) R.csv - data_mrs
#
# QDC Anole V14 (0000) L.csv:
#   QDC Anole V14 (0000) L.csv - data_mrs
#   QDC Anole V14 (0001) L.csv - data_mrs
#   QDC Anole V14 (0010) L.csv - data_mrs
#   QDC Anole V14 (0100) L.csv - data_mrs
#   QDC Anole V14 (1000) L.csv - data_mrs
#
# QDC Neptune L.csv:
#   QDC Neptune L.csv - data_mrs
#
# QDC Uranus L.csv:
#   QDC Uranus L.csv - data_mrs
#
# Radius HP-NEF11 L.csv:
#   Radius HP-NEF11 L.csv - data_mrs
#   Radius HP-NEF11 R.csv - data_mrs
#
# Samsung Earphones (2019) L.csv:
#   Samsung Earphones (2019) L.csv - data_mrs
#   Samsung Earphones L.csv - data_mrs
#
# Sennheiser IE 200 (Azla Max) L.csv:
#   Sennheiser IE 200 (Azla Max) L.csv - data_mrs
#   Sennheiser IE 200 (Azla Max) R.csv - data_mrs
#   Sennheiser IE 200 (D1) L.csv - data_mrs
#   Sennheiser IE 200 (D1) R.csv - data_mrs
#   Sennheiser IE 200 (D2) L.csv - data_mrs
#   Sennheiser IE 200 (D2) R.csv - data_mrs
#   Sennheiser IE 200 (Spiral Dot) L.csv - data_mrs
#   Sennheiser IE 200 (Spiral Dot) R.csv - data_mrs
#   Sennheiser IE 200 (UC tips) L.csv - data_mrs
#   Sennheiser IE 200 (UC tips) R.csv - data_mrs
#
# Sennheiser IE 300 (AutoEQ) L.csv:
#   Sennheiser IE 300 (AutoEQ) L.csv - data_mrs
#   Sennheiser IE 300 (Final E) L.csv - data_mrs
#   Sennheiser IE 300 (Sedna Light) L.csv - data_mrs
#   Sennheiser IE 300 L.csv - data_mrs
#
# Sennheiser IE 600 (E-type shallow) L.csv:
#   Sennheiser IE 600 (E-type shallow) L.csv - data_mrs
#   Sennheiser IE 600 (E-type shallow) R.csv - data_mrs
#   Sennheiser IE 600 (E-type) L.csv - data_mrs
#   Sennheiser IE 600 (E-type) R.csv - data_mrs
#   Sennheiser IE 600 (foam) L.csv - data_mrs
#   Sennheiser IE 600 (foam) R.csv - data_mrs
#   Sennheiser IE 600 (Sedna) L.csv - data_mrs
#   Sennheiser IE 600 (Sedna) R.csv - data_mrs
#   Sennheiser IE 600 (Spinfit) L.csv - data_mrs
#   Sennheiser IE 600 (Spinfit) R.csv - data_mrs
#   Sennheiser IE 600 (Spring tips) L.csv - data_mrs
#   Sennheiser IE 600 (Spring tips) R.csv - data_mrs
#   Sennheiser IE 600 L.csv - data_mrs
#   Sennheiser IE 600 R.csv - data_mrs
#
# Sennheiser Momentum TW3 L.csv:
#   Sennheiser Momentum TW3 L.csv - data_mrs
#   Sennheiser Momentum TW3 R.csv - data_mrs
#
# Sennheiser MTW2 (HE) L.csv:
#   Sennheiser MTW2 (HE) L.csv - data_mrs
#   Sennheiser MTW2 L.csv - data_mrs
#
# Shanling ME700 Lite L.csv:
#   Shanling ME700 Lite L.csv - data_mrs
#
# Shozy CP L.csv:
#   Shozy CP L.csv - data_mrs
#
# Shozy Rouge L.csv:
#   Shozy Rouge L.csv - data_mrs
#
# Simgot EN700 Pro (Moondrop) L.csv:
#   Simgot EN700 Pro (Moondrop) L.csv - data_mrs
#   Simgot EN700 Pro (Tanchjim) L.csv - data_mrs
#   Simgot EN700 Pro L.csv - data_mrs
#
# Softears Studio4 L.csv:
#   Softears Studio4 L.csv - data_mrs
#   Softears Studio4 R.csv - data_mrs
#
# Sony IER-NW510N L.csv:
#   Sony IER-NW510N L.csv - data_mrs
#
# Sony MDR-AS800 L.csv:
#   Sony MDR-AS800 L.csv - data_mrs
#   Sony MDR-AS800 R.csv - data_mrs
#
# Sony MH1 L.csv:
#   Sony MH1 L.csv - data_mrs
#   Sony MH1 R.csv - data_mrs
#
# Status Audio IEM-2X L.csv:
#   Status Audio IEM-2X L.csv - data_mrs
#
# Tanchjim Darling (depth 1) L.csv:
#   Tanchjim Darling (depth 1) L.csv - data_mrs
#   Tanchjim Darling (depth 2) L.csv - data_mrs
#
# Tansio Mirai Spark (010) L.csv:
#   Tansio Mirai Spark (010) L.csv - data_mrs
#   Tansio Mirai Spark (110) L.csv - data_mrs
#   Tansio Mirai Spark (111) L.csv - data_mrs
#
# Tenhz 3BA L.csv:
#   Tenhz 3BA L.csv - data_mrs
#
# Tenhz P4 Pro L.csv:
#   Tenhz P4 Pro L.csv - data_mrs
#
# Thinksound Rain3 L.csv:
#   Thinksound Rain3 L.csv - data_mrs
#   Thinksound Rain3 R.csv - data_mrs
#
# Tin Hifi C5 L.csv:
#   Tin Hifi C5 L.csv - data_mrs
#   Tin Hifi C5 R.csv - data_mrs
#
# TRN IM1 L.csv:
#   TRN IM1 L.csv - data_mrs
#
# TRN V30 L.csv:
#   TRN V30 L.csv - data_mrs
#
# Ucotech RE-2 L.csv:
#   Ucotech RE-2 L.csv - data_mrs
#   Ucotech RE-2 R.csv - data_mrs
#
# Vision Ears VE7 L.csv:
#   Vision Ears VE7 L.csv - data_mrs
#   Vision Ears VE7 R.csv - data_mrs
#
# Vsonic GR07 (Bass) L.csv:
#   Vsonic GR07 (Bass) L.csv - data_mrs
#   Vsonic GR07 L.csv - data_mrs
#   Vsonic GR07 R.csv - data_mrs
#
# Yinfu MD51 L.csv:
#   Yinfu MD51 L.csv - data_mrs

# %% [markdown]
# ### Dataframe

# %%
# ... (previous code remains unchanged)

# Prepare the data for the DataFrame
iem_data = defaultdict(lambda: defaultdict(list))

for representative, files in grouped_files.items():
    for file in files:
        reviewers_with_file = [reviewer for reviewer, f in all_files if f == file]
        for reviewer in reviewers_with_file:
            iem_data[representative][reviewer].append(file)

# Convert the nested dictionary to a pandas DataFrame
iem_df = pd.DataFrame.from_dict(iem_data, orient='index')

# Fill empty cells with an empty list
iem_df = iem_df.applymap(lambda x: x if isinstance(x, list) else [])

# %%
iem_df
# Out:
#                                                              achoreviews  \
# 7Hz Dioko L.csv                                        [7Hz Dioko L.csv]
# 7Hz Eternal L.csv                                    [7Hz Eternal L.csv]
# 7Hz Legato L.csv                                      [7Hz Legato L.csv]
# 7Hz Timeless L.csv                                  [7Hz Timeless L.csv]
# 7Hz Zero L.csv                                          [7Hz Zero L.csv]
# ...                                                                  ...
# 710 Btnc (Active, ANC off) L.csv                                      []
# Elegia (Stock Pads) L.csv                                             []
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...                    []
# Ola L.csv                                                             []
# test L.csv                                                            []
#
#                                                                                    bedrock  \
# 7Hz Dioko L.csv                                         [7Hz Dioko L.csv, 7Hz Dioko R.csv]
# 7Hz Eternal L.csv                                   [7Hz Eternal L.csv, 7Hz Eternal R.csv]
# 7Hz Legato L.csv                                                                        []
# 7Hz Timeless L.csv                                                                      []
# 7Hz Zero L.csv                                            [7Hz Zero L.csv, 7Hz Zero R.csv]
# ...                                                                                    ...
# 710 Btnc (Active, ANC off) L.csv                                                        []
# Elegia (Stock Pads) L.csv                                                               []
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...                                      []
# Ola L.csv                                                                               []
# test L.csv                                                                              []
#
#                                                                                                timmyv  \
# 7Hz Dioko L.csv                                                    [7Hz Dioko L.csv, 7Hz Dioko R.csv]
# 7Hz Eternal L.csv                                                                                  []
# 7Hz Legato L.csv                                                 [7Hz Legato L.csv, 7Hz Legato R.csv]
# 7Hz Timeless L.csv                                  [7Hz Timeless L.csv, 7Hz Timeless R.csv, 7Hz T...
# 7Hz Zero L.csv                                                       [7Hz Zero L.csv, 7Hz Zero R.csv]
# ...                                                                                               ...
# 710 Btnc (Active, ANC off) L.csv                                                                   []
# Elegia (Stock Pads) L.csv                                                                          []
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...                                                 []
# Ola L.csv                                                                                          []
# test L.csv                                                                                         []
#
#                                                
# ...                                                                                               ...
# 710 Btnc (Active, ANC off) L.csv                                                                   []
# Elegia (Stock Pads) L.csv                                                                          []
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...                                                 []
# Ola L.csv                                                                                          []
# test L.csv                                                                                         []
#
#                                                     ...  \
# 7Hz Dioko L.csv                                     ...
# 7Hz Eternal L.csv                                   ...
# 7Hz Legato L.csv                                    ...
# 7Hz Timeless L.csv                                  ...
# 7Hz Zero L.csv                                      ...
# ...                                                 ...
# 710 Btnc (Active, ANC off) L.csv                    ...
# Elegia (Stock Pads) L.csv                           ...
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...  ...
# Ola L.csv                                           ...
# test L.csv                                          ...
#
#                                                                       recode  \
# 7Hz Dioko L.csv                                                           []
# 7Hz Eternal L.csv                                                         []
# 7Hz Legato L.csv                                                          []
# 7Hz Timeless L.csv                                                        []
# 7Hz Zero L.csv                                      [zero L.csv, zero R.csv]
# ...                                                                      ...
# 710 Btnc (Active, ANC off) L.csv                                          []
# Elegia (Stock Pads) L.csv                                                 []
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...                        []
# Ola L.csv                                                                 []
# test L.csv                                                                []
#
#                                                    animagus bryaudioreviews  \
# 7Hz Dioko L.csv                                          []              []
# 7Hz Eternal L.csv                                        []              []
# 7Hz Legato L.csv                                         []              []
# 7Hz Timeless L.csv                                       []              []
# 7Hz Zero L.csv                                           []              []
# ...                                                     ...             ...
# 710 Btnc (Active, ANC off) L.csv                         []              []
# Elegia (Stock Pads) L.csv                                []              []
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...       []              []
# Ola L.csv                                                []              []
# test L.csv                                               []              []
#
#                                                    cammyfi eplv melatonin  \
# 7Hz Dioko L.csv                                         []   []        []
# 7Hz Eternal L.csv                                       []   []        []
# 7Hz Legato L.csv                                        []   []        []
# 7Hz Timeless L.csv                                      []   []        []
# 7Hz Zero L.csv                                          []   []        []
# ...                                                    ...  ...       ...
# 710 Btnc (Active, ANC off) L.csv                        []   []        []
# Elegia (Stock Pads) L.csv                               []   []        []
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...      []   []        []
# Ola L.csv                                               []   []        []
# test L.csv                                              []   []        []
#
#                                                    shortbus suporsalad  \
# 7Hz Dioko L.csv                                          []         []
# 7Hz Eternal L.csv                                        []         []
# 7Hz Legato L.csv                                         []         []
# 7Hz Timeless L.csv                                       []         []
# 7Hz Zero L.csv                                           []         []
# ...                                                     ...        ...
# 710 Btnc (Active, ANC off) L.csv                         []         []
# Elegia (Stock Pads) L.csv                                []         []
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...       []         []
# Ola L.csv                                                []         []
# test L.csv                                               []         []
#
#                                                                                                  wdym  \
# 7Hz Dioko L.csv                                                                                    []
# 7Hz Eternal L.csv                                                                                  []
# 7Hz Legato L.csv                                                                                   []
# 7Hz Timeless L.csv                                                                                 []
# 7Hz Zero L.csv                                                                                     []
# ...                                                                                               ...
# 710 Btnc (Active, ANC off) L.csv                    [710 Btnc (Active, ANC off) L.csv, 710 Btnc (A...
# Elegia (Stock Pads) L.csv                                                 [Elegia (Stock Pads) L.csv]
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...  [Elex (Dekoni Elite Fenestrated Sheepskin Pads...
# Ola L.csv                                                                                          []
# test L.csv                                                                                         []
#
#                                                                 akros
# 7Hz Dioko L.csv                                                    []
# 7Hz Eternal L.csv                                                  []
# 7Hz Legato L.csv                                                   []
# 7Hz Timeless L.csv                                                 []
# 7Hz Zero L.csv                                                     []
# ...                                                               ...
# 710 Btnc (Active, ANC off) L.csv                                   []
# Elegia (Stock Pads) L.csv                                          []
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) ...                 []
# Ola L.csv                                           [Ola Stock L.csv]
# test L.csv                                               [test L.csv]
#
# [2356 rows x 32 columns]

# %% [markdown]
# ### Average

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.signal import savgol_filter

# %%
def read_and_interpolate(file_path, x_values):
    df = pd.read_csv(file_path)

    # Check if 'Y' column is present in the DataFrame
    if 'Y' not in df.columns:
        raise KeyError("Missing 'Y' column in the DataFrame")

    # Group data points by the same X-value and take the mean of their Y-values
    df = df.groupby('X', as_index=False).mean(numeric_only=True)

    min_x = df['X'].min()
    max_x = df['X'].max()
    x_values_interp = x_values[(x_values >= min_x) & (x_values <= max_x)]
    f = interp1d(df['X'], df['Y'], kind='linear', fill_value='extrapolate')
    y_values = np.empty_like(x_values)
    y_values[:] = np.nan
    y_values[(x_values >= min_x) & (x_values <= max_x)] = f(x_values_interp)
    return y_values

# %%
def generate_x_values():
    x_values = np.logspace(np.log10(20), np.log10(20000), num=1000)
    return np.concatenate(([0], x_values))

# %%
def calculate_average(file_paths, output_path):
    x_values = generate_x_values()

# %%
def find_mean_in_range(data, x_min, x_max):
    values = [df.loc[(df['X'] >= x_min) & (df['X'] <= x_max), 'Y'].dropna() for df in data]
    non_empty_values = [v for v in values if len(v) > 0]

    if not non_empty_values:
        return np.nan

    combined_values = np.concatenate(non_empty_values)
    return np.nanmean(combined_values)

# %%
def calculate_average(file_paths, output_path):
    x_values = generate_x_values()

    # Read and interpolate all .csv files
    data = []
    for file_path in file_paths:
        try:
            interpolated_data = read_and_interpolate(file_path, x_values)
            # Create a DataFrame with the interpolated data
            interpolated_df = pd.DataFrame({'X': x_values, 'Y': interpolated_data})
            data.append(interpolated_df)
        except KeyError as e:
            print(f"KeyError in {file_path}: {e}. Skipping this file.")

    average = []
    for x_min, x_max in zip(x_values[:-1], x_values[1:]):
        mean = find_mean_in_range(data, x_min, x_max)
        average.append(mean)

    # Save average to .csv
    df = pd.DataFrame({'X': x_values[:-1], 'Y': average})
    df.to_csv(output_path, index=False)

    return x_values, average, data

# %%
def calculate_iem_average(iem, reviewers_files, output_directory):
    #print(f"Reviewers_files for {iem}:\n{reviewers_files}\n")  # Add this line for debugging
    
    file_paths = []
    for reviewer in reviewers_files.index:
        files = reviewers_files[reviewer]
        if files:
            for file in files:  # Add this loop to iterate over the file paths in each cell
                file_path = os.path.join(output_directory, '..', 'csv', reviewer, file).replace('\\', '/')
                file_paths.append(file_path)

    output_path = os.path.join(output_directory, f"Average_{iem}.csv")

    x_values, average, data = calculate_average(file_paths, output_path)
    return x_values, average, data

# %%
# Create a new DataFrame to store the average measurements
avg_df = pd.DataFrame(columns=['IEM', 'Average Measurement', 'Reviewers'])

# %%
# Calculate the average for each IEM
output_directory = 'output/averages'
os.makedirs(output_directory, exist_ok=True)

# %%
for iem, reviewers_files in iem_df.iterrows():
    x_values, average, data = calculate_iem_average(iem, reviewers_files, output_directory)

    avg_df = pd.concat([avg_df, pd.DataFrame([{
        'IEM': iem,
        'Average Measurement': average,
        'Reviewers': {reviewer: files for reviewer, files in reviewers_files.items() if files}
    }], index=[0])], ignore_index=True)
# Out:
# KeyError in output/averages/../csv/hbb/HBB 1 R.csv: 'Y'. Skipping this file.
# KeyError in output/averages/../csv/vsg/Ugreen HiTune T3 L.csv: 'Y'. Skipping this file.

# %%
avg_df
# Out:
#                                                     IEM  \
# 0                                       7Hz Dioko L.csv
# 1                                     7Hz Eternal L.csv
# 2                                      7Hz Legato L.csv
# 3                                    7Hz Timeless L.csv
# 4                                        7Hz Zero L.csv
# ...                                                 ...
# 2351                   710 Btnc (Active, ANC off) L.csv
# 2352                          Elegia (Stock Pads) L.csv
# 2353  Elex (Dekoni Elite Fenestrated Sheepskin Pads)...
# 2354                                          Ola L.csv
# 2355                                         test L.csv
#
#                                     Average Measurement  \
# 0     [87.02973913043476, 87.02921538582903, 87.0281...
# 1     [81.9075, 81.90825430746554, 81.90662147303475...
# 2     [86.40225, 86.40302850929731, 86.4045909296810...
# 3     [79.6973817751938, 79.70461227888228, 79.71955...
# 4     [85.48116781818182, 85.48417048438543, 85.4908...
# ...                                                 ...
# 2351  [73.60333333333334, 73.6313962428586, 73.68771...
# 2352  [78.959, 78.97773430498528, 79.01533290539408,...
# 2353  [70.5, 70.53076126621039, 70.59249723972114, 7...
# 2354  [74.668, 74.6497282095405, 74.61305784740108, ...
# 2355  [nan, nan, nan, 72.89712704463912, 72.90216994...
#
#                                               Reviewers
# 0     {'achoreviews': ['7Hz Dioko L.csv'], 'bedrock'...
# 1     {'achoreviews': ['7Hz Eternal L.csv'], 'bedroc...
# 2     {'achoreviews': ['7Hz Legato L.csv'], 'timmyv'...
# 3     {'achoreviews': ['7Hz Timeless L.csv'], 'timmy...
# 4     {'achoreviews': ['7Hz Zero L.csv'], 'bedrock':...
# ...                                                 ...
# 2351  {'wdym': ['710 Btnc (Active, ANC off) L.csv', ...
# 2352            {'wdym': ['Elegia (Stock Pads) L.csv']}
# 2353  {'wdym': ['Elex (Dekoni Elite Fenestrated Shee...
# 2354                     {'akros': ['Ola Stock L.csv']}
# 2355                          {'akros': ['test L.csv']}
#
# [2356 rows x 3 columns]

# %%
print(avg_df['Average Measurement'].to_string(index=False))
# Out:
# [87.02973913043476, 87.02921538582903, 87.02816...
# [81.9075, 81.90825430746554, 81.90662147303475,...
# [86.40225, 86.40302850929731, 86.40459092968104...
# [79.6973817751938, 79.70461227888228, 79.719559...
# [85.48116781818182, 85.48417048438543, 85.49084...
# [72.25953534185213, 72.25885762255763, 72.25001...
# [nan, nan, nan, 83.5085502104203, 83.5130367729...
# [58.4, 58.4, 58.4, 80.70259167489402, 83.499705...
# [86.1115, 86.11045920180928, 86.10837038371271,...
# [83.85133333333333, 83.86167493491506, 83.88242...
# [nan, nan, nan, 84.34163338652131, 84.346870386...
# [91.011156125, 91.01335472444474, 91.0177671786...
# [nan, nan, nan, 94.52515283092448, 94.529403258...
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, n...
# [nan, nan, nan, 83.20452400537833, 83.211371916...
# [83.003, 83.01387055888097, 83.03568710344493, ...
# [nan, nan, nan, 96.5589475899161, 96.5636702873...
# [83.509, 83.51200675032878, 83.51804111371882, ...
# [91.629, 91.63501350065756, 91.64708222743762, ...
# [78.994, 78.98382330657952, 78.96339930741325, ...
# [nan, nan, nan, 77.00203930756292, 76.998497284...
# [81.559, 81.55876871151317, 81.55830452971394, ...
# [86.026, 86.03386380855218, 86.04964598972612, ...
# [nan, nan, nan, 87.17678165647064, 87.178434600...
# [91.562, 91.59553683059023, 91.66284319147904, ...
# [nan, nan, nan, 82.63456331294127, 82.637869201...
# [106.813, 106.81831963519707, 106.8289958165794...
# [108.873, 108.873, 108.873, 108.87240393075629,...
# [84.752, 84.74598649934244, 84.73391777256238, ...
# [nan, nan, nan, 83.54302620504195, 83.540664856...
# [84.752, 84.74598649934244, 84.73391777256238, ...
# [84.56, 84.55329263388197, 84.5398313617042, 84...
# [84.998, 84.99175521085562, 84.97922230227633, ...
# [96.114, 96.10937423026343, 96.10009059427875, ...
# [84.964, 84.95706134539512, 84.94313589141814, ...
# [87.088, 87.08476196118438, 87.07826341599512, ...
# [nan, nan, nan, 99.3623973794958, 99.3626335143...
# [66.745, 66.73921778782928, 66.72761324284843, ...
# [nan, nan, nan, 95.21995629310985, 95.241916836...
# [nan, nan, nan, 8.271001961011855, 8.3969799154...
# [nan, nan, nan, nan, nan, nan, nan, 83.97171750...
# [nan, nan, nan, nan, nan, nan, nan, 70.74739657...
# [nan, nan, nan, nan, nan, nan, nan, 81.04792314...
# [62.265, 62.26384355756585, 62.26152264856968, ...
# [48.56290699407844, 48.8780076546459, 49.536118...
# [51.693326928651295, 51.769947150065875, 51.919...
# [nan, nan, nan, 67.01357785008442, 67.027588519...
# [74.24693341339186, 74.24597566062417, 74.24453...
# [nan, nan, nan, nan, nan, nan, nan, 72.76056379...
# [nan, nan, nan, 94.06496724369757, 94.067918929...
# [nan, nan, nan, 97.62824234890772, 97.633437316...
# [nan, nan, nan, 98.48917248470596, 98.491651900...
# [nan, nan, nan, 91.43453490823569, 91.449411405...
# [nan, nan, nan, 103.77265718252136, 103.7855265...
# [nan, nan, nan, nan, nan, nan, nan, 78.71631522...
# [nan, nan, nan, 81.26437547832037, 81.302629327...
# [73.60333333333334, 73.6313962428586, 73.687716...
# [78.959, 78.97773430498528, 79.01533290539408, ...
# [70.5, 70.53076126621039, 70.59249723972114, 70...
# [74.668, 74.6497282095405, 74.61305784740108, 7...
# [nan, nan, nan, 72.89712704463912, 72.902169941...

# %% [markdown]
# ### Target Adherence

# %%
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

# %%
def generate_x_values():
    return np.logspace(np.log10(20), np.log10(20000), num=2000)

# %%
def read_and_interpolate(file_path, x_values):
    df = pd.read_csv(file_path)
    min_x = df['X'].min()
    max_x = df['X'].max()
    x_values_interp = x_values[(x_values >= min_x) & (x_values <= max_x)]
    f = interp1d(df['X'], pd.to_numeric(df['Y'], errors='coerce'), kind='linear', fill_value='extrapolate')
    y_values = np.empty_like(x_values)
    y_values[:] = np.nan
    y_values[(x_values >= min_x) & (x_values <= max_x)] = f(x_values_interp)
    return y_values

# %%
def find_mean_in_range(data, x_min, x_max, x_values):
    indices = (x_values >= x_min) & (x_values <= x_max)
    return np.mean(data[indices])

# %%
def target_adherence(average_measurement, target_csv, x_values):
    target_data = read_and_interpolate(target_csv, x_values)

    alignment_freq_range = (200, 10000)  # frequency range for alignment

    input_mean = find_mean_in_range(average_measurement, *alignment_freq_range, x_values)
    target_mean = find_mean_in_range(target_data, *alignment_freq_range, x_values)

    shift = target_mean - input_mean
    average_measurement += shift

    differences = np.abs(target_data - average_measurement)
    
    if np.any(np.isfinite(differences)):
        mean_difference = np.nanmean(differences)
    else:
        mean_difference = 0  # or np.nan if you prefer

    y_range = np.nanmax(target_data) - np.nanmin(target_data)

    adherence = 100 * (1 - mean_difference / y_range)

    return adherence

# %%
def calculate_preference(row, target_csv, x_values):
    average_measurement_file = row['Average Measurement']
    average_measurement = read_and_interpolate(average_measurement_file, x_values)
    return target_adherence(average_measurement, target_csv, x_values)

# %%
# Replace this with the path to your target curve CSV file
target_csv = 'Objectively Neutral IE Target.csv'

# Reuse the x_values generated earlier
x_values = generate_x_values()

# Calculate the Preference % for each IEM
avg_df['Preference %'] = avg_df.apply(calculate_preference, axis=1, args=(target_csv, x_values))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14880\1332091193.py in <module>
#       6
#       7 # Calculate the Preference % for each IEM
# ----> 8 avg_df['Preference %'] = avg_df.apply(calculate_preference, axis=1, args=(target_csv, x_values))
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9563             kwargs=kwargs,
#    9564         )
# -> 9565         return op.apply().__finalize__(self, method="apply")
#    9566
#    9567     def applymap(
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     744             return self.apply_raw()
#     745
# --> 746         return self.apply_standard()
#     747
#     748     def agg(self):
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     871
#     872     def apply_standard(self):
# --> 873         results, res_index = self.apply_series_generator()
#     874
#     875         # wrap results
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     887             for i, v in enumerate(series_gen):
#     888                 # ignore SettingWithCopy here in case the user mutates
# --> 889                 results[i] = self.f(v)
#     890                 if isinstance(results[i], ABCSeries):
#     891                     # If we have a view on v, we need to make a copy because
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\core\apply.py in f(x)
#     137
#     138             def f(x):
# --> 139                 return func(x, *args, **kwargs)
#     140
#     141         else:
#
# ~\AppData\Local\Temp\ipykernel_14880\1850322424.py in calculate_preference(row, target_csv, x_values)
#       1 def calculate_preference(row, target_csv, x_values):
#       2     average_measurement_file = row['Average Measurement']
# ----> 3     average_measurement = read_and_interpolate(average_measurement_file, x_values)
#       4     return target_adherence(average_measurement, target_csv, x_values)
#
# ~\AppData\Local\Temp\ipykernel_14880\1327374734.py in read_and_interpolate(file_path, x_values)
#       1 def read_and_interpolate(file_path, x_values):
# ----> 2     df = pd.read_csv(file_path)
#       3     min_x = df['X'].min()
#       4     max_x = df['X'].max()
#       5     x_values_interp = x_values[(x_values >= min_x) & (x_values <= max_x)]
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# c:\Users\Agnes\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1748         elif engine != "python":
#    1749             msg = f"Invalid file path or buffer object type: {type(f)}"
# -> 1750             raise ValueError(msg)
#    1751
#    1752         try:
#
# ValueError: Invalid file path or buffer object type: <class 'list'>
