# %%
# List of reviewers
reviewers = [
    'achoreviews',
    'aftersound',
    'animagus',
    'arn',
    'bedrock',
    'bryaudioreviews',
    'cammyfi',
    'soundjedi',
    'eplv',
    'timmyv',
    'harpo',
    'hbb',
    'cqtek',
    'hobbytalk',
    'ianfann',
    'iemworld',
    'jacstone',
    'kr0mka',
    'kurin',
    'melatonin',
    'nymz', 
    'pw',
    'recode',
    'rg',
    'shortbus',
    'suporsalad',
    'tgx78',
    'vortexreviews',
    'vsg',
    'wdym',
    'akros',
    'data_mrs'
]

# %%
#from fuzzywuzzy import fuzz
#from collections import defaultdict
#
#def group_files_by_iem(files, threshold=80):
#    groups = defaultdict(list)
#    grouped_files = set()
#    
#    for file1 in files:
#        if file1 not in grouped_files:
#            groups[file1].append(file1)
#            grouped_files.add(file1)
#            
#            for file2 in files:
#                if file2 not in grouped_files:
#                    similarity = fuzz.token_set_ratio(file1, file2)
#                    
#                    if similarity >= threshold:
#                        groups[file1].append(file2)
#                        grouped_files.add(file2)
#    
#    return groups

# %%
from fuzzywuzzy import fuzz
from collections import defaultdict
import re

# %%
def custom_similarity(file1, file2):
    brand_pattern = r'^(.*?)\s'
    iem_pattern = r'\s(.*?)\s'
    variation_pattern = r'\s(.*)$'
    
    brand1 = re.search(brand_pattern, file1).group(1) if re.search(brand_pattern, file1) else ''
    iem1 = re.search(iem_pattern, file1).group(1) if re.search(iem_pattern, file1) else ''
    variation1 = re.search(variation_pattern, file1).group(1) if re.search(variation_pattern, file1) else ''
    
    brand2 = re.search(brand_pattern, file2).group(1) if re.search(brand_pattern, file2) else ''
    iem2 = re.search(iem_pattern, file2).group(1) if re.search(iem_pattern, file2) else ''
    variation2 = re.search(variation_pattern, file2).group(1) if re.search(variation_pattern, file2) else ''
    
    brand_similarity = fuzz.token_set_ratio(brand1, brand2)
    iem_similarity = fuzz.token_set_ratio(iem1, iem2)
    variation_similarity = fuzz.token_set_ratio(variation1, variation2)
    
    return brand_similarity, iem_similarity, variation_similarity

# %%
def group_files_by_iem(files, threshold=85):
    groups = defaultdict(list)
    grouped_files = set()
    
    # Create a special "target" group
    target_group = "target"
    
    for file1 in files:
        if file1 not in grouped_files:
            # Check if the file name contains "target"
            if "target" in file1.lower():
                groups[target_group].append(file1)
                grouped_files.add(file1)
                continue
            
            groups[file1].append(file1)
            grouped_files.add(file1)
            
            for file2 in files:
                if file2 not in grouped_files:
                    similarity = fuzz.token_set_ratio(file1, file2)
                    
                    if similarity >= threshold:
                        groups[file1].append(file2)
                        grouped_files.add(file2)
    
    return groups

# %%
import os

# Gather all file names
all_files = []

for reviewer in reviewers:
    reviewer_path = f'output/csv/{reviewer}'
    
    if os.path.exists(reviewer_path):
        files = os.listdir(reviewer_path)
        all_files.extend([(reviewer, file) for file in files])

# Group files by IEM
grouped_files = group_files_by_iem([file for _, file in all_files])

# %%
# Print the names of the created groups
print("Names of the created groups:")
for group_name in grouped_files.keys():
    print(group_name)
print()
# Out:
# Names of the created groups:
# 7Hz Dioko L.csv
# 7Hz Eternal L.csv
# 7Hz Legato L.csv
# 7Hz Timeless L.csv
# 7Hz Zero L.csv
# target
# Audeze iSine LX (Spinfit) L.csv
# Aune Jasper L.csv
# Blon BL01 L.csv
# Blon Fat Girl L.csv
# Blon Z200 L.csv
# CCA CRA L.csv
# CCZ Emerald L.csv
# CCZ Warrior L.csv
# Celest Pandamon L.csv
# Dunu Kima L.csv
# Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv
# Dunu Titan S (Isolation) L.csv
# Dunu Vulkan L.csv
# Effect Audio Axiom L.csv
# Fiio FHE Eclipse L.csv
# Final Audio E500 L.csv
# Hidition Violet L.csv
# Hifiman RE600s v2 L.csv
# Hifiman Svanar L.csv
# Hifiman TWS800 L.csv
# HZ Sound Heart Mirror Pro L.csv
# Ikko Opal OH02 L.csv
# ITK Unknown L.csv
# Joyodio Shine (0000) L.csv
# KBEAR Lark (S1) L.csv
# KBEAR Little Q L.csv
# KBEAR Qinglong L.csv
# KBEAR Robin L.csv
# Kinera BD005 Pro L.csv
# Kiwi Ears Cadenza L.csv
# Kiwi Ears Orchestra Lite L.csv
# Koss KEB90 L.csv
# KZ AS16 Pro L.csv
# KZ ATE L.csv
# KZ DQ6 L.csv
# KZ EDX L.csv
# KZ PR1 L.csv
# KZ ZAX L.csv
# KZ ZES L.csv
# KZ ZSN Pro X L.csv
# Letshuoer D13 (Gold Filter) L.csv
# Letshuoer S12 (S1) L.csv
# LZ A4 Pro NzBlk FiBlk L.csv
# LZ A4 Pro NzRed FiRed L.csv
# Meze Audio Advar L.csv
# Moondrop Aria L.csv
# NF Audio NM2 L.csv
# NiceHCK Topguy L.csv
# Openheart Resin L.csv
# Plussound Allegro L.csv
# QKZ CK5 L.csv
# QKZ x HBB Khan L.csv
# QOA Gimlet L.csv
# Reecho SG01 L.csv
# SeeAudio Yume Midnight L.csv
# Seek Real Airship L.csv
# Sennheiser IE600 (Stock Foam) L.csv
# Simgot EA500 (black) L.csv
# Sony MH755 L.csv
# Strauss and Wagner EM205 L.csv
# Symphonium Helios L.csv
# T Force Yuan Li L.csv
# Tanchjim Ola L.csv
# Tangzu Shimin Li L.csv
# Tangzu Wan Er SG L.csv
# Thieaudio Legacy 2 L.csv
# Tin C3 L.csv
# Tipsy TTROMSO Pine Stone Sea L.csv
# TKZK Ouranos L.csv
# Tri i One L.csv
# Tri Meteor L.csv
# Tri x HBB KAI L.csv
# Tripowin Cencibel L.csv
# Tripowin Rhombus L.csv
# TRN MT1 L.csv
# TRN Xuanwu L.csv
# Unique Melody Mest Mk2 L.csv
# Urbanfun YBF-ISS014 (S1) L.csv
# Venture Electronics Grand Duke L.csv
# z_Isolation Comparison Free Field L.csv
# 4ACOUSTIC HARMONIE R.csv
# 4ACOUSTIC SYMPHONIE 1 ON R.csv
# 4ACOUSTIC UNISON L.csv
# 64 AUDIO TIA TRIO L.csv
# 64 AUDIO U12T M15 L.csv
# 64 AUDIO U18S R.csv
# 7TH ACOUSTICS PROXIMA L.csv
# 7TH ACOUSTICS STARGAZER 3 L.csv
# 7TH ACOUSTICS SUPERNOVA R.csv
# ACOUSTUNE HS2000MX MKII L.csv
# ACOUSTUNE RS1 R.csv
# AFUL PERFORMER 5 L.csv
# ANKER LIFE DOT 3i R.csv
# ASTELL N KERN AK ZERO1 L.csv
# ASTELL N KERN UW100 R.csv
# ASTROTEC VESNA L.csv
# AUDIO HEKILI L.csv
# AUDIOSENSE AQ0 L.csv
# AUDIOSENSE DT200 R.csv
# AVARA AV3 L.csv
# AZLA AZEL L.csv
# BAMBOO FOREST BIRD ZHU SKYLARK L.csv
# BEEMIX PISCES L.csv
# BGVP DH5 L.csv
# BGVP DN2 R.csv
# BGVP NS10 GOLD R.csv
# BGVP NS9 DEF FILTER R.csv
# BINARYACOUSTIC VOID R.csv
# BLON MAX L.csv
# BLON MINI L.csv
# BQEYZ TOPAZ L.csv
# CAMPFIRE AUDIO ANDROMEDA S R.csv
# CATEAR HITAM L.csv
# CCA C10 R.csv
# CCA CA16 PRO L.csv
# CCA HM20 L.csv
# CCZ COFFEE BEAN L.csv
# CCZ MELODY R.csv
# CCZ PLUME L.csv
# CVJ CSN L.csv
# DBE PR500 L.csv
# DIREM E3 R.csv
# DRESSAGE 6+1 L.csv
# DUNU FALCON PRO ATMOSPHERIC R.csv
# DUNU FALCON PRO REFERENCE L.csv
# DUNU FALCON PRO TRANSPARENCY R.csv
# DUNU SA6 L.csv
# DUNU TALOS OFF R.csv
# EDIFIER NEOBUDS S CLASSIC L.csv
# EDIFIER NEOBUDS S DYNAMIC R.csv
# ETYMOTIC ER4SR L.csv
# FAAEAL POPPY L.csv
# FIDUE SIRIUS R.csv
# FIIL T1 PRO R.csv
# FIIO F1 R.csv
# FIIO FD5 LARGE NOZZLE L.csv
# FIIO FW5 L.csv
# FIIO JD3 L.csv
# FINAL AUDIO A4000 R.csv
# FITEAR MH335 DW L.csv
# FLARE AUDIO FLARES PRO L.csv
# FOSTEX TE02N L.csv
# GEEK WORLD GK10 L.csv
# HIFIMAN RE 400 L.csv
# HZSOUND HEART MIRROR R.csv
# IEF neutral.csv
# IKKO OH2 L.csv
# INTIME GO L.csv
# INTIME SORA LIGHT R.csv
# JOYODIO SHINE 1 ON R.csv
# JQ 4U L.csv
# JUZEAR 41T L.csv
# KBEAR KS1 R.csv
# KBEAR STORM L.csv
# KINERA CELEST GUMIHO L.csv
# KINERA HODUR L.csv
# KINERA IDUN GOLDEN L.csv
# KINERA SKULD L.csv
# KKI 1 BA SWITCH 1 L.csv
# KZ D-FI DDDD L.csv
# KZ D-FI UDDD R.csv
# KZ EDA BALANCE L.csv
# KZ EDA BASS L.csv
# KZ EDA HIGH L.csv
# KZ LINLONG L.csv
# KZ VXS L.csv
# KZ ZEX PRO R.csv
# KZ ZST X R.csv
# KZ ZVX FINAL TIPS L.csv
# LYPERTEK LEVI L.csv
# LZ A7 BLACK MONITOR L.csv
# LZ A7 BLACK POP R.csv
# LZ A7 GOLD MONITOR R.csv
# LZ A7 SILVER POP R.csv
# MADOO TYPE 512 L.csv
# MANGIRD XENNS UP L.csv
# MASSDROP PLUS L.csv
# MEE X20 L.csv
# MOONDROP BLESSING 2 R.csv
# MOONDROP CRESCENT R.csv
# MOONDROP DROPLET R.csv
# MOONDROP KATO (BRASS) R.csv
# MOONDROP NEKOCAKE R.csv
# MOONDROP QUARKS R.csv
# MOONDROP SPACESHIP R.csv
# MOONDROP STARDUST R.csv
# MOONDROP VARIATIONS R.csv
# MR LEE 5+2 L.csv
# MR LEE AROUSE D8 R.csv
# MR WATER ARIA L.csv
# MUSEHIFI POWER L.csv
# NFAUDIO NM2 R.csv
# NICEHCK DB3 R.csv
# NYK AURORA L.csv
# OMNIWAVE ALPHA R.csv
# OMNIWAVE EUNOIA R.csv
# OPERAFACTORY OM01 R.csv
# PENON GLOBE L.csv
# PENON SPHERE R.csv
# PLEXTONE RX1 L.csv
# PMV PP L.csv
# QDC ANOLE VX 1 ON R.csv
# QDC ANOLE VX ALL OFF L.csv
# QKZ VK4 R.csv
# QOA VESPER L.csv
# RADIUS NEF 31 L.csv
# RAPTGO HOOK X HBB L.csv
# REECHO INSECTS AWAKEN L.csv
# SEEAUDIO BRAVERY L.csv
# SEEAUDIO KAGUYA R.csv
# SENFER MT300 L.csv
# SENNHEISER IE300 L.csv
# SENNHEISER IE600 AET08 R.csv
# SG AIRLINE IEM L.csv
# SGOR VENUS L.csv
# SHANLING ME80 L.csv
# SHANLING MTW300 R.csv
# SHUOER GALILEO L.csv
# SHUOER S12 PRO L.csv
# SIMGOT EA500 CLASSIC R.csv
# SIMGOT EA500 HARMAN R.csv
# SIMGOT EM2 ROLTION L.csv
# SKALD S11 R.csv
# SMABAT NCO L.csv
# SOFTEARS TWILIGHT L.csv
# SONY IER M9 L.csv
# SONY IER Z1R R.csv
# TAGO T3-02 L.csv
# TANCHJIM OXYGEN R.csv
# TANCHJIM TANYA R.csv
# TANGZU ZETIAN WU HEYDAY L.csv
# TFZ ESSENCE R.csv
# THHIFI FACE RED L.csv
# THIEAUDIO CLAIRVOYANCE L.csv
# THIEAUDIO ELIXIR L.csv
# THIEAUDIO MONARCH MKII L.csv
# THIEAUDIO V16 DIVINITY L.csv
# TIN BUDS 3 R.csv
# TIN C2 MECH WARROR R.csv
# TIN T2 2PIN R.csv
# TIN T2PLUS R.csv
# TKZK WAVE L.csv
# TRI STAR RIVER 1 ON R.csv
# TRI STAR RIVER ALL OFF L.csv
# TRIPOWIN OLINA (TANYA FILTER) L.csv
# TRIPOWIN OLINA VENT COVERED R.csv
# TRN BA5 L.csv
# TRN CS1 R.csv
# TRN KIRIN (ATMOSPHERIC FILTER) L.csv
# TRN KIRIN (REFERENCE FILTER) L.csv
# TRN KIRIN (TRANSPARENCY FILTER) L.csv
# TRN MT3 R.csv
# TRN V80 L.csv
# TRUTHEAR HEXA L.csv
# TRUTHEAR HOLA R.csv
# VE AZURE L.csv
# VIDO EARBUD L.csv
# WEMLIK MISTY 1 R.csv
# WHIZZER HE01 L.csv
# WILLSOUND DEWA COPPER L.csv
# WILLSOUND DEWA SILVER R.csv
# XUANERJI X01 R.csv
# YANYIN MAHINA L.csv
# ZHULINNIAO JINGHONG L.csv
# BGVP DH3 (00) L.csv
# BGVP ES12 (000) L.csv
# BGVP ES12 (110) R.csv
# BGVP Melody (Balanced) L.csv
# BGVP NE5 (Champagne Filter) L.csv
# Campfire Andromeda Pre-2020 L.csv
# Campfire Solaris 2020 R.csv
# Campfire Supermoon Universal L.csv
# Custom Art FIBAE 5 (Filter) L.csv
# Custom Art FIBAE 7U Universal L.csv
# DROP x Etymotic ERX R.csv
# Empire Ears Odin Sample 1 L.csv
# FiR Audio XE6 UIEM L.csv
# ItsFit Fusion R.csv
# Kinera Nanna 2.0 L.csv
# Lime Ears Aether R (Bass Off) L.csv
# Lime Ears Anima (Spinfit) R.csv
# Lime Ears Pneuma (Bass On) L.csv
# Moondrop KXXS (New Filters) R.csv
# Moondrop S8 Sample 1 R.csv
# Moondrop Stellaris (Foam) R.csv
# Project HRP L.csv
# Samsung Buds2 Pro (ANC) L.csv
# Shozy Ceres L.csv
# Shozy Elsa R.csv
# Shozy Pola39 (Shallow) L.csv
# Softears RSV R.csv
# SoftEars Turii Ti L.csv
# Softears Volume (Foam) L.csv
# Tanchjim Hana 2021 R.csv
# Tanchjim Prism (Small Bore) R.csv
# THHiFi Character (Small bore) L.csv
# TRI Starlight R.csv
# TRI Starsea (00) L.csv
# UE UE18+ Pro (2nd Gen) L.csv
# Vision Ears VE8 L.csv
# Aria Snow L.csv
# BGVP VG4 off-off-off L.csv
# BLON 03 Foam Mod L.csv
# BQEYZ Autumn Bass L.csv
# BQEYZ Spring 1 L.csv
# BQEYZ Summer L.csv
# BQEYZ Winter L.csv
# Co-Donguri Brass L.csv
# ddHiFi Janus 2 L.csv
# Enco X2 EQ Classic L.csv
# Enco X2 EQ Punchy L.csv
# Enco X2 EQ Simple & Clear L.csv
# Final E4000 L.csv
# GK100 L.csv
# HeartField Deer L.csv
# Hidizs MD4 Balanced L.csv
# Hidizs MD4 Treble L.csv
# Hidizs Mermaid MM2 L.csv
# Humka Hamlet M L.csv
# JD7 L.csv
# KBEAR Believe L.csv
# KBEAR Dumpling L.csv
# KBEAR Ormosia L.csv
# KBEAR Rosefinch L.csv
# Meze 12 Classics V2 L.csv
# Meze Rai Solo L.csv
# MS5 Balanced R.csv
# MS5 Bass L.csv
# MS5 Treble R.csv
# OnePlus Bullets 2 L.csv
# OURART Wine L.csv
# T4 Plus R.csv
# TINHiFi Buds 3 L.csv
# TinHiFi C2 R.csv
# TINHiFi P1 Plus L.csv
# TINHiFi T2 DLC L.csv
# TRI i3 Pro L.csv
# VE Bonus IE L.csv
# Ambient Dynamics AD-006 L.csv
# Blon BL-05 L.csv
# BQEYZ Autumn (Normal) R.csv
# Dunu DM-480 L.csv
# Dunu Talos (Switch On) L.csv
# EZAudio D4 (Modded) L.csv
# EZAudio X3 R.csv
# HZSound Waist Drum L.csv
# Jade Audio EA3 L.csv
# KBEAR Diamond L.csv
# KBEAR KB04 L.csv
# Kinera Tyr R.csv
# KZ CRN L.csv
# Letshuoer D13 (Silver) L.csv
# Meeture MT3 L.csv
# Thieaudio Voyager 3 (00) L.csv
# TRN STM (Blue) L.csv
# TRN STM (Gold) L.csv
# TRN STM (Red) R.csv
# TRN V90S R.csv
# UiiSii CM5 L.csv
# Yinyoo Ash L.csv
# Yinyoo V2 R.csv
# 2ht L.csv
# Acoustune hs1650cu L.csv
# Acoustune RS One L.csv
# Cayin YB04 dualflange L.csv
# Cayin YB04 trilange R.csv
# CVJ Angel Wings L.csv
# Effect Audio GAEA R.csv
# Hidizs MS5 1Ohm L.csv
# Hidizs MS5 High OI R.csv
# Hisenior Fe3U L.csv
# Hisenior T2 Classic R.csv
# HZSound Zero L.csv
# JVC FD02 L.csv
# KB Ear Aurora R.csv
# KB Ear BElieve R.csv
# KB Ear Diamond R.csv
# KB Ear KS2 L.csv
# KB Ear Neon triflange R.csv
# KB Ear Robin R.csv
# KBEar Neon 75Ohm L.csv
# Kotori Dauntless L.csv
# Kotori Vampire pre-release L.csv
# NOTBRAND NOTBLON L.csv
# Proto1 green gold no L.csv
# Proto1 green red yes L.csv
# Proto1 green silver no R.csv
# Proto1 red gold yes1 R.csv
# Proto1 red silver yes R.csv
# Sony MH1c L.csv
# TForce Yuan Li Modded L.csv
# Tri Star River Natural L.csv
# TRN VX Pro L.csv
# Yuan Li FINAL L.csv
# Broken Variations.csv
# JBuds Pro L.csv
# Letshuoer x Gizaudio Galileo L.csv
# MH150 L.csv
# Mixx Earphones L.csv
# PR1 PRO R.csv
# Pusheen Buds L.csv
# Salnotes Zero L.csv
# Sennheiser CX80S L.csv
# Sennheiser MOMENTUM True Wireless 2 L.csv
# Skullcandy Dime L.csv
# Sony MDR-EX15AP L.csv
# T160 L.csv
# Waner L.csv
# ZAR L.csv
# 64 Audio Fourte L.csv
# Aroma Jewel L.csv
# Astell Kern Odyssey L.csv
# AuR Audio Allure L.csv
# AuR Audio Neon R.csv
# Elysian Diva Bass Heavy L.csv
# Elysian Diva Bass Light R.csv
# Elysian X Elise L.csv
# Empire Ears Evo R.csv
# Fatfreq Maestro Mini L.csv
# Fir Audio KR5 Black Atom L.csv
# FiR Audio M4 R.csv
# Hidition Viento B R.csv
# InEar PMX L.csv
# ISN H40 L.csv
# Jomo GT600 L.csv
# LetShuoer Cadenza 12 L.csv
# LetShuoer EJ07M Lava L.csv
# LimeEars Anima L.csv
# MiM Dark Magician L.csv
# MMR Thummim L.csv
# Nostalgia Audio Camelot L.csv
# oBravo Ra 21 C-Cu L.csv
# Oriolus Percivali L.csv
# Oriolus Trailli L.csv
# SeeAudio Yume2 L.csv
# Shortbus Eru L.csv
# Subtonic Storm 004 L.csv
# Symphonium Meteor Sample R.csv
# Symphonium Triton L.csv
# ThieAudio L9 R.csv
# ThieAudio Oracle MKII deep L.csv
# ThieAudio Prestige Deep L.csv
# Unique Melody Fabled Sound L.csv
# Vision Ears Elysium R.csv
# Vision Ears Phonix R.csv
# Westone Mach 60 L.csv
# 1More ComfoBudsPro L.csv
# 1More PistonClassic L.csv
# ADVANCED S20009 L.csv
# ALPEX HR-4000 L.csv
# ALPEX HSE-A20009 L.csv
# Altec iM716Bass L.csv
# Altec iM716HD R.csv
# Apple MA850GA L.csv
# Artio CR-S1 L.csv
# Ashida EA-HF1 L.csv
# AT ATH-SPORT5TW L.csv
# atQ AT-ES11 L.csv
# Augl F300light L.csv
# BGVP DMGBk9 L.csv
# BONAKO Royole L.csv
# BQEYZ KB19 L.csv
# BUSAX JS81 L.csv
# CCZ CoffeeBean L.csv
# Creative EP-6309 L.csv
# CYBERDRIVE IMPDURBass9 L.csv
# DAISO AL-001 L.csv
# DAISO EV-001 R.csv
# DIY E3000 L.csv
# DQSM Hermit L.csv
# DZAT DF-10 L.csv
# Echobox FinderX1 L.csv
# Echobox NOMADN1Bk L.csv
# Echobox TravelerT1 L.csv
# ELECOM EHP-CH1000 L.csv
# ELECOM EHP-CS200A R.csv
# ELECOM EHP-GB10A L.csv
# Eono Eonobuds2 L.csv
# Ety ER-4S L.csv
# EZEAR Q70Y L.csv
# EZEAR X12 R.csv
# Fender NINE L.csv
# Fender PureSonicWireless L.csv
# Fengru QZX-A1 L.csv
# final EVA2020 L.csv
# Floaudio CALLA L.csv
# Floaudio LILY R.csv
# G-Most E89 L.csv
# GEVO GV3 L.csv
# GLIDiC TW-3000 L.csv
# GuideRay GR-i18 L.csv
# HZSOUND HMPro R.csv
# HZSound WaistDrum9 L.csv
# intime SORA29 R.csv
# intime SORAlight2019 R.csv
# JBL ENDURANCERUN L.csv
# JPRiDE 1984Premium L.csv
# JVC HA-A50TOff L.csv
# JVC HA-A7T R.csv
# KBEAR LarkEarly9 L.csv
# Kinden UE L.csv
# KOSS ThePlug L.csv
# Ksound EP-K05 L.csv
# KZ AS06-2020 L.csv
# KZ AS12 L.csv
# KZ AS12R22 R.csv
# KZ AS16ProHi-IMP L.csv
# KZ ASX9 R.csv
# KZ ATR R.csv
# KZ BA10 R.csv
# KZ ES4 R.csv
# KZ ZEXpro L.csv
# KZ ZSNProX L.csv
# Lenovo HF130 L.csv
# MassdropxNoble Univ L.csv
# Mulazo BT1019-m L.csv
# NAGAOKA P608 L.csv
# NAGAOKA P609 R.csv
# NICEHCK NX7PeoEd L.csv
# NICEHCK Youth L.csv
# NOKIA E35119 L.csv
# OKCSC ED10 L.csv
# Panasonic RP-HJE150 L.csv
# Philips SHE9500 L.csv
# Pioneer SE-CL20 L.csv
# PROfundo focus01 L.csv
# QKZ CK10 R.csv
# QKZ VK4old L.csv
# QoA Affinity L.csv
# RevoNext QT5 L.csv
# RevoNext RX8 R.csv
# Salnotes Dioko R.csv
# Seeaudio AnouJp L.csv
# Senfer DT6pro9 L.csv
# Senfer DT9 R.csv
# Shuoer TAPE9 L.csv
# SHURE E2c R.csv
# SIMGOT EM2R9 L.csv
# Soundpeats MiniPro L.csv
# Soundpeats T3Off L.csv
# TANGZU ShiminLi R.csv
# TFZ BALANCE19 L.csv
# TIMMKOO C6109 L.csv
# TinHiFi T1S9 L.csv
# TinHiFi T3pro9 L.csv
# Tripowin TC019 L.csv
# TRN VXpro9 L.csv
# TTR Co-DonguriBrass9 L.csv
# TTR Co-DonguriShizuku L.csv
# UNCJC iRock9 L.csv
# UrbanUtility UEHE-EP2 L.csv
# ZERO CarboTenore L.csv
# ZERO ZircoPezzo L.csv
# AFB5 L.csv
# Aful Soloist L.csv
# Agent 007 L.csv
# ANA Airline Freebud L.csv
# CCA PLA13 L.csv
# Dita Perpetua L.csv
# DKM L.csv
# Dunu EST112 L.csv
# Dunu Talos (Hybrid) L.csv
# Elysian Annihilator R.csv
# Elysian Diva (Blue Switch) L.csv
# Elysian Gaea L.csv
# Fatfreq Harmony L.csv
# Fearless Dawn L.csv
# FiiO FH15 (Balanced) L.csv
# FiiO FH15 (Treble) L.csv
# Fir VxV L.csv
# G R.csv
# Galileo Retail L.csv
# HBB Olina SE L.csv
# Hisenior Mega5P R.csv
# HZ Heartmirror L.csv
# IKKO ASGARD L.csv
# IKKO OH10 R.csv
# Kinera Pandamon L.csv
# KND L.csv
# Letshuoer Galileo (Pre-Production) L.csv
# Letshuoer KL R.csv
# Mangird Tea 2 L.csv
# MD B2 Dusk L.csv
# MD B3 L.csv
# MD Droplet DSP L.csv
# MD KXXS L.csv
# MD Quarks DSP L.csv
# Moondrop B2 Dusk R.csv
# Mooondrop Kato L.csv
# MuseHifi ME1 R.csv
# Mystery 010 L.csv
# NF  NA2 Plus L.csv
# Not Project Red R.csv
# Prisma Azul L.csv
# QDC 8SS L.csv
# QDC FOLK L.csv
# QDC Gemini (Bass Off) L.csv
# QoA Adonis L.csv
# QoA Magarita L.csv
# QoA Mojito 2 L.csv
# RoseT QT7 Pro 2 L.csv
# RoseT QT9 MK2 L.csv
# RoseT QTX R.csv
# SeeAudio Rinko L.csv
# Sennheiser IE200 (Dunu SS Tips) R.csv
# Tangzu Encounter L.csv
# Tangzu Heydey L.csv
# THC L.csv
# Thieaudio L3 (02) L.csv
# Tin P1 Max R.csv
# TinHifi T4 Pluss L.csv
# Truthears Zero L.csv
# TZ Yuan Li R.csv
# UM 3DT L.csv
# UM McBeth L.csv
# UM Mest MK1 L.csv
# Xenns Top R.csv
# Yanyin Moonlight L.csv
# APPLE AIRPODS PRO 2 L.csv
# Apple Powerbeats Pro R.csv
# Aukey EP-B44 R.csv
# Beyerdynamic Xelento 2. Gen R.csv
# BGVP Scale R.csv
# Blon A8 R.csv
# Bose IE2 R.csv
# Canpur Joyfull 1 R.csv
# Cat Ear Meow R.csv
# CCA FLA R.csv
# CREATIVE Aurvana Trio LS R.csv
# Devialet Gemini flat R.csv
# Dunu 380 R.csv
# Dunu EST 112 R.csv
# Enco X2 - Real R.csv
# EPZ Q1 R.csv
# Erasmus 00 R.csv
# Final ZE3000 R.csv
# Focus EDM R.csv
# G2 L.csv
# Hiby Seeds 2 R.csv
# Hifiman R800 R.csv
# Huawei Freebuds Pro 2 R.csv
# Jadeaudio EA1 R.csv
# KiiBOOM Allure R.csv
# KS ZS10 Pro L.csv
# Lenovo XT98 R.csv
# Magaosi V3 R.csv
# Penon Fan 2 R.csv
# Penon Serial R.csv
# Penon Vortex R.csv
# QCY T18 L.csv
# QKZ ZXD R.csv
# Sennheiser HD600 R.csv
# Shozy Form 1.1 L.csv
# Shuoer EJ07m R.csv
# Sony MDR-XB41EX R.csv
# Soundcore Liberty 3 Pro R.csv
# StageSound Stage Magic Plus L.csv
# TFZ T2 Pro R.csv
# Tipsy Tromso L.csv
# UiiSii BA-T6 R.csv
# v4 R.csv
# Volume 01-23 R.csv
# Whizzer BS1 R.csv
# XINHS Erasmus L.csv
# 55Hz 03xx R.csv
# 55Hz 350 R.csv
# 55Hz Eki fil fo R.csv
# 55Hz Hbb M R.csv
# 55Hz Hok R.csv
# 55Hz Mystery R.csv
# 55Hz No Damp R.csv
# 55Hz Osummer R.csv
# 55Hz Osun Sil R.csv
# 55Hz P1 Foam R.csv
# 55Hz Qkz Foa R.csv
# 55Hz Secretz 429 R.csv
# 55Hz See R.csv
# 7Hz i77 R.csv
# 7Hz i88 2 R.csv
# 7Hz Planar R.csv
# 7Hz Sample Med R.csv
# AAW Halycon R.csv
# AAW Mockingbird R.csv
# Acoustine RS ONE (Foam) R.csv
# Aful Band 5 R.csv
# Aful New R.csv
# Aful Perf 5 R.csv
# AKG 371 R.csv
# ASG 25 R.csv
# Astell & Kern Solaris X R.csv
# Audio Lokahi 8+1 R.csv
# Beats Fit Pro R.csv
# Bonus IE PRO R.csv
# Cat Ears Mia R.csv
# CCA CA24 R.csv
# CCa Pla Silicon R.csv
# Dethonray Tender 1 R.csv
# Du B R.csv
# Duna SA6 Ultra Bass R.csv
# Edifier Ambient R.csv
# Edifier High Noise R.csv
# Edifier Normal R.csv
# ELy x R.csv
# Excalibur R.csv
# Fat Freq 400 Filt R.csv
# Fat Freq Mae See R.csv
# Fearless Audio ACME 10 R.csv
# Fearless Barcelona R.csv
# Fearless Provence R.csv
# Fearless Shangrila R.csv
# FF GM 1 R.csv
# FH5s Bass R.csv
# FH5s Mids R.csv
# FH5s Standard R.csv
# Foam And 450 R.csv
# GK GS10 R.csv
# Goldpl Cus R.csv
# Goldpla Filt 2 R.csv
# Goldplanar AMT Stock R.csv
# Graph x R.csv
# Harmonicdyne Athena Raw R.csv
# HBB Audio X R.csv
# Hifiman Arya Stealth R.csv
# Hifiman HE400se R.csv
# Hifiman Susvara R.csv
# HS Audio Tech R.csv
# IBasso iT04 R.csv
# iF Audio 11 R.csv
# Ikko Gems OH1s R.csv
# Indigo R.csv
# J1234s R.csv
# J1b R.csv
# JH Jolene R.csv
# Joyaudio Shine R.csv
# JQ Audio Hua Jiang R.csv
# JQ Audio White Knight R.csv
# JVC 1100 R.csv
# JVC FDX1 R.csv
# Kiwi Ears New R.csv
# KZ EDA Resolution R.csv
# LAND Bass R.csv
# Leisurely Audio L8 R.csv
# Little Dot GYFU Raw R.csv
# LZ A2 Pro R.csv
# LZ AX Blue R.csv
# LZ AX Gold Off R.csv
# LZA4 PRO Blue R.csv
# M - Audio Q40 R.csv
# Madoo T711 R.csv
# Mangird Top R.csv
# MEST MK II R.csv
# Moji Monica H2O R.csv
# Moondrop Alice TWS R.csv
# Moondrop Chu 3 R.csv
# Moondrop Illumination R.csv
# Moondrop Turii TI R.csv
# Moondrop Twilight R.csv
# Moondrop Volume R.csv
# Muse Power R.csv
# Naga Audio Sirius R.csv
# NF Audio NA2 R.csv
# Nice Hck F1 Black R.csv
# Noble Audio Kublai Khan R.csv
# Noble Sultan R.csv
# Olina Mod Mesh R.csv
# Olina Se 2 Foam R.csv
# Olina1dot R.csv
# Open Audio Alkaid R.csv
# Open Audio Mercury R.csv
# Oriolus Szalayi R.csv
# Ovidius RX100 R.csv
# QDC V14 ACG R.csv
# QKZ X Hbb1 R.csv
# Qkzxhbb Foam R.csv
# Raptgo - 40CP.csv
# Raptgo GR-2CP R.csv
# Raptgo Huk X R.csv
# Raptgo Leaf R.csv
# Reecho SG-03 R.csv
# Reecho Spring 1 R.csv
# Rose Technics Aura R.csv
# Sam 250 R.csv
# Sam No Fil R.csv
# Sam Rxcap 2 Da R.csv
# Sample TR B R.csv
# Secret T 422 R.csv
# Seek Real Dawn Pro R.csv
# SEEK Real Fusion R.csv
# SEEK Real Proser R.csv
# Semkarch CNT R.csv
# Sendy Peacock R.csv
# Sennheiser IE900 Regular Foams R.csv
# Sennhieser IE80 R.csv
# Shanling ME800 Clear R.csv
# Shortbus Prometheus R.csv
# Shu z12 R.csv
# Shuoer Conductor R (1).csv
# Shuoer D13 2 R.csv
# Shuoer Kinda Lava 2R.csv
# Shuoer Soloist R.csv
# Simgot 2000 Blue R.csv
# Simgot Ea 500 R.csv
# Simgot Ea2000 R.csv
# Simphonio Rx 10 R.csv
# Sivga P2 R.csv
# Sony EX1000 R.csv
# Sony EX800 Taped Vent R.csv
# Sony N3ap R.csv
# Sony Xb90ex R.csv
# Sony Xba Z5 R.csv
# T20 Mod 3 R.csv
# T20 Raw R.csv
# T50RP MKIII R.csv
# Tansio Mirai 5 R.csv
# TFZ King 2 R.csv
# TFZ LIVE 3 R.csv
# TH Hifi Face Red R.csv
# Thie Or r R.csv
# THOR Mojinhor R.csv
# Tipsy Dunmer R.csv
# Toneking P10 R.csv
# TRI ione Mic 2 R.csv
# TRI Starshine R.csv
# Tri Xhbbkai R.csv
# Trihbk R.csv
# Tripowin Black 2 R.csv
# Tripowin Silver R.csv
# Tripowin X Hbb Loki R(1).csv
# Tripowin Xhbb Olina Foamz R.csv
# TRN BA 5 R.csv
# TRZR Ouranos R.csv
# TSMR 8 Bass R.csv
# TSMR 8 Mids R.csv
# TSMR Space R.csv
# VENTURE BIE R.csv
# Yan Mahina 2 R.csv
# Yan Ult 3 R.csv
# Yanyin Aladdin R.csv
# Yanyin Canon 000 R.csv
# Yanyin Rosemary 00 R.csv
# Yanyin Sample 2 R.csv
# Yanyin X HBB Final R.csv
# Anew U1 L.csv
# Auglamour RT-3 L.csv
# Auglamour T100 R.csv
# BGVP SGZ-DN1S L.csv
# Cozoy Hera C103 L.csv
# DB Monroe L.csv
# Dunu DN-1000 L.csv
# ECCI YST-02 L.csv
# Faaeal Hibiscus L.csv
# Geek Wold GK80 MIC L.csv
# Geekfly GF10 L.csv
# GEEKFLY GF8S R.csv
# Hessian TWS7 L.csv
# Hidizs MD4 Bass R.csv
# Hidizs MM2 Ref R.csv
# ISN Rambo II L.csv
# JH TriFi L.csv
# KBEAR Stellar L.csv
# KiiBOOM Evoke L.csv
# Lypertek Bevi R.csv
# LZ A4 Pro Black-Black L.csv
# Moondrop Kanas Pro R.csv
# NiceHCK EB2S L.csv
# NiceHCK F1 Black L.csv
# NiceHCK F1 Silver L.csv
# NiceHCK Lofty L.csv
# NiceHCK M5 Blue L.csv
# NiceHCK NX7 MK4 Gold L.csv
# NiceHCK Traceless L.csv
# NS Audio NS3 L.csv
# NS Audio NS5MKII Bass R.csv
# Oriolus Finschi L.csv
# Ostry KC06A L.csv
# Paiaduio DR2 L.csv
# Reecho SG-01 OVA L.csv
# Rose Mini2 MKII 2.0 L.csv
# Rose QT9 MK2s R.csv
# RY4S MMCX PLUS 32 L.csv
# Shozy Neo BG L.csv
# Smabat M0 R.csv
# SoundMagic T60BT L.csv
# SuperTFZ Force King L.csv
# SuperTFZ Force1 R.csv
# SWD2LE.csv
# Symphonium Audio Helios_r R.csv
# TFZ My Love 4 L.csv
# TFZ No.3 L.csv
# TFZ Tequila 1 R.csv
# Tin HiFi P2 R.csv
# Tronsmart Apollo Bold CLASSIC R.csv
# Tronsmart Onyx Prime L.csv
# 1 Custom PM-01 L.csv
# BASN MTPro L.csv
# Carot One (S2) L.csv
# Etymotic ER2XR Brown L.csv
# Etymotic ER2XR Orange R.csv
# Jaybird X3 L.csv
# KB Ear Storm R.csv
# KIMAFUN L.csv
# LETSHUOER Conductor 75ohm L.csv
# LETSHUOER D13 2nd Nozzle L.csv
# LETSHUOER Tape Pro L.csv
# QKZ X HBB TAPE MOD R.csv
# QKZ x HBB VE Adapter R.csv
# Soundpeats Capsule3 Pro L.csv
# Soundpeats Free2 Classic L.csv
# Soundpeats Opera05 L.csv
# Tanchjim Zero DSP R.csv
# TANGZU x HBB Zetian Wu R.csv
# TLC Socl300 L.csv
# Unknown Amazon IEM R.csv
# Westone UM2 R.csv
# X2 Sport L.csv
# AUR AUDIO DUET PLUS L.csv
# BLON X HBB Z300 L.csv
# CALCINI SWEATPRO 3 L.csv
# CAMPFIRE SABER L.csv
# EARBUDS - BGVP DX6 L.csv
# EARBUDS - HZSOUND BELL RHYME L.csv
# EARBUDS - LBBS L.csv
# EDIFIER W240TN L.csv
# FIFINE H6 GAMING EQ L.csv
# FIFINE H6 MOVIE EQ R.csv
# FZ AUDIO LIBERTY MAX L.csv
# HIFIMAN DEVA PRO L.csv
# HIFIMAN EDITION XS L.csv
# HIFIMAN SUNDARA 2022 L.csv
# ianfann.csv
# INEAR PRO MISSION X R.csv
# KINERA BALDR L.csv
# KIWIEARS CADANZA L.csv
# KIWIEARS ORCHESTRA LITE R.csv
# KZ DFI DDDU R.csv
# KZ DFI DUUD L.csv
# KZ DFI UUUU R.csv
# KZ DQS R.csv
# KZ EDA (GOLD) L.csv
# KZ EDA (GREEN) L.csv
# KZ EDA (SILVER) L.csv
# KZ H10 L.csv
# KZ ZNA R.csv
# LAFITEAR LF1 L.csv
# LETSHUOERXGIZAUDIO GALILEO L.csv
# MUSE X HIBY ME1 L.csv
# ONEODIO A10 L.csv
# QOA PROTOTYPE 1 L.csv
# QOA SUNRISE L.csv
# ROSE TECHNIC PHOTON L.csv
# SIMGOT EN1000 C3A035 L.csv
# SIMGOT EW100P L.csv
# SOUNDPEATS LIFE TWS L.csv
# TANGZU ZETIANWU HAYDAY R.csv
# THIEAUDIO GHOST L.csv
# TRI STAR RIVER (ENHANCED TREBLE) L.csv
# TRIPOWIN PICCOLO L.csv
# TRN ROSEFINCH R.csv
# 1MORE Quad Driver L.csv
# 1More Triple Driver (FOAM Eartips) R.csv
# 64 Audio U6t m20 (Foam) L.csv
# 64 Audio U6t mx (NO TIP on Coupler) L.csv
# 64 Audio U6t mx (Silicon Tips WIDE) L.csv
# AKG N400 L.csv
# AKG N5005 (BASS) L.csv
# AKG N5005 (HIGH) R.csv
# Fiio FD3
# Fiio FH7 (Black) L.csv
# Fiio FH9
# KZ HBB DQ6S L.csv
# MoonDrop LAN (BGVP Foam) R.csv
# MoonDrop LAN (FINAL EARTIPS) R.csv
# MoonDrop LAN (ORIGNAL SILICON) R.csv
# SeeAudio Yume (Final Eartips) L.csv
# Sennheiser IE600 (NO TIP on Coupler) L.csv
# Sennheiser Momentum 3 (BGVP Foam) L.csv
# Sennheiser Momentum 3 (FINAL EARTIPS) L.csv
# Sennheiser Momentum 3 (ORIGNAL SILICON) L.csv
# Shozy Black Hole Mini Stainless Steel Version L.csv
# Shuoer S12 (EJ07 FOAM Eartips) R.csv
# Shuoer S12 (MoonDrop Eartips) R.csv
# Whizzer Kylin HE03D L.csv
# Koast Audio Mithi L.csv
# KZ EDA HiRes R.csv
# LREY Nectar L.csv
# ND NSK L.csv
# QKZ AK6 Max L.csv
# QKZ AK6 Pro R.csv
# REECHO GY09s R.csv
# Shure SE215 SE Blue L.csv
# Sony XBA-N3 L.csv
# VE BIE L.csv
# Whizzer Opera Factory OM3 L.csv
# 556 L.csv
# 5i ANC BASS L.csv
# 5i ANC TREBLE L.csv
# Apollo Bold classical anc off L.csv
# Apollo Bold default anc on L.csv
# AT1 L.csv
# CCA C16 47R OI L.csv
# Dioko Spring R.csv
# DT200 Spring 23R OI L.csv
# e1000 L.csv
# EDC3 L.csv
# EO-IC100 L.csv
# EO-IG955 Fake L.csv
# HA-FR15-H L.csv
# Inkd 2.0 L.csv
# KXXS (BGVP W01) R.csv
# KXXS (CP 100) R.csv
# KXXS (EX15) R.csv
# KXXS (Symbio W Peel) R.csv
# KXXS spring R.csv
# MDR-EX15 (BGVP W01) L.csv
# MDR-EX15 (Symbio W Peel) L.csv
# MDR-EX15 CP100 L.csv
# MDR-XB55AP L.csv
# MH755 Fake L.csv
# Mini Pro HS anc off L.csv
# Onyx Free L.csv
# Onyx Neo L.csv
# RP-HJE125E-K L.csv
# RP-HJE270E L.csv
# SD251-BT L.csv
# SJ01 L.csv
# Sparks Balanced 1.2.1 L.csv
# Sparks Basshead 1.2.1 L.csv
# Sparks David Xu 1.2.1 L.csv
# Sparks Studio 1.2.1 L.csv
# Sparks Wennebostel 1.2.1 L.csv
# TAE1105 L.csv
# TE0 Narrow L.csv
# TE0 Wide 47 OI L.csv
# Tune 110 L.csv
# V20 L.csv
# ZS5v1 47R OI L.csv
# Average Reviewer.csv
# Oratory 64 Audio N8 L.csv
# Oratory AKG K3003 L.csv
# Oratory Akoustyx R-220 L.csv
# Oratory Amazon Echo Buds L.csv
# Oratory Anker SoundCore Liberty Air 2 L.csv
# Oratory Apple ME186 In-Ear Headphones L.csv
# Oratory Audeze Euclid L.csv
# Oratory Beats Powerbeats Pro L.csv
# Oratory Beats Studio Buds L.csv
# Oratory Beyerdynamic Blue Byrd L.csv
# Oratory BGVP DMG (foam eartips) L.csv
# Oratory Bose QuietComfort 20 L.csv
# Oratory Bose SoundSport Free L.csv
# Oratory Bowers & Wilkins C5 Series 2 L.csv
# Oratory Brainwavz M5 L.csv
# Oratory EarFun Free Pro (Oluv Edition) L.csv
# Oratory Etymotic ER2SE L.csv
# Oratory FiiO FA7 L.csv
# Oratory Grado GT220 L.csv
# Oratory Huawei Freebuds 4i L.csv
# Oratory IKKO OH1 L.csv
# Oratory Jabra Elite 7 Pro L.csv
# Oratory Jabra Evolve 75e L.csv
# Oratory JBL T200A L.csv
# Oratory JVC HA-FW01 L.csv
# Oratory KZ EDSE L.csv
# Oratory Light Harmonic Mera L.csv
# Oratory Mackie MP-360 L.csv
# Oratory Monoprice M350 L.csv
# Oratory NuForce Stride L.csv
# Oratory oBravo Cupid L.csv
# Oratory Oppo Enco X L.csv
# Oratory Panasonic RP-HJE120 L.csv
# Oratory Philips SHE3855 L.csv
# Oratory Qudelix Qx-over L.csv
# Oratory Rock Zircon L.csv
# Oratory Samsung EO-IC500 ANC Type-C L.csv
# Oratory Samsung Galaxy Buds L.csv
# Oratory Sennheiser CX 2.00 L.csv
# Oratory Shouer S12 L.csv
# Oratory Shuoer Tape L.csv
# Oratory Shure KSE1500 L.csv
# Oratory SoftEars Cerberus L.csv
# Oratory Sony MDR-7550 L.csv
# Oratory Sony WF-1000X L.csv
# Oratory Stax SR-003MK2 (CES-A1 closedback adapter) L.csv
# Oratory Tripowin Olina L.csv
# Oratory Ultimate Ears Reference Monitor L.csv
# Oratory V-MODA Zn L.csv
# Oratory Vivo XE800 L.csv
# Oratory VSonic VS7 L.csv
# Oratory Westone UM3X L.csv
# Oratory Xiaomi Mi ANC L.csv
# P1 Max Foam Deep L.csv
# P1 Max Spring Tips L.csv
# P1 Max Sticky Red L.csv
# P1 Max Stock Black L.csv
# P1 Max Xelastec L.csv
# Resolve 7Hz Tmeless Gras L.csv
# Resolve Blessing 2 Dusk Gras L.csv
# Resolve Dunu Titan S Foam Gras L.csv
# Resolve Galaxy Buds2 Pro Active Anc Gras L.csv
# Resolve Letshouer S12 Gras L.csv
# Resolve Monarch Gras L.csv
# Resolve Oracle MK2 Gras L.csv
# Resolve Pixel Buds Pro Gras L.csv
# Resolve Sennheiser IE600 Gras L.csv
# AIDERLOT M5 Bass R.csv
# ASF 3BA 2way L.csv
# ASF Flat L.csv
# ASX 10BA 2WAY R.csv
# Blessing2_Dusk R.csv
# Bose QC EARBUDS R.csv
# BOSE QC30 R.csv
# CCA A10 30ohm R.csv
# CCA CS16 L.csv
# CHIKYU-SEKAI 2COSMOS L.csv
# DIY 5BA L.csv
# DIY 846 4BA L.csv
# DIY SK846 L.csv
# DIY846 Wooeasy EE846 L.csv
# DUNU SA03 R.csv
# GK GS5 L.csv
# KZ AS06 30ohm R.csv
# KZ AS10 old R.csv
# KZ AS16 200Ω R.csv
# KZ EDA HighResolution L.csv
# KZ EDC R.csv
# KZ ZS5 old L.csv
# NFaudio NA2+ L.csv
# NICEHCK NX7mk3 Red filter L.csv
# openheart A2 R.csv
# SeeAudio YumeMidnight L.csv
# SOUNDPEATS Q35+ R.csv
# Vento Conductor Celestial L.csv
# Vento Conductor Ethereal R.csv
# Vento Conductor T-500Pro L.csv
# WF1000X R.csv
# WGZBLON BL-Max L.csv
# 64Audio Trio R.csv
# AFUL Performer5 R.csv
# BQEYZ Autumn Treb Tanya R.csv
# Dunu VERNUS Atmos L.csv
# Dunu VERNUS Reference R.csv
# Dunu VERNUS Transpa R.csv
# DUNU Zen Foam R.csv
# GS Audio GT12x L.csv
# GS Audio ST1 R.csv
# HarmonicDyne Devil L.csv
# MiM DM Comply R.csv
# MiM DM Softears L.csv
# MiM DM XbassII R.csv
# MiM DM XD-05 L.csv
# Oriveti O400 L.csv
# Oriveti OV800 00 R.csv
# SeekReal Airship L.csv
# SeekReal Dawn R.csv
# Shuoer S12 BassheadEQ R.csv
# Shuoer S12 Final E R.csv
# Shuoer S12 XbassII R.csv
# Tripowin Mele Naked L.csv
# Tripowin Mele Sony R.csv
# Tripowin Olina Dual Comply L.csv
# Tripowin Olina US Full L.csv
# TRZR Wave EQ L.csv
# TRZR Wave Narrow R.csv
# TRZR Wave Olina R.csv
# Akros Erasmus 11 L.csv
# Audio Ehiku L.csv
# Audio Lokahi 7BA L.csv
# AXS Audio Pro Earbuds L.csv
# BASN BMaster 2nd L.csv
# BLON BL03 Filter L.csv
# BLON BL03 Stock L.csv
# CCA CSNv2 L.csv
# CCA Lyra Y1 L.csv
# CCA NRA Stock L.csv
# CCA NRA Taped L.csv
# DUNU Titan Tanya L.csv
# Etymotic ER4XR Foam L.csv
# Fearless Roland R.csv
# HiFri Hybrid L.csv
# KBEAR KS2v2 L.csv
# KBEAR Lark4kv2 L.csv
# KBEAR OS1 Pro L.csv
# KZ AST 25ohm L.csv
# KZ AST Stock L.csv
# KZ AST Tanya L.csv
# KZ D-Fi UUUD DP L.csv
# KZ EDS BTX HIFI L.csv
# KZ PL1 Hifi MedFoam R.csv
# KZ SA08 L.csv
# KZ ZEX Taped L.csv
# KZ ZSTXv2 L.csv
# KZ ZVX IEMatch L.csv
# MEMT R1 L.csv
# Redeyes Not DM L.csv
# Senfer DT6 Max L.csv
# Senfer KP580 L.csv
# Shine Classical L.csv
# Shine Hifi L.csv
# Shine Pop W L.csv
# Shine RandB L.csv
# Shine Standard 1000 L.csv
# Shortbus Autumn R.csv
# Shortbus EJ07SB R.csv
# Shortbus Olina R.csv
# Shuoer EJ07KLC L.csv
# Tangzu Heyday Micropore L.csv
# Tinhifi P1Max L.csv
# Tinhifi T2plusv2 L.csv
# Tranya T10 Upgraded L.csv
# Tripowin Olina 1TanyaMP L.csv
# Tripowin Olina HighDensity Foam OlinaD L.csv
# Tripowin Olina Mesh B1S L.csv
# TRN Kirin Atmosphere R.csv
# TRN Kirin Transparent L.csv
# TRN T300 L.csv
# Urbanfun Hybrid L.csv
# Urbanfun YBFISS014 L.csv
# Velodyne Pink L.csv
# VJJB N30 L.csv
# 2p R.csv
# 4p L.csv
# 4ss L.csv
# 7A est7 L.csv
# 7A pro1 L.csv
# 7A pro1stock L.csv
# 7A SG1 L.csv
# a4k L.csv
# apexti L.csv
# arere L.csv
# ath clr100 L.csv
# avid L.csv
# chu 9khz L.csv
# chu detach L.csv
# chu foamfilter L.csv
# chu fullinsertion L.csv
# chu t300t L.csv
# ciembellosx5 L.csv
# cwu22 L.csv
# cwu77 L.csv
# dn3 L.csv
# dusk bgvp L.csv
# dusk bgvpshallow L.csv
# dusk mistip L.csv
# dusk ortofon L.csv
# dusk w1shallow R.csv
# er3xr (68ohm) L.csv
# fw10k L.csv
# helios 8khz L.csv
# helios ortofon L.csv
# helios symp R.csv
# hzhm L.csv
# illu eqharman L.csv
# illu ortofon L.csv
# illu shallowfit L.csv
# illu symbio L.csv
# kato gold symbio L.csv
# kato max L.csv
# kato silver symbio R.csv
# kato spring L.csv
# kato vivid L.csv
# legendx L.csv
# mdplus L.csv
# melodie L.csv
# mestjp L.csv
# oxy L.csv
# plateada L.csv
# pro1 8k R.csv
# proto3ba L.csv
# rs10 L.csv
# sg8 L.csv
# sho L.csv
# sk7 L.csv
# sm2 L.csv
# sncp100 L.csv
# ssp R.csv
# ssr faudio L.csv
# ssr foamdamper L.csv
# ssr new1 L.csv
# ssr new2 R.csv
# stg8p R.csv
# supernova cp155 L.csv
# supernova final L.csv
# supernova mistip L.csv
# supernova ortofon L.csv
# supernova stock L.csv
# supernova vivid L.csv
# supernova w1deep L.csv
# supernova w1impedance L.csv
# supernova w1shallow L.csv
# titans L.csv
# turiiti L.csv
# u18t L.csv
# vientocp155 L.csv
# vientoD L.csv
# vientoVivid R.csv
# voyager3 L.csv
# xuan L.csv
# yuanli L.csv
# z1r aet06s L.csv
# z1r aet08m R.csv
# z1r azlamaxS L.csv
# z1r azlavivid L.csv
# z1r azlavividshallow L.csv
# z1r cp800 L.csv
# z1r dqsmS L.csv
# z1r epro00M L.csv
# z1r max L.csv
# z1r radiusS L.csv
# z1r sednareg L.csv
# z1r sonyhybridM L.csv
# z1r stockMS L.csv
# z1r symbiofoamlessS L.csv
# 10mm Bio V1 R.csv
# Aiderlot M5 (Filterless) L.csv
# Aiderlot M5 (Reference) L.csv
# Aiderlot M5 (Treble + 350 Mesh) L.csv
# Aiderlot M5 (Treble + Sony Import Foam) L.csv
# Aiderlot M5 Pro modded L.csv
# Audiosense DT600 (stock) R.csv
# Bamboo Forest Bird Jinghong (Sony Import Foam) L.csv
# BQEYZ Autumn (Y3 WTF inner vent, 2 high-density tuning foam, 500 mesh) R.csv
# CCA NRA (0.15ohm) L.csv
# Dunu Falcon Pro (Transparent filter, 2 outer vent 500 WTF, 1 inner vent 500 WTF, low-density tuning foam) L.csv
# Dunu Titan S (500 Mesh) L.csv
# Dunu Titan S (Y3 Paper Filter) L.csv
# Dunu Zen (High-Density Tuning Foams Inside Tips) L.csv
# Dunu Zen (Micropore Tape Mod) L.csv
# Earsonics Onyx L.csv
# FIIL T1 Lite (Bass) L.csv
# Fiio FD5 (1dividedby16 foam) L.csv
# Fiio FD5 (Bass filter) L.csv
# Fiio FD5 (Micropore Tape Mod) L.csv
# Fiio FH5S (000) L.csv
# Geek Wold GK10 (0.16ohm cable) L.csv
# GS Audio GD11 (40H) L.csv
# KBEAR Neon (A3 type E deep) L.csv
# Kinera Freya L.csv
# Klipsch S4 L.csv
# KZ ED9 (Balanced filter) L.csv
# LZ A4 Pro (Blue F + Blue V) L.csv
# LZ A6 (Black filter) L.csv
# LZ A7 (Pop-Blue) L.csv
# LZ Z04A L.csv
# Peacock Audio P1 L.csv
# Periodic Audio Beryllium L.csv
# Sennheiser CX 400BT TWS L.csv
# Shuoer Tape (1dividedby16 foam) L.csv
# Sony MDR-EX800ST (BluTack) L.csv
# Sony WF-1000XM3 L.csv
# Tingker TK200 L.csv
# 07m L.csv
# 07m_retune L.csv
# Blon_03_busmod L.csv
# burson_pm2_loopback L.csv
# DM2_DM1 L.csv
# DM2_olina L.csv
# EJ07_custom L.csv
# EJ_SB L.csv
# Hekili_foamdeep L.csv
# iem_2 L.csv
# motu_calibrated_loopback L.csv
# not_dm L.csv
# not_tanya L.csv
# Ola_olina_200 R.csv
# Olina Magician L.csv
# Olina_Tanya L.csv
# Oriolus_isabellae L.csv
# S12_SB L.csv
# Softears_rsv L.csv
# toneking_bl1 L.csv
# Unknown_Soldier L.csv
# Variations_sb L.csv
# xduoo_ta20_loopback L.csv
# Yanyin_M L.csv
# Air Canada Earphones R.csv
# CAL SE L.csv
# DF Tilt 711 Ref.csv
# Electra Earbuds L.csv
# HEAD Corded Earbuds L.csv
# IE200 Less Bass L.csv
# IE200 Spinfit CP100 Plus Tips L.csv
# iHip Anzu L.csv
# Koss KPH40 L.csv
# KZ EDABass L.csv
# Raycon E25 L.csv
# Rode NTH100 L.csv
# Sony MDREX15 L.csv
# 32BG R.csv
# AKG N200 R.csv
# Aroma Thunder Focus mode.csv
# Asura L.csv
# Audiosense AQ4 30 R.csv
# Blur MX64 R.csv
# Campfire Audio Onyx L.csv
# CIEM Anni L2.csv
# EE Odin 2 L.csv
# Ep05 R.csv
# Fiio FD7 Modded L.csv
# Fir KR5 Gold R.csv
# FiR NE4 R.csv
# Haylou GT1plus R.csv
# Hookx L.csv
# IMR Astra R.csv
# Jcally JC10 R.csv
# JVC FW10000 L.csv
# Ksearphone Lbbs L.csv
# Lbbs2 R.csv
# Miku Buds L.csv
# Monk R.csv
# Newbsound 32Pro R.csv
# Odin Fix L.csv
# Oriolus Reborn L.csv
# Penon Impact L.csv
# Qian39 R.csv
# Ripples R.csv
# Serratus L.csv
# Sun Copper R.csv
# Tantalus L.csv
# Tantan R.csv
# Tgx78 150BG L.csv
# Tgx78 B1 R.csv
# Tgx78 Tofino L.csv
# Tgxear Red Dot Ti R.csv
# Tgxear Tiolake Red R (1).csv
# Tiolake Sr2 L.csv
# Tofino Mmcx L.csv
# Tofino Pro R.csv
# Totem P3 R.csv
# Tronsmart Onyx Apex R.csv
# UM Mentor L.csv
# VE AWS L.csv
# VE EXT L.csv
# VE Phonix2 L.csv
# Yincrow RW9 L.csv
# BASN MMCX L.csv
# EDL Mini Piano L.csv
# Fonge X2 Pro L.csv
# Geek Wold GK10 No Tape L.csv
# Gravastar Sirius L.csv
# HAKII Action R.csv
# Openheart IE800 L.csv
# SuperEQ Q2 Pro R.csv
# Tangzu Ze Tian Wu L.csv
# THOR Mjölnir MKII L.csv
# Tozo Golden X1 L.csv
# 1MORE ColorBuds 2 L.csv
# 64 Audio U4s M12 L.csv
# AK PATHFINDER L.csv
# Allway OE10 L.csv
# Antlion Kimura Duo L.csv
# Audeze CRBN L.csv
# Audeze LCD-2 Classic L.csv
# Audeze LCD-5 Old Headband L.csv
# Audeze LCD-X (2021) L.csv
# Audio-Technica ATH-ANC300TW L.csv
# Bang & Olufsen Beoplay H95 ANC L.csv
# Cambridge Audio Melomania 1+ L.csv
# Campfire Audio Holocene R.csv
# Campfire Audio Mammoth R.csv
# Campfire Audio Orbit S2 R.csv
# Campfire Audio Satsuma R.csv
# Campfire Audio Trifecta R.csv
# Cleer Flow II Ambient L.csv
# Cleer Roam NC L.csv
# Drop + Dan Clark Audio Aeon Closed X 1-notch white filter L.csv
# DUNU TITAN S pre-production L.csv
# Edifier STAX SPIRIT S3 Lambskin BT L.csv
# Edifier STAX SPIRIT S3 Mesh wired L.csv
# Edifier WH950NB Bluetooth L.csv
# Edifier WH950NB wired R.csv
# FiiO FA7s L.csv
# FiiO FT3 pleather L.csv
# FiiO FT3 suede L.csv
# final UX3000 Bluetooth ANC L.csv
# final UX3000 Wired R.csv
# final ZE8000 1.8.0 L.csv
# Focal Bathys L.csv
# Focal Utopia 2022 L.csv
# GoldPlanar GL12 Filter L.csv
# HarmonicDyne G200 Flannel R.csv
# HarmonicDyne Poseidon R.csv
# Hear+Hi Acuity Duo L.csv
# HiBy Lasya L.csv
# HIFIMAN Ananda (2022 Stealth Magnets) L.csv
# HIFIMAN HE-R10D Bluemini L.csv
# HIFIMAN HE-R10P R.csv
# HIFIMAN RE2000 Pro Gold R.csv
# HIFIMAN Shangri-La Jr L.csv
# iBasso SR3 L.csv
# Ikko OH1s Sample 2 L.csv
# JQ 4Upro R.csv
# Kinera YH802 ANC L.csv
# Lime Ears Pneuma Switch R.csv
# Mackie MP-320 R.csv
# Meze 99 Neo Dekoni L.csv
# Meze Liric L.csv
# Monoprice M1070C Lambskin L.csv
# Monoprice M1070C Velour R.csv
# Monoprice Monolith M-TWE L.csv
# MOONDROP VENUS R.csv
# Moondrop VOID S1 R.csv
# Nectar HiveX (No Sponge Insert) L.csv
# Noble Audio Viking Ragnar L.csv
# Ovidius RX-100 L.csv
# Ovidius TX-901 R.csv
# Padmate PaMu Z1 L.csv
# Peacock Flight L.csv
# Philips Fidelio X2HR L.csv
# Sennheiser HD 598 L.csv
# Sivga Oriole L.csv
# Sivga Phoenix L.csv
# Sivga Robin (SV021) L.csv
# Sivga SV023 L.csv
# Technics AZ70 L.csv
# ThieAudio Wraith Pad A L.csv
# TinHiFi C5 prototype L.csv
# Tripowin TC-01 R.csv
# UA Complimentary 1 L.csv
# Ugreen HiTune T3 L.csv
# XENNS UP Sample 2 L.csv
# Yanyin Canon all switches L.csv
# Yanyin Canon treble switch L.csv
# Zephone Tiger L.csv
# 710 Btnc (Active, ANC off) L.csv
# 710 Btnc (Passive) L.csv
# Deva (Wired) L.csv
# Elegia (Stock Pads) L.csv
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) L.csv
# Elex (Elear Pads) L.csv
# Elex (Utopia Pads) L.csv
# Sparks (Stock Tuning) L.csv
# test L.csv
# 64 Audio Nio (Fir red) L.csv
# 64 Audio Nio (S1 - m20) L.csv
# Akoustyx S-6 (S2) L.csv
# BGVP DMG (silver) L.csv
# BGVP NS9 (black tips + no mesh) L.csv
# Campfire Audio Dorado 2020 R.csv
# Cayin Fantasy L.csv
# Colorfly Quintet L.csv
# Custom Art Fibae 7 Unlimited L.csv
# Dunu Falcon Pro (experimental) L.csv
# Dunu Vulka (S2 + red) L.csv
# Dunu Zen Pro (pre) L.csv
# Empire Ears Bravado mkII L.csv
# Etymotic ER2SE (sample 2) L.csv
# Etymotic ETY Kids L.csv
# Etymotic Evo (2F) L.csv
# Etyotic ER2XR (S2) L.csv
# Fiio FD7 (40 hrs) L.csv
# Fiio FD7 (bass + SpinFit) L.csv
# Fiio FH3 (Spring) L.csv
# Fiio FHE (franken) L.csv
# Final B3 (E-type) L.csv
# Final E2000 (S2) R.csv
# FLC 8P (gold-black-gunmetal) L.csv
# FLC 8P (gold-white-transparent) L.csv
# FLC 8P (green-gray-gunmetal) L.csv
# FLC DD31 L.csv
# Haylou GT1 L.csv
# Hiby Crystal6 II L.csv
# Hifiman Bolt L.csv
# iBasso IT01X (S2) R.csv
# JH Audio Layla (max) L.csv
# JVC FX7 L.csv
# KZ (avg) L.csv
# KZ ZEX (vent blocked) L.csv
# LG HBS800 (ANC off) L.csv
# Magaosi K3 (F0) L.csv
# Magaosi K5 (15 ohm + IEMatch+ ultra) L.csv
# MEE Audio M6 Pro 2G L.csv
# Meizu Live (black) L.csv
# Meizu Live (white) L.csv
# Mi True Wireless Earbuds Basic 2 L.csv
# Moondrop LAN (Blu Tack) R.csv
# Moondrop Solis S2 R.csv
# Moondrop SSR (deep) R.csv
# Nothing Ear 2 (balanced) L.csv
# Nothing Ear 2 (more bass) L.csv
# Nothing Ear 2 (personalized B) L.csv
# Nothing Ear 2 (treble -6) L.csv
# Nothing Ear 2 (voice) R.csv
# OpenAudio Mercury L.csv
# Oriolus 2nd Gen L.csv
# Phonak Audeo PFE 112 L.csv
# Pre-Prod 03 (nozzle A) L.csv
# QDC Anole V14 (0000) L.csv
# QDC Neptune L.csv
# QDC Uranus L.csv
# Radius HP-NEF11 R.csv
# Sennheiser IE 200 (Azla Max) L.csv
# Sennheiser IE 200 (Spiral Dot) L.csv
# Sennheiser IE 200 (UC tips) R.csv
# Sennheiser IE 300 (AutoEQ) L.csv
# Sennheiser IE 40 Pro L.csv
# Sennheiser IE 600 (E-type shallow) L.csv
# Sennheiser IE 600 (Sedna) R.csv
# Sennheiser IE 600 (Spring tips) L.csv
# Sennheiser IE 900 (fake) R.csv
# Sennheiser MTW2 (HE) L.csv
# Shozy Rouge L.csv
# Simgot EN700 Pro L.csv
# Softears Studio4 L.csv
# Sony MDR-AS800 L.csv
# Sony MDR-EX15LP (deep) R.csv
# Sony MH1 R.csv
# Sony WF-1000XM4 (ambient on) L.csv
# Sony WF-1000XM4 (EQ - bass boost) L.csv
# Sony WF-1000XM4 (fw 1.1.15) L.csv
# Sony WF-1000XM4 (max - ANC off) L.csv
# Sony WF-1000XM4 (MRS config) L.csv
# Sony WF-1000XM4 (Sedna Light Short) L.csv
# Sony WF-1000XM4 (SpinFit) L.csv
# Sony WF-1000XM4 (XM3 silicone) L.csv
# Status Audio IEM-2X L.csv
# Tenhz 3BA L.csv
# TFZ T2 Galaxy L.csv
# Thinksound Rain3 L.csv
# Ucotech RE-2 L.csv
# Vsonic GR07 (Bass) L.csv
# Yinfu MD51 L.csv

# %%
# Print grouped files
for representative, files in grouped_files.items():
    print(f"{representative}:")
    for file in files:
        reviewers_with_file = [reviewer for reviewer, f in all_files if f == file]
        print(f"  {file} - {', '.join(reviewers_with_file)}")
    print()
# Out:
# 7Hz Dioko L.csv:
#   7Hz Dioko L.csv - achoreviews, bedrock, timmyv, iemworld, data_mrs
#   7HZ SALNOTES DIOKO L.csv - aftersound
#   7HZ SALNOTES DIOKO R.csv - aftersound
#   7Hz Salnotes Dioko L.csv - arn, pw
#   7Hz Dioko R.csv - bedrock, timmyv, hbb, iemworld, data_mrs
#   Salnotes Dioko L.csv - eplv
#   7hz Dioko L.csv - hobbytalk
#   7hz Dioko R.csv - hobbytalk
#   7HZ DIOKO (bass mod) L.csv - ianfann
#   7HZ DIOKO (bass mod) R.csv - ianfann
#   7HZ DIOKO L.csv - ianfann
#   7HZ DIOKO R.csv - ianfann
#   Dioko L.csv - kr0mka
#   Dioko R.csv - kr0mka
#   Resolve 7Hz Salnotes Dioko Gras L.csv - kurin
#   7hz Salnotes Dioko L.csv - nymz
#   7hz Salnotes Dioko R.csv - nymz
#   7Hz Salnotes Dioko R.csv - pw
#   7Hz Salnotes Dioko TapedVent L.csv - pw
#   7hz x Crinacle Dioko L.csv - vortexreviews
#   7hz x Crinacle Dioko R.csv - vortexreviews
#   7hz x Crinacle Dioko Updated L.csv - vortexreviews
#   7hz x Crinacle Dioko Updated R.csv - vortexreviews
#   7Hz x Crinacle Salnotes Dioko L.csv - vsg
#   7Hz x Crinacle Salnotes Dioko R.csv - vsg
#   7Hz Dioko (post-op) L.csv - data_mrs
#   7Hz Dioko (post-op) R.csv - data_mrs
#   7Hz Dioko (pre-op) L.csv - data_mrs
#   7Hz Dioko (pre-op) R.csv - data_mrs
#
# 7Hz Eternal L.csv:
#   7Hz Eternal L.csv - achoreviews, bedrock, vsg
#   7Hz Eternal R.csv - bedrock, harpo, hbb, vsg
#   7Hz ETERNAL L.csv - iemworld
#   7Hz ETERNAL R.csv - iemworld
#   7hz Eternal L.csv - vortexreviews
#   7hz Eternal R.csv - vortexreviews
#
# 7Hz Legato L.csv:
#   7Hz Legato L.csv - achoreviews, timmyv, cqtek, vsg
#   7HZ LEGATO L.csv - aftersound, ianfann
#   7HZ LEGATO R.csv - aftersound, ianfann
#   7Hz Legato R.csv - timmyv, hbb, cqtek, vsg
#   7hz LEGATO L.csv - nymz
#   7hz LEGATO R.csv - nymz
#   7hz Legato (250 mesh) L.csv - rg
#   7hz Legato (3 outer vent blutack) L.csv - rg
#   7hz Legato (500 mesh) L.csv - rg
#   7hz Legato (inner vent blutack) L.csv - rg
#   7hz Legato L.csv - rg, vortexreviews
#   7hz Legato R.csv - rg, vortexreviews
#
# 7Hz Timeless L.csv:
#   7Hz Timeless L.csv - achoreviews, arn, soundjedi, timmyv, pw, rg, vsg, data_mrs
#   7 HERTZ TIMELESS L.csv - aftersound
#   7 HERTZ TIMELESS R.csv - aftersound
#   7HZ TIMELESS AE L.csv - aftersound, ianfann
#   7HZ TIMELESS AE R.csv - aftersound, ianfann
#   7HZ TIMELESS L.csv - aftersound
#   7HZ TIMELESS R.csv - aftersound
#   7HZ TIMELESS S2 L.csv - aftersound
#   7HZ TIMELESS S2 R.csv - aftersound
#   7Hz Timeless R.csv - soundjedi, timmyv, harpo, pw, rg, vsg, data_mrs
#   7Hz Timeless AE L.csv - timmyv
#   7Hz Timeless AE R.csv - timmyv, hbb
#   7Hz Timeless (no filter) R.csv - hbb
#   7hz Timeless L.csv - hobbytalk, tgx78, vortexreviews
#   7hz Timeless R.csv - hobbytalk, tgx78, vortexreviews
#   7hz Timeless Tape Mod L.csv - hobbytalk
#   7hz Timeless Tape Mod R.csv - hobbytalk
#   7HZ TIMELESS OG L.csv - ianfann
#   7HZ TIMELESS OG R.csv - ianfann
#   7Hz Timeless (FINAL Tips) L.csv - iemworld
#   7Hz Timeless (FINAL Tips) R.csv - iemworld
#   7Hz Timeless (Foam Tips) L.csv - iemworld
#   7Hz Timeless (Foam Tips) R.csv - iemworld
#   7Hz Timeless (MoonDroop Tips) L.csv - iemworld
#   7Hz Timeless (MoonDroop Tips) R.csv - iemworld
#   Timeless L.csv - kr0mka
#   Timeless R.csv - kr0mka
#   Oratory 7Hz Timeless L.csv - kurin
#   7hertz Timeless L.csv - melatonin
#   7hertz Timeless R.csv - melatonin
#   7hz Timeless AE L.csv - nymz
#   7hz Timeless AE R.csv - nymz
#   7Hz Timeless S2 25ohm R.csv - pw
#   7Hz Timeless S2 75ohm R.csv - pw
#   7Hz Timeless S2 L.csv - pw
#   7Hz Timeless S2 MPBack L.csv - pw
#   7Hz Timeless S2 MPFront L.csv - pw
#   7Hz Timeless S2 R.csv - pw
#   7Hz Timeless (350 Mesh, stock tuning foam sideways, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (350 Mesh, stock tuning foam, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (Sony Import Foam) L.csv - rg
#   7Hz Timeless (Sony Import Foam, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (Tanchjim Filter, stock tuning foam sideways, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (S2) L.csv - data_mrs
#   7Hz Timeless (S2) R.csv - data_mrs
#
# 7Hz Zero L.csv:
#   7Hz Zero L.csv - achoreviews, bedrock, timmyv, data_mrs
#   7HZ SALNOTES ZERO L.csv - aftersound
#   7HZ SALNOTES ZERO R.csv - aftersound
#   7Hz Salnotes Zero L.csv - arn, pw
#   7Hz Zero R.csv - bedrock, timmyv, data_mrs
#   7Hz Salnotes Zero R.csv - harpo, pw
#   7hz Zero R.csv - hbb, hobbytalk
#   7hz Zero L.csv - hobbytalk
#   7hz Zero Tape L.csv - hobbytalk
#   7hz Zero Tape R.csv - hobbytalk
#   7HZ ZERO L.csv - ianfann
#   7HZ ZERO MECHA L.csv - ianfann
#   7HZ ZERO MECHA R.csv - ianfann
#   7HZ ZERO R.csv - ianfann
#   7hz Zero (EJ07 FOAM Eartips) L.csv - iemworld
#   7hz Zero (EJ07 FOAM Eartips) R.csv - iemworld
#   7hz Zero (Final Eartips) L.csv - iemworld
#   7hz Zero (Final Eartips) R.csv - iemworld
#   7hz Zero (MoonDrop Eartips) L.csv - iemworld
#   7hz Zero (MoonDrop Eartips) R.csv - iemworld
#   7hz Zero (Red Orignal Eartips) L.csv - iemworld
#   7hz Zero (Red Orignal Eartips) R.csv - iemworld
#   7Hz ZERO S1 L.csv - jacstone
#   7Hz ZERO S1 R.csv - jacstone
#   Oratory 7Hz Salnotes Zero L.csv - kurin
#   Resolve 7hz salnotes zero Gras L.csv - kurin
#   7hz Salnotes Zero L.csv - nymz, vortexreviews
#   7hz Salnotes Zero R.csv - nymz, vortexreviews
#   7hz Salnotes Zero S2 L.csv - nymz
#   7hz Salnotes Zero S2 R.csv - nymz
#   7Hz Salnotes Zero NoGrill L.csv - pw
#   7Hz Salnotes Zero Tape 500Damper R.csv - pw
#   7Hz Salnotes Zero Tape R.csv - pw
#   7Hz Salnotes Zero v2 L.csv - pw
#   7Hz Salnotes Zero v2 R.csv - pw
#   zero L.csv - recode
#   zero R.csv - recode
#
# target:
#   Acho Reviews Target.csv - achoreviews
#   Antdroid Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Bad Guy Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Banbeucmas Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Crinacle Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, timmyv, harpo, hbb, cqtek, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, shortbus, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Diffuse Field Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Etymotic Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Free Field Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Harman Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, iemworld, melatonin, nymz, pw, recode, shortbus, suporsalad, tgx78, vortexreviews, wdym, akros, data_mrs
#   Innerfidelity ID Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Precogvision Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Rtings Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Sonarworks Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Super Review Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   IEF neutral Target.csv - aftersound
#   Innerfidelity Target.csv - aftersound
#   Animagus Preference Target.csv - animagus
#   Harman In Ear 2019 Target.csv - animagus
#   Harman In Room Target.csv - animagus
#   Harman Over Ear 2018 Target.csv - animagus
#   Harman V2 Target.csv - arn
#   Bry Audio Reviews Target.csv - bryaudioreviews
#   Harman 2017 Target.csv - bryaudioreviews, ianfann
#   Harman 2019 Target.csv - bryaudioreviews, ianfann, jacstone
#   Oratory1990 Target.csv - bryaudioreviews, pw, vortexreviews
#   CammyFi Target.csv - cammyfi, kurin
#   Harman IE 2019 v2 Target.csv - cammyfi, kr0mka, kurin
#   Kurin Target.csv - cammyfi, kurin
#   AutoEQ Target.csv - eplv, pw
#   Harman2019v2 Target.csv - eplv
#   Old Crinacle Target.csv - eplv
#   Nymz Target.csv - timmyv
#   Timmy Target.csv - timmyv, kurin
#   AX Target.csv - harpo
#   Bad Guy 2022 Target.csv - harpo, hbb, kurin
#   EJ Target.csv - harpo
#   Harpo Target.csv - harpo, rg
#   Harpo v3 Target.csv - harpo
#   Harpo v4 Target (11.03.2023 02-43-36).csv - harpo
#   Harpo v4 Target.csv - harpo
#   Harpo_v2 Target.csv - harpo
#   RikudouGoku Target.csv - harpo, hbb, jacstone, kurin, nymz, pw, rg, tgx78, vortexreviews, data_mrs
#   Softears Target.csv - harpo
#   X Target.csv - harpo
#   Bad Guy Target v2.csv - hbb
#   IEF Target.csv - hbb, ianfann
#   MRS Target.csv - hbb
#   Precog Target.csv - hbb, kurin
#   Precog_broken Target.csv - hbb
#   Redeyes Target.csv - hbb, kurin, pw
#   Harman IE 2019 Target.csv - hobbytalk
#   Hobby Talk Flat Target.csv - hobbytalk
#   Hobby Talk Preference Target OG.csv - hobbytalk
#   Hobby Talk Preference Target.csv - hobbytalk, kurin
#   Honest Target.csv - hobbytalk
#   IEF OE Target.csv - hobbytalk
#   IanFann-Target Target.csv - ianfann
#   IEF Target1.csv - ianfann
#   IEM WORLD Target.csv - iemworld
#   nymz Target.csv - jacstone, nymz, rg
#   Paul Wasabii Target.csv - jacstone
#   Sharur Target.csv - jacstone, kurin
#   Harman IE 2016 Target.csv - kr0mka, kurin
#   Harman IE 2017 v2 Target.csv - kr0mka
#   kr0mka Target.csv - kr0mka
#   Coda Target.csv - kurin
#   Comfy Target.csv - kurin
#   Flat Target.csv - kurin
#   Freeryder05v2 Target.csv - kurin
#   Hobby Talk Target.csv - kurin
#   markanini Target.csv - kurin
#   Moondrop Target.csv - kurin
#   Normative Target.csv - kurin
#   Olive-Welti Harman Bass Target.csv - kurin
#   Olive-Welti Target.csv - kurin
#   Oratory IE Target.csv - kurin
#   Rikudogoku Target.csv - kurin
#   SEAP Target.csv - kurin
#   Srg0mes Target.csv - kurin
#   Super 22 Target.csv - kurin, data_mrs
#   Harman 2019v2 Target.csv - nymz, pw, rg
#   RikudouGoku_Target.csv - nymz
#   tgx78 Target.csv - nymz, rg
#   Crackhead Target.csv - pw, rg
#   PaulWasabii Target.csv - pw
#   Harman 2017v2 Target.csv - recode, rg
#   Recode Target.csv - recode
#   target 8.csv - recode
#   ALPHA 1.0 Target.csv - rg
#   Amelie Target.csv - rg
#   DynamicEars Target.csv - rg
#   evasb Target.csv - rg
#   Lixeem Target.csv - rg
#   PW Target.csv - rg
#   Resolution Target.csv - rg
#   stakk Target.csv - rg
#   Super Bass Target.csv - rg, data_mrs
#   Super Review 2021 Target.csv - rg
#   Super Review 2022 Target.csv - rg
#   Talbot Target.csv - rg
#   TKSilver Target.csv - rg
#   Redeyes 1 Target.csv - shortbus
#   DF Tilt 711 Ref Target.csv - suporsalad
#   Harman IEM Target.csv - suporsalad
#   Harman OE Target.csv - suporsalad
#   Kemar DF 1.3 Bass Target.csv - suporsalad
#   Kemar DF 1.3 Target.csv - suporsalad
#   Kemar DF Target.csv - suporsalad
#   Listener Target.csv - suporsalad
#   USound1V1 Oratory 1990 Target.csv - suporsalad
#   Tgx78 Target.csv - tgx78
#   Harman 2018 Over-Ear Target.csv - vsg
#   Harman 2019 In-Ear Target.csv - vsg
#   Harman Combined Over-Ear Target.csv - vsg
#   Harman In-Ear Target.csv - vsg
#   VSG Target.csv - vsg
#   Wdym Target.csv - wdym
#   Crinacle 2023 Adjusted Target.csv - data_mrs
#   Crinacle Adjusted Target.csv - data_mrs
#   Dent Target.csv - data_mrs
#   dentReviews Target.csv - data_mrs
#   Ghost Target.csv - data_mrs
#   Harman Adjusted Target.csv - data_mrs
#   HBB Comp Target.csv - data_mrs
#   HPDC 10dB Tilt 5128 DF 100Hz Target.csv - data_mrs
#   HPDC 10dB Tilt 5128 DF Target.csv - data_mrs
#   HPDC 10dB Tilt KEMAR DF 100Hz Target.csv - data_mrs
#   HPDC 10dB Tilt KEMAR DF Target.csv - data_mrs
#   HPDC 14dB Tilt 5128 DF 100Hz Target.csv - data_mrs
#   HPDC 14dB Tilt 5128 DF Target.csv - data_mrs
#   HPDC 14dB Tilt KEMAR DF 100Hz Target.csv - data_mrs
#   HPDC 14dB Tilt KEMAR DF Target.csv - data_mrs
#   IEC711 Comp Target.csv - data_mrs
#   IEF Comp Target.csv - data_mrs
#   Super 21 Target.csv - data_mrs
#   Working 001 Target.csv - data_mrs
#   Working 002 Target.csv - data_mrs
#
# Audeze iSine LX (Spinfit) L.csv:
#   Audeze iSine LX (Spinfit) L.csv - achoreviews
#
# Aune Jasper L.csv:
#   Aune Jasper L.csv - achoreviews, data_mrs
#   AUNE JASPER L.csv - aftersound
#   AUNE JASPER R.csv - aftersound
#   Aune Jasper R.csv - hbb, data_mrs
#   Aune Jasper (Tanchjim filter) L.csv - data_mrs
#   Aune Jasper (Tanchjim filter) R.csv - data_mrs
#
# Blon BL01 L.csv:
#   Blon BL01 L.csv - achoreviews
#   Blon BL03 L.csv - achoreviews, timmyv, suporsalad, data_mrs
#   Blon BL05s L.csv - achoreviews
#   Blon T1 L.csv - achoreviews
#   Blon T3 L.csv - achoreviews
#   BLON BL03 R.csv - aftersound, bryaudioreviews, ianfann
#   BLON BL07 L.csv - aftersound, ianfann, pw
#   BLON BL07 R.csv - aftersound, ianfann, pw
#   BLON BL01 L.csv - bryaudioreviews, pw
#   BLON BL01 R.csv - bryaudioreviews
#   BLON BL03 L.csv - bryaudioreviews, ianfann
#   Blon BL03 R.csv - timmyv, suporsalad
#   Blon BL07 R.csv - harpo
#   BLON 01 R.csv - hbb
#   Blon BL50 R.csv - hbb
#   BLON BL01v2 L.csv - pw
#   BLON BL05 L.csv - pw
#   BLON BL05S L.csv - pw
#   BLON BL05Sv2 L.csv - pw
#   BLON BL05v2 L.csv - pw
#   Blon A8 L.csv - vortexreviews
#   BLON B20 L.csv - vsg
#   BLON B60 L.csv - vsg
#   Blon BL05 L.csv - data_mrs
#
# Blon Fat Girl L.csv:
#   Blon Fat Girl L.csv - achoreviews, vortexreviews
#   BLON FAT GIRL L.csv - aftersound, ianfann
#   BLON FAT GIRL R.csv - aftersound, ianfann
#   BLON FatGirl9 L.csv - eplv
#   BLON FatGirl9 R.csv - eplv
#   BLON Fat Girl R.csv - hbb, jacstone, pw
#   BLON Fat Girl L.csv - jacstone, pw
#   Blon Fat Girl R.csv - vortexreviews
#
# Blon Z200 L.csv:
#   Blon Z200 L.csv - achoreviews, harpo, vortexreviews
#   BLON Z200 L.csv - arn, ianfann, pw
#   Blon Z200 R.csv - harpo, vortexreviews
#   BLON Z200 R.csv - ianfann, pw
#
# CCA CRA L.csv:
#   CCA CRA L.csv - achoreviews, aftersound, eplv, hobbytalk, ianfann, jacstone, melatonin, nymz, pw, rg, suporsalad, tgx78, vortexreviews, data_mrs
#   CCA CRA Plus L.csv - achoreviews, timmyv, pw, data_mrs
#   CCA CA10 L.csv - aftersound, ianfann, jacstone, melatonin, pw, rg, vortexreviews
#   CCA CRA R.csv - aftersound, eplv, harpo, hbb, hobbytalk, ianfann, jacstone, melatonin, nymz, pw, rg, suporsalad, data_mrs
#   CCA CRA S2 L.csv - aftersound, nymz, rg, tgx78
#   CCA CRA S2 R.csv - aftersound, nymz, rg, tgx78
#   CCA CRA+ L.csv - aftersound, bedrock, ianfann, jacstone, melatonin, nymz, rg, vortexreviews
#   CCA CRA+ R.csv - aftersound, bedrock, ianfann, jacstone, melatonin, nymz, rg, vortexreviews
#   CCA CSN L.csv - aftersound, bedrock, melatonin, pw
#   CCA NRA L.csv - aftersound, eplv, hobbytalk, ianfann, iemworld, melatonin, pw, vortexreviews
#   CCA NRA R.csv - aftersound, eplv, hbb, hobbytalk, ianfann, iemworld, melatonin
#   CCA C10 L.csv - bedrock, eplv, timmyv, melatonin, rg, data_mrs
#   CCA CRA Plus R.csv - timmyv, data_mrs
#   CCA CRA + R.csv - hbb
#   CCA LYRA L.csv - hobbytalk, ianfann
#   CCA CRA+ (STOCK TIPS) L.csv - ianfann
#   CCA CRA+ (STOCK TIPS) R.csv - ianfann
#   CCA CXS L.csv - ianfann, pw, vortexreviews
#   CCA C16 L.csv - kr0mka, melatonin
#   CRA L.csv - kr0mka
#   CRA R.csv - kr0mka
#   CCA A10 L.csv - melatonin
#   CCA C12 L.csv - melatonin
#   CCA CA16 L.csv - melatonin, pw
#   CCA CA24 L.csv - melatonin, vsg
#   CCA CRA EQ3 R.csv - nymz
#   CCA CA2 L.csv - pw, vortexreviews
#   CCA CA2v2 L.csv - pw
#   CCA CRA Plus Tape L.csv - pw
#   CCA CRA Plus Vent L.csv - pw
#   CCA CRA Plus Vent R.csv - pw
#   CCA CST L.csv - pw, vortexreviews
#   CCA CX4 L.csv - pw
#   CCA Lyra L.csv - pw, vortexreviews
#   CCA CRA (1dividedby4 Foam) L.csv - rg
#   CCA CRA (1dividedby8 Foam) L.csv - rg
#   CCA CRA (200 Mesh) L.csv - rg
#   CCA CRA (350 Mesh) L.csv - rg
#   CCA CRA (500 Mesh + 200 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 250 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 300 Paper Filter + High-Density Tuning Foam) L.csv - rg
#   CCA CRA (500 Mesh + 300 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 350 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 500 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + High-Density Tuning Foam) L.csv - rg
#   CCA CRA (500 Mesh + Sony General Foam) L.csv - rg
#   CCA CRA (500 Mesh + Y1 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + Y3 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + Y6 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh) L.csv - rg
#   CCA CRA (Filterless + 2 High-Density Tuning Foams) L.csv - rg
#   CCA CRA (Filterless + High-Density Tuning Foams) L.csv - rg
#   CCA CRA (Filterless) L.csv - rg
#   CCA CRA (Nylon filter) L.csv - rg
#   CCA CRA (Sony General Foam) L.csv - rg
#   CCA CRA (Sony Import Foam) L.csv - rg
#   CCA CRA (Tanchjim Filter) L.csv - rg
#   CCA CRA+ (Stock Filter + 350 Mesh) L.csv - rg
#   CCA CRA EQ L.csv - tgx78
#   CCA CRA Mod R.csv - tgx78
#   CCA CKX L.csv - vortexreviews
#   CCA CSA L.csv - vortexreviews
#   CCA FLA L.csv - vortexreviews
#
# CCZ Emerald L.csv:
#   CCZ Emerald L.csv - achoreviews, eplv
#   CCZ Melody L.csv - achoreviews, pw, vortexreviews
#   CCZ EMERALD L.csv - aftersound
#   CCZ EMERALD R.csv - aftersound
#   CCZ MELODY L.csv - aftersound, ianfann
#   CCZ Emerald R.csv - eplv
#   CCZ emerald L.csv - melatonin
#   CCZ emerald R.csv - melatonin
#   CCZ melody L.csv - melatonin
#
# CCZ Warrior L.csv:
#   CCZ Warrior L.csv - achoreviews, arn, pw
#   Tin C2 Mech Warrior L.csv - achoreviews
#   TIN C2 MECH WARRIOR L.csv - aftersound
#   CCZ WARRIOR L.csv - ianfann
#   CCZ WARRIOR R.csv - ianfann
#   CCZ Warrior R.csv - pw
#   Tin Hifi C2 Mech Warrior L.csv - data_mrs
#
# Celest Pandamon L.csv:
#   Celest Pandamon L.csv - achoreviews
#   Kinera Celest Pandamon L.csv - arn, cqtek, vortexreviews
#   Kinera Celest Pandamon R.csv - arn, cqtek, vortexreviews
#
# Dunu Kima L.csv:
#   Dunu Kima L.csv - achoreviews, bedrock, timmyv, cqtek, vortexreviews, data_mrs
#   DUNU KIMA L.csv - aftersound, ianfann, nymz, vsg
#   DUNU KIMA R.csv - aftersound, ianfann, nymz, vsg
#   Dunu Kima R.csv - bedrock, timmyv, hbb, cqtek, vortexreviews, data_mrs
#
# Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv:
#   Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv - achoreviews
#   Dunu Talos (Planar + BA) L.csv - achoreviews
#   Dunu Talos (Planar Only) (IE600 Foam Tips) L.csv - achoreviews
#   Dunu Talos (Planar Only) L.csv - achoreviews
#   DUNU TALOS OFF L.csv - aftersound
#   DUNU TALOS ON L.csv - aftersound
#   DUNU TALOS ON R.csv - aftersound
#   Dunu Talos (ON) L.csv - animagus
#   Dunu Talos (ON) R.csv - animagus
#   Dunu Talos L.csv - animagus, data_mrs
#   Dunu Talos R.csv - animagus, hbb, data_mrs
#   DUNU Talos Planar L.csv - arn
#   DUNU Talos Planar+BA L.csv - arn
#   Dunu Talos (Planar) L.csv - timmyv
#   Dunu Talos (Planar) R.csv - timmyv
#   Dunu Talos BA R.csv - hbb
#   DUNU TALOS PLANAR MODE L.csv - ianfann
#   DUNU TALOS PLANAR MODE R.csv - ianfann
#   DUNU TALOS PLANAR+BA L.csv - ianfann
#   DUNU TALOS PLANAR+BA R.csv - ianfann
#   DUNU TALOS L.csv - nymz
#   DUNU TALOS R.csv - nymz
#   DUNU Zen Foam L.csv - nymz
#   DUNU Talos L.csv - pw
#   DUNU Talos R.csv - pw
#   ie600 L.csv - recode
#   ie600 R.csv - recode
#   DUNU TALOS Planar L.csv - vsg
#   DUNU TALOS Planar mode L.csv - vsg
#   DUNU TALOS Planar mode R.csv - vsg
#   DUNU TALOS Planar R.csv - vsg
#   Dunu Talos (on) L.csv - data_mrs
#   Dunu Talos (on) R.csv - data_mrs
#
# Dunu Titan S (Isolation) L.csv:
#   Dunu Titan S (Isolation) L.csv - achoreviews
#   Dunu Titan S L.csv - achoreviews, bedrock, bryaudioreviews, timmyv, cqtek, nymz, rg, vortexreviews
#   DUNU TITAN 5 L.csv - aftersound
#   DUNU TITAN 5 R.csv - aftersound
#   DUNU TITAN S L.csv - aftersound, ianfann, iemworld, vsg
#   DUNU TITAN S R.csv - aftersound, ianfann, iemworld, vsg
#   DUNU Titan S L.csv - arn
#   DUNU Titan S R.csv - arn
#   Dunu Titan S R.csv - bedrock, bryaudioreviews, timmyv, hbb, cqtek, nymz, rg
#   DUNU Titan L.csv - pw
#   DUNU Titan R.csv - pw
#   Dunu Titan S (pre) L.csv - data_mrs
#
# Dunu Vulkan L.csv:
#   Dunu Vulkan L.csv - achoreviews, bedrock, timmyv, harpo, data_mrs
#   Dunu Vulkan R.csv - bedrock, timmyv, harpo, hbb, data_mrs
#   DUNU Vulkan L.csv - nymz
#   DUNU Vulkan R.csv - nymz
#   Dunu VULKAN L.csv - rg
#   Dunu VULKAN R.csv - rg
#   DUNU VULKAN L.csv - vsg
#   DUNU VULKAN R.csv - vsg
#   Dunu Vulkan (S2 + red) R.csv - data_mrs
#   Dunu Vulkan (S2) L.csv - data_mrs
#   Dunu Vulkan (S2) R.csv - data_mrs
#
# Effect Audio Axiom L.csv:
#   Effect Audio Axiom L.csv - achoreviews, vsg, data_mrs
#   Effect Audio GAEA L.csv - bryaudioreviews
#   Effect Audio Axiom R.csv - vsg, data_mrs
#   Effect Audio Gaea (deep) L.csv - data_mrs
#   Effect Audio Gaea L.csv - data_mrs
#
# Fiio FHE Eclipse L.csv:
#   Fiio FHE Eclipse L.csv - achoreviews
#   FIIO F1 L.csv - aftersound
#   Fiio F1 L.csv - bedrock
#   FiiO FHE L.csv - timmyv, melatonin
#   FiiO FHE R.csv - timmyv, melatonin
#   FIIO x Crinacle FHE Eclipse (Foam Eartips) L.csv - iemworld
#   FIIO x Crinacle FHE Eclipse (Foam Eartips) R.csv - iemworld
#   FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) L.csv - iemworld
#   FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) R.csv - iemworld
#   FiiO FHE S1 L.csv - jacstone
#   FiiO FHE S2 L.csv - jacstone
#   FiiO x Crinacle FHE (Eclipse) L.csv - vsg
#   FiiO x Crinacle FHE (Eclipse) R.csv - vsg
#   Fiio FHE (S2) L.csv - data_mrs
#   Fiio FHE L.csv - data_mrs
#   Fiio FHE R.csv - data_mrs
#
# Final Audio E500 L.csv:
#   Final Audio E500 L.csv - achoreviews, rg
#   FINAL AUDIO A4000 L.csv - aftersound
#   Final Audio B3 L.csv - bryaudioreviews
#   Final Audio B3 R.csv - bryaudioreviews
#   Final Audio e5000 L.csv - bryaudioreviews
#   Final Audio e5000 R.csv - bryaudioreviews
#   final E500 L.csv - eplv
#   final E500 R.csv - eplv
#   Final Audio E3000 R.csv - harpo, hobbytalk
#   Final Audio E1000 (S2) L.csv - hobbytalk
#   Final Audio E1000 L.csv - hobbytalk, nymz, rg
#   Final Audio E1000 R.csv - hobbytalk, nymz
#   Final Audio E3000 (S2) L.csv - hobbytalk
#   Final Audio E3000 L.csv - hobbytalk, rg
#   Oratory Final Audio A8000 L.csv - kurin
#   Oratory Final Audio Adagio III L.csv - kurin
#   Oratory Final Audio E1000 L.csv - kurin
#   Oratory Final Audio E3000 L.csv - kurin
#   Oratory Final Audio E4000 L.csv - kurin
#   Oratory Final Audio E500 L.csv - kurin
#   Oratory Final Audio E5000 L.csv - kurin
#   Oratory Final Audio F3100 L.csv - kurin
#   Oratory Final Audio Heaven IV L.csv - kurin
#   Oratory Final Audio Heaven V L.csv - kurin
#   Oratory Final Audio UX3000 (B, ANC on) L.csv - kurin
#   Final Audio A4000 L.csv - nymz
#   Final Audio A4000 V2 L.csv - nymz
#   Final Audio VR3000 L.csv - nymz, rg
#   Final E500 AutoEQ L.csv - pw
#   Final E500 L.csv - pw, akros, data_mrs
#   Final Audio E1000 (Micropore mod) L.csv - rg
#   Final Audio E2000 L.csv - rg
#   Final Audio E4000 L.csv - rg
#   Final Audio E500 R.csv - rg
#   Final Audio E5000 L.csv - rg
#   Final Audio F3100 L.csv - rg
#   Final Audio FI-EVA2020 L.csv - rg
#
# Hidition Violet L.csv:
#   Hidition Violet L.csv - achoreviews, soundjedi, cqtek, data_mrs
#   Hidition Viento B L.csv - soundjedi
#   Hidition Violet R.csv - soundjedi
#   Hidition Viento-B L.csv - timmyv
#
# Hifiman RE600s v2 L.csv:
#   Hifiman RE600s v2 L.csv - achoreviews
#   HIFIMAN RE800 L.csv - ianfann
#   Oratory HIFIMAN RE600S L.csv - kurin
#   Hifiman RE600 V2 L.csv - nymz
#   Hifiman RE600 V2 R.csv - nymz
#
# Hifiman Svanar L.csv:
#   Hifiman Svanar L.csv - achoreviews
#   HIFIMAN Susvara L.csv - vsg
#   HIFIMAN Svanar L.csv - vsg
#   HIFIMAN Svanar R.csv - vsg
#   HIFIMAN Svanar S2 L.csv - vsg
#   HIFIMAN Svanar S2 R.csv - vsg
#   HIFIMAN Svanar S3 L.csv - vsg
#   HIFIMAN Svanar S3 R.csv - vsg
#
# Hifiman TWS800 L.csv:
#   Hifiman TWS800 L.csv - achoreviews
#   HIFIMAN TWS800 L.csv - ianfann, vsg
#   HIFIMAN TWS800 R.csv - ianfann, vsg
#
# HZ Sound Heart Mirror Pro L.csv:
#   HZ Sound Heart Mirror Pro L.csv - achoreviews
#   HZSOUND HEART MIRROR L.csv - aftersound
#   CVJ Mirror L.csv - arn
#   Heart Mirror Pro L.csv - arn
#   Heart Mirror L.csv - bryaudioreviews
#   Heart Mirror R.csv - bryaudioreviews
#   HZ Heartmirror Pro L.csv - timmyv
#   HZSound Heart Mirror Pro L.csv - harpo
#   HZSound Heart Mirror Pro R.csv - harpo
#   HZ sound pro R.csv - hbb
#   HZ SOUND HEART MIRROR L.csv - ianfann
#   HZ SOUND HEART MIRROR PRO L.csv - ianfann
#   HZ SOUND HEART MIRROR PRO R.csv - ianfann
#   HZ SOUND HEART MIRROR R.csv - ianfann
#   X2 pro L.csv - kr0mka
#   HZSOUND Heart Mirror L.csv - nymz, vortexreviews
#   HZSOUND Heart Mirror Pro L.csv - nymz
#   HZSOUND Heart Mirror Pro R.csv - nymz
#   HZSound Heart Mirror L.csv - data_mrs
#
# Ikko Opal OH02 L.csv:
#   Ikko Opal OH02 L.csv - achoreviews
#   IKKO OPAL OH2 L.csv - arn
#   Ikko Opal OH2 L.csv - data_mrs
#   Ikko Opal OH2 R.csv - data_mrs
#
# ITK Unknown L.csv:
#   ITK Unknown L.csv - achoreviews
#   Unknown Amazon IEM L.csv - hobbytalk
#
# Joyodio Shine (0000) L.csv:
#   Joyodio Shine (0000) L.csv - achoreviews
#   Joyodio Shine (0010) L.csv - achoreviews
#   Joyodio Shine (0100) L.csv - achoreviews
#   Joyodio Shine (0110) L.csv - achoreviews
#   Joyodio Shine (1000) L.csv - achoreviews
#   Joyodio Shine (1010) L.csv - achoreviews
#   Joyodio Shine (1100) L.csv - achoreviews
#   Joyodio Shine (1110) L.csv - achoreviews
#   JOYODIO SHINE ALL OFF L.csv - aftersound
#   Joyodio Shine 0000 L.csv - cqtek
#   Joyodio Shine 0000 R.csv - cqtek
#   Joyodio Shine 0001 L.csv - cqtek
#   Joyodio Shine 0001 R.csv - cqtek
#   Joyodio Shine 0011 L.csv - cqtek
#   Joyodio Shine 0011 R.csv - cqtek
#   Joyodio Shine 0111 L.csv - cqtek
#   Joyodio Shine 1000 L.csv - cqtek
#   Joyodio Shine 1000 R.csv - cqtek
#   Joyodio Shine 1001 L.csv - cqtek
#   Joyodio Shine 1001 R.csv - cqtek
#   Joyodio Shine 1010 L.csv - cqtek
#   Joyodio Shine 1010 R.csv - cqtek
#   Joyodio Shine 1011 L.csv - cqtek
#   Joyodio Shine 1100 L.csv - cqtek
#   Joyodio Shine 1100 R.csv - cqtek
#   Joyodio Shine 1110 L.csv - cqtek
#   Joyodio Shine 1111 L.csv - cqtek
#   CVJ SHINE L.csv - ianfann
#   JOYODIO SHINE CLASSICAL L.csv - ianfann
#   JOYODIO SHINE HIFI L.csv - ianfann
#   JOYODIO SHINE POP L.csv - ianfann
#   JOYODIO SHINE POP R.csv - ianfann
#   JOYODIO SHINE RNB ROCK L.csv - ianfann
#   JOYODIO SHINE STANDARD L.csv - ianfann
#   Shine Pop L.csv - pw
#   Joyodio Shine POP R.csv - vortexreviews
#
# KBEAR Lark (S1) L.csv:
#   KBEAR Lark (S1) L.csv - achoreviews
#   KBEAR Lark (S2) L.csv - achoreviews
#   KBEAR KS1 L.csv - aftersound, ianfann, jacstone, pw
#   KBEAR INK L.csv - arn, ianfann, melatonin
#   KBEAR KS2 L.csv - bedrock, cqtek, ianfann, pw, rg
#   KBEAR Lark L.csv - bedrock, eplv, cqtek, melatonin
#   KBEAR Lark R.csv - bedrock, eplv, cqtek, melatonin
#   KBEAR F1 L.csv - eplv, pw
#   KBEAR KS19 L.csv - eplv
#   KBEAR ST1 L.csv - melatonin, pw
#   KBEAR Ink L.csv - pw
#   KBEAR Lark4k L.csv - pw
#   Kbear KS1 L.csv - vortexreviews
#   Kbear KS2 L.csv - vortexreviews
#   KBEar KS2 L.csv - data_mrs
#
# KBEAR Little Q L.csv:
#   KBEAR Little Q L.csv - achoreviews, arn
#   KBEar Little Q L.csv - bryaudioreviews
#   KBEar Little Q R.csv - bryaudioreviews
#   Kbear Q R.csv - hbb
#   KBEAR LITTLE Q L.csv - ianfann
#   KBEAR LITTLE Q R.csv - ianfann
#   KBEAR LittleQ L.csv - pw
#   KBEAR LittleQ R.csv - pw
#
# KBEAR Qinglong L.csv:
#   KBEAR Qinglong L.csv - achoreviews, arn
#   KBEAR QINGLONG L.csv - aftersound, ianfann
#   KBEAR QINGLONG R.csv - aftersound, ianfann
#   KBEAR Qinglong R.csv - arn
#
# KBEAR Robin L.csv:
#   KBEAR Robin L.csv - achoreviews, cqtek, melatonin, pw, rg
#   KBEAR NEON L.csv - aftersound, ianfann
#   KB Ear Robin L.csv - bryaudioreviews
#   KBEAR Neon L.csv - bryaudioreviews, eplv, pw
#   KBEAR Robin R.csv - cqtek, melatonin, rg
#
# Kinera BD005 Pro L.csv:
#   Kinera BD005 Pro L.csv - achoreviews, bedrock
#   KINERA BD005 PRO R.csv - aftersound
#   Kinera BD005 Pro R.csv - bedrock
#   Kinera Tyr L.csv - bedrock
#   Kinera BD005 R.csv - hbb
#   KINERA URD L.csv - ianfann
#   Kinera BD005Pro L.csv - pw
#   Kinera Sif L.csv - data_mrs
#
# Kiwi Ears Cadenza L.csv:
#   Kiwi Ears Cadenza L.csv - achoreviews, bedrock, cammyfi, hobbytalk, vortexreviews, data_mrs
#   KIWI EARS CADENZA L.csv - aftersound
#   KIWI EARS CADENZA R.csv - aftersound
#   Kiwi Ears CADENZA L.csv - arn
#   Kiwi Ears CADENZA R.csv - arn
#   Kiwi Ears Cadenza R.csv - bedrock, cammyfi, harpo, hbb, hobbytalk, vortexreviews, data_mrs
#   Kiwi Cadenza L.csv - timmyv
#   Kiwi Cadenza R.csv - timmyv
#   Kiwi Ears R.csv - hbb
#
# Kiwi Ears Orchestra Lite L.csv:
#   Kiwi Ears Orchestra Lite L.csv - achoreviews, bedrock, nymz, pw, rg, vortexreviews, vsg, data_mrs
#   Kiwi Ears Orchestra Lite R.csv - bedrock, nymz, pw, rg, vortexreviews, vsg, data_mrs
#   Kiwi Orchestra L.csv - timmyv
#   Kiwi Orchestra Lite L.csv - timmyv
#   Kiwi Orchestra Lite R.csv - timmyv
#   Kiwi Orchestra R.csv - timmyv
#   KIWIEARS ORCHESTRA LITE L.csv - ianfann
#   Kiwi Ears Orchestra Lite (2.5mm 500 mesh on green bore) L.csv - rg
#   Kiwi Ears Orchestra Lite (2.5mm 500 mesh on white bore) L.csv - rg
#   Kiwi Ears Orchestra Lite (2.5mm 500 mesh on yellow bore) L.csv - rg
#   Kiwi Ears Orchestra Lite (25ohm) L.csv - rg
#   Kiwi Ears Orchestra Lite deep fit L.csv - vsg
#   Kiwi Ears Orchestra Lite deep fit R.csv - vsg
#   Kiwi Ears Orchestra (E-type TWS) L.csv - data_mrs
#   Kiwi Ears Orchestra (E-type TWS) R.csv - data_mrs
#   Kiwi Ears Orchestra (Sedna Short) L.csv - data_mrs
#   Kiwi Ears Orchestra (Sedna Short) R.csv - data_mrs
#   Kiwi Ears Orchestra L.csv - data_mrs
#   Kiwi Ears Orchestra R.csv - data_mrs
#
# Koss KEB90 L.csv:
#   Koss KEB90 L.csv - achoreviews, data_mrs
#   KOSS KEB90 L.csv - hobbytalk
#   KOSS KEB90 R.csv - hobbytalk
#   Koss KEB90 R.csv - data_mrs
#
# KZ AS16 Pro L.csv:
#   KZ AS16 Pro L.csv - achoreviews, melatonin, pw, vortexreviews
#   KZ EDX Pro L.csv - achoreviews, melatonin, pw, rg, vortexreviews, data_mrs
#   KZ ZEX Pro L.csv - achoreviews, pw, rg, vortexreviews, data_mrs
#   KZ ZS10 Pro L.csv - achoreviews, eplv, melatonin, pw, data_mrs
#   KZ ZSN Pro L.csv - achoreviews, melatonin, pw, data_mrs
#   KZ AS16 PRO L.csv - aftersound, ianfann
#   KZ AS16 PRO R.csv - aftersound, ianfann
#   KZ EDX PRO L.csv - aftersound, jacstone
#   KZ ZEX PRO L.csv - aftersound, ianfann, jacstone
#   KZ ZSN PRO L.csv - aftersound
#   KZ PR1 Pro L.csv - arn, pw, data_mrs
#   KZ AS16 L.csv - eplv, melatonin
#   KZ AS16 R.csv - eplv, melatonin
#   KZ AS16Pro L.csv - eplv
#   KZ AS16Pro R.csv - eplv
#   KZ AS16Pro22 L.csv - eplv
#   KZ AS16R22 L.csv - eplv
#   KZ ZS10 PRO L.csv - timmyv, ianfann, jacstone
#   KZ AS16 Pro R.csv - hbb, melatonin, pw, vortexreviews
#   KZ PR1 PRO L.csv - ianfann
#   KZ SK10 PRO L.csv - ianfann
#   QKZ AK6 Pro L.csv - jacstone
#   KZ AS16 Pro 200Ω R.csv - melatonin
#   KZ AS16 Pro 30Ω R.csv - melatonin
#   KZ AS16 Pro 75Ω R.csv - melatonin
#   KZ AS16 Pro 25ohm L.csv - pw
#   KZ AS16 Pro BTX L.csv - pw
#   KZ AS16 Pro TK2 L.csv - pw
#   KZ Zex Pro L.csv - tgx78
#
# KZ ATE L.csv:
#   KZ ATE L.csv - achoreviews, data_mrs
#   KZ ATR L.csv - eplv
#   KZ AST L.csv - harpo, melatonin, data_mrs
#   Oratory KZ ATE L.csv - kurin
#   KZ ATE R.csv - data_mrs
#
# KZ DQ6 L.csv:
#   KZ DQ6 L.csv - achoreviews, eplv, ianfann, jacstone, melatonin, nymz, pw, rg, data_mrs
#   KZ DQ6s L.csv - achoreviews, melatonin, nymz
#   KZ DQS L.csv - achoreviews, ianfann, pw
#   KZ ED16 L.csv - achoreviews
#   KZ DQ6 R.csv - aftersound, eplv, hbb, ianfann, jacstone, melatonin, nymz, vortexreviews, data_mrs
#   KZ DQ6S L.csv - aftersound, bedrock, ianfann, jacstone, pw, rg
#   KZ DQ6S R.csv - aftersound, bedrock, harpo, ianfann, jacstone, pw, rg
#   KZ DQ6 5 R.csv - hbb
#   KZ DQ6 R Xf R.csv - hbb
#   KZ DQ6 X HBB R.csv - hbb
#   KZ DQ6 X R.csv - hbb
#   KZ DQ6 X2 R.csv - hbb
#   KZ DQ6 X5 R.csv - hbb
#   KZ DQ6 Xl R.csv - hbb
#   KZ DQ6s R.csv - melatonin, nymz
#   KZ DQ6Sv2 L.csv - pw
#   KZ DQ6Sv3 L.csv - pw
#   KZ DQ6v2 L.csv - pw
#   KZ DQ6 (1dividedby16 foam) L.csv - rg
#   KZ DQ6 (Hana Filter) L.csv - rg
#   KZ DQ6 (High-Density Tuning Foam + cotton filter) L.csv - rg
#   KZ DQ6 (High-Density Tuning Foam) L.csv - rg
#   KZ DQ6 (Low-Density Tuning Foam) L.csv - rg
#   KZ DQ6 (Micropore Tape Mod) L.csv - rg
#   KZ DQ6 (Micropore tape+ 1dividedby16foam Mod) L.csv - rg
#   KZ DQ6 (Micropore Tips) L.csv - rg
#   KZ DQ6 (Micropore+ 1dividedby16foam Tips) L.csv - rg
#   KZ DQ6 (O2 Filter) L.csv - rg
#   KZ DQ6 (Sony Import Foam) L.csv - rg
#   KZ DQ6 (Tanchjim filter) L.csv - data_mrs
#   KZ DQ6 (Tanchjim filter) R.csv - data_mrs
#
# KZ EDX L.csv:
#   KZ EDX L.csv - achoreviews, eplv, jacstone, melatonin, pw, vortexreviews
#   KZ ZEX L.csv - achoreviews, bryaudioreviews, ianfann, iemworld, jacstone, melatonin, suporsalad, tgx78, vortexreviews, data_mrs
#   KZ EDX PRO R.csv - aftersound, hbb, jacstone
#   KZ EDX R.csv - aftersound, eplv, jacstone, melatonin, vortexreviews
#   KZ EDX ULTRA L.csv - aftersound, ianfann
#   KZ EDX ULTRA R.csv - aftersound, ianfann
#   KZ ESX L.csv - arn, harpo, ianfann, jacstone, melatonin, pw
#   KZ ESX9 L.csv - eplv
#   KZ Edcx R.csv - hbb
#   KZ EDCX L.csv - ianfann, suporsalad
#   KZ EDCX R.csv - ianfann, suporsalad
#   KZ EDS L.csv - jacstone, melatonin, pw
#   KZ EDX Ultra L.csv - jacstone, pw, rg, vortexreviews
#   KZ EDX Ultra R.csv - jacstone, pw, rg, vortexreviews
#   KZ EDC L.csv - melatonin, pw
#   KZ EDX Pro R.csv - melatonin, pw, rg, data_mrs
#   KZ EDXv2 L.csv - pw
#   KZ EDR1 L.csv - rg
#   KZ EDX Pro (2 Low-Density Tuning Foams) L.csv - rg
#   KZ EDX Pro (High-Density Tuning Foam) L.csv - rg
#   KZ EDX Pro (Low-Density Tuning Foam) L.csv - rg
#   KZ EDAB L.csv - suporsalad
#   KZ EDAHi L.csv - suporsalad
#
# KZ PR1 L.csv:
#   KZ PR1 L.csv - achoreviews, timmyv, ianfann
#   KZ PR1 HiFi L.csv - arn
#   KZ PR1 HiFi R.csv - arn
#   KZ PR1 Pro R.csv - arn, pw, data_mrs
#   PR1 PRO L.csv - cammyfi
#   KZ PR1 R.csv - timmyv, hbb, ianfann
#   KZ PR1 Balanced L.csv - harpo
#   KZ PR1 PRO R.csv - ianfann
#   KZ PR1 STOCK TIPS L.csv - ianfann
#   KZ PR1 STOCK TIPS R.csv - ianfann
#   KZ PR1 Balanced version R.csv - melatonin
#   KZ PR1 HiFi version form R.csv - melatonin
#   KZ PR1 HiFi version R.csv - melatonin
#   KZ S1 L.csv - pw
#   KZ Z1 L.csv - pw
#   pro1 8k L.csv - recode
#   KZ PR1 Hifi L.csv - vortexreviews
#   KZ PR1 Hifi R.csv - vortexreviews
#
# KZ ZAX L.csv:
#   KZ ZAX L.csv - achoreviews, melatonin, pw, vortexreviews
#   KZ ZVX L.csv - achoreviews, aftersound, timmyv, ianfann, pw
#   KZ ASX9 L.csv - eplv
#   KZ ZAS L.csv - eplv, ianfann, melatonin, pw, vortexreviews
#   KZ ZSA9 L.csv - eplv
#   KZ ZSTx L.csv - eplv
#   KZ ZSX L.csv - eplv, melatonin, pw, vortexreviews
#   KZ ZAX R.csv - hbb, melatonin
#   KZ ZAR L.csv - ianfann, pw, vortexreviews
#   KZ ZNA L.csv - ianfann, pw, vortexreviews
#   QKZ ZXT L.csv - jacstone
#   KZ ASX L.csv - pw, data_mrs
#   KZ ASXv2 L.csv - pw
#   KZ Z3 L.csv - pw
#   KZ ZAXv2 L.csv - pw
#   KZ ZSTX L.csv - pw
#   KZ ZSXv2 L.csv - pw
#
# KZ ZES L.csv:
#   KZ ZES L.csv - achoreviews, aftersound, ianfann, pw, rg, vortexreviews
#   KZ ZSN L.csv - achoreviews, eplv, melatonin, pw
#   KZ ZST X L.csv - achoreviews, melatonin, vortexreviews
#   KZ ZES R.csv - aftersound, ianfann, rg, vortexreviews
#   KZ ES4 L.csv - eplv, melatonin, pw
#   KZ ZS4 L.csv - eplv, rg
#   KZ ZS5 L.csv - eplv, melatonin
#   KZ ZS6 L.csv - eplv, melatonin, rg
#   KZ ZS79 L.csv - eplv
#   KZ ZSR L.csv - eplv, pw
#   KZ ZS10 L.csv - melatonin, data_mrs
#   KZ ZS7 L.csv - melatonin, rg, data_mrs
#   KZ ZST L.csv - melatonin, pw
#   KZ ZSNv2 L.csv - pw
#   KZ ZSTv2 L.csv - pw
#   KZ ZSE L.csv - rg
#
# KZ ZSN Pro X L.csv:
#   KZ ZSN Pro X L.csv - achoreviews, bryaudioreviews, melatonin, pw
#   KZ ZSN PRO R.csv - aftersound
#   KZ ZSN PRO X R.csv - aftersound
#   KZ ZSN Pro X R.csv - bryaudioreviews, hbb, melatonin
#   KZ ZSN R.csv - eplv, hbb, melatonin
#   KZ ZS10 PRO X L.csv - ianfann
#   KZ ZS10 PRO X R.csv - ianfann
#   Oratory KZ ZSN Pro L.csv - kurin
#   KZ ZSN Pro R.csv - melatonin
#   KZ ZSN PRO X BROKEN R.csv - nymz
#   KZ ZSN PRO X OK L.csv - nymz
#   KZ ZSN Pro Xv2 L.csv - pw
#   KZ ZSN Prov2 L.csv - pw
#   KZ ZS10 Pro X L.csv - vortexreviews, data_mrs
#   KZ ZS10 Pro X R.csv - vortexreviews, data_mrs
#   KZ ZSN Pro (1-8 foam) L.csv - data_mrs
#   KZ ZSN Pro (Blessing 2 filter) L.csv - data_mrs
#   KZ ZSN Pro (Starfield filter) L.csv - data_mrs
#   KZ ZSN Pro (Tanchjim filter) L.csv - data_mrs
#
# Letshuoer D13 (Gold Filter) L.csv:
#   Letshuoer D13 (Gold Filter) L.csv - achoreviews
#   Letshuoer D13 (Silver Filter) L.csv - achoreviews
#   LETSHUOER S12 L.csv - arn, eplv, vortexreviews, vsg
#   Letshuoer D13 (Gold) L.csv - bedrock
#   Letshuoer D13 (Gold) R.csv - bedrock
#   LetShuoer S12 L.csv - soundjedi, cqtek
#   Letshuoer KL L.csv - timmyv
#   Letshuoer S12 L.csv - timmyv, data_mrs
#   LETSHUOER D13 Olina Filter mod R.csv - harpo
#   LetShuoer D13 Gold L.csv - cqtek, pw
#   LetShuoer D13 Gold R.csv - cqtek, pw
#   LETSHUOER D13 L.csv - hobbytalk, ianfann
#   LETSHUOER D13 MBP L.csv - hobbytalk
#   LETSHUOER D13 MBP R.csv - hobbytalk
#   LETSHUOER D13 R.csv - hobbytalk, ianfann, vortexreviews
#   LETSHUOER EJ07 L.csv - hobbytalk
#   LETSHUOER EJ09 L.csv - hobbytalk
#   LETSHUOER Z12 L.csv - hobbytalk, vsg
#   LETSHUOER D13 gold nozzle L.csv - vsg
#   Letshuoer D13 (gold) L.csv - data_mrs
#   Letshuoer D13 (gold) R.csv - data_mrs
#
# Letshuoer S12 (S1) L.csv:
#   Letshuoer S12 (S1) L.csv - achoreviews
#   Letshuoer S12 (S2) L.csv - achoreviews
#   Letshuoer S12 PRO L.csv - cammyfi
#   Letshuoer S12 PRO R.csv - cammyfi
#   Letshuoer S12 PRO Vents Blocked 300 Damping L.csv - cammyfi
#   Letshuoer S12 PRO Vents Blocked L.csv - cammyfi
#   LetShuoer S12 R.csv - soundjedi, cqtek
#   LETSHUOER S12 R.csv - eplv, melatonin, vortexreviews, vsg
#   Letshuoer S12 Pro L.csv - timmyv
#   Letshuoer S12 Pro R.csv - timmyv
#   Letshuoer S12 R.csv - timmyv, harpo, data_mrs
#   LetShuoer S12 Pro L.csv - cqtek
#   LetShuoer S12 Pro R.csv - cqtek
#   LETSHUOER S12 PRO L.csv - hobbytalk, ianfann, vortexreviews
#   LETSHUOER S12 PRO R.csv - hobbytalk, ianfann, vortexreviews
#   LETSHUOER Z12 (S2) L.csv - hobbytalk
#   LETSHUOER Z12 (S2) R.csv - hobbytalk
#   LETSHUOER S12 Foam R.csv - melatonin
#   S12 L.csv - shortbus
#   Letshuoer S12 (front vent blocked) L.csv - data_mrs
#   Letshuoer S12 (post) L.csv - data_mrs
#   Letshuoer S12 (post) R.csv - data_mrs
#   Letshuoer S12 (prepro) L.csv - data_mrs
#   Letshuoer S12 (prepro) R.csv - data_mrs
#   Letshuoer S12 (top vent blocked) L.csv - data_mrs
#
# LZ A4 Pro NzBlk FiBlk L.csv:
#   LZ A4 Pro NzBlk FiBlk L.csv - achoreviews
#   LZ A4 Pro NzBlk FiBlu L.csv - achoreviews
#   LZ A4 Pro NzBlk FiRed L.csv - achoreviews
#   LZ A4 Pro NzBlu FiBlk L.csv - achoreviews
#   LZ A4 Pro NzBlu FiBlu L.csv - achoreviews
#   LZ A4 Pro NzBlu FiRed L.csv - achoreviews
#   LZ A4 Pro NzRed FiBlk L.csv - achoreviews
#   LZ A4 Pro NzRed FiBlu L.csv - achoreviews
#   LZ A4 Pro NzSil FiBlk L.csv - achoreviews
#   LZ A4 Pro NzSil FiBlu L.csv - achoreviews
#   LZ A4 PRO R.csv - hbb
#   LZ A2 PRO L.csv - cqtek
#
# LZ A4 Pro NzRed FiRed L.csv:
#   LZ A4 Pro NzRed FiRed L.csv - achoreviews
#   LZ A4 Pro NzSil FiRed L.csv - achoreviews
#
# Meze Audio Advar L.csv:
#   Meze Audio Advar L.csv - achoreviews
#
# Moondrop Aria L.csv:
#   Moondrop Aria L.csv - achoreviews, animagus, bedrock, bryaudioreviews, timmyv, pw, vortexreviews, vsg, data_mrs
#   Moondrop Blessing 2 Dusk (Spinfit) L.csv - achoreviews
#   Moondrop Chu L.csv - achoreviews, arn, bedrock, cammyfi, eplv, timmyv, hobbytalk, jacstone, nymz, pw, suporsalad, data_mrs
#   Moondrop Nekocake (Balanced + ANC) L.csv - achoreviews
#   Moondrop Nekocake (Balanced) L.csv - achoreviews
#   Moondrop Nekocake (Classic) L.csv - achoreviews
#   Moondrop Nekocake (Nobass) L.csv - achoreviews
#   Moondrop Nekocake (Wennebostel) L.csv - achoreviews
#   Moondrop Nekocake (X-Dynamic) L.csv - achoreviews
#   Moondrop Quarks L.csv - achoreviews, bedrock, eplv, hobbytalk, rg, suporsalad, vortexreviews, data_mrs
#   Moondrop SSP L.csv - achoreviews, bedrock, eplv, cqtek, data_mrs
#   Moondrop SSR L.csv - achoreviews, bedrock, bryaudioreviews, cqtek, nymz, data_mrs
#   Moondrop Starfield L.csv - achoreviews, timmyv, suporsalad, data_mrs
#   MOONDROP ARIA (OLD) L.csv - aftersound
#   MOONDROP ARIA (OLD) R.csv - aftersound
#   MOONDROP ARIA L.csv - aftersound, ianfann
#   MOONDROP ARIA R.csv - aftersound, ianfann
#   MOONDROP BLESSING 2 L.csv - aftersound
#   MOONDROP CHU L.csv - aftersound, ianfann
#   MOONDROP CRESCENT L.csv - aftersound
#   MOONDROP DROPLET L.csv - aftersound, ianfann
#   MOONDROP KATO (BRASS) L.csv - aftersound
#   MOONDROP KATO (COPPER) L.csv - aftersound
#   MOONDROP KATO (SILVER) L.csv - aftersound
#   MOONDROP KATO (STEEL) L.csv - aftersound
#   MOONDROP KATO NON SPRING (BRASS) L.csv - aftersound
#   MOONDROP KATO NON SPRING (STEEL) L.csv - aftersound
#   MOONDROP KXXX L.csv - aftersound
#   MOONDROP NEKOCAKE L.csv - aftersound, vsg
#   MOONDROP QUARKS L.csv - aftersound
#   MOONDROP S8 L.csv - aftersound
#   MOONDROP SPARKS L.csv - aftersound
#   MOONDROP SSP L.csv - aftersound
#   MOONDROP SSR L.csv - aftersound
#   MOONDROP STARDUST L.csv - aftersound
#   MOONDROP STELLARIS L.csv - aftersound, ianfann, vsg
#   MOONDROP VARIATIONS L.csv - aftersound
#   Moondrop A8 L.csv - animagus, pw
#   Moondrop Aria R.csv - animagus, bedrock, bryaudioreviews, timmyv, harpo, hbb, pw, vsg
#   Moondrop Aria Snow Edition L.csv - animagus
#   Moondrop Aria Snow Edition R.csv - animagus
#   Moondrop Blessing2 L.csv - animagus
#   Moondrop Kato L.csv - animagus, timmyv, hobbytalk, tgx78, data_mrs
#   Moondrop KXXS (New Filters) L.csv - animagus
#   Moondrop Stellaris (Foam) L.csv - animagus
#   Moondrop Stellaris (UC) L.csv - animagus
#   MOONDROP Droplet L.csv - arn, vsg
#   Moondrop LAN L.csv - arn, bryaudioreviews, data_mrs
#   Moondrop Lan L.csv - bedrock, cammyfi, timmyv, vortexreviews
#   Moondrop S8 L.csv - bedrock, timmyv, data_mrs
#   Moondrop Stellaris L.csv - bedrock, bryaudioreviews, timmyv, nymz, pw, vortexreviews, data_mrs
#   Moondrop Stellaris modded L.csv - bryaudioreviews
#   Moondrop Variations L.csv - bryaudioreviews, cammyfi, timmyv, hobbytalk, nymz, data_mrs
#   Moondrop Quarks DSP L.csv - cammyfi, harpo, hobbytalk, nymz, suporsalad, vsg, data_mrs
#   Moondrop Variations Manufacturer Measurment L.csv - cammyfi
#   Moondrop Spaceship L.csv - eplv, rg, data_mrs
#   Moondrop  Starfield L.csv - timmyv
#   Moondrop Aria Snow L.csv - timmyv, pw, data_mrs
#   Moondrop Aria Snow R.csv - timmyv, hbb, pw, data_mrs
#   Moondrop B2 Dusk L.csv - timmyv, nymz
#   Moondrop B2 L.csv - timmyv
#   Moondrop Blessing 2 Dusk L.csv - cqtek, data_mrs
#   Moondrop Kanas Pro L.csv - cqtek, data_mrs
#   Moondrop Droplet L.csv - hobbytalk, pw
#   Moondrop Quarks (S2) L.csv - hobbytalk
#   Moondrop Quarks (S3) L.csv - hobbytalk
#   Moondrop Quarks DSP 77db L.csv - hobbytalk
#   Moondrop Quarks DSP Stock Tips L.csv - hobbytalk
#   Moondrop Quarks DSP Ultra Deep L.csv - hobbytalk
#   Moondrop Variations 220ohm L.csv - hobbytalk
#   Moondrop Variations CP100+ L.csv - hobbytalk
#   Moondrop Variations Springtips L.csv - hobbytalk
#   MOONDROP ARIA SNOW L.csv - ianfann
#   MOONDROP ARIA SNOW R.csv - ianfann
#   MOONDROP CHU (MOD) L.csv - ianfann
#   MOONDROP CHU (SF 145) L.csv - ianfann
#   MOONDROP CHU (SPRING TIPS) L.csv - ianfann
#   MOONDROP CHU BASS MOD L.csv - ianfann
#   MOONDROP LAN L.csv - ianfann, vsg
#   MOONDROP QUARKS DSP L.csv - ianfann
#   Hidizs MS5 Balanced (MoonDrop Spring Tips) L.csv - iemworld
#   Hidizs MS5 Bass (MoonDrop Spring Tips) L.csv - iemworld
#   Hidizs MS5 Treble (MoonDrop Spring Tips) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (BGVP Foam) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (FINAL EARTIPS) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (NO TIP on Coupler 8K) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (ORIGNAL SILICON) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (SOFTEAR UC EARTIPS)C L.csv - iemworld
#   Moondrop Blessing 2 Dusk (Tripowin Foam) L.csv - iemworld
#   MoonDrop CHU L.csv - iemworld
#   MoonDrop LAN (BGVP Foam) L.csv - iemworld
#   MoonDrop LAN (FINAL EARTIPS) L.csv - iemworld
#   MoonDrop LAN (ORIGNAL SILICON) L.csv - iemworld
#   MoonDrop LAN (SOFTEAR UC EARTIPS) L.csv - iemworld
#   MoonDrop LAN (Tripowin Foam) L.csv - iemworld
#   MoonDrop Quarks DSP L.csv - iemworld
#   SeeAudio Yume (MoonDrop Eartips) L.csv - iemworld
#   Shuoer S12 (MoonDrop Eartips) L.csv - iemworld
#   Tripowin x HBB Olina (2 Filter MoonDrop Eartips) L.csv - iemworld
#   Tripowin x HBB Olina (MoonDrop Eartips) L.csv - iemworld
#   TRUTHEAR x Crinacle ZERO (MoonDrop Eartips) L.csv - iemworld
#   Moondrop Aria S1 L.csv - jacstone
#   Moondrop Aria S1 R.csv - jacstone
#   Moondrop Aria S2 L.csv - jacstone
#   Moondrop Aria S2 R.csv - jacstone
#   Moondrop Blessing 2 Dusk S1 L.csv - jacstone
#   Moondrop Blessing 2 Dusk S2 L.csv - jacstone
#   Aria L.csv - kr0mka
#   Aria R.csv - kr0mka
#   Oratory Moondrop Blessing 2 Dusk L.csv - kurin
#   Oratory Moondrop Blessing 2 L.csv - kurin
#   Oratory Moondrop Blessing L.csv - kurin
#   Oratory Moondrop Chu L.csv - kurin
#   Oratory Moondrop Crescent L.csv - kurin
#   Oratory Moondrop Quarks L.csv - kurin
#   Oratory Moondrop Starfield L.csv - kurin
#   Resolve Moondrop Kato Gras L.csv - kurin
#   Resolve Moondrop KXXX Gras L.csv - kurin
#   Moondrop KXXS L.csv - melatonin, rg, data_mrs
#   Moondrop Blessing 2 L.csv - nymz, rg, data_mrs
#   Moondrop Chu Tanya L.csv - nymz, pw
#   Moondrop Aria Snow MP L.csv - pw
#   Moondrop Aria Snow NoFoam L.csv - pw
#   Moondrop Aria Snow NoFoam MP L.csv - pw
#   Moondrop Chu MP L.csv - pw
#   Moondrop Stellaris NoFoam L.csv - pw
#   Moondrop Illumination L.csv - recode, data_mrs
#   Moondrop Kato (Gold) L.csv - rg
#   Moondrop Kato (Gold, High-Density Tuning Foam) L.csv - rg
#   Moondrop Kato (Gold, Sony General Foam) L.csv - rg
#   Moondrop Kato (Gold, Sony Import Foam) L.csv - rg
#   Moondrop Kato (Gold, Sony Import Foam, Micropore Vent) L.csv - rg
#   Moondrop Kato (Silver) L.csv - rg
#   Moondrop B2D L.csv - suporsalad
#   Moondrop Crescent L.csv - vortexreviews, data_mrs
#   MOONDROP Aria Snow Edition L.csv - vsg
#   MOONDROP Aria Snow Edition R.csv - vsg
#   MOONDROP Blessing 3 L.csv - vsg
#   Moondrop CHU L.csv - vsg
#   Moondrop KATO Brass L.csv - vsg
#   Moondrop KATO L.csv - vsg
#   Moondrop Sparks L.csv - vsg, data_mrs
#   MOONDROP VENUS L.csv - vsg
#   Moondrop VOID L.csv - vsg
#   Moondrop VOID S1 L.csv - vsg
#   Moondrop VOID S2 L.csv - vsg
#   ARIA L.csv - akros
#   Moondrop Alice (0.1.9) L.csv - data_mrs
#   Moondrop Alice (2.0.1 + E-type) L.csv - data_mrs
#   Moondrop Alice (2.0.1) L.csv - data_mrs
#   Moondrop Alice (EQ Austria) L.csv - data_mrs
#   Moondrop Alice (EQ Berlin) L.csv - data_mrs
#   Moondrop Alice (EQ Brooklyn) L.csv - data_mrs
#   Moondrop Alice (EQ Hokkaido) L.csv - data_mrs
#   Moondrop Alice (EQ In-Ear Target) L.csv - data_mrs
#   Moondrop Alice (EQ Munich) L.csv - data_mrs
#   Moondrop Alice (EQ PEQ default) L.csv - data_mrs
#   Moondrop Alice (EQ Tokyo) L.csv - data_mrs
#   Moondrop Alice (EQ Vienna) L.csv - data_mrs
#   Moondrop Alice (EQ Wennebostel) L.csv - data_mrs
#   Moondrop Alice L.csv - data_mrs
#   Moondrop Aria Snow (Spring) L.csv - data_mrs
#   Moondrop Aria Snow (Spring) R.csv - data_mrs
#   Moondrop Blessing 2 (E-type) L.csv - data_mrs
#   Moondrop Blessing 2 (Moondrop filter) L.csv - data_mrs
#   Moondrop Blessing 2 (Precog) L.csv - data_mrs
#   Moondrop Blessing 2 Dusk (Precog) L.csv - data_mrs
#   Moondrop Blessing 3 L.csv - data_mrs
#   Moondrop Chu (Tanchjim filter) L.csv - data_mrs
#   Moondrop Chu (vent - BluTack) L.csv - data_mrs
#   Moondrop Chu (vent - Tanchjim) L.csv - data_mrs
#   Moondrop Illumination (filter removed) L.csv - data_mrs
#   Moondrop Illumination (Final E) L.csv - data_mrs
#   Moondrop Illumination (Final TWS) L.csv - data_mrs
#   Moondrop Illumination (Moondrop Foam) L.csv - data_mrs
#   Moondrop Illumination (S2) L.csv - data_mrs
# ...
#   HIFIMAN Ananda (2022 Stealth Magnets) L.csv - vsg
#
# HIFIMAN HE-R10D Bluemini L.csv:
#   HIFIMAN HE-R10D Bluemini L.csv - vsg
#   HIFIMAN HE-R10D Bluemini R.csv - vsg
#   HIFIMAN HE-R10D L.csv - vsg
#   HIFIMAN HE-R10D R.csv - vsg
#   HIFIMAN HE-R10P Bluemini L.csv - vsg
#   HIFIMAN HE-R10P Bluemini R.csv - vsg
#   HIFIMAN HE-R10P L.csv - vsg
#   HIFIMAN HE-R9 Bluemini L.csv - vsg
#   HIFIMAN HE-R9 Bluemini R.csv - vsg
#   HIFIMAN HE-R9 L.csv - vsg
#   HIFIMAN HE-R9 R.csv - vsg
#
# HIFIMAN HE-R10P R.csv:
#   HIFIMAN HE-R10P R.csv - vsg
#
# HIFIMAN RE2000 Pro Gold R.csv:
#   HIFIMAN RE2000 Pro Gold R.csv - vsg
#
# HIFIMAN Shangri-La Jr L.csv:
#   HIFIMAN Shangri-La Jr L.csv - vsg
#   HIFIMAN Shangri-La Jr R.csv - vsg
#   HIFIMAN Shangri-La Sr L.csv - vsg
#   HIFIMAN Shangri-La Sr R.csv - vsg
#
# iBasso SR3 L.csv:
#   iBasso SR3 L.csv - vsg
#   iBasso SR3 spare pads L.csv - vsg
#   iBasso SR3 spare pads R.csv - vsg
#   iBasso IT01X (S2) L.csv - data_mrs
#
# Ikko OH1s Sample 2 L.csv:
#   Ikko OH1s Sample 2 L.csv - vsg
#
# JQ 4Upro R.csv:
#   JQ 4Upro R.csv - vsg
#
# Kinera YH802 ANC L.csv:
#   Kinera YH802 ANC L.csv - vsg
#   Kinera YH802 L.csv - vsg
#   Kinera YH802 Transparency L.csv - vsg
#
# Lime Ears Pneuma Switch R.csv:
#   Lime Ears Pneuma Switch R.csv - vsg
#
# Mackie MP-320 R.csv:
#   Mackie MP-320 R.csv - vsg
#   Mackie MP-460 R.csv - vsg
#
# Meze 99 Neo Dekoni L.csv:
#   Meze 99 Neo Dekoni L.csv - vsg
#   Meze 99 Neo Dekoni R.csv - vsg
#   Meze 99 Neo L.csv - vsg
#   Meze 99 Neo R.csv - vsg
#
# Meze Liric L.csv:
#   Meze Liric L.csv - vsg
#   Meze Liric R.csv - vsg
#
# Monoprice M1070C Lambskin L.csv:
#   Monoprice M1070C Lambskin L.csv - vsg
#   Monoprice M1070C Lambskin R.csv - vsg
#   Monoprice M1070C Velour L.csv - vsg
#
# Monoprice M1070C Velour R.csv:
#   Monoprice M1070C Velour R.csv - vsg
#
# Monoprice Monolith M-TWE L.csv:
#   Monoprice Monolith M-TWE L.csv - vsg
#   Monoprice Monolith M-TWE R.csv - vsg
#
# MOONDROP VENUS R.csv:
#   MOONDROP VENUS R.csv - vsg
#
# Moondrop VOID S1 R.csv:
#   Moondrop VOID S1 R.csv - vsg
#   Moondrop VOID S2 R.csv - vsg
#   Moondrop Solis R.csv - data_mrs
#
# Nectar HiveX (No Sponge Insert) L.csv:
#   Nectar HiveX (No Sponge Insert) L.csv - vsg
#   Nectar HiveX (No Sponge Insert) R.csv - vsg
#   Nectar HiveX (Sponge Insert) L.csv - vsg
#   Nectar HiveX (Sponge Insert) R.csv - vsg
#
# Noble Audio Viking Ragnar L.csv:
#   Noble Audio Viking Ragnar L.csv - vsg
#   Noble Audio Viking Ragnar R.csv - vsg
#
# Ovidius RX-100 L.csv:
#   Ovidius RX-100 L.csv - vsg
#   Ovidius TX-901 L.csv - vsg
#
# Ovidius TX-901 R.csv:
#   Ovidius TX-901 R.csv - vsg
#
# Padmate PaMu Z1 L.csv:
#   Padmate PaMu Z1 L.csv - vsg
#   Padmate PaMu Z1 R.csv - vsg
#
# Peacock Flight L.csv:
#   Peacock Flight L.csv - vsg
#   Peacock Flight R.csv - vsg
#
# Philips Fidelio X2HR L.csv:
#   Philips Fidelio X2HR L.csv - vsg
#   Philips Fidelio X2HR R.csv - vsg
#   Philips Fidelio X3 L.csv - vsg
#   Philips Fidelio X3 R.csv - vsg
#
# Sennheiser HD 598 L.csv:
#   Sennheiser HD 598 L.csv - vsg
#   Sennheiser HD 598 R.csv - vsg
#   Sennheiser x Drop HD 6XX L.csv - vsg
#   Sennheiser x Drop HD 6XX R.csv - vsg
#
# Sivga Oriole L.csv:
#   Sivga Oriole L.csv - vsg
#
# Sivga Phoenix L.csv:
#   Sivga Phoenix L.csv - vsg
#
# Sivga Robin (SV021) L.csv:
#   Sivga Robin (SV021) L.csv - vsg
#
# Sivga SV023 L.csv:
#   Sivga SV023 L.csv - vsg
#
# Technics AZ70 L.csv:
#   Technics AZ70 L.csv - vsg
#
# ThieAudio Wraith Pad A L.csv:
#   ThieAudio Wraith Pad A L.csv - vsg
#   ThieAudio Wraith Pad B L.csv - vsg
#
# TinHiFi C5 prototype L.csv:
#   TinHiFi C5 prototype L.csv - vsg
#
# Tripowin TC-01 R.csv:
#   Tripowin TC-01 R.csv - vsg
#
# UA Complimentary 1 L.csv:
#   UA Complimentary 1 L.csv - vsg
#   UA Complimentary 1 R.csv - vsg
#   UA Complimentary 2 L.csv - vsg
#   UA Complimentary 2 R.csv - vsg
#
# Ugreen HiTune T3 L.csv:
#   Ugreen HiTune T3 L.csv - vsg
#   Ugreen HiTune T3 R.csv - vsg
#
# XENNS UP Sample 2 L.csv:
#   XENNS UP Sample 2 L.csv - vsg
#
# Yanyin Canon all switches L.csv:
#   Yanyin Canon all switches L.csv - vsg
#   Yanyin Canon bass switch L.csv - vsg
#   Yanyin Canon mids switch L.csv - vsg
#   Yanyin Canon no switches L.csv - vsg
#
# Yanyin Canon treble switch L.csv:
#   Yanyin Canon treble switch L.csv - vsg
#
# Zephone Tiger L.csv:
#   Zephone Tiger L.csv - vsg
#   Zephone Tiger R.csv - vsg
#
# 710 Btnc (Active, ANC off) L.csv:
#   710 Btnc (Active, ANC off) L.csv - wdym
#   710 Btnc (Active, ANC on) L.csv - wdym
#
# 710 Btnc (Passive) L.csv:
#   710 Btnc (Passive) L.csv - wdym
#
# Deva (Wired) L.csv:
#   Deva (Wired) L.csv - wdym
#
# Elegia (Stock Pads) L.csv:
#   Elegia (Stock Pads) L.csv - wdym
#   Elex (Stock Pads) L.csv - wdym
#
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) L.csv:
#   Elex (Dekoni Elite Fenestrated Sheepskin Pads) L.csv - wdym
#
# Elex (Elear Pads) L.csv:
#   Elex (Elear Pads) L.csv - wdym
#
# Elex (Utopia Pads) L.csv:
#   Elex (Utopia Pads) L.csv - wdym
#
# Sparks (Stock Tuning) L.csv:
#   Sparks (Stock Tuning) L.csv - wdym
#
# test L.csv:
#   test L.csv - akros
#
# 64 Audio Nio (Fir red) L.csv:
#   64 Audio Nio (Fir red) L.csv - data_mrs
#   64 Audio Nio (S1 - mX) L.csv - data_mrs
#
# 64 Audio Nio (S1 - m20) L.csv:
#   64 Audio Nio (S1 - m20) L.csv - data_mrs
#
# Akoustyx S-6 (S2) L.csv:
#   Akoustyx S-6 (S2) L.csv - data_mrs
#   Akoustyx S-6 (S2) R.csv - data_mrs
#   Akoustyx S-6 (Tanchjim) R.csv - data_mrs
#
# BGVP DMG (silver) L.csv:
#   BGVP DMG (silver) L.csv - data_mrs
#   BGVP NS9 (silver) L.csv - data_mrs
#
# BGVP NS9 (black tips + no mesh) L.csv:
#   BGVP NS9 (black tips + no mesh) L.csv - data_mrs
#   BGVP NS9 (black tips) L.csv - data_mrs
#   BGVP NS9 (gray) L.csv - data_mrs
#   BGVP NS9 (red) L.csv - data_mrs
#
# Campfire Audio Dorado 2020 R.csv:
#   Campfire Audio Dorado 2020 R.csv - data_mrs
#
# Cayin Fantasy L.csv:
#   Cayin Fantasy L.csv - data_mrs
#
# Colorfly Quintet L.csv:
#   Colorfly Quintet L.csv - data_mrs
#   Colorfly Quintet R.csv - data_mrs
#
# Custom Art Fibae 7 Unlimited L.csv:
#   Custom Art Fibae 7 Unlimited L.csv - data_mrs
#   Custom Art Fibae 7 Unlimited R.csv - data_mrs
#
# Dunu Falcon Pro (experimental) L.csv:
#   Dunu Falcon Pro (experimental) L.csv - data_mrs
#   Dunu Falcon Pro (experimental) R.csv - data_mrs
#
# Dunu Vulka (S2 + red) L.csv:
#   Dunu Vulka (S2 + red) L.csv - data_mrs
#
# Dunu Zen Pro (pre) L.csv:
#   Dunu Zen Pro (pre) L.csv - data_mrs
#
# Empire Ears Bravado mkII L.csv:
#   Empire Ears Bravado mkII L.csv - data_mrs
#   Empire Ears ESR mkII L.csv - data_mrs
#   Empire Ears Valkyrie mkII L.csv - data_mrs
#
# Etymotic ER2SE (sample 2) L.csv:
#   Etymotic ER2SE (sample 2) L.csv - data_mrs
#   Etymotic ER2SE (sample 2) R.csv - data_mrs
#
# Etymotic ETY Kids L.csv:
#   Etymotic ETY Kids L.csv - data_mrs
#
# Etymotic Evo (2F) L.csv:
#   Etymotic Evo (2F) L.csv - data_mrs
#
# Etyotic ER2XR (S2) L.csv:
#   Etyotic ER2XR (S2) L.csv - data_mrs
#
# Fiio FD7 (40 hrs) L.csv:
#   Fiio FD7 (40 hrs) L.csv - data_mrs
#
# Fiio FD7 (bass + SpinFit) L.csv:
#   Fiio FD7 (bass + SpinFit) L.csv - data_mrs
#
# Fiio FH3 (Spring) L.csv:
#   Fiio FH3 (Spring) L.csv - data_mrs
#
# Fiio FHE (franken) L.csv:
#   Fiio FHE (franken) L.csv - data_mrs
#
# Final B3 (E-type) L.csv:
#   Final B3 (E-type) L.csv - data_mrs
#   Final B3 (TWS) L.csv - data_mrs
#   Sony WF-1000XM4 (Final E-type) L.csv - data_mrs
#   Sony WF-1000XM4 (max - Final E-type) L.csv - data_mrs
#
# Final E2000 (S2) R.csv:
#   Final E2000 (S2) R.csv - data_mrs
#
# FLC 8P (gold-black-gunmetal) L.csv:
#   FLC 8P (gold-black-gunmetal) L.csv - data_mrs
#   FLC 8P (gold-black-red) L.csv - data_mrs
#   FLC 8P (gold-gray-gunmetal) L.csv - data_mrs
#   FLC 8P (gold-white-gunmetal) L.csv - data_mrs
#   FLC 8P (gunmetal-black-gunmetal) L.csv - data_mrs
#   FLC 8P (gunmetal-gray-gunmetal) L.csv - data_mrs
#
# FLC 8P (gold-white-transparent) L.csv:
#   FLC 8P (gold-white-transparent) L.csv - data_mrs
#
# FLC 8P (green-gray-gunmetal) L.csv:
#   FLC 8P (green-gray-gunmetal) L.csv - data_mrs
#   FLC 8P (silver-gray-gunmetal) L.csv - data_mrs
#
# FLC DD31 L.csv:
#   FLC DD31 L.csv - data_mrs
#
# Haylou GT1 L.csv:
#   Haylou GT1 L.csv - data_mrs
#   Haylou GT2 L.csv - data_mrs
#
# Hiby Crystal6 II L.csv:
#   Hiby Crystal6 II L.csv - data_mrs
#   Hiby Crystal6 II R.csv - data_mrs
#   Hiby Crystal6 L.csv - data_mrs
#
# Hifiman Bolt L.csv:
#   Hifiman Bolt L.csv - data_mrs
#
# iBasso IT01X (S2) R.csv:
#   iBasso IT01X (S2) R.csv - data_mrs
#
# JH Audio Layla (max) L.csv:
#   JH Audio Layla (max) L.csv - data_mrs
#   JH Audio Layla (max) R.csv - data_mrs
#   JH Audio Layla (min) L.csv - data_mrs
#   JH Audio Layla (min) R.csv - data_mrs
#
# JVC FX7 L.csv:
#   JVC FX7 L.csv - data_mrs
#
# KZ (avg) L.csv:
#   KZ (avg) L.csv - data_mrs
#
# KZ ZEX (vent blocked) L.csv:
#   KZ ZEX (vent blocked) L.csv - data_mrs
#
# LG HBS800 (ANC off) L.csv:
#   LG HBS800 (ANC off) L.csv - data_mrs
#   LG HBS800 (ANC off) R.csv - data_mrs
#   LG HBS800 (ANC on) L.csv - data_mrs
#   LG HBS800 (ANC on) R.csv - data_mrs
#   LG HBS800 L.csv - data_mrs
#   LG HBS800 R.csv - data_mrs
#
# Magaosi K3 (F0) L.csv:
#   Magaosi K3 (F0) L.csv - data_mrs
#   Magaosi K3 (F1) L.csv - data_mrs
#   Magaosi K3 (F2) L.csv - data_mrs
#   Magaosi K3 L.csv - data_mrs
#   Magaosi K5 L.csv - data_mrs
#
# Magaosi K5 (15 ohm + IEMatch+ ultra) L.csv:
#   Magaosi K5 (15 ohm + IEMatch+ ultra) L.csv - data_mrs
#   Magaosi K5 (15 ohm + IEMatch+) L.csv - data_mrs
#   Magaosi K5 (15 ohm) L.csv - data_mrs
#
# MEE Audio M6 Pro 2G L.csv:
#   MEE Audio M6 Pro 2G L.csv - data_mrs
#
# Meizu Live (black) L.csv:
#   Meizu Live (black) L.csv - data_mrs
#   Meizu Live (blue) L.csv - data_mrs
#
# Meizu Live (white) L.csv:
#   Meizu Live (white) L.csv - data_mrs
#
# Mi True Wireless Earbuds Basic 2 L.csv:
#   Mi True Wireless Earbuds Basic 2 L.csv - data_mrs
#
# Moondrop LAN (Blu Tack) R.csv:
#   Moondrop LAN (Blu Tack) R.csv - data_mrs
#
# Moondrop Solis S2 R.csv:
#   Moondrop Solis S2 R.csv - data_mrs
#   Moondrop SSR (S4) R.csv - data_mrs
#
# Moondrop SSR (deep) R.csv:
#   Moondrop SSR (deep) R.csv - data_mrs
#
# Nothing Ear 2 (balanced) L.csv:
#   Nothing Ear 2 (balanced) L.csv - data_mrs
#   Nothing Ear 2 (voice) L.csv - data_mrs
#   Nothing Ear 2 L.csv - data_mrs
#   Nothing Ear 2 R.csv - data_mrs
#
# Nothing Ear 2 (more bass) L.csv:
#   Nothing Ear 2 (more bass) L.csv - data_mrs
#   Nothing Ear 2 (more bass) R.csv - data_mrs
#   Nothing Ear 2 (more treble) L.csv - data_mrs
#
# Nothing Ear 2 (personalized B) L.csv:
#   Nothing Ear 2 (personalized B) L.csv - data_mrs
#   Nothing Ear 2 (personalized B) R.csv - data_mrs
#   Nothing Ear 2 (personalized) L.csv - data_mrs
#   Nothing Ear 2 (personalized) R.csv - data_mrs
#
# Nothing Ear 2 (treble -6) L.csv:
#   Nothing Ear 2 (treble -6) L.csv - data_mrs
#
# Nothing Ear 2 (voice) R.csv:
#   Nothing Ear 2 (voice) R.csv - data_mrs
#
# OpenAudio Mercury L.csv:
#   OpenAudio Mercury L.csv - data_mrs
#   OpenAudio Mercury R.csv - data_mrs
#
# Oriolus 2nd Gen L.csv:
#   Oriolus 2nd Gen L.csv - data_mrs
#
# Phonak Audeo PFE 112 L.csv:
#   Phonak Audeo PFE 112 L.csv - data_mrs
#   Phonak Audeo PFE 112 R.csv - data_mrs
#
# Pre-Prod 03 (nozzle A) L.csv:
#   Pre-Prod 03 (nozzle A) L.csv - data_mrs
#   Pre-Prod 03 (nozzle A) R.csv - data_mrs
#   Pre-Prod 03 (nozzle B) L.csv - data_mrs
#   Pre-Prod 03 (nozzle B) R.csv - data_mrs
#
# QDC Anole V14 (0000) L.csv:
#   QDC Anole V14 (0000) L.csv - data_mrs
#   QDC Anole V14 (0001) L.csv - data_mrs
#   QDC Anole V14 (0010) L.csv - data_mrs
#   QDC Anole V14 (0100) L.csv - data_mrs
#   QDC Anole V14 (1000) L.csv - data_mrs
#   QDC Anole VX (S2 000) L.csv - data_mrs
#
# QDC Neptune L.csv:
#   QDC Neptune L.csv - data_mrs
#
# QDC Uranus L.csv:
#   QDC Uranus L.csv - data_mrs
#
# Radius HP-NEF11 R.csv:
#   Radius HP-NEF11 R.csv - data_mrs
#
# Sennheiser IE 200 (Azla Max) L.csv:
#   Sennheiser IE 200 (Azla Max) L.csv - data_mrs
#   Sennheiser IE 200 (Azla Max) R.csv - data_mrs
#   Sennheiser IE 200 (D1) L.csv - data_mrs
#   Sennheiser IE 200 (D1) R.csv - data_mrs
#   Sennheiser IE 200 (D2) L.csv - data_mrs
#   Sennheiser IE 200 (D2) R.csv - data_mrs
#   Sennheiser IE 200 (UC tips) L.csv - data_mrs
#   Sennheiser IE 600 L.csv - data_mrs
#   Sennheiser IE 900 L.csv - data_mrs
#   Sennheiser IE 900 R.csv - data_mrs
#
# Sennheiser IE 200 (Spiral Dot) L.csv:
#   Sennheiser IE 200 (Spiral Dot) L.csv - data_mrs
#   Sennheiser IE 200 (Spiral Dot) R.csv - data_mrs
#
# Sennheiser IE 200 (UC tips) R.csv:
#   Sennheiser IE 200 (UC tips) R.csv - data_mrs
#   Sennheiser IE 600 (Spring tips) R.csv - data_mrs
#
# Sennheiser IE 300 (AutoEQ) L.csv:
#   Sennheiser IE 300 (AutoEQ) L.csv - data_mrs
#   Sennheiser IE 300 (Final E) L.csv - data_mrs
#   Sennheiser IE 300 (Sedna Light) L.csv - data_mrs
#   Sennheiser IE 900 (fake) L.csv - data_mrs
#
# Sennheiser IE 40 Pro L.csv:
#   Sennheiser IE 40 Pro L.csv - data_mrs
#
# Sennheiser IE 600 (E-type shallow) L.csv:
#   Sennheiser IE 600 (E-type shallow) L.csv - data_mrs
#   Sennheiser IE 600 (E-type shallow) R.csv - data_mrs
#   Sennheiser IE 600 (E-type) L.csv - data_mrs
#   Sennheiser IE 600 (E-type) R.csv - data_mrs
#   Sennheiser IE 600 (foam) R.csv - data_mrs
#   Sennheiser IE 600 (Sedna) L.csv - data_mrs
#   Sennheiser IE 600 (Spinfit) L.csv - data_mrs
#
# Sennheiser IE 600 (Sedna) R.csv:
#   Sennheiser IE 600 (Sedna) R.csv - data_mrs
#   Sennheiser IE 600 (Spinfit) R.csv - data_mrs
#   Sennheiser IE 900 (Final) R.csv - data_mrs
#
# Sennheiser IE 600 (Spring tips) L.csv:
#   Sennheiser IE 600 (Spring tips) L.csv - data_mrs
#
# Sennheiser IE 900 (fake) R.csv:
#   Sennheiser IE 900 (fake) R.csv - data_mrs
#
# Sennheiser MTW2 (HE) L.csv:
#   Sennheiser MTW2 (HE) L.csv - data_mrs
#
# Shozy Rouge L.csv:
#   Shozy Rouge L.csv - data_mrs
#
# Simgot EN700 Pro L.csv:
#   Simgot EN700 Pro L.csv - data_mrs
#
# Softears Studio4 L.csv:
#   Softears Studio4 L.csv - data_mrs
#
# Sony MDR-AS800 L.csv:
#   Sony MDR-AS800 L.csv - data_mrs
#   Sony MDR-AS800 R.csv - data_mrs
#
# Sony MDR-EX15LP (deep) R.csv:
#   Sony MDR-EX15LP (deep) R.csv - data_mrs
#
# Sony MH1 R.csv:
#   Sony MH1 R.csv - data_mrs
#
# Sony WF-1000XM4 (ambient on) L.csv:
#   Sony WF-1000XM4 (ambient on) L.csv - data_mrs
#   Sony WF-1000XM4 (ANC off) L.csv - data_mrs
#   Sony WF-1000XM4 (ANC on) L.csv - data_mrs
#   Sony WF-1000XM4 (max - ambient on) L.csv - data_mrs
#   Sony WF-1000XM4 (max - ANC on) L.csv - data_mrs
#
# Sony WF-1000XM4 (EQ - bass boost) L.csv:
#   Sony WF-1000XM4 (EQ - bass boost) L.csv - data_mrs
#   Sony WF-1000XM4 (EQ - bright) L.csv - data_mrs
#   Sony WF-1000XM4 (EQ - custom) L.csv - data_mrs
#   Sony WF-1000XM4 (EQ - excited) L.csv - data_mrs
#   Sony WF-1000XM4 (EQ - mellow) L.csv - data_mrs
#   Sony WF-1000XM4 (EQ - relaxed) L.csv - data_mrs
#   Sony WF-1000XM4 (EQ - speech) L.csv - data_mrs
#   Sony WF-1000XM4 (EQ - treble boost) L.csv - data_mrs
#   Sony WF-1000XM4 (EQ - vocal) L.csv - data_mrs
#   Sony WF-1000XM4 (max - EQ - bass boost) L.csv - data_mrs
#   Sony WF-1000XM4 (max - EQ - treble boost) L.csv - data_mrs
#
# Sony WF-1000XM4 (fw 1.1.15) L.csv:
#   Sony WF-1000XM4 (fw 1.1.15) L.csv - data_mrs
#   Sony WF-1000XM4 (max - fw 1.1.15) L.csv - data_mrs
#   Sony WF-1000XM4 (max - fw 1.2.6) L.csv - data_mrs
#
# Sony WF-1000XM4 (max - ANC off) L.csv:
#   Sony WF-1000XM4 (max - ANC off) L.csv - data_mrs
#   Sony WF-1000XM4 (max - EQ - bright) L.csv - data_mrs
#   Sony WF-1000XM4 (max - EQ - excited) L.csv - data_mrs
#   Sony WF-1000XM4 (max - EQ - mellow) L.csv - data_mrs
#   Sony WF-1000XM4 (max - EQ - relaxed) L.csv - data_mrs
#   Sony WF-1000XM4 (max - EQ - speech) L.csv - data_mrs
#   Sony WF-1000XM4 (max - EQ - vocal) L.csv - data_mrs
#   Sony WF-1000XM4 (max - MRS config) L.csv - data_mrs
#   Sony WF-1000XM4 (max - Sedna Light Short) L.csv - data_mrs
#   Sony WF-1000XM4 (max - SpinFit) L.csv - data_mrs
#   Sony WF-1000XM4 (max - XM3 silicone) L.csv - data_mrs
#
# Sony WF-1000XM4 (MRS config) L.csv:
#   Sony WF-1000XM4 (MRS config) L.csv - data_mrs
#
# Sony WF-1000XM4 (Sedna Light Short) L.csv:
#   Sony WF-1000XM4 (Sedna Light Short) L.csv - data_mrs
#
# Sony WF-1000XM4 (SpinFit) L.csv:
#   Sony WF-1000XM4 (SpinFit) L.csv - data_mrs
#
# Sony WF-1000XM4 (XM3 silicone) L.csv:
#   Sony WF-1000XM4 (XM3 silicone) L.csv - data_mrs
#
# Status Audio IEM-2X L.csv:
#   Status Audio IEM-2X L.csv - data_mrs
#
# Tenhz 3BA L.csv:
#   Tenhz 3BA L.csv - data_mrs
#   Tenhz P4 Pro L.csv - data_mrs
#
# TFZ T2 Galaxy L.csv:
#   TFZ T2 Galaxy L.csv - data_mrs
#
# Thinksound Rain3 L.csv:
#   Thinksound Rain3 L.csv - data_mrs
#   Thinksound Rain3 R.csv - data_mrs
#
# Ucotech RE-2 L.csv:
#   Ucotech RE-2 L.csv - data_mrs
#   Ucotech RE-2 R.csv - data_mrs
#
# Vsonic GR07 (Bass) L.csv:
#   Vsonic GR07 (Bass) L.csv - data_mrs
#   Vsonic GR07 L.csv - data_mrs
#   Vsonic GR07 R.csv - data_mrs
#
# Yinfu MD51 L.csv:
#   Yinfu MD51 L.csv - data_mrs

# %%
print(f"Total number of files: {len(all_files)}")
print(f"Total number of groups: {len(grouped_files)}")
print(f"Total number of files in groups: {sum([len(files) for files in grouped_files.values()])}")
print(f"Total number of files not in groups: {len(all_files) - sum([len(files) for files in grouped_files.values()])}")
print(f"\nAvg number of files per group: {sum([len(files) for files in grouped_files.values()]) / len(grouped_files)}")
# Out:
# Total number of files: 9884
# Total number of groups: 1627
# Total number of files in groups: 7670
# Total number of files not in groups: 2214
#
# Avg number of files per group: 4.71419791026429

# %%
# all_files = []
# 
# for reviewer in reviewers:
#     reviewer_path = f'output/csv/{reviewer}'
#     
#     if os.path.exists(reviewer_path):
#         files = os.listdir(reviewer_path)
#         cleaned_files = []
#         for file in files:
#             file_lower = file.lower()
#             if file_lower.endswith(' l.csv'):
#                 cleaned_files.append(file_lower[:-6])
#             elif file_lower.endswith(' r.csv'):
#                 cleaned_files.append(file_lower[:-6])
#             else:
#                 cleaned_files.append(file_lower)
#         all_files.extend(cleaned_files)
# 
# # Remove duplicates and sort the list
# unique_files = sorted(set(all_files))
# 
# # Print unique, lowercased, and sorted file names
# for file in unique_files:
#     print(file)
# Out:
# 07m
# 07m_retune
# 1 custom pm-01
# 10mm bio v1
# 10mm bio v2
# 10mm bio v3
# 10mm bio v4
# 10mm bio v5
# 1more colorbuds 2
# 1more comfobudspro
# 1more comfobudsprooff
# 1more evo
# 1more pistonclassic
# 1more quad driver
# 1more triple driver (foam eartips)
# 1more triple driver (no tip on coupler 8k peak disappeared foam)
# 1more triple driver (orignal silicone eartips)
# 2ht
# 2p
# 32bg
# 4acoustic harmonie
# 4acoustic symphonie 1 on
# 4acoustic symphonie 2 on
# 4acoustic symphonie 3 on
# 4acoustic symphonie all off
# 4acoustic symphonie all on
# 4acoustic unison
# 4p
# 4ss
# 556
# 55hz 03xx
# 55hz 1
# 55hz 350
# 55hz 3d
# 55hz b
# 55hz eki
# 55hz eki fil fo
# 55hz eki tune
# 55hz fo
# 55hz hbb m
# 55hz hbb maka
# 55hz hok
# 55hz mystery
# 55hz no damp
# 55hz os
# 55hz osummer
# 55hz osun sil
# 55hz p1 foam
# 55hz p1 sil
# 55hz p2
# 55hz qk
# 55hz qkz foa
# 55hz qkz sil
# 55hz r
# 55hz secretz 429
# 55hz see
# 55hz sil
# 55hz ss
# 55hz st
# 55hz t
# 55hz x hbb kai
# 5i
# 5i anc
# 5i anc bass
# 5i anc treble
# 5i bass
# 5i transparency
# 5i treble
# 64 audio duo
# 64 audio fourte
# 64 audio fourte blanc
# 64 audio fourte noir
# 64 audio nio (fir black)
# 64 audio nio (fir red)
# 64 audio nio (m12)
# 64 audio nio (m15)
# 64 audio nio (m20)
# 64 audio nio (mx)
# 64 audio nio (s1 - m15)
# 64 audio nio (s1 - m20)
# 64 audio nio (s1 - mx)
# 64 audio tia fourte
# 64 audio tia trio
# 64 audio trio
# 64 audio u12t
# 64 audio u12t (filter 1)
# 64 audio u12t (filter 2)
# 64 audio u12t (filter 3)
# 64 audio u12t (m15)
# 64 audio u12t (m20)
# 64 audio u12t (mx)
# 64 audio u12t (no filter)
# 64 audio u12t fir black
# 64 audio u12t fir red
# 64 audio u12t m12
# 64 audio u12t m15
# 64 audio u12t m20
# 64 audio u12t mx
# 64 audio u12t mx15
# 64 audio u12t mx20
# 64 audio u12t non apex
# 64 audio u12t sample 1 (m15)
# 64 audio u12t sample 2 (m15)
# 64 audio u12t sample 3 (m15)
# 64 audio u12t sample 3 (m20)
# 64 audio u18s
# 64 audio u18s (m20)
# 64 audio u18t (m15)
# 64 audio u18t (m20)
# 64 audio u18t (mx)
# 64 audio u18t m15
# 64 audio u18t m20
# 64 audio u18t mx
# 64 audio u18t none
# 64 audio u4s (fir black)
# 64 audio u4s (fir red)
# 64 audio u4s (m12)
# 64 audio u4s (m15)
# 64 audio u4s (m20)
# 64 audio u4s (mx)
# 64 audio u4s (s1 - m12)
# 64 audio u4s (s1 - m15)
# 64 audio u4s (s1 - m20)
# 64 audio u4s (s1 - mx)
# 64 audio u4s m12
# 64 audio u4s m15
# 64 audio u4s m20
# 64 audio u4s mx
# 64 audio u6t
# 64 audio u6t (m15)
# 64 audio u6t m15 (foam)
# 64 audio u6t m15 (no tip on coupler)
# 64 audio u6t m15 (silicon tips wide)
# 64 audio u6t m15 (silicon tips)
# 64 audio u6t m20 (foam)
# 64 audio u6t m20 (no tip on coupler)
# 64 audio u6t m20 (silicon tips wide)
# 64 audio u6t m20 (silicon tips)
# 64 audio u6t mx (foam)
# 64 audio u6t mx (no tip on coupler)
# 64 audio u6t mx (silicon tips wide)
# 64 audio u6t mx (silicon tips)
# 64 audio u6t xx (foam)
# 64 audio u6t xx (no tip on coupler)
# 64 audio u6t xx (silicon tips wide)
# 64 audio u6t xx (silicon tips)
# 64audio duo
# 64audio trio
# 64audio trio v2
# 64audio u12t
# 7 hertz timeless
# 710 btnc (active, anc off)
# 710 btnc (active, anc on)
# 710 btnc (passive)
# 7a est7
# 7a pro1
# 7a pro1stock
# 7a sg1
# 7hertz timeless
# 7hz dioko
# 7hz dioko (bass mod)
# 7hz dioko (post-op)
# 7hz dioko (pre-op)
# 7hz eternal
# 7hz i77
# 7hz i88
# 7hz i88 2
# 7hz i88 mini
# 7hz legato
# 7hz legato (250 mesh)
# 7hz legato (3 outer vent blutack)
# 7hz legato (500 mesh)
# 7hz legato (inner vent blutack)
# 7hz planar
# 7hz salnotes dioko
# 7hz salnotes dioko tapedvent
# 7hz salnotes zero
# 7hz salnotes zero nogrill
# 7hz salnotes zero s2
# 7hz salnotes zero tape
# 7hz salnotes zero tape 500damper
# 7hz salnotes zero v2
# 7hz sample
# 7hz sample med
# 7hz sample shal
# 7hz sample shal.csv
# 7hz timeless
# 7hz timeless (350 mesh, stock tuning foam sideways, super thin hs foam inner vent)
# 7hz timeless (350 mesh, stock tuning foam, super thin hs foam inner vent)
# 7hz timeless (final tips)
# 7hz timeless (foam tips)
# 7hz timeless (moondroop tips)
# 7hz timeless (no filter)
# 7hz timeless (s2)
# 7hz timeless (sony import foam)
# 7hz timeless (sony import foam, super thin hs foam inner vent)
# 7hz timeless (tanchjim filter, stock tuning foam sideways, super thin hs foam inner vent)
# 7hz timeless ae
# 7hz timeless og
# 7hz timeless s2
# 7hz timeless s2 25ohm
# 7hz timeless s2 75ohm
# 7hz timeless s2 mpback
# 7hz timeless s2 mpfront
# 7hz timeless tape mod
# 7hz x crinacle dioko
# 7hz x crinacle dioko updated
# 7hz x crinacle salnotes dioko
# 7hz zero
# 7hz zero (ej07 foam eartips)
# 7hz zero (final eartips)
# 7hz zero (moondrop eartips)
# 7hz zero (red orignal eartips)
# 7hz zero mecha
# 7hz zero s1
# 7hz zero tape
# 7th acoustics proxima
# 7th acoustics stargazer 3
# 7th acoustics stargazer 3 prototype
# 7th acoustics supernova
# 7th acoustics supernova (s2)
# 7th proxima
# 7th supernova
# a2
# a2.csv
# a4k
# aaw halycon
# aaw mockingbird
# acho reviews target.csv
# acoustine rs one (foam)
# acoustune hs1650cu
# acoustune hs1670ss
# acoustune hs2000mx mkii
# acoustune rs one
# acoustune rs1
# advanced s20009
# afb5
# aful acoustics performer 5
# aful acoustics performer5
# aful acoustics performer5 (15 ohm)
# aful acoustics performer5 (36 ohm)
# aful acoustics performer5 (75 ohm)
# aful band 5
# aful band 8
# aful new
# aful perf 5
# aful performer 5
# aful performer5
# aful soloist
# agent 007
# agent 008
# aiderlot m5 (bass)
# aiderlot m5 (filterless)
# aiderlot m5 (reference)
# aiderlot m5 (treble + 350 mesh)
# aiderlot m5 (treble + 500 mesh)
# aiderlot m5 (treble + 80ohm)
# aiderlot m5 (treble + sony import foam)
# aiderlot m5 (treble)
# aiderlot m5 bass
# aiderlot m5 pro
# aiderlot m5 pro modded
# aiderlot m5 reference
# aiderlot m5 treble
# aiderlot m5 treble 30ohm
# air canada earphones
# ak pathfinder
# ak zero1
# akg 371
# akg eo
# akg k371
# akg n200
# akg n400
# akg n5005 (bass)
# akg n5005 (high)
# akg n5005 (mid high)
# akg n5005 (reference)
# akg n5005 ref (no tip on coupler 8k)
# akoustyx r-120
# akoustyx r-220
# akoustyx s-6
# akoustyx s-6 (s2)
# akoustyx s-6 (tanchjim)
# akros erasmus
# akros erasmus 11
# allway oe10
# alpex hr-4000
# alpex hse-a20009
# alpha 1.0 target.csv
# altec im716bass
# altec im716hd
# ambient dynamics ad-006
# amelie target.csv
# ana airline freebud
# anew u1
# anima
# animagus neutral target.csv
# animagus preference target.csv
# anker life dot 3i
# anker life note 3i
# anole vx 000
# anole vx 003
# anole vx 020
# anole vx 100
# antdroid target.csv
# antlion kimura duo
# antlion kimura solo
# apexti
# apollo bold classical anc off
# apollo bold classical anc on
# apollo bold default anc off
# apollo bold default anc on
# apollo bold jazz anc off
# apollo bold jazz anc on
# apollo bold pop anc off
# apollo bold pop anc on
# apollo bold rock anc off
# apollo bold rock anc on
# apple airpods pro
# apple airpods pro 2
# apple airpods pro 2 (anc mode)
# apple airpods pro 2 (transparency mode)
# apple ma850ga
# apple powerbeats pro
# arere
# aria
# aria snow
# aroma jewel
# aroma jewel 100h
# aroma jewel2
# aroma thunder focus mode
# aroma thunder focus mode.csv
# aroma thunder harmony mode
# aroma thunder harmony mode.csv
# artio cr-s1
# asf 3ba 2way
# asf flat
# asg 25
# ashida ea-hf1
# astell & kern solaris x
# astell kern odyssey
# astell n kern ak zero1
# astell n kern uw100
# astrotec vesna
# asura
# asx 10ba 2way
# at ath-sport5tw
# at1
# ath clr100
# atq at-es11
# audeze crbn
# audeze euclid
# audeze isine lx (spinfit)
# audeze lcd-2 classic
# audeze lcd-5
# audeze lcd-5 old headband
# audeze lcd-x (2021)
# audeze lcd-xc (2021)
# audio ehiku
# audio hekili
# audio lokahi 7ba
# audio lokahi 7bav2
# audio lokahi 8+1
# audio-technica ath-anc300tw
# audio-technica ath-anc900bt
# audio-technica ath-anc900bt anc
# audio-technica ath-anc900bt ht
# audiosense aq0
# audiosense aq4
# audiosense aq4 30
# audiosense aq7
# audiosense dt100
# audiosense dt100 (80ohm)
# audiosense dt100s
# audiosense dt200
# audiosense dt300
# audiosense dt300 (80ohm)
# audiosense dt300+36
# audiosense dt300+75
# audiosense dt600
# audiosense dt600 (20ohm)
# audiosense dt600 (25ohm)
# audiosense dt600 (30ohm)
# audiosense dt600 (30ohm+tanya filter)
# audiosense dt600 (stock)
# audiosense dt600 20
# audiosense dt600 20.csv
# audiosense dt600 30
# audiosense dt600 80
# audiosense dt600 ohm
# audiosense t100
# audiosense t180
# audiosense t180 pro
# audiosense t800
# audiosense t800 (1dividedby16 foam)
# audiosense t8009
# augl f300light
# auglamour f300
# auglamour rt-3
# auglamour t100
# aukey ep-b44
# aune jasper
# aune jasper (tanchjim filter)
# aur audio allure
# aur audio duet plus
# aur audio neon
# aur audio neon pro
# aur audio neon pro bass on
# aurisonics asg 2
# autoeq target.csv
# avara av3
# average reviewer.csv
# avid
# ax target.csv
# axs audio pro earbuds
# azla azel
# ba5
# bad guy 2022 target.csv
# bad guy target v2.csv
# bad guy target.csv
# bamboo forest bird jinghong
# bamboo forest bird jinghong (sony import foam)
# bamboo forest bird zhu skylark
# banbeucmas target.csv
# bang & olufsen beoplay h95
# bang & olufsen beoplay h95 anc
# basn bmaster 2nd
# basn mmcx
# basn mtpro
# beats fit pro
# beats powerbeats pro
# beemix pisces
# beyerdynamic dt990
# beyerdynamic xelento 2. gen
# bgvp dh3 (00)
# bgvp dh3 (02)
# bgvp dh3 (10)
# bgvp dh3 (12)
# bgvp dh3 01
# bgvp dh5
# bgvp dm6
# bgvp dm7
# bgvp dm8
# bgvp dmg (silver)
# bgvp dmgbk9
# bgvp dn2
# bgvp dn3
# bgvp dn3 bass tip
# bgvp dn3 vocal tip
# bgvp es12 (000)
# bgvp es12 (100)
# bgvp es12 (110)
# bgvp es12 (111)
# bgvp melody (balanced)
# bgvp melody (hifi)
# bgvp melody (pop)
# bgvp melody balanced
# bgvp melody hifi
# bgvp melody pop
# bgvp ne5 (champagne filter)
# bgvp ne5 (grey filter)
# bgvp ne5 (red filter)
# bgvp ns10
# bgvp ns10 gold
# bgvp ns10 red
# bgvp ns10 silver
# bgvp ns9
# bgvp ns9 (black tips + no mesh)
# bgvp ns9 (black tips)
# bgvp ns9 (gray)
# bgvp ns9 (red)
# bgvp ns9 (silver)
# bgvp ns9 def filter
# bgvp ns9 red filter
# bgvp ns9 silver filter
# bgvp scale
# bgvp scale 2dd
# bgvp scale pro
# bgvp sgz-dn1s
# bgvp vg4 off-off-off
# bgvp vg4 off-off-on
# bgvp vg4 off-on-off
# bgvp vg4 off-on-on
# bgvp vg4 on-off-off
# bgvp vg4 on-on-off
# bgvp vg4 on-on-on
# binaryacoustic void
# blessing 2 dusk
# blessing2_dusk
# blon 01
# blon 03
# blon 03 foam mod
# blon 03x
# blon 03xx
# blon 05
# blon 07 b
# blon 07a
# blon a72
# blon a8
# blon a8 prometheus
# blon aa
# blon b20
# blon b60
# blon b60 tape
# blon b72
# blon bb
# blon bl max
# blon bl-01
# blon bl-03
# blon bl-03 (450 mesh + micropore tape 2pin vent block)
# blon bl-03 (500 mesh + micropore tape 2pin vent block)
# blon bl-03 (5mm y4 wtf + micropore tape 2pin vent block)
# blon bl-03 (cotton filter + high-density tuning foam + micropore tape 2pin vent block)
# blon bl-03 (cotton filter + micropore tape 2pin vent block)
# blon bl-03 (high-density tuning foam)
# blon bl-03 (high-density tuning foam, tanchjim filter)
# blon bl-03 (mesh mod)
# blon bl-03 (micropore tape 2pin vent block)
# blon bl-03 (tanchjim filter + blutack 2pin vent block)
# blon bl-03 (tanchjim filter + micropore tape 2pin vent block)
# blon bl-03 (tanchjim filter)
# blon bl-03 (white fine mesh + micropore tape 2pin vent block)
# blon bl-05
# blon bl-05s
# blon bl-a8
# blon bl-a8v2
# blon bl-max
# blon bl-mini
# blon bl01
# blon bl01v2
# blon bl03
# blon bl03 filter
# blon bl03 stock
# blon bl03v2 stock
# blon bl05
# blon bl05s
# blon bl05sv2
# blon bl05v2
# blon bl07
# blon bl50
# blon fat girl
# blon fatgirl9
# blon headphones
# blon max
# blon mini
# blon miniv2
# blon t1
# blon t3
# blon x hbb z300
# blon xa
# blon xb
# blon z200
# blon_03_busmod
# blur mx64
# bonako royole
# bonus ie pro
# bose ie2
# bose qc earbuds
# bose qc30
# bqeyz autum bass
# bqeyz autumn
# bqeyz autumn (500 mesh inner vent, sony import foam)
# bqeyz autumn (500 mesh inner vent, sony import foam, blutack outer vent)
# bqeyz autumn (bass vent, filterless)
# bqeyz autumn (bass vent, high-density tuning foam)
# bqeyz autumn (bass vent, high-density tuning foam, cotton filter)
# bqeyz autumn (bass vent, sony import foam)
# bqeyz autumn (bass)
# bqeyz autumn (none)
# bqeyz autumn (normal vent, sony import foam)
# bqeyz autumn (normal vent, sony import foam, blutack outer vent)
# bqeyz autumn (normal)
# bqeyz autumn (treble vent, sony import foam)
# bqeyz autumn (treble)
# bqeyz autumn (y3 wtf inner vent, 2 high-density tuning foam, 500 mesh)
# bqeyz autumn (y3 wtf inner vent, sony import foam)
# bqeyz autumn (y6 wtf inner vent, sony import foam)
# bqeyz autumn bass
# bqeyz autumn bass tanya
# bqeyz autumn norm tanya
# bqeyz autumn normal
# bqeyz autumn shortbus
# bqeyz autumn treb tanya
# bqeyz autumn treb xbassii
# bqeyz autumn treble
# bqeyz k1
# bqeyz k2
# bqeyz kb1
# bqeyz kb100
# bqeyz kb19
# bqeyz kc2
# bqeyz spring 1
# bqeyz spring 2
# bqeyz spring 2 (modded)
# bqeyz summer
# bqeyz topaz
# bqeyz winter
# bqeyz winter morebass
# bqeyz winter y1
# brainwavz koel
# bravery
# broken variations.csv
# bry audio reviews target.csv
# bt
# burson_pm2_loopback
# busax js81
# cal se
# calcini sweatpro 3
# cambridge audio melomania 1+
# cammyfi neutral target.csv
# cammyfi target.csv
# campfire andromeda 2020
# campfire andromeda pre-2020
# campfire audio andromeda 2019
# campfire audio andromeda 2020
# campfire audio andromeda s
# campfire audio ara
# campfire audio dorado 2020
# campfire audio holocene
# campfire audio honeydew
# campfire audio mammoth
# campfire audio onyx
# campfire audio orbit
# campfire audio orbit s2
# campfire audio pathfinder
# campfire audio saber
# campfire audio saber foam
# campfire audio satsuma
# campfire audio solaris stellar horizon
# campfire audio supermoon
# campfire audio trifecta
# campfire saber
# campfire solaris 2020
# campfire supermoon universal
# canon
# canpur joyfull 1
# carot one
# carot one (s2)
# cat ear meow
# cat ears mia
# catear hitam
# catear hitam final tuning
# catear hitam preproduction
# cayin fantasy
# cayin yb04
# cayin yb04 dualflange
# cayin yb04 triflange
# cayin yb04 trilange
# cca a10
# cca a10 30ohm
# cca c10
# cca c10 pro
# cca c10pro
# cca c12
# cca c16
# cca c16 30ohm
# cca c16 47r oi
# cca ca10
# cca ca10 30ohm
# cca ca16
# cca ca16 pro
# cca ca16v2
# cca ca2
# cca ca24
# cca ca24 30ohm
# cca ca2v2
# cca ckx
# cca cra
# cca cra (1dividedby4 foam)
# cca cra (1dividedby8 foam)
# cca cra (200 mesh)
# cca cra (350 mesh)
# cca cra (500 mesh + 200 paper filter)
# cca cra (500 mesh + 250 paper filter)
# cca cra (500 mesh + 300 paper filter + high-density tuning foam)
# cca cra (500 mesh + 300 paper filter)
# cca cra (500 mesh + 350 paper filter)
# cca cra (500 mesh + 500 paper filter)
# cca cra (500 mesh + high-density tuning foam)
# cca cra (500 mesh + sony general foam)
# cca cra (500 mesh + y1 paper filter)
# cca cra (500 mesh + y3 paper filter)
# cca cra (500 mesh + y6 paper filter)
# cca cra (500 mesh)
# cca cra (filterless + 2 high-density tuning foams)
# cca cra (filterless + high-density tuning foams)
# cca cra (filterless)
# cca cra (nylon filter)
# cca cra (sony general foam)
# cca cra (sony import foam)
# cca cra (tanchjim filter)
# cca cra +
# cca cra eq
# cca cra eq3
# cca cra mod
# cca cra plus
# cca cra plus tape
# cca cra plus vent
# cca cra s2
# cca cra+
# cca cra+ (stock filter + 350 mesh)
# cca cra+ (stock tips)
# cca cs16
# cca cs16 30ohm
# cca csa
# cca csn
# cca csnv2
# cca cst
# cca cx10
# cca cx4
# cca cxs
# cca fla
# cca hm20
# cca hm20 foam
# cca lyra
# cca lyra y1
# cca lyra y2
# cca nra
# cca nra (0.15ohm)
# cca nra (0.66ohm)
# cca nra stock
# cca nra taped
# cca pla
# cca pla s
# cca pla silicon
# cca pla13
# ccz coffee bean
# ccz coffee beanv2
# ccz coffeebean
# ccz emerald
# ccz melody
# ccz plume
# ccz warrior
# celest pandamon
# cfa andromeda 2020
# chikyu-sekai 2cosmos
# chu
# chu 9khz
# chu detach
# chu foamfilter
# chu fullinsertion
# chu t300t
# ciem anni l2.csv
# ciem anni l3.csv
# ciembellosx5
# clairvoyance
# cleer flow ii ambient
# cleer flow ii anc
# cleer roam nc
# co-donguri brass
# co-donguri brass (1dividedby16 foam)
# co-donguri brass (1dividedby2 foam_nozzle)
# co-donguri brass (1dividedby4 foam_nozzle)
# co-donguri shizuku
# coda target.csv
# colorfly quintet
# comfy target.csv
# cozoy hera c103
# cra
# cra spring
# crackhead target.csv
# creative aurvana trio ls
# creative ep-6309
# crin neutral.csv
# crinacle 2023 adjusted target.csv
# crinacle adjusted target.csv
# crinacle ief-neutral target.csv
# crinacle neutral 2023 target.csv
# crinacle neutral target.csv
# crinacle target.csv
# custom art fibae 3x3
# custom art fibae 5
# custom art fibae 5 (filter)
# custom art fibae 5 filter
# custom art fibae 7
# custom art fibae 7 unlimited
# custom art fibae 7u
# custom art fibae 7u ciem
# custom art fibae 7u universal
# custom art fibae go 1
# cvj angel wings
# cvj csa
# cvj csk
# cvj csn
# cvj mirror
# cvj river
# cvj shine
# cwu22
# cwu77
# cyberdrive impdurbass9
# daiso al-001
# daiso al-002
# daiso al-003
# daiso al-004
# daiso al-005
# daiso ev-001
# db monroe
# dbe pr500
# ddhifi janus
# ddhifi janus 2
# deer
# dent target.csv
# dentreviews target.csv
# dethonray tender 1
# deva (wired)
# devialet gemini flat
# df tilt 711 ref target.csv
# df tilt 711 ref.csv
# diffuse field target.csv
# dioko
# dioko spring
# direm e3
# dita perpetua
# diy 5ba
# diy 6ba
# diy 846 4ba
# diy 846 4ba1dd
# diy 846 k5ba
# diy 8ba
# diy e3000
# diy e4000
# diy sk846
# diy846 wooeasy ee846
# dkm
# dm
# dm2
# dm2_dm1
# dm2_eqmdm1
# dm2_olina
# dn3
# dqsm hermit
# dressage 6+1
# drop + dan clark audio aeon closed x
# drop + dan clark audio aeon closed x 1-notch white filter
# drop x etymotic erx
# dt200
# dt200 spring
# dt200 spring 23r oi
# du b
# dummy mangird top
# duna sa6 ultra bass
# dunu 380
# dunu dm-480
# dunu dn-1000
# dunu est 112
# dunu est 112 (spinfit)
# dunu est 112 og
# dunu est112
# dunu est112 (1dividedby16 foam)
# dunu est112 (30ohm)
# dunu est112 (micropore tape mod)
# dunu falcon pro
# dunu falcon pro (atmospheric immersion filter)
# dunu falcon pro (atmospheric immersion)
# dunu falcon pro (atmospheric)
# dunu falcon pro (experimental)
# dunu falcon pro (reference filter)
# dunu falcon pro (reference filter, 2 outer vent blutack)
# dunu falcon pro (reference filter, 2 outer vent blutack, high-density tuning foam)
# dunu falcon pro (reference filter, 2 outer vent pk foam)
# dunu falcon pro (reference filter, 2 outer vent pk foam, high-density tuning foam)
# dunu falcon pro (reference)
# dunu falcon pro (transparency)
# dunu falcon pro (transparent filter)
# dunu falcon pro (transparent filter, 2 outer vent 500 wtf, 1 inner vent 500 wtf, low-density tuning foam)
# dunu falcon pro (transparent filter, 2 outer vent blutack, 1 inner vent blutack, low-density tuning foam)
# dunu falcon pro (transparent filter, 2 outer vent blutack, high-density tuning foam)
# dunu falcon pro (transparent filter, 2 outer vent blutack, low-density tuning foam)
# dunu falcon pro (transparent filter, 2 outer vent pk foam, high-density tuning foam)
# dunu falcon pro (transparent filter, 2 outer vent pk foam, low-density tuning foam)
# dunu falcon pro atm
# dunu falcon pro atmospheric
# dunu falcon pro ref
# dunu falcon pro reference
# dunu falcon pro riku
# dunu falcon pro tran
# dunu falcon pro transparency
# dunu kima
# dunu sa03
# dunu sa3
# dunu sa6
# dunu sa6 (atmospheric)
# dunu sa6 bass mk2
# dunu sa6 mk2
# dunu sa6 mk2 (off)
# dunu sa6 mk2 (on)
# dunu sa6 mk2 off
# dunu sa6 mk2 on
# dunu sa6 mkii
# dunu sa6 mkii bass
# dunu sa6 on
# dunu sa6 ultra
# dunu sa6 ultra (off)
# dunu sa6 ultra (on)
# dunu sa6 ultra off
# dunu sa6 ultra on
# dunu talos
# dunu talos (hybrid)
# dunu talos (on)
# dunu talos (planar + ba)
# dunu talos (planar + ba) (ie600 foam tips)
# dunu talos (planar only)
# dunu talos (planar only) (ie600 foam tips)
# dunu talos (planar)
# dunu talos (s2 off)
# dunu talos (s2 on)
# dunu talos (switch off)
# dunu talos (switch on)
# dunu talos ba
# dunu talos hybrid
# dunu talos hybrid mode
# dunu talos off
# dunu talos on
# dunu talos planar
# dunu talos planar mode
# dunu talos planar+ba
# dunu titan
# dunu titan 5
# dunu titan s
# dunu titan s (500 mesh)
# dunu titan s (isolation)
# dunu titan s (pre)
# dunu titan s (tanchjim filter)
# dunu titan s (y3 paper filter)
# dunu titan s (y6 paper filter)
# dunu titan s pre-production
# dunu titan tanya
# dunu titans
# dunu vernus atmos
# dunu vernus reference
# dunu vernus transpa
# dunu vulka (s2 + red)
# dunu vulkan
# dunu vulkan (s2 + red)
# dunu vulkan (s2)
# dunu zen
# dunu zen (high-density tuning foams inside tips)
# dunu zen (micropore tape mod)
# dunu zen foam
# dunu zen pro
# dunu zen pro (pre)
# dunu zen pro tanya
# dusk
# dusk bgvp
# dusk bgvpshallow
# dusk mistip
# dusk ortofon
# dusk w1
# dusk w1shallow
# dynamicears target.csv
# dzat df-10
# e1000
# earbuds - bgvp dx6
# earbuds - hzsound bell rhyme
# earbuds - lbbs
# earfun free pro oluv edition
# earfun free pro oluv edition (anc)
# earsonics onyx
# ecci yst-02
# echobox finderx1
# echobox nomadn1bk
# echobox travelert1
# edc3
# edifier ambient
# edifier high noise
# edifier neobuds pro
# edifier neobuds s
# edifier neobuds s classic
# edifier neobuds s dynamic
# edifier normal
# edifier stax spirit s3 lambskin bt
# edifier stax spirit s3 lambskin wired
# edifier stax spirit s3 mesh bt
# edifier stax spirit s3 mesh wired
# edifier w240tn
# edifier wh950nb bluetooth
# edifier wh950nb wired
# edl mini piano
# ee odin
# ee odin 2
# effect audio axiom
# effect audio gaea
# effect audio gaea (deep)
# ej target.csv
# ej07_custom
# ej07_custom1
# ej07m
# ej_sb
# elecom ehp-ch1000
# elecom ehp-ch30009
# elecom ehp-cs200a
# elecom ehp-gb10a
# elecom ehp-gb2000
# electra earbuds
# elegia (stock pads)
# elex (dekoni elite fenestrated sheepskin pads)
# elex (elear pads)
# elex (stock pads)
# elex (utopia pads)
# ely x
# ely-x-effect-gaea-r.csv
# elysian accoustic annihilator 2021
# elysian ann
# elysian ann.csv
# elysian annihilator
# elysian annihilator x
# elysian diva
# elysian diva (blue switch)
# elysian diva (red switch)
# elysian diva (white switch)
# elysian diva bass
# elysian diva bass heavy
# elysian diva bass light
# elysian diva mid
# elysian diva treb
# elysian gaea
# elysian x
# elysian x elise
# empire ears bravado mkii
# empire ears esr mkii
# empire ears evo
# empire ears legend evo
# empire ears legend x
# empire ears lx
# empire ears lx se
# empire ears odin
# empire ears odin sample 1
# empire ears odin sample 2
# empire ears odin sample 3
# empire ears valkyrie mkii
# enco x2 - classic
# enco x2 - punchy
# enco x2 - real
# enco x2 - simple and clear
# enco x2 eq classic
# enco x2 eq punchy
# enco x2 eq real
# enco x2 eq simple & clear
# eo-ic100
# eo-ig955 fake
# eono eonobuds2
# ep05
# epz q1
# er2se
# er3xr
# er3xr (68ohm)
# er4sr
# er4xr
# erasmus 00
# erasmus 01
# erasmus 10
# erasmus 11
# ety er-4s
# etymotic er2se
# etymotic er2se (autoeq - oratory)
# etymotic er2se (autoeq)
# etymotic er2se (sample 2)
# etymotic er2xr
# etymotic er2xr (brown + 2f)
# etymotic er2xr (brown)
# etymotic er2xr (s2)
# etymotic er2xr (white)
# etymotic er2xr brown
# etymotic er2xr comply
# etymotic er2xr comply p
# etymotic er2xr double
# etymotic er2xr foams
# etymotic er2xr orange
# etymotic er2xr red
# etymotic er2xr tip
# etymotic er2xr triple
# etymotic er2xr white
# etymotic er4s
# etymotic er4sr
# etymotic er4xr
# etymotic er4xr (2f)
# etymotic er4xr (foam)
# etymotic er4xr foam
# etymotic erx
# etymotic erx (brown)
# etymotic ety kids
# etymotic evo
# etymotic evo (2f)
# etymotic mk5
# etymotic target.csv
# etyotic er2xr (s2)
# eva2020 x final
# evasb target.csv
# ex1000
# excalibur
# ezaudio d4 (modded)
# ezaudio x3
# ezear q70y
# ezear x12
# faaeal hibiscus
# faaeal poppy
# fat freq
# fat freq 400 filt
# fat freq gm
# fat freq mae see
# fat freq meastro se
# fatfreq harmony
# fatfreq maestro mini
# fatfreq maestro se
# fd5
# fearless audio acme 10
# fearless audio dawn
# fearless audio s6 v2
# fearless audio s8f
# fearless barcelona
# fearless dawn
# fearless provence
# fearless roland
# fearless s8p
# fearless shangrila
# fender nine
# fender puresonicwireless
# fengru pt1
# fengru qzx-a1
# ff gm 1
# ff gm 2
# ff gm 3
# ff gm 4
# fh5s bass
# fh5s mids
# fh5s standard
# fh5s treble
# fidue sirius
# fifine h6 gaming eq
# fifine h6 movie eq
# fifine h6 music eq
# fiil t1 lite (bass)
# fiil t1 lite (treble)
# fiil t1 lite tws
# fiil t1 pro
# fiio em5
# fiio f1
# fiio fa1
# fiio fa1j
# fiio fa7s
# fiio fa9 pro
# fiio fd3
# fiio fd3
# fiio fd3 (bass tips)
# fiio fd3 (blk nozzle)
# fiio fd3 (foam tips)
# fiio fd3 (vocal tips)
# fiio fd3 stock
# fiio fd3 treble
# fiio fd5
# fiio fd5 (1dividedby16 foam)
# fiio fd5 (balanced filter)
# fiio fd5 (bass filter)
# fiio fd5 (micropore tape mod)
# fiio fd5 (narrow + brainwavz)
# fiio fd5 (narrow + shure)
# fiio fd5 (narrow)
# fiio fd5 large nozzle
# fiio fd5 small nozzle
# fiio fd7
# fiio fd7 (40 hrs)
# fiio fd7 (balanced)
# fiio fd7 (bass + spinfit)
# fiio fd7 (bass)
# fiio fd7 (treble)
# fiio fd7 balanced
# fiio fd7 modded
# fiio fd7 stock
# fiio fd7 tiny noz
# fiio fd7 treb
# fiio fh1
# fiio fh15 (balanced)
# fiio fh15 (bass)
# fiio fh15 (treble)
# fiio fh3
# fiio fh3 (spring)
# fiio fh5
# fiio fh5s
# fiio fh5s (0 hrs burn-in)
# fiio fh5s (000)
# fiio fh5s (001)
# fiio fh5s (010)
# fiio fh5s (011)
# fiio fh5s (100)
# fiio fh5s (101)
# fiio fh5s (110)
# fiio fh5s (111)
# fiio fh5s (200 hrs + fd5 cable)
# fiio fh5s (200 hrs burn-in)
# fiio fh5s (stock)
# fiio fh5s (t0 m0 b0)
# fiio fh5s (t0 m0 b1)
# fiio fh5s (t0 m1 b0)
# fiio fh5s (t1 m0 b0)
# fiio fh5s (t1 m1 b1)
# fiio fh5s (tanchjim filter)
# fiio fh5s bass
# fiio fh5s mids
# fiio fh5s treble
# fiio fh7 (black)
# fiio fh7 (blue)
# fiio fh7 (red)
# fiio fh7s
# fiio fh7s (bass)
# fiio fh7s (treble)
# fiio fh7s balanced
# fiio fh7s bass
# fiio fh7s treble
# fiio fh9
# fiio fhe
# fiio fhe (franken)
# fiio fhe (s2)
# fiio fhe eclipse
# fiio fhe s1
# fiio fhe s2
# fiio ft3 pleather
# fiio ft3 suede
# fiio fw5
# fiio jd3
# fiio jd3 black
# fiio jd7
# fiio jh3
# fiio x crinacle fhe
# fiio x crinacle fhe (eclipse)
# fiio x crinacle fhe eclipse (foam eartips)
# fiio x crinacle fhe eclipse (no tip on coupler)
# fiio x jadeaudio jd3
# final a4000
# final audio a4000
# final audio a4000 v2
# final audio b3
# final audio e1000
# final audio e1000 (micropore mod)
# final audio e1000 (s2)
# final audio e2000
# final audio e3000
# final audio e3000 (s2)
# final audio e4000
# final audio e500
# final audio e5000
# final audio f3100
# final audio fi-eva2020
# final audio vr3000
# final b3 (e-type)
# final b3 (tws)
# final e1000
# final e1000 (sedna)
# final e2000
# final e2000 (s2)
# final e4000
# final e500
# final e500 autoeq
# final eva2020
# final ux3000 bluetooth
# final ux3000 bluetooth anc
# final ux3000 wired
# final vr3000
# final ze3000
# final ze3000 s1
# final ze3000 s2
# final ze3000 s3
# final ze8000 1.8.0
# final ze8000 1.8.1
# fir audio ciem xenon 6
# fir audio kr5 black atom
# fir audio kr5 silver atom
# fir audio m4
# fir audio m5
# fir audio ne4 black atom
# fir audio rn6
# fir audio vxv
# fir audio xe6 black atom
# fir audio xe6 gold atom
# fir audio xe6 silver atom
# fir audio xe6 uiem
# fir audio xenon 6
# fir audio xenon xe6
# fir kr5
# fir kr5 black
# fir kr5 gold
# fir kr5 s2
# fir ne4
# fir vxv
# fitear mh335 dw
# flare audio flares pro
# flat target.csv
# flc 8p (gold-black-gunmetal)
# flc 8p (gold-black-red)
# flc 8p (gold-gray-gunmetal)
# flc 8p (gold-white-gunmetal)
# flc 8p (gold-white-transparent)
# flc 8p (green-gray-gunmetal)
# flc 8p (gunmetal-black-gunmetal)
# flc 8p (gunmetal-gray-gunmetal)
# flc 8p (silver-gray-gunmetal)
# flc dd31
# floaudio calla
# floaudio lily
# floaudio lily
# foam and 450
# focal bathys
# focal utopia 2022
# focus audio vocal
# focus edm
# fonge x2 pro
# fostex te02n
# free field target.csv
# freeryder05v2 target.csv
# fw10k
# fz audio liberty max
# fz audio liberty z2
# g
# g-most e89
# g1
# g2
# gaea
# galileo retail
# gbuds pro
# geek wold gk10
# geek wold gk10 (0.16ohm cable)
# geek wold gk10 (0.86ohm cable)
# geek wold gk10 (50h)
# geek wold gk10 no tape
# geek wold gk10 tape
# geek wold gk100
# geek wold gk3
# geek wold gk80 mic
# geek wold gk80 nomic
# geek world gk10
# geekfly gf10
# geekfly gf8s
# geekwold gk10
# gevo gv3
# ghost target.csv
# gk gs10
# gk gs5
# gk gst
# gk10
# gk100
# glidic tw-3000
# glidic tw-5100
# goldpl cus
# goldpl filt 1
# goldpla filt 2
# goldplan filt 3
# goldplan filt 4
# goldplanar amt stock
# goldplanar gl12
# goldplanar gl12 filter
# goldplanar gl20
# gr-i18
# graph x
# gravastar sirius
# gs audio gd11
# gs audio gd11 (40h)
# gs audio gd11 (85h)
# gs audio gd3a
# gs audio gd3c
# gs audio gd5
# gs audio gt12
# gs audio gt12 (1ohm)
# gs audio gt12x
# gs audio gt12x (30ohm)
# gs audio gt12x 20ohm
# gs audio sd9
# gs audio se11
# gs audio se12
# gs audio se12b
# gs audio st1
# gs audio st1 (30ohm + 500 mesh)
# gs audio st1 (30ohm)
# guideray gr-i18
# ha-fr15-h
# hakii action
# halycon bass
# halycon vocal
# harman 2017 target.csv
# harman 2017v2 target.csv
# harman 2018 over-ear target.csv
# harman 2019 in-ear target.csv
# harman 2019 target.csv
# harman 2019v2 target.csv
# harman adjusted target.csv
# harman combined over-ear target.csv
# harman ie 2016 target.csv
# harman ie 2017 v2 target.csv
# harman ie 2019 target.csv
# harman ie 2019 v2 target.csv
# harman iem target.csv
# harman in ear 2019 target.csv
# harman in room target.csv
# harman in-ear target.csv
# harman oe target.csv
# harman over ear 2018 target.csv
# harman target.csv
# harman v2 target.csv
# harman2019v2 target.csv
# harmonicdyne athena
# harmonicdyne athena raw
# harmonicdyne devil
# harmonicdyne devil micropore
# harmonicdyne devil preprod
# harmonicdyne g200 flannel
# harmonicdyne g200 lambskin
# harmonicdyne g200 yaxi alcantara
# harmonicdyne g200 yaxi leather
# harmonicdyne new
# harmonicdyne p.d.1
# harmonicdyne pd1
# harmonicdyne poseidon
# harmonicdyne zeus
# harpo target.csv
# harpo v3 target.csv
# harpo v4 target (11.03.2023 02-43-36).csv
# harpo v4 target.csv
# harpo_v2 target.csv
# haylou gt1
# haylou gt1plus
# haylou gt2
# hbb 1
# hbb audio x
# hbb comp target.csv
# hbb olina se
# hd600
# head corded earbuds
# hear+hi acuity duo
# heart mirror
# heart mirror pro
# heartfield deer
# hekili
# hekili_foamdeep
# helios
# helios 8khz
# helios ortofon
# helios symp
# hessian tws7
# hexa
# hiby crystal6
# hiby crystal6 ii
# hiby lasya
# hiby seeds
# hiby seeds 2
# hidition viento b
# hidition viento-b
# hidition violet
# hidizs md4 balanced
# hidizs md4 bass
# hidizs md4 treble
# hidizs md4 warm
# hidizs mermaid mm2
# hidizs mm2 balance
# hidizs mm2 balanced
# hidizs mm2 bass
# hidizs mm2 ref
# hidizs mm2 treble
# hidizs mm2 treble olina
# hidizs ms2
# hidizs ms4
# hidizs ms5
# hidizs ms5 1ohm
# hidizs ms5 2ohm
# hidizs ms5 bal
# hidizs ms5 balanced
# hidizs ms5 balanced (balanced tips)
# hidizs ms5 balanced (bass tips)
# hidizs ms5 balanced (final e tips)
# hidizs ms5 balanced (moondrop spring tips)
# hidizs ms5 balanced (no tip on coupler 8k)
# hidizs ms5 balanced (softear uc tips)
# hidizs ms5 balanced (tripowin foam)
# hidizs ms5 balanced (vocal tips)
# hidizs ms5 balanced (whizzer easytips et100ab)
# hidizs ms5 balanced 18ohm
# hidizs ms5 bass
# hidizs ms5 bass (balanced tips)
# hidizs ms5 bass (bass tips)
# hidizs ms5 bass (final e tips)
# hidizs ms5 bass (moondrop spring tips)
# hidizs ms5 bass (no tip on coupler 8k)
# hidizs ms5 bass (softear uc tips)
# hidizs ms5 bass (softear uc tips)l .csv
# hidizs ms5 bass (tripowin foam)
# hidizs ms5 bass (vocal tips)
# hidizs ms5 bass (whizzer easytips et100ab)
# hidizs ms5 high oi
# hidizs ms5 treb
# hidizs ms5 treble
# hidizs ms5 treble (balanced tips)
# hidizs ms5 treble (bass tips)
# hidizs ms5 treble (final e tips)
# hidizs ms5 treble (moondrop spring tips)
# hidizs ms5 treble (no tip on coupler 8k)
# hidizs ms5 treble (softear uc tips)
# hidizs ms5 treble (tripowin foam)
# hidizs ms5 treble (vocal tips)
# hidizs ms5 treble (whizzer easytips et100ab)
# hidizs ms5 treble 18ohm
# hidizs ms5 treble headamp
# hidizs ms5 treble tk2
# hifiman ananda (2022 stealth magnets)
# hifiman arya (2021 stealth magnets)
# hifiman arya stealth
# hifiman bolt
# hifiman deva pro
# hifiman edition xs
# hifiman he-r10d
# hifiman he-r10d bluemini
# hifiman he-r10p
# hifiman he-r10p bluemini
# hifiman he-r9
# hifiman he-r9 bluemini
# hifiman he1000se
# hifiman he400se
# hifiman hesev2
# hifiman r800
# hifiman re 400
# hifiman re2000 pro gold
# hifiman re600 v2
# hifiman re600s v2
# hifiman re800
# hifiman shangri-la jr
# hifiman shangri-la sr
# hifiman sundara 2022
# hifiman susvara
# hifiman svanar
# hifiman svanar s2
# hifiman svanar s3
# hifiman tws800
# hifri hybrid
# hisenior b5+
# hisenior fe3u
# hisenior mega5p
# hisenior mega5p (foam eartips)
# hisenior mega5p (no tip on coupler 8k peak disappeared foam)
# hisenior mega5p (orignal silicone eartips)
# hisenior mega5p (softears uc eartips)
# hisenior t2
# hisenior t2 classic
# hisenior t2c
# hobby talk flat target.csv
# hobby talk preference target og.csv
# hobby talk preference target.csv
# hobby talk target.csv
# honest target.csv
# hookx
# hpdc 10db tilt 5128 df 100hz target.csv
# hpdc 10db tilt 5128 df target.csv
# hpdc 10db tilt kemar df 100hz target.csv
# hpdc 10db tilt kemar df target.csv
# hpdc 14db tilt 5128 df 100hz target.csv
# hpdc 14db tilt 5128 df target.csv
# hpdc 14db tilt kemar df 100hz target.csv
# hpdc 14db tilt kemar df target.csv
# hs audio tech
# hs2000mx
# huawei freebuds pro 2
# huawei freebuds proo 2
# humka hamlet
# humka hamlet m
# hz heartmirror
# hz heartmirror pro
# hz sound heart mirror
# hz sound heart mirror pro
# hz sound pro
# hz sound zero
# hzhm
# hzsound heart mirror
# hzsound heart mirror pro
# hzsound heartmirror
# hzsound hmpro
# hzsound waist drum
# hzsound waistdrum9
# hzsound zero
# hzsound zero no foam
# ianfann-target target.csv
# ianfann.csv
# ibasso it00
# ibasso it01x
# ibasso it01x (s2)
# ibasso it04
# ibasso sr3
# ibasso sr3 spare pads
# ie200
# ie200 less bass
# ie200 less bass s2
# ie200 spinfit cp100 plus tips
# ie600
# ie600 stock.csv
# iec711 comp target.csv
# ief comp target.csv
# ief neutral 2020 target.csv
# ief neutral 2023 target.csv
# ief neutral target.csv
# ief neutral.csv
# ief oe target.csv
# ief target.csv
# ief target1.csv
# iem world target.csv
# iem_2
# if audio 11
# if audio 31
# if audio 51
# if audio d2
# if audio d5
# ihip anzu
# ikko asgard
# ikko gems oh1s
# ikko gems oh1s (s2 + etype tips)
# ikko gems oh1s (s2 + stock foams + blutack)
# ikko gems oh1s (s2 + stock foams + micropore mod)
# ikko gems oh1s (s2 + stock foams)
# ikko gems oh1s (s5 + stock foams)
# ikko oh1
# ikko oh10
# ikko oh10 (1dividedby16 foam)
# ikko oh10 (foam eartips)
# ikko oh10 (hana filter)
# ikko oh10 (high-density tuning foams)
# ikko oh10 (high-density tuning foams, tanchjim filters)
# ikko oh10 (no tip on coupler)
# ikko oh1s
# ikko oh1s sample 2
# ikko oh2
# ikko oh5
# ikko opal oh02
# ikko opal oh2
# illu
# illu eqharman
# illu ortofon
# illu shallowfit
# illu symbio
# illumination
# imr astra
# indigo
# inear pmx
# inear pro mission x
# inkd 2.0
# innerfidelity id target.csv
# innerfidelity target.csv
# intime go
# intime sora
# intime sora 2
# intime sora 2019
# intime sora light
# intime sora light (vent mod)
# intime sora light 2019
# intime sora light 2019 (s2)
# intime sora midnight
# intime sora29
# intime sora2fixed
# intime soralight2019
# intime sorati3
# intime todoroki go
# isn d10
# isn h40
# isn h50
# isn rambo ii
# itk unknown
# itsfit fusion
# j1234s
# j1b
# j1s
# j2b
# j2s
# j3b
# j3s
# j4b
# j4s
# jabra elite 5
# jade audio ea3
# jadeaudio ea1
# jaybird x3
# jbl endurance run
# jbl endurancerun
# jbl tune 110
# jbuds pro
# jcally jc10
# jd7
# jh audio layla (max)
# jh audio layla (min)
# jh jolene
# jh trifi
# jomo gt600
# joyaudio shine
# joyodio shine (0000)
# joyodio shine (0010)
# joyodio shine (0100)
# joyodio shine (0110)
# joyodio shine (1000)
# joyodio shine (1010)
# joyodio shine (1100)
# joyodio shine (1110)
# joyodio shine 0000
# joyodio shine 0001
# joyodio shine 0011
# joyodio shine 0111
# joyodio shine 1 on
# joyodio shine 1000
# joyodio shine 1001
# joyodio shine 1010
# joyodio shine 1011
# joyodio shine 1100
# joyodio shine 1110
# joyodio shine 1111
# joyodio shine 2 on
# joyodio shine 3 on
# joyodio shine 4 on
# joyodio shine all off
# joyodio shine all on
# joyodio shine classical
# joyodio shine hifi
# joyodio shine pop
# joyodio shine r&b rock
# joyodio shine rnb rock
# joyodio shine standard
# jpride 1984premium
# jq 4u
# jq 4upro
# jq audio 4u
# jq audio 4u pro
# jq audio hua jiang
# jq audio white knight
# juzear 41t
# jvc 1100
# jvc fd02
# jvc fdx1
# jvc fdx1 (f000)
# jvc fdx1 (f050)
# jvc fdx1 (f100)
# jvc fdx1 blue
# jvc fdx1 green
# jvc fdx1 white
# jvc fw10000
# jvc fwx1
# jvc fx7
# jvc ha-a50toff
# jvc ha-a7t
# jvc ha-fx6
# kato gold symbio
# kato max
# kato silver symbio
# kato spring
# kato vivid
# kb ear aurora
# kb ear believe
# kb ear diamond
# kb ear ks2
# kb ear neon triflange
# kb ear robin
# kb ear storm
# kb04
# kbear aurora
# kbear aurora matte
# kbear believe
# kbear believe new filter
# kbear believe vent
# kbear believe y2 mod
# kbear believev2
# kbear diamond
# kbear diamondv2
# kbear dumpling
# kbear f1
# kbear ink
# kbear kb04
# kbear kb04v2
# kbear kb06
# kbear ks1
# kbear ks19
# kbear ks1v2
# kbear ks2
# kbear ks2v2
# kbear lark
# kbear lark (s1)
# kbear lark (s2)
# kbear lark4k
# kbear lark4kv2
# kbear larkearly9
# kbear little q
# kbear littleq
# kbear neon
# kbear neon (a3 type e deep)
# kbear neon (stock type e avg)
# kbear neon (stock type e deep 80ohm)
# kbear neon (stock type e deep)
# kbear neon 75ohm
# kbear neon mod
# kbear neon+100ohm
# kbear ormosia
# kbear os1 pro
# kbear q
# kbear qinglong
# kbear robin
# kbear rosefinch
# kbear st1
# kbear st19
# kbear stellar
# kbear storm
# kemar df 1.3 bass target.csv
# kemar df 1.3 target.csv
# kemar df target.csv
# kiiboom allure
# kiiboom evoke
# kimafun
# kinden ue
# kinera baldr
# kinera bd005
# kinera bd005 pro
# kinera bd005pro
# kinera celest
# kinera celest foam
# kinera celest gumiho
# kinera celest gumiho 36ohm
# kinera celest pandamon
# kinera freya
# kinera hodur
# kinera idun golden
# kinera nanna 2
# kinera nanna 2.0
# kinera nanna 2.1 z-tune edition
# kinera nanna2
# kinera norn
# kinera pandamon
# kinera sif
# kinera skuld
# kinera tyr
# kinera tyr9
# kinera urd
# kinera yh802
# kinera yh802 anc
# kinera yh802 transparency
# kiwi cadenza
# kiwi ears
# kiwi ears cadenza
# kiwi ears new
# kiwi ears orchestra
# kiwi ears orchestra (e-type tws)
# kiwi ears orchestra (sedna short)
# kiwi ears orchestra lite
# kiwi ears orchestra lite (2.5mm 500 mesh on green bore)
# kiwi ears orchestra lite (2.5mm 500 mesh on white bore)
# kiwi ears orchestra lite (2.5mm 500 mesh on yellow bore)
# kiwi ears orchestra lite (25ohm)
# kiwi ears orchestra lite deep fit
# kiwi orchestra
# kiwi orchestra lite
# kiwiears cadanza
# kiwiears cadenza
# kiwiears orchestra lite
# kki 1 ba switch 1
# kki 1 ba switch 2
# kki 1 ba switch 3
# klipsch s4
# knd
# koast audio mithi
# koss keb90
# koss kph40
# koss theplug
# kotori dauntless
# kotori vampire pre-release
# kr0mka target.csv
# kr5
# ks zs10 pro
# ksearphone lbbs
# ksound ep-k05
# kurin target.csv
# kxxs
# kxxs (bgvp w01)
# kxxs (cp 100)
# kxxs (ep-ex11)
# kxxs (ex15)
# kxxs (symbio w peel)
# kxxs spring
# kz (avg)
# kz as06
# kz as06 30ohm
# kz as06-2020
# kz as10
# kz as10 30ohm
# kz as10 old
# kz as12
# kz as12 30ohm
# kz as12r22
# kz as16
# kz as16 200ω
# kz as16 30ohm
# kz as16 75ω
# kz as16 pro
# kz as16 pro 200ω
# kz as16 pro 25ohm
# kz as16 pro 30ω
# kz as16 pro 75ω
# kz as16 pro btx
# kz as16 pro tk2
# kz as16pro
# kz as16pro22
# kz as16prohi-imp
# kz as16r22
# kz asf
# kz asfv2
# kz ast
# kz ast 25ohm
# kz ast stock
# kz ast tanya
# kz asx
# kz asx 2
# kz asx 25ohm
# kz asx 30omh
# kz asx9
# kz asxv2
# kz ate
# kz atr
# kz ba10
# kz ba10 (1dividedby4 foam)
# kz ba10 (500 mesh)
# kz ba10 (tanchjim filter)
# kz ba10 30ohm
# kz crn
# kz crn zexpro
# kz d-fi
# kz d-fi dddd
# kz d-fi dddu
# kz d-fi ddud
# kz d-fi dudd
# kz d-fi mp
# kz d-fi uddd
# kz d-fi uudd
# kz d-fi uuud dp
# kz dfi dddd
# kz dfi dddu
# kz dfi ddud
# kz dfi dduu
# kz dfi dudd
# kz dfi dudu
# kz dfi duud
# kz dfi duuu
# kz dfi uddd
# kz dfi uddu
# kz dfi udud
# kz dfi uduu
# kz dfi uudd
# kz dfi uudu
# kz dfi uuud
# kz dfi uuuu
# kz dq6
# kz dq6 (1dividedby16 foam)
# kz dq6 (hana filter)
# kz dq6 (high-density tuning foam + cotton filter)
# kz dq6 (high-density tuning foam)
# kz dq6 (low-density tuning foam)
# kz dq6 (micropore tape mod)
# kz dq6 (micropore tape+ 1dividedby16foam mod)
# kz dq6 (micropore tips)
# kz dq6 (micropore+ 1dividedby16foam tips)
# kz dq6 (o2 filter)
# kz dq6 (sony import foam)
# kz dq6 (tanchjim filter)
# kz dq6 5
# kz dq6 r xf
# kz dq6 x
# kz dq6 x hbb
# kz dq6 x2
# kz dq6 x5
# kz dq6 xl
# kz dq6s
# kz dq6sv2
# kz dq6sv3
# kz dq6v2
# kz dqs
# kz ed16
# kz ed9 (balanced filter)
# kz eda (gold)
# kz eda (green)
# kz eda (silver)
# kz eda balance
# kz eda balanced
# kz eda balanced 300
# kz eda bass
# kz eda heavy bass
# kz eda hi res
# kz eda high
# kz eda high resolution
# kz eda highresolution
# kz eda hires
# kz eda resolution
# kz edab
# kz edabass
# kz edahi
# kz edc
# kz edcx
# kz edr1
# kz eds
# kz eds btx
# kz eds btx hifi
# kz edx
# kz edx pro
# kz edx pro (2 low-density tuning foams)
# kz edx pro (high-density tuning foam)
# kz edx pro (low-density tuning foam)
# kz edx ultra
# kz edxv2
# kz es4
# kz esx
# kz esx9
# kz h10
# kz hbb dq6s
# kz linglong
# kz linlong
# kz linlong mp
# kz pl1 hifi
# kz pl1 hifi medfoam
# kz pr1
# kz pr1 balanced
# kz pr1 balanced version
# kz pr1 hifi
# kz pr1 hifi version
# kz pr1 hifi version form
# kz pr1 pro
# kz pr1 stock tips
# kz s1
# kz s1d
# kz sa08
# kz sk10
# kz sk10 pro
# kz tc10
# kz tc10 a
# kz vx10 stock
# kz vx10 tanya
# kz vxs
# kz x crinacle crn
# kz x hbb dq6s
# kz z1
# kz z3
# kz zar
# kz zas
# kz zax
# kz zaxv2
# kz zes
# kz zex
# kz zex (vent blocked)
# kz zex pro
# kz zex pro (30ohm)
# kz zex pro taped
# kz zex stock
# kz zex taped
# kz zexpro
# kz zna
# kz zs10
# kz zs10 pro
# kz zs10 pro foam
# kz zs10 pro new
# kz zs10 pro x
# kz zs10 pro x sil
# kz zs10 prov2
# kz zs4
# kz zs5
# kz zs5 old
# kz zs6
# kz zs7
# kz zs7 (1dividedby16 foam)
# kz zs79
# kz zsa9
# kz zse
# kz zsn
# kz zsn pro
# kz zsn pro (1-8 foam)
# kz zsn pro (blessing 2 filter)
# kz zsn pro (starfield filter)
# kz zsn pro (tanchjim filter)
# kz zsn pro x
# kz zsn pro x broken
# kz zsn pro x ok
# kz zsn pro xv2
# kz zsn prov2
# kz zsnpro
# kz zsnprox
# kz zsnv2
# kz zsr
# kz zst
# kz zst x
# kz zstv2
# kz zstx
# kz zstxv2
# kz zsx
# kz zsxv2
# kz zvx
# kz zvx 25ohm
# kz zvx final tips
# kz zvx iematch
# kz zvx mp
# lafitear lf1
# land bass
# land treble
# lbbs2
# legendx
# leisurely audio e16
# leisurely audio l6
# leisurely audio l8
# lenovo hf130
# lenovo xt98
# letshuoer 12
# letshuoer cadenza
# letshuoer cadenza 12
# letshuoer conductor
# letshuoer conductor 75ohm
# letshuoer d13
# letshuoer d13 (gold filter)
# letshuoer d13 (gold)
# letshuoer d13 (pre-prod - nozzle a)
# letshuoer d13 (pre-prod - nozzle b)
# letshuoer d13 (silver filter)
# letshuoer d13 (silver)
# letshuoer d13 (treble nozzle)
# letshuoer d13 2nd nozzle
# letshuoer d13 gold
# letshuoer d13 gold nozzle
# letshuoer d13 mbp
# letshuoer d13 olina filter mod
# letshuoer d13 silver
# letshuoer d13 silver nozzle
# letshuoer d13 stock nozzle
# letshuoer d13 treble
# letshuoer ej07
# letshuoer ej07m
# letshuoer ej07m 75ohm
# letshuoer ej07m ciem
# letshuoer ej07m kinda lava
# letshuoer ej07m kinda lava (modded)
# letshuoer ej07m lava
# letshuoer ej07m resin
# letshuoer ej09
# letshuoer ej09 75ohm
# letshuoer galileo
# letshuoer galileo (pre-production)
# letshuoer galileo (retail)
# letshuoer galileo 75
# letshuoer galileo tape
# letshuoer kl
# letshuoer s12
# letshuoer s12 (front vent blocked)
# letshuoer s12 (post)
# letshuoer s12 (prepro)
# letshuoer s12 (s1)
# letshuoer s12 (s2)
# letshuoer s12 (top vent blocked)
# letshuoer s12 foam
# letshuoer s12 pro
# letshuoer s12 pro vents blocked
# letshuoer s12 pro vents blocked 300 damping
# letshuoer singer
# letshuoer soloist
# letshuoer tape pro
# letshuoer x gizaudio galileo
# letshuoer z12
# letshuoer z12 (s2)
# letshuoerxgizaudio galileo
# lg hbs800
# lg hbs800 (anc off)
# lg hbs800 (anc on)
# lime ears aether r (bass off)
# lime ears aether r (bass on)
# lime ears anima (spinfit)
# lime ears anima (symbio)
# lime ears pneuma
# lime ears pneuma (bass off)
# lime ears pneuma (bass on)
# lime ears pneuma switch
# limeears anima
# listener target.csv
# little dot gyfu raw
# lixeem target.csv
# lokahi
# lrey nectar
# lypertek bevi
# lypertek levi
# lypertek mevi
# lypertek pureplay z3
# lypertek pureplay z3 (1.0)
# lypertek pureplay z3 (1.0, tanchjim filter)
# lypertek pureplay z5
# lypertek pureplay z5 ambient
# lypertek pureplay z5 anc
# lypertek pureplay z7
# lypertek tevi
# lypertek z3 2.0
# lz a2 pro
# lz a4 pro
# lz a4 pro (a7 gold f + black v)
# lz a4 pro (a7 red f + black v)
# lz a4 pro (black f + black v)
# lz a4 pro (black f + blue v)
# lz a4 pro (black f + red v)
# lz a4 pro (blue f + black v)
# lz a4 pro (blue f + blue v)
# lz a4 pro (blue f + red v)
# lz a4 pro (gold f + black v)
# lz a4 pro (gold f + blue v)
# lz a4 pro (gold f + red v)
# lz a4 pro (red f + black v)
# lz a4 pro (red f + blue v)
# lz a4 pro (red f + red v)
# lz a4 pro black-black
# lz a4 pro black-blue
# lz a4 pro black-red
# lz a4 pro blue-black
# lz a4 pro gold-black
# lz a4 pro nzblk fiblk
# lz a4 pro nzblk fiblu
# lz a4 pro nzblk fired
# lz a4 pro nzblu fiblk
# lz a4 pro nzblu fiblu
# lz a4 pro nzblu fired
# lz a4 pro nzred fiblk
# lz a4 pro nzred fiblu
# lz a4 pro nzred fired
# lz a4 pro nzsil fiblk
# lz a4 pro nzsil fiblu
# lz a4 pro nzsil fired
# lz a4 pro red
# lz a4 pro red-black
# lz a4 pro silver
# lz a6 (black filter)
# lz a6 (blue filter)
# lz a6 (dark blue filter)
# lz a6 (grey filter)
# lz a6 (pink filter)
# lz a6 (purple filter)
# lz a6 (red filter)
# lz a6 (silver filter)
# lz a6 (yellow filter)
# lz a6 mini (black filter)
# lz a6 mini (blue filter)
# lz a6 mini (red filter)
# lz a7 (monitor-black)
# lz a7 (monitor-blue)
# lz a7 (monitor-gold)
# lz a7 (monitor-red)
# lz a7 (monitor-silver)
# lz a7 (pop-black)
# lz a7 (pop-black, high-density tuning foams)
# lz a7 (pop-blue)
# lz a7 (pop-blue, high-density tuning foams)
# lz a7 (pop-gold)
# lz a7 (pop-red)
# lz a7 (pop-red, 30ohm)
# lz a7 (pop-silver)
# lz a7 black monitor
# lz a7 black pop
# lz a7 blue monitor
# lz a7 blue pop
# lz a7 gold
# lz a7 gold monitor
# lz a7 gold pop
# lz a7 monitor black
# lz a7 monitor black foam
# lz a7 monitor blue
# lz a7 monitor blue foam
# lz a7 monitor gold
# lz a7 monitor red
# lz a7 monitor silver
# lz a7 pop black
# lz a7 pop black foam
# lz a7 pop blue
# lz a7 pop blue foam
# lz a7 pop gold
# lz a7 pop red
# lz a7 pop silver
# lz a7 red monitor
# lz a7 red pop
# lz a7 silver monitor
# lz a7 silver pop
# lz ax black
# lz ax black off
# lz ax blue
# lz ax gold
# lz ax gold off
# lz ax red
# lz ax silver
# lz z04a
# lz z04a (1dividedby16 foam)
# lz z04a (low-density tuning foam)
# lz z05a
# lza4 pro blue
# m - audio q40
# mackie mp-320
# mackie mp-460
# madoo t711
# madoo type 512
# magaosi k3
# magaosi k3 (f0)
# magaosi k3 (f1)
# magaosi k3 (f2)
# magaosi k5
# magaosi k5 (15 ohm + iematch+ ultra)
# magaosi k5 (15 ohm + iematch+)
# magaosi k5 (15 ohm)
# magaosi v3
# mangird
# mangird tea
# mangird tea 2
# mangird top
# mangird xenns up
# markanini target.csv
# massdrop plus
# massdropxnoble univ
# md b2
# md b2 dusk
# md b3
# md droplet dsp
# md kxxs
# md kxxx
# md quarks dsp
# mdplus
# mdr-ex15 (bgvp w01)
# mdr-ex15 (kxxs)
# mdr-ex15 (symbio w peel)
# mdr-ex15 cp100
# mdr-ex15ap
# mdr-xb55ap
# mee audio m6 pro 2g
# mee x20
# meeture mt3
# meizu live (black)
# meizu live (blue)
# meizu live (white)
# melodie
# memt r1
# mest mk ii
# mestjp
# meze 12 classics v2
# meze 99 neo
# meze 99 neo dekoni
# meze audio advar
# meze liric
# meze rai solo
# mh150
# mh755
# mh755 fake
# mi true wireless earbuds basic 2
# miku buds
# mim audio dark magician
# mim dark magician
# mim dark magician og
# mim dark magician revised
# mim dark magician tape
# mim dark magician v2
# mim dm
# mim dm comply
# mim dm softears
# mim dm xbassii
# mim dm xd-05
# mini pro hs anc off
# mini pro hs anc on
# mixx earphones
# mmr thummim
# moji monica h2o
# monarch
# monk
# monoprice m1070c lambskin
# monoprice m1070c velour
# monoprice monolith m-twe
# moondrop  starfield
# moondrop a8
# moondrop alice
# moondrop alice (0.1.9)
# moondrop alice (2.0.1 + e-type)
# moondrop alice (2.0.1)
# moondrop alice (eq austria)
# moondrop alice (eq berlin)
# moondrop alice (eq brooklyn)
# moondrop alice (eq hokkaido)
# moondrop alice (eq in-ear target)
# moondrop alice (eq munich)
# moondrop alice (eq peq default)
# moondrop alice (eq tokyo)
# moondrop alice (eq vienna)
# moondrop alice (eq wennebostel)
# moondrop alice tws
# moondrop aria
# moondrop aria (old)
# moondrop aria s1
# moondrop aria s2
# moondrop aria snow
# moondrop aria snow (spring)
# moondrop aria snow edition
# moondrop aria snow mp
# moondrop aria snow nofoam
# moondrop aria snow nofoam mp
# moondrop b2
# moondrop b2 dusk
# moondrop b2d
# moondrop blessing 2
# moondrop blessing 2 (e-type)
# moondrop blessing 2 (moondrop filter)
# moondrop blessing 2 (precog)
# moondrop blessing 2 dusk
# moondrop blessing 2 dusk (bgvp foam)
# moondrop blessing 2 dusk (final eartips)
# moondrop blessing 2 dusk (no tip on coupler 8k)
# moondrop blessing 2 dusk (orignal silicon)
# moondrop blessing 2 dusk (precog)
# moondrop blessing 2 dusk (softear uc eartips)
# moondrop blessing 2 dusk (softear uc eartips)c
# moondrop blessing 2 dusk (spinfit)
# moondrop blessing 2 dusk (tripowin foam)
# moondrop blessing 2 dusk s1
# moondrop blessing 2 dusk s2
# moondrop blessing 2 target.csv
# moondrop blessing 3
# moondrop blessing2
# moondrop chu
# moondrop chu (mod)
# moondrop chu (sf 145)
# moondrop chu (spring tips)
# moondrop chu (tanchjim filter)
# moondrop chu (vent - blutack)
# moondrop chu (vent - tanchjim)
# moondrop chu 2
# moondrop chu 3
# moondrop chu bass mod
# moondrop chu mp
# moondrop chu tanya
# moondrop crescent
# moondrop droplet
# moondrop dusk
# moondrop illumination
# moondrop illumination (filter removed)
# moondrop illumination (final e)
# moondrop illumination (final tws)
# moondrop illumination (moondrop foam)
# moondrop illumination (s2)
# moondrop illumination (sedna light)
# moondrop illumination (spiral dots)
# moondrop ix
# moondrop kanas pro
# moondrop kato
# moondrop kato (brass)
# moondrop kato (copper)
# moondrop kato (gold)
# moondrop kato (gold, high-density tuning foam)
# moondrop kato (gold, sony general foam)
# moondrop kato (gold, sony import foam)
# moondrop kato (gold, sony import foam, micropore vent)
# moondrop kato (silver)
# moondrop kato (steel)
# moondrop kato brass
# moondrop kato non spring (brass)
# moondrop kato non spring (steel)
# moondrop kxxs
# moondrop kxxs (new filters)
# moondrop kxxx
# moondrop lan
# moondrop lan (bgvp foam)
# moondrop lan (blu tack)
# moondrop lan (final eartips)
# moondrop lan (orignal silicon)
# moondrop lan (softear uc eartips)
# moondrop lan (tripowin foam)
# moondrop nekocake
# moondrop nekocake (anc off)
# moondrop nekocake (anc on)
# moondrop nekocake (balanced + anc)
# moondrop nekocake (balanced)
# moondrop nekocake (classic anc)
# moondrop nekocake (classic)
# moondrop nekocake (dynamic anc)
# moondrop nekocake (nobass anc)
# moondrop nekocake (nobass)
# moondrop nekocake (wennebostel anc)
# moondrop nekocake (wennebostel)
# moondrop nekocake (x-dynamic)
# moondrop quarks
# moondrop quarks (s2)
# moondrop quarks (s3)
# moondrop quarks dsp
# moondrop quarks dsp 77db
# moondrop quarks dsp stock tips
# moondrop quarks dsp ultra deep
# moondrop s8
# moondrop s8 (precog)
# moondrop s8 (s2)
# moondrop s8 sample 1
# moondrop s8 sample 2
# moondrop solis
# moondrop solis s2
# moondrop spaceship
# moondrop sparks
# moondrop sparks (1.1.2)
# moondrop sparks (1.1.4)
# moondrop sparks (1.1.5)
# moondrop sparks (1.1.7)
# moondrop sparks (1.1.9 - balanced)
# moondrop sparks (1.1.9 - basshead)
# moondrop sparks (1.1.9 - david xu)
# moondrop sparks (1.1.9 - no bass)
# moondrop sparks (1.1.9 - studio)
# moondrop sparks (1.1.9 - wennebostel)
# moondrop ssp
# moondrop ssp (vent blocked)
# moondrop ssr
# moondrop ssr (deep)
# moondrop ssr (final e)
# moondrop ssr (micro pore)
# moondrop ssr (os100)
# moondrop ssr (os200)
# moondrop ssr (os300)
# moondrop ssr (s2 + tanchjim filter)
# moondrop ssr (s2 - autoeq)
# moondrop ssr (s2)
# ...
# sparks no bass 1.2.1
# sparks studio 1.2.1
# sparks wennebostel 1.2.1
# srg0mes target.csv
# ssp
# ssr
# ssr faudio
# ssr foamdamper
# ssr new1
# ssr new2
# ssr new3
# ssr new4
# stagesound stage magic plus
# stakk target.csv
# stardust
# status audio iem-2x
# stg8p
# strauss and wagner em205
# strauss em205
# subtonic storm 004
# sun copper
# super 21 target.csv
# super 22 target.csv
# super bass target.csv
# super review 2021 target.csv
# super review 2022 target.csv
# super review target.csv
# supereq q2 pro
# supernova cp155
# supernova cp155eq
# supernova cp155s
# supernova cp155sdeep
# supernova final
# supernova mistip
# supernova ortofon
# supernova stock
# supernova vivid
# supernova w1
# supernova w1deep
# supernova w1impedance
# supernova w1shallow
# supertfz force king
# supertfz force1
# swd2le.csv
# symphonium audio helios_r
# symphonium audio meteor
# symphonium audio triton
# symphonium helios
# symphonium helios shallow fit
# symphonium helios spinfit
# symphonium meteor
# symphonium meteor (canjam)
# symphonium meteor (inverted)
# symphonium meteor s1
# symphonium meteor s2
# symphonium meteor sample
# symphonium triton
# t force yuan li
# t force yuan li final
# t-force yuan li
# t-force yuan li (pre final)
# t160
# t20 mod 3
# t20 mod1
# t20 raw
# t4 plus
# t50rp mkiii
# t60rp mkiii
# tae1105
# tago t3-02
# talbot target.csv
# tanchjim 02
# tanchjim cora
# tanchjim darling (depth 1)
# tanchjim darling (depth 2)
# tanchjim echo
# tanchjim echo (tanchjim echo filter + 200 paper vent)
# tanchjim echo (tanchjim echo filter + y6 paper vent)
# tanchjim echo (tanchjim echo filter)
# tanchjim hana
# tanchjim hana (1dividedby16 foam)
# tanchjim hana (1dividedby8 foam)
# tanchjim hana (final e)
# tanchjim hana (sedna light)
# tanchjim hana (y6 paper vent + 350 mesh)
# tanchjim hana (y6 paper vent + 500 mesh)
# tanchjim hana (y6 paper vent)
# tanchjim hana 2021
# tanchjim hana v2
# tanchjim hana21
# tanchjim new hana 2021 bass
# tanchjim new hana 2021 treble
# tanchjim ola
# tanchjim ola (s2 - filterless - taped)
# tanchjim ola (s2 - filterless)
# tanchjim ola (vent blu tack)
# tanchjim ola (vent tanchjim filter)
# tanchjim ola bass
# tanchjim ola shortbus
# tanchjim oxygen
# tanchjim oxygen (1dividedby16 foam)
# tanchjim oxygen (foam eartips)
# tanchjim oxygen (no tip on coupler)
# tanchjim oxygen microporevent set2
# tanchjim oxygen o2.csv
# tanchjim oxygen set2
# tanchjim prism
# tanchjim prism (small bore)
# tanchjim prism (treble tips)
# tanchjim prism (wide bore)
# tanchjim tanya
# tanchjim tanya olina
# tanchjim tanya openback
# tanchjim tanya openback olina
# tanchjim tanyav2
# tanchjim zero
# tanchjim zero dsp
# tanchjim_tanya
# tangzu audio shimin li
# tangzu audio waner sg
# tangzu audio zetian wu
# tangzu encounter
# tangzu fo
# tangzu heyday
# tangzu heyday micropore
# tangzu heyday wu
# tangzu heydey
# tangzu r
# tangzu shimin li
# tangzu shimin li encounter
# tangzu shiminli
# tangzu shiminli downunder
# tangzu shiminli encounter
# tangzu shiminli nodamper
# tangzu wan er
# tangzu wan er sg
# tangzu wan'er
# tangzu wan'er (foam eartips)
# tangzu wan'er (no tip on coupler)
# tangzu wan'er (wide bore silicone tips)
# tangzu wan-er s.g
# tangzu waner
# tangzu waner frontvent
# tangzu waner sg
# tangzu wu heyday
# tangzu wu zetian
# tangzu wu zetian heyday
# tangzu x hbb wu heyday
# tangzu x hbb zetian wu
# tangzu x hbb zetian wu tape
# tangzu x hbb zetian wu xbass
# tangzu x hbb zetian wu xbass xspace
# tangzu x hbb zetian wu xspace
# tangzu z
# tangzu ze tian wu
# tangzu zetian
# tangzu zetian wu
# tangzu zetian wu heyday
# tangzu zetianwu
# tangzu zetianwu hayday
# tansio mirai 5
# tansio mirai land
# tansio mirai rgb
# tansio mirai rgb bass
# tansio mirai sands 020
# tansio mirai spark (010)
# tansio mirai spark (110)
# tansio mirai spark (111)
# tansio mirai tsmr - 4 pro (120 + 0.15ohm cable)
# tansio mirai tsmr - 4 pro (120 + 0.46ohm cable)
# tansio mirai tsmr - 4 pro (120 + 1dividedby16 foam)
# tansio mirai tsmr - 4 pro (120 + 80ohm)
# tansio mirai tsmr - 4 pro (120)
# tantalus
# tantan
# target 8.csv
# tcl socl300
# te0 narrow
# te0 wide
# te0 wide 47 oi
# technics az70
# tenhz 3ba
# tenhz p4 pro
# test
# tforce audio yuan li
# tforce yuan li
# tforce yuan li modded
# tfz balance19
# tfz essence
# tfz essence.csv
# tfz king 2
# tfz king rs
# tfz live 1
# tfz live 3
# tfz live x
# tfz my love 2019
# tfz my love 4
# tfz my love edition 2021
# tfz my love iii
# tfz no.3
# tfz no3
# tfz t2 galaxy
# tfz t2 pro
# tfz tequila 1
# tfz tequila pro
# tgx78 150bg
# tgx78 b1
# tgx78 tantalus
# tgx78 target.csv
# tgx78 tofino
# tgxear red dot ti
# tgxear tiolake red
# tgxear tiolake red r (1).csv
# tgxear tiolake white
# th hifi face red
# thc
# thhifi character
# thhifi character (small bore)
# thhifi character (wide bore)
# thhifi face red
# thhifi face red (small bore)
# thhifi face red (wide bore)
# thie or r
# thieaudio clair
# thieaudio clairvoyance
# thieaudio elixir
# thieaudio elixir shallow fit
# thieaudio ghost
# thieaudio l2
# thieaudio l3
# thieaudio l3 (00)
# thieaudio l3 (00)r.csv
# thieaudio l3 (02)
# thieaudio l3 (10)
# thieaudio l3 (12)
# thieaudio l4
# thieaudio l4 (00)
# thieaudio l4 (02)
# thieaudio l4 (10)
# thieaudio l4 (12)
# thieaudio l5
# thieaudio l9
# thieaudio legacy 2
# thieaudio legacy 3 1 on
# thieaudio legacy 3 2 on
# thieaudio legacy 3 all on
# thieaudio legacy 3 off
# thieaudio legacy 4
# thieaudio legacy 4 (spring)
# thieaudio legacy 4 (switch on)
# thieaudio legacy 4 1 on
# thieaudio legacy 4 2 on
# thieaudio legacy 4 all on
# thieaudio legacy 4 off
# thieaudio legacy 5
# thieaudio legacy 5 (126 ohm)
# thieaudio legacy 5 (15 ohm)
# thieaudio legacy 5 (36 ohm)
# thieaudio legacy 5 (75 ohm)
# thieaudio legacy 5 (s1 seized)
# thieaudio legacy 5 (s1)
# thieaudio legacy 5 (s2 15ohm)
# thieaudio legacy 5 (s2)
# thieaudio monarch
# thieaudio monarch 2
# thieaudio monarch mk2
# thieaudio monarch mk2 (bgvp memory cotton)
# thieaudio monarch mk2 (final eartips)
# thieaudio monarch mk2 (foam eartips)
# thieaudio monarch mk2 (no tip on coupler 8k peak disappeared 87db foam)
# thieaudio monarch mk2 (no tip on coupler 8k peak disappeared 95db foam)
# thieaudio monarch mk2 (orignal silicone eartips)
# thieaudio monarch mk2 (softears uc eartips)
# thieaudio monarch mkii
# thieaudio monarch mkii (s2 - spring tips)
# thieaudio monarch mkii (s2)
# thieaudio monarch mkii imr cable
# thieaudio oracle
# thieaudio oracle 2
# thieaudio oracle mk2
# thieaudio oracle mkii
# thieaudio oracle mkii deep
# thieaudio prestige
# thieaudio prestige deep
# thieaudio v14
# thieaudio v16
# thieaudio v16 divinity
# thieaudio voyager 3 (00)
# thieaudio voyager 3 (02)
# thieaudio voyager 3 (10)
# thieaudio voyager 3 (12)
# thieaudio wraith
# thieaudio wraith pad a
# thieaudio wraith pad b
# thinksound rain3
# thor mjölnir mkii
# thor mojinhor
# timeless
# timmkoo c6109
# timmy target.csv
# tin buds 3
# tin c2 mech warrior
# tin c2 mech warror
# tin c3
# tin hifi c2
# tin hifi c2 mech warrior
# tin hifi c3
# tin hifi c5
# tin hifi p1
# tin hifi p1 (vent blocked)
# tin hifi p1 max
# tin hifi p1 plus
# tin hifi p2
# tin hifi t1 plus
# tin hifi t1s
# tin hifi t1s eq
# tin hifi t2
# tin hifi t2 dlc
# tin hifi t2 evo
# tin hifi t2 plus
# tin hifi t2 plus (sedna light)
# tin hifi t2 pro
# tin hifi t2 pro (comply)
# tin hifi t2 pro (white grill + comply)
# tin hifi t3
# tin hifi t3 plus
# tin hifi t3 plus (2 high-density tuning foams + tanchjim filter)
# tin hifi t3 plus (filterless)
# tin hifi t4
# tin hifi t4 plus
# tin hifi t5
# tin hifi t5 (comply waxguard)
# tin hifi tin buds 3
# tin p1
# tin p1 max
# tin p2
# tin t1 plus
# tin t1s
# tin t2
# tin t2 2pin
# tin t2 dlc
# tin t2 evo
# tin t2 plus
# tin t2+
# tin t2plus
# tin t3 buds
# tin t3 plus
# tin t3plus
# tin t4 plus
# tin t5
# tingker tk200
# tinhifi buds 3
# tinhifi c2
# tinhifi c3
# tinhifi c5
# tinhifi c5 prototype
# tinhifi meca c2
# tinhifi p1
# tinhifi p1 max
# tinhifi p1 max giant panda
# tinhifi p1 max prototype
# tinhifi p1 max tape mod
# tinhifi p1 plus
# tinhifi p1max
# tinhifi p1max tape
# tinhifi p2
# tinhifi t1s
# tinhifi t1s9
# tinhifi t2
# tinhifi t2 +
# tinhifi t2 dlc
# tinhifi t2 dlc mp
# tinhifi t2 evo
# tinhifi t2 plus
# tinhifi t2+ no filter
# tinhifi t2d silicon
# tinhifi t2plus
# tinhifi t2plusv2
# tinhifi t3 plus
# tinhifi t3+
# tinhifi t39
# tinhifi t3pro9
# tinhifi t4
# tinhifi t4 plus
# tinhifi t4 plus deep fit
# tinhifi t4 pluss
# tinhifi t4+
# tinhifi t4plus
# tinhifi t5
# tinhifi t59
# tinhifi t5s
# tinhifi tinbuds 3
# tiolake sr2
# tipsy dunmer
# tipsy tromso
# tipsy ttroms
# tipsy ttromso
# tipsy ttromso pine stone sea
# titans
# tksilver target.csv
# tkzk ouranos
# tkzk ouranos2
# tkzk wave
# tlc socl300
# tofino mmcx
# tofino pro
# toneking p10
# toneking_bl1
# totem
# totem p3
# tozo golden x1
# tranya t10 upgraded
# tri hbb kai
# tri hbb kai s2
# tri i one
# tri i3
# tri i3 pro
# tri i3 pro (88h)
# tri i3 pro (micropore-vent)
# tri i4
# tri ione
# tri ione mic 2
# tri ione mp
# tri kai
# tri kai x hbb
# tri meteor
# tri star river
# tri star river (enhanced treble)
# tri star river (natural)
# tri star river (pop)
# tri star river (vocal)
# tri star river 1 on
# tri star river 2 on
# tri star river all off
# tri star river all on
# tri star river bass
# tri star river ii
# tri star river io
# tri star river natural
# tri star river oi
# tri star river pop
# tri star river treble
# tri starlight
# tri starsea
# tri starsea (00)
# tri starsea (01)
# tri starsea (02)
# tri starsea (10)
# tri starsea (11)
# tri starsea (12)
# tri starshine
# tri x hbb kai
# tri x hbb kai 2
# tri xhbbkai
# tri ｍeteor
# trifi
# trihbk
# trio
# tripowin
# tripowin a
# tripowin black
# tripowin black 2
# tripowin cencibel
# tripowin cencibel 2x filter mod
# tripowin h1
# tripowin h1 r (1).csv
# tripowin lea
# tripowin lea'
# tripowin leá
# tripowin mele
# tripowin mele naked
# tripowin mele s2
# tripowin mele sony
# tripowin olina
# tripowin olina (s2)
# tripowin olina (tanya filter)
# tripowin olina 1tanya
# tripowin olina 1tanyamp
# tripowin olina 6
# tripowin olina comply
# tripowin olina dual
# tripowin olina dual comply
# tripowin olina dual open
# tripowin olina dual vent
# tripowin olina filter mod
# tripowin olina highdensity foam olinad
# tripowin olina mesh
# tripowin olina mesh b1s
# tripowin olina nofilter
# tripowin olina s2
# tripowin olina s3
# tripowin olina se
# tripowin olina sony foam 500
# tripowin olina tanya
# tripowin olina tanyaolina
# tripowin olina taped
# tripowin olina us full
# tripowin olina us full naked
# tripowin olina us half
# tripowin olina us half naked
# tripowin olina us half tan
# tripowin olina vent covered
# tripowin piccolo
# tripowin rhombus
# tripowin silver
# tripowin tc-01
# tripowin tc01
# tripowin tc019
# tripowin x hbb loki
# tripowin x hbb loki r(1).csv
# tripowin x hbb makaha
# tripowin x hbb mele
# tripowin x hbb mele blue
# tripowin x hbb olina
# tripowin x hbb olina (2 filter final eartips)
# tripowin x hbb olina (2 filter foam eartips)
# tripowin x hbb olina (2 filter moondrop eartips)
# tripowin x hbb olina (2 filter orignal eartips)
# tripowin x hbb olina (final eartips)
# tripowin x hbb olina (foam eartips)
# tripowin x hbb olina (moondrop eartips)
# tripowin x hbb olina (orignal eartips)
# tripowin x hbb olina a
# tripowin x hbb olina b
# tripowin x hbb olina double filter
# tripowin x hbb olina se
# tripowin x hbb olina silicon
# tripowin xhbb olina foam
# tripowin xhbb olina foamz
# tripowin xs l
# trn ba 5
# trn ba15
# trn ba5
# trn ba59
# trn ba8
# trn bax
# trn cs1
# trn cs2
# trn emx
# trn h2
# trn im1
# trn im2
# trn kirin
# trn kirin (atmospheric filter)
# trn kirin (reference filter)
# trn kirin (transparency filter)
# trn kirin atmosphere
# trn kirin atmospheric
# trn kirin reference
# trn kirin transparency
# trn kirin transparent
# trn m10
# trn mt1
# trn mt1 pro
# trn mt1v2
# trn mt3
# trn mt4
# trn reference
# trn rosefinch
# trn st1
# trn st2
# trn st5
# trn stm
# trn stm (blue)
# trn stm (gold)
# trn stm (red)
# trn stm gold
# trn t300
# trn ta
# trn ta1
# trn ta1 max
# trn ta2
# trn ta3
# trn transparency
# trn v30
# trn v80
# trn v809
# trn v90
# trn v90s
# trn vx
# trn vx pro
# trn vx pro red
# trn vx pro red set 2
# trn vx pro tanya
# trn vx9
# trn vxpro9
# trn x6
# trn x7
# trn xuanwu
# tronsmart apollo air+
# tronsmart apollo bold
# tronsmart apollo bold classic
# tronsmart apollo bold jazz
# tronsmart apollo bold pop
# tronsmart apollo bold rock
# tronsmart onyx apex
# tronsmart onyx prime
# tronsmart onyx prime custom
# tronsmart onyx prime default
# tronsmart onyx prime hifi
# tronsmart onyx pure bass
# tronsmart onyx pure normal
# tronsmart onyx pure pure
# trurhear hola
# truthear crin zero
# truthear hexa
# truthear hexa (final e tips)
# truthear hexa (foam eartips)
# truthear hexa (no tip on coupler)
# truthear hexa (s2 - airlocked)
# truthear hexa (s2)
# truthear hexa (softears uc eartips)
# truthear hexa 220ohm
# truthear hexa cp100+
# truthear hola
# truthear hola (foam eartips)
# truthear hola (no tip on coupler)
# truthear hola (wide bore silicone tips)
# truthear hola wide bore
# truthear x crinacle zero
# truthear x crinacle zero (final e eartips)
# truthear x crinacle zero (moondrop eartips)
# truthear x crinacle zero (orignal foam eartips)
# truthear x crinacle zero (orignal silicone eartips)
# truthear zero
# truthear zero (s2 deep)
# truthear zero (s2)
# truthear zero 2
# truthear zero 220ohm
# truthear zero 220ohm + filter mod
# truthear zero 75ohm
# truthear zero 80ohm
# truthear zero double filter
# truthear zero filter mod
# truthears hexa
# truthears hola
# truthears zero
# trzr ouranos
# trzr wave
# trzr wave eq
# trzr wave narrow
# trzr wave olina
# trzr wave tanya
# tsmr 8 bass
# tsmr 8 mids
# tsmr space
# ttr co-donguribrass9
# ttr co-dongurishizuku
# ttr co-dongurishizuku9
# tune 110
# turiiti
# twilight
# tz shimin li
# tz yuan li
# u18s
# u18t
# ua complimentary 1
# ua complimentary 2
# ucotech re-2
# ue ue18+ pro (2nd gen)
# ue18
# ugreen hitune t3
# uiisii ba-t6
# uiisii cm5
# um 3dt
# um mcbeth
# um mentor
# um mest
# um mest mk1
# uncjc irock9
# unique melody fabled sound
# unique melody maven pro
# unique melody mentor
# unique melody mest
# unique melody mest indigo
# unique melody mest mk2
# unique melody mest mkii
# unique melody mest mkii
# unique melody mext
# unison
# unknown amazon iem
# unknown_soldier
# unknown_soldier_bucky
# urbanfun hybrid
# urbanfun iss014
# urbanfun ybf
# urbanfun ybf-iss014 (s1)
# urbanfun ybf-iss014 (s2)
# urbanfun ybfiss014
# urbanfun ybfiss014v2
# urbanutility uehe-ep2
# usound1v1 oratory 1990 target.csv
# v20
# v3
# v4
# variations
# variations_sb
# variations_sb2
# variations_sb3
# variations_sb4
# variations_sb5
# variations_sb6
# variations_sb7
# variations_sb8
# ve aws
# ve azure
# ve bie
# ve bie pro
# ve bonus ie
# ve elysium
# ve ext
# ve phonix2
# ve sun copper
# velodyne pink
# vento conductor celestial
# vento conductor celestial2
# vento conductor ethereal
# vento conductor hanabi
# vento conductor t-1000
# vento conductor t-500 pro
# vento conductor t-500 pro (1dividedby16 foam)
# vento conductor t-500 pro (high-density tuning foams + tanchjim tanya filter)
# vento conductor t-500pro
# vento conductor t-800
# vento conductor tony
# venture bie
# venture electronics bonus ie
# venture electronics bonus ie pro
# venture electronics grand duke
# venture ie mod
# venus
# vido earbud
# viento
# vientocp155
# vientod
# vientovivid
# vision ears elysium
# vision ears phonix
# vision ears ve7
# vision ears ve8
# vjjb n1
# vjjb n30
# vk4
# volume 01-23
# voyager3
# vsg target.csv
# vsonic gr07
# vsonic gr07 (bass)
# vsonic vs7
# waner
# wdym target.csv
# wemlik misty 1
# wemlik misty 2
# westone mach 10
# westone mach 20
# westone mach 30
# westone mach 40
# westone mach 50
# westone mach 60
# westone mach 70
# westone mach 80
# westone um2
# wf1000x
# wf1000xm4
# wgzblon bl-max
# whizzer bs1
# whizzer he01
# whizzer he03d
# whizzer he1
# whizzer kylin
# whizzer kylin he03d
# whizzer opera factory om3
# willsound dewa copper
# willsound dewa silver
# working 001 target.csv
# working 002 target.csv
# x target.csv
# x2 pro
# x2 sport
# xduoo_ta20_loopback
# xe6
# xenns mangird tea
# xenns mangird tea 2
# xenns mangird tea 2 (s2)
# xenns mangird tea2
# xenns mangird top
# xenns top
# xenns up
# xenns up sample 2
# xinhs erasmus
# xuan
# xuanerji x01
# yan mahina 2
# yan ult 2
# yan ult 3
# yanyin aladdin
# yanyin canon
# yanyin canon 000
# yanyin canon 001
# yanyin canon 010
# yanyin canon 100
# yanyin canon all switches
# yanyin canon bass switch
# yanyin canon dip 1
# yanyin canon dip 2
# yanyin canon dip 3
# yanyin canon mids switch
# yanyin canon no switches
# yanyin canon treble switch
# yanyin m
# yanyin mahina
# yanyin mahina
# yanyin mahina s2
# yanyin moonlight
# yanyin rosemary 00
# yanyin rosemary 01
# yanyin rosemary 10
# yanyin rosemary 11
# yanyin sample 2
# yanyin ult 1
# yanyin x hbb final
# yanyin x hbb mahina
# yanyin_m
# ybf
# yincrow rw9
# yinfu md51
# yinyoo ash
# yinyoo pro
# yinyoo q70
# yinyoo st7
# yinyoo v2
# yuan li final
# yuanli
# z1r aet06s
# z1r aet08m
# z1r azlamaxs
# z1r azlavivid
# z1r azlavivid8khz
# z1r azlavivid9khz
# z1r azlavividdeep
# z1r azlavividshallow
# z1r cp800
# z1r dqsms
# z1r epro00m
# z1r max
# z1r radiuss
# z1r sednareg
# z1r sednaregss
# z1r sonyhybridm
# z1r stockms
# z1r symbiofoamlesss
# z_isolation comparison free field
# zar
# zephone tiger
# zero
# zero carbotenore
# zero zircopezzo
# zetian wu
# zex pro
# zexpro
# zhulinniao jinghong
# zhulinniao jinghong mp
# zs10
# zs10 pro
# zs5v1
# zs5v1 47r oi

# %%
# import os
# from collections import defaultdict
# import re
# 
# def remove_channel_suffix(file_name):
#     file_name = file_name.lower()
#     file_name = re.sub(r'\(.*?\)', '', file_name)  # Remove content in brackets
#     file_name = file_name.strip()  # Remove leading and trailing spaces
# 
#     if " l.csv" in file_name:
#         file_name = file_name.replace(" l.csv", ".csv")
#     elif " r.csv" in file_name:
#         file_name = file_name.replace(" r.csv", ".csv")
# 
#     return file_name.strip()  # Remove any extra spaces after channel suffix removal
# 
# def group_files_by_iem(files, threshold=80):
#     groups = defaultdict(list)
#     added_files = set()
# 
#     # Create a special "target" group
#     target_group = "target"
# 
#     for file1 in files:
#         modified_file1 = remove_channel_suffix(file1)
# 
#         # Check if the file name contains "target"
#         if "target" in file1.lower():
#             if file1 not in added_files:
#                 groups[target_group].append(file1)
#                 added_files.add(file1)
#             continue
# 
#         if file1 not in added_files:
#             groups[file1].append(file1)
#             added_files.add(file1)
# 
#         for file2 in files:
#             if file2 not in added_files:
#                 modified_file2 = remove_channel_suffix(file2)
#                 similarity = fuzz.token_set_ratio(modified_file1, modified_file2)
# 
#                 if similarity >= threshold:
#                     groups[file1].append(file2)
#                     added_files.add(file2)
# 
#     return groups
# 
# # Gather all file names
# all_files = []
# 
# for reviewer in reviewers:
#     reviewer_path = f'output/csv/{reviewer}'
# 
#     if os.path.exists(reviewer_path):
#         files = os.listdir(reviewer_path)
#         all_files.extend([(reviewer, file) for file in files])
# 
# # Group files by IEM
# grouped_files = group_files_by_iem([file for _, file in all_files])
# 
# # Print grouped files
# for representative, files in grouped_files.items():
#     print(f"{representative}:")
#     for file in files:
#         reviewers_with_file = [reviewer for reviewer, f in all_files if f == file]
#         print(f"  {file} - {', '.join(reviewers_with_file)}")
#     print()
#
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7352\1637703398.py in <module>
#      58
#      59 # Group files by IEM
# ---> 60 grouped_files = group_files_by_iem([file for _, file in all_files])
#      61
#      62 # Print grouped files
#
# ~\AppData\Local\Temp\ipykernel_7352\1637703398.py in group_files_by_iem(files, threshold)
#      39             if file2 not in added_files:
#      40                 modified_file2 = remove_channel_suffix(file2)
# ---> 41                 similarity = fuzz.token_set_ratio(modified_file1, modified_file2)
#      42
#      43                 if similarity >= threshold:
#
# c:\Users\Agnes\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py in token_set_ratio(s1, s2, force_ascii, full_process)
#     167
#     168 def token_set_ratio(s1, s2, force_ascii=True, full_process=True):
# --> 169     return _token_set(s1, s2, partial=False, force_ascii=force_ascii, full_process=full_process)
#     170
#     171
#
# c:\Users\Agnes\anaconda3\lib\site-packages\fuzzywuzzy\utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# c:\Users\Agnes\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py in _token_set(s1, s2, partial, force_ascii, full_process)
#     126
#     127     p1 = utils.full_process(s1, force_ascii=force_ascii) if full_process else s1
# --> 128     p2 = utils.full_process(s2, force_ascii=force_ascii) if full_process else s2
#     129
#     130     if not utils.validate_string(p1):
#
# c:\Users\Agnes\anaconda3\lib\site-packages\fuzzywuzzy\utils.py in full_process(s, force_ascii)
#      91
#      92     if force_ascii:
# ---> 93         s = asciidammit(s)
#      94     # Keep only Letters and Numbers (see Unicode docs).
#      95     string_out = StringProcessor.replace_non_letters_non_numbers_with_whitespace(s)
#
# KeyboardInterrupt:

# %%
import os
from collections import defaultdict
from fuzzywuzzy import fuzz
import re

# List of reviewers
reviewers = [
    'achoreviews',
    'aftersound',
    'animagus',
    'arn',
    'bedrock',
    'bryaudioreviews',
    'cammyfi',
    'soundjedi',
    'eplv',
    'timmyv',
    'harpo',
    'hbb',
    'cqtek',
    'hobbytalk',
    'ianfann',
    'iemworld',
    'jacstone',
    'kr0mka',
    'kurin',
    'melatonin',
    'nymz', 
    'pw',
    'recode',
    'rg',
    'shortbus',
    'suporsalad',
    'tgx78',
    'vortexreviews',
    'vsg',
    'wdym',
    'akros',
    'data_mrs'
]

def remove_channel_suffix(file_name):
    file_name = file_name.lower()
    file_name = re.sub(r'\(.*?\)', '', file_name)  # Remove content in brackets
    file_name = file_name.strip()  # Remove leading and trailing spaces

    if " l.csv" in file_name:
        file_name = file_name.replace(" l.csv", ".csv")
    elif " r.csv" in file_name:
        file_name = file_name.replace(" r.csv", ".csv")

    return file_name.strip()  # Remove any extra spaces after channel suffix removal

def group_files_by_iem(files, threshold=90):
    groups = defaultdict(list)
    added_files = set()

    # Create a special "target" group
    target_group = "target"

    for file1 in files:
        modified_file1 = remove_channel_suffix(file1)

        # Check if the file name contains "target"
        if "target" in file1.lower():
            if file1 not in added_files:
                groups[target_group].append(file1)
                added_files.add(file1)
            continue

        if file1 not in added_files:
            groups[file1].append(file1)
            added_files.add(file1)

        for file2 in files:
            if file2 not in added_files:
                modified_file2 = remove_channel_suffix(file2)
                similarity = fuzz.token_set_ratio(modified_file1, modified_file2)

                # If the similarity score is above the threshold, add the file to the group
                if similarity >= threshold:
                    groups[file1].append(file2)
                    added_files.add(file2)
                # If the similarity score is between 80 and the threshold, compare only the IEM part
                elif 80 <= similarity < threshold:
                    iem1 = re.sub(r'[^a-zA-Z0-9]', '', modified_file1.split()[1]) if len(modified_file1.split()) > 1 else ''
                    iem2 = re.sub(r'[^a-zA-Z0-9]', '', modified_file2.split()[1]) if len(modified_file2.split()) > 1 else ''
                    iem_similarity = fuzz.token_set_ratio(iem1, iem2)
                    
                    if iem_similarity >= threshold:
                        groups[file1].append(file2)
                        added_files.add(file2)

    return groups

# Gather all file names
all_files = []

for reviewer in reviewers:
    reviewer_path = f'output/csv/{reviewer}'

    if os.path.exists(reviewer_path):
        files = os.listdir(reviewer_path)
        all_files.extend([(reviewer, file) for file in files])

# Group files by IEM
grouped_files = group_files_by_iem([file for _, file in all_files])

# Print grouped files
for representative, files in grouped_files.items():
    print(f"{representative}:")
    for file in files:
        reviewers_with_file = [reviewer for reviewer, f in all_files if f == file]
        print(f"  {file} - {', '.join(reviewers_with_file)}")
    print()
# Out:
# 7Hz Dioko L.csv:
#   7Hz Dioko L.csv - achoreviews, bedrock, timmyv, iemworld, data_mrs
#   7HZ SALNOTES DIOKO L.csv - aftersound
#   7HZ SALNOTES DIOKO R.csv - aftersound
#   7Hz Salnotes Dioko L.csv - arn, pw
#   7Hz Dioko R.csv - bedrock, timmyv, hbb, iemworld, data_mrs
#   Salnotes Dioko L.csv - eplv
#   Salnotes Dioko R.csv - eplv
#   7hz Dioko L.csv - hobbytalk
#   7hz Dioko R.csv - hobbytalk
#   7HZ DIOKO (bass mod) L.csv - ianfann
#   7HZ DIOKO (bass mod) R.csv - ianfann
#   7HZ DIOKO L.csv - ianfann
#   7HZ DIOKO R.csv - ianfann
#   Dioko L.csv - kr0mka
#   Dioko R.csv - kr0mka
#   Resolve 7Hz Salnotes Dioko Gras L.csv - kurin
#   7hz Salnotes Dioko L.csv - nymz
#   7hz Salnotes Dioko R.csv - nymz
#   7Hz Salnotes Dioko R.csv - pw
#   7Hz Salnotes Dioko TapedVent L.csv - pw
#   7hz x Crinacle Dioko L.csv - vortexreviews
#   7hz x Crinacle Dioko R.csv - vortexreviews
#   7hz x Crinacle Dioko Updated L.csv - vortexreviews
#   7hz x Crinacle Dioko Updated R.csv - vortexreviews
#   7Hz x Crinacle Salnotes Dioko L.csv - vsg
#   7Hz x Crinacle Salnotes Dioko R.csv - vsg
#   7Hz Dioko (post-op) L.csv - data_mrs
#   7Hz Dioko (post-op) R.csv - data_mrs
#   7Hz Dioko (pre-op) L.csv - data_mrs
#   7Hz Dioko (pre-op) R.csv - data_mrs
#
# 7Hz Eternal L.csv:
#   7Hz Eternal L.csv - achoreviews, bedrock, vsg
#   7Hz Eternal R.csv - bedrock, harpo, hbb, vsg
#   7Hz ETERNAL L.csv - iemworld
#   7Hz ETERNAL R.csv - iemworld
#   7hz Eternal L.csv - vortexreviews
#   7hz Eternal R.csv - vortexreviews
#
# 7Hz Legato L.csv:
#   7Hz Legato L.csv - achoreviews, timmyv, cqtek, vsg
#   7HZ LEGATO L.csv - aftersound, ianfann
#   7HZ LEGATO R.csv - aftersound, ianfann
#   7Hz Legato R.csv - timmyv, hbb, cqtek, vsg
#   7hz LEGATO L.csv - nymz
#   7hz LEGATO R.csv - nymz
#   7hz Legato (250 mesh) L.csv - rg
#   7hz Legato (3 outer vent blutack) L.csv - rg
#   7hz Legato (500 mesh) L.csv - rg
#   7hz Legato (inner vent blutack) L.csv - rg
#   7hz Legato L.csv - rg, vortexreviews
#   7hz Legato R.csv - rg, vortexreviews
#
# 7Hz Timeless L.csv:
#   7Hz Timeless L.csv - achoreviews, arn, soundjedi, timmyv, pw, rg, vsg, data_mrs
#   7HZ TIMELESS AE L.csv - aftersound, ianfann
#   7HZ TIMELESS AE R.csv - aftersound, ianfann
#   7HZ TIMELESS L.csv - aftersound
#   7HZ TIMELESS R.csv - aftersound
#   7HZ TIMELESS S2 L.csv - aftersound
#   7HZ TIMELESS S2 R.csv - aftersound
#   7Hz Timeless R.csv - soundjedi, timmyv, harpo, pw, rg, vsg, data_mrs
#   7Hz Timeless AE L.csv - timmyv
#   7Hz Timeless AE R.csv - timmyv, hbb
#   7Hz Timeless (no filter) R.csv - hbb
#   7hz Timeless L.csv - hobbytalk, tgx78, vortexreviews
#   7hz Timeless R.csv - hobbytalk, tgx78, vortexreviews
#   7hz Timeless Tape Mod L.csv - hobbytalk
#   7hz Timeless Tape Mod R.csv - hobbytalk
#   7HZ TIMELESS OG L.csv - ianfann
#   7HZ TIMELESS OG R.csv - ianfann
#   7Hz Timeless (FINAL Tips) L.csv - iemworld
#   7Hz Timeless (FINAL Tips) R.csv - iemworld
#   7Hz Timeless (Foam Tips) L.csv - iemworld
#   7Hz Timeless (Foam Tips) R.csv - iemworld
#   7Hz Timeless (MoonDroop Tips) L.csv - iemworld
#   7Hz Timeless (MoonDroop Tips) R.csv - iemworld
#   Timeless L.csv - kr0mka
#   Timeless R.csv - kr0mka
#   Oratory 7Hz Timeless L.csv - kurin
#   7hertz Timeless L.csv - melatonin
#   7hertz Timeless R.csv - melatonin
#   7hz Timeless AE L.csv - nymz
#   7hz Timeless AE R.csv - nymz
#   7Hz Timeless S2 25ohm R.csv - pw
#   7Hz Timeless S2 75ohm R.csv - pw
#   7Hz Timeless S2 L.csv - pw
#   7Hz Timeless S2 MPBack L.csv - pw
#   7Hz Timeless S2 MPFront L.csv - pw
#   7Hz Timeless S2 R.csv - pw
#   7Hz Timeless (350 Mesh, stock tuning foam sideways, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (350 Mesh, stock tuning foam, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (Sony Import Foam) L.csv - rg
#   7Hz Timeless (Sony Import Foam, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (Tanchjim Filter, stock tuning foam sideways, Super Thin HS Foam inner vent) L.csv - rg
#   7Hz Timeless (S2) L.csv - data_mrs
#   7Hz Timeless (S2) R.csv - data_mrs
#
# 7Hz Zero L.csv:
#   7Hz Zero L.csv - achoreviews, bedrock, timmyv, data_mrs
#   Tanchjim Zero L.csv - achoreviews, arn, bryaudioreviews, cammyfi, timmyv, suporsalad, data_mrs
#   7HZ SALNOTES ZERO L.csv - aftersound
#   7HZ SALNOTES ZERO R.csv - aftersound
#   7Hz Salnotes Zero L.csv - arn, pw
#   Truthear Zero L.csv - arn, bedrock, hobbytalk, suporsalad, data_mrs
#   Truthear Zero R.csv - arn, bedrock, harpo, hobbytalk, suporsalad, data_mrs
#   7Hz Zero R.csv - bedrock, timmyv, data_mrs
#   HZSound Zero L.csv - bryaudioreviews
#   HZSound Zero R.csv - bryaudioreviews
#   Tanchjim Zero R.csv - bryaudioreviews, cammyfi, timmyv, suporsalad, data_mrs
#   Salnotes Zero L.csv - cammyfi, suporsalad
#   Salnotes Zero R.csv - cammyfi, suporsalad
#   Salnotes ZERO L.csv - eplv
#   Salnotes ZERO R.csv - eplv
#   Tanchjim ZERO L.csv - eplv, jacstone
#   Tanchjim ZERO R.csv - eplv, jacstone
#   Truthear ZERO L.csv - eplv, jacstone
#   Truthear ZERO R.csv - eplv, jacstone
#   Truthears Zero L.csv - timmyv
#   Truthears Zero R.csv - timmyv
#   7Hz Salnotes Zero R.csv - harpo, pw
#   7hz Zero R.csv - hbb, hobbytalk
#   7hz Zero L.csv - hobbytalk
#   7hz Zero Tape L.csv - hobbytalk
#   7hz Zero Tape R.csv - hobbytalk
#   7HZ ZERO L.csv - ianfann
#   7HZ ZERO MECHA L.csv - ianfann
#   7HZ ZERO MECHA R.csv - ianfann
#   7HZ ZERO R.csv - ianfann
#   TANCHJIM ZERO L.csv - ianfann
#   TANCHJIM ZERO R.csv - ianfann
#   TRUTHEAR ZERO L.csv - ianfann
#   TRUTHEAR ZERO R.csv - ianfann
#   7hz Zero (EJ07 FOAM Eartips) L.csv - iemworld
#   7hz Zero (EJ07 FOAM Eartips) R.csv - iemworld
#   7hz Zero (Final Eartips) L.csv - iemworld
#   7hz Zero (Final Eartips) R.csv - iemworld
#   7hz Zero (MoonDrop Eartips) L.csv - iemworld
#   7hz Zero (MoonDrop Eartips) R.csv - iemworld
#   7hz Zero (Red Orignal Eartips) L.csv - iemworld
#   7hz Zero (Red Orignal Eartips) R.csv - iemworld
#   7Hz ZERO S1 L.csv - jacstone
#   7Hz ZERO S1 R.csv - jacstone
#   Oratory 7Hz Salnotes Zero L.csv - kurin
#   Resolve 7hz salnotes zero Gras L.csv - kurin
#   7hz Salnotes Zero L.csv - nymz, vortexreviews
#   7hz Salnotes Zero R.csv - nymz, vortexreviews
#   7hz Salnotes Zero S2 L.csv - nymz
#   7hz Salnotes Zero S2 R.csv - nymz
#   7Hz Salnotes Zero NoGrill L.csv - pw
#   7Hz Salnotes Zero Tape 500Damper R.csv - pw
#   7Hz Salnotes Zero Tape R.csv - pw
#   7Hz Salnotes Zero v2 L.csv - pw
#   7Hz Salnotes Zero v2 R.csv - pw
#   zero L.csv - recode
#   zero R.csv - recode
#
# target:
#   Acho Reviews Target.csv - achoreviews
#   Antdroid Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Bad Guy Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Banbeucmas Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Crinacle Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, timmyv, harpo, hbb, cqtek, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, shortbus, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Diffuse Field Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Etymotic Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Free Field Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Harman Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, iemworld, melatonin, nymz, pw, recode, shortbus, suporsalad, tgx78, vortexreviews, wdym, akros, data_mrs
#   Innerfidelity ID Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Precogvision Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   Rtings Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, kurin, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Sonarworks Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, hbb, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, rg, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros
#   Super Review Target.csv - achoreviews, aftersound, animagus, arn, bedrock, bryaudioreviews, cammyfi, soundjedi, eplv, timmyv, harpo, cqtek, hobbytalk, ianfann, iemworld, kr0mka, melatonin, nymz, pw, recode, shortbus, suporsalad, tgx78, vortexreviews, vsg, wdym, akros, data_mrs
#   IEF neutral Target.csv - aftersound
#   Innerfidelity Target.csv - aftersound
#   Animagus Neutral Target.csv - animagus
#   Animagus Preference Target.csv - animagus
#   Harman In Ear 2019 Target.csv - animagus
#   Harman In Room Target.csv - animagus
#   Harman Over Ear 2018 Target.csv - animagus
#   Harman V2 Target.csv - arn
#   Bry Audio Reviews Target.csv - bryaudioreviews
#   Harman 2017 Target.csv - bryaudioreviews, ianfann
#   Harman 2019 Target.csv - bryaudioreviews, ianfann, jacstone
#   Oratory1990 Target.csv - bryaudioreviews, pw, vortexreviews
#   CammyFi Neutral Target.csv - cammyfi
#   CammyFi Target.csv - cammyfi, kurin
#   Harman IE 2019 v2 Target.csv - cammyfi, kr0mka, kurin
#   Kurin Target.csv - cammyfi, kurin
#   AutoEQ Target.csv - eplv, pw
#   Harman2019v2 Target.csv - eplv
#   Old Crinacle Target.csv - eplv
#   Nymz Target.csv - timmyv
#   Timmy Target.csv - timmyv, kurin
#   AX Target.csv - harpo
#   Bad Guy 2022 Target.csv - harpo, hbb, kurin
#   EJ Target.csv - harpo
#   Harpo Target.csv - harpo, rg
#   Harpo v3 Target.csv - harpo
#   Harpo v4 Target (11.03.2023 02-43-36).csv - harpo
#   Harpo v4 Target.csv - harpo
#   Harpo_v2 Target.csv - harpo
#   RikudouGoku Target.csv - harpo, hbb, jacstone, kurin, nymz, pw, rg, tgx78, vortexreviews, data_mrs
#   Softears Target.csv - harpo
#   X Target.csv - harpo
#   Bad Guy Target v2.csv - hbb
#   IEF Target.csv - hbb, ianfann
#   MRS Target.csv - hbb
#   Precog Target.csv - hbb, kurin
#   Precog_broken Target.csv - hbb
#   Redeyes Target.csv - hbb, kurin, pw
#   Harman IE 2019 Target.csv - hobbytalk
#   Hobby Talk Flat Target.csv - hobbytalk
#   Hobby Talk Preference Target OG.csv - hobbytalk
#   Hobby Talk Preference Target.csv - hobbytalk, kurin
#   Honest Target.csv - hobbytalk
#   IEF OE Target.csv - hobbytalk
#   IanFann-Target Target.csv - ianfann
#   IEF Target1.csv - ianfann
#   IEM WORLD Target.csv - iemworld
#   nymz Target.csv - jacstone, nymz, rg
#   Paul Wasabii Target.csv - jacstone
#   Sharur Target.csv - jacstone, kurin
#   Harman IE 2016 Target.csv - kr0mka, kurin
#   Harman IE 2017 v2 Target.csv - kr0mka
#   kr0mka Target.csv - kr0mka
#   Coda Target.csv - kurin
#   Comfy Target.csv - kurin
#   Flat Target.csv - kurin
#   Freeryder05v2 Target.csv - kurin
#   Hobby Talk Target.csv - kurin
#   markanini Target.csv - kurin
#   Moondrop Target.csv - kurin
#   Normative Target.csv - kurin
#   Objectively Neutral IE Target.csv - kurin
#   Olive-Welti Harman Bass Target.csv - kurin
#   Olive-Welti Target.csv - kurin
#   Oratory IE Target.csv - kurin
#   Rikudogoku Target.csv - kurin
#   SEAP Target.csv - kurin
#   Srg0mes Target.csv - kurin
#   Super 22 Target.csv - kurin, data_mrs
#   Harman 2019v2 Target.csv - nymz, pw, rg
#   RikudouGoku_Target.csv - nymz
#   tgx78 Target.csv - nymz, rg
#   Crackhead Target.csv - pw, rg
#   PaulWasabii Target.csv - pw
#   Crinacle Neutral Target.csv - recode, data_mrs
#   Harman 2017v2 Target.csv - recode, rg
#   Recode Neutral Target.csv - recode
#   Recode Target.csv - recode
#   Recode Warm Neutral Target.csv - recode
#   target 8.csv - recode
#   ALPHA 1.0 Target.csv - rg
#   Amelie Target.csv - rg
#   DynamicEars Target.csv - rg
#   evasb Target.csv - rg
#   Lixeem Target.csv - rg
#   PW Target.csv - rg
#   Resolution Target.csv - rg
#   stakk Target.csv - rg
#   Super Bass Target.csv - rg, data_mrs
#   Super Review 2021 Target.csv - rg
#   Super Review 2022 Target.csv - rg
#   Talbot Target.csv - rg
#   TKSilver Target.csv - rg
#   Redeyes 1 Target.csv - shortbus
#   DF Tilt 711 Ref Target.csv - suporsalad
#   Harman IEM Target.csv - suporsalad
#   Harman OE Target.csv - suporsalad
#   Kemar DF 1.3 Bass Target.csv - suporsalad
#   Kemar DF 1.3 Target.csv - suporsalad
#   Kemar DF Target.csv - suporsalad
#   Listener Target.csv - suporsalad
#   USound1V1 Oratory 1990 Target.csv - suporsalad
#   Tgx78 Target.csv - tgx78
#   Harman 2018 Over-Ear Target.csv - vsg
#   Harman 2019 In-Ear Target.csv - vsg
#   Harman Combined Over-Ear Target.csv - vsg
#   Harman In-Ear Target.csv - vsg
#   VSG Target.csv - vsg
#   Wdym Target.csv - wdym
#   Crinacle 2023 Adjusted Target.csv - data_mrs
#   Crinacle Adjusted Target.csv - data_mrs
#   Crinacle Neutral 2023 Target.csv - data_mrs
#   Dent Target.csv - data_mrs
#   dentReviews Target.csv - data_mrs
#   Ghost Target.csv - data_mrs
#   Harman Adjusted Target.csv - data_mrs
#   HBB Comp Target.csv - data_mrs
#   HPDC 10dB Tilt 5128 DF 100Hz Target.csv - data_mrs
#   HPDC 10dB Tilt 5128 DF Target.csv - data_mrs
#   HPDC 10dB Tilt KEMAR DF 100Hz Target.csv - data_mrs
#   HPDC 10dB Tilt KEMAR DF Target.csv - data_mrs
#   HPDC 14dB Tilt 5128 DF 100Hz Target.csv - data_mrs
#   HPDC 14dB Tilt 5128 DF Target.csv - data_mrs
#   HPDC 14dB Tilt KEMAR DF 100Hz Target.csv - data_mrs
#   HPDC 14dB Tilt KEMAR DF Target.csv - data_mrs
#   IEC711 Comp Target.csv - data_mrs
#   IEF Comp Target.csv - data_mrs
#   Super 21 Target.csv - data_mrs
#   Working 001 Target.csv - data_mrs
#   Working 002 Target.csv - data_mrs
#
# Audeze iSine LX (Spinfit) L.csv:
#   Audeze iSine LX (Spinfit) L.csv - achoreviews
#   Oratory Audeze iSINE 10 L.csv - kurin
#   Oratory Audeze iSINE 20 L.csv - kurin
#
# Aune Jasper L.csv:
#   Aune Jasper L.csv - achoreviews, data_mrs
#   AUNE JASPER L.csv - aftersound
#   AUNE JASPER R.csv - aftersound
#   Aune Jasper R.csv - hbb, data_mrs
#   Aune Jasper (Tanchjim filter) L.csv - data_mrs
#   Aune Jasper (Tanchjim filter) R.csv - data_mrs
#
# Blon BL01 L.csv:
#   Blon BL01 L.csv - achoreviews
#   Blon BL03 L.csv - achoreviews, timmyv, suporsalad, data_mrs
#   BLON BL03 R.csv - aftersound, bryaudioreviews, ianfann
#   BLON BL07 L.csv - aftersound, ianfann, pw
#   BLON BL07 R.csv - aftersound, ianfann, pw
#   BLON BL01 L.csv - bryaudioreviews, pw
#   BLON BL01 R.csv - bryaudioreviews
#   BLON BL03 L.csv - bryaudioreviews, ianfann
#   Blon BL03 R.csv - timmyv, suporsalad
#   Blon BL07 R.csv - harpo
#   BLON 01 R.csv - hbb
#   Blon BL50 R.csv - hbb
#   Blon BL-01 L.csv - cqtek, rg, vortexreviews
#   Blon BL-01 R.csv - cqtek
#   BLON BL01v2 L.csv - pw
#   BLON BL05 L.csv - pw
#   Blon BL05 L.csv - data_mrs
#
# Blon BL03 L.csv:
#   BLON BL-03 L.csv - eplv, jacstone
#   BLON BL-03 R.csv - eplv, jacstone
#   Blon BL-03 L.csv - harpo, cqtek, hobbytalk, nymz, vortexreviews
#   BLON 03 R.csv - hbb
#   Blon BL-03 R.csv - cqtek, hobbytalk, nymz
#   BLON BL03 Filter L.csv - pw
#   BLON BL03 Stock L.csv - pw
#
# Blon BL05s L.csv:
#   Blon BL05s L.csv - achoreviews
#   Blon BL-05S L.csv - bedrock, vortexreviews
#   Blon BL-05S R.csv - bedrock
#   BLON BL05S L.csv - pw
#   BLON BL05Sv2 L.csv - pw
#   BLON BL05v2 L.csv - pw
#
# Blon Fat Girl L.csv:
#   Blon Fat Girl L.csv - achoreviews, vortexreviews
#   BLON FAT GIRL L.csv - aftersound, ianfann
#   BLON FAT GIRL R.csv - aftersound, ianfann
#   BLON FatGirl9 L.csv - eplv
#   BLON FatGirl9 R.csv - eplv
#   BLON Fat Girl R.csv - hbb, jacstone, pw
#   BLON Fat Girl L.csv - jacstone, pw
#   Blon Fat Girl R.csv - vortexreviews
#
# Blon T1 L.csv:
#   Blon T1 L.csv - achoreviews
#   Blon T3 L.csv - achoreviews
#
# Blon Z200 L.csv:
#   Blon Z200 L.csv - achoreviews, harpo, vortexreviews
#   BLON Z200 L.csv - arn, ianfann, pw
#   Blon Z200 R.csv - harpo, vortexreviews
#   BLON Z200 R.csv - ianfann, pw
#
# CCA CRA L.csv:
#   CCA CRA L.csv - achoreviews, aftersound, eplv, hobbytalk, ianfann, jacstone, melatonin, nymz, pw, rg, suporsalad, tgx78, vortexreviews, data_mrs
#   CCA CRA Plus L.csv - achoreviews, timmyv, pw, data_mrs
#   CCA CRA R.csv - aftersound, eplv, harpo, hbb, hobbytalk, ianfann, jacstone, melatonin, nymz, pw, rg, suporsalad, data_mrs
#   CCA CRA S2 L.csv - aftersound, nymz, rg, tgx78
#   CCA CRA S2 R.csv - aftersound, nymz, rg, tgx78
#   CCA CRA+ L.csv - aftersound, bedrock, ianfann, jacstone, melatonin, nymz, rg, vortexreviews
#   CCA CRA+ R.csv - aftersound, bedrock, ianfann, jacstone, melatonin, nymz, rg, vortexreviews
#   CCA NRA L.csv - aftersound, eplv, hobbytalk, ianfann, iemworld, melatonin, pw, vortexreviews
#   CCA NRA R.csv - aftersound, eplv, hbb, hobbytalk, ianfann, iemworld, melatonin
#   CCA CRA Plus R.csv - timmyv, data_mrs
#   CCA CRA + R.csv - hbb
#   CCA CRA+ (STOCK TIPS) L.csv - ianfann
#   CCA CRA+ (STOCK TIPS) R.csv - ianfann
#   CRA L.csv - kr0mka
#   CRA R.csv - kr0mka
#   CCA CRA EQ3 R.csv - nymz
#   CCA CA2 L.csv - pw, vortexreviews
#   CCA CRA Plus Tape L.csv - pw
#   CCA CRA Plus Vent L.csv - pw
#   CCA CRA Plus Vent R.csv - pw
#   CCA CRA (1dividedby4 Foam) L.csv - rg
#   CCA CRA (1dividedby8 Foam) L.csv - rg
#   CCA CRA (200 Mesh) L.csv - rg
#   CCA CRA (350 Mesh) L.csv - rg
#   CCA CRA (500 Mesh + 200 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 250 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 300 Paper Filter + High-Density Tuning Foam) L.csv - rg
#   CCA CRA (500 Mesh + 300 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 350 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + 500 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + High-Density Tuning Foam) L.csv - rg
#   CCA CRA (500 Mesh + Sony General Foam) L.csv - rg
#   CCA CRA (500 Mesh + Y1 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + Y3 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh + Y6 Paper Filter) L.csv - rg
#   CCA CRA (500 Mesh) L.csv - rg
#   CCA CRA (Filterless + 2 High-Density Tuning Foams) L.csv - rg
#   CCA CRA (Filterless + High-Density Tuning Foams) L.csv - rg
#   CCA CRA (Filterless) L.csv - rg
#   CCA CRA (Nylon filter) L.csv - rg
#   CCA CRA (Sony General Foam) L.csv - rg
#   CCA CRA (Sony Import Foam) L.csv - rg
#   CCA CRA (Tanchjim Filter) L.csv - rg
#   CCA CRA+ (Stock Filter + 350 Mesh) L.csv - rg
#   CCA NRA (0.15ohm) L.csv - rg
#   CCA NRA (0.66ohm) L.csv - rg
#   CCA NRA (0.66ohm) R.csv - rg
#   CCA CRA EQ L.csv - tgx78
#   CCA CRA Mod R.csv - tgx78
#   CCA CSA L.csv - vortexreviews
#
# CCZ Emerald L.csv:
#   CCZ Emerald L.csv - achoreviews, eplv
#   CCZ EMERALD L.csv - aftersound
#   CCZ EMERALD R.csv - aftersound
#   CCZ Emerald R.csv - eplv
#   CCZ emerald L.csv - melatonin
#   CCZ emerald R.csv - melatonin
#
# CCZ Melody L.csv:
#   CCZ Melody L.csv - achoreviews, pw, vortexreviews
#   CCZ MELODY L.csv - aftersound, ianfann
#   CCZ MELODY R.csv - aftersound, ianfann
#   CCZ Melody R.csv - harpo
#   CCZ melody L.csv - melatonin
#   CCZ melody R.csv - melatonin
#
# CCZ Warrior L.csv:
#   CCZ Warrior L.csv - achoreviews, arn, pw
#   CCZ WARRIOR L.csv - ianfann
#   CCZ WARRIOR R.csv - ianfann
#   CCZ Warrior R.csv - pw
#
# Celest Pandamon L.csv:
#   Celest Pandamon L.csv - achoreviews
#   Kinera Celest Pandamon L.csv - arn, cqtek, vortexreviews
#   Kinera Celest Pandamon R.csv - arn, cqtek, vortexreviews
#
# Dunu Kima L.csv:
#   Dunu Kima L.csv - achoreviews, bedrock, timmyv, cqtek, vortexreviews, data_mrs
#   DUNU KIMA L.csv - aftersound, ianfann, nymz, vsg
#   DUNU KIMA R.csv - aftersound, ianfann, nymz, vsg
#   Dunu Kima R.csv - bedrock, timmyv, hbb, cqtek, vortexreviews, data_mrs
#
# Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv:
#   Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv - achoreviews
#   Dunu Talos (Planar + BA) L.csv - achoreviews
#   Dunu Talos (Planar Only) (IE600 Foam Tips) L.csv - achoreviews
#   Dunu Talos (Planar Only) L.csv - achoreviews
#   DUNU TALOS OFF L.csv - aftersound
#   DUNU TALOS OFF R.csv - aftersound
#   DUNU TALOS ON L.csv - aftersound
#   DUNU TALOS ON R.csv - aftersound
#   Dunu Talos (ON) L.csv - animagus
#   Dunu Talos (ON) R.csv - animagus
#   Dunu Talos L.csv - animagus, data_mrs
#   Dunu Talos R.csv - animagus, hbb, data_mrs
#   DUNU Talos Planar L.csv - arn
#   DUNU Talos Planar+BA L.csv - arn
#   Dunu Talos (Switch Off) L.csv - bedrock
#   Dunu Talos (Switch Off) R.csv - bedrock
#   Dunu Talos (Switch On) L.csv - bedrock
#   Dunu Talos (Switch On) R.csv - bedrock
#   Dunu Talos (Hybrid) L.csv - timmyv
#   Dunu Talos (Hybrid) R.csv - timmyv
#   Dunu Talos (Planar) L.csv - timmyv
#   Dunu Talos (Planar) R.csv - timmyv
#   Dunu Talos BA R.csv - hbb
#   DUNU TALOS PLANAR MODE L.csv - ianfann
#   DUNU TALOS PLANAR MODE R.csv - ianfann
#   DUNU TALOS PLANAR+BA L.csv - ianfann
#   DUNU TALOS PLANAR+BA R.csv - ianfann
#   DUNU TALOS Hybrid L.csv - nymz, vsg
#   DUNU TALOS Hybrid R.csv - nymz, vsg
#   DUNU TALOS L.csv - nymz
#   DUNU TALOS R.csv - nymz
#   DUNU Talos L.csv - pw
#   DUNU Talos R.csv - pw
#   DUNU TALOS Hybrid mode L.csv - vsg
#   DUNU TALOS Hybrid mode R.csv - vsg
#   DUNU TALOS Planar L.csv - vsg
#   DUNU TALOS Planar mode L.csv - vsg
#   DUNU TALOS Planar mode R.csv - vsg
#   DUNU TALOS Planar R.csv - vsg
#   Dunu Talos (on) L.csv - data_mrs
#   Dunu Talos (on) R.csv - data_mrs
#   Dunu Talos (S2 off) L.csv - data_mrs
#   Dunu Talos (S2 off) R.csv - data_mrs
#   Dunu Talos (S2 on) L.csv - data_mrs
#   Dunu Talos (S2 on) R.csv - data_mrs
#
# Dunu Titan S (Isolation) L.csv:
#   Dunu Titan S (Isolation) L.csv - achoreviews
#   Dunu Titan S L.csv - achoreviews, bedrock, bryaudioreviews, timmyv, cqtek, nymz, rg, vortexreviews
#   DUNU TITAN 5 L.csv - aftersound
#   DUNU TITAN 5 R.csv - aftersound
#   DUNU TITAN S L.csv - aftersound, ianfann, iemworld, vsg
#   DUNU TITAN S R.csv - aftersound, ianfann, iemworld, vsg
#   DUNU Titan S L.csv - arn
#   DUNU Titan S R.csv - arn
#   Dunu Titan S R.csv - bedrock, bryaudioreviews, timmyv, hbb, cqtek, nymz, rg
#   Resolve Dunu Titan S Foam Gras L.csv - kurin
#   Resolve Dunu Titan S Foam Silicone L.csv - kurin
#   DUNU Titan L.csv - pw
#   DUNU Titan R.csv - pw
#   DUNU Titan Tanya L.csv - pw
#   Dunu Titan S (500 Mesh) L.csv - rg
#   Dunu Titan S (Tanchjim Filter) L.csv - rg
#   Dunu Titan S (Y3 Paper Filter) L.csv - rg
#   Dunu Titan S (Y6 Paper Filter) L.csv - rg
#   Dunu Titans L.csv - suporsalad
#   Dunu Titans R.csv - suporsalad
#   DUNU TITAN S pre-production L.csv - vsg
#   DUNU TITAN S pre-production R.csv - vsg
#   Dunu Titan S (pre) L.csv - data_mrs
#   Dunu Titan S (pre) R.csv - data_mrs
#
# Dunu Vulkan L.csv:
#   Dunu Vulkan L.csv - achoreviews, bedrock, timmyv, harpo, data_mrs
#   Dunu Vulkan R.csv - bedrock, timmyv, harpo, hbb, data_mrs
#   DUNU Vulkan L.csv - nymz
#   DUNU Vulkan R.csv - nymz
#   Dunu VULKAN L.csv - rg
#   Dunu VULKAN R.csv - rg
#   DUNU VULKAN L.csv - vsg
#   DUNU VULKAN R.csv - vsg
#   Dunu Vulka (S2 + red) L.csv - data_mrs
#   Dunu Vulkan (S2 + red) R.csv - data_mrs
#   Dunu Vulkan (S2) L.csv - data_mrs
#   Dunu Vulkan (S2) R.csv - data_mrs
#
# Effect Audio Axiom L.csv:
#   Effect Audio Axiom L.csv - achoreviews, vsg, data_mrs
#   Effect Audio GAEA L.csv - bryaudioreviews
#   Effect Audio GAEA R.csv - bryaudioreviews
#   Effect Audio Axiom R.csv - vsg, data_mrs
#   Effect Audio Gaea (deep) L.csv - data_mrs
#   Effect Audio Gaea (deep) R.csv - data_mrs
#   Effect Audio Gaea L.csv - data_mrs
#   Effect Audio Gaea R.csv - data_mrs
#
# Fiio FHE Eclipse L.csv:
#   Fiio FHE Eclipse L.csv - achoreviews
#   FiiO FHE L.csv - timmyv, melatonin
#   FiiO FHE R.csv - timmyv, melatonin
#   FIIO x Crinacle FHE Eclipse (Foam Eartips) L.csv - iemworld
#   FIIO x Crinacle FHE Eclipse (Foam Eartips) R.csv - iemworld
#   FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) L.csv - iemworld
#   FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) R.csv - iemworld
#   FiiO FHE S1 L.csv - jacstone
#   FiiO FHE S1 R.csv - jacstone
#   FiiO FHE S2 L.csv - jacstone
#   FiiO FHE S2 R.csv - jacstone
#   Fiio FHE (franken) L.csv - data_mrs
#   Fiio FHE (franken) R.csv - data_mrs
#   Fiio FHE (S2) L.csv - data_mrs
#   Fiio FHE (S2) R.csv - data_mrs
#   Fiio FHE L.csv - data_mrs
#   Fiio FHE R.csv - data_mrs
#
# Final Audio E500 L.csv:
#   Final Audio E500 L.csv - achoreviews, rg
#   FINAL AUDIO A4000 L.csv - aftersound
#   FINAL AUDIO A4000 R.csv - aftersound
#   Final Audio B3 L.csv - bryaudioreviews
#   Final Audio B3 R.csv - bryaudioreviews
#   Final Audio e5000 L.csv - bryaudioreviews
#   Final Audio e5000 R.csv - bryaudioreviews
#   final E500 L.csv - eplv
#   final E500 R.csv - eplv
#   Final Audio E3000 R.csv - harpo, hobbytalk
#   Final Audio E1000 (S2) L.csv - hobbytalk
#   Final Audio E1000 (S2) R.csv - hobbytalk
#   Final Audio E1000 L.csv - hobbytalk, nymz, rg
#   Final Audio E1000 R.csv - hobbytalk, nymz
#   Final Audio E3000 (S2) L.csv - hobbytalk
#   Final Audio E3000 (S2) R.csv - hobbytalk
#   Final Audio E3000 L.csv - hobbytalk, rg
#   Oratory Final Audio E500 L.csv - kurin
#   Final Audio A4000 L.csv - nymz
#   Final Audio A4000 R.csv - nymz
#   Final Audio A4000 V2 L.csv - nymz
#   Final Audio A4000 V2 R.csv - nymz
#   Final Audio VR3000 L.csv - nymz, rg
#   Final Audio VR3000 R.csv - nymz, rg
#   Final E500 L.csv - pw, akros, data_mrs
#   Final Audio E1000 (Micropore mod) L.csv - rg
#   Final Audio E2000 L.csv - rg
#   Final Audio E4000 L.csv - rg
#   Final Audio E500 R.csv - rg
#   Final Audio E5000 L.csv - rg
#   Final Audio F3100 L.csv - rg
#   Final Audio FI-EVA2020 L.csv - rg
#
# Hidition Violet L.csv:
#   Hidition Violet L.csv - achoreviews, soundjedi, cqtek, data_mrs
#   Hidition Violet R.csv - soundjedi
#
# Hifiman RE600s v2 L.csv:
#   Hifiman RE600s v2 L.csv - achoreviews
#   Oratory HIFIMAN RE600S L.csv - kurin
#   Hifiman RE600 V2 L.csv - nymz
#   Hifiman RE600 V2 R.csv - nymz
#
# Hifiman Svanar L.csv:
#   Hifiman Svanar L.csv - achoreviews
#   HIFIMAN Svanar L.csv - vsg
#   HIFIMAN Svanar R.csv - vsg
#   HIFIMAN Svanar S2 L.csv - vsg
#   HIFIMAN Svanar S2 R.csv - vsg
#   HIFIMAN Svanar S3 L.csv - vsg
#   HIFIMAN Svanar S3 R.csv - vsg
#
# Hifiman TWS800 L.csv:
#   Hifiman TWS800 L.csv - achoreviews
#   HIFIMAN TWS800 L.csv - ianfann, vsg
#   HIFIMAN TWS800 R.csv - ianfann, vsg
#
# HZ Sound Heart Mirror Pro L.csv:
#   HZ Sound Heart Mirror Pro L.csv - achoreviews
#   HZSOUND HEART MIRROR L.csv - aftersound
#   HZSOUND HEART MIRROR R.csv - aftersound
#   Heart Mirror Pro L.csv - arn
#   Heart Mirror L.csv - bryaudioreviews
#   Heart Mirror R.csv - bryaudioreviews
#   HZSound Heart Mirror Pro L.csv - harpo
#   HZSound Heart Mirror Pro R.csv - harpo
#   HZSOUND Heart Mirror R.csv - harpo, nymz, vortexreviews
#   HZ sound pro R.csv - hbb
#   Hz Sound Zero R.csv - hbb
#   HZ SOUND HEART MIRROR L.csv - ianfann
#   HZ SOUND HEART MIRROR PRO L.csv - ianfann
#   HZ SOUND HEART MIRROR PRO R.csv - ianfann
#   HZ SOUND HEART MIRROR R.csv - ianfann
#   HZSOUND Heart Mirror L.csv - nymz, vortexreviews
#   HZSOUND Heart Mirror Pro L.csv - nymz
#   HZSOUND Heart Mirror Pro R.csv - nymz
#   HZSound Heart Mirror L.csv - data_mrs
#
# Ikko Opal OH02 L.csv:
#   Ikko Opal OH02 L.csv - achoreviews
#   IKKO OPAL OH2 L.csv - arn
#   Ikko Opal OH2 L.csv - data_mrs
#   Ikko Opal OH2 R.csv - data_mrs
#
# ITK Unknown L.csv:
#   ITK Unknown L.csv - achoreviews
#
# Joyodio Shine (0000) L.csv:
#   Joyodio Shine (0000) L.csv - achoreviews
#   Joyodio Shine (0010) L.csv - achoreviews
#   Joyodio Shine (0100) L.csv - achoreviews
#   Joyodio Shine (0110) L.csv - achoreviews
#   Joyodio Shine (1000) L.csv - achoreviews
#   Joyodio Shine (1010) L.csv - achoreviews
#   Joyodio Shine (1100) L.csv - achoreviews
#   Joyodio Shine (1110) L.csv - achoreviews
#   JOYODIO SHINE 1 ON R.csv - aftersound
#   JOYODIO SHINE 2 ON R.csv - aftersound
#   JOYODIO SHINE 3 ON R.csv - aftersound
#   JOYODIO SHINE 4 ON R.csv - aftersound
#   JOYODIO SHINE ALL OFF L.csv - aftersound
#   JOYODIO SHINE ALL OFF R.csv - aftersound
#   JOYODIO SHINE ALL ON R.csv - aftersound
#   Joyaudio Shine R.csv - hbb
#   Joyodio Shine 0000 L.csv - cqtek
#   Joyodio Shine 0000 R.csv - cqtek
#   Joyodio Shine 0001 L.csv - cqtek
#   Joyodio Shine 0001 R.csv - cqtek
#   Joyodio Shine 0011 L.csv - cqtek
#   Joyodio Shine 0011 R.csv - cqtek
#   Joyodio Shine 0111 L.csv - cqtek
#   Joyodio Shine 0111 R.csv - cqtek
#   Joyodio Shine 1000 L.csv - cqtek
#   Joyodio Shine 1000 R.csv - cqtek
#   Joyodio Shine 1001 L.csv - cqtek
#   Joyodio Shine 1001 R.csv - cqtek
#   Joyodio Shine 1010 L.csv - cqtek
#   Joyodio Shine 1010 R.csv - cqtek
#   Joyodio Shine 1011 L.csv - cqtek
#   Joyodio Shine 1011 R.csv - cqtek
#   Joyodio Shine 1100 L.csv - cqtek
#   Joyodio Shine 1100 R.csv - cqtek
#   Joyodio Shine 1110 L.csv - cqtek
#   Joyodio Shine 1110 R.csv - cqtek
#   Joyodio Shine 1111 L.csv - cqtek
#   Joyodio Shine 1111 R.csv - cqtek
#   JOYODIO SHINE CLASSICAL L.csv - ianfann
#   JOYODIO SHINE CLASSICAL R.csv - ianfann
#   JOYODIO SHINE HIFI L.csv - ianfann
#   JOYODIO SHINE HIFI R.csv - ianfann
#   JOYODIO SHINE POP L.csv - ianfann
#   JOYODIO SHINE POP R.csv - ianfann
#   JOYODIO SHINE RNB ROCK L.csv - ianfann
#   JOYODIO SHINE RNB ROCK R.csv - ianfann
#   JOYODIO SHINE STANDARD L.csv - ianfann
#   JOYODIO SHINE STANDARD R.csv - ianfann
#   Joyodio Shine Classical R.csv - vortexreviews
#   Joyodio Shine HIFI R.csv - vortexreviews
#   Joyodio Shine POP R.csv - vortexreviews
#   Joyodio Shine R&B Rock R.csv - vortexreviews
#   Joyodio Shine Standard R.csv - vortexreviews
#
# KBEAR Lark (S1) L.csv:
#   KBEAR Lark (S1) L.csv - achoreviews
#   KBEAR Lark (S2) L.csv - achoreviews
#   KBEAR Lark L.csv - bedrock, eplv, cqtek, melatonin
#   KBEAR Lark R.csv - bedrock, eplv, cqtek, melatonin
#   Kbear Q R.csv - hbb
#   KBEAR Lark4k L.csv - pw
#
# KBEAR Little Q L.csv:
#   KBEAR Little Q L.csv - achoreviews, arn
#   KBEar Little Q L.csv - bryaudioreviews
#   KBEar Little Q R.csv - bryaudioreviews
#   KBEAR LITTLE Q L.csv - ianfann
#   KBEAR LITTLE Q R.csv - ianfann
#   KBEAR LittleQ L.csv - pw
#   KBEAR LittleQ R.csv - pw
#
# KBEAR Qinglong L.csv:
#   KBEAR Qinglong L.csv - achoreviews, arn
#   KBEAR QINGLONG L.csv - aftersound, ianfann
#   KBEAR QINGLONG R.csv - aftersound, ianfann
#   KBEAR Qinglong R.csv - arn
#
# KBEAR Robin L.csv:
#   KBEAR Robin L.csv - achoreviews, cqtek, melatonin, pw, rg
#   KBEAR Robin R.csv - cqtek, melatonin, rg
#
# Kinera BD005 Pro L.csv:
#   Kinera BD005 Pro L.csv - achoreviews, bedrock
#   KINERA BD005 PRO R.csv - aftersound
#   Kinera BD005 Pro R.csv - bedrock
#   Kinera BD005 R.csv - hbb
#   Kinera BD005Pro L.csv - pw
#
# Kiwi Ears Cadenza L.csv:
#   Kiwi Ears Cadenza L.csv - achoreviews, bedrock, cammyfi, hobbytalk, vortexreviews, data_mrs
#   KIWI EARS CADENZA L.csv - aftersound
#   KIWI EARS CADENZA R.csv - aftersound
#   Kiwi Ears CADENZA L.csv - arn
#   Kiwi Ears CADENZA R.csv - arn
#   Kiwi Ears Cadenza R.csv - bedrock, cammyfi, harpo, hbb, hobbytalk, vortexreviews, data_mrs
#   Kiwi Cadenza L.csv - timmyv
#   Kiwi Cadenza R.csv - timmyv
#   Kiwi Ears New R.csv - hbb
#   Kiwi Ears R.csv - hbb
#
# Kiwi Ears Orchestra Lite L.csv:
#   Kiwi Ears Orchestra Lite L.csv - achoreviews, bedrock, nymz, pw, rg, vortexreviews, vsg, data_mrs
#   Kiwi Ears Orchestra Lite R.csv - bedrock, nymz, pw, rg, vortexreviews, vsg, data_mrs
#   Kiwi Orchestra L.csv - timmyv
#   Kiwi Orchestra Lite L.csv - timmyv
#   Kiwi Orchestra Lite R.csv - timmyv
#   Kiwi Orchestra R.csv - timmyv
#   Kiwi Ears Orchestra Lite (2.5mm 500 mesh on green bore) L.csv - rg
#   Kiwi Ears Orchestra Lite (2.5mm 500 mesh on white bore) L.csv - rg
#   Kiwi Ears Orchestra Lite (2.5mm 500 mesh on yellow bore) L.csv - rg
#   Kiwi Ears Orchestra Lite (25ohm) L.csv - rg
#   Kiwi Ears Orchestra Lite deep fit L.csv - vsg
#   Kiwi Ears Orchestra Lite deep fit R.csv - vsg
#   Kiwi Ears Orchestra (E-type TWS) L.csv - data_mrs
#   Kiwi Ears Orchestra (E-type TWS) R.csv - data_mrs
#   Kiwi Ears Orchestra (Sedna Short) L.csv - data_mrs
#   Kiwi Ears Orchestra (Sedna Short) R.csv - data_mrs
#   Kiwi Ears Orchestra L.csv - data_mrs
#   Kiwi Ears Orchestra R.csv - data_mrs
#
# Koss KEB90 L.csv:
#   Koss KEB90 L.csv - achoreviews, data_mrs
#   KOSS KEB90 L.csv - hobbytalk
#   KOSS KEB90 R.csv - hobbytalk
#   Koss KEB90 R.csv - data_mrs
#
# KZ AS16 Pro L.csv:
#   KZ AS16 Pro L.csv - achoreviews, melatonin, pw, vortexreviews
#   KZ AS16 PRO L.csv - aftersound, ianfann
#   KZ AS16 PRO R.csv - aftersound, ianfann
#   KZ AS16 L.csv - eplv, melatonin
#   KZ AS16 R.csv - eplv, melatonin
#   KZ AS16Pro L.csv - eplv
#   KZ AS16Pro R.csv - eplv
#   KZ AS16Pro22 L.csv - eplv
#   KZ AS16Pro22 R.csv - eplv
#   KZ AS16 Pro R.csv - hbb, melatonin, pw, vortexreviews
#   KZ AS16 200Ω R.csv - melatonin
#   KZ AS16 30ohm R.csv - melatonin
#   KZ AS16 75Ω R.csv - melatonin
#   KZ AS16 Pro 200Ω R.csv - melatonin
#   KZ AS16 Pro 30Ω R.csv - melatonin
#   KZ AS16 Pro 75Ω R.csv - melatonin
#   KZ AS16 Pro 25ohm L.csv - pw
#   KZ AS16 Pro BTX L.csv - pw
#   KZ AS16 Pro TK2 L.csv - pw
#   KZ (avg) L.csv - data_mrs
#
# KZ ATE L.csv:
#   KZ ATE L.csv - achoreviews, data_mrs
#   KZ ATR L.csv - eplv
#   KZ ATR R.csv - eplv, melatonin
#   KZ AST L.csv - harpo, melatonin, data_mrs
#   KZ AST R.csv - hbb, melatonin
#   Oratory KZ ATE L.csv - kurin
#   KZ ATE R.csv - data_mrs
#
# KZ DQ6 L.csv:
#   KZ DQ6 L.csv - achoreviews, eplv, ianfann, jacstone, melatonin, nymz, pw, rg, data_mrs
#   KZ DQ6s L.csv - achoreviews, melatonin, nymz
#   KZ DQS L.csv - achoreviews, ianfann, pw
#   KZ DQ6 R.csv - aftersound, eplv, hbb, ianfann, jacstone, melatonin, nymz, vortexreviews, data_mrs
#   KZ DQ6S L.csv - aftersound, bedrock, ianfann, jacstone, pw, rg
#   KZ DQ6S R.csv - aftersound, bedrock, harpo, ianfann, jacstone, pw, rg
#   KZ DQ6 5 R.csv - hbb
#   KZ DQ6 R Xf R.csv - hbb
#   KZ DQ6 X HBB R.csv - hbb
#   KZ DQ6 X R.csv - hbb
#   KZ DQ6 X2 R.csv - hbb
#   KZ DQ6 X5 R.csv - hbb
#   KZ DQ6 Xl R.csv - hbb
#   KZ DQS R.csv - ianfann, pw, vortexreviews
#   KZ DQ6s R.csv - melatonin, nymz
#   KZ DQ6v2 L.csv - pw
#   KZ DQ6 (1dividedby16 foam) L.csv - rg
#   KZ DQ6 (Hana Filter) L.csv - rg
#   KZ DQ6 (High-Density Tuning Foam + cotton filter) L.csv - rg
#   KZ DQ6 (High-Density Tuning Foam) L.csv - rg
#   KZ DQ6 (Low-Density Tuning Foam) L.csv - rg
#   KZ DQ6 (Micropore Tape Mod) L.csv - rg
#   KZ DQ6 (Micropore tape+ 1dividedby16foam Mod) L.csv - rg
#   KZ DQ6 (Micropore Tips) L.csv - rg
#   KZ DQ6 (Micropore+ 1dividedby16foam Tips) L.csv - rg
#   KZ DQ6 (O2 Filter) L.csv - rg
#   KZ DQ6 (Sony Import Foam) L.csv - rg
#   KZ DQ6 (Tanchjim filter) L.csv - data_mrs
#   KZ DQ6 (Tanchjim filter) R.csv - data_mrs
#
# KZ DQ6s L.csv:
#   KZ HBB DQ6S L.csv - iemworld
#   KZ HBB DQ6S R.csv - iemworld
#   KZ DQ6Sv2 L.csv - pw
#   KZ DQ6Sv3 L.csv - pw
#   KZ DQ6Sv3 R.csv - pw
#   KZ x HBB DQ6S L.csv - vortexreviews, vsg
#   KZ x HBB DQ6S R.csv - vortexreviews, vsg
#
# KZ DQS L.csv:
#   KZ EDS L.csv - jacstone, melatonin, pw
#   KZ EDS R.csv - jacstone, melatonin, pw
#
# KZ ED16 L.csv:
#   KZ ED16 L.csv - achoreviews
#   KZ EDR1 L.csv - rg
#
# KZ EDX L.csv:
#   KZ EDX L.csv - achoreviews, eplv, jacstone, melatonin, pw, vortexreviews
#   KZ EDX Pro L.csv - achoreviews, melatonin, pw, rg, vortexreviews, data_mrs
#   KZ ZEX L.csv - achoreviews, bryaudioreviews, ianfann, iemworld, jacstone, melatonin, suporsalad, tgx78, vortexreviews, data_mrs
#   KZ EDX PRO L.csv - aftersound, jacstone
#   KZ EDX PRO R.csv - aftersound, hbb, jacstone
#   KZ EDX R.csv - aftersound, eplv, jacstone, melatonin, vortexreviews
#   KZ EDX ULTRA L.csv - aftersound, ianfann
#   KZ EDX ULTRA R.csv - aftersound, ianfann
#   KZ ESX L.csv - arn, harpo, ianfann, jacstone, melatonin, pw
#   KZ ZEX R.csv - bryaudioreviews, hbb, ianfann, iemworld, jacstone, melatonin, suporsalad, data_mrs
#   KZ ESX R.csv - harpo, hbb, ianfann, jacstone, melatonin, pw, vortexreviews
#   KZ Edcx R.csv - hbb
#   KZ EDA (GOLD) L.csv - ianfann
#   KZ EDA (GOLD) R.csv - ianfann
#   KZ EDA (GREEN) L.csv - ianfann
#   KZ EDA (GREEN) R.csv - ianfann
#   KZ EDA (SILVER) L.csv - ianfann
#   KZ EDA (SILVER) R.csv - ianfann
#   KZ EDCX L.csv - ianfann, suporsalad
#   KZ EDCX R.csv - ianfann, suporsalad
#   KZ EDX Ultra L.csv - jacstone, pw, rg, vortexreviews
#   KZ EDX Ultra R.csv - jacstone, pw, rg, vortexreviews
#   KZ EDC L.csv - melatonin, pw
#   KZ EDC R.csv - melatonin, pw
#   KZ EDX Pro R.csv - melatonin, pw, rg, data_mrs
#   KZ EDXv2 L.csv - pw
#   KZ ED9 (Balanced filter) L.csv - rg
#   KZ EDX Pro (2 Low-Density Tuning Foams) L.csv - rg
#   KZ EDX Pro (High-Density Tuning Foam) L.csv - rg
#   KZ EDX Pro (Low-Density Tuning Foam) L.csv - rg
#   KZ ZEX (vent blocked) L.csv - data_mrs
#
# KZ EDX Pro L.csv:
#   KZ ZEX Pro L.csv - achoreviews, pw, rg, vortexreviews, data_mrs
#   KZ ZEX PRO L.csv - aftersound, ianfann, jacstone
#   KZ ZEX PRO R.csv - aftersound, hbb, ianfann, jacstone
#   KZ ZEX Pro R.csv - pw, rg, vortexreviews, data_mrs
#   KZ ZEX Pro (30ohm) L.csv - rg
#   KZ Zex Pro L.csv - tgx78
#   KZ Zex Pro R.csv - tgx78
#
# KZ PR1 L.csv:
#   KZ PR1 L.csv - achoreviews, timmyv, ianfann
#   KZ PR1 HiFi L.csv - arn
#   KZ PR1 HiFi R.csv - arn
#   KZ PR1 Pro L.csv - arn, pw, data_mrs
#   KZ PR1 Pro R.csv - arn, pw, data_mrs
#   KZ PR1 R.csv - timmyv, hbb, ianfann
#   KZ PR1 Balanced L.csv - harpo
#   KZ PR1 PRO L.csv - ianfann
#   KZ PR1 PRO R.csv - ianfann
#   KZ PR1 STOCK TIPS L.csv - ianfann
#   KZ PR1 STOCK TIPS R.csv - ianfann
#   KZ PR1 Balanced version R.csv - melatonin
#   KZ PR1 HiFi version form R.csv - melatonin
#   KZ PR1 HiFi version R.csv - melatonin
#   KZ PR1 Hifi L.csv - vortexreviews
#   KZ PR1 Hifi R.csv - vortexreviews
#
# KZ ZAX L.csv:
#   KZ ZAX L.csv - achoreviews, melatonin, pw, vortexreviews
#   KZ ZVX L.csv - achoreviews, aftersound, timmyv, ianfann, pw
#   KZ ZVX R.csv - aftersound, timmyv, harpo, ianfann
#   KZ ZAS L.csv - eplv, ianfann, melatonin, pw, vortexreviews
#   KZ ZAS R.csv - eplv, hbb, ianfann, melatonin, pw
#   KZ ZSX L.csv - eplv, melatonin, pw, vortexreviews
#   KZ ZSX R.csv - eplv, melatonin, vortexreviews
#   KZ ASX R.csv - hbb, vortexreviews
#   KZ ZAX R.csv - hbb, melatonin
#   Kz Zvx R.csv - hbb
#   KZ ZAR L.csv - ianfann, pw, vortexreviews
#   KZ ZAR R.csv - ianfann, pw, vortexreviews
#   KZ ZNA L.csv - ianfann, pw, vortexreviews
#   KZ ZNA R.csv - ianfann, pw, vortexreviews
#   KZ ASX L.csv - pw, data_mrs
#   KZ ZAXv2 L.csv - pw
#
# KZ ZES L.csv:
#   KZ ZES L.csv - achoreviews, aftersound, ianfann, pw, rg, vortexreviews
#   KZ ZSN L.csv - achoreviews, eplv, melatonin, pw
#   KZ ZES R.csv - aftersound, ianfann, rg, vortexreviews
#   KZ ES4 L.csv - eplv, melatonin, pw
#   KZ ES4 R.csv - eplv, melatonin
#   KZ ZS4 L.csv - eplv, rg
#   KZ ZS4 R.csv - eplv
#   KZ ZS5 L.csv - eplv, melatonin
#   KZ ZS5 R.csv - eplv, melatonin
#   KZ ZS6 L.csv - eplv, melatonin, rg
#   KZ ZS6 R.csv - eplv, melatonin
#   KZ ZSN R.csv - eplv, hbb, melatonin
#   KZ ZSR L.csv - eplv, pw
#   KZ ZSR R.csv - eplv
#   KZ ZST R.csv - hbb, melatonin
#   KZ ZS7 L.csv - melatonin, rg, data_mrs
#   KZ ZS7 R.csv - melatonin
#   KZ ZST L.csv - melatonin, pw
#   KZ ZS7 (1dividedby16 foam) L.csv - rg
#   KZ ZSE L.csv - rg
#
# KZ ZEX L.csv:
#   Resolve KZ Zex Pro CRN Gras L.csv - kurin
#   KZ ZEX Pro Taped L.csv - pw
#   KZ ZEX Stock L.csv - pw
#   KZ ZEX Taped L.csv - pw
#
# KZ ZEX Pro L.csv:
#   ZEX Pro L.csv - kr0mka
#   ZEX Pro R.csv - kr0mka
#
# KZ ZS10 Pro L.csv:
#   KZ ZS10 Pro L.csv - achoreviews, eplv, melatonin, pw, data_mrs
#   KZ ZSN Pro L.csv - achoreviews, melatonin, pw, data_mrs
#   KZ ZS10 PRO R.csv - aftersound, timmyv, ianfann, jacstone
#   KZ ZSN PRO L.csv - aftersound
#   KZ ZSN PRO R.csv - aftersound
#   KZ ZS10 Pro R.csv - eplv, melatonin
#   KZ ZS10 PRO L.csv - timmyv, ianfann, jacstone
#   KS ZS10 Pro L.csv - harpo
#   KZ ZS10 PRO Foam R.csv - hbb
#   KZ ZS10 PRO X Sil R.csv - hbb
#   KZ SK10 PRO L.csv - ianfann
#   KZ SK10 PRO R.csv - ianfann
#   KZ ZS10 PRO X L.csv - ianfann
#   KZ ZS10 PRO X R.csv - ianfann
#   ZS10 L.csv - kr0mka
#   ZS10 Pro L.csv - kr0mka
#   ZS10 Pro R.csv - kr0mka
#   ZS10 R.csv - kr0mka
#   KZ ZS10 L.csv - melatonin, data_mrs
#   KZ ZS10 Pro NEW L.csv - melatonin
#   KZ ZS10 Pro NEW R.csv - melatonin
#   KZ ZS10 R.csv - melatonin
#   KZ ZSN Pro R.csv - melatonin
#   KZ ZS10 Prov2 L.csv - pw
#   KZ ZS10 Pro X L.csv - vortexreviews, data_mrs
#   KZ ZS10 Pro X R.csv - vortexreviews, data_mrs
#   KZ ZSN Pro (1-8 foam) L.csv - data_mrs
#   KZ ZSN Pro (Blessing 2 filter) L.csv - data_mrs
#   KZ ZSN Pro (Starfield filter) L.csv - data_mrs
#   KZ ZSN Pro (Tanchjim filter) L.csv - data_mrs
#
# KZ ZSN L.csv:
#   KZ ZSN Pro X L.csv - achoreviews, bryaudioreviews, melatonin, pw
#   KZ ZSN PRO X R.csv - aftersound
#   KZ ZSN Pro X R.csv - bryaudioreviews, hbb, melatonin
#   Oratory KZ ZSN Pro L.csv - kurin
#   KZ ZSN PRO X BROKEN R.csv - nymz
#   KZ ZSN PRO X OK L.csv - nymz
#   KZ ZSN Pro Xv2 L.csv - pw
#   KZ ZSN Prov2 L.csv - pw
#   KZ ZSNv2 L.csv - pw
#
# KZ ZST X L.csv:
#   KZ ZST X L.csv - achoreviews, melatonin, vortexreviews
#   KZ ZST X R.csv - aftersound, hbb, melatonin
#   Oratory KZ ZST L.csv - kurin
#
# KZ ZVX L.csv:
#   KZ VXS L.csv - aftersound, ianfann, pw, vortexreviews
#   KZ VXS R.csv - aftersound, ianfann, pw, vortexreviews
#   KZ ZVX FINAL TIPS L.csv - aftersound
#   KZ ZVX FINAL TIPS R.csv - aftersound
#   KZ ZVX 25ohm L.csv - pw
#   KZ ZVX IEMatch L.csv - pw
#   KZ ZVX MP L.csv - pw
#
# Letshuoer D13 (Gold Filter) L.csv:
#   Letshuoer D13 (Gold Filter) L.csv - achoreviews
#   Letshuoer D13 (Silver Filter) L.csv - achoreviews
#   Letshuoer D13 (Gold) L.csv - bedrock
#   Letshuoer D13 (Gold) R.csv - bedrock
#   Letshuoer D13 (Silver) L.csv - bedrock
#   Letshuoer D13 (Silver) R.csv - bedrock
#   Letshuoer KL L.csv - timmyv
#   Letshuoer KL R.csv - timmyv
#   LETSHUOER D13 Gold Nozzle R.csv - harpo
#   LETSHUOER D13 Olina Filter mod R.csv - harpo
#   LETSHUOER D13 Silver Nozzle R.csv - harpo
#   Letshuoer 12 R.csv - hbb
#   Shuoer D13 2 R.csv - hbb
#   Shuoer D13 R.csv - hbb
#   LetShuoer D13 Gold L.csv - cqtek, pw
#   LetShuoer D13 Gold R.csv - cqtek, pw
#   LetShuoer D13 Silver L.csv - cqtek, pw
#   LetShuoer D13 Silver R.csv - cqtek, pw
#   LETSHUOER D13 2nd Nozzle L.csv - hobbytalk
#   LETSHUOER D13 2nd Nozzle R.csv - hobbytalk
#   LETSHUOER D13 L.csv - hobbytalk, ianfann
#   LETSHUOER D13 MBP L.csv - hobbytalk
#   LETSHUOER D13 MBP R.csv - hobbytalk
#   LETSHUOER D13 R.csv - hobbytalk, ianfann, vortexreviews
#   LETSHUOER D13 Stock Nozzle L.csv - hobbytalk
#   LETSHUOER D13 Stock Nozzle R.csv - hobbytalk
#   LETSHUOER D13 (TREBLE NOZZLE) L.csv - ianfann
#   LETSHUOER D13 (TREBLE NOZZLE) R.csv - ianfann
#   LETSHUOER D13 TREBLE R.csv - vortexreviews
#   LETSHUOER D13 gold nozzle L.csv - vsg
#   LETSHUOER D13 gold nozzle R.csv - vsg
#   LETSHUOER D13 silver nozzle L.csv - vsg
#   LETSHUOER D13 silver nozzle R.csv - vsg
#   Letshuoer D13 (gold) L.csv - data_mrs
#   Letshuoer D13 (gold) R.csv - data_mrs
#   Letshuoer D13 (pre-prod - nozzle A) L.csv - data_mrs
#   Letshuoer D13 (pre-prod - nozzle A) R.csv - data_mrs
#   Letshuoer D13 (pre-prod - nozzle B) L.csv - data_mrs
#   Letshuoer D13 (pre-prod - nozzle B) R.csv - data_mrs
#   Letshuoer D13 (silver) L.csv - data_mrs
#   Letshuoer D13 (silver) R.csv - data_mrs
#
# Letshuoer S12 (S1) L.csv:
#   Letshuoer S12 (S1) L.csv - achoreviews
#   Letshuoer S12 (S2) L.csv - achoreviews
#   SHUOER S12 L.csv - aftersound
#   SHUOER S12 PRO L.csv - aftersound
#   SHUOER S12 PRO R.csv - aftersound
#   SHUOER S12 R.csv - aftersound
#   Shuoer S12 L.csv - animagus, iemworld, pw
#   LETSHUOER S12 L.csv - arn, eplv, vortexreviews, vsg
#   Letshuoer S12 PRO L.csv - cammyfi
#   Letshuoer S12 PRO R.csv - cammyfi
#   Letshuoer S12 PRO Vents Blocked 300 Damping L.csv - cammyfi
#   Letshuoer S12 PRO Vents Blocked L.csv - cammyfi
#   LetShuoer S12 L.csv - soundjedi, cqtek
#   LetShuoer S12 R.csv - soundjedi, cqtek
#   LETSHUOER S12 R.csv - eplv, melatonin, vortexreviews, vsg
#   Letshuoer S12 L.csv - timmyv, data_mrs
#   Letshuoer S12 Pro L.csv - timmyv
#   Letshuoer S12 Pro R.csv - timmyv
#   Letshuoer S12 R.csv - timmyv, harpo, data_mrs
#   Shuoer s12 pro R.csv - hbb
#   Shuoer S12 R.csv - hbb, iemworld, nymz, pw
#   LetShuoer S12 Pro L.csv - cqtek
#   LetShuoer S12 Pro R.csv - cqtek
#   LETSHUOER S12 PRO L.csv - hobbytalk, ianfann, vortexreviews
#   LETSHUOER S12 PRO R.csv - hobbytalk, ianfann, vortexreviews
#   LETSHUOER Z12 (S2) L.csv - hobbytalk
#   LETSHUOER Z12 (S2) R.csv - hobbytalk
#   LETSHUOER Z12 L.csv - hobbytalk, vsg
#   LETSHUOER Z12 R.csv - hobbytalk, vsg
#   Shuoer S12 (EJ07 FOAM Eartips) L.csv - iemworld
#   Shuoer S12 (EJ07 FOAM Eartips) R.csv - iemworld
#   Shuoer S12 (Final Eartips) L.csv - iemworld
#   Shuoer S12 (Final Eartips) R.csv - iemworld
#   Shuoer S12 (MoonDrop Eartips) L.csv - iemworld
#   Shuoer S12 (MoonDrop Eartips) R.csv - iemworld
#   Shuoer S12 (Orignal Eartips) L.csv - iemworld
#   Shuoer S12 (Orignal Eartips) R.csv - iemworld
#   LETSHUOER S12 Foam R.csv - melatonin
#   Shuoer S12 ERU L.csv - nymz
#   Shuoer S12 ERU R.csv - nymz
#   S12 L.csv - shortbus
#   Letshuoer S12 (front vent blocked) L.csv - data_mrs
#   Letshuoer S12 (post) L.csv - data_mrs
#   Letshuoer S12 (post) R.csv - data_mrs
#   Letshuoer S12 (prepro) L.csv - data_mrs
#   Letshuoer S12 (prepro) R.csv - data_mrs
#   Letshuoer S12 (top vent blocked) L.csv - data_mrs
#
# LZ A4 Pro NzBlk FiBlk L.csv:
#   LZ A4 Pro NzBlk FiBlk L.csv - achoreviews
#   LZ A4 Pro NzBlk FiBlu L.csv - achoreviews
#   LZ A4 Pro NzBlk FiRed L.csv - achoreviews
#   LZ A4 Pro NzBlu FiBlk L.csv - achoreviews
#   LZ A4 Pro NzBlu FiBlu L.csv - achoreviews
#   LZ A4 Pro NzBlu FiRed L.csv - achoreviews
#   LZ A4 Pro NzRed FiBlk L.csv - achoreviews
#   LZ A4 Pro NzRed FiBlu L.csv - achoreviews
#   LZ A4 Pro NzSil FiBlk L.csv - achoreviews
#   LZ A4 Pro NzSil FiBlu L.csv - achoreviews
#   LZ A4 Pro NzSil FiRed L.csv - achoreviews
#   LZ A4 PRO R.csv - hbb
#   LZ A4 PRO Red R.csv - hbb
#   LZ A4 Pro Black-Black L.csv - cqtek
#   LZ A4 Pro Black-Black R.csv - cqtek
#   LZ A4 Pro Black-Blue L.csv - cqtek
#   LZ A4 Pro Blue-Black L.csv - cqtek
#   LZ A4 Pro (A7 Gold F + Black V) L.csv - rg
#   LZ A4 Pro (A7 Red F + Black V) L.csv - rg
#   LZ A4 Pro (Black F + Black V) L.csv - rg
#   LZ A4 Pro (Black F + Blue V) L.csv - rg
#   LZ A4 Pro (Black F + Red V) L.csv - rg
#   LZ A4 Pro (Blue F + Black V) L.csv - rg
#   LZ A4 Pro (Blue F + Blue V) L.csv - rg
#   LZ A4 Pro (Blue F + Red V) L.csv - rg
#   LZ A4 Pro (Gold F + Black V) L.csv - rg
#   LZ A4 Pro (Gold F + Blue V) L.csv - rg
#   LZ A4 Pro (Gold F + Red V) L.csv - rg
#   LZ A4 Pro (Red F + Black V) L.csv - rg
#   LZ A4 Pro (Red F + Blue V) L.csv - rg
#   LZ A4 Pro (Red F + Red V) L.csv - rg
#
# LZ A4 Pro NzBlk FiRed L.csv:
#   LZ A4 Pro NzRed FiRed L.csv - achoreviews
#
# LZ A4 Pro NzRed FiBlk L.csv:
#   LZ A4 Pro Black-Red L.csv - cqtek
#   LZ A4 Pro Red-Black L.csv - cqtek
#
# Meze Audio Advar L.csv:
#   Meze Audio Advar L.csv - achoreviews
#
# Moondrop Aria L.csv:
#   Moondrop Aria L.csv - achoreviews, animagus, bedrock, bryaudioreviews, timmyv, pw, vortexreviews, vsg, data_mrs
#   MOONDROP ARIA (OLD) L.csv - aftersound
#   MOONDROP ARIA (OLD) R.csv - aftersound
#   MOONDROP ARIA L.csv - aftersound, ianfann
#   MOONDROP ARIA R.csv - aftersound, ianfann
#   Moondrop Aria R.csv - animagus, bedrock, bryaudioreviews, timmyv, harpo, hbb, pw, vsg
#   Moondrop Aria Snow Edition L.csv - animagus
#   Moondrop Aria Snow Edition R.csv - animagus
#   Moondrop Aria Snow L.csv - timmyv, pw, data_mrs
#   Moondrop Aria Snow R.csv - timmyv, hbb, pw, data_mrs
#   MOONDROP ARIA SNOW L.csv - ianfann
#   MOONDROP ARIA SNOW R.csv - ianfann
#   Moondrop Aria S1 L.csv - jacstone
#   Moondrop Aria S1 R.csv - jacstone
#   Moondrop Aria S2 L.csv - jacstone
#   Moondrop Aria S2 R.csv - jacstone
#   Aria L.csv - kr0mka
#   Aria R.csv - kr0mka
#   Moondrop Aria Snow MP L.csv - pw
#   Moondrop Aria Snow NoFoam L.csv - pw
#   Moondrop Aria Snow NoFoam MP L.csv - pw
#   MOONDROP Aria Snow Edition L.csv - vsg
#   MOONDROP Aria Snow Edition R.csv - vsg
#   ARIA L.csv - akros
#   Moondrop Aria Snow (Spring) L.csv - data_mrs
#   Moondrop Aria Snow (Spring) R.csv - data_mrs
#
# Moondrop Blessing 2 Dusk (Spinfit) L.csv:
#   Moondrop Blessing 2 Dusk (Spinfit) L.csv - achoreviews
#   MOONDROP BLESSING 2 L.csv - aftersound
#   MOONDROP BLESSING 2 R.csv - aftersound
#   Moondrop B2 Dusk L.csv - timmyv, nymz
#   Moondrop B2 Dusk R.csv - timmyv, nymz
#   Moondrop Blessing 3 R.csv - hbb, data_mrs
#   Moondrop Dusk R.csv - hbb
# ...
#
# BQEYZ K2 L.csv:
#   BQEYZ KC2 L.csv - vortexreviews
#   BQEYZ KC2 R.csv - vortexreviews
#
# EDL Mini Piano L.csv:
#   EDL Mini Piano L.csv - vortexreviews
#
# Gravastar Sirius L.csv:
#   Gravastar Sirius L.csv - vortexreviews
#
# HAKII Action R.csv:
#   HAKII Action R.csv - vortexreviews
#
# Hisenior B5+ L.csv:
#   Hisenior B5+ L.csv - vortexreviews
#   Hisenior B5+ R.csv - vortexreviews
#
# SuperEQ Q2 Pro R.csv:
#   SuperEQ Q2 Pro R.csv - vortexreviews
#
# THOR Mjölnir MKII L.csv:
#   THOR Mjölnir MKII L.csv - vortexreviews
#   THOR Mjölnir MKII R.csv - vortexreviews
#
# Tozo Golden X1 L.csv:
#   Tozo Golden X1 L.csv - vortexreviews
#   Tozo Golden X1 R.csv - vortexreviews
#
# TRN H2 L.csv:
#   TRN H2 L.csv - vortexreviews
#
# 1MORE ColorBuds 2 L.csv:
#   1MORE ColorBuds 2 L.csv - vsg
#   1MORE ColorBuds 2 R.csv - vsg
#
# 1MORE EVO L.csv:
#   1MORE EVO L.csv - vsg
#   1MORE EVO R.csv - vsg
#
# AK PATHFINDER L.csv:
#   AK PATHFINDER L.csv - vsg
#   AK PATHFINDER R.csv - vsg
#
# Allway OE10 L.csv:
#   Allway OE10 L.csv - vsg
#
# Antlion Kimura Duo L.csv:
#   Antlion Kimura Duo L.csv - vsg
#   Antlion Kimura Duo R.csv - vsg
#   Antlion Kimura Solo L.csv - vsg
#   Antlion Kimura Solo R.csv - vsg
#
# Audeze CRBN L.csv:
#   Audeze CRBN L.csv - vsg
#   Audeze CRBN R.csv - vsg
#
# Audeze LCD-2 Classic L.csv:
#   Audeze LCD-2 Classic L.csv - vsg
#   Audeze LCD-2 Classic R.csv - vsg
#   Audeze LCD-5 L.csv - vsg
#   Audeze LCD-5 R.csv - vsg
#   Audeze LCD-X (2021) L.csv - vsg
#   Audeze LCD-X (2021) R.csv - vsg
#   Audeze LCD-XC (2021) L.csv - vsg
#   Audeze LCD-XC (2021) R.csv - vsg
#
# Audeze LCD-5 L.csv:
#   Audeze LCD-5 Old Headband L.csv - vsg
#   Audeze LCD-5 Old Headband R.csv - vsg
#
# Audio-Technica ATH-ANC300TW L.csv:
#   Audio-Technica ATH-ANC300TW L.csv - vsg
#   Audio-Technica ATH-ANC300TW R.csv - vsg
#   Audio-Technica ATH-ANC900BT L.csv - vsg
#   Audio-Technica ATH-ANC900BT R.csv - vsg
#
# Audio-Technica ATH-ANC900BT ANC L.csv:
#   Audio-Technica ATH-ANC900BT ANC L.csv - vsg
#   Audio-Technica ATH-ANC900BT HT L.csv - vsg
#
# Bang & Olufsen Beoplay H95 ANC L.csv:
#   Bang & Olufsen Beoplay H95 ANC L.csv - vsg
#   Bang & Olufsen Beoplay H95 ANC R.csv - vsg
#   Bang & Olufsen Beoplay H95 L.csv - vsg
#   Bang & Olufsen Beoplay H95 R.csv - vsg
#
# Cambridge Audio Melomania 1+ L.csv:
#   Cambridge Audio Melomania 1+ L.csv - vsg
#   Cambridge Audio Melomania 1+ R.csv - vsg
#
# Cleer Flow II Ambient L.csv:
#   Cleer Flow II Ambient L.csv - vsg
#   Cleer Flow II Ambient R.csv - vsg
#   Cleer Flow II ANC L.csv - vsg
#   Cleer Flow II ANC R.csv - vsg
#
# Cleer Roam NC L.csv:
#   Cleer Roam NC L.csv - vsg
#   Cleer Roam NC R.csv - vsg
#
# Drop + Dan Clark Audio Aeon Closed X 1-notch white filter L.csv:
#   Drop + Dan Clark Audio Aeon Closed X 1-notch white filter L.csv - vsg
#   Drop + Dan Clark Audio Aeon Closed X L.csv - vsg
#   Drop + Dan Clark Audio Aeon Closed X R.csv - vsg
#
# Edifier STAX SPIRIT S3 Lambskin BT L.csv:
#   Edifier STAX SPIRIT S3 Lambskin wired L.csv - vsg
#   Edifier STAX SPIRIT S3 Lambskin wired R.csv - vsg
#   Edifier STAX SPIRIT S3 Mesh wired L.csv - vsg
#   Edifier STAX SPIRIT S3 Mesh wired R.csv - vsg
#
# Edifier WH950NB Bluetooth L.csv:
#   Edifier WH950NB Bluetooth L.csv - vsg
#   Edifier WH950NB Bluetooth R.csv - vsg
#   Edifier WH950NB wired L.csv - vsg
#   Edifier WH950NB wired R.csv - vsg
#
# FiiO FA7s L.csv:
#   FiiO FA7s L.csv - vsg
#   FiiO FA7s R.csv - vsg
#
# FiiO FH5s Bass L.csv:
#   FiiO FH7S Bass L.csv - vsg
#   FiiO FH7S Bass R.csv - vsg
#
# FiiO FH5s Treble L.csv:
#   FiiO FH7S Treble L.csv - vsg
#   FiiO FH7S Treble R.csv - vsg
#
# FiiO FT3 pleather L.csv:
#   FiiO FT3 pleather L.csv - vsg
#   FiiO FT3 pleather R.csv - vsg
#   FiiO FT3 suede L.csv - vsg
#   FiiO FT3 suede R.csv - vsg
#
# final UX3000 Bluetooth ANC L.csv:
#   final UX3000 Bluetooth ANC L.csv - vsg
#   final UX3000 Bluetooth L.csv - vsg
#   final UX3000 Bluetooth R.csv - vsg
#   final UX3000 Wired L.csv - vsg
#   final UX3000 Wired R.csv - vsg
#
# final ZE8000 1.8.0 L.csv:
#   final ZE8000 1.8.0 L.csv - vsg
#   final ZE8000 1.8.0 R.csv - vsg
#   final ZE8000 1.8.1 L.csv - vsg
#   final ZE8000 1.8.1 R.csv - vsg
#
# Focal Bathys L.csv:
#   Focal Bathys L.csv - vsg
#   Focal Bathys R.csv - vsg
#
# Focal Utopia 2022 L.csv:
#   Focal Utopia 2022 L.csv - vsg
#   Focal Utopia 2022 R.csv - vsg
#
# HarmonicDyne G200 Flannel L.csv:
#   HarmonicDyne G200 Flannel L.csv - vsg
#   HarmonicDyne G200 Flannel R.csv - vsg
#   HarmonicDyne G200 Lambskin L.csv - vsg
#   HarmonicDyne G200 Lambskin R.csv - vsg
#   HarmonicDyne G200 Yaxi Alcantara L.csv - vsg
#   HarmonicDyne G200 Yaxi Alcantara R.csv - vsg
#   HarmonicDyne G200 Yaxi Leather L.csv - vsg
#   HarmonicDyne G200 Yaxi Leather R.csv - vsg
#
# HarmonicDyne P.D.1 L.csv:
#   HarmonicDyne P.D.1 L.csv - vsg
#   HarmonicDyne P.D.1 R.csv - vsg
#   HarmonicDyne PD1 L.csv - data_mrs
#   HarmonicDyne PD1 R.csv - data_mrs
#
# HarmonicDyne Poseidon L.csv:
#   HarmonicDyne Poseidon L.csv - vsg
#   HarmonicDyne Poseidon R.csv - vsg
#
# Hear+Hi Acuity Duo L.csv:
#   Hear+Hi Acuity Duo L.csv - vsg
#   Hear+Hi Acuity Duo R.csv - vsg
#
# HiBy Lasya L.csv:
#   HiBy Lasya L.csv - vsg
#   HiBy Lasya R.csv - vsg
#
# HIFIMAN Ananda (2022 Stealth Magnets) L.csv:
#   HIFIMAN Ananda (2022 Stealth Magnets) L.csv - vsg
#   HIFIMAN Ananda (2022 Stealth Magnets) R.csv - vsg
#
# HIFIMAN HE-R10D Bluemini L.csv:
#   HIFIMAN HE-R10D Bluemini L.csv - vsg
#   HIFIMAN HE-R10D Bluemini R.csv - vsg
#   HIFIMAN HE-R10D L.csv - vsg
#   HIFIMAN HE-R10D R.csv - vsg
#   HIFIMAN HE-R10P Bluemini L.csv - vsg
#   HIFIMAN HE-R10P Bluemini R.csv - vsg
#   HIFIMAN HE-R9 Bluemini L.csv - vsg
#   HIFIMAN HE-R9 Bluemini R.csv - vsg
#   HIFIMAN HE-R9 L.csv - vsg
#   HIFIMAN HE-R9 R.csv - vsg
#
# HIFIMAN HE-R10D L.csv:
#   HIFIMAN HE-R10P L.csv - vsg
#   HIFIMAN HE-R10P R.csv - vsg
#
# HIFIMAN RE2000 Pro Gold L.csv:
#   HIFIMAN RE2000 Pro Gold L.csv - vsg
#   HIFIMAN RE2000 Pro Gold R.csv - vsg
#
# HIFIMAN Shangri-La Jr L.csv:
#   HIFIMAN Shangri-La Jr L.csv - vsg
#   HIFIMAN Shangri-La Jr R.csv - vsg
#   HIFIMAN Shangri-La Sr L.csv - vsg
#   HIFIMAN Shangri-La Sr R.csv - vsg
#
# iBasso SR3 L.csv:
#   iBasso SR3 L.csv - vsg
#   iBasso SR3 R.csv - vsg
#   iBasso SR3 spare pads L.csv - vsg
#   iBasso SR3 spare pads R.csv - vsg
#
# JQ 4Upro L.csv:
#   JQ 4Upro L.csv - vsg
#   JQ 4Upro R.csv - vsg
#
# Kinera YH802 ANC L.csv:
#   Kinera YH802 ANC L.csv - vsg
#   Kinera YH802 L.csv - vsg
#   Kinera YH802 R.csv - vsg
#
# Mackie MP-320 L.csv:
#   Mackie MP-320 L.csv - vsg
#   Mackie MP-320 R.csv - vsg
#
# Mackie MP-460 L.csv:
#   Mackie MP-460 L.csv - vsg
#   Mackie MP-460 R.csv - vsg
#
# Meze 99 Neo Dekoni L.csv:
#   Meze 99 Neo Dekoni L.csv - vsg
#   Meze 99 Neo Dekoni R.csv - vsg
#   Meze 99 Neo L.csv - vsg
#   Meze 99 Neo R.csv - vsg
#
# Meze Liric L.csv:
#   Meze Liric L.csv - vsg
#   Meze Liric R.csv - vsg
#
# Monoprice M1070C Lambskin L.csv:
#   Monoprice M1070C Lambskin L.csv - vsg
#   Monoprice M1070C Lambskin R.csv - vsg
#   Monoprice M1070C Velour L.csv - vsg
#   Monoprice M1070C Velour R.csv - vsg
#
# Monoprice Monolith M-TWE L.csv:
#   Monoprice Monolith M-TWE L.csv - vsg
#   Monoprice Monolith M-TWE R.csv - vsg
#
# Moondrop VOID L.csv:
#   Moondrop VOID L.csv - vsg
#   Moondrop VOID R.csv - vsg
#   Moondrop VOID S1 L.csv - vsg
#   Moondrop VOID S1 R.csv - vsg
#   Moondrop VOID S2 L.csv - vsg
#   Moondrop VOID S2 R.csv - vsg
#
# Nectar HiveX (No Sponge Insert) L.csv:
#   Nectar HiveX (No Sponge Insert) L.csv - vsg
#   Nectar HiveX (No Sponge Insert) R.csv - vsg
#   Nectar HiveX (Sponge Insert) L.csv - vsg
#   Nectar HiveX (Sponge Insert) R.csv - vsg
#
# Noble Audio Viking Ragnar L.csv:
#   Noble Audio Viking Ragnar L.csv - vsg
#   Noble Audio Viking Ragnar R.csv - vsg
#
# Ovidius TX-901 L.csv:
#   Ovidius TX-901 L.csv - vsg
#   Ovidius TX-901 R.csv - vsg
#
# Padmate PaMu Z1 L.csv:
#   Padmate PaMu Z1 L.csv - vsg
#   Padmate PaMu Z1 R.csv - vsg
#
# Peacock Flight L.csv:
#   Peacock Flight L.csv - vsg
#   Peacock Flight R.csv - vsg
#
# Philips Fidelio X2HR L.csv:
#   Philips Fidelio X2HR L.csv - vsg
#   Philips Fidelio X2HR R.csv - vsg
#   Philips Fidelio X3 L.csv - vsg
#   Philips Fidelio X3 R.csv - vsg
#
# Sennheiser HD 598 L.csv:
#   Sennheiser HD 598 L.csv - vsg
#   Sennheiser HD 598 R.csv - vsg
#
# Sennheiser x Drop HD 6XX L.csv:
#   Sennheiser x Drop HD 6XX L.csv - vsg
#   Sennheiser x Drop HD 6XX R.csv - vsg
#
# Sivga Oriole L.csv:
#   Sivga Oriole L.csv - vsg
#   Sivga Oriole R.csv - vsg
#
# Sivga Phoenix L.csv:
#   Sivga Phoenix L.csv - vsg
#   Sivga Phoenix R.csv - vsg
#
# Sivga Robin (SV021) L.csv:
#   Sivga Robin (SV021) L.csv - vsg
#   Sivga Robin (SV021) R.csv - vsg
#
# Sivga SV023 L.csv:
#   Sivga SV023 L.csv - vsg
#   Sivga SV023 R.csv - vsg
#
# Technics AZ70 L.csv:
#   Technics AZ70 L.csv - vsg
#   Technics AZ70 R.csv - vsg
#
# UA Complimentary 1 L.csv:
#   UA Complimentary 1 L.csv - vsg
#   UA Complimentary 1 R.csv - vsg
#   UA Complimentary 2 L.csv - vsg
#   UA Complimentary 2 R.csv - vsg
#
# Ugreen HiTune T3 L.csv:
#   Ugreen HiTune T3 L.csv - vsg
#   Ugreen HiTune T3 R.csv - vsg
#
# Zephone Tiger L.csv:
#   Zephone Tiger L.csv - vsg
#   Zephone Tiger R.csv - vsg
#
# 710 Btnc (Active, ANC off) L.csv:
#   710 Btnc (Active, ANC off) L.csv - wdym
#   710 Btnc (Active, ANC on) L.csv - wdym
#   710 Btnc (Passive) L.csv - wdym
#
# Elegia (Stock Pads) L.csv:
#   Elegia (Stock Pads) L.csv - wdym
#
# Elex (Dekoni Elite Fenestrated Sheepskin Pads) L.csv:
#   Elex (Dekoni Elite Fenestrated Sheepskin Pads) L.csv - wdym
#   Elex (Elear Pads) L.csv - wdym
#   Elex (Stock Pads) L.csv - wdym
#   Elex (Utopia Pads) L.csv - wdym
#
# test L.csv:
#   test L.csv - akros
#
# Akoustyx R-120 L.csv:
#   Akoustyx R-120 L.csv - data_mrs
#
# Akoustyx S-6 (S2) L.csv:
#   Akoustyx S-6 (S2) L.csv - data_mrs
#   Akoustyx S-6 (S2) R.csv - data_mrs
#   Akoustyx S-6 (Tanchjim) L.csv - data_mrs
#   Akoustyx S-6 (Tanchjim) R.csv - data_mrs
#   Akoustyx S-6 L.csv - data_mrs
#   Akoustyx S-6 R.csv - data_mrs
#
# Brainwavz Koel L.csv:
#   Brainwavz Koel L.csv - data_mrs
#
# Cayin Fantasy L.csv:
#   Cayin Fantasy L.csv - data_mrs
#
# Co-Donguri Shizuku L.csv:
#   Co-Donguri Shizuku L.csv - data_mrs
#
# Colorfly Quintet L.csv:
#   Colorfly Quintet L.csv - data_mrs
#   Colorfly Quintet R.csv - data_mrs
#
# Etymotic ETY Kids L.csv:
#   Etymotic ETY Kids L.csv - data_mrs
#
# Etymotic MK5 L.csv:
#   Etymotic MK5 L.csv - data_mrs
#
# FLC 8P (gold-black-gunmetal) L.csv:
#   FLC 8P (gold-black-gunmetal) L.csv - data_mrs
#   FLC 8P (gold-black-red) L.csv - data_mrs
#   FLC 8P (gold-gray-gunmetal) L.csv - data_mrs
#   FLC 8P (gold-white-gunmetal) L.csv - data_mrs
#   FLC 8P (gold-white-transparent) L.csv - data_mrs
#   FLC 8P (green-gray-gunmetal) L.csv - data_mrs
#   FLC 8P (gunmetal-black-gunmetal) L.csv - data_mrs
#   FLC 8P (gunmetal-gray-gunmetal) L.csv - data_mrs
#   FLC 8P (silver-gray-gunmetal) L.csv - data_mrs
#
# FLC DD31 L.csv:
#   FLC DD31 L.csv - data_mrs
#
# Haylou GT1 L.csv:
#   Haylou GT1 L.csv - data_mrs
#   Haylou GT2 L.csv - data_mrs
#   Haylou GT2 R.csv - data_mrs
#
# Hiby Crystal6 II L.csv:
#   Hiby Crystal6 II L.csv - data_mrs
#   Hiby Crystal6 II R.csv - data_mrs
#   Hiby Crystal6 L.csv - data_mrs
#
# Hifiman Bolt L.csv:
#   Hifiman Bolt L.csv - data_mrs
#
# JH Audio Layla (max) L.csv:
#   JH Audio Layla (max) L.csv - data_mrs
#   JH Audio Layla (max) R.csv - data_mrs
#   JH Audio Layla (min) L.csv - data_mrs
#   JH Audio Layla (min) R.csv - data_mrs
#
# JVC FX7 L.csv:
#   JVC FX7 L.csv - data_mrs
#   JVC FX7 R.csv - data_mrs
#
# Kinera Sif L.csv:
#   Kinera Sif L.csv - data_mrs
#
# LG HBS800 (ANC off) L.csv:
#   LG HBS800 (ANC off) L.csv - data_mrs
#   LG HBS800 (ANC off) R.csv - data_mrs
#   LG HBS800 (ANC on) L.csv - data_mrs
#   LG HBS800 (ANC on) R.csv - data_mrs
#   LG HBS800 L.csv - data_mrs
#   LG HBS800 R.csv - data_mrs
#
# Magaosi K3 (F0) L.csv:
#   Magaosi K5 (15 ohm + IEMatch+ ultra) L.csv - data_mrs
#   Magaosi K5 (15 ohm + IEMatch+) L.csv - data_mrs
#   Magaosi K5 (15 ohm) L.csv - data_mrs
#   Magaosi K5 L.csv - data_mrs
#
# Meizu Live (black) L.csv:
#   Meizu Live (black) L.csv - data_mrs
#   Meizu Live (blue) L.csv - data_mrs
#   Meizu Live (white) L.csv - data_mrs
#
# Mi True Wireless Earbuds Basic 2 L.csv:
#   Mi True Wireless Earbuds Basic 2 L.csv - data_mrs
#
# Moondrop Solis L.csv:
#   Moondrop Solis L.csv - data_mrs
#   Moondrop Solis R.csv - data_mrs
#   Moondrop Solis S2 L.csv - data_mrs
#   Moondrop Solis S2 R.csv - data_mrs
#
# Nothing Ear 2 (balanced) L.csv:
#   Nothing Ear 2 (balanced) L.csv - data_mrs
#   Nothing Ear 2 (balanced) R.csv - data_mrs
#   Nothing Ear 2 (more bass) L.csv - data_mrs
#   Nothing Ear 2 (more bass) R.csv - data_mrs
#   Nothing Ear 2 (more treble) L.csv - data_mrs
#   Nothing Ear 2 (more treble) R.csv - data_mrs
#   Nothing Ear 2 (personalized B) L.csv - data_mrs
#   Nothing Ear 2 (personalized B) R.csv - data_mrs
#   Nothing Ear 2 (personalized) L.csv - data_mrs
#   Nothing Ear 2 (personalized) R.csv - data_mrs
#   Nothing Ear 2 (treble -6) L.csv - data_mrs
#   Nothing Ear 2 (treble -6) R.csv - data_mrs
#   Nothing Ear 2 (voice) L.csv - data_mrs
#   Nothing Ear 2 (voice) R.csv - data_mrs
#   Nothing Ear 2 L.csv - data_mrs
#   Nothing Ear 2 R.csv - data_mrs
#
# OpenAudio Mercury L.csv:
#   OpenAudio Mercury L.csv - data_mrs
#   OpenAudio Mercury R.csv - data_mrs
#
# Oriolus 2nd Gen L.csv:
#   Oriolus 2nd Gen L.csv - data_mrs
#
# Philips SHE3590PK L.csv:
#   Philips SHE3590PK L.csv - data_mrs
#
# Phonak Audeo PFE 112 L.csv:
#   Phonak Audeo PFE 112 L.csv - data_mrs
#   Phonak Audeo PFE 112 R.csv - data_mrs
#
# Pre-Prod 03 (nozzle A) L.csv:
#   Pre-Prod 03 (nozzle A) L.csv - data_mrs
#   Pre-Prod 03 (nozzle A) R.csv - data_mrs
#   Pre-Prod 03 (nozzle B) L.csv - data_mrs
#   Pre-Prod 03 (nozzle B) R.csv - data_mrs
#
# QDC Neptune L.csv:
#   QDC Neptune L.csv - data_mrs
#
# QDC Uranus L.csv:
#   QDC Uranus L.csv - data_mrs
#
# Radius HP-NEF11 L.csv:
#   Radius HP-NEF11 L.csv - data_mrs
#   Radius HP-NEF11 R.csv - data_mrs
#
# Samsung Earphones (2019) L.csv:
#   Samsung Earphones (2019) L.csv - data_mrs
#
# Sennheiser IE 200 (Azla Max) L.csv:
#   Sennheiser IE 200 (Azla Max) L.csv - data_mrs
#   Sennheiser IE 200 (Azla Max) R.csv - data_mrs
#   Sennheiser IE 200 (D1) L.csv - data_mrs
#   Sennheiser IE 200 (D1) R.csv - data_mrs
#   Sennheiser IE 200 (D2) L.csv - data_mrs
#   Sennheiser IE 200 (D2) R.csv - data_mrs
#   Sennheiser IE 200 (Spiral Dot) L.csv - data_mrs
#   Sennheiser IE 200 (Spiral Dot) R.csv - data_mrs
#   Sennheiser IE 200 (UC tips) L.csv - data_mrs
#   Sennheiser IE 200 (UC tips) R.csv - data_mrs
#   Sennheiser IE 300 (AutoEQ) L.csv - data_mrs
#   Sennheiser IE 300 (Final E) L.csv - data_mrs
#   Sennheiser IE 300 (Sedna Light) L.csv - data_mrs
#   Sennheiser IE 300 L.csv - data_mrs
#   Sennheiser IE 600 (E-type shallow) L.csv - data_mrs
#   Sennheiser IE 600 (E-type shallow) R.csv - data_mrs
#   Sennheiser IE 600 (E-type) L.csv - data_mrs
#   Sennheiser IE 600 (E-type) R.csv - data_mrs
#   Sennheiser IE 600 (foam) L.csv - data_mrs
#   Sennheiser IE 600 (foam) R.csv - data_mrs
#   Sennheiser IE 600 (Sedna) L.csv - data_mrs
#   Sennheiser IE 600 (Sedna) R.csv - data_mrs
#   Sennheiser IE 600 (Spinfit) L.csv - data_mrs
#   Sennheiser IE 600 (Spinfit) R.csv - data_mrs
#   Sennheiser IE 600 (Spring tips) L.csv - data_mrs
#   Sennheiser IE 600 (Spring tips) R.csv - data_mrs
#   Sennheiser IE 600 L.csv - data_mrs
#   Sennheiser IE 600 R.csv - data_mrs
#
# Sennheiser MTW2 (HE) L.csv:
#   Sennheiser MTW2 (HE) L.csv - data_mrs
#   Sennheiser MTW2 L.csv - data_mrs
#
# Shanling ME700 Lite L.csv:
#   Shanling ME700 Lite L.csv - data_mrs
#
# Shozy CP L.csv:
#   Shozy CP L.csv - data_mrs
#
# Shozy Rouge L.csv:
#   Shozy Rouge L.csv - data_mrs
#
# Simgot EN700 Pro (Moondrop) L.csv:
#   Simgot EN700 Pro (Moondrop) L.csv - data_mrs
#   Simgot EN700 Pro (Tanchjim) L.csv - data_mrs
#   Simgot EN700 Pro L.csv - data_mrs
#
# Softears Studio4 L.csv:
#   Softears Studio4 L.csv - data_mrs
#   Softears Studio4 R.csv - data_mrs
#
# Sony IER-NW510N L.csv:
#   Sony IER-NW510N L.csv - data_mrs
#
# Sony MDR-AS800 L.csv:
#   Sony MDR-AS800 L.csv - data_mrs
#   Sony MDR-AS800 R.csv - data_mrs
#
# Status Audio IEM-2X L.csv:
#   Status Audio IEM-2X L.csv - data_mrs
#
# Tanchjim Darling (depth 1) L.csv:
#   Tanchjim Darling (depth 1) L.csv - data_mrs
#   Tanchjim Darling (depth 2) L.csv - data_mrs
#
# Tenhz 3BA L.csv:
#   Tenhz 3BA L.csv - data_mrs
#
# Tenhz P4 Pro L.csv:
#   Tenhz P4 Pro L.csv - data_mrs
#
# Thinksound Rain3 L.csv:
#   Thinksound Rain3 L.csv - data_mrs
#   Thinksound Rain3 R.csv - data_mrs
#
# Ucotech RE-2 L.csv:
#   Ucotech RE-2 L.csv - data_mrs
#   Ucotech RE-2 R.csv - data_mrs
#
# Vsonic GR07 (Bass) L.csv:
#   Vsonic GR07 (Bass) L.csv - data_mrs
#   Vsonic GR07 L.csv - data_mrs
#   Vsonic GR07 R.csv - data_mrs
#
# Yinfu MD51 L.csv:
#   Yinfu MD51 L.csv - data_mrs

# %%
print(f"Total number of files: {len(all_files)}")
print(f"Total number of groups: {len(grouped_files)}")
print(f"Total number of files in groups: {sum([len(files) for files in grouped_files.values()])}")
print(f"Total number of files not in groups: {len(all_files) - sum([len(files) for files in grouped_files.values()])}")
print(f"\nAvg number of files per group: {sum([len(files) for files in grouped_files.values()]) / len(grouped_files)}")
# Out:
# Total number of files: 9882
# Total number of groups: 1603
# Total number of files in groups: 7668
# Total number of files not in groups: 2214
#
# Avg number of files per group: 4.7835308796007485

# %%
import os

# List of reviewers
reviewers = [
    'achoreviews',
    'aftersound',
    'animagus',
    'arn',
    'bedrock',
    'bryaudioreviews',
    'cammyfi',
    'soundjedi',
    'eplv',
    'timmyv',
    'harpo',
    'hbb',
    'cqtek',
    'hobbytalk',
    'ianfann',
    'iemworld',
    'jacstone',
    'kr0mka',
    'kurin',
    'melatonin',
    'nymz', 
    'pw',
    'recode',
    'rg',
    'shortbus',
    'suporsalad',
    'tgx78',
    'vortexreviews',
    'vsg',
    'wdym',
    'akros',
    'data_mrs'
]

for reviewer in reviewers:
    reviewer_path = f'output/csv/{reviewer}'
    
    if os.path.exists(reviewer_path):
        print(f"Files in '{reviewer_path}':")
        for file_name in os.listdir(reviewer_path):
            print(f"  {file_name}")
        print()
    else:
        print(f"Directory '{reviewer_path}' not found.\n")
# Out:
# Files in 'output/csv/achoreviews':
#   7Hz Dioko L.csv
#   7Hz Eternal L.csv
#   7Hz Legato L.csv
#   7Hz Timeless L.csv
#   7Hz Zero L.csv
#   Acho Reviews Target.csv
#   Antdroid Target.csv
#   Audeze iSine LX (Spinfit) L.csv
#   Aune Jasper L.csv
#   Bad Guy Target.csv
#   Banbeucmas Target.csv
#   Blon BL01 L.csv
#   Blon BL03 L.csv
#   Blon BL05s L.csv
#   Blon Fat Girl L.csv
#   Blon T1 L.csv
#   Blon T3 L.csv
#   Blon Z200 L.csv
#   CCA CRA L.csv
#   CCA CRA Plus L.csv
#   CCZ Emerald L.csv
#   CCZ Melody L.csv
#   CCZ Warrior L.csv
#   Celest Pandamon L.csv
#   Crinacle Target.csv
#   Diffuse Field Target.csv
#   Dunu Kima L.csv
#   Dunu Talos (Planar + BA) (IE600 Foam Tips) L.csv
#   Dunu Talos (Planar + BA) L.csv
#   Dunu Talos (Planar Only) (IE600 Foam Tips) L.csv
#   Dunu Talos (Planar Only) L.csv
#   Dunu Titan S (Isolation) L.csv
#   Dunu Titan S L.csv
#   Dunu Vulkan L.csv
#   Effect Audio Axiom L.csv
#   Etymotic Target.csv
#   Fiio FHE Eclipse L.csv
#   Final Audio E500 L.csv
#   Free Field Target.csv
#   Harman Target.csv
#   Hidition Violet L.csv
#   Hifiman RE600s v2 L.csv
#   Hifiman Svanar L.csv
#   Hifiman TWS800 L.csv
#   HZ Sound Heart Mirror Pro L.csv
#   Ikko Opal OH02 L.csv
#   Innerfidelity ID Target.csv
#   ITK Unknown L.csv
#   Joyodio Shine (0000) L.csv
#   Joyodio Shine (0010) L.csv
#   Joyodio Shine (0100) L.csv
#   Joyodio Shine (0110) L.csv
#   Joyodio Shine (1000) L.csv
#   Joyodio Shine (1010) L.csv
#   Joyodio Shine (1100) L.csv
#   Joyodio Shine (1110) L.csv
#   KBEAR Lark (S1) L.csv
#   KBEAR Lark (S2) L.csv
#   KBEAR Little Q L.csv
#   KBEAR Qinglong L.csv
#   KBEAR Robin L.csv
#   Kinera BD005 Pro L.csv
#   Kiwi Ears Cadenza L.csv
#   Kiwi Ears Orchestra Lite L.csv
#   Koss KEB90 L.csv
#   KZ AS16 Pro L.csv
#   KZ ATE L.csv
#   KZ DQ6 L.csv
#   KZ DQ6s L.csv
#   KZ DQS L.csv
#   KZ ED16 L.csv
#   KZ EDX L.csv
#   KZ EDX Pro L.csv
#   KZ PR1 L.csv
#   KZ ZAX L.csv
#   KZ ZES L.csv
#   KZ ZEX L.csv
#   KZ ZEX Pro L.csv
#   KZ ZS10 Pro L.csv
#   KZ ZSN L.csv
#   KZ ZSN Pro L.csv
#   KZ ZSN Pro X L.csv
#   KZ ZST X L.csv
#   KZ ZVX L.csv
#   Letshuoer D13 (Gold Filter) L.csv
#   Letshuoer D13 (Silver Filter) L.csv
#   Letshuoer S12 (S1) L.csv
#   Letshuoer S12 (S2) L.csv
#   LZ A4 Pro NzBlk FiBlk L.csv
#   LZ A4 Pro NzBlk FiBlu L.csv
#   LZ A4 Pro NzBlk FiRed L.csv
#   LZ A4 Pro NzBlu FiBlk L.csv
#   LZ A4 Pro NzBlu FiBlu L.csv
#   LZ A4 Pro NzBlu FiRed L.csv
#   LZ A4 Pro NzRed FiBlk L.csv
#   LZ A4 Pro NzRed FiBlu L.csv
#   LZ A4 Pro NzRed FiRed L.csv
#   LZ A4 Pro NzSil FiBlk L.csv
#   LZ A4 Pro NzSil FiBlu L.csv
#   LZ A4 Pro NzSil FiRed L.csv
#   Meze Audio Advar L.csv
#   Moondrop Aria L.csv
#   Moondrop Blessing 2 Dusk (Spinfit) L.csv
#   Moondrop Chu L.csv
#   Moondrop Nekocake (Balanced + ANC) L.csv
#   Moondrop Nekocake (Balanced) L.csv
#   Moondrop Nekocake (Classic) L.csv
#   Moondrop Nekocake (Nobass) L.csv
#   Moondrop Nekocake (Wennebostel) L.csv
#   Moondrop Nekocake (X-Dynamic) L.csv
#   Moondrop Quarks L.csv
#   Moondrop SSP L.csv
#   Moondrop SSR L.csv
#   Moondrop Starfield L.csv
#   NF Audio NM2 L.csv
#   NiceHCK Topguy L.csv
#   Openheart Resin L.csv
#   Plussound Allegro L.csv
#   Precogvision Target.csv
#   QKZ CK5 L.csv
#   QKZ x HBB Khan L.csv
#   QKZ x HBB L.csv
#   QOA Gimlet L.csv
#   Reecho SG01 L.csv
#   Reecho SG03 L.csv
#   Rtings Target.csv
#   SeeAudio Yume Midnight L.csv
#   Seek Real Airship L.csv
#   Sennheiser IE600 (Stock Foam) L.csv
#   Sennheiser IE600 (Stock Silicone) L.csv
#   Sennheiser IE600 L.csv
#   Simgot EA500 (black) L.csv
#   Simgot EA500 (red) L.csv
#   Sonarworks Target.csv
#   Sony MH755 L.csv
#   Strauss and Wagner EM205 L.csv
#   Super Review Target.csv
#   Symphonium Helios L.csv
#   T Force Yuan Li L.csv
#   Tanchjim Ola L.csv
#   Tanchjim Tanya L.csv
#   Tanchjim Zero L.csv
#   Tangzu Shimin Li L.csv
#   Tangzu Wan Er SG L.csv
#   Thieaudio Legacy 2 L.csv
#   Tin C2 Mech Warrior L.csv
#   Tin C3 L.csv
#   Tin T1 Plus L.csv
#   Tin T1S L.csv
#   Tin T2 DLC L.csv
#   Tin T2 L.csv
#   Tin T2 Plus L.csv
#   Tin T3 Buds L.csv
#   Tin T3 Plus L.csv
#   Tin T4 Plus L.csv
#   Tipsy TTROMSO Pine Stone Sea L.csv
#   TKZK Ouranos L.csv
#   Tri i One L.csv
#   Tri Meteor L.csv
#   Tri x HBB KAI L.csv
#   Tripowin Cencibel L.csv
#   Tripowin Lea L.csv
#   Tripowin Rhombus L.csv
#   TRN MT1 L.csv
#   TRN ST5 L.csv
#   TRN TA1 L.csv
#   TRN TA1 Max L.csv
#   TRN Xuanwu L.csv
#   Unique Melody Mest Mk2 L.csv
#   Urbanfun YBF-ISS014 (S1) L.csv
#   Urbanfun YBF-ISS014 (S2) L.csv
#   Venture Electronics Grand Duke L.csv
#   z_Isolation Comparison Free Field L.csv
#
# Files in 'output/csv/aftersound':
#   4ACOUSTIC HARMONIE R.csv
#   4ACOUSTIC SYMPHONIE 1 ON R.csv
#   4ACOUSTIC SYMPHONIE 2 ON R.csv
#   4ACOUSTIC SYMPHONIE 3 ON R.csv
#   4ACOUSTIC SYMPHONIE ALL OFF R.csv
#   4ACOUSTIC SYMPHONIE ALL ON R.csv
#   4ACOUSTIC UNISON L.csv
#   4ACOUSTIC UNISON R.csv
#   64 AUDIO TIA TRIO L.csv
#   64 AUDIO TIA TRIO R.csv
#   64 AUDIO U12T M15 L.csv
#   64 AUDIO U12T M15 R.csv
#   64 AUDIO U12T M20 L.csv
#   64 AUDIO U12T M20 R.csv
#   64 AUDIO U12T NON APEX L.csv
#   64 AUDIO U12T NON APEX R.csv
#   64 AUDIO U18S L.csv
#   64 AUDIO U18S R.csv
#   7 HERTZ TIMELESS L.csv
#   7 HERTZ TIMELESS R.csv
#   7HZ LEGATO L.csv
#   7HZ LEGATO R.csv
#   7HZ SALNOTES DIOKO L.csv
#   7HZ SALNOTES DIOKO R.csv
#   7HZ SALNOTES ZERO L.csv
#   7HZ SALNOTES ZERO R.csv
#   7HZ TIMELESS AE L.csv
#   7HZ TIMELESS AE R.csv
#   7HZ TIMELESS L.csv
#   7HZ TIMELESS R.csv
#   7HZ TIMELESS S2 L.csv
#   7HZ TIMELESS S2 R.csv
#   7TH ACOUSTICS PROXIMA L.csv
#   7TH ACOUSTICS PROXIMA R.csv
#   7TH ACOUSTICS STARGAZER 3 L.csv
#   7TH ACOUSTICS STARGAZER 3 PROTOTYPE L.csv
#   7TH ACOUSTICS STARGAZER 3 PROTOTYPE R.csv
#   7TH ACOUSTICS STARGAZER 3 R.csv
#   7TH ACOUSTICS SUPERNOVA L.csv
#   7TH ACOUSTICS SUPERNOVA R.csv
#   ACOUSTUNE HS2000MX MKII L.csv
#   ACOUSTUNE HS2000MX MKII R.csv
#   ACOUSTUNE RS1 L.csv
#   ACOUSTUNE RS1 R.csv
#   AFUL PERFORMER 5 L.csv
#   AFUL PERFORMER 5 R.csv
#   ANKER LIFE DOT 3i R.csv
#   ANKER LIFE NOTE 3i L.csv
#   ANKER LIFE NOTE 3i R.csv
#   Antdroid Target.csv
#   ASTELL N KERN AK ZERO1 L.csv
#   ASTELL N KERN AK ZERO1 R.csv
#   ASTELL N KERN UW100 L.csv
#   ASTELL N KERN UW100 R.csv
#   ASTROTEC VESNA L.csv
#   ASTROTEC VESNA R.csv
#   AUDIO HEKILI L.csv
#   AUDIO HEKILI R.csv
#   AUDIOSENSE AQ0 L.csv
#   AUDIOSENSE AQ0 R.csv
#   AUDIOSENSE AQ7 R.csv
#   AUDIOSENSE DT200 L.csv
#   AUDIOSENSE DT200 R.csv
#   AUDIOSENSE DT600 L.csv
#   AUDIOSENSE DT600 R.csv
#   AUNE JASPER L.csv
#   AUNE JASPER R.csv
#   AVARA AV3 L.csv
#   AVARA AV3 R.csv
#   AZLA AZEL L.csv
#   AZLA AZEL R.csv
#   Bad Guy Target.csv
#   BAMBOO FOREST BIRD ZHU SKYLARK L.csv
#   BAMBOO FOREST BIRD ZHU SKYLARK R.csv
#   Banbeucmas Target.csv
#   BEEMIX PISCES L.csv
#   BEEMIX PISCES R.csv
#   BGVP DH5 L.csv
#   BGVP DH5 R.csv
#   BGVP DN2 L.csv
#   BGVP DN2 R.csv
#   BGVP DN3 L.csv
#   BGVP DN3 R.csv
#   BGVP NS10 GOLD R.csv
#   BGVP NS10 L.csv
#   BGVP NS10 R.csv
#   BGVP NS10 RED R.csv
#   BGVP NS10 SILVER R.csv
#   BGVP NS9 DEF FILTER R.csv
#   BGVP NS9 RED FILTER R.csv
#   BGVP NS9 SILVER FILTER R.csv
#   BINARYACOUSTIC VOID R.csv
#   BLON BL03 R.csv
#   BLON BL07 L.csv
#   BLON BL07 R.csv
#   BLON FAT GIRL L.csv
#   BLON FAT GIRL R.csv
#   BLON MAX L.csv
#   BLON MAX R.csv
#   BLON MINI L.csv
#   BLON MINI R.csv
#   BQEYZ TOPAZ L.csv
#   BQEYZ TOPAZ R.csv
#   CAMPFIRE AUDIO ANDROMEDA S R.csv
#   CATEAR HITAM L.csv
#   CATEAR HITAM R.csv
#   CCA C10 R.csv
#   CCA CA10 L.csv
#   CCA CA10 R.csv
#   CCA CA16 PRO L.csv
#   CCA CA16 PRO R.csv
#   CCA CRA L.csv
#   CCA CRA R.csv
#   CCA CRA S2 L.csv
#   CCA CRA S2 R.csv
#   CCA CRA+ L.csv
#   CCA CRA+ R.csv
#   CCA CSN L.csv
#   CCA CSN R.csv
#   CCA HM20 L.csv
#   CCA HM20 R.csv
#   CCA NRA L.csv
#   CCA NRA R.csv
#   CCZ COFFEE BEAN L.csv
#   CCZ COFFEE BEAN R.csv
#   CCZ EMERALD L.csv
#   CCZ EMERALD R.csv
#   CCZ MELODY L.csv
#   CCZ MELODY R.csv
#   CCZ PLUME L.csv
#   CCZ PLUME R.csv
#   Crinacle Target.csv
#   CVJ CSN L.csv
#   CVJ CSN R.csv
#   DBE PR500 L.csv
#   DBE PR500 R.csv
#   Diffuse Field Target.csv
#   DIREM E3 R.csv
#   DRESSAGE 6+1 L.csv
#   DRESSAGE 6+1 R.csv
#   DUNU FALCON PRO ATMOSPHERIC R.csv
#   DUNU FALCON PRO REFERENCE L.csv
#   DUNU FALCON PRO REFERENCE R.csv
#   DUNU FALCON PRO TRANSPARENCY R.csv
#   DUNU KIMA L.csv
#   DUNU KIMA R.csv
#   DUNU SA6 L.csv
#   DUNU SA6 ON L.csv
#   DUNU SA6 ON R.csv
#   DUNU SA6 R.csv
#   DUNU TALOS OFF L.csv
#   DUNU TALOS OFF R.csv
#   DUNU TALOS ON L.csv
#   DUNU TALOS ON R.csv
#   DUNU TITAN 5 L.csv
#   DUNU TITAN 5 R.csv
#   DUNU TITAN S L.csv
#   DUNU TITAN S R.csv
#   DUNU ZEN PRO L.csv
#   DUNU ZEN PRO R.csv
#   EDIFIER NEOBUDS S CLASSIC L.csv
#   EDIFIER NEOBUDS S CLASSIC R.csv
#   EDIFIER NEOBUDS S DYNAMIC L.csv
#   EDIFIER NEOBUDS S DYNAMIC R.csv
#   EDIFIER NEOBUDS S L.csv
#   EDIFIER NEOBUDS S R.csv
#   ETYMOTIC ER4SR L.csv
#   ETYMOTIC ER4SR R.csv
#   Etymotic Target.csv
#   FAAEAL POPPY L.csv
#   FAAEAL POPPY R.csv
#   FIDUE SIRIUS R.csv
#   FIIL T1 PRO R.csv
#   FIIO F1 L.csv
#   FIIO F1 R.csv
#   FIIO FD5 LARGE NOZZLE L.csv
#   FIIO FD5 LARGE NOZZLE R.csv
#   FIIO FD5 SMALL NOZZLE L.csv
#   FIIO FD5 SMALL NOZZLE R.csv
#   FIIO FW5 L.csv
#   FIIO FW5 R.csv
#   FIIO JD3 L.csv
#   FIIO JD3 R.csv
#   FIIO JD7 L.csv
#   FIIO JD7 R.csv
#   FIIO JH3 L.csv
#   FIIO JH3 R.csv
#   FINAL AUDIO A4000 L.csv
#   FINAL AUDIO A4000 R.csv
#   FITEAR MH335 DW L.csv
#   FITEAR MH335 DW R.csv
#   FLARE AUDIO FLARES PRO L.csv
#   FLARE AUDIO FLARES PRO R.csv
#   FOSTEX TE02N L.csv
#   FOSTEX TE02N R.csv
#   Free Field Target.csv
#   GEEK WORLD GK10 L.csv
#   GEEK WORLD GK10 R.csv
#   Harman Target.csv
#   HIFIMAN RE 400 L.csv
#   HIFIMAN RE 400 R.csv
#   HZSOUND HEART MIRROR L.csv
#   HZSOUND HEART MIRROR R.csv
#   IEF neutral Target.csv
#   IEF neutral.csv
#   IKKO OH2 L.csv
#   IKKO OH2 R.csv
#   Innerfidelity ID Target.csv
#   Innerfidelity Target.csv
#   INTIME GO L.csv
#   INTIME GO R.csv
#   INTIME SORA LIGHT R.csv
#   INTIME SORA MIDNIGHT R.csv
#   JOYODIO SHINE 1 ON R.csv
#   JOYODIO SHINE 2 ON R.csv
#   JOYODIO SHINE 3 ON R.csv
#   JOYODIO SHINE 4 ON R.csv
#   JOYODIO SHINE ALL OFF L.csv
#   JOYODIO SHINE ALL OFF R.csv
#   JOYODIO SHINE ALL ON R.csv
#   JQ 4U L.csv
#   JQ 4U R.csv
#   JUZEAR 41T L.csv
#   JUZEAR 41T R.csv
#   KBEAR KS1 L.csv
#   KBEAR KS1 R.csv
#   KBEAR KS2 R.csv
#   KBEAR NEON L.csv
#   KBEAR NEON R.csv
#   KBEAR QINGLONG L.csv
#   KBEAR QINGLONG R.csv
#   KBEAR STORM L.csv
#   KBEAR STORM R.csv
#   KINERA BD005 PRO R.csv
#   KINERA CELEST GUMIHO L.csv
#   KINERA CELEST GUMIHO R.csv
#   KINERA HODUR L.csv
#   KINERA HODUR R.csv
#   KINERA IDUN GOLDEN L.csv
#   KINERA IDUN GOLDEN R.csv
#   KINERA SKULD L.csv
#   KINERA SKULD R.csv
#   KIWI EARS CADENZA L.csv
#   KIWI EARS CADENZA R.csv
#   KKI 1 BA SWITCH 1 L.csv
#   KKI 1 BA SWITCH 1 R.csv
#   KKI 1 BA SWITCH 2 L.csv
#   KKI 1 BA SWITCH 2 R.csv
#   KKI 1 BA SWITCH 3 L.csv
#   KKI 1 BA SWITCH 3 R.csv
#   KZ AS16 PRO L.csv
#   KZ AS16 PRO R.csv
#   KZ D-FI DDDD L.csv
#   KZ D-FI DDDD R.csv
#   KZ D-FI DDDU L.csv
#   KZ D-FI DDDU R.csv
#   KZ D-FI DDUD R.csv
#   KZ D-FI DUDD R.csv
#   KZ D-FI UDDD R.csv
#   KZ D-FI UUDD R.csv
#   KZ DQ6 R.csv
#   KZ DQ6S L.csv
#   KZ DQ6S R.csv
#   KZ EDA BALANCE L.csv
#   KZ EDA BALANCE R.csv
#   KZ EDA BASS L.csv
#   KZ EDA BASS R.csv
#   KZ EDA HIGH L.csv
#   KZ EDA HIGH R.csv
#   KZ EDX PRO L.csv
#   KZ EDX PRO R.csv
#   KZ EDX R.csv
#   KZ EDX ULTRA L.csv
#   KZ EDX ULTRA R.csv
#   KZ LINLONG L.csv
#   KZ LINLONG R.csv
#   KZ VXS L.csv
#   KZ VXS R.csv
#   KZ ZES L.csv
#   KZ ZES R.csv
#   KZ ZEX PRO L.csv
#   KZ ZEX PRO R.csv
#   KZ ZS10 PRO R.csv
#   KZ ZSN PRO L.csv
#   KZ ZSN PRO R.csv
#   KZ ZSN PRO X R.csv
#   KZ ZST X R.csv
#   KZ ZVX FINAL TIPS L.csv
#   KZ ZVX FINAL TIPS R.csv
#   KZ ZVX L.csv
#   KZ ZVX R.csv
#   LYPERTEK LEVI L.csv
#   LYPERTEK LEVI R.csv
#   LYPERTEK TEVI R.csv
#   LZ A7 BLACK MONITOR L.csv
#   LZ A7 BLACK MONITOR R.csv
#   LZ A7 BLACK POP R.csv
#   LZ A7 BLUE MONITOR R.csv
#   LZ A7 BLUE POP R.csv
#   LZ A7 GOLD MONITOR R.csv
#   LZ A7 GOLD POP R.csv
#   LZ A7 RED MONITOR R.csv
#   LZ A7 RED POP R.csv
#   LZ A7 SILVER MONITOR R.csv
#   LZ A7 SILVER POP R.csv
#   MADOO TYPE 512 L.csv
#   MADOO TYPE 512 R.csv
#   MANGIRD XENNS UP L.csv
#   MANGIRD XENNS UP R.csv
#   MASSDROP PLUS L.csv
#   MASSDROP PLUS R.csv
#   MEE X20 L.csv
#   MEE X20 R.csv
#   MOONDROP ARIA (OLD) L.csv
#   MOONDROP ARIA (OLD) R.csv
#   MOONDROP ARIA L.csv
#   MOONDROP ARIA R.csv
#   MOONDROP BLESSING 2 L.csv
#   MOONDROP BLESSING 2 R.csv
#   MOONDROP CHU L.csv
#   MOONDROP CHU R.csv
#   MOONDROP CRESCENT L.csv
#   MOONDROP CRESCENT R.csv
#   MOONDROP DROPLET L.csv
#   MOONDROP DROPLET R.csv
#   MOONDROP IX R.csv
#   MOONDROP KATO (BRASS) L.csv
#   MOONDROP KATO (BRASS) R.csv
#   MOONDROP KATO (COPPER) L.csv
#   MOONDROP KATO (COPPER) R.csv
#   MOONDROP KATO (SILVER) L.csv
#   MOONDROP KATO (SILVER) R.csv
#   MOONDROP KATO (STEEL) L.csv
#   MOONDROP KATO (STEEL) R.csv
#   MOONDROP KATO NON SPRING (BRASS) L.csv
#   MOONDROP KATO NON SPRING (BRASS) R.csv
#   MOONDROP KATO NON SPRING (STEEL) L.csv
#   MOONDROP KATO NON SPRING (STEEL) R.csv
#   MOONDROP KXXS R.csv
#   MOONDROP KXXX L.csv
#   MOONDROP KXXX R.csv
#   MOONDROP NEKOCAKE L.csv
#   MOONDROP NEKOCAKE R.csv
#   MOONDROP QUARKS L.csv
#   MOONDROP QUARKS R.csv
#   MOONDROP S8 L.csv
#   MOONDROP S8 R.csv
#   MOONDROP SPACESHIP R.csv
#   MOONDROP SPARKS L.csv
#   MOONDROP SPARKS R.csv
#   MOONDROP SSP L.csv
#   MOONDROP SSP R.csv
#   MOONDROP SSR L.csv
#   MOONDROP SSR R.csv
#   MOONDROP STARDUST L.csv
#   MOONDROP STARDUST R.csv
#   MOONDROP STELLARIS L.csv
#   MOONDROP STELLARIS R.csv
#   MOONDROP VARIATIONS L.csv
#   MOONDROP VARIATIONS R.csv
#   MR LEE 5+2 L.csv
#   MR LEE 5+2 R.csv
#   MR LEE AROUSE D8 L.csv
#   MR LEE AROUSE D8 R.csv
#   MR WATER ARIA L.csv
#   MR WATER ARIA R.csv
#   MUSEHIFI POWER L.csv
#   MUSEHIFI POWER R.csv
#   NFAUDIO NM2 L.csv
#   NFAUDIO NM2 R.csv
#   NICEHCK DB3 L.csv
#   NICEHCK DB3 R.csv
#   NYK AURORA L.csv
#   NYK AURORA R.csv
#   OMNIWAVE ALPHA R.csv
#   OMNIWAVE EUNOIA R.csv
#   OPERAFACTORY OM01 R.csv
#   PENON GLOBE L.csv
#   PENON GLOBE R.csv
#   PENON SPHERE R.csv
#   PLEXTONE RX1 L.csv
#   PLEXTONE RX1 R.csv
#   PMV PP L.csv
#   PMV PP R.csv
#   Precogvision Target.csv
#   QDC ANOLE VX 1 ON R.csv
#   QDC ANOLE VX 2 ON R.csv
#   QDC ANOLE VX 3 ON R.csv
#   QDC ANOLE VX ALL OFF L.csv
#   QDC ANOLE VX ALL OFF R.csv
#   QDC ANOLE VX ALL ON R.csv
#   QKZ QKZ X HBB L.csv
#   QKZ QKZ X HBB R.csv
#   QKZ VK4 R.csv
#   QKZ X HBB KHAN L.csv
#   QKZ X HBB KHAN R.csv
#   QKZ X HBB L.csv
#   QKZ X HBB R.csv
#   QOA GIMLET L.csv
#   QOA GIMLET R.csv
#   QOA VESPER L.csv
#   QOA VESPER R.csv
#   RADIUS NEF 31 L.csv
#   RADIUS NEF 31 R.csv
#   RAPTGO HOOK X HBB L.csv
#   RAPTGO HOOK X HBB R.csv
#   RAPTGO HOOK X L.csv
#   RAPTGO HOOK X R.csv
#   REECHO INSECTS AWAKEN L.csv
#   REECHO INSECTS AWAKEN R.csv
#   Rtings Target.csv
#   SEEAUDIO BRAVERY L.csv
#   SEEAUDIO BRAVERY R.csv
#   SEEAUDIO KAGUYA R.csv
#   SEEAUDIO NEO R.csv
#   SEEAUDIO YUME MIDNIGHT L.csv
#   SEEAUDIO YUME MIDNIGHT R.csv
#   SEEAUDIO YUME R.csv
#   SENFER MT300 L.csv
#   SENFER MT300 R.csv
#   SENNHEISER IE300 L.csv
#   SENNHEISER IE300 R.csv
#   SENNHEISER IE600 AET08 L.csv
#   SENNHEISER IE600 AET08 R.csv
#   SENNHEISER IE600 L.csv
#   SENNHEISER IE600 R.csv
#   SENNHEISER IE900 L.csv
#   SENNHEISER IE900 R.csv
#   SG AIRLINE IEM L.csv
#   SG AIRLINE IEM R.csv
#   SGOR VENUS L.csv
#   SGOR VENUS R.csv
#   SHANLING ME80 L.csv
#   SHANLING ME80 R.csv
#   SHANLING MTW300 L.csv
#   SHANLING MTW300 R.csv
#   SHUOER GALILEO L.csv
#   SHUOER GALILEO R.csv
#   SHUOER S12 L.csv
#   SHUOER S12 PRO L.csv
#   SHUOER S12 PRO R.csv
#   SHUOER S12 R.csv
#   SIMGOT EA500 CLASSIC L.csv
#   SIMGOT EA500 CLASSIC R.csv
#   SIMGOT EA500 HARMAN L.csv
#   SIMGOT EA500 HARMAN R.csv
#   SIMGOT EM2 ROLTION L.csv
#   SIMGOT EM2 ROLTION R.csv
#   SKALD S11 R.csv
#   SMABAT NCO L.csv
#   SMABAT NCO R.csv
#   SOFTEARS TWILIGHT L.csv
#   SOFTEARS TWILIGHT R.csv
#   Sonarworks Target.csv
#   SONY IER M9 L.csv
#   SONY IER M9 R.csv
#   SONY IER Z1R L.csv
#   SONY IER Z1R R.csv
#   SONY MH755 L.csv
#   SONY MH755 R.csv
#   Super Review Target.csv
#   SYMPHONIUM HELIOS L.csv
#   SYMPHONIUM HELIOS R.csv
#   SYMPHONIUM HELIOS SPINFIT L.csv
#   SYMPHONIUM HELIOS SPINFIT R.csv
#   T-FORCE YUAN LI (PRE FINAL) L.csv
#   T-FORCE YUAN LI (PRE FINAL) R.csv
#   T-FORCE YUAN LI L.csv
#   T-FORCE YUAN LI R.csv
#   TAGO T3-02 L.csv
#   TAGO T3-02 R.csv
#   TANCHJIM OXYGEN L.csv
#   TANCHJIM OXYGEN R.csv
#   TANCHJIM TANYA L.csv
#   TANCHJIM TANYA R.csv
#   TANGZU SHIMIN LI ENCOUNTER R.csv
#   TANGZU SHIMIN LI L.csv
#   TANGZU SHIMIN LI R.csv
#   TANGZU WAN ER L.csv
#   TANGZU WAN ER R.csv
#   TANGZU ZETIAN WU HEYDAY L.csv
#   TANGZU ZETIAN WU HEYDAY R.csv
#   TFZ ESSENCE R.csv
#   TFZ ESSENCE.csv
#   THHIFI FACE RED L.csv
#   THHIFI FACE RED R.csv
#   THIEAUDIO CLAIRVOYANCE L.csv
#   THIEAUDIO CLAIRVOYANCE R.csv
#   THIEAUDIO ELIXIR L.csv
#   THIEAUDIO ELIXIR R.csv
#   THIEAUDIO LEGACY 3 1 ON R.csv
#   THIEAUDIO LEGACY 3 2 ON R.csv
#   THIEAUDIO LEGACY 3 ALL ON R.csv
#   THIEAUDIO LEGACY 3 OFF L.csv
#   THIEAUDIO LEGACY 3 OFF R.csv
#   THIEAUDIO LEGACY 4 1 ON R.csv
#   THIEAUDIO LEGACY 4 2 ON R.csv
#   THIEAUDIO LEGACY 4 ALL ON R.csv
#   THIEAUDIO LEGACY 4 OFF R.csv
#   THIEAUDIO LEGACY 5 L.csv
#   THIEAUDIO LEGACY 5 R.csv
#   THIEAUDIO MONARCH MKII L.csv
#   THIEAUDIO MONARCH MKII R.csv
#   THIEAUDIO V16 DIVINITY L.csv
#   THIEAUDIO V16 DIVINITY R.csv
#   TIN BUDS 3 L.csv
#   TIN BUDS 3 R.csv
#   TIN C2 MECH WARRIOR L.csv
#   TIN C2 MECH WARROR R.csv
#   TIN P2 R.csv
#   TIN T2 2PIN L.csv
#   TIN T2 2PIN R.csv
#   TIN T2 EVO L.csv
#   TIN T2 EVO R.csv
#   TIN T2PLUS R.csv
#   TIN T3PLUS L.csv
#   TIN T3PLUS R.csv
#   TIN T5 L.csv
#   TIN T5 R.csv
#   TKZK WAVE L.csv
#   TKZK WAVE R.csv
#   TRI METEOR L.csv
#   TRI METEOR R.csv
#   TRI STAR RIVER 1 ON R.csv
#   TRI STAR RIVER 2 ON R.csv
#   TRI STAR RIVER ALL OFF L.csv
#   TRI STAR RIVER ALL OFF R.csv
#   TRI STAR RIVER ALL ON R.csv
#   TRIPOWIN OLINA (TANYA FILTER) L.csv
#   TRIPOWIN OLINA (TANYA FILTER) R.csv
#   TRIPOWIN OLINA L.csv
#   TRIPOWIN OLINA R.csv
#   TRIPOWIN OLINA VENT COVERED R.csv
#   TRIPOWIN TC01 R.csv
#   TRN BA5 L.csv
#   TRN BA5 R.csv
#   TRN CS1 L.csv
#   TRN CS1 R.csv
#   TRN KIRIN (ATMOSPHERIC FILTER) L.csv
#   TRN KIRIN (ATMOSPHERIC FILTER) R.csv
#   TRN KIRIN (REFERENCE FILTER) L.csv
#   TRN KIRIN (REFERENCE FILTER) R.csv
#   TRN KIRIN (TRANSPARENCY FILTER) L.csv
#   TRN KIRIN (TRANSPARENCY FILTER) R.csv
#   TRN MT1 L.csv
#   TRN MT1 R.csv
#   TRN MT3 L.csv
#   TRN MT3 R.csv
#   TRN V80 L.csv
#   TRN V80 R.csv
#   TRUTHEAR HEXA L.csv
#   TRUTHEAR HEXA R.csv
#   TRUTHEAR HOLA L.csv
#   TRUTHEAR HOLA R.csv
#   UNIQUE MELODY MENTOR L.csv
#   UNIQUE MELODY MENTOR R.csv
#   UNIQUE MELODY MEST L.csv
#   UNIQUE MELODY MEST MK2 L.csv
#   UNIQUE MELODY MEST MK2 R.csv
#   UNIQUE MELODY MEST R.csv
#   VE AZURE L.csv
#   VE AZURE R.csv
#   VIDO EARBUD L.csv
#   VIDO EARBUD R.csv
#   WEMLIK MISTY 1 R.csv
#   WEMLIK MISTY 2 R.csv
#   WHIZZER HE01 L.csv
#   WHIZZER HE01 R.csv
#   WILLSOUND DEWA COPPER L.csv
#   WILLSOUND DEWA COPPER R.csv
#   WILLSOUND DEWA SILVER L.csv
#   WILLSOUND DEWA SILVER R.csv
#   XUANERJI X01 R.csv
#   YANYIN MAHINA L.csv
#   YANYIN MAHINA R.csv
#   YANYIN MAHINA S2 L.csv
#   YANYIN MAHINA S2 R.csv
#   ZHULINNIAO JINGHONG L.csv
#   ZHULINNIAO JINGHONG R.csv
#
# Files in 'output/csv/animagus':
#   64 Audio U12t Sample 1 (M15) L.csv
#   64 Audio U12t Sample 1 (M15) R.csv
#   64 Audio U12t Sample 2 (M15) L.csv
#   64 Audio U12t Sample 3 (M15) L.csv
#   64 Audio U12t Sample 3 (M15) R.csv
#   64 Audio U12t Sample 3 (M20) L.csv
#   64 Audio U12t Sample 3 (M20) R.csv
#   Animagus Neutral Target.csv
#   Animagus Preference Target.csv
#   Antdroid Target.csv
#   Bad Guy Target.csv
#   Banbeucmas Target.csv
#   BGVP DH3 (00) L.csv
#   BGVP DH3 (02) L.csv
#   BGVP DH3 (10) L.csv
#   BGVP DH3 (12) L.csv
#   BGVP DM7 R.csv
#   BGVP DM8 R.csv
#   BGVP ES12 (000) L.csv
#   BGVP ES12 (000) R.csv
#   BGVP ES12 (100) L.csv
#   BGVP ES12 (100) R.csv
#   BGVP ES12 (110) L.csv
#   BGVP ES12 (110) R.csv
#   BGVP ES12 (111) L.csv
#   BGVP ES12 (111) R.csv
#   BGVP Melody (Balanced) L.csv
#   BGVP Melody (Balanced) R.csv
#   BGVP Melody (HiFi) L.csv
#   BGVP Melody (HiFi) R.csv
#   BGVP Melody (Pop) L.csv
#   BGVP Melody (Pop) R.csv
#   BGVP NE5 (Champagne Filter) L.csv
#   BGVP NE5 (Grey Filter) L.csv
#   BGVP NE5 (Red Filter) L.csv
#   Campfire Andromeda 2020 L.csv
#   Campfire Andromeda Pre-2020 L.csv
#   Campfire Andromeda Pre-2020 R.csv
#   Campfire Solaris 2020 R.csv
#   Campfire Supermoon Universal L.csv
#   Campfire Supermoon Universal R.csv
#   Crinacle Target.csv
#   Custom Art FIBAE 5 (Filter) L.csv
#   Custom Art FIBAE 5 (Filter) R.csv
#   Custom Art FIBAE 5 L.csv
#   Custom Art FIBAE 5 R.csv
#   Custom Art FIBAE 7 L.csv
#   Custom Art FIBAE 7U CIEM L.csv
#   Custom Art FIBAE 7U Universal L.csv
#   Diffuse Field Target.csv
#   DROP x Etymotic ERX R.csv
#   Dunu Talos (ON) L.csv
#   Dunu Talos (ON) R.csv
#   Dunu Talos L.csv
#   Dunu Talos R.csv
#   Empire Ears Odin Sample 1 L.csv
#   Empire Ears Odin Sample 1 R.csv
#   Empire Ears Odin Sample 2 L.csv
#   Empire Ears Odin Sample 3 L.csv
#   Etymotic Target.csv
#   FiR Audio XE6 UIEM L.csv
#   Free Field Target.csv
#   Harman In Ear 2019 Target.csv
#   Harman In Room Target.csv
#   Harman Over Ear 2018 Target.csv
#   Harman Target.csv
#   Innerfidelity ID Target.csv
#   ItsFit Fusion R.csv
#   KBEAR Aurora Matte L.csv
#   KBEAR Aurora Matte R.csv
#   Kinera Nanna 2.0 L.csv
#   Kinera Nanna 2.0 R.csv
#   Lime Ears Aether R (Bass Off) L.csv
#   Lime Ears Aether R (Bass On) L.csv
#   Lime Ears Anima (Spinfit) R.csv
#   Lime Ears Anima (Symbio) R.csv
#   Lime Ears Pneuma (Bass Off) L.csv
#   Lime Ears Pneuma (Bass On) L.csv
#   Moondrop A8 L.csv
#   Moondrop A8 R.csv
#   Moondrop Aria L.csv
#   Moondrop Aria R.csv
#   Moondrop Aria Snow Edition L.csv
#   Moondrop Aria Snow Edition R.csv
#   Moondrop Blessing2 L.csv
#   Moondrop Blessing2 R.csv
#   Moondrop Kato L.csv
#   Moondrop Kato R.csv
#   Moondrop KXXS (New Filters) L.csv
#   Moondrop KXXS (New Filters) R.csv
#   Moondrop S8 Sample 1 R.csv
#   Moondrop S8 Sample 2 R.csv
#   Moondrop Stellaris (Foam) L.csv
#   Moondrop Stellaris (Foam) R.csv
#   Moondrop Stellaris (UC) L.csv
#   Moondrop Stellaris (UC) R.csv
#   Precogvision Target.csv
#   Project HRP L.csv
#   Project HRP R.csv
#   Rtings Target.csv
#   Samsung Buds2 Pro (ANC) L.csv
#   Samsung Buds2 Pro (ANC) R.csv
#   Samsung Buds2 Pro (Passive) L.csv
#   Samsung Buds2 Pro (Passive) R.csv
#   Sennheiser IE600 L.csv
#   Shozy Ceres L.csv
#   Shozy Ceres R.csv
#   Shozy Elsa L.csv
#   Shozy Elsa R.csv
#   Shozy Pola39 (Shallow) L.csv
#   Shozy Pola39 (Shallow) R.csv
#   Shozy Pola39 L.csv
#   Shozy Pola39 R.csv
#   Shuoer S12 L.csv
#   Softears RS10 L.csv
#   Softears RSV L.csv
#   Softears RSV R.csv
#   SoftEars Turii Ti L.csv
#   SoftEars Turii Ti R.csv
#   Softears Twilight L.csv
#   Softears Volume (Foam) L.csv
#   Softears Volume (Foam) R.csv
#   Softears Volume (Silicone) L.csv
#   Softears Volume (Silicone) R.csv
#   Softears Volume (Ultraclear) L.csv
#   Softears Volume (Ultraclear) R.csv
#   Sonarworks Target.csv
#   Super Review Target.csv
#   Tanchjim Hana 2021 L.csv
#   Tanchjim Hana 2021 R.csv
#   Tanchjim Prism (Small Bore) R.csv
#   Tanchjim Prism (Wide Bore) R.csv
#   THHiFi Character (Small bore) L.csv
#   THHiFi Character (Small bore) R.csv
#   THHiFi Character (Wide bore) L.csv
#   THHiFi Character (Wide bore) R.csv
#   THHiFi Face Red (Small Bore) L.csv
#   THHiFi Face Red (Small Bore) R.csv
#   THHiFi Face Red (Wide bore) L.csv
#   THHiFi Face Red (Wide bore) R.csv
#   TRI Meteor L.csv
#   TRI Meteor R.csv
#   TRI Starlight R.csv
#   TRI Starsea (00) L.csv
#   TRI Starsea (00) R.csv
#   TRI Starsea (01) L.csv
#   TRI Starsea (01) R.csv
#   TRI Starsea (10) L.csv
#   TRI Starsea (10) R.csv
#   TRI Starsea (11) L.csv
#   TRI Starsea (11) R.csv
#   TruthEar Hexa L.csv
#   TruthEar Hexa R.csv
#   UE UE18+ Pro (2nd Gen) L.csv
#   UE UE18+ Pro (2nd Gen) R.csv
#   Vision Ears VE8 L.csv
#
# Files in 'output/csv/arn':
#   7Hz Salnotes Dioko L.csv
#   7Hz Salnotes Zero L.csv
#   7Hz Timeless L.csv
#   Antdroid Target.csv
#   Aria Snow L.csv
#   Bad Guy Target.csv
#   Banbeucmas Target.csv
#   BGVP VG4 off-off-off L.csv
#   BGVP VG4 off-off-on L.csv
#   BGVP VG4 off-on-off L.csv
#   BGVP VG4 off-on-on L.csv
#   BGVP VG4 on-off-off L.csv
#   BGVP VG4 on-on-off L.csv
#   BGVP VG4 on-on-on L.csv
#   BLON 03 Foam Mod L.csv
#   BLON Z200 L.csv
#   BQEYZ Autumn Bass L.csv
#   BQEYZ Autumn Normal L.csv
#   BQEYZ Autumn Treble L.csv
#   BQEYZ Spring 1 L.csv
#   BQEYZ Summer L.csv
#   BQEYZ Winter L.csv
#   BQEYZ Winter R.csv
#   CCZ Plume L.csv
#   CCZ Warrior L.csv
#   Co-Donguri Brass L.csv
#   Crinacle Target.csv
#   CVJ Mirror L.csv
#   ddHiFi Janus 2 L.csv
#   Diffuse Field Target.csv
#   DUNU Talos Planar L.csv
#   DUNU Talos Planar+BA L.csv
#   DUNU Titan S L.csv
#   DUNU Titan S R.csv
#   Enco X2 EQ Classic L.csv
#   Enco X2 EQ Punchy L.csv
#   Enco X2 EQ Real L.csv
#   Enco X2 EQ Simple & Clear L.csv
#   Etymotic Target.csv
#   FiiO JH3 L.csv
#   Final E4000 L.csv
#   Final ZE3000 L.csv
#   Free Field Target.csv
#   GK100 L.csv
#   GK100 R.csv
#   Harman Target.csv
#   Harman V2 Target.csv
#   Heart Mirror Pro L.csv
#   HeartField Deer L.csv
#   Hidizs MD4 Balanced L.csv
#   Hidizs MD4 Bass L.csv
#   Hidizs MD4 Treble L.csv
#   Hidizs MD4 Warm L.csv
#   Hidizs Mermaid MM2 L.csv
#   Humka Hamlet M L.csv
#   IKKO OH1s L.csv
#   IKKO OPAL OH2 L.csv
#   Innerfidelity ID Target.csv
#   JD7 L.csv
#   JD7 R.csv
#   KBEAR Believe L.csv
#   KBEAR Dumpling L.csv
#   KBEAR INK L.csv
#   KBEAR Little Q L.csv
#   KBEAR Ormosia L.csv
#   KBEAR Qinglong L.csv
#   KBEAR Qinglong R.csv
#   KBEAR Rosefinch L.csv
#   Kinera Celest Gumiho L.csv
#   Kinera Celest Pandamon L.csv
#   Kinera Celest Pandamon R.csv
#   Kinera Hodur L.csv
#   Kiwi Ears CADENZA L.csv
#   Kiwi Ears CADENZA R.csv
#   KZ D-Fi L.csv
#   KZ D-Fi R.csv
#   KZ ESX L.csv
#   KZ PR1 HiFi L.csv
#   KZ PR1 HiFi R.csv
#   KZ PR1 Pro L.csv
#   KZ PR1 Pro R.csv
#   LETSHUOER S12 L.csv
#   Meze 12 Classics V2 L.csv
#   Meze Rai Solo L.csv
#   Moondrop Chu L.csv
#   MOONDROP Droplet L.csv
#   MOONDROP Droplet R.csv
#   Moondrop LAN L.csv
#   Moondrop LAN R.csv
#   MS5 Balanced L.csv
#   MS5 Balanced R.csv
#   MS5 Bass L.csv
#   MS5 Bass R.csv
#   MS5 Treble L.csv
#   MS5 Treble R.csv
#   NF Audio NA3 L.csv
#   OnePlus Bullets 2 L.csv
#   OURART Wine L.csv
#   Precogvision Target.csv
#   Project HRP L.csv
#   Project HRP R.csv
#   QKZ Khan L.csv
#   QKZ Khan R.csv
#   QKZ x HBB L.csv
#   QoA Gimlet L.csv
#   QoA Gimlet R.csv
#   Rtings Target.csv
#   Sonarworks Target.csv
#   Super Review Target.csv
#   T4 Plus L.csv
#   T4 Plus R.csv
#   Tanchjim Ola L.csv
#   Tanchjim Zero L.csv
#   TANGZU Shimin Li L.csv
#   TANGZU WAN-ER S.G L.csv
#   ThieAudio Elixir L.csv
#   ThieAudio Elixir R.csv
#   TINHiFi Buds 3 L.csv
#   TinHiFi C2 L.csv
#   TinHiFi C2 R.csv
#   TinHiFi C3 R.csv
#   TINHiFi C5 L.csv
#   TINHiFi C5 R.csv
#   TINHiFi P1 Plus L.csv
#   TINHiFi T1S L.csv
#   TINHiFi T2 DLC L.csv
#   Tipsy TTROMSO L.csv
#   TRI i3 Pro L.csv
#   TRI x HBB KAI L.csv
#   Tripowin Leá L.csv
#   TRN Bax L.csv
#   TRN Kirin Atmospheric L.csv
#   TRN Kirin Reference L.csv
#   TRN Kirin Transparency L.csv
#   TRN MT1 Pro L.csv
#   TRN ST5 L.csv
#   TRN Xuanwu L.csv
#   TRN Xuanwu R.csv
#   Trurhear HOLA L.csv
#   Trurhear HOLA R.csv
#   Truthear HEXA L.csv
#   Truthear HEXA R.csv
#   Truthear Zero L.csv
#   Truthear Zero R.csv
#   VE Bonus IE L.csv
#   Whizzer BS1 L.csv
#   Whizzer HE01 L.csv
#   Whizzer HE03D L.csv
#
# Files in 'output/csv/bedrock':
#   7Hz Dioko L.csv
#   7Hz Dioko R.csv
#   7Hz Eternal L.csv
#   7Hz Eternal R.csv
#   7Hz Zero L.csv
#   7Hz Zero R.csv
#   Ambient Dynamics AD-006 L.csv
#   Ambient Dynamics AD-006 R.csv
#   Antdroid Target.csv
#   Bad Guy Target.csv
#   Banbeucmas Target.csv
#   Blon BL-05 L.csv
#   Blon BL-05 R.csv
#   Blon BL-05S L.csv
#   Blon BL-05S R.csv
#   BQEYZ Autumn (Bass) L.csv
#   BQEYZ Autumn (Bass) R.csv
#   BQEYZ Autumn (Normal) L.csv
#   BQEYZ Autumn (Normal) R.csv
#   BQEYZ Autumn (Treble) L.csv
#   BQEYZ Autumn (Treble) R.csv
#   CCA C10 L.csv
#   CCA C10 Pro L.csv
#   CCA C10 Pro R.csv
#   CCA C10 R.csv
#   CCA CRA+ L.csv
#   CCA CRA+ R.csv
#   CCA CSN L.csv
#   CCA CSN R.csv
#   Crinacle Target.csv
#   CVJ CSA L.csv
#   CVJ CSA R.csv
#   Diffuse Field Target.csv
#   Dunu DM-480 L.csv
#   Dunu DM-480 R.csv
#   Dunu Falcon Pro (Atmospheric Immersion) L.csv
#   Dunu Falcon Pro (Atmospheric Immersion) R.csv
#   Dunu Falcon Pro (Reference) L.csv
#   Dunu Falcon Pro (Reference) R.csv
#   Dunu Falcon Pro (Transparency) L.csv
#   Dunu Falcon Pro (Transparency) R.csv
#   Dunu Kima L.csv
#   Dunu Kima R.csv
#   Dunu Talos (Switch Off) L.csv
#   Dunu Talos (Switch Off) R.csv
#   Dunu Talos (Switch On) L.csv
#   Dunu Talos (Switch On) R.csv
#   Dunu Titan S L.csv
#   Dunu Titan S R.csv
#   Dunu Vulkan L.csv
#   Dunu Vulkan R.csv
#   Etymotic Target.csv
#   EZAudio D4 (Modded) L.csv
#   EZAudio D4 (Modded) R.csv
#   EZAudio X3 L.csv
#   EZAudio X3 R.csv
#   Fiio F1 L.csv
#   Fiio F1 R.csv
#   Free Field Target.csv
#   Harman Target.csv
#   HZSound Waist Drum L.csv
#   HZSound Waist Drum R.csv
#   Innerfidelity ID Target.csv
#   Jade Audio EA3 L.csv
#   Jade Audio EA3 R.csv
#   KBEAR Diamond L.csv
#   KBEAR Diamond R.csv
#   KBEAR KB04 L.csv
#   KBEAR KB04 R.csv
#   KBEAR KS2 L.csv
#   KBEAR KS2 R.csv
#   KBEAR Lark L.csv
#   KBEAR Lark R.csv
#   Kinera BD005 Pro L.csv
#   Kinera BD005 Pro R.csv
#   Kinera Tyr L.csv
#   Kinera Tyr R.csv
#   Kiwi Ears Cadenza L.csv
#   Kiwi Ears Cadenza R.csv
#   Kiwi Ears Orchestra Lite L.csv
#   Kiwi Ears Orchestra Lite R.csv
#   KZ CRN L.csv
#   KZ CRN R.csv
#   KZ DQ6S L.csv
#   KZ DQ6S R.csv
#   Letshuoer D13 (Gold) L.csv
#   Letshuoer D13 (Gold) R.csv
#   Letshuoer D13 (Silver) L.csv
#   Letshuoer D13 (Silver) R.csv
#   Meeture MT3 L.csv
#   Meeture MT3 R.csv
#   Moondrop Aria L.csv
#   Moondrop Aria R.csv
#   Moondrop Chu L.csv
#   Moondrop Chu R.csv
#   Moondrop Lan L.csv
#   Moondrop Lan R.csv
#   Moondrop Quarks L.csv
#   Moondrop Quarks R.csv
#   Moondrop S8 L.csv
#   Moondrop S8 R.csv
#   Moondrop SSP L.csv
#   Moondrop SSP R.csv
#   Moondrop SSR L.csv
#   Moondrop SSR R.csv
#   Moondrop Stellaris L.csv
#   Moondrop Stellaris R.csv
#   Nicehck M6 L.csv
#   Nicehck M6 R.csv
#   Nicehck N3 L.csv
#   Nicehck N3 R.csv
#   Nicehck X49 L.csv
#   Nicehck X49 R.csv
#   Precogvision Target.csv
#   Raptgo Hook-X L.csv
#   Raptgo Hook-X R.csv
#   Rtings Target.csv
#   SeeAudio Bravery L.csv
#   SeeAudio Bravery R.csv
#   SeeAudio Yume L.csv
#   SeeAudio Yume R.csv
#   Simgot EM1 L.csv
#   Simgot EM1 R.csv
#   Sonarworks Target.csv
#   Super Review Target.csv
#   Tanchjim Ola L.csv
#   Tanchjim Ola R.csv
#   Tanchjim Tanya L.csv
#   Tanchjim Tanya R.csv
#   Thieaudio Legacy 2 L.csv
#   Thieaudio Legacy 2 R.csv
#   Thieaudio Voyager 3 (00) L.csv
#   Thieaudio Voyager 3 (00) R.csv
#   Thieaudio Voyager 3 (02) L.csv
#   Thieaudio Voyager 3 (02) R.csv
#   Thieaudio Voyager 3 (10) L.csv
#   Thieaudio Voyager 3 (10) R.csv
#   Thieaudio Voyager 3 (12) L.csv
#   Thieaudio Voyager 3 (12) R.csv
#   TinHiFi C2 L.csv
#   TinHiFi C2 R.csv
#   TinHiFi C3 L.csv
#   TinHiFi C3 R.csv
#   TinHiFi C5 L.csv
#   TinHiFi C5 R.csv
#   TinHiFi T1S L.csv
#   TinHiFi T1S R.csv
#   TinHiFi T2 DLC L.csv
#   TinHiFi T2 DLC R.csv
#   TinHiFi T2 Plus L.csv
#   TinHiFi T2 Plus R.csv
#   TinHiFi T3 Plus L.csv
#   TinHiFi T3 Plus R.csv
#   TinHiFi T4 Plus L.csv
#   TinHiFi T4 Plus R.csv
#   TinHiFi T5 L.csv
#   TinHiFi T5 R.csv
#   TRN BA8 L.csv
#   TRN BA8 R.csv
#   TRN STM (Blue) L.csv
#   TRN STM (Blue) R.csv
#   TRN STM (Gold) L.csv
#   TRN STM (Gold) R.csv
#   TRN STM (Red) L.csv
#   TRN STM (Red) R.csv
#   TRN V90S L.csv
#   TRN V90S R.csv
#   TRN VX L.csv
#   TRN VX R.csv
#   Truthear Hexa L.csv
#   Truthear Hexa R.csv
#   Truthear Hola L.csv
#   Truthear Hola R.csv
#   Truthear Zero L.csv
#   Truthear Zero R.csv
#   UiiSii CM5 L.csv
#   UiiSii CM5 R.csv
#   Yinyoo Ash L.csv
#   Yinyoo Ash R.csv
#   Yinyoo V2 L.csv
#   Yinyoo V2 R.csv
#
# Files in 'output/csv/bryaudioreviews':
#   2ht L.csv
#   2ht R.csv
#   Acoustune hs1650cu L.csv
#   Acoustune hs1650cu R.csv
#   Acoustune RS One L.csv
#   Acoustune RS One R.csv
#   Antdroid Target.csv
#   Audiosense DT200 L.csv
#   Audiosense DT200 R.csv
#   Bad Guy Target.csv
#   Banbeucmas Target.csv
#   BGVP DH5 L.csv
#   BGVP DH5 R.csv
#   BGVP DN3 L.csv
#   BGVP DN3 R.csv
#   BLON BL01 L.csv
#   BLON BL01 R.csv
#   BLON BL03 L.csv
#   BLON BL03 R.csv
#   BQEYZ Autum Bass L.csv
#   BQEYZ Autumn Bass R.csv
#   BQEYZ Autumn Normal L.csv
#   BQEYZ Autumn Normal R.csv
#   BQEYZ Autumn Treble L.csv
#   BQEYZ Autumn Treble R.csv
#   BQEYZ Spring 2 L.csv
#   BQEYZ Spring 2 R.csv
#   BQEYZ Summer L.csv
#   BQEYZ Summer R.csv
#   Bry Audio Reviews Target.csv
#   CatEar Hitam final tuning L.csv
#   CatEar Hitam final tuning R.csv
#   CatEar HITAM preproduction L.csv
#   CatEar HITAM preproduction R.csv
#   Cayin YB04 dualflange L.csv
#   Cayin YB04 dualflange R.csv
#   Cayin YB04 L.csv
#   Cayin YB04 R.csv
#   Cayin YB04 triflange L.csv
#   Cayin YB04 trilange R.csv
#   CCZ Plume L.csv
#   CCZ Plume R.csv
#   Crinacle IEF-Neutral Target.csv
#   Crinacle Target.csv
#   CVJ Angel Wings L.csv
#   CVJ Angel Wings R.csv
#   CVJ CSN L.csv
#   CVJ CSN R.csv
#   Diffuse Field Target.csv
#   Dunu Titan S L.csv
#   Dunu Titan S R.csv
#   Effect Audio GAEA L.csv
#   Effect Audio GAEA R.csv
#   Etymotic Target.csv
#   Final Audio B3 L.csv
#   Final Audio B3 R.csv
#   Final Audio e5000 L.csv
#   Final Audio e5000 R.csv
#   Free Field Target.csv
#   Harman 2017 Target.csv
#   Harman 2019 Target.csv
#   Harman Target.csv
#   Heart Mirror L.csv
#   Heart Mirror R.csv
#   Hidizs MS5 1Ohm L.csv
#   Hidizs MS5 1Ohm R.csv
#   Hidizs MS5 2Ohm L.csv
#   Hidizs MS5 2Ohm R.csv
#   Hidizs MS5 Bass L.csv
#   Hidizs MS5 Bass R.csv
#   Hidizs MS5 High OI L.csv
#   Hidizs MS5 High OI R.csv
#   Hidizs MS5 L.csv
#   Hidizs MS5 R.csv
#   Hidizs MS5 Treble L.csv
#   Hidizs MS5 Treble R.csv
#   Hisenior Fe3U L.csv
#   Hisenior Fe3U R.csv
#   Hisenior T2 Classic L.csv
#   Hisenior T2 Classic R.csv
#   HZSound Zero L.csv
#   HZSound Zero no foam L.csv
#   HZSound Zero no foam R.csv
#   HZSound Zero R.csv
#   Innerfidelity ID Target.csv
#   JVC FD02 L.csv
#   JVC FD02 R.csv
#   KB Ear Aurora L.csv
#   KB Ear Aurora R.csv
#   KB Ear BElieve L.csv
#   KB Ear BElieve R.csv
#   KB Ear Diamond L.csv
#   KB Ear Diamond R.csv
#   KB Ear KS2 L.csv
#   KB Ear KS2 R.csv
#   KB Ear Neon triflange L.csv
#   KB Ear Neon triflange R.csv
#   KB Ear Robin L.csv
#   KB Ear Robin R.csv
#   KBEar BElieve new filter L.csv
#   KBEar BElieve new filter R.csv
#   KBEar BElieve Y2 Mod L.csv
#   KBEar BElieve Y2 Mod R.csv
#   KBEar Little Q L.csv
#   KBEar Little Q R.csv
#   KBEar Neon 75Ohm L.csv
#   KBEar Neon 75ohm R.csv
#   KBEAR Neon L.csv
#   KBEar Neon mod L.csv
#   KBEar Neon mod R.csv
#   KBEAR Neon R.csv
#   KBEar Ormosia L.csv
#   KBEar Ormosia R.csv
#   KBEAR Storm L.csv
#   KBEAR Storm R.csv
#   Kotori Dauntless L.csv
#   Kotori Dauntless R.csv
#   Kotori Vampire pre-release L.csv
#   Kotori Vampire pre-release R.csv
#   KZ ZEX L.csv
#   KZ ZEX R.csv
#   KZ ZSN Pro X L.csv
#   KZ ZSN Pro X R.csv
#   Moondrop Aria L.csv
#   Moondrop Aria R.csv
#   Moondrop LAN L.csv
#   Moondrop LAN R.csv
#   Moondrop SSR L.csv
#   Moondrop SSR R.csv
#   Moondrop Stellaris L.csv
#   Moondrop Stellaris modded L.csv
#   Moondrop Stellaris modded R.csv
#   Moondrop Stellaris R.csv
#   Moondrop Variations L.csv
#   Moondrop Variations R.csv
#   NOTBRAND NOTBLON L.csv
#   NOTBRAND NOTBLON R.csv
#   Oratory1990 Target.csv
#   Precogvision Target.csv
#   Proto1 green gold no L.csv
#   Proto1 green gold no R.csv
#   Proto1 green gold yes L.csv
#   Proto1 green gold yes R.csv
#   Proto1 green red no L.csv
#   Proto1 green red no R.csv
#   Proto1 green red yes L.csv
#   Proto1 green red yes R.csv
#   Proto1 green silver no L.csv
#   Proto1 green silver no R.csv
#   Proto1 green silver yes L.csv
#   Proto1 green silver yes R.csv
#   Proto1 red gold no L.csv
#   Proto1 red gold no R.csv
#   Proto1 red gold yes1 L.csv
#   Proto1 red gold yes1 R.csv
#   Proto1 red red no L.csv
#   Proto1 red red no R.csv
#   Proto1 red red yes L.csv
#   Proto1 red red yes R.csv
#   Proto1 red silver no L.csv
#   Proto1 red silver no R.csv
#   Proto1 red silver yes L.csv
#   Proto1 red silver yes R.csv
#   Rtings Target.csv
#   SeeAudio Bravery L.csv
#   SeeAudio Bravery R.csv
#   SeeAudio Midnight L.csv
#   SeeAudio Midnight R.csv
#   SeeAudio Yume L.csv
#   SeeAudio Yume R.csv
#   Sonarworks Target.csv
#   Sony IER M7 L.csv
#   Sony IER M7 R.csv
#   Sony MH1c L.csv
#   Sony MH1c R.csv
#   Sony MH755 L.csv
#   Sony MH755 R.csv
#   Strauss em205 L.csv
#   Strauss em205 R.csv
#   Super Review Target.csv
#   Tanchjim Hana21 L.csv
#   Tanchjim Hana21 R.csv
#   Tanchjim OLA L.csv
#   Tanchjim OLA R.csv
#   Tanchjim Oxygen L.csv
#   Tanchjim Oxygen R.csv
#   Tanchjim Tanya L.csv
#   Tanchjim Tanya R.csv
#   Tanchjim Zero L.csv
#   Tanchjim Zero R.csv
#   TForce Yuan Li L.csv
#   TForce Yuan Li Modded L.csv
#   TForce Yuan Li Modded R.csv
#   TForce Yuan Li R.csv
#   Tin Hifi C3 L.csv
#   Tin Hifi C3 R.csv
#   Tin T3 Plus L.csv
#   Tin T3 Plus R.csv
#   TKZK Wave L.csv
#   TKZK Wave R.csv
#   Tri i3 Pro L.csv
#   Tri i3 Pro R.csv
#   Tri Meteor L.csv
#   Tri Meteor R.csv
#   Tri Star River Bass L.csv
#   Tri Star River Bass R.csv
#   Tri Star River Natural L.csv
#   Tri Star River Natural R.csv
#   Tri Star River Pop L.csv
#   Tri Star River Pop R.csv
#   Tri Star River Treble L.csv
#   Tri Star River Treble R.csv
#   TRN BA8 L.csv
#   TRN BA8 R.csv
#   TRN M10 L.csv
#   TRN M10 R.csv
#   TRN MT1 L.csv
#   TRN MT1 R.csv
#   TRN STM L.csv
#   TRN STM R.csv
#   TRN TA L.csv
#   TRN TA R.csv
#   TRN TA1 L.csv
#   TRN TA1 R.csv
#   TRN TA2 L.csv
#   TRN TA2 R.csv
#   TRN V90 L.csv
#   TRN V90 R.csv
#   TRN VX L.csv
#   TRN VX Pro L.csv
#   TRN VX Pro R.csv
#   TRN VX R.csv
#   TRN X7 L.csv
#   TRN X7 R.csv
#   Truthear HOLA L.csv
#   Truthear HOLA R.csv
#   Yuan Li FINAL L.csv
#   Yuan Li FINAL R.csv
#
# Files in 'output/csv/cammyfi':
#   Antdroid Target.csv
#   Bad Guy Target.csv
#   Banbeucmas Target.csv
#   Broken Variations.csv
#   CammyFi Neutral Target.csv
#   CammyFi Target.csv
#   Crinacle Target.csv
#   Diffuse Field Target.csv
#   Etymotic ER2SE L.csv
#   Etymotic ER2SE R.csv
#   Etymotic Target.csv
#   Free Field Target.csv
#   Harman IE 2019 v2 Target.csv
#   Harman Target.csv
#   Innerfidelity ID Target.csv
#   JBuds Pro L.csv
#   JBuds Pro R.csv
#   KBear Storm L.csv
#   KBear Storm R.csv
#   Kiwi Ears Cadenza L.csv
#   Kiwi Ears Cadenza R.csv
#   Kurin Target.csv
#   Letshuoer S12 PRO L.csv
#   Letshuoer S12 PRO R.csv
#   Letshuoer S12 PRO Vents Blocked 300 Damping L.csv
#   Letshuoer S12 PRO Vents Blocked L.csv
#   Letshuoer x Gizaudio Galileo L.csv
#   Letshuoer x Gizaudio Galileo R.csv
#   MH150 L.csv
#   MH150 R.csv
#   Mixx Earphones L.csv
#   Moondrop Chu L.csv
#   Moondrop Chu R.csv
#   Moondrop Lan L.csv
#   Moondrop Lan R.csv
#   Moondrop Quarks DSP L.csv
#   Moondrop Quarks DSP R.csv
#   Moondrop Variations L.csv
#   Moondrop Variations Manufacturer Measurment L.csv
#   Moondrop Variations Manufacturer Measurment R.csv
#   Moondrop Variations R.csv
#   PR1 PRO L.csv
#   PR1 PRO R.csv
#   Precogvision Target.csv
#   Project HRP L.csv
#   Project HRP R.csv
#   Pusheen Buds L.csv
#   Rtings Target.csv
#   Salnotes Zero L.csv
#   Salnotes Zero R.csv
#   Sennheiser CX80S L.csv
#   Sennheiser CX80S R.csv
#   Sennheiser MOMENTUM True Wireless 2 L.csv
#   Sennheiser MOMENTUM True Wireless 2 R.csv
#   Sennheiser MOMENTUM True Wireless 3 L.csv
#   Sennheiser MOMENTUM True Wireless 3 R.csv
#   Skullcandy Dime L.csv
#   Skullcandy Dime R.csv
#   Sonarworks Target.csv
#   Sony MDR-EX15AP L.csv
#   Sony MDR-EX15AP R.csv
#   Super Review Target.csv
#   T160 L.csv
#   T160 R.csv
#   Tanchjim Ola Bass L.csv
#   Tanchjim Ola Bass R.csv
#   Tanchjim Tanya L.csv
#   Tanchjim Tanya R.csv
#   Tanchjim Zero L.csv
#   Tanchjim Zero R.csv
#   Tri Kai L.csv
#   Tri Kai R.csv
#   Truthear Hexa L.csv
#   Truthear Hexa R.csv
#   Waner L.csv
#   Waner R.csv
#   ZAR L.csv
#   ZAR R.csv
#   Zetian Wu L.csv
#   Zetian Wu R.csv
#
# Files in 'output/csv/soundjedi':
#   64 Audio Fourte L.csv
#   64 Audio Fourte Noir L.csv
#   64 Audio Fourte Noir R.csv
#   64 Audio Fourte R.csv
#   64 Audio U12t L.csv
#   64 Audio U12t R.csv
#   64 Audio U6t L.csv
#   64 Audio U6t R.csv
#   7Hz Timeless L.csv
#   7Hz Timeless R.csv
#   Antdroid Target.csv
#   Aroma Jewel L.csv
#   Aroma Jewel R.csv
#   Astell Kern Odyssey L.csv
#   Astell Kern Odyssey R.csv
#   AuR Audio Allure L.csv
#   AuR Audio Allure R.csv
#   AuR Audio Neon L.csv
#   AuR Audio Neon R.csv
#   Bad Guy Target.csv
#   Banbeucmas Target.csv
#   Campfire Audio Supermoon L.csv
#   Campfire Audio Supermoon R.csv
#   Crinacle Target.csv
#   Diffuse Field Target.csv
#   Dunu SA6 Ultra L.csv
#   Dunu SA6 Ultra R.csv
#   Elysian Diva Bass Heavy L.csv
#   Elysian Diva Bass Heavy R.csv
#   Elysian Diva Bass Light L.csv
#   Elysian Diva Bass Light R.csv
#   Elysian Diva L.csv
#   Elysian Diva R.csv
#   Elysian X Elise L.csv
#   Elysian X Elise R.csv
#   Empire Ears Evo L.csv
#   Empire Ears Evo R.csv
#   Empire Ears Legend Evo L.csv
#   Empire Ears Legend Evo R.csv
#   Empire Ears LX L.csv
#   Empire Ears LX R.csv
#   Empire Ears LX SE L.csv
#   Empire Ears LX SE R.csv
#   Etymotic Target.csv
#   Fatfreq Maestro Mini L.csv
#   Fatfreq Maestro Mini R.csv
#   Fatfreq Maestro SE L.csv
#   Fatfreq Maestro SE R.csv
#   Fir Audio KR5 Black Atom L.csv
#   Fir Audio KR5 Black Atom R.csv
#   Fir Audio KR5 Silver Atom L.csv
#   Fir Audio KR5 Silver Atom R.csv
#   FiR Audio M4 L.csv
#   FiR Audio M4 R.csv
#   FiR Audio M5 L.csv
#   FiR Audio M5 R.csv
#   FiR Audio NE4 Black Atom L.csv
#   FiR Audio NE4 Black Atom R.csv
#   FiR Audio RN6 L.csv
#   FiR Audio RN6 R.csv
#   FiR Audio VxV L.csv
#   FiR Audio VxV R.csv
#   FiR Audio XE6 Black Atom L.csv
#   FiR Audio XE6 Black Atom R.csv
#   FiR Audio XE6 Gold Atom L.csv
#   FiR Audio XE6 Gold Atom R.csv
#   FiR Audio XE6 Silver Atom L.csv
#   FiR Audio XE6 Silver Atom R.csv
#   Free Field Target.csv
#   Harman Target.csv
#   Hidition Viento B L.csv
#   Hidition Viento B R.csv
#   Hidition Violet L.csv
#   Hidition Violet R.csv
#   InEar PMX L.csv
#   InEar PMX R.csv
#   Innerfidelity ID Target.csv
#   ISN H40 L.csv
#   ISN H40 R.csv
#   ISN H50 L.csv
#   ISN H50 R.csv
#   Jomo GT600 L.csv
#   Jomo GT600 R.csv
#   Kinera Nanna2 L.csv
#   Kinera Nanna2 R.csv
#   Kinera Skuld L.csv
#   Kinera Skuld R.csv
#   LetShuoer Cadenza 12 L.csv
#   LetShuoer Cadenza 12 R.csv
#   LetShuoer EJ07M Lava L.csv
#   LetShuoer EJ07M Lava R.csv
#   LetShuoer S12 L.csv
#   LetShuoer S12 R.csv
#   LimeEars Anima L.csv
#   LimeEars Anima R.csv
#   MiM Dark Magician L.csv
#   MiM Dark Magician R.csv
#   MiM Dark Magician V2 L.csv
#   MiM Dark Magician V2 R.csv
#   MMR Thummim L.csv
#   MMR Thummim R.csv
#   Nostalgia Audio Camelot L.csv
#   Nostalgia Audio Camelot R.csv
#   oBravo Ra 21 C-Cu L.csv
#   oBravo Ra 21 C-Cu R.csv
#   Oriolus Percivali L.csv
#   Oriolus Percivali R.csv
#   Oriolus Trailli L.csv
#   Oriolus Trailli R.csv
#   PlusSound Allegro L.csv
#   PlusSound Allegro R.csv
#   Precogvision Target.csv
#   QDC Anole VX 001 L.csv
#   QDC Anole VX 001 R.csv
#   QDC Anole VX 011 L.csv
#   QDC Anole VX 011 R.csv
#   QDC Anole VX 100 L.csv
#   QDC Anole VX 100 R.csv
#   QDC Anole VX 110 L.csv
#   QDC Anole VX 110 R.csv
#   QDC Anole VX 111 L.csv
#   QDC Anole VX 111 R.csv
#   QDC Anole VX L.csv
#   QDC Anole VX R.csv
#   Rtings Target.csv
#   Sample 1 Deep L.csv
#   Sample 1 Deep R.csv
#   Sample 1 L.csv
#   Sample 1 R.csv
#   Sample 2 L.csv
#   Sample 2 R.csv
#   Sample 3 L.csv
#   Sample 3 R.csv
#   Sample 4 L.csv
#   Sample 4 R.csv
#   SeeAudio Neo L.csv
#   SeeAudio Neo R.csv
#   SeeAudio Yume2 L.csv
#   SeeAudio Yume2 R.csv
#   Sennheiser IE600 L.csv
#   Sennheiser IE600 R.csv
#   Sennheiser IE900 L.csv
#   Sennheiser IE900 R.csv
#   Shortbus Eru L.csv
#   Shortbus Eru R.csv
#   Softears RSV L.csv
#   Softears RSV R.csv
#   Softears Twilight L.csv
#   Softears Twilight R.csv
#   Sonarworks Target.csv
#   Sony IER-Z1R L.csv
#   Sony IER-Z1R R.csv
#   Subtonic Storm 004 L.csv
#   Subtonic Storm 004 R.csv
#   Super Review Target.csv
#   Symphonium Helios L.csv
#   Symphonium Helios R.csv
#   Symphonium Meteor Sample L.csv
#   Symphonium Meteor Sample R.csv
#   Symphonium Triton L.csv
#   Symphonium Triton R.csv
#   Tangzu Zetian Wu L.csv
#   Tangzu Zetian Wu R.csv
#   ThieAudio L9 L.csv
#   ThieAudio L9 R.csv
#   ThieAudio Monarch MKII L.csv
#   ThieAudio Monarch MKII R.csv
#   ThieAudio Oracle MKII deep L.csv
#   ThieAudio Oracle MKII deep R.csv
#   ThieAudio Oracle MKII L.csv
#   ThieAudio Oracle MKII R.csv
#   ThieAudio Prestige Deep L.csv
#   ThieAudio Prestige Deep R.csv
#   ThieAudio Prestige L.csv
#   ThieAudio Prestige R.csv
#   ThieAudio V16 L.csv
#   ThieAudio V16 R.csv
#   Tripowin x HBB Olina L.csv
#   Tripowin x HBB Olina R.csv
#   Unique Melody Fabled Sound L.csv
#   Unique Melody Fabled Sound R.csv
#   Unique Melody MEST Indigo L.csv
#   Unique Melody MEST Indigo R.csv
#   Unique Melody MEST MKII  L.csv
#   Unique Melody MEST MKII  R.csv
#   Unique Melody MEST MKII L.csv
#   Unique Melody MEST MKII R.csv
#   Vision Ears Elysium L.csv
#   Vision Ears Elysium R.csv
#   Vision Ears Phonix L.csv
#   Vision Ears Phonix R.csv
#   Vision Ears VE8 L.csv
#   Vision Ears VE8 R.csv
#   Westone Mach 60 L.csv
#   Westone Mach 60 R.csv
#   Xenns Mangird Tea2 L.csv
#   Xenns Mangird Tea2 R.csv
#   YanYin Mahina L.csv
#   YanYin Mahina R.csv
#
# Files in 'output/csv/eplv':
#   1More ComfoBudsPro L.csv
#   1More ComfoBudsProOff L.csv
#   1More ComfoBudsProOff R.csv
#   1More PistonClassic L.csv
#   1More PistonClassic R.csv
#   ADVANCED S20009 L.csv
#   ADVANCED S20009 R.csv
#   ALPEX HR-4000 L.csv
#   ALPEX HSE-A20009 L.csv
#   ALPEX HSE-A20009 R.csv
#   Altec iM716Bass L.csv
#   Altec iM716Bass R.csv
#   Altec iM716HD L.csv
#   Altec iM716HD R.csv
#   Antdroid Target.csv
#   Apple MA850GA L.csv
#   Apple MA850GA R.csv
#   Artio CR-S1 L.csv
#   Artio CR-S1 R.csv
#   Ashida EA-HF1 L.csv
#   Ashida EA-HF1 R.csv
#   AT ATH-SPORT5TW L.csv
#   AT ATH-SPORT5TW R.csv
#   atQ AT-ES11 L.csv
#   atQ AT-ES11 R.csv
#   Audiosense DT100S L.csv
#   Audiosense DT100S R.csv
#   Audiosense DT300 L.csv
#   Audiosense DT300 R.csv
#   Audiosense DT300+36 L.csv
#   Audiosense DT300+36 R.csv
#   Audiosense DT300+75 L.csv
#   Audiosense DT300+75 R.csv
#   AudioSense T8009 L.csv
#   AudioSense T8009 R.csv
#   Augl F300light L.csv
#   Augl F300light R.csv
#   AutoEQ Target.csv
#   AZLA AZEL L.csv
#   AZLA AZEL R.csv
#   Bad Guy Target.csv
#   Banbeucmas Target.csv
#   BGVP DMGBk9 L.csv
#   BGVP DMGBk9 R.csv
#   BLON BL-03 L.csv
#   BLON BL-03 R.csv
#   BLON BL-Mini L.csv
#   BLON BL-Mini R.csv
#   BLON FatGirl9 L.csv
#   BLON FatGirl9 R.csv
#   BONAKO Royole L.csv
#   BONAKO Royole R.csv
#   BQEYZ KB19 L.csv
#   BQEYZ KB19 R.csv
#   BUSAX JS81 L.csv
#   BUSAX JS81 R.csv
#   CCA C10 L.csv
#   CCA CRA L.csv
#   CCA CRA R.csv
#   CCA NRA L.csv
#   CCA NRA R.csv
#   CCZ CoffeeBean L.csv
#   CCZ CoffeeBean R.csv
#   CCZ Emerald L.csv
#   CCZ Emerald R.csv
#   Creative EP-6309 L.csv
#   Creative EP-6309 R.csv
#   CYBERDRIVE IMPDURBass9 L.csv
#   CYBERDRIVE IMPDURBass9 R.csv
#   DAISO AL-001 L.csv
#   DAISO AL-001 R.csv
#   DAISO AL-002 L.csv
#   DAISO AL-002 R.csv
#   DAISO AL-003 L.csv
#   DAISO AL-003 R.csv
#   DAISO AL-004 L.csv
#   DAISO AL-004 R.csv
#   DAISO AL-005 L.csv
#   DAISO AL-005 R.csv
#   DAISO EV-001 L.csv
#   DAISO EV-001 R.csv
#   Diffuse Field Target.csv
#   DIY E3000 L.csv
#   DIY E3000 R.csv
#   DIY E4000 L.csv
#   DIY E4000 R.csv
#   DQSM Hermit L.csv
#   DQSM Hermit R.csv
#   DZAT DF-10 L.csv
#   DZAT DF-10 R.csv
#   Echobox FinderX1 L.csv
#   Echobox FinderX1 R.csv
#   Echobox NOMADN1Bk L.csv
#   Echobox NOMADN1Bk R.csv
#   Echobox TravelerT1 L.csv
#   Echobox TravelerT1 R.csv
#   ELECOM EHP-CH1000 L.csv
#   ELECOM EHP-CH1000 R.csv
#   ELECOM EHP-CH30009 L.csv
#   ELECOM EHP-CH30009 R.csv
#   ELECOM EHP-CS200A L.csv
#   ELECOM EHP-CS200A R.csv
#   ELECOM EHP-GB10A L.csv
#   ELECOM EHP-GB10A R.csv
#   ELECOM EHP-GB2000 L.csv
#   ELECOM EHP-GB2000 R.csv
#   Eono Eonobuds2 L.csv
#   Eono Eonobuds2 R.csv
#   Ety ER-4S L.csv
#   Ety ER-4S R.csv
#   Etymotic Target.csv
#   EZEAR Q70Y L.csv
#   EZEAR Q70Y R.csv
#   EZEAR X12 L.csv
#   EZEAR X12 R.csv
#   Fender NINE L.csv
#   Fender NINE R.csv
#   Fender PureSonicWireless L.csv
#   Fender PureSonicWireless R.csv
#   Fengru QZX-A1 L.csv
#   Fengru QZX-A1 R.csv
#   final E2000 L.csv
#   final E2000 R.csv
#   final E500 L.csv
#   final E500 R.csv
#   final EVA2020 L.csv
#   final EVA2020 R.csv
#   Floaudio CALLA L.csv
#   Floaudio CALLA R.csv
#   Floaudio LILY  L.csv
#   Floaudio LILY L.csv
#   Floaudio LILY R.csv
#   Free Field Target.csv
#   G-Most E89 L.csv
#   G-Most E89 R.csv
#   GeekWold GK10 L.csv
#   GeekWold GK10 R.csv
#   GEVO GV3 L.csv
#   GEVO GV3 R.csv
#   GLIDiC TW-3000 L.csv
#   GLIDiC TW-3000 R.csv
#   GLIDiC TW-5100 L.csv
#   GLIDiC TW-5100 R.csv
#   GuideRay GR-i18 L.csv
#   GuideRay GR-i18 R.csv
#   Harman Target.csv
#   Harman2019v2 Target.csv
#   Hisenior T2C L.csv
#   Hisenior T2C R.csv
#   HZSOUND HeartMirror L.csv
#   HZSOUND HeartMirror R.csv
#   HZSOUND HMPro L.csv
#   HZSOUND HMPro R.csv
#   HZSound WaistDrum9 L.csv
#   HZSound WaistDrum9 R.csv
#   IEF Neutral Target.csv
#   Ikko OH2 L.csv
#   Ikko OH2 R.csv
#   Innerfidelity ID Target.csv
#   intime SORA L.csv
#   intime SORA R.csv
#   intime SORA29 L.csv
#   intime SORA29 R.csv
#   intime SORA2fixed L.csv
#   intime SORA2fixed R.csv
#   intime SORAlight2019 L.csv
#   intime SORAlight2019 R.csv
#   intime SORATI3 L.csv
#   intime SORATI3 R.csv
#   JBL ENDURANCERUN L.csv
#   JBL ENDURANCERUN R.csv
#   JPRiDE 1984Premium L.csv
#   JPRiDE 1984Premium R.csv
#   JVC HA-A50TOff L.csv
#   JVC HA-A50TOff R.csv
#   JVC HA-A7T L.csv
#   JVC HA-A7T R.csv
#   KBEAR F1 L.csv
#   KBEAR F1 R.csv
#   KBEAR KS19 L.csv
#   KBEAR KS19 R.csv
#   KBEAR Lark L.csv
#   KBEAR Lark R.csv
#   KBEAR LarkEarly9 L.csv
#   KBEAR LarkEarly9 R.csv
#   KBEAR Neon L.csv
#   KBEAR Neon R.csv
#   KBEAR NEON+100Ohm L.csv
#   KBEAR NEON+100Ohm R.csv
#   KBEAR ST19 L.csv
#   KBEAR ST19 R.csv
#   Kinden UE L.csv
#   Kinden UE R.csv
#   Kinera TYR9 L.csv
#   Kinera TYR9 R.csv
#   KOSS ThePlug L.csv
#   KOSS ThePlug R.csv
#   Ksound EP-K05 L.csv
#   Ksound EP-K05 R.csv
#   KZ AS06-2020 L.csv
#   KZ AS06-2020 R.csv
#   KZ AS12 L.csv
#   KZ AS12 R.csv
#   KZ AS12R22 L.csv
#   KZ AS12R22 R.csv
#   KZ AS16 L.csv
#   KZ AS16 R.csv
#   KZ AS16Pro L.csv
#   KZ AS16Pro R.csv
#   KZ AS16Pro22 L.csv
#   KZ AS16Pro22 R.csv
#   KZ AS16ProHi-IMP L.csv
#   KZ AS16ProHi-IMP R.csv
#   KZ AS16R22 L.csv
#   KZ AS16R22 R.csv
#   KZ ASX9 L.csv
#   KZ ASX9 R.csv
#   KZ ATR L.csv
#   KZ ATR R.csv
#   KZ BA10 L.csv
#   KZ BA10 R.csv
#   KZ DQ6 L.csv
#   KZ DQ6 R.csv
#   KZ EDX L.csv
#   KZ EDX R.csv
#   KZ ES4 L.csv
#   KZ ES4 R.csv
#   KZ ESX9 L.csv
#   KZ ESX9 R.csv
#   KZ ZAS L.csv
#   KZ ZAS R.csv
#   KZ ZEXpro L.csv
#   KZ ZEXpro R.csv
#   KZ ZS10 Pro L.csv
#   KZ ZS10 Pro R.csv
#   KZ ZS4 L.csv
#   KZ ZS4 R.csv
#   KZ ZS5 L.csv
#   KZ ZS5 R.csv
#   KZ ZS6 L.csv
#   KZ ZS6 R.csv
#   KZ ZS79 L.csv
#   KZ ZS79 R.csv
# ...
#   Moondrop Alice (EQ In-Ear Target) L.csv
#   Moondrop Alice (EQ In-Ear Target) R.csv
#   Moondrop Alice (EQ Munich) L.csv
#   Moondrop Alice (EQ Munich) R.csv
#   Moondrop Alice (EQ PEQ default) L.csv
#   Moondrop Alice (EQ PEQ default) R.csv
#   Moondrop Alice (EQ Tokyo) L.csv
#   Moondrop Alice (EQ Tokyo) R.csv
#   Moondrop Alice (EQ Vienna) L.csv
#   Moondrop Alice (EQ Vienna) R.csv
#   Moondrop Alice (EQ Wennebostel) L.csv
#   Moondrop Alice (EQ Wennebostel) R.csv
#   Moondrop Alice L.csv
#   Moondrop Alice R.csv
#   Moondrop Aria L.csv
#   Moondrop Aria Snow (Spring) L.csv
#   Moondrop Aria Snow (Spring) R.csv
#   Moondrop Aria Snow L.csv
#   Moondrop Aria Snow R.csv
#   Moondrop Blessing 2 (E-type) L.csv
#   Moondrop Blessing 2 (Moondrop filter) L.csv
#   Moondrop Blessing 2 (Precog) L.csv
#   Moondrop Blessing 2 Dusk (Precog) L.csv
#   Moondrop Blessing 2 Dusk L.csv
#   Moondrop Blessing 2 L.csv
#   Moondrop Blessing 2 R.csv
#   Moondrop Blessing 2 Target.csv
#   Moondrop Blessing 3 L.csv
#   Moondrop Blessing 3 R.csv
#   Moondrop Chu (Tanchjim filter) L.csv
#   Moondrop Chu (Tanchjim filter) R.csv
#   Moondrop Chu (vent - BluTack) L.csv
#   Moondrop Chu (vent - BluTack) R.csv
#   Moondrop Chu (vent - Tanchjim) L.csv
#   Moondrop Chu (vent - Tanchjim) R.csv
#   Moondrop Chu L.csv
#   Moondrop Chu R.csv
#   Moondrop Crescent L.csv
#   Moondrop Crescent R.csv
#   Moondrop Illumination (filter removed) L.csv
#   Moondrop Illumination (Final E) L.csv
#   Moondrop Illumination (Final TWS) L.csv
#   Moondrop Illumination (Moondrop Foam) L.csv
#   Moondrop Illumination (S2) L.csv
#   Moondrop Illumination (Sedna Light) L.csv
#   Moondrop Illumination (Spiral Dots) L.csv
#   Moondrop Illumination L.csv
#   Moondrop Kanas Pro L.csv
#   Moondrop Kato (gold) L.csv
#   Moondrop Kato (gold) R.csv
#   Moondrop Kato L.csv
#   Moondrop Kato R.csv
#   Moondrop KXXS L.csv
#   Moondrop KXXS R.csv
#   Moondrop KXXX L.csv
#   Moondrop LAN (Blu Tack) L.csv
#   Moondrop LAN (Blu Tack) R.csv
#   Moondrop LAN L.csv
#   Moondrop LAN R.csv
#   Moondrop Nekocake (ANC off) L.csv
#   Moondrop Nekocake (ANC off) R.csv
#   Moondrop Nekocake (ANC on) L.csv
#   Moondrop Nekocake (ANC on) R.csv
#   Moondrop Nekocake (Classic ANC) L.csv
#   Moondrop Nekocake (Dynamic ANC) L.csv
#   Moondrop Nekocake (Nobass ANC) L.csv
#   Moondrop Nekocake (Wennebostel ANC) L.csv
#   Moondrop Quarks DSP L.csv
#   Moondrop Quarks DSP R.csv
#   Moondrop Quarks L.csv
#   Moondrop Quarks R.csv
#   Moondrop S8 (Precog) L.csv
#   Moondrop S8 (S2) L.csv
#   Moondrop S8 (S2) R.csv
#   Moondrop S8 L.csv
#   Moondrop S8 R.csv
#   Moondrop Solis L.csv
#   Moondrop Solis R.csv
#   Moondrop Solis S2 L.csv
#   Moondrop Solis S2 R.csv
#   Moondrop Spaceship L.csv
#   Moondrop Sparks (1.1.2) L.csv
#   Moondrop Sparks (1.1.4) L.csv
#   Moondrop Sparks (1.1.5) L.csv
#   Moondrop Sparks (1.1.7) L.csv
#   Moondrop Sparks (1.1.9 - balanced) L.csv
#   Moondrop Sparks (1.1.9 - basshead) L.csv
#   Moondrop Sparks (1.1.9 - David Xu) L.csv
#   Moondrop Sparks (1.1.9 - no bass) L.csv
#   Moondrop Sparks (1.1.9 - studio) L.csv
#   Moondrop Sparks (1.1.9 - Wennebostel) L.csv
#   Moondrop Sparks L.csv
#   Moondrop SSP (vent blocked) L.csv
#   Moondrop SSP L.csv
#   Moondrop SSR (deep) L.csv
#   Moondrop SSR (deep) R.csv
#   Moondrop SSR (Final E) L.csv
#   Moondrop SSR (micro pore) L.csv
#   Moondrop SSR (OS100) L.csv
#   Moondrop SSR (OS200) L.csv
#   Moondrop SSR (OS300) L.csv
#   Moondrop SSR (S2 + Tanchjim filter) L.csv
#   Moondrop SSR (S2 - AutoEQ) L.csv
#   Moondrop SSR (S2) L.csv
#   Moondrop SSR (S3) L.csv
#   Moondrop SSR (S4) L.csv
#   Moondrop SSR (S4) R.csv
#   Moondrop SSR (Sedna) L.csv
#   Moondrop SSR (vent blocked) L.csv
#   Moondrop SSR L.csv
#   Moondrop Stardust (S2) L.csv
#   Moondrop Stardust (S2) R.csv
#   Moondrop Stardust (S3) L.csv
#   Moondrop Stardust (S3) R.csv
#   Moondrop Stardust (S4) L.csv
#   Moondrop Stardust (S4) R.csv
#   Moondrop Stardust L.csv
#   Moondrop Stardust R.csv
#   Moondrop Starfield L.csv
#   Moondrop Stellaris (Tanchjim filter) L.csv
#   Moondrop Stellaris (Tanchjim filter) R.csv
#   Moondrop Stellaris L.csv
#   Moondrop Stellaris R.csv
#   Moondrop The Droplet L.csv
#   Moondrop The Droplet R.csv
#   Moondrop Variations (S2) L.csv
#   Moondrop Variations (S2) R.csv
#   Moondrop Variations L.csv
#   NF Audio NA2+ (balanced tips) L.csv
#   NF Audio NA2+ (Etype tips) L.csv
#   NF Audio NA2+ (Tanchjim filter) L.csv
#   NF Audio NA2+ L.csv
#   NF Audio NM2 L.csv
#   NF Audio NM2 R.csv
#   NiceHCK Topguy L.csv
#   NiceHCK Topguy R.csv
#   Nothing Ear 2 (balanced) L.csv
#   Nothing Ear 2 (balanced) R.csv
#   Nothing Ear 2 (more bass) L.csv
#   Nothing Ear 2 (more bass) R.csv
#   Nothing Ear 2 (more treble) L.csv
#   Nothing Ear 2 (more treble) R.csv
#   Nothing Ear 2 (personalized B) L.csv
#   Nothing Ear 2 (personalized B) R.csv
#   Nothing Ear 2 (personalized) L.csv
#   Nothing Ear 2 (personalized) R.csv
#   Nothing Ear 2 (treble -6) L.csv
#   Nothing Ear 2 (treble -6) R.csv
#   Nothing Ear 2 (voice) L.csv
#   Nothing Ear 2 (voice) R.csv
#   Nothing Ear 2 L.csv
#   Nothing Ear 2 R.csv
#   OpenAudio Mercury L.csv
#   OpenAudio Mercury R.csv
#   Oriolus 2nd Gen L.csv
#   Oriolus Traillii L.csv
#   Philips SHE3590PK L.csv
#   Phonak Audeo PFE 112 L.csv
#   Phonak Audeo PFE 112 R.csv
#   Pre-Prod 03 (nozzle A) L.csv
#   Pre-Prod 03 (nozzle A) R.csv
#   Pre-Prod 03 (nozzle B) L.csv
#   Pre-Prod 03 (nozzle B) R.csv
#   Precogvision Target.csv
#   Prisma Audio Azul (E-type) L.csv
#   Prisma Audio Azul (S2) L.csv
#   Prisma Audio Azul (S2) R.csv
#   Prisma Audio Azul (Sedna) L.csv
#   Prisma Audio Azul (SpinFit) L.csv
#   Prisma Audio Azul (Spiral Dot) L.csv
#   Prisma Audio Azul L.csv
#   Project HRP L.csv
#   Project HRP R.csv
#   QDC Anole V14 (0000) L.csv
#   QDC Anole V14 (0001) L.csv
#   QDC Anole V14 (0010) L.csv
#   QDC Anole V14 (0100) L.csv
#   QDC Anole V14 (1000) L.csv
#   QDC Anole VX (000) L.csv
#   QDC Anole VX (001) L.csv
#   QDC Anole VX (010) L.csv
#   QDC Anole VX (100) L.csv
#   QDC Anole VX (S2 000) L.csv
#   QDC Anole VX (S2 000) R.csv
#   QDC Neptune L.csv
#   QDC Uranus L.csv
#   QKZ x HBB L.csv
#   QKZ x HBB R.csv
#   Radius HP-NEF11 L.csv
#   Radius HP-NEF11 R.csv
#   Raptgo Hook L.csv
#   Raptgo Hook R.csv
#   RikudouGoku Target.csv
#   Samsung Earphones (2019) L.csv
#   Samsung Earphones L.csv
#   Samsung Galaxy Buds Plus L.csv
#   Samsung Galaxy Buds2 Pro (ANC off) L.csv
#   Samsung Galaxy Buds2 Pro (ANC off) R.csv
#   Samsung Galaxy Buds2 Pro (bass boost) L.csv
#   Samsung Galaxy Buds2 Pro (bass boost) R.csv
#   Samsung Galaxy Buds2 Pro (clear) L.csv
#   Samsung Galaxy Buds2 Pro (clear) R.csv
#   Samsung Galaxy Buds2 Pro (dynamic) L.csv
#   Samsung Galaxy Buds2 Pro (dynamic) R.csv
#   Samsung Galaxy Buds2 Pro (normal) L.csv
#   Samsung Galaxy Buds2 Pro (normal) R.csv
#   Samsung Galaxy Buds2 Pro (soft) L.csv
#   Samsung Galaxy Buds2 Pro (soft) R.csv
#   Samsung Galaxy Buds2 Pro (treble boost) L.csv
#   Samsung Galaxy Buds2 Pro (treble boost) R.csv
#   SeeAudio Bravery L.csv
#   SeeAudio Bravery R.csv
#   SeeAudio Yume L.csv
#   SeeAudio Yume Midnight (126ohm) L.csv
#   SeeAudio Yume Midnight (15ohm) L.csv
#   SeeAudio Yume Midnight (36ohm) L.csv
#   SeeAudio Yume Midnight (75ohm) L.csv
#   SeeAudio Yume Midnight (S2) L.csv
#   SeeAudio Yume Midnight (S2) R.csv
#   SeeAudio Yume Midnight L.csv
#   SeeAudio Yume Midnight R.csv
#   Sennheiser IE 200 (Azla Max) L.csv
#   Sennheiser IE 200 (Azla Max) R.csv
#   Sennheiser IE 200 (D1) L.csv
#   Sennheiser IE 200 (D1) R.csv
#   Sennheiser IE 200 (D2) L.csv
#   Sennheiser IE 200 (D2) R.csv
#   Sennheiser IE 200 (Spiral Dot) L.csv
#   Sennheiser IE 200 (Spiral Dot) R.csv
#   Sennheiser IE 200 (UC tips) L.csv
#   Sennheiser IE 200 (UC tips) R.csv
#   Sennheiser IE 300 (AutoEQ) L.csv
#   Sennheiser IE 300 (Final E) L.csv
#   Sennheiser IE 300 (Sedna Light) L.csv
#   Sennheiser IE 300 L.csv
#   Sennheiser IE 40 Pro L.csv
#   Sennheiser IE 600 (E-type shallow) L.csv
#   Sennheiser IE 600 (E-type shallow) R.csv
#   Sennheiser IE 600 (E-type) L.csv
#   Sennheiser IE 600 (E-type) R.csv
#   Sennheiser IE 600 (foam) L.csv
#   Sennheiser IE 600 (foam) R.csv
#   Sennheiser IE 600 (Sedna) L.csv
#   Sennheiser IE 600 (Sedna) R.csv
#   Sennheiser IE 600 (Spinfit) L.csv
#   Sennheiser IE 600 (Spinfit) R.csv
#   Sennheiser IE 600 (Spring tips) L.csv
#   Sennheiser IE 600 (Spring tips) R.csv
#   Sennheiser IE 600 L.csv
#   Sennheiser IE 600 R.csv
#   Sennheiser IE 900 (fake) L.csv
#   Sennheiser IE 900 (fake) R.csv
#   Sennheiser IE 900 (Final) L.csv
#   Sennheiser IE 900 (Final) R.csv
#   Sennheiser IE 900 L.csv
#   Sennheiser IE 900 R.csv
#   Sennheiser Momentum TW3 L.csv
#   Sennheiser Momentum TW3 R.csv
#   Sennheiser MTW2 (HE) L.csv
#   Sennheiser MTW2 L.csv
#   Shanling ME700 Lite L.csv
#   Shozy CP L.csv
#   Shozy Rouge L.csv
#   Shure SE215 L.csv
#   Simgot EN700 Pro (Moondrop) L.csv
#   Simgot EN700 Pro (Tanchjim) L.csv
#   Simgot EN700 Pro L.csv
#   Softears RSV L.csv
#   Softears Studio4 L.csv
#   Softears Studio4 R.csv
#   Softears Volume (Apple + 126ohm) L.csv
#   Softears Volume (Apple + 15ohm) L.csv
#   Softears Volume (Apple + 36ohm) L.csv
#   Softears Volume (Apple + 75ohm) L.csv
#   Softears Volume (Apple dongle) L.csv
#   Softears Volume (Fiio Q3) L.csv
#   Softears Volume (Qudelix) L.csv
#   Softears Volume L.csv
#   Softears Volume R.csv
#   Sony IER-NW510N L.csv
#   Sony IER-Z1R (S2 - Sedna) L.csv
#   Sony IER-Z1R (S2 - Sedna) R.csv
#   Sony IER-Z1R (S2 - Symbio) L.csv
#   Sony IER-Z1R (S2 - Symbio) R.csv
#   Sony IER-Z1R (S3) L.csv
#   Sony IER-Z1R (S3) R.csv
#   Sony IER-Z1R L.csv
#   Sony MDR-AS800 L.csv
#   Sony MDR-AS800 R.csv
#   Sony MDR-EX15LP (deep) L.csv
#   Sony MDR-EX15LP (deep) R.csv
#   Sony MDR-EX15LP L.csv
#   Sony MDR-EX15LP R.csv
#   Sony MH1 L.csv
#   Sony MH1 R.csv
#   Sony MH755 (S2) L.csv
#   Sony MH755 (S3) L.csv
#   Sony MH755 (S3) R.csv
#   Sony MH755 (vent Blu Tack) L.csv
#   Sony MH755 clone L.csv
#   Sony MH755 L.csv
#   Sony WF-1000XM3 L.csv
#   Sony WF-1000XM4 (ambient on) L.csv
#   Sony WF-1000XM4 (ANC off) L.csv
#   Sony WF-1000XM4 (ANC on) L.csv
#   Sony WF-1000XM4 (EQ - bass boost) L.csv
#   Sony WF-1000XM4 (EQ - bright) L.csv
#   Sony WF-1000XM4 (EQ - custom) L.csv
#   Sony WF-1000XM4 (EQ - excited) L.csv
#   Sony WF-1000XM4 (EQ - mellow) L.csv
#   Sony WF-1000XM4 (EQ - relaxed) L.csv
#   Sony WF-1000XM4 (EQ - speech) L.csv
#   Sony WF-1000XM4 (EQ - treble boost) L.csv
#   Sony WF-1000XM4 (EQ - vocal) L.csv
#   Sony WF-1000XM4 (Final E-type) L.csv
#   Sony WF-1000XM4 (fw 1.1.15) L.csv
#   Sony WF-1000XM4 (max - ambient on) L.csv
#   Sony WF-1000XM4 (max - ANC off) L.csv
#   Sony WF-1000XM4 (max - ANC on) L.csv
#   Sony WF-1000XM4 (max - EQ - bass boost) L.csv
#   Sony WF-1000XM4 (max - EQ - bright) L.csv
#   Sony WF-1000XM4 (max - EQ - excited) L.csv
#   Sony WF-1000XM4 (max - EQ - mellow) L.csv
#   Sony WF-1000XM4 (max - EQ - relaxed) L.csv
#   Sony WF-1000XM4 (max - EQ - speech) L.csv
#   Sony WF-1000XM4 (max - EQ - treble boost) L.csv
#   Sony WF-1000XM4 (max - EQ - vocal) L.csv
#   Sony WF-1000XM4 (max - Final E-type) L.csv
#   Sony WF-1000XM4 (max - fw 1.1.15) L.csv
#   Sony WF-1000XM4 (max - fw 1.2.6) L.csv
#   Sony WF-1000XM4 (max - MRS config) L.csv
#   Sony WF-1000XM4 (max - Sedna Light Short) L.csv
#   Sony WF-1000XM4 (max - SpinFit) L.csv
#   Sony WF-1000XM4 (max - Tanchjim APB) L.csv
#   Sony WF-1000XM4 (max - XM3 silicone) L.csv
#   Sony WF-1000XM4 (MRS config) L.csv
#   Sony WF-1000XM4 (Sedna Light Short) L.csv
#   Sony WF-1000XM4 (SpinFit) L.csv
#   Sony WF-1000XM4 (Tanchjim APB) L.csv
#   Sony WF-1000XM4 (XM3 silicone) L.csv
#   Sony WF-1000XM4 L.csv
#   Sony XBA-N3 (S2) L.csv
#   Sony XBA-N3 (S2) R.csv
#   Sony XBA-N3 L.csv
#   Sony XBA-N3 R.csv
#   Status Audio IEM-2X L.csv
#   Super 21 Target.csv
#   Super 22 Target.csv
#   Super Bass Target.csv
#   Super Review Target.csv
#   Symphonium Helios L.csv
#   Symphonium Helios R.csv
#   Symphonium Meteor (CanJam) L.csv
#   Symphonium Meteor (CanJam) R.csv
#   Symphonium Meteor (inverted) L.csv
#   Symphonium Meteor (inverted) R.csv
#   Symphonium Meteor L.csv
#   Symphonium Meteor R.csv
#   Symphonium Triton L.csv
#   Symphonium Triton R.csv
#   Tanchjim Darling (depth 1) L.csv
#   Tanchjim Darling (depth 2) L.csv
#   Tanchjim Echo L.csv
#   Tanchjim Echo R.csv
#   Tanchjim Hana (Final E) L.csv
#   Tanchjim Hana (Sedna Light) L.csv
#   Tanchjim Hana 2021 L.csv
#   Tanchjim Hana L.csv
#   Tanchjim Ola (s2 - filterless - taped) L.csv
#   Tanchjim Ola (s2 - filterless - taped) R.csv
#   Tanchjim Ola (s2 - filterless) L.csv
#   Tanchjim Ola (s2 - filterless) R.csv
#   Tanchjim Ola (vent Blu Tack) L.csv
#   Tanchjim Ola (vent Tanchjim filter) L.csv
#   Tanchjim Ola L.csv
#   Tanchjim Ola R.csv
#   Tanchjim Oxygen L.csv
#   Tanchjim Prism (treble tips) L.csv
#   Tanchjim Prism (treble tips) R.csv
#   Tanchjim Prism L.csv
#   Tanchjim Prism R.csv
#   Tanchjim Tanya L.csv
#   Tanchjim Zero L.csv
#   Tanchjim Zero R.csv
#   Tangzu Waner L.csv
#   Tangzu Waner R.csv
#   Tangzu Wu Heyday L.csv
#   Tangzu Wu Heyday R.csv
#   Tangzu Ze Tian Wu L.csv
#   Tangzu Ze Tian Wu R.csv
#   Tansio Mirai Spark (010) L.csv
#   Tansio Mirai Spark (110) L.csv
#   Tansio Mirai Spark (111) L.csv
#   Tenhz 3BA L.csv
#   Tenhz P4 Pro L.csv
#   TFZ No.3 L.csv
#   TFZ T2 Galaxy L.csv
#   ThieAudio Clairvoyance L.csv
#   ThieAudio Elixir L.csv
#   ThieAudio Elixir R.csv
#   ThieAudio Legacy 2 L.csv
#   ThieAudio Legacy 4 (Spring) L.csv
#   ThieAudio Legacy 4 (Spring) R.csv
#   ThieAudio Legacy 4 (switch on) L.csv
#   ThieAudio Legacy 4 L.csv
#   ThieAudio Legacy 4 R.csv
#   ThieAudio Legacy 5 (126 ohm) L.csv
#   ThieAudio Legacy 5 (15 ohm) L.csv
#   ThieAudio Legacy 5 (36 ohm) L.csv
#   ThieAudio Legacy 5 (75 ohm) L.csv
#   ThieAudio Legacy 5 (S1 seized) L.csv
#   ThieAudio Legacy 5 (S1) L.csv
#   ThieAudio Legacy 5 (S2 15ohm) L.csv
#   ThieAudio Legacy 5 (S2) L.csv
#   ThieAudio Legacy 5 (S2) R.csv
#   ThieAudio Legacy 5 L.csv
#   ThieAudio Legacy 5 R.csv
#   ThieAudio Monarch L.csv
#   ThieAudio Monarch MkII (S2 - Spring tips) L.csv
#   ThieAudio Monarch MkII (S2 - Spring tips) R.csv
#   ThieAudio Monarch MkII (S2) L.csv
#   ThieAudio Monarch MkII (S2) R.csv
#   ThieAudio Monarch MkII L.csv
#   ThieAudio Monarch MkII R.csv
#   ThieAudio Monarch R.csv
#   ThieAudio Oracle L.csv
#   ThieAudio Oracle mkII L.csv
#   ThieAudio Oracle mkII R.csv
#   ThieAudio Oracle R.csv
#   Thinksound Rain3 L.csv
#   Thinksound Rain3 R.csv
#   Tin Hifi C2 Mech Warrior L.csv
#   Tin Hifi C2 Mech Warrior R.csv
#   Tin Hifi C3 L.csv
#   Tin Hifi C3 R.csv
#   Tin Hifi C5 L.csv
#   Tin Hifi C5 R.csv
#   Tin Hifi P1 (vent blocked) L.csv
#   Tin Hifi P1 L.csv
#   Tin Hifi P1 Max L.csv
#   Tin Hifi P1 Max R.csv
#   Tin Hifi P1 Plus L.csv
#   Tin Hifi P1 Plus R.csv
#   Tin Hifi T2 DLC L.csv
#   Tin Hifi T2 DLC R.csv
#   Tin Hifi T2 Evo L.csv
#   Tin Hifi T2 Evo R.csv
#   Tin Hifi T2 L.csv
#   Tin Hifi T2 Plus (Sedna Light) L.csv
#   Tin Hifi T2 Plus L.csv
#   Tin Hifi T2 Pro (Comply) L.csv
#   Tin Hifi T2 Pro (white grill + Comply) L.csv
#   Tin Hifi T2 Pro L.csv
#   Tin Hifi T3 L.csv
#   Tin Hifi T3 Plus L.csv
#   Tin Hifi T3 Plus R.csv
#   Tin Hifi T4 L.csv
#   Tin Hifi T4 Plus L.csv
#   Tin Hifi T4 Plus R.csv
#   Tin Hifi T5 (Comply Waxguard) L.csv
#   Tin Hifi T5 L.csv
#   Tin Hifi Tin Buds 3 L.csv
#   Tin Hifi Tin Buds 3 R.csv
#   Tripowin Cencibel L.csv
#   Tripowin Cencibel R.csv
#   Tripowin Lea L.csv
#   Tripowin Lea R.csv
#   Tripowin Mele L.csv
#   Tripowin Mele R.csv
#   Tripowin Olina (S2) L.csv
#   Tripowin Olina (S2) R.csv
#   Tripowin Olina L.csv
#   Tripowin Olina R.csv
#   Tripowin Olina SE L.csv
#   Tripowin Olina SE R.csv
#   Tripowin Rhombus L.csv
#   Tripowin Rhombus R.csv
#   TRN IM1 L.csv
#   TRN V30 L.csv
#   TRN V90 L.csv
#   Truthear Hexa (S2 - airlocked) L.csv
#   Truthear Hexa (S2 - airlocked) R.csv
#   Truthear Hexa (S2) L.csv
#   Truthear Hexa (S2) R.csv
#   Truthear Hexa L.csv
#   Truthear Hexa R.csv
#   Truthear Hola L.csv
#   Truthear Hola R.csv
#   Truthear Zero (S2 deep) L.csv
#   Truthear Zero (S2 deep) R.csv
#   Truthear Zero (S2) L.csv
#   Truthear Zero (S2) R.csv
#   Truthear Zero L.csv
#   Truthear Zero R.csv
#   Ucotech RE-2 L.csv
#   Ucotech RE-2 R.csv
#   Unique Melody MEST L.csv
#   Unique Melody MEST mkII L.csv
#   Unique Melody MEST mkII R.csv
#   Unique Melody MEST R.csv
#   Vision Ears VE7 L.csv
#   Vision Ears VE7 R.csv
#   Vision Ears VE8 L.csv
#   Vsonic GR07 (Bass) L.csv
#   Vsonic GR07 L.csv
#   Vsonic GR07 R.csv
#   Vsonic VS7 L.csv
#   Whizzer Kylin L.csv
#   Working 001 Target.csv
#   Working 002 Target.csv
#   Xenns Mangird Tea 2 (S2) L.csv
#   Xenns Mangird Tea 2 (S2) R.csv
#   Xenns Mangird Tea 2 L.csv
#   Xenns Mangird Tea 2 R.csv
#   Xenns Mangird Tea L.csv
#   Yanyin Mahina L.csv
#   Yanyin Mahina R.csv
#   Yinfu MD51 L.csv
#   Yinyoo V2 L.csv
