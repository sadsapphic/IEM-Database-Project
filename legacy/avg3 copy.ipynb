# %%
import pandas as pd
import numpy as np

# Paths
vari_super_s1 = 'Measurements/vari_super_s1.csv'
vari_super_s2 = 'Measurements/vari_super_s2.csv'
vari_precog_s1 = 'Measurements/vari_precog_s1.csv'
vari_precog_s2 = 'Measurements/vari_precog_s2.csv'
vari_precog_s3 = 'Measurements/vari_precog_s3.csv'
vari_nymz = 'Measurements/vari_nymz.csv'
vari_hobbytalk_stock = 'Measurements/vari_hobbytalk_stock.csv'
vari_hbb = 'Measurements/vari_hbb.csv'
vari_harpo = 'Measurements/vari_harpo.csv'
vari_gizaudio = 'Measurements/vari_gizaudio.csv'
vari_crinacle = 'Measurements/vari_crinacle.csv'
vari_aftersound = 'Measurements/vari_aftersound.csv'
CammyFi = 'Measurements/CammyFi.csv'
BryAudioReviews = 'Measurements/BryAudioReviews.csv'
Vari_105dBC = 'Measurements/Vari_105dBC.csv'
Vari_85dBC = 'Measurements/Vari_85dBC.csv'
Vari_77dBC = 'Measurements/Vari_77dBC.csv'
Moondrop_Measurement_Official = 'Measurements/Moondrop_Measurement_Official.csv'


# List of file paths
file_paths = [vari_super_s1, vari_super_s2, vari_precog_s1, vari_precog_s2, vari_precog_s3, vari_nymz, vari_hobbytalk_stock, vari_hbb, vari_harpo, vari_gizaudio, vari_crinacle, vari_aftersound, CammyFi, BryAudioReviews, Vari_105dBC, Vari_85dBC, Vari_77dBC, Moondrop_Measurement_Official]

# Function to read and interpolate data
def read_and_interpolate_normalized(file_path, x_values, reference_frequency=1000):
    df = pd.read_csv(file_path)
    df = df.drop_duplicates(subset='X', keep='first')  # Drop duplicate X values
    df = df.set_index('X')
    df = df.reindex(df.index.union(x_values)).interpolate(method='linear')
    df = df.loc[x_values]
    
    # Normalize Y values
    reference_value = df.loc[reference_frequency, 'Y']
    df['Y'] = df['Y'] - reference_value
    
    return df

# Define common X-axis
x_values = np.linspace(21, 20000, 19980)  # Change the number of data points as needed

# Read and interpolate all .csv files
dfs = [read_and_interpolate_normalized(file_path, x_values) for file_path in file_paths]

# Calculate average
average_df = pd.concat(dfs).groupby(level=0).mean()
reference_value = dfs[0].loc[1000, 'Y']
average_df['Y'] = average_df['Y'] + reference_value

# Save the average to a new .csv file
average_df.to_csv('Measurements/average2.csv', index_label='X')

# %%
import matplotlib.pyplot as plt

# Load the averaged data
average_df = pd.read_csv('Measurements/average.csv')

# Set the figure size (width, height) in inches
plt.figure(figsize=(12, 6))

# Create a plot of the data with a logarithmic X-axis
plt.semilogx(average_df['X'], average_df['Y'])

# Set the Y-axis range
plt.ylim(30, 85)

# Add labels and title
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude (dB)')
plt.title('Averaged Frequency Response')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Function to plot individual .csv file data
def plot_individual_data(file_path):
    df = pd.read_csv(file_path)
    plt.semilogx(df['X'], df['Y'], color='lightgray', linewidth=0.5)

# Load the averaged data
average_df = pd.read_csv('Measurements/average.csv')

# Set the figure size (width, height) in inches
plt.figure(figsize=(12, 6))

# Plot individual .csv files
for file_path in file_paths:
    plot_individual_data(file_path)

# Create a plot of the averaged data with a logarithmic X-axis
plt.semilogx(average_df['X'], average_df['Y'], color='red', linewidth=2, label='Average')

# Set the Y-axis range
plt.ylim(30, 85)

# Add labels and title
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude (dB)')
plt.title('Averaged Frequency Response')

# Add a legend
plt.legend()

# Display the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Paths
vari_super_s1 = 'Measurements/vari_super_s1.csv'
vari_super_s2 = 'Measurements/vari_super_s2.csv'
vari_precog_s1 = 'Measurements/vari_precog_s1.csv'
vari_precog_s2 = 'Measurements/vari_precog_s2.csv'
vari_precog_s3 = 'Measurements/vari_precog_s3.csv'
vari_nymz = 'Measurements/vari_nymz.csv'
vari_hobbytalk_stock = 'Measurements/vari_hobbytalk_stock.csv'
vari_hbb = 'Measurements/vari_hbb.csv'
vari_harpo = 'Measurements/vari_harpo.csv'
vari_gizaudio = 'Measurements/vari_gizaudio.csv'
vari_crinacle = 'Measurements/vari_crinacle.csv'
vari_aftersound = 'Measurements/vari_aftersound.csv'
CammyFi = 'Measurements/CammyFi.csv'
BryAudioReviews = 'Measurements/BryAudioReviews.csv'
Vari_105dBC = 'Measurements/Vari_105dBC.csv'
Vari_85dBC = 'Measurements/Vari_85dBC.csv'
Vari_77dBC = 'Measurements/Vari_77dBC.csv'
Moondrop_Measurement_Official = 'Measurements/Moondrop_Measurement_Official.csv'

# List of file paths
file_paths = [vari_super_s1, vari_super_s2, vari_precog_s1, vari_precog_s2, vari_precog_s3, vari_nymz, vari_hobbytalk_stock, vari_hbb, vari_harpo, vari_gizaudio, vari_crinacle, vari_aftersound, CammyFi, BryAudioReviews, Vari_105dBC, Vari_85dBC, Vari_77dBC, Moondrop_Measurement_Official]

# Function to read and interpolate data
def read_and_interpolate_normalized(file_path, x_values, reference_frequency=1000):
    df = pd.read_csv(file_path)
    df = df.drop_duplicates(subset='X', keep='first')  # Drop duplicate X values
    df = df.set_index('X')
    df = df.reindex(df.index.union(x_values)).interpolate(method='linear')
    df = df.loc[x_values]

    # Normalize Y values
    reference_value = df.loc[reference_frequency, 'Y']
    df['Y'] = df['Y'] - reference_value

    return df

# Define common X-axis
x_values = np.linspace(21, 20000, 19980)  # Change the number of data points as needed

# Read and interpolate all .csv files
dfs = [read_and_interpolate_normalized(file_path, x_values) for file_path in file_paths]

# Calculate average
average_df = pd.concat(dfs).groupby(level=0).mean()
reference_value = dfs[0].loc[1000, 'Y']
average_df['Y'] = average_df['Y'] + reference_value

# Save the average to a new .csv file
average_df.to_csv('Measurements/average2.csv', index_label='X')

# Function to plot individual .csv file data
def plot_individual_data(file_path):
    df = pd.read_csv(file_path)
    df = df[df['X'] >= 21]
    plt.semilogx(df['X'], df['Y'], color='lightgray', linewidth=0.5)

# Load the averaged data
average_df = pd.read_csv('Measurements/average2.csv')

# Set the figure size (width, height) in inches
plt.figure(figsize=(12, 6))

# Plot individual .csv files
for file_path in file_paths:
    plot_individual_data(file_path)

# Create a plot of the averaged data with a logarithmic X-axis
plt.semilogx(average_df['X'], average_df['Y'], color='red', linewidth=2, label='Average')

# Set the Y-axis range
plt.ylim(30, 85)

# Add labels and title
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude (dB)')
plt.title('Averaged Frequency Response')

# Add a legend
plt.legend()

# Display the plot
plt.show()

print("Min Y value:", average_df['Y'].min())
print("Max Y value:", average_df['Y'].max())

for file_path in file_paths:
    df = pd.read_csv(file_path)
    print(file_path)
    print(df.head(1))
    print(df.tail(1))
    print()
# Out:
# Min Y value: -12.35277875439531
# Max Y value: 8.946623555727637
# Measurements/vari_super_s1.csv
#            X          Y
# 0  20.849648  70.457113
#                  X          Y
# 1227  18995.622913  46.087866
#
# Measurements/vari_super_s2.csv
#            X          Y
# 0  20.849648  70.578782
#                  X          Y
# 1182  19093.747951  54.432773
#
# Measurements/vari_precog_s1.csv
#           X          Y
# 0  20.79471  69.682839
#                  X          Y
# 1228  19794.801701  48.836478
#
# Measurements/vari_precog_s2.csv
#           X          Y
# 0  20.79471  69.708895
#                  X          Y
# 1185  19290.969527  55.649895
#
# Measurements/vari_precog_s3.csv
#            X          Y
# 0  20.781388  70.439902
#                  X          Y
# 1194  19794.801701  40.870021
#
# Measurements/vari_nymz.csv
#            X         Y
# 0  20.800042  69.68805
#                  X          Y
# 1242  19692.993401  46.740042
#
# Measurements/vari_hobbytalk_stock.csv
#            X          Y
# 0  20.843633  72.396665
#                  X          Y
# 1180  19191.752528  54.012605
#
# Measurements/vari_hbb.csv
#            X          Y
# 0  20.172778  68.817086
#                X          Y
# 1256  19897.0549  50.828092
#
# Measurements/vari_harpo.csv
#            X          Y
# 0  20.799504  70.365263
#                  X          Y
# 1129  19392.123377  55.526316
#
# Measurements/vari_gizaudio.csv
#            X          Y
# 0  20.963303  71.297895
#                  X          Y
# 1166  19592.348627  50.473684
#
# Measurements/vari_crinacle.csv
#            X          Y
# 0  20.843633  69.255252
#                  X          Y
# 1116  19794.801701  55.693277
#
# Measurements/vari_aftersound.csv
#            X         Y
# 0  20.775333  69.63363
#                  X          Y
# 1161  19591.388012  52.887029
#
# Measurements/CammyFi.csv
#            X          Y
# 0  19.927637  68.047066
#                X          Y
# 1255  101.532281  64.107981
#
# Measurements/BryAudioReviews.csv
#            X          Y
# 0  20.881206  69.184397
#              X          Y
# 1221  20.09779  69.042553
#
# Measurements/Vari_105dBC.csv
#            X          Y
# 0  20.031511 -13.127512
#                X         Y
# 142  3389.820392 -9.851117
#
# Measurements/Vari_85dBC.csv
#            X          Y
# 0  19.856062 -11.242804
#                 X          Y
# 144  11179.728146 -19.139785
#
# Measurements/Vari_77dBC.csv
#           X         Y
# 0  19.70874 -9.955343
#                 X          Y
# 164  19478.106769 -37.326733
#
# Measurements/Moondrop_Measurement_Official.csv
#            X           Y
# 0  19.889913  122.903007
#                  X           Y
# 1885  20240.228935  110.444131

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Paths
vari_super_s1 = 'Measurements/vari_super_s1.csv'
vari_super_s2 = 'Measurements/vari_super_s2.csv'
vari_precog_s1 = 'Measurements/vari_precog_s1.csv'
vari_precog_s2 = 'Measurements/vari_precog_s2.csv'
vari_precog_s3 = 'Measurements/vari_precog_s3.csv'
vari_nymz = 'Measurements/vari_nymz.csv'
vari_hobbytalk_stock = 'Measurements/vari_hobbytalk_stock.csv'
vari_hbb = 'Measurements/vari_hbb.csv'
vari_harpo = 'Measurements/vari_harpo.csv'
vari_gizaudio = 'Measurements/vari_gizaudio.csv'
vari_crinacle = 'Measurements/vari_crinacle.csv'
vari_aftersound = 'Measurements/vari_aftersound.csv'
CammyFi = 'Measurements/CammyFi.csv'
BryAudioReviews = 'Measurements/BryAudioReviews.csv'
Vari_105dBC = 'Measurements/Vari_105dBC.csv'
Vari_85dBC = 'Measurements/Vari_85dBC.csv'
Vari_77dBC = 'Measurements/Vari_77dBC.csv'
Moondrop_Measurement_Official = 'Measurements/Moondrop_Measurement_Official.csv'

# List of file paths
file_paths = [vari_super_s1, vari_super_s2, vari_precog_s1, vari_precog_s2, vari_precog_s3, vari_nymz, vari_hobbytalk_stock, vari_hbb, vari_harpo, vari_gizaudio, vari_crinacle, vari_aftersound, CammyFi, BryAudioReviews, Vari_105dBC, Vari_85dBC, Vari_77dBC, Moondrop_Measurement_Official]

# Function to read and interpolate data
def read_and_interpolate_normalized(file_path, x_values, reference_frequency=1000):
   df = pd.read_csv(file_path)
   df = df.drop_duplicates(subset='X', keep='first')  # Drop duplicate X values
   df = df.set_index('X')
   df = df.reindex(df.index.union(x_values)).interpolate(method='linear')  # Change method to 'linear'
   df = df.loc[x_values]

   # Normalize Y values
   reference_value = df.iloc[(df.index - reference_frequency).abs().argmin()]['Y']
   df['Y'] = df['Y'] - reference_value

   return df


# Define common X-axis
x_values = np.linspace(19.7, 20268.3, 40000)

# Read and interpolate all .csv files
df = df.reindex(df.index.union(x_values)).interpolate(method='polynomial', order=2)

# Calculate average
average_df = pd.concat(dfs).groupby(level=0).mean()
reference_value = dfs[0].loc[1000, 'Y']
average_df['Y'] = average_df['Y'] - reference_value

# Save the average to a new .csv file
average_df.to_csv('Measurements/average2.csv', index_label='X')

# Function to plot individual .csv file data
def plot_individual_data(file_path):
    df = read_and_interpolate_normalized(file_path, x_values)
    print(df)  # Add this line
    plt.semilogx(df.index, df['Y'], color='lightgray', linewidth=0.5)


# Load the averaged data
average_df = pd.read_csv('Measurements/average2.csv')

# Set the figure size (width, height) in inches
plt.figure(figsize=(12, 6))

# Plot individual .csv files
for file_path in file_paths:
    plot_individual_data(file_path)

# Create a plot of the averaged data with a logarithmic X-axis
plt.semilogx(average_df['X'], average_df['Y'], color='red', linewidth=2, label='Average')

# Set the Y-axis range
plt.ylim(30, 85)

# Add labels and title
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude (dB)')
plt.title('Averaged Frequency Response')

# Add a legend
plt.legend()

# Display the plot
plt.show()

# Check frequency range and data shape of each .csv file
for file_path in file_paths:
    df = pd.read_csv(file_path)
    print(file_path)
    print("Min frequency:", df['X'].min())
    print("Max frequency:", df['X'].max())
    print("Data shape:", df.shape)
    print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/nm/_dj8kh1j5hx4wbvcdmw7smmh0000gn/T/ipykernel_1868/226083694.py in <module>
#      70 # Plot individual .csv files
#      71 for file_path in file_paths:
# ---> 72     plot_individual_data(file_path)
#      73
#      74 # Create a plot of the averaged data with a logarithmic X-axis
#
# /var/folders/nm/_dj8kh1j5hx4wbvcdmw7smmh0000gn/T/ipykernel_1868/226083694.py in plot_individual_data(file_path)
#      57 # Function to plot individual .csv file data
#      58 def plot_individual_data(file_path):
# ---> 59     df = read_and_interpolate_normalized(file_path, x_values)
#      60     print(df)  # Add this line
#      61     plt.semilogx(df.index, df['Y'], color='lightgray', linewidth=0.5)
#
# /var/folders/nm/_dj8kh1j5hx4wbvcdmw7smmh0000gn/T/ipykernel_1868/226083694.py in read_and_interpolate_normalized(file_path, x_values, reference_frequency)
#      35
#      36    # Normalize Y values
# ---> 37    reference_value = df.iloc[(df.index - reference_frequency).abs().argmin()]['Y']
#      38    df['Y'] = df['Y'] - reference_value
#      39
#
# AttributeError: 'Float64Index' object has no attribute 'abs'
