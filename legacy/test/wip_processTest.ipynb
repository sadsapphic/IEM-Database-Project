# %%
import os
from collections import defaultdict
from fuzzywuzzy import fuzz, process
import re
import pandas as pd
from sklearn.cluster import DBSCAN
import numpy as np

# %%
# List of reviewers
reviewers = [
    'achoreviews',
    'aftersound',
    'animagus',
    'arn',
    'bedrock',
    'bryaudioreviews',
    'cammyfi',
    'soundjedi',
    'eplv',
    'timmyv',
    'harpo',
    'hbb',
    'cqtek',
    'hobbytalk',
    'ianfann',
    'iemworld',
    'jacstone',
    'kr0mka',
    'kurin',
    'melatonin',
    'nymz', 
    'pw',
    'recode',
    'rg',
    'shortbus',
    'suporsalad',
    'tgx78',
    'vortexreviews',
    'vsg',
    'wdym',
    'akros',
    'data_mrs'
]

# %%
known_iems = {
    'moondrop blessing 2 dusk': ['dusk', 'blessing 2 dusk', 'b2 dusk', 'md b2 dusk', 'moondrop dusk', 'moondrop blessing 2 dusk']
    # Add more IEMs and their variations here
}

# %%
def normalize_file_name(file_name, known_iems, threshold=80):
    file_name = re.sub(r'\.csv$', '', file_name, flags=re.IGNORECASE)  # Remove file extension
    file_name = file_name.strip()  # Remove leading/trailing spaces
    file_name = file_name.lower()  # Convert to lowercase

    best_match = None
    best_ratio = 0

    for iem_name, variations in known_iems.items():
        for variation in variations:
            ratio = fuzz.token_set_ratio(file_name, variation)
            if ratio > best_ratio and ratio >= threshold:
                best_ratio = ratio
                best_match = iem_name

    if best_match:
        return best_match
    else:
        return file_name

# %%
def merge_similar_keys(grouped_data, threshold=80):
    keys = list(grouped_data.keys())
    merged_data = {}
    
    for key in keys:
        found_similar = False
        for merged_key in merged_data:
            if fuzz.token_set_ratio(key, merged_key) >= threshold:
                merged_data[merged_key].update(grouped_data[key])
                found_similar = True
                break

        if not found_similar:
            merged_data[key] = grouped_data[key]

    return merged_data

grouped_data = {}

# %%
for reviewer in reviewers:
    dir_path = f'output/csv/{reviewer}'
    for file_name in os.listdir(dir_path):
        normalized_name = normalize_file_name(file_name, known_iems)
        file_path = os.path.join(dir_path, file_name)

        if normalized_name not in grouped_data:
            grouped_data[normalized_name] = {}

        if reviewer not in grouped_data[normalized_name]:
            grouped_data[normalized_name][reviewer] = []

        grouped_data[normalized_name][reviewer].append(file_path)

# %%
merged_data = merge_similar_keys(grouped_data, threshold=80)

# Optional: Convert the dictionary to a pandas DataFrame with lists of file paths
df = pd.DataFrame.from_dict(merged_data, orient='index')

# %%
total_files = sum([len(files) for iem_group in grouped_data.values() for files in iem_group.values()])
total_groups = len(grouped_data)
total_files_in_groups = sum([len(files) for iem_group in grouped_data.values() for files in iem_group.values() if len(files) > 1])
total_files_not_in_groups = total_files - total_files_in_groups
avg_files_per_group = total_files / total_groups

# %%
print(f"Total number of files: {total_files}")
print(f"Total number of groups: {total_groups}")
print(f"Total number of files in groups: {total_files_in_groups}")
print(f"Total number of files not in groups: {total_files_not_in_groups}")
print(f"\nAvg number of files per group: {avg_files_per_group}")
# Out:
# Total number of files: 11473
# Total number of groups: 6807
# Total number of files in groups: 68
# Total number of files not in groups: 11405
#
# Avg number of files per group: 1.6854708388423683

# %%
# Print grouped files
for representative, group in merged_data.items():
    print(f"{representative}:")
    for reviewer, files in group.items():
        for file in files:
            file_name = os.path.basename(file)
            print(f"  {file_name} - {reviewer}")
    print()
# Out:
# 7hz dioko l:
#   7Hz Dioko L.csv - achoreviews
#   7Hz Dioko R.csv - bedrock
#   7Hz Dioko R.csv - timmyv
#   7hz Dioko R.csv - hobbytalk
#   7HZ DIOKO (bass mod) R.csv - ianfann
#   7Hz Dioko R.csv - iemworld
#   7Hz Dioko (pre-op) R.csv - data_mrs
#   7HZ SALNOTES DIOKO R.csv - aftersound
#   7Hz Salnotes Dioko L.csv - arn
#   7hz Salnotes Dioko R.csv - nymz
#   7Hz Salnotes Dioko TapedVent L.csv - pw
#   7Hz Dioko R.csv - hbb
#   Dioko R.csv - kr0mka
#   Resolve 7Hz Salnotes Dioko Gras L.csv - kurin
#   7hz x Crinacle Dioko Updated R.csv - vortexreviews
#   7Hz x Crinacle Salnotes Dioko R.csv - vsg
#
# 7hz eternal l:
#   7Hz Eternal L.csv - achoreviews
#   7Hz Eternal R.csv - bedrock
#   7Hz ETERNAL R.csv - iemworld
#   7hz Eternal R.csv - vortexreviews
#   7Hz Eternal R.csv - vsg
#   7Hz Eternal R.csv - harpo
#   7Hz Eternal R.csv - hbb
#
# 7hz legato l:
#   7Hz Legato L.csv - achoreviews
#   7HZ LEGATO R.csv - aftersound
#   7Hz Legato R.csv - timmyv
#   7Hz Legato R.csv - cqtek
#   7HZ LEGATO R.csv - ianfann
#   7hz LEGATO R.csv - nymz
#   7hz Legato (inner vent blutack) L.csv - rg
#   7hz Legato R.csv - vortexreviews
#   7Hz Legato R.csv - vsg
#   7Hz Legato R.csv - hbb
#
# 7hz timeless l:
#   7Hz Timeless L.csv - achoreviews
#   7HZ TIMELESS S2 R.csv - aftersound
#   7Hz Timeless L.csv - arn
#   7Hz Timeless R.csv - soundjedi
#   7Hz Timeless R.csv - timmyv
#   7hz Timeless Tape Mod R.csv - hobbytalk
#   7Hz Timeless S2 MPFront L.csv - pw
#   7Hz Timeless (Tanchjim Filter, stock tuning foam sideways, Super Thin HS Foam inner vent) L.csv - rg
#   7hz Timeless R.csv - tgx78
#   7hz Timeless R.csv - vortexreviews
#   7Hz Timeless R.csv - vsg
#   7Hz Timeless (S2) R.csv - data_mrs
#   7HZ TIMELESS OG R.csv - ianfann
#   7hz Timeless AE R.csv - nymz
#   7Hz Timeless (no filter) R.csv - hbb
#   7Hz Timeless R.csv - harpo
#   7Hz Timeless (MoonDroop Tips) R.csv - iemworld
#   Timeless R.csv - kr0mka
#   Oratory 7Hz Timeless L.csv - kurin
#   7hertz Timeless R.csv - melatonin
#
# 7hz zero l:
#   7Hz Zero L.csv - achoreviews
#   7Hz Zero R.csv - bedrock
#   7Hz Zero R.csv - timmyv
#   7hz Zero Tape R.csv - hobbytalk
#   7HZ ZERO MECHA R.csv - ianfann
#   7Hz Zero R.csv - data_mrs
#   7HZ SALNOTES ZERO R.csv - aftersound
#   7Hz Salnotes Zero L.csv - arn
#   7hz Salnotes Zero S2 R.csv - nymz
#   7Hz Salnotes Zero v2 R.csv - pw
#   7hz Salnotes Zero R.csv - vortexreviews
#   7Hz Salnotes Zero R.csv - harpo
#   7hz Zero R.csv - hbb
#   7hz Zero (Red Orignal Eartips) R.csv - iemworld
#   7Hz ZERO S1 R.csv - jacstone
#   Resolve 7hz salnotes zero Gras L.csv - kurin
#   zero R.csv - recode
#
# acho reviews target:
#   Acho Reviews Target.csv - achoreviews
#   Bry Audio Reviews Target.csv - bryaudioreviews
#   X Target.csv - harpo
#   target 8.csv - recode
#   PW Target.csv - rg
#
# antdroid target:
#   Antdroid Target.csv - achoreviews
#   Antdroid Target.csv - aftersound
#   Antdroid Target.csv - animagus
#   Antdroid Target.csv - arn
#   Antdroid Target.csv - bedrock
#   Antdroid Target.csv - bryaudioreviews
#   Antdroid Target.csv - cammyfi
#   Antdroid Target.csv - soundjedi
#   Antdroid Target.csv - eplv
#   Antdroid Target.csv - timmyv
#   Antdroid Target.csv - harpo
#   Antdroid Target.csv - hbb
#   Antdroid Target.csv - cqtek
#   Antdroid Target.csv - hobbytalk
#   Antdroid Target.csv - ianfann
#   Antdroid Target.csv - iemworld
#   Antdroid Target.csv - kr0mka
#   Antdroid Target.csv - kurin
#   Antdroid Target.csv - melatonin
#   Antdroid Target.csv - nymz
#   Antdroid Target.csv - pw
#   Antdroid Target.csv - recode
#   Antdroid Target.csv - rg
#   Antdroid Target.csv - shortbus
#   Antdroid Target.csv - suporsalad
#   Antdroid Target.csv - tgx78
#   Antdroid Target.csv - vortexreviews
#   Antdroid Target.csv - vsg
#   Antdroid Target.csv - wdym
#   Antdroid Target.csv - akros
#   Antdroid Target.csv - data_mrs
#
# audeze isine lx (spinfit) l:
#   Audeze iSine LX (Spinfit) L.csv - achoreviews
#
# aune jasper l:
#   Aune Jasper L.csv - achoreviews
#   AUNE JASPER R.csv - aftersound
#   Aune Jasper (Tanchjim filter) R.csv - data_mrs
#   Aune Jasper R.csv - hbb
#
# bad guy target:
#   Bad Guy Target.csv - achoreviews
#   Bad Guy Target.csv - aftersound
#   Bad Guy Target.csv - animagus
#   Bad Guy Target.csv - arn
#   Bad Guy Target.csv - bedrock
#   Bad Guy Target.csv - bryaudioreviews
#   Bad Guy Target.csv - cammyfi
#   Bad Guy Target.csv - soundjedi
#   Bad Guy Target.csv - eplv
#   Bad Guy Target.csv - timmyv
#   Bad Guy 2022 Target.csv - harpo
#   Bad Guy Target v2.csv - hbb
#   Bad Guy Target.csv - cqtek
#   Bad Guy Target.csv - hobbytalk
#   Bad Guy Target.csv - ianfann
#   Bad Guy Target.csv - iemworld
#   Bad Guy Target.csv - kr0mka
#   Bad Guy Target.csv - melatonin
#   Bad Guy Target.csv - nymz
#   Bad Guy Target.csv - pw
#   Bad Guy Target.csv - recode
#   Bad Guy Target.csv - rg
#   Bad Guy Target.csv - shortbus
#   Bad Guy Target.csv - suporsalad
#   Bad Guy Target.csv - tgx78
#   Bad Guy Target.csv - vortexreviews
#   Bad Guy Target.csv - vsg
#   Bad Guy Target.csv - wdym
#   Bad Guy Target.csv - akros
#   Bad Guy Target.csv - data_mrs
#   Bad Guy 2022 Target.csv - kurin
#
# banbeucmas target:
#   Banbeucmas Target.csv - achoreviews
#   Banbeucmas Target.csv - aftersound
#   Banbeucmas Target.csv - animagus
#   Banbeucmas Target.csv - arn
#   Banbeucmas Target.csv - bedrock
#   Banbeucmas Target.csv - bryaudioreviews
#   Banbeucmas Target.csv - cammyfi
#   Banbeucmas Target.csv - soundjedi
#   Banbeucmas Target.csv - eplv
#   Banbeucmas Target.csv - timmyv
#   Banbeucmas Target.csv - harpo
#   Banbeucmas Target.csv - cqtek
#   Banbeucmas Target.csv - hobbytalk
#   Banbeucmas Target.csv - ianfann
#   Banbeucmas Target.csv - iemworld
#   Banbeucmas Target.csv - kr0mka
#   Banbeucmas Target.csv - kurin
#   Banbeucmas Target.csv - melatonin
#   Banbeucmas Target.csv - nymz
#   Banbeucmas Target.csv - pw
#   Banbeucmas Target.csv - recode
#   Banbeucmas Target.csv - rg
#   Banbeucmas Target.csv - shortbus
#   Banbeucmas Target.csv - suporsalad
#   Banbeucmas Target.csv - tgx78
#   Banbeucmas Target.csv - vortexreviews
#   Banbeucmas Target.csv - vsg
#   Banbeucmas Target.csv - wdym
#   Banbeucmas Target.csv - akros
#   Banbeucmas Target.csv - data_mrs
#
# blon bl01 l:
#   Blon T3 L.csv - achoreviews
#   BLON BL01 R.csv - bryaudioreviews
#   BLON BL05v2 L.csv - pw
#   Blon BL03 R.csv - timmyv
#   BLON BL07 R.csv - ianfann
#   Blon BL03 R.csv - suporsalad
#   Blon BL05 L.csv - data_mrs
#   BLON BL07 R.csv - aftersound
#   Blon BL07 R.csv - harpo
#   Blon BL50 R.csv - hbb
#   Blon A8 L.csv - vortexreviews
#   BLON B60 L.csv - vsg
#
# blon fat girl l:
#   Blon Fat Girl L.csv - achoreviews
#   BLON FAT GIRL R.csv - aftersound
#   BLON FAT GIRL R.csv - ianfann
#   BLON Fat Girl R.csv - jacstone
#   BLON Fat Girl R.csv - pw
#   Blon Fat Girl R.csv - vortexreviews
#   BLON Fat Girl R.csv - hbb
#   BLON FatGirl9 R.csv - eplv
#
# blon z200 l:
#   Blon Z200 L.csv - achoreviews
#   BLON Z200 L.csv - arn
#   Blon Z200 R.csv - harpo
#   BLON Z200 R.csv - ianfann
#   BLON Z200 R.csv - pw
#   Blon Z200 R.csv - vortexreviews
#
# cca cra l:
#   CCA CRA Plus L.csv - achoreviews
#   CCA NRA L.csv - aftersound
#   CCA NRA L.csv - eplv
#   CCA LYRA L.csv - hobbytalk
#   CCA CRA+ (STOCK TIPS) R.csv - ianfann
#   CCA CRA+ R.csv - jacstone
#   CCA CA24 L.csv - melatonin
#   CCA CRA EQ3 R.csv - nymz
#   CCA CRA Plus Vent R.csv - pw
#   CCA CRA+ (Stock Filter + 350 Mesh) L.csv - rg
#   CCA CRA R.csv - suporsalad
#   CCA CRA Mod R.csv - tgx78
#   CCA CSA L.csv - vortexreviews
#   CCA CRA Plus R.csv - data_mrs
#   CCA CRA Plus R.csv - timmyv
#   CCA CRA R.csv - harpo
#   CCA CRA + R.csv - hbb
#   CCA CRA+ R.csv - bedrock
#   CCA NRA L.csv - iemworld
#   CRA L.csv - kr0mka
#   CCA CA24 L.csv - vsg
#
# ccz emerald l:
#   CCZ Melody L.csv - achoreviews
#   CCZ EMERALD R.csv - aftersound
#   CCZ Emerald R.csv - eplv
#   CCZ emerald R.csv - melatonin
#   CCZ MELODY L.csv - ianfann
#   CCZ Melody L.csv - pw
#   CCZ Melody L.csv - vortexreviews
#
# ccz warrior l:
#   Tin C2 Mech Warrior L.csv - achoreviews
#   CCZ Warrior L.csv - arn
#   CCZ WARRIOR R.csv - ianfann
#   CCZ Warrior R.csv - pw
#   TIN C2 MECH WARRIOR L.csv - aftersound
#   Tin Hifi C2 Mech Warrior L.csv - data_mrs
#
# celest pandamon l:
#   Celest Pandamon L.csv - achoreviews
#   Kinera Celest Pandamon R.csv - arn
#   Kinera Celest Pandamon R.csv - cqtek
#   Kinera Celest Pandamon R.csv - vortexreviews
#
# crinacle target:
#   Crinacle Target.csv - achoreviews
#   Crinacle Target.csv - aftersound
#   Crinacle Target.csv - animagus
#   Crinacle Target.csv - arn
#   Crinacle Target.csv - bedrock
#   Crinacle IEF-Neutral Target.csv - bryaudioreviews
#   Crinacle Target.csv - cammyfi
#   Crinacle Target.csv - soundjedi
#   Crinacle Target.csv - timmyv
#   Crinacle Target.csv - harpo
#   Crinacle Target.csv - hbb
#   Crinacle Target.csv - cqtek
#   Crinacle Target.csv - ianfann
#   Crinacle Target.csv - iemworld
#   Crinacle Target.csv - kr0mka
#   Crinacle Target.csv - kurin
#   Crinacle Target.csv - melatonin
#   Crinacle Target.csv - nymz
#   Crinacle Target.csv - pw
#   Crinacle Target.csv - shortbus
#   Crinacle Target.csv - tgx78
#   Crinacle Target.csv - vortexreviews
#   Crinacle Target.csv - vsg
#   Crinacle Target.csv - wdym
#   Crinacle Target.csv - akros
#   Crinacle Neutral 2023 Target.csv - data_mrs
#   Old Crinacle Target.csv - eplv
#   Crinacle Neutral Target.csv - recode
#
# diffuse field target:
#   Free Field Target.csv - achoreviews
#   Free Field Target.csv - aftersound
#   Free Field Target.csv - animagus
#   Free Field Target.csv - arn
#   Free Field Target.csv - bedrock
#   Free Field Target.csv - bryaudioreviews
#   Free Field Target.csv - cammyfi
#   Free Field Target.csv - soundjedi
#   Free Field Target.csv - eplv
#   Free Field Target.csv - timmyv
#   Free Field Target.csv - harpo
#   Free Field Target.csv - hbb
#   Free Field Target.csv - cqtek
#   Free Field Target.csv - hobbytalk
#   Free Field Target.csv - ianfann
#   Free Field Target.csv - iemworld
#   Free Field Target.csv - kr0mka
#   Diffuse Field Target.csv - kurin
#   Free Field Target.csv - melatonin
#   Free Field Target.csv - nymz
#   Free Field Target.csv - pw
#   Free Field Target.csv - recode
#   Free Field Target.csv - rg
#   Free Field Target.csv - shortbus
#   Free Field Target.csv - suporsalad
#   Free Field Target.csv - tgx78
#   Free Field Target.csv - vortexreviews
#   Free Field Target.csv - vsg
#   Free Field Target.csv - wdym
#   Free Field Target.csv - akros
#   Diffuse Field Target.csv - data_mrs
#
# dunu kima l:
#   Dunu Kima L.csv - achoreviews
#   DUNU KIMA R.csv - aftersound
#   Dunu Kima R.csv - bedrock
#   Dunu Kima R.csv - timmyv
#   Dunu Kima R.csv - cqtek
#   DUNU KIMA R.csv - ianfann
#   DUNU KIMA R.csv - nymz
#   Dunu Kima R.csv - vortexreviews
#   DUNU KIMA R.csv - vsg
#   Dunu Kima R.csv - data_mrs
#   Dunu Kima R.csv - hbb
#
# dunu talos (planar + ba) (ie600 foam tips) l:
#   Dunu Talos (Planar Only) L.csv - achoreviews
#   DUNU TALOS ON R.csv - aftersound
#   Dunu Talos R.csv - animagus
#   Dunu Talos (S2 on) L.csv - data_mrs
#   DUNU Zen Foam L.csv - nymz
#   DUNU Talos R.csv - pw
#   Dunu Talos BA R.csv - hbb
#   DUNU Talos Planar+BA L.csv - arn
#   DUNU TALOS Planar R.csv - vsg
#   DUNU TALOS PLANAR+BA R.csv - ianfann
#   Dunu Talos (Planar) R.csv - timmyv
#   ie600 R.csv - recode
#
# dunu titan s (isolation) l:
#   Dunu Titan S L.csv - achoreviews
#   DUNU TITAN S R.csv - aftersound
#   DUNU Titan S R.csv - arn
#   Dunu Titan S R.csv - bedrock
#   Dunu Titan S R.csv - bryaudioreviews
#   Dunu Titan S R.csv - timmyv
#   Dunu Titan S R.csv - cqtek
#   DUNU TITAN S R.csv - ianfann
#   DUNU TITAN S R.csv - iemworld
#   Dunu Titan S R.csv - nymz
#   Dunu Titan S R.csv - rg
#   Dunu Titan S L.csv - vortexreviews
#   DUNU TITAN S R.csv - vsg
#   Dunu Titan S R.csv - hbb
#   DUNU Titan Tanya L.csv - pw
#   Dunu Titan S (pre) R.csv - data_mrs
#
# dunu vulkan l:
#   Dunu Vulkan L.csv - achoreviews
#   Dunu Vulkan R.csv - bedrock
#   Dunu Vulkan R.csv - timmyv
#   Dunu Vulkan R.csv - harpo
#   DUNU Vulkan R.csv - nymz
#   Dunu VULKAN R.csv - rg
#   DUNU VULKAN R.csv - vsg
#   Dunu Vulkan (S2) R.csv - data_mrs
#   Dunu Vulkan R.csv - hbb
#
# effect audio axiom l:
#   Effect Audio Axiom L.csv - achoreviews
#   Effect Audio Axiom R.csv - vsg
#   Effect Audio Gaea (deep) L.csv - data_mrs
#   Effect Audio GAEA L.csv - bryaudioreviews
#
# etymotic target:
#   Etymotic Target.csv - achoreviews
#   Etymotic Target.csv - aftersound
#   Etymotic Target.csv - animagus
#   Etymotic Target.csv - arn
#   Etymotic Target.csv - bedrock
#   Etymotic Target.csv - bryaudioreviews
#   Etymotic Target.csv - cammyfi
#   Etymotic Target.csv - soundjedi
#   Etymotic Target.csv - eplv
#   Etymotic Target.csv - timmyv
#   Etymotic Target.csv - harpo
#   Etymotic Target.csv - hbb
#   Etymotic Target.csv - cqtek
#   Etymotic Target.csv - hobbytalk
#   Etymotic Target.csv - ianfann
#   Etymotic Target.csv - iemworld
#   Etymotic Target.csv - kr0mka
#   Etymotic Target.csv - kurin
#   Etymotic Target.csv - melatonin
#   Etymotic Target.csv - nymz
#   Etymotic Target.csv - pw
#   Etymotic Target.csv - recode
#   Etymotic Target.csv - rg
#   Etymotic Target.csv - shortbus
#   Etymotic Target.csv - suporsalad
#   Etymotic Target.csv - tgx78
#   Etymotic Target.csv - vortexreviews
#   Etymotic Target.csv - vsg
#   Etymotic Target.csv - wdym
#   Etymotic Target.csv - akros
#   Etymotic Target.csv - data_mrs
#
# fiio fhe eclipse l:
#   Fiio FHE Eclipse L.csv - achoreviews
#   FIIO F1 L.csv - aftersound
#   Fiio F1 L.csv - bedrock
#   FiiO FHE R.csv - timmyv
#   FiiO FHE R.csv - melatonin
#   Fiio FHE (S2) L.csv - data_mrs
#   FIIO x Crinacle FHE Eclipse (NO TIP on Coupler) R.csv - iemworld
#   FiiO FHE S2 L.csv - jacstone
#   FiiO x Crinacle FHE (Eclipse) R.csv - vsg
#
# final audio e500 l:
#   Final Audio E500 L.csv - achoreviews
#   Final Audio FI-EVA2020 L.csv - rg
#   FINAL AUDIO A4000 R.csv - aftersound
#   Final Audio VR3000 L.csv - nymz
#   Final Audio e5000 R.csv - bryaudioreviews
#   final E500 R.csv - eplv
#   Final E500 AutoEQ L.csv - pw
#   Final E500 L.csv - akros
#   Final E500 L.csv - data_mrs
#   Final Audio E3000 R.csv - harpo
#   Final Audio E3000 L.csv - hobbytalk
#   Oratory Final Audio UX3000 (B, ANC on) L.csv - kurin
#
# harman target:
#   Harman Target.csv - achoreviews
#   Harman Target.csv - aftersound
#   Harman Over Ear 2018 Target.csv - animagus
#   Harman V2 Target.csv - arn
#   Harman Target.csv - bedrock
#   Harman 2019 Target.csv - bryaudioreviews
#   Harman IE 2019 v2 Target.csv - cammyfi
#   Harman Target.csv - soundjedi
#   Harman2019v2 Target.csv - eplv
#   Harman Target.csv - timmyv
#   Harpo Target.csv - harpo
#   Harman Target.csv - hbb
#   Harman Target.csv - cqtek
#   Harman IE 2019 Target.csv - hobbytalk
#   Harman Target.csv - iemworld
#   Harman Target.csv - melatonin
#   Harman 2019v2 Target.csv - nymz
#   Harman 2019v2 Target.csv - pw
#   Harman 2017v2 Target.csv - recode
#   Harman Target.csv - shortbus
#   Harman OE Target.csv - suporsalad
#   Harman Target.csv - tgx78
#   Harman Target.csv - vortexreviews
#   Harman Target.csv - wdym
#   Harman Target.csv - akros
#   Harman Adjusted Target.csv - data_mrs
#   Harman 2019 Target.csv - ianfann
#   Harman 2019 Target.csv - jacstone
#   Harman IE 2017 v2 Target.csv - kr0mka
#   Olive-Welti Harman Bass Target.csv - kurin
#   Harman 2017v2 Target.csv - rg
#   Harman In-Ear Target.csv - vsg
#
# hidition violet l:
#   Hidition Violet L.csv - achoreviews
#   Hidition Violet R.csv - soundjedi
#   Hidition Violet L.csv - cqtek
#   Hidition Violet L.csv - data_mrs
#   Hidition Viento-B L.csv - timmyv
#
# hifiman re600s v2 l:
#   Hifiman RE600s v2 L.csv - achoreviews
#   HIFIMAN RE800 L.csv - ianfann
#   Oratory HIFIMAN RE600S L.csv - kurin
#   Hifiman RE600 V2 R.csv - nymz
#
# hifiman svanar l:
#   Hifiman Svanar L.csv - achoreviews
#   HIFIMAN Svanar S3 R.csv - vsg
#
# hifiman tws800 l:
#   Hifiman TWS800 L.csv - achoreviews
#   HIFIMAN TWS800 R.csv - ianfann
#   HIFIMAN TWS800 R.csv - vsg
#   Hifiman R800 R.csv - harpo
#
# hz sound heart mirror pro l:
#   HZ Sound Heart Mirror Pro L.csv - achoreviews
#   HZ SOUND HEART MIRROR R.csv - ianfann
#   HZSOUND HEART MIRROR R.csv - aftersound
#   HZSOUND Heart Mirror Pro R.csv - nymz
#   HZSOUND Heart Mirror R.csv - vortexreviews
#   HZSound Heart Mirror L.csv - data_mrs
#   HZSound Heart Mirror Pro R.csv - harpo
#   Heart Mirror Pro L.csv - arn
#   Heart Mirror R.csv - bryaudioreviews
#   HZ Heartmirror Pro R.csv - timmyv
#   HZ sound pro R.csv - hbb
#
# ikko opal oh02 l:
#   Ikko Opal OH02 L.csv - achoreviews
#   IKKO OPAL OH2 L.csv - arn
#   Ikko Opal OH2 R.csv - data_mrs
#
# innerfidelity id target:
#   Innerfidelity ID Target.csv - achoreviews
#   Innerfidelity Target.csv - aftersound
#   Innerfidelity ID Target.csv - animagus
#   Innerfidelity ID Target.csv - arn
#   Innerfidelity ID Target.csv - bedrock
#   Innerfidelity ID Target.csv - bryaudioreviews
#   Innerfidelity ID Target.csv - cammyfi
#   Innerfidelity ID Target.csv - soundjedi
#   Innerfidelity ID Target.csv - eplv
#   Innerfidelity ID Target.csv - timmyv
#   Innerfidelity ID Target.csv - harpo
#   Innerfidelity ID Target.csv - cqtek
#   Innerfidelity ID Target.csv - hobbytalk
#   Innerfidelity ID Target.csv - ianfann
#   Innerfidelity ID Target.csv - iemworld
#   Innerfidelity ID Target.csv - kr0mka
#   Innerfidelity ID Target.csv - melatonin
#   Innerfidelity ID Target.csv - nymz
#   Innerfidelity ID Target.csv - pw
#   Innerfidelity ID Target.csv - recode
#   Innerfidelity ID Target.csv - rg
#   Innerfidelity ID Target.csv - shortbus
#   Innerfidelity ID Target.csv - suporsalad
#   Innerfidelity ID Target.csv - tgx78
#   Innerfidelity ID Target.csv - vortexreviews
#   Innerfidelity ID Target.csv - vsg
#   Innerfidelity ID Target.csv - wdym
#   Innerfidelity ID Target.csv - akros
#
# itk unknown l:
#   ITK Unknown L.csv - achoreviews
#   Unknown Amazon IEM L.csv - hobbytalk
#
# joyodio shine (0000) l:
#   Joyodio Shine (1110) L.csv - achoreviews
#   JOYODIO SHINE ALL OFF L.csv - aftersound
#   Joyodio Shine 1111 L.csv - cqtek
#   JOYODIO SHINE STANDARD L.csv - ianfann
#   Joyodio Shine POP R.csv - vortexreviews
#
# kbear lark (s1) l:
#   KBEAR Lark (S2) L.csv - achoreviews
#   KBEAR KS1 L.csv - aftersound
#   KBEAR KS1 L.csv - ianfann
#   KBEAR KS1 L.csv - jacstone
#   KBEAR Lark4k L.csv - pw
#   Kbear KS1 L.csv - vortexreviews
#   KBEAR Lark R.csv - bedrock
#   KBEAR KS19 L.csv - eplv
#   KBEAR Lark R.csv - cqtek
#   KBEAR Lark R.csv - melatonin
#
# kbear little q l:
#   KBEAR Little Q L.csv - achoreviews
#   KBEAR Little Q L.csv - arn
#   KBEar Little Q R.csv - bryaudioreviews
#   KBEAR LITTLE Q R.csv - ianfann
#   Kbear Q R.csv - hbb
#   KBEAR LittleQ R.csv - pw
#
# kbear qinglong l:
#   KBEAR Qinglong L.csv - achoreviews
#   KBEAR QINGLONG R.csv - aftersound
#   KBEAR Qinglong R.csv - arn
#   KBEAR QINGLONG R.csv - ianfann
#
# kbear robin l:
#   KBEAR Robin L.csv - achoreviews
#   KBEAR Robin R.csv - cqtek
#   KBEAR Robin R.csv - melatonin
#   KBEAR Rosefinch L.csv - pw
#   KBEAR Robin R.csv - rg
#   KBEAR NEON L.csv - aftersound
#   KB Ear Robin L.csv - bryaudioreviews
#   KBEAR Neon L.csv - eplv
#   KBEAR ROSEFINCH L.csv - ianfann
#   KBEAR Rosefinch L.csv - arn
#
# kinera bd005 pro l:
#   Kinera BD005 Pro L.csv - achoreviews
#   Kinera Tyr L.csv - bedrock
#   KINERA BD005 PRO R.csv - aftersound
#   Kinera BD005 R.csv - hbb
#   KINERA URD L.csv - ianfann
#   Kinera BD005Pro L.csv - pw
#   Kinera Sif L.csv - data_mrs
#
# kiwi ears cadenza l:
#   Kiwi Ears Cadenza L.csv - achoreviews
#   KIWI EARS CADENZA R.csv - aftersound
#   Kiwi Ears CADENZA R.csv - arn
#   Kiwi Ears Cadenza R.csv - bedrock
#   Kiwi Ears Cadenza R.csv - cammyfi
#   Kiwi Ears Cadenza R.csv - hobbytalk
#   Kiwi Ears Cadenza R.csv - vortexreviews
#   Kiwi Ears Cadenza R.csv - data_mrs
#   Kiwi Ears Cadenza R.csv - harpo
#   Kiwi Ears R.csv - hbb
#   Kiwi Cadenza R.csv - timmyv
#
# kiwi ears orchestra lite l:
#   Kiwi Ears Orchestra Lite L.csv - achoreviews
#   Kiwi Ears Orchestra Lite R.csv - bedrock
#   Kiwi Ears Orchestra Lite R.csv - nymz
#   Kiwi Ears Orchestra Lite R.csv - pw
#   Kiwi Ears Orchestra Lite (25ohm) L.csv - rg
#   Kiwi Ears Orchestra Lite R.csv - vortexreviews
#   Kiwi Ears Orchestra Lite deep fit R.csv - vsg
#   Kiwi Ears Orchestra R.csv - data_mrs
#   Kiwi Orchestra R.csv - timmyv
#   KIWIEARS ORCHESTRA LITE L.csv - ianfann
#
# koss keb90 l:
#   Koss KEB90 L.csv - achoreviews
#   KOSS KEB90 R.csv - hobbytalk
#   Koss KEB90 R.csv - data_mrs
#
# kz as16 pro l:
#   KZ ZSN Pro L.csv - achoreviews
#   KZ AS16 PRO R.csv - aftersound
#   KZ SK10 PRO L.csv - ianfann
#   KZ AS16 Pro 75Ω R.csv - melatonin
#   KZ AS16 Pro TK2 L.csv - pw
#   KZ AS16 Pro R.csv - vortexreviews
#   QKZ AK6 Pro L.csv - jacstone
#   KZ ZEX Pro L.csv - rg
#   KZ PR1 Pro L.csv - data_mrs
#   KZ Zex Pro L.csv - tgx78
#   KZ AS16R22 L.csv - eplv
#   KZ ZS10 PRO L.csv - timmyv
#   KZ AS16 Pro R.csv - hbb
#   KZ PR1 Pro L.csv - arn
#
# kz ate l:
#   KZ ATE L.csv - achoreviews
#   KZ ATE R.csv - data_mrs
#   KZ ATR L.csv - eplv
#   KZ AST L.csv - harpo
#   KZ AST L.csv - melatonin
#   Oratory KZ ATE L.csv - kurin
#
# kz dq6 l:
#   KZ ED16 L.csv - achoreviews
#   KZ DQ6 R.csv - eplv
#   KZ DQ6S R.csv - ianfann
#   KZ DQ6S R.csv - jacstone
#   KZ DQ6s R.csv - melatonin
#   KZ DQ6s R.csv - nymz
#   KZ DQ6v2 L.csv - pw
#   KZ DQ6 (Sony Import Foam) L.csv - rg
#   KZ DQ6 (Tanchjim filter) R.csv - data_mrs
#   KZ DQ6S R.csv - aftersound
#   KZ DQ6S R.csv - bedrock
#   KZ DQ6 Xl R.csv - hbb
#   KZ DQ6 R.csv - vortexreviews
#   KZ DQ6S R.csv - harpo
#
# kz edx l:
#   KZ ZEX L.csv - achoreviews
#   KZ ESX9 L.csv - eplv
#   KZ EDS L.csv - jacstone
#   KZ EDC L.csv - melatonin
#   KZ EDXv2 L.csv - pw
#   KZ EDX Ultra R.csv - vortexreviews
#   KZ ZEX L.csv - bryaudioreviews
#   KZ EDCX L.csv - ianfann
#   KZ ZEX L.csv - iemworld
#   KZ EDAB L.csv - suporsalad
#   KZ ZEX L.csv - tgx78
#   KZ EDX Pro R.csv - data_mrs
#   KZ EDX ULTRA R.csv - aftersound
#   KZ Edcx R.csv - hbb
#   KZ EDX Pro (Low-Density Tuning Foam) L.csv - rg
#   KZ ESX L.csv - arn
#   KZ ESX L.csv - harpo
#
# kz pr1 l:
#   KZ PR1 L.csv - achoreviews
#   KZ PR1 R.csv - timmyv
#   KZ PR1 STOCK TIPS R.csv - ianfann
#   KZ PR1 Pro R.csv - arn
#   KZ PR1 Hifi R.csv - vortexreviews
#   KZ Z1 L.csv - pw
#   KZ PR1 Pro R.csv - data_mrs
#   KZ PR1 R.csv - hbb
#   KZ PR1 Balanced L.csv - harpo
#   KZ PR1 HiFi version R.csv - melatonin
#   pro1 8k L.csv - recode
#
# kz zax l:
#   KZ ZVX L.csv - achoreviews
#   KZ ZAX R.csv - melatonin
#   KZ ZAXv2 L.csv - pw
#   KZ ZNA L.csv - vortexreviews
#   KZ ZVX L.csv - aftersound
#   KZ ZVX L.csv - timmyv
#   KZ ZNA L.csv - ianfann
#   KZ ZSX L.csv - eplv
#   KZ ZAX R.csv - hbb
#   QKZ ZXT L.csv - jacstone
#   KZ ASX L.csv - data_mrs
#
# kz zes l:
#   KZ ZSN L.csv - achoreviews
#   KZ ZES R.csv - aftersound
#   KZ ZES R.csv - ianfann
#   KZ ZST L.csv - pw
#   KZ ZSE L.csv - rg
#   KZ ZES R.csv - vortexreviews
#   KZ ZSR L.csv - eplv
#   KZ ZST L.csv - melatonin
#   KZ ZS7 L.csv - data_mrs
#
# kz zsn pro x l:
#   KZ ZSN Pro X L.csv - achoreviews
#   KZ ZSN Pro X R.csv - bryaudioreviews
#   KZ ZSN R.csv - melatonin
#   KZ ZSN Prov2 L.csv - pw
#   KZ ZSN PRO X R.csv - aftersound
#   KZ ZSN R.csv - hbb
#   KZ ZSN R.csv - eplv
#   KZ ZS10 PRO X R.csv - ianfann
#   KZ ZS10 Pro X R.csv - vortexreviews
#   KZ ZSN Pro (Tanchjim filter) L.csv - data_mrs
#   Oratory KZ ZSN Pro L.csv - kurin
#   KZ ZSN PRO X OK L.csv - nymz
#
# kz zst x l:
#   KZ ZST X L.csv - achoreviews
#   KZ ZST R.csv - melatonin
#   KZ ZST X L.csv - vortexreviews
#   KZ ZST X R.csv - aftersound
#   KZ ZST R.csv - hbb
#   Oratory KZ ZST L.csv - kurin
#   KZ ZSTv2 L.csv - pw
#
# letshuoer d13 (gold filter) l:
#   Letshuoer D13 (Silver Filter) L.csv - achoreviews
#   LETSHUOER S12 L.csv - arn
#   LetShuoer S12 L.csv - soundjedi
#   LETSHUOER S12 L.csv - eplv
#   Letshuoer KL L.csv - timmyv
#   LetShuoer D13 Silver L.csv - cqtek
#   LETSHUOER D13 R.csv - vortexreviews
#   LETSHUOER D13 gold nozzle L.csv - vsg
#   Letshuoer D13 (silver) L.csv - data_mrs
#   Letshuoer D13 (Silver) L.csv - bedrock
#   LETSHUOER D13 Olina Filter mod R.csv - harpo
#   LetShuoer D13 Silver L.csv - pw
#   LETSHUOER Z12 L.csv - hobbytalk
#   LETSHUOER D13 R.csv - ianfann
#
# letshuoer s12 (s1) l:
#   Letshuoer S12 (S2) L.csv - achoreviews
#   SHUOER S12 L.csv - aftersound
#   Shuoer S12 L.csv - animagus
#   Shuoer S12 L.csv - iemworld
#   Shuoer S12 L.csv - pw
#   Letshuoer S12 PRO Vents Blocked L.csv - cammyfi
#   Letshuoer S12 R.csv - timmyv
#   LetShuoer S12 R.csv - cqtek
#   LETSHUOER Z12 (S2) R.csv - hobbytalk
#   LETSHUOER S12 PRO R.csv - ianfann
#   LETSHUOER S12 R.csv - vortexreviews
#   LetShuoer S12 R.csv - soundjedi
#   LETSHUOER S12 R.csv - eplv
#   Letshuoer S12 R.csv - harpo
#   LETSHUOER S12 Foam R.csv - melatonin
#   LETSHUOER S12 R.csv - vsg
#   Letshuoer S12 (top vent blocked) L.csv - data_mrs
#   Shuoer S12 Sony L.csv - nymz
#   S12 L.csv - shortbus
#
# lz a4 pro nzblk fiblk l:
#   LZ A4 Pro NzSil FiBlu L.csv - achoreviews
#   LZ A4 PRO R.csv - hbb
#   LZ A4 Pro Blue-Black L.csv - cqtek
#
# lz a4 pro nzred fired l:
#   LZ A4 Pro NzSil FiRed L.csv - achoreviews
#   LZ A4 Pro (Red F + Red V) L.csv - rg
#
# meze audio advar l:
#   Meze Audio Advar L.csv - achoreviews
#
# moondrop aria l:
#   Moondrop Starfield L.csv - achoreviews
#   MOONDROP VARIATIONS L.csv - aftersound
#   Moondrop Stellaris (UC) L.csv - animagus
#   Moondrop Lan L.csv - bedrock
#   Moondrop Stellaris modded L.csv - bryaudioreviews
#   Moondrop B2 L.csv - timmyv
#   MOONDROP CHU BASS MOD L.csv - ianfann
#   Moondrop Stellaris NoFoam L.csv - pw
#   Moondrop Lan L.csv - vortexreviews
#   Moondrop VOID S2 L.csv - vsg
#   Simgot EN700 Pro (Moondrop) L.csv - data_mrs
#   Moondrop LAN L.csv - arn
#   Moondrop Variations Manufacturer Measurment L.csv - cammyfi
#   Moondrop Spaceship L.csv - eplv
#   Moondrop Variations Springtips L.csv - hobbytalk
#   TRUTHEAR x Crinacle ZERO (MoonDrop Eartips) L.csv - iemworld
#   Moondrop Aria S2 R.csv - jacstone
#   Moondrop Chu Tanya L.csv - nymz
#   Moondrop B2D L.csv - suporsalad
#   Moondrop Kato (Gold, Sony Import Foam, Micropore Vent) L.csv - rg
#   Moondrop Kanas Pro L.csv - cqtek
#   Moondrop Quarks DSP L.csv - harpo
#   Moondrop Aria Snow R.csv - hbb
#   Moondrop Kato L.csv - tgx78
#   Aria R.csv - kr0mka
#   ARIA L.csv - akros
#   Resolve Moondrop KXXX Gras L.csv - kurin
#   Moondrop KXXS L.csv - melatonin
#   Moondrop Illumination L.csv - recode
#
# moondrop blessing 2 dusk:
#   Moondrop Blessing 2 Dusk (Spinfit) L.csv - achoreviews
#   MOONDROP BLESSING 2 L.csv - aftersound
#   MOONDROP BLESSING 2 R.csv - aftersound
#   Moondrop Blessing2 L.csv - animagus
#   Moondrop Blessing2 R.csv - animagus
#   MD B2 Dusk L.csv - timmyv
#   MD B2 Dusk R.csv - timmyv
#   MD B2 L.csv - timmyv
#   MD B2 R.csv - timmyv
#   Moondrop B2 Dusk L.csv - timmyv
#   Moondrop B2 Dusk R.csv - timmyv
#   Moondrop Blessing 3 R.csv - hbb
#   Moondrop Dusk R.csv - hbb
#   Moondrop Blessing 2 Dusk L.csv - cqtek
#   Moondrop Blessing 2 Dusk R.csv - cqtek
#   Moondrop Blessing 2 Dusk (BGVP Foam) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (BGVP Foam) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (FINAL EARTIPS) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (FINAL EARTIPS) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (NO TIP on Coupler 8K) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (NO TIP on Coupler 8K) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (ORIGNAL SILICON) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (ORIGNAL SILICON) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (SOFTEAR UC EARTIPS) R.csv - iemworld
#   Moondrop Blessing 2 Dusk (SOFTEAR UC EARTIPS)C L.csv - iemworld
#   Moondrop Blessing 2 Dusk (Tripowin Foam) L.csv - iemworld
#   Moondrop Blessing 2 Dusk (Tripowin Foam) R.csv - iemworld
#   Moondrop Blessing 2 Dusk S1 L.csv - jacstone
#   Moondrop Blessing 2 Dusk S1 R.csv - jacstone
#   Moondrop Blessing 2 Dusk S2 L.csv - jacstone
#   Moondrop Blessing 2 Dusk S2 R.csv - jacstone
#   Dusk L.csv - kr0mka
#   Dusk R.csv - kr0mka
#   Oratory Moondrop Blessing 2 Dusk L.csv - kurin
#   Oratory Moondrop Blessing 2 L.csv - kurin
#   Oratory Moondrop Blessing L.csv - kurin
#   Resolve Blessing 2 Dusk Gras L.csv - kurin
#   Resolve Blessing 2 Gras L.csv - kurin
#   Moondrop B2 Dusk L.csv - nymz
#   Moondrop B2 Dusk R.csv - nymz
#   Moondrop Blessing 2 L.csv - nymz
#   Moondrop Blessing 2 R.csv - nymz
#   dusk bgvp L.csv - recode
#   dusk bgvp R.csv - recode
#   dusk bgvpshallow L.csv - recode
#   dusk bgvpshallow R.csv - recode
#   dusk L.csv - recode
#   dusk mistip L.csv - recode
#   dusk mistip R.csv - recode
#   dusk ortofon L.csv - recode
#   dusk ortofon R.csv - recode
#   dusk R.csv - recode
#   dusk w1 L.csv - recode
#   dusk w1 R.csv - recode
#   dusk w1shallow L.csv - recode
#   dusk w1shallow R.csv - recode
#   Moondrop Blessing 2 L.csv - rg
#   MOONDROP Blessing 3 L.csv - vsg
#   MOONDROP Blessing 3 R.csv - vsg
#   Blessing 2 Dusk L.csv - wdym
#   KZ ZSN Pro (Blessing 2 filter) L.csv - data_mrs
#   Moondrop Blessing 2 (E-type) L.csv - data_mrs
#   Moondrop Blessing 2 (Moondrop filter) L.csv - data_mrs
#   Moondrop Blessing 2 (Precog) L.csv - data_mrs
#   Moondrop Blessing 2 Dusk (Precog) L.csv - data_mrs
#   Moondrop Blessing 2 Dusk L.csv - data_mrs
#   Moondrop Blessing 2 L.csv - data_mrs
#   Moondrop Blessing 2 R.csv - data_mrs
#   Moondrop Blessing 2 Target.csv - data_mrs
#   Moondrop Blessing 3 L.csv - data_mrs
#   Moondrop Blessing 3 R.csv - data_mrs
#
# nf audio nm2 l:
#   NF Audio NM2 L.csv - achoreviews
#   NF AUDIO NM2+ R.csv - cqtek
#   NF AUDIO NM2 R.csv - ianfann
#   NF Audio NM2 L.csv - tgx78
#   NF Audio NM2 R.csv - vortexreviews
#   NF Audio NA2+ (Tanchjim filter) L.csv - data_mrs
#   NFAUDIO NM2 L.csv - aftersound
#   NFAudio NM2 L.csv - pw
#   NF Audio NA3 L.csv - arn
#   NF Audio N2+ R.csv - hbb
#   NFaudio NM2+ L.csv - melatonin
#
# nicehck topguy l:
#   NiceHCK Topguy L.csv - achoreviews
#   NiceHCK DB1 L.csv - cqtek
#   NICEHCK Topguy R.csv - melatonin
#   NiceHCK Topguy R.csv - data_mrs
#   NICEHCK DB3 L.csv - aftersound
#   NICEHCK DB3 L.csv - iemworld
#   NiceHCK DB3 L.csv - pw
#   Nicehck X49 L.csv - bedrock
#   NICEHCK X49 L.csv - eplv
#   NiceHck Topguy R.csv - hbb
#   NiceHCK DB1 L.csv - jacstone
#
# openheart resin l:
#   Openheart Resin L.csv - achoreviews
#   Openheart Resin L.csv - vortexreviews
#   openheart A2 L.csv - melatonin
#   Openheart Resin R.csv - tgx78
#
# plussound allegro l:
#   Plussound Allegro L.csv - achoreviews
#   PlusSound Allegro R.csv - soundjedi
#
# precogvision target:
#   Precogvision Target.csv - achoreviews
#   Precogvision Target.csv - aftersound
#   Precogvision Target.csv - animagus
#   Precogvision Target.csv - arn
#   Precogvision Target.csv - bedrock
#   Precogvision Target.csv - bryaudioreviews
#   Precogvision Target.csv - cammyfi
#   Precogvision Target.csv - soundjedi
#   Precogvision Target.csv - eplv
#   Precogvision Target.csv - timmyv
#   Precogvision Target.csv - harpo
#   Precogvision Target.csv - cqtek
#   Precogvision Target.csv - hobbytalk
#   Precogvision Target.csv - ianfann
#   Precogvision Target.csv - iemworld
#   Precogvision Target.csv - kr0mka
#   Precogvision Target.csv - melatonin
#   Precogvision Target.csv - nymz
#   Precogvision Target.csv - pw
#   Precogvision Target.csv - recode
#   Precogvision Target.csv - rg
#   Precogvision Target.csv - shortbus
#   Precogvision Target.csv - suporsalad
#   Precogvision Target.csv - tgx78
#   Precogvision Target.csv - vortexreviews
#   Precogvision Target.csv - vsg
#   Precogvision Target.csv - wdym
#   Precogvision Target.csv - akros
#   Precogvision Target.csv - data_mrs
#   Precog Target.csv - hbb
#   Precog Target.csv - kurin
#
# qkz ck5 l:
#   QKZ CK5 L.csv - achoreviews
#   QKZ CK10 L.csv - eplv
#
# qkz x hbb khan l:
#   QKZ x HBB L.csv - achoreviews
#   QKZ X HBB R.csv - aftersound
#   QKZ x HBB R.csv - timmyv
#   QKZ x HBB Khan R.csv - cqtek
#   QKZ x HBB VE Adapter L.csv - hobbytalk
#   QKZ X HBB R.csv - ianfann
#   QKZ x HBB R.csv - nymz
#   QKZ x HBB Khan TK2 L.csv - pw
#   QKZ x HBB R.csv - vortexreviews
#   QKZ Khan R.csv - arn
#   QKZ X HBB R.csv - iemworld
#   QKZ x HBB R.csv - data_mrs
#   QKZ HBB R.csv - hbb
#   QKZ x HBB R.csv - melatonin
#   QKZ Khan R.csv - jacstone
#   QKZ x HBB Kahn R.csv - harpo
#
# qoa gimlet l:
#   QOA Gimlet L.csv - achoreviews
#   QOA GIMLET R.csv - aftersound
#   QoA Gimlet R.csv - arn
#   QoA Gimlet R.csv - pw
#
# reecho sg01 l:
#   Reecho SG03 L.csv - achoreviews
#   Reecho SG-03 L.csv - cqtek
#   REECHO GY09s L.csv - jacstone
#
# rtings target:
#   Rtings Target.csv - achoreviews
#   Rtings Target.csv - aftersound
#   Rtings Target.csv - animagus
#   Rtings Target.csv - arn
#   Rtings Target.csv - bedrock
#   Rtings Target.csv - bryaudioreviews
#   Kurin Target.csv - cammyfi
#   Rtings Target.csv - soundjedi
#   Rtings Target.csv - eplv
#   Rtings Target.csv - timmyv
#   Rtings Target.csv - harpo
#   Rtings Target.csv - hbb
#   Rtings Target.csv - cqtek
#   Rtings Target.csv - hobbytalk
#   Rtings Target.csv - ianfann
#   Rtings Target.csv - iemworld
#   Rtings Target.csv - kr0mka
#   Kurin Target.csv - kurin
#   Rtings Target.csv - melatonin
#   Rtings Target.csv - nymz
#   Rtings Target.csv - pw
#   Rtings Target.csv - recode
#   Rtings Target.csv - rg
#   Rtings Target.csv - shortbus
#   Rtings Target.csv - suporsalad
#   Rtings Target.csv - tgx78
#   Rtings Target.csv - vortexreviews
#   Rtings Target.csv - vsg
#   Rtings Target.csv - wdym
#   Rtings Target.csv - akros
#
# seeaudio yume midnight l:
#   SeeAudio Yume Midnight L.csv - achoreviews
#   SEEAUDIO YUME R.csv - aftersound
#   SeeAudio Yume Midnight R.csv - jacstone
#   SeeAudio Yume Midnight (S2) R.csv - data_mrs
#   SeeAudio Yume L.csv - bedrock
#   SeeAudio Midnight R.csv - bryaudioreviews
#   SeeAudio Yume 2 R.csv - timmyv
#   SeeAudio X Crinacle Midnight R.csv - hbb
#   SEEAUDIO YUME 2 R.csv - ianfann
#   SeeAudio Neo L.csv - soundjedi
#   SeeAudio Yume 2 R.csv - harpo
#   SeeAudio Yume 2 R.csv - pw
#   SeeAudio Yume 2 R.csv - vortexreviews
#   Resolve Seeaudio Yume Midnight Gras L.csv - kurin
#   SeeAudio YumeMidnight L.csv - melatonin
#   SeeAudio Yume II R.csv - nymz
#   SeeAudio X Crinacle Yume Midnight R.csv - vsg
#
# seek real airship l:
#   Seek Real Airship L.csv - achoreviews
#   SEEK REAL DAWN L.csv - ianfann
#   Seek Real Airship R.csv - vortexreviews
#   SEEK Real Airship R.csv - hbb
#
# sennheiser ie600 (stock foam) l:
#   Sennheiser IE600 L.csv - achoreviews
#   SENNHEISER IE900 L.csv - aftersound
#   Sennheiser IE600 L.csv - animagus
#   Sennheiser IE900 L.csv - soundjedi
#   Sennheiser IE200 L.csv - timmyv
#   Sennheiser IE600 R.csv - hobbytalk
#   Sennheiser IE600 R.csv - hbb
#   SENNHEISER IE800 L.csv - ianfann
#   Sennheiser IE900 L.csv - tgx78
#   Sennheiser CX80S L.csv - cammyfi
#   Sennheiser IE600 (Foam Eartips) R.csv - iemworld
#   Sennheiser IE600 S2 R.csv - nymz
#   Sennheiser HD600 L.csv - suporsalad
#   Sennheiser MTW2 L.csv - data_mrs
#
# simgot ea500 (black) l:
#   Simgot EA500 (red) L.csv - achoreviews
#   Simgot EA500 (Red) R.csv - timmyv
#   SIMGOT EA500 HARMAN L.csv - aftersound
#   Simgot EM1 L.csv - bedrock
#   Simgot EA500 R.csv - harpo
#   Simgot EA500 Red R.csv - hobbytalk
#   SIMGOT EA500 RED R.csv - nymz
#   Simgot EA500 Red Bandaid L.csv - pw
#   Simgot EA500 Red R.csv - vortexreviews
#   SIMGOT EA500 BLUE R.csv - ianfann
#
# sonarworks target:
#   Sonarworks Target.csv - achoreviews
#   Sonarworks Target.csv - aftersound
#   Sonarworks Target.csv - animagus
#   Sonarworks Target.csv - arn
#   Sonarworks Target.csv - bedrock
#   Sonarworks Target.csv - bryaudioreviews
#   Sonarworks Target.csv - cammyfi
#   Sonarworks Target.csv - soundjedi
#   Sonarworks Target.csv - eplv
#   Sonarworks Target.csv - timmyv
#   Sonarworks Target.csv - harpo
#   Sonarworks Target.csv - hbb
#   Sonarworks Target.csv - cqtek
#   Sonarworks Target.csv - hobbytalk
#   Sonarworks Target.csv - ianfann
#   Sonarworks Target.csv - iemworld
#   Sonarworks Target.csv - kr0mka
#   Sonarworks Target.csv - melatonin
#   Sonarworks Target.csv - nymz
#   Sonarworks Target.csv - pw
#   Sonarworks Target.csv - recode
#   Sonarworks Target.csv - rg
#   Sonarworks Target.csv - shortbus
#   Sonarworks Target.csv - suporsalad
#   Sonarworks Target.csv - tgx78
#   Sonarworks Target.csv - vortexreviews
#   Sonarworks Target.csv - vsg
#   Sonarworks Target.csv - wdym
#   Sonarworks Target.csv - akros
#
# sony mh755 l:
#   Sony MH755 L.csv - achoreviews
#   SONY MH755 R.csv - aftersound
#   Sony MH755 R.csv - bryaudioreviews
#   Sony MH755 R.csv - nymz
#   Sony MH755v2 L.csv - pw
#   Sony MH750 L.csv - rg
#   Sony MH755 clone L.csv - data_mrs
#   Sony MH755 R.csv - hbb
#   Sony MH755 R.csv - tgx78
#   Oratory Sony MH755 L.csv - kurin
#   mh755 R.csv - recode
#
# strauss and wagner em205 l:
#   Strauss and Wagner EM205 L.csv - achoreviews
#   Strauss em205 R.csv - bryaudioreviews
#
# super review target:
#   Super Review Target.csv - achoreviews
#   Super Review Target.csv - aftersound
#   Super Review Target.csv - animagus
#   Super Review Target.csv - arn
#   Super Review Target.csv - bedrock
#   Super Review Target.csv - bryaudioreviews
#   Super Review Target.csv - cammyfi
#   Super Review Target.csv - soundjedi
#   Super Review Target.csv - eplv
#   Super Review Target.csv - timmyv
#   Super Review Target.csv - harpo
#   Super Review Target.csv - cqtek
#   Super Review Target.csv - hobbytalk
#   Super Review Target.csv - ianfann
#   Super Review Target.csv - iemworld
#   Super Review Target.csv - kr0mka
#   Super Review Target.csv - melatonin
#   Super Review Target.csv - nymz
#   Super Review Target.csv - pw
#   Super Review Target.csv - recode
#   Super Review Target.csv - shortbus
#   Super Review Target.csv - suporsalad
#   Super Review Target.csv - tgx78
#   Super Review Target.csv - vortexreviews
#   Super Review Target.csv - vsg
#   Super Review Target.csv - wdym
#   Super Review Target.csv - akros
#   Super 21 Target.csv - data_mrs
#   Super 22 Target.csv - kurin
#   Super Review 2022 Target.csv - rg
#
# symphonium helios l:
#   Symphonium Helios L.csv - achoreviews
#   SYMPHONIUM HELIOS SPINFIT R.csv - aftersound
#   Symphonium Helios R.csv - soundjedi
#   Symphonium Helios R.csv - timmyv
#   Symphonium Helios R.csv - nymz
#   Symphonium Helios R.csv - tgx78
#   Symphonium Helios shallow fit R.csv - vsg
#   Symphonium Helios R.csv - data_mrs
#   Simphoniom Helious R.csv - hbb
#   Symphonium Audio Helios_r L.csv - cqtek
#   Resolve Symphonium Helios Gras L.csv - kurin
#   helios symp L.csv - recode
#
# t force yuan li l:
#   T Force Yuan Li L.csv - achoreviews
#   T-FORCE YUAN LI R.csv - aftersound
#   TForce Yuan Li L.csv - bryaudioreviews
#   TForce Yuan Li L.csv - harpo
#   TZ Yuan Li L.csv - timmyv
#   T Force Yuan Li Final R.csv - hbb
#
# tanchjim ola l:
#   Tanchjim Zero L.csv - achoreviews
#   Tanchjim Zero L.csv - arn
#   Tanchjim Ola R.csv - bedrock
#   Tanchjim Hana21 L.csv - bryaudioreviews
#   Tanchjim Ola Bass R.csv - timmyv
#   TANCHJIM OLA R.csv - ianfann
#   TANCHJIM Oxygen (NO TIP on Coupler) L.csv - iemworld
#   Tanchjim Tanyav2 L.csv - pw
#   Tanchjim Ola R.csv - suporsalad
#   Tanchjim Prism L.csv - data_mrs
#   TANCHJIM OXYGEN L.csv - aftersound
#   Tanchjim Ola Bass R.csv - cammyfi
#   Tanchjim ZERO L.csv - eplv
#   Vento Conductor T-500 Pro (High-Density Tuning Foams + Tanchjim Tanya Filter) L.csv - rg
#   Tanchjim Hana L.csv - tgx78
#   Tanchjim Tanya L.csv - akros
#   Tanchjim ZERO L.csv - jacstone
#   Tanchjim Hana 2021 L.csv - animagus
#   Tanchjim Ola R.csv - harpo
#   Tanchjim OLA R.csv - hbb
#   Tanchjim Ola R.csv - vortexreviews
#   Tanchjim Zero DSP L.csv - hobbytalk
#   Tanchjim Cora L.csv - cqtek
#   Ola L.csv - kr0mka
#   Tanchjim New HANA 2021 Treble L.csv - vsg
#
# tangzu shimin li l:
#   Tangzu Shimin Li L.csv - achoreviews
#   TANGZU SHIMIN LI R.csv - aftersound
#   TANGZU Shimin Li L.csv - arn
#   TangZu Shimin Li R.csv - jacstone
#   Tangzu Shimin Li R.csv - vortexreviews
#   TANGZU Shimin Li Encounter L.csv - hobbytalk
#   TANGZU ShiminLi R.csv - eplv
#   TANGZU SHIMINLI R.csv - ianfann
#   Tangzu ShiminLi L.csv - pw
#   TZ Shimin Li R.csv - timmyv
#   Tangzu R R.csv - hbb
#   TangZu Audio Shimin Li R.csv - vsg
#
# tangzu wan er sg l:
#   Tangzu Wan Er SG L.csv - achoreviews
#   TANGZU WAN ER R.csv - aftersound
#   Tangzu Wan Er R.csv - hbb
#   TANGZU WAN-ER S.G L.csv - arn
#   TANGZU WAN'ER (wide bore silicone tips) R.csv - iemworld
#   Tangzu Waner SG R.csv - nymz
#   Tangzu Waner SG R.csv - suporsalad
#   Tangzu Wan'er R.csv - vortexreviews
#
# thieaudio legacy 2 l:
#   Thieaudio Legacy 2 L.csv - achoreviews
#   Thieaudio Legacy 2 R.csv - bedrock
#   ThieAudio Legacy 2 R.csv - vsg
#   ThieAudio Legacy 5 (S2) R.csv - data_mrs
#   THIEAUDIO LEGACY 5 R.csv - aftersound
#   ThieAudio V16 L.csv - soundjedi
#   ThieAudio V16 L.csv - vortexreviews
#   Thieaudio Oracle 2 L.csv - timmyv
#   Thieaudio L2 L.csv - pw
#
# tin c3 l:
#   Tin C3 L.csv - achoreviews
#   TinHiFi C3 L.csv - bedrock
#   TinHifi C3 L.csv - timmyv
#   TinHiFi C3 L.csv - cqtek
#   TinHiFi C3 L.csv - hobbytalk
#   TINHIFI C3 L.csv - ianfann
#   Tinhifi C3 L.csv - pw
#   Tin Hifi C3 R.csv - bryaudioreviews
#   Tin Hifi C3 L.csv - vortexreviews
#   Tin Hifi C3 R.csv - data_mrs
#
# tin t1 plus l:
#   Tin T4 Plus L.csv - achoreviews
#   Tin T2 Plus R.csv - timmyv
#   Tin T3 Plus R.csv - bryaudioreviews
#   TIN T3PLUS L.csv - aftersound
#   TINHiFi P1 Plus L.csv - arn
#   TinHiFi T4 Plus L.csv - bedrock
#   TinHiFi T3 Plus L.csv - jacstone
#   Tinhifi T4 Plus L.csv - pw
#   Tin HiFi T2 Plus L.csv - cqtek
#   TinHiFi T4 Plus L.csv - hobbytalk
#   Tin Hifi T1 Plus R.csv - vortexreviews
#   Tin Hifi T2 Plus (Sedna Light) L.csv - data_mrs
#   Oratory Tin HiFi T2 Plus L.csv - kurin
#   Tin Hifi T4 Plus L.csv - nymz
#   Tin Hifi T3 Plus L.csv - rg
#
# tin t1s l:
#   Tin T2 L.csv - achoreviews
#   TIN T5 L.csv - aftersound
#   Tin P1 L.csv - timmyv
#   TINHiFi T1S L.csv - arn
#   TinHiFi T1S L.csv - bedrock
#   TINHIFI T1S L.csv - ianfann
#   Tinhifi T1S L.csv - pw
#   Tin Hifi T1S R.csv - nymz
#   Tin Hifi T1S L.csv - vortexreviews
#
# tin t2 dlc l:
#   Tin T2 DLC L.csv - achoreviews
#   TIN T2 EVO L.csv - aftersound
#   TINHiFi T2 DLC L.csv - arn
#   TinHiFi T2 DLC L.csv - bedrock
#   TinHifi T2 DLC L.csv - timmyv
#   TinHiFi T2 DLC L.csv - cqtek
#   TinHiFi T2 DLC L.csv - hobbytalk
#   TINHIFI T2 DLC L.csv - ianfann
#   Tinhifi T2 DLC MP L.csv - pw
#   Tin T2+ R.csv - harpo
#   Oratory Tin HiFi T2 L.csv - kurin
#   Tin Hifi T2 DLC R.csv - nymz
#   Tin Hifi T2 DLC R.csv - vortexreviews
#   Tin Hifi T2 Pro L.csv - data_mrs
#
# tin t3 buds l:
#   Tin T3 Buds L.csv - achoreviews
#   TIN BUDS 3 R.csv - aftersound
#   TINHiFi Buds 3 L.csv - arn
#   Tin Hifi Tin Buds 3 L.csv - vortexreviews
#   Tin Hifi Tin Buds 3 L.csv - data_mrs
#
# tipsy ttromso pine stone sea l:
#   Tipsy TTROMSO Pine Stone Sea L.csv - achoreviews
#   Tipsy TTROMSO L.csv - arn
#
# tkzk ouranos l:
#   TKZK Ouranos L.csv - achoreviews
#   TKZK Ouranos2 R.csv - timmyv
#   TKZK Ouranos R.csv - cqtek
#   TKZK OURANOS R.csv - ianfann
#   TKZK Ouranos R.csv - pw
#
# tri i one l:
#   Tri i One L.csv - achoreviews
#   TRI i ONE R.csv - cqtek
#   TRI iOne MP L.csv - pw
#
# tri meteor l:
#   Tri Meteor L.csv - achoreviews
#   TRI METEOR R.csv - aftersound
#   TRI Meteor R.csv - animagus
#   Tri Meteor R.csv - bryaudioreviews
#   TRI Meteor L.csv - harpo
#   Tri Meteor R.csv - cqtek
#   TRI METEOR R.csv - ianfann
#   TRI Meteor R.csv - iemworld
#   TRI Meteor L.csv - pw
#   Symphonium Meteor Sample L.csv - soundjedi
#   Symphonium Meteor L.csv - hobbytalk
#   Symphonium Meteor (inverted) L.csv - data_mrs
#   Resolve Symphonium Meteor Gras L.csv - kurin
#   TRI Ｍeteor R.csv - melatonin
#   Symphonium Meteor S2 L.csv - nymz
#   Symphonium Audio Meteor L.csv - vortexreviews
#
# tri x hbb kai l:
#   Tri x HBB KAI L.csv - achoreviews
#   TRI x HBB KAI L.csv - arn
#   TRI x HBB Kai R.csv - harpo
#   TRI X HBB KAI R.csv - vortexreviews
#   Tri Kai R.csv - cammyfi
#   TRI Kai R.csv - timmyv
#   TRI KAI R.csv - hobbytalk
#   TRI KAI R.csv - ianfann
#   TRI KAI R.csv - pw
#   TRI X HBB Kai 2 R.csv - hbb
#   TRI KAI x HBB R.csv - cqtek
#   Tri HBB Kai S2 R.csv - nymz
#
# tripowin cencibel l:
#   Tripowin Lea L.csv - achoreviews
#   TRIPOWIN CENCIBEL R.csv - ianfann
#   Tripowin Cencibel R.csv - nymz
#   Tripowin Cencibel R.csv - data_mrs
#   Tripowin TC01 L.csv - timmyv
#   Tripowin Cencibel R.csv - harpo
#   Tripowin Mele L.csv - jacstone
#   TRIPOWIN Lea L.csv - melatonin
#   Tripowin Lea L.csv - suporsalad
#   Tripowin Lea L.csv - vsg
#   Tripowin Leá L.csv - arn
#   TRIPOWIN Leá L.csv - eplv
#   Tripowin TC01 L.csv - vortexreviews
#   Tripowin Xs L R.csv - hbb
#
# tripowin rhombus l:
#   Tripowin Rhombus L.csv - achoreviews
#   TRIPOWIN RHOMBUS R.csv - ianfann
#   Tripowin Rhombus R.csv - nymz
#   Tripowin Rhombus R.csv - data_mrs
#
# trn mt1 l:
#   TRN TA1 Max L.csv - achoreviews
#   TRN MT3 L.csv - aftersound
#   TRN TA L.csv - bryaudioreviews
#   TRN MT1 R.csv - jacstone
#   TRN MT1 R.csv - melatonin
#   TRN ST1 L.csv - pw
#   TRN MT3 L.csv - vortexreviews
#   TRN M10 L.csv - eplv
#   TRN MT4 L.csv - ianfann
#   TRN MT3 L.csv - iemworld
#   TRN MT1 R.csv - hbb
#   TRN MT1 Pro L.csv - arn
#   TRN IM1 L.csv - data_mrs
#
# trn st5 l:
#   TRN ST5 L.csv - achoreviews
#   TRN ST5 L.csv - arn
#   TRN ST5 R.csv - harpo
#   TRN ST5 R.csv - ianfann
#   TRN ST5 R.csv - nymz
#   TRN ST2 L.csv - pw
#   TRN ST5 R.csv - vortexreviews
#   TRN STM L.csv - bryaudioreviews
#   TRN ST5 R.csv - hbb
#   TRN ST2 L.csv - iemworld
#
# trn xuanwu l:
#   TRN Xuanwu L.csv - achoreviews
#   TRN Xuanwu R.csv - arn
#   TRN XUANWU R.csv - ianfann
#   TRN Xuanwu R.csv - pw
#   TRN Xuanwu R.csv - vortexreviews
#   TRN Xuanwu R.csv - hbb
#
# unique melody mest mk2 l:
#   Unique Melody Mest Mk2 L.csv - achoreviews
#   UNIQUE MELODY MEST R.csv - aftersound
#   Unique Melody MEST mkII R.csv - data_mrs
#   Unique Melody MEST MKII R.csv - soundjedi
#   Unique Melody MEXT R.csv - hbb
#   UNIQUE MELODY MEXT L.csv - ianfann
#   UM MEST L.csv - pw
#
# urbanfun ybf-iss014 (s1) l:
#   Urbanfun YBF-ISS014 (S2) L.csv - achoreviews
#   Urbanfun Ybf R.csv - hbb
#   Urbanfun ISS014 L.csv - rg
#
# venture electronics grand duke l:
#   Venture Electronics Grand Duke L.csv - achoreviews
#
# z_isolation comparison free field l:
#   z_Isolation Comparison Free Field L.csv - achoreviews
#
# 4acoustic harmonie r:
#   4ACOUSTIC HARMONIE R.csv - aftersound
#
# 4acoustic symphonie 1 on r:
#   4ACOUSTIC SYMPHONIE ALL ON R.csv - aftersound
#
# 4acoustic unison l:
#   4ACOUSTIC UNISON R.csv - aftersound
#   unison R.csv - recode
#
# 64 audio tia trio l:
#   64 AUDIO U18S L.csv - aftersound
#   64 Audio Tia Trio L.csv - harpo
#   64 Audio Tia Trio R.csv - hbb
#   64 Audio U6t L.csv - soundjedi
#   64 Audio U12T L.csv - timmyv
#   64Audio Trio V2 L.csv - nymz
#   64Audio Trio L.csv - pw
#   trio R.csv - recode
#   64 Audio Duo L.csv - vsg
#   64 Audio Trio L.csv - data_mrs
#
# 64 audio u12t m15 l:
#   64 AUDIO U12T NON APEX R.csv - aftersound
#   64 Audio U4s M15 R.csv - vsg
#   64 Audio U12t Sample 3 (M20) R.csv - animagus
#   64 Audio U12t R.csv - soundjedi
#   64 Audio U12T R.csv - timmyv
#   64 Audio U6t m15 (Silicon Tips) L.csv - iemworld
#   Oratory 64 Audio A12t (m15 Apex module) L.csv - kurin
#   64 Audio U12T MX20 R.csv - nymz
#   64audio U12T L.csv - tgx78
#   64 Audio U6t (m15) R.csv - data_mrs
#
# 64 audio u18s r:
#   64 AUDIO U18S R.csv - aftersound
#   64 Audio U6t R.csv - soundjedi
#   64 Audio Tia Fourte R.csv - hbb
#   64 Audio U4s MX R.csv - vsg
#   64 Audio U4s (S1 - mX) R.csv - data_mrs
#   64 Audio U6t xx (Silicon Tips) R.csv - iemworld
#   u18s R.csv - recode
#   64audio U12T R.csv - tgx78
#
# 7th acoustics proxima l:
#   7TH ACOUSTICS SUPERNOVA L.csv - aftersound
#   7th Acoustics Supernova L.csv - data_mrs
#   7TH ACOUSTICS SUPERNOVA L.csv - recode
#   7th Proxima R.csv - timmyv
#
# 7th acoustics stargazer 3 l:
#   7TH ACOUSTICS STARGAZER 3 R.csv - aftersound
#
# 7th acoustics supernova r:
#   7TH ACOUSTICS SUPERNOVA R.csv - aftersound
#   supernova w1 R.csv - recode
#   7th Acoustics Supernova (S2) R.csv - data_mrs
#   7th Supernova R.csv - timmyv
#
# acoustune hs2000mx mkii l:
#   ACOUSTUNE RS1 L.csv - aftersound
#   hs2000mx R.csv - recode
#
# acoustune rs1 r:
#   ACOUSTUNE RS1 R.csv - aftersound
#   Acoustune RS One R.csv - bryaudioreviews
#   Acoustune RS ONE R.csv - hbb
#   Acoustune HS1670SS R.csv - melatonin
#
# aful performer 5 l:
#   AFUL PERFORMER 5 R.csv - aftersound
#   AFUL PERFORMER 5 R.csv - ianfann
#   AFUL Performer 5 R.csv - jacstone
#   AFUL Performer5 R.csv - nymz
#   Aful Performer5 R.csv - vortexreviews
#   AFUL Acoustics Performer 5 R.csv - vsg
#
# anker life dot 3i r:
#   ANKER LIFE NOTE 3i R.csv - aftersound
#
# astell n kern ak zero1 l:
#   ASTELL N KERN UW100 L.csv - aftersound
#   AK ZERO1 R.csv - vsg
#
# astell n kern uw100 r:
#   ASTELL N KERN UW100 R.csv - aftersound
#
# astrotec vesna l:
#   ASTROTEC VESNA R.csv - aftersound
#   Astrotec Vesna R.csv - pw
#
# audio hekili l:
#   AUDIO HEKILI R.csv - aftersound
#   Audio Hekili R.csv - pw
#   Audio Hekili R.csv - vsg
#   Audio Hekili R.csv - data_mrs
#   Hekili L.csv - shortbus
#
# audiosense aq0 l:
#   AUDIOSENSE DT600 L.csv - aftersound
#   Audiosense DT200 L.csv - bryaudioreviews
#   Audiosense T800 L.csv - rg
#   Audiosense DT600 80 L.csv - tgx78
#   Audiosense T180 L.csv - data_mrs
#   AUDIOSENSE DT300 L.csv - ianfann
#   AudioSense T8009 L.csv - eplv
#   AUDIOSENSE DT600 ohm L.csv - harpo
#   Audiosense T100 L.csv - pw
#
# audiosense dt200 r:
#   AUDIOSENSE DT600 R.csv - aftersound
#   Audiosense DT200 R.csv - bryaudioreviews
#   Audiosense DT600 20.csv - tgx78
#   AUDIOSENSE DT600 ohm R.csv - harpo
#   AUDIOSENSE DT300 R.csv - ianfann
#   AudioSense T8009 R.csv - eplv
#   Audiosense DT600 (stock) R.csv - rg
#   DT200 R.csv - kr0mka
#
# avara av3 l:
#   AVARA AV3 R.csv - aftersound
#
# azla azel l:
#   AZLA AZEL R.csv - aftersound
#   AZLA AZEL R.csv - eplv
#   AZLA Azel L.csv - rg
#
# bamboo forest bird zhu skylark l:
#   BAMBOO FOREST BIRD ZHU SKYLARK R.csv - aftersound
#   Bamboo Forest Bird Jinghong L.csv - rg
#
# beemix pisces l:
#   BEEMIX PISCES R.csv - aftersound
#
# bgvp dh5 l:
#   BGVP DN3 L.csv - aftersound
#   BGVP DN3 L.csv - bryaudioreviews
#   BGVP DM6 L.csv - pw
#   BGVP DM8 L.csv - data_mrs
#
# bgvp dn2 r:
#   BGVP DN3 R.csv - aftersound
#   BGVP DN3 R.csv - bryaudioreviews
#   BGVP DM8 R.csv - animagus
#   BGVP DM7 R.csv - hbb
# ...
#
# lz z04a l:
#   LZ Z05A L.csv - rg
#
# peacock audio p1 l:
#   Peacock Audio P1 L.csv - rg
#
# periodic audio beryllium l:
#   Periodic Audio Beryllium L.csv - rg
#
# resolution target:
#   Resolution Target.csv - rg
#
# sennheiser cx 400bt tws l:
#   Sennheiser CX 400BT TWS L.csv - rg
#
# sony mdr-ex800st (blutack) l:
#   Sony MDR-EX800ST L.csv - rg
#
# sony wf-1000xm3 l:
#   Sony WF-1000XM3 L.csv - rg
#   Sony WF-1000XM4 L.csv - data_mrs
#
# stakk target:
#   stakk Target.csv - rg
#
# talbot target:
#   Talbot Target.csv - rg
#
# tingker tk200 l:
#   Tingker TK200 L.csv - rg
#
# tksilver target:
#   TKSilver Target.csv - rg
#
# 07m l:
#   07m L.csv - shortbus
#
# 07m_retune l:
#   07m_retune L.csv - shortbus
#
# blon_03_busmod l:
#   Blon_03_busmod L.csv - shortbus
#
# burson_pm2_loopback l:
#   burson_pm2_loopback L.csv - shortbus
#
# dm2_dm1 l:
#   DM2_eqmdm1 L.csv - shortbus
#
# dm2_olina l:
#   DM2_olina L.csv - shortbus
#
# ej07_custom l:
#   EJ07_custom1 L.csv - shortbus
#
# ej_sb l:
#   EJ_SB L.csv - shortbus
#
# er4xr l:
#   ER4XR L.csv - shortbus
#
# hekili_foamdeep l:
#   Hekili_foamdeep L.csv - shortbus
#
# iem_2 l:
#   iem_2 L.csv - shortbus
#
# motu_calibrated_loopback l:
#   motu_calibrated_loopback L.csv - shortbus
#
# not 02 l:
#   Not 02 L.csv - shortbus
#
# not_dm l:
#   not_dm L.csv - shortbus
#
# not_tanya l:
#   not_tanya L.csv - shortbus
#
# ola_olina_200 r:
#   Ola_olina_200 R.csv - shortbus
#
# olina magician l:
#   Olina Magician L.csv - shortbus
#
# olina_tanya l:
#   Olina_Tanya L.csv - shortbus
#
# oriolus_isabellae l:
#   Oriolus_isabellae L.csv - shortbus
#
# s12_sb l:
#   S12_SB3 L.csv - shortbus
#
# softears_rsv l:
#   Softears_rsv L.csv - shortbus
#
# toneking_bl1 l:
#   toneking_bl1 L.csv - shortbus
#
# unknown_soldier l:
#   Unknown_Soldier_Bucky L.csv - shortbus
#
# variations_sb l:
#   Variations_sb8 L.csv - shortbus
#
# xduoo_ta20_loopback l:
#   xduoo_ta20_loopback L.csv - shortbus
#
# yanyin_m l:
#   Yanyin_M L.csv - shortbus
#
# air canada earphones r:
#   Air Canada Earphones R.csv - suporsalad
#
# cal se l:
#   CAL SE L.csv - suporsalad
#
# df tilt 711 ref target:
#   DF Tilt 711 Ref.csv - suporsalad
#
# electra earbuds l:
#   Electra Earbuds L.csv - suporsalad
#
# head corded earbuds l:
#   HEAD Corded Earbuds L.csv - suporsalad
#
# ie200 less bass l:
#   IE200 Less Bass S2 R.csv - suporsalad
#
# ie200 spinfit cp100 plus tips l:
#   IE200 Spinfit CP100 Plus Tips L.csv - suporsalad
#
# ihip anzu l:
#   iHip Anzu L.csv - suporsalad
#
# kemar df 1.3 bass target:
#   Kemar DF Target.csv - suporsalad
#
# koss kph40 l:
#   Koss KPH40 L.csv - suporsalad
#
# kz edabass l:
#   KZ EDABass R.csv - suporsalad
#
# listener target:
#   Listener Target.csv - suporsalad
#
# raycon e25 l:
#   Raycon E25 R.csv - suporsalad
#
# rode nth100 l:
#   Rode NTH100 L.csv - suporsalad
#
# sony mdrex15 l:
#   Sony MDREX15 R.csv - suporsalad
#
# usound1v1 oratory 1990 target:
#   USound1V1 Oratory 1990 Target.csv - suporsalad
#
# 32bg r:
#   32BG R.csv - tgx78
#
# a2 l:
#   A2 L.csv - tgx78
#
# akg n200 r:
#   AKG N200 R.csv - tgx78
#
# aroma thunder focus mode r:
#   Aroma Thunder Harmony mode.csv - tgx78
#
# asura l:
#   Asura R.csv - tgx78
#
# blur mx64 r:
#   Blur MX64 R.csv - tgx78
#
# ciem anni l2:
#   CIEM Anni L3.csv - tgx78
#
# ee odin 2 l:
#   EE Odin R.csv - tgx78
#
# elysian ann:
#   Elysian Ann.csv - tgx78
#
# ep05 r:
#   Ep05 R.csv - tgx78
#
# fiio fd7 modded l:
#   Fiio FD7 Modded L.csv - tgx78
#
# fir kr5 gold r:
#   KR5 R.csv - tgx78
#
# fir ne4 r:
#   NE4 R.csv - tgx78
#
# haylou gt1plus r:
#   Haylou GT1plus R.csv - tgx78
#   Haylou GT2 R.csv - data_mrs
#
# hookx l:
#   Hookx R.csv - tgx78
#
# imr astra r:
#   IMR Astra R.csv - tgx78
#
# jcally jc10 r:
#   Jcally JC10 R.csv - tgx78
#
# jvc fw10000 l:
#   JVC FW10000 L.csv - tgx78
#
# ksearphone lbbs l:
#   Ksearphone Lbbs L.csv - tgx78
#
# lbbs2 r:
#   Lbbs2 R.csv - tgx78
#
# miku buds l:
#   Miku Buds L.csv - tgx78
#
# monk r:
#   Monk R.csv - tgx78
#
# ne4 l:
#   NE4 L.csv - tgx78
#
# newbsound 32pro r:
#   Newbsound 32Pro R.csv - tgx78
#
# odin fix l:
#   Odin Fix R.csv - tgx78
#
# oriolus reborn l:
#   Oriolus Reborn R.csv - tgx78
#
# penon impact l:
#   Penon Impact R.csv - tgx78
#
# penon volt r:
#   Penon Volt R.csv - tgx78
#
# penon vortex eq r:
#   Penon Vortex L.csv - tgx78
#
# qian39 r:
#   QianYun Qian39 R.csv - tgx78
#
# ripples r:
#   Ripples R.csv - tgx78
#
# serratus l:
#   Serratus Pro R.csv - tgx78
#
# sun copper r:
#   VE Sun Copper R.csv - tgx78
#
# tantalus l:
#   Tgx78 Tantalus R.csv - tgx78
#
# tantan r:
#   Tantan R.csv - tgx78
#
# tgx78 150bg l:
#   Tgx78 B1 L.csv - tgx78
#
# tgx78 b1 r:
#   Tgx78 Tofino R.csv - tgx78
#
# tgx78 tofino l:
#   Tgx78 Tofino L.csv - tgx78
#
# tgxear red dot ti r:
#   Tgxear Red Dot Ti R.csv - tgx78
#
# tgxear tiolake red r (1):
#   Tiolake Sr2 R.csv - tgx78
#
# tiolake sr2 l:
#   Tiolake Sr2 L.csv - tgx78
#
# tofino mmcx l:
#   Tofino Mmcx L.csv - tgx78
#
# tofino pro r:
#   Tofino Pro R.csv - tgx78
#
# totem p3 r:
#   Totem R.csv - tgx78
#
# um mentor l:
#   UM Mentor R.csv - tgx78
#
# ve aws l:
#   VE AWS L.csv - tgx78
#
# ve ext l:
#   VE EXT R.csv - tgx78
#
# ve phonix2 l:
#   VE Phonix2 R.csv - tgx78
#
# xe6 r:
#   XE6 R.csv - tgx78
#
# yincrow rw9 l:
#   Yincrow RW9 R.csv - tgx78
#
# basn mmcx l:
#   BASN MMCX R.csv - vortexreviews
#
# bqeyz kc2 l:
#   BQEYZ KC2 R.csv - vortexreviews
#
# edl mini piano l:
#   EDL Mini Piano L.csv - vortexreviews
#
# geek wold gk10 no tape r:
#   Geek Wold GK10 No Tape R.csv - vortexreviews
#
# gravastar sirius l:
#   Gravastar Sirius L.csv - vortexreviews
#
# hakii action r:
#   HAKII Action R.csv - vortexreviews
#
# openheart ie800 l:
#   Openheart IE800 L.csv - vortexreviews
#
# supereq q2 pro r:
#   SuperEQ Q2 Pro R.csv - vortexreviews
#
# thor mjölnir mkii l:
#   THOR Mjölnir MKII R.csv - vortexreviews
#
# tin hifi c2 r:
#   Tin Hifi C2 R.csv - vortexreviews
#   Tin Hifi Tin Buds 3 R.csv - data_mrs
#
# tozo golden x1 l:
#   Tozo Golden X1 R.csv - vortexreviews
#
# 1more colorbuds 2 l:
#   1MORE ColorBuds 2 R.csv - vsg
#
# 1more evo l:
#   1MORE EVO R.csv - vsg
#
# ak pathfinder l:
#   AK PATHFINDER R.csv - vsg
#   Campfire Audio Pathfinder R.csv - data_mrs
#
# allway oe10 l:
#   Allway OE10 L.csv - vsg
#
# antlion kimura duo l:
#   Antlion Kimura Solo R.csv - vsg
#
# audeze crbn l:
#   Audeze CRBN R.csv - vsg
#
# audeze lcd-2 classic l:
#   Audeze LCD-5 R.csv - vsg
#
# audeze lcd-5 old headband l:
#   Audeze LCD-5 Old Headband R.csv - vsg
#
# audeze lcd-x (2021) l:
#   Audeze LCD-XC (2021) R.csv - vsg
#
# audio-technica ath-anc300tw l:
#   Audio-Technica ATH-ANC900BT R.csv - vsg
#
# bang & olufsen beoplay h95 anc l:
#   Bang & Olufsen Beoplay H95 R.csv - vsg
#
# cambridge audio melomania 1+ l:
#   Cambridge Audio Melomania 1+ R.csv - vsg
#
# campfire audio holocene l:
#   Campfire Audio Satsuma L.csv - vsg
#
# campfire audio orbit s2 l:
#   Campfire Audio Trifecta L.csv - vsg
#
# campfire audio trifecta r:
#   Campfire Audio Trifecta R.csv - vsg
#
# cleer flow ii ambient l:
#   Cleer Flow II ANC R.csv - vsg
#
# cleer roam nc l:
#   Cleer Roam NC R.csv - vsg
#
# custom art fibae 7u ciem r:
#   Custom Art Fibae 7U CIEM R.csv - vsg
#   Custom Art Fibae 7 Unlimited R.csv - data_mrs
#
# drop + dan clark audio aeon closed x 1-notch white filter l:
#   Drop + Dan Clark Audio Aeon Closed X L.csv - vsg
#
# dunu titan s pre-production l:
#   DUNU TITAN S pre-production R.csv - vsg
#
# edifier stax spirit s3 lambskin bt l:
#   Edifier STAX SPIRIT S3 Mesh wired L.csv - vsg
#
# edifier stax spirit s3 mesh wired r:
#   Edifier STAX SPIRIT S3 Mesh wired R.csv - vsg
#
# edifier wh950nb bluetooth l:
#   Edifier WH950NB wired L.csv - vsg
#
# edifier wh950nb wired r:
#   Edifier WH950NB wired R.csv - vsg
#
# fiio fa7s l:
#   FiiO FA7s L.csv - vsg
#   Fiio FH7S L.csv - data_mrs
#
# fiio ft3 pleather l:
#   FiiO FT3 pleather L.csv - vsg
#
# fiio ft3 suede l:
#   FiiO FT3 suede L.csv - vsg
#
# final ux3000 bluetooth anc l:
#   final UX3000 Wired L.csv - vsg
#
# final ux3000 wired r:
#   final UX3000 Wired R.csv - vsg
#
# final ze8000 1.8.0 l:
#   final ZE8000 1.8.1 L.csv - vsg
#
# focal bathys l:
#   Focal Bathys R.csv - vsg
#
# focal utopia 2022 l:
#   Focal Utopia 2022 R.csv - vsg
#
# goldplanar gl12 filter l:
#   GoldPlanar GL12 L.csv - vsg
#
# harmonicdyne g200 flannel r:
#   HarmonicDyne G200 Yaxi Leather R.csv - vsg
#
# harmonicdyne poseidon r:
#   HarmonicDyne Poseidon R.csv - vsg
#
# hear+hi acuity duo l:
#   Hear+Hi Acuity Duo R.csv - vsg
#
# hiby lasya l:
#   HiBy Lasya R.csv - vsg
#
# hifiman he-r10d bluemini l:
#   HIFIMAN HE-R9 R.csv - vsg
#
# hifiman he-r10p r:
#   HIFIMAN HE-R10P R.csv - vsg
#
# hifiman re2000 pro gold r:
#   HIFIMAN RE2000 Pro Gold R.csv - vsg
#
# hifiman shangri-la jr l:
#   HIFIMAN Shangri-La Sr R.csv - vsg
#
# ibasso sr3 l:
#   iBasso SR3 spare pads R.csv - vsg
#   iBasso IT01X (S2) L.csv - data_mrs
#
# ikko oh1s sample 2 l:
#   Ikko OH1s Sample 2 L.csv - vsg
#
# jq 4upro r:
#   JQ 4Upro R.csv - vsg
#
# kinera yh802 anc l:
#   Kinera YH802 Transparency L.csv - vsg
#
# lime ears pneuma switch r:
#   Lime Ears Pneuma Switch R.csv - vsg
#
# lypertek pureplay z5 r:
#   Lypertek PurePlay Z7 R.csv - vsg
#
# mackie mp-320 r:
#   Mackie MP-460 R.csv - vsg
#
# meze 99 neo dekoni l:
#   Meze 99 Neo R.csv - vsg
#
# meze liric l:
#   Meze Liric R.csv - vsg
#
# monoprice m1070c lambskin l:
#   Monoprice M1070C Velour L.csv - vsg
#
# monoprice m1070c velour r:
#   Monoprice M1070C Velour R.csv - vsg
#
# monoprice monolith m-twe l:
#   Monoprice Monolith M-TWE R.csv - vsg
#
# nectar hivex (no sponge insert) l:
#   Nectar HiveX (Sponge Insert) R.csv - vsg
#
# noble audio viking ragnar l:
#   Noble Audio Viking Ragnar R.csv - vsg
#
# ovidius rx-100 l:
#   Ovidius TX-901 L.csv - vsg
#
# ovidius tx-901 r:
#   Ovidius TX-901 R.csv - vsg
#
# padmate pamu z1 l:
#   Padmate PaMu Z1 R.csv - vsg
#
# peacock flight l:
#   Peacock Flight R.csv - vsg
#
# philips fidelio x2hr l:
#   Philips Fidelio X3 R.csv - vsg
#
# sennheiser hd 598 l:
#   Sennheiser x Drop HD 6XX L.csv - vsg
#
# sivga oriole l:
#   Sivga Oriole L.csv - vsg
#
# sivga phoenix l:
#   Sivga Phoenix L.csv - vsg
#
# sivga robin (sv021) l:
#   Sivga Robin (SV021) L.csv - vsg
#
# sivga sv023 l:
#   Sivga SV023 L.csv - vsg
#
# technics az70 l:
#   Technics AZ70 L.csv - vsg
#
# thieaudio wraith pad a l:
#   ThieAudio Wraith Pad B L.csv - vsg
#
# tripowin tc-01 r:
#   Tripowin TC-01 R.csv - vsg
#
# ua complimentary 1 l:
#   UA Complimentary 2 R.csv - vsg
#
# ugreen hitune t3 l:
#   Ugreen HiTune T3 R.csv - vsg
#
# xenns up sample 2 l:
#   XENNS UP Sample 2 R.csv - vsg
#
# zephone tiger l:
#   Zephone Tiger R.csv - vsg
#
# 710 btnc (active, anc off) l:
#   710 Btnc (Active, ANC on) L.csv - wdym
#
# 710 btnc (passive) l:
#   710 Btnc (Passive) L.csv - wdym
#
# deva (wired) l:
#   Deva (Wired) L.csv - wdym
#
# elegia (stock pads) l:
#   Elex (Stock Pads) L.csv - wdym
#
# elex (dekoni elite fenestrated sheepskin pads) l:
#   Elex (Dekoni Elite Fenestrated Sheepskin Pads) L.csv - wdym
#
# elex (elear pads) l:
#   Elex (Elear Pads) L.csv - wdym
#
# elex (utopia pads) l:
#   Elex (Utopia Pads) L.csv - wdym
#
# sparks (basshead tuning) l:
#   Sparks (Stock Tuning) L.csv - wdym
#
# ola stock l:
#   Ola Stock L.csv - akros
#
# test l:
#   test L.csv - akros
#
# 64 audio nio (fir red) l:
#   64 Audio U4s (Fir red) L.csv - data_mrs
#
# 64 audio u4s (s1 - m12) l:
#   64 Audio U4s (S1 - mX) L.csv - data_mrs
#
# aful acoustics performer5 (15 ohm) l:
#   Aful Acoustics Performer5 R.csv - data_mrs
#
# akoustyx s-6 (s2) l:
#   Akoustyx S-6 (Tanchjim) R.csv - data_mrs
#
# bgvp dmg (silver) l:
#   BGVP NS9 (silver) L.csv - data_mrs
#
# bgvp ns9 (black tips + no mesh) l:
#   BGVP NS9 (red) L.csv - data_mrs
#
# campfire audio dorado 2020 l:
#   Campfire Audio Dorado 2020 R.csv - data_mrs
#
# cayin fantasy l:
#   Cayin Fantasy L.csv - data_mrs
#
# colorfly quintet l:
#   Colorfly Quintet R.csv - data_mrs
#
# dent target:
#   Dent Target.csv - data_mrs
#
# dentreviews target:
#   dentReviews Target.csv - data_mrs
#
# dunu falcon pro (experimental) r:
#   Dunu Falcon Pro (experimental) R.csv - data_mrs
#
# dunu vulka (s2 + red) l:
#   Dunu Vulka (S2 + red) L.csv - data_mrs
#
# dunu zen pro (pre) l:
#   Dunu Zen Pro (pre) L.csv - data_mrs
#
# empire ears bravado mkii l:
#   Empire Ears Valkyrie mkII L.csv - data_mrs
#
# etymotic er2se (sample 2) r:
#   Etymotic ER2SE (sample 2) R.csv - data_mrs
#
# etymotic ety kids l:
#   Etymotic ETY Kids L.csv - data_mrs
#
# etymotic evo (2f) l:
#   Etymotic Evo (2F) L.csv - data_mrs
#
# etyotic er2xr (s2) l:
#   Etyotic ER2XR (S2) L.csv - data_mrs
#
# fiio fd3 (bass tips) l:
#   Fiio FD3 (vocal tips) L.csv - data_mrs
#
# fiio fd3 (blk nozzle) l:
#   Fiio FD3 (blk nozzle) L.csv - data_mrs
#
# fiio fd7 (40 hrs) l:
#   Fiio FD7 (40 hrs) L.csv - data_mrs
#
# fiio fh3 (spring) l:
#   Fiio FH3 (Spring) L.csv - data_mrs
#
# fiio fhe (franken) l:
#   Fiio FHE (franken) L.csv - data_mrs
#
# final b3 (e-type) l:
#   Sony WF-1000XM4 (max - Final E-type) L.csv - data_mrs
#
# flc 8p (gold-black-gunmetal) l:
#   FLC 8P (gunmetal-gray-gunmetal) L.csv - data_mrs
#
# flc 8p (gold-white-transparent) l:
#   FLC 8P (gold-white-transparent) L.csv - data_mrs
#
# flc 8p (green-gray-gunmetal) l:
#   FLC 8P (silver-gray-gunmetal) L.csv - data_mrs
#
# flc dd31 l:
#   FLC DD31 L.csv - data_mrs
#
# haylou gt1 l:
#   Haylou GT2 L.csv - data_mrs
#
# hbb comp target:
#   IEC711 Comp Target.csv - data_mrs
#
# hiby crystal6 ii l:
#   Hiby Crystal6 L.csv - data_mrs
#
# hifiman bolt l:
#   Hifiman Bolt L.csv - data_mrs
#
# hpdc 10db tilt 5128 df 100hz target:
#   HPDC 14dB Tilt KEMAR DF 100Hz Target.csv - data_mrs
#
# hpdc 14db tilt kemar df target:
#   HPDC 14dB Tilt KEMAR DF Target.csv - data_mrs
#
# jh audio layla (max) l:
#   JH Audio Layla (min) R.csv - data_mrs
#
# jvc fx7 l:
#   JVC FX7 L.csv - data_mrs
#
# kz (avg) l:
#   KZ (avg) L.csv - data_mrs
#
# kz zex (vent blocked) l:
#   KZ ZEX (vent blocked) L.csv - data_mrs
#
# letshuoer singer l:
#   Letshuoer Singer L.csv - data_mrs
#
# lg hbs800 (anc off) l:
#   LG HBS800 R.csv - data_mrs
#
# magaosi k3 (f0) l:
#   Magaosi K5 L.csv - data_mrs
#
# magaosi k5 (15 ohm + iematch+ ultra) l:
#   Magaosi K5 (15 ohm) L.csv - data_mrs
#
# mee audio m6 pro 2g l:
#   MEE Audio M6 Pro 2G L.csv - data_mrs
#
# meizu live (black) l:
#   Meizu Live (white) L.csv - data_mrs
#
# mi true wireless earbuds basic 2 l:
#   Mi True Wireless Earbuds Basic 2 L.csv - data_mrs
#
# nothing ear 2 (balanced) l:
#   Nothing Ear 2 R.csv - data_mrs
#
# nothing ear 2 (more bass) l:
#   Nothing Ear 2 (more treble) R.csv - data_mrs
#
# nothing ear 2 (personalized b) l:
#   Nothing Ear 2 (personalized) R.csv - data_mrs
#
# nothing ear 2 (treble -6) r:
#   Nothing Ear 2 (voice) R.csv - data_mrs
#
# openaudio mercury l:
#   OpenAudio Mercury R.csv - data_mrs
#
# oriolus 2nd gen l:
#   Oriolus 2nd Gen L.csv - data_mrs
#
# phonak audeo pfe 112 l:
#   Phonak Audeo PFE 112 R.csv - data_mrs
#
# pre-prod 03 (nozzle a) l:
#   Pre-Prod 03 (nozzle B) R.csv - data_mrs
#
# qdc anole v14 (0000) l:
#   QDC Anole V14 (1000) L.csv - data_mrs
#
# qdc neptune l:
#   QDC Neptune L.csv - data_mrs
#
# qdc uranus l:
#   QDC Uranus L.csv - data_mrs
#
# radius hp-nef11 r:
#   Radius HP-NEF11 R.csv - data_mrs
#
# sennheiser ie 200 (azla max) l:
#   Sennheiser IE 900 L.csv - data_mrs
#
# sennheiser ie 300 (autoeq) l:
#   Sennheiser IE 900 (fake) L.csv - data_mrs
#
# sennheiser ie 600 (e-type shallow) l:
#   Sennheiser IE 600 (Spinfit) L.csv - data_mrs
#
# sennheiser ie 600 (spring tips) l:
#   Sennheiser IE 600 (Spring tips) L.csv - data_mrs
#
# sennheiser ie 900 (final) l:
#   Sennheiser IE 900 (Final) L.csv - data_mrs
#
# sennheiser mtw2 (he) l:
#   Sennheiser MTW2 (HE) L.csv - data_mrs
#
# shozy rouge l:
#   Shozy Rouge L.csv - data_mrs
#
# simgot en700 pro l:
#   Simgot EN700 Pro L.csv - data_mrs
#
# softears studio4 l:
#   Softears Studio4 L.csv - data_mrs
#
# sony mdr-as800 l:
#   Sony MDR-AS800 R.csv - data_mrs
#
# sony mdr-ex15lp (deep) r:
#   Sony MDR-EX15LP (deep) R.csv - data_mrs
#
# sony mh1 r:
#   Sony MH1 R.csv - data_mrs
#
# sony wf-1000xm4 (ambient on) l:
#   Sony WF-1000XM4 (SpinFit) L.csv - data_mrs
#
# sony wf-1000xm4 (eq - bass boost) l:
#   Sony WF-1000XM4 (max - EQ - vocal) L.csv - data_mrs
#
# sony wf-1000xm4 (max - anc off) l:
#   Sony WF-1000XM4 (max - XM3 silicone) L.csv - data_mrs
#
# sony wf-1000xm4 (mrs config) l:
#   Sony WF-1000XM4 (MRS config) L.csv - data_mrs
#
# sony wf-1000xm4 (sedna light short) l:
#   Sony WF-1000XM4 (Sedna Light Short) L.csv - data_mrs
#
# sony wf-1000xm4 (xm3 silicone) l:
#   Sony WF-1000XM4 (XM3 silicone) L.csv - data_mrs
#
# status audio iem-2x l:
#   Status Audio IEM-2X L.csv - data_mrs
#
# tanchjim prism (treble tips) r:
#   Tanchjim Prism (treble tips) R.csv - data_mrs
#
# tenhz 3ba l:
#   Tenhz 3BA L.csv - data_mrs
#
# tenhz p4 pro l:
#   Tenhz P4 Pro L.csv - data_mrs
#
# tfz t2 galaxy l:
#   TFZ T2 Galaxy L.csv - data_mrs
#
# thinksound rain3 l:
#   Thinksound Rain3 R.csv - data_mrs
#
# ucotech re-2 l:
#   Ucotech RE-2 R.csv - data_mrs
#
# vsonic gr07 (bass) l:
#   Vsonic GR07 R.csv - data_mrs
#
# working 001 target:
#   Working 002 Target.csv - data_mrs
#
# yinfu md51 l:
#   Yinfu MD51 L.csv - data_mrs

# %%
df
# Out:
#                                                             achoreviews  \
# 7hz dioko l                    [output/csv/achoreviews\7Hz Dioko L.csv]
# 7hz eternal l                [output/csv/achoreviews\7Hz Eternal L.csv]
# 7hz legato l                  [output/csv/achoreviews\7Hz Legato L.csv]
# 7hz timeless l              [output/csv/achoreviews\7Hz Timeless L.csv]
# 7hz zero l                      [output/csv/achoreviews\7Hz Zero L.csv]
# ...                                                                 ...
# elex (elear pads) l                                                 NaN
# elex (utopia pads) l                                                NaN
# sparks (basshead tuning) l                                          NaN
# ola stock l                                                         NaN
# test l                                                              NaN
#
#                                                            bedrock  \
# 7hz dioko l                   [output/csv/bedrock\7Hz Dioko R.csv]
# 7hz eternal l               [output/csv/bedrock\7Hz Eternal R.csv]
# 7hz legato l                                                   NaN
# 7hz timeless l                                                 NaN
# 7hz zero l                     [output/csv/bedrock\7Hz Zero R.csv]
# ...                                                            ...
# elex (elear pads) l                                            NaN
# elex (utopia pads) l                                           NaN
# sparks (basshead tuning) l                                     NaN
# ola stock l                                                    NaN
# test l                                                         NaN
#
#                                                             timmyv  \
# 7hz dioko l                    [output/csv/timmyv\7Hz Dioko R.csv]
# 7hz eternal l                                                  NaN
# 7hz legato l                  [output/csv/timmyv\7Hz Legato R.csv]
# 7hz timeless l              [output/csv/timmyv\7Hz Timeless R.csv]
# 7hz zero l                      [output/csv/timmyv\7Hz Zero R.csv]
# ...                                                            ...
# elex (elear pads) l                                            NaN
# elex (utopia pads) l                                           NaN
# sparks (basshead tuning) l                                     NaN
# ola stock l                                                    NaN
# test l                                                         NaN
#
#                                                                     hobbytalk  \
# 7hz dioko l                            [output/csv/hobbytalk\7hz Dioko R.csv]
# 7hz eternal l                                                             NaN
# 7hz legato l                                                              NaN
# 7hz timeless l              [output/csv/hobbytalk\7hz Timeless Tape Mod R....
# 7hz zero l                         [output/csv/hobbytalk\7hz Zero Tape R.csv]
# ...                                                                       ...
# elex (elear pads) l                                                       NaN
# elex (utopia pads) l                                                      NaN
# sparks (basshead tuning) l                                                NaN
# ola stock l                                                               NaN
# test l                                                                    NaN
#
#                                                                     ianfann  \
# 7hz dioko l                 [output/csv/ianfann\7HZ DIOKO (bass mod) R.csv]
# 7hz eternal l                                                           NaN
# 7hz legato l                          [output/csv/ianfann\7HZ LEGATO R.csv]
# 7hz timeless l                   [output/csv/ianfann\7HZ TIMELESS OG R.csv]
# 7hz zero l                        [output/csv/ianfann\7HZ ZERO MECHA R.csv]
# ...                                                                     ...
# elex (elear pads) l                                                     NaN
# elex (utopia pads) l                                                    NaN
# sparks (basshead tuning) l                                              NaN
# ola stock l                                                             NaN
# test l                                                                  NaN
#
#                                                                      iemworld  \
# 7hz dioko l                             [output/csv/iemworld\7Hz Dioko R.csv]
# 7hz eternal l                         [output/csv/iemworld\7Hz ETERNAL R.csv]
# 7hz legato l                                                              NaN
# 7hz timeless l              [output/csv/iemworld\7Hz Timeless (MoonDroop T...
# 7hz zero l                  [output/csv/iemworld\7hz Zero (Red Orignal Ear...
# ...                                                                       ...
# elex (elear pads) l                                                       NaN
# elex (utopia pads) l                                                      NaN
# sparks (basshead tuning) l                                                NaN
# ola stock l                                                               NaN
# test l                                                                    NaN
#
#                                                                   data_mrs  \
# 7hz dioko l                 [output/csv/data_mrs\7Hz Dioko (pre-op) R.csv]
# 7hz eternal l                                                          NaN
# 7hz legato l                                                           NaN
# 7hz timeless l               [output/csv/data_mrs\7Hz Timeless (S2) R.csv]
# 7hz zero l                            [output/csv/data_mrs\7Hz Zero R.csv]
# ...                                                                    ...
# elex (elear pads) l                                                    NaN
# elex (utopia pads) l                                                   NaN
# sparks (basshead tuning) l                                             NaN
# ola stock l                                                            NaN
# test l                                                                 NaN
#
#                                                                   aftersound  \
# 7hz dioko l                 [output/csv/aftersound\7HZ SALNOTES DIOKO R.csv]
# 7hz eternal l                                                            NaN
# 7hz legato l                        [output/csv/aftersound\7HZ LEGATO R.csv]
# 7hz timeless l                 [output/csv/aftersound\7HZ TIMELESS S2 R.csv]
# 7hz zero l                   [output/csv/aftersound\7HZ SALNOTES ZERO R.csv]
# ...                                                                      ...
# elex (elear pads) l                                                      NaN
# elex (utopia pads) l                                                     NaN
# sparks (basshead tuning) l                                               NaN
# ola stock l                                                              NaN
# test l                                                                   NaN
#
#                                                                   arn  \
# 7hz dioko l                 [output/csv/arn\7Hz Salnotes Dioko L.csv]
# 7hz eternal l                                                     NaN
# 7hz legato l                                                      NaN
# 7hz timeless l                    [output/csv/arn\7Hz Timeless L.csv]
# 7hz zero l                   [output/csv/arn\7Hz Salnotes Zero L.csv]
# ...                                                               ...
# elex (elear pads) l                                               NaN
# elex (utopia pads) l                                              NaN
# sparks (basshead tuning) l                                        NaN
# ola stock l                                                       NaN
# test l                                                            NaN
#
#                                                                     nymz  ...  \
# 7hz dioko l                   [output/csv/nymz\7hz Salnotes Dioko R.csv]  ...
# 7hz eternal l                                                        NaN  ...
# 7hz legato l                          [output/csv/nymz\7hz LEGATO R.csv]  ...
# 7hz timeless l                   [output/csv/nymz\7hz Timeless AE R.csv]  ...
# 7hz zero l                  [output/csv/nymz\7hz Salnotes Zero S2 R.csv]  ...
# ...                                                                  ...  ...
# elex (elear pads) l                                                  NaN  ...
# elex (utopia pads) l                                                 NaN  ...
# sparks (basshead tuning) l                                           NaN  ...
# ola stock l                                                          NaN  ...
# test l                                                               NaN  ...
#
#                                                            jacstone  \
# 7hz dioko l                                                     NaN
# 7hz eternal l                                                   NaN
# 7hz legato l                                                    NaN
# 7hz timeless l                                                  NaN
# 7hz zero l                  [output/csv/jacstone\7Hz ZERO S1 R.csv]
# ...                                                             ...
# elex (elear pads) l                                             NaN
# elex (utopia pads) l                                            NaN
# sparks (basshead tuning) l                                      NaN
# ola stock l                                                     NaN
# test l                                                          NaN
#
#                                                     recode bryaudioreviews  \
# 7hz dioko l                                            NaN             NaN
# 7hz eternal l                                          NaN             NaN
# 7hz legato l                                           NaN             NaN
# 7hz timeless l                                         NaN             NaN
# 7hz zero l                  [output/csv/recode\zero R.csv]             NaN
# ...                                                    ...             ...
# elex (elear pads) l                                    NaN             NaN
# elex (utopia pads) l                                   NaN             NaN
# sparks (basshead tuning) l                             NaN             NaN
# ola stock l                                            NaN             NaN
# test l                                                 NaN             NaN
#
#                            animagus cammyfi eplv shortbus suporsalad  \
# 7hz dioko l                     NaN     NaN  NaN      NaN        NaN
# 7hz eternal l                   NaN     NaN  NaN      NaN        NaN
# 7hz legato l                    NaN     NaN  NaN      NaN        NaN
# 7hz timeless l                  NaN     NaN  NaN      NaN        NaN
# 7hz zero l                      NaN     NaN  NaN      NaN        NaN
# ...                             ...     ...  ...      ...        ...
# elex (elear pads) l             NaN     NaN  NaN      NaN        NaN
# elex (utopia pads) l            NaN     NaN  NaN      NaN        NaN
# sparks (basshead tuning) l      NaN     NaN  NaN      NaN        NaN
# ola stock l                     NaN     NaN  NaN      NaN        NaN
# test l                          NaN     NaN  NaN      NaN        NaN
#
#                                                                      wdym  \
# 7hz dioko l                                                           NaN
# 7hz eternal l                                                         NaN
# 7hz legato l                                                          NaN
# 7hz timeless l                                                        NaN
# 7hz zero l                                                            NaN
# ...                                                                   ...
# elex (elear pads) l             [output/csv/wdym\Elex (Elear Pads) L.csv]
# elex (utopia pads) l           [output/csv/wdym\Elex (Utopia Pads) L.csv]
# sparks (basshead tuning) l  [output/csv/wdym\Sparks (Stock Tuning) L.csv]
# ola stock l                                                           NaN
# test l                                                                NaN
#
#                                                          akros
# 7hz dioko l                                                NaN
# 7hz eternal l                                              NaN
# 7hz legato l                                               NaN
# 7hz timeless l                                             NaN
# 7hz zero l                                                 NaN
# ...                                                        ...
# elex (elear pads) l                                        NaN
# elex (utopia pads) l                                       NaN
# sparks (basshead tuning) l                                 NaN
# ola stock l                 [output/csv/akros\Ola Stock L.csv]
# test l                           [output/csv/akros\test L.csv]
#
# [1644 rows x 32 columns]

# %% [markdown]
# ### Group Similar Names

# %%
import os
import re
from fuzzywuzzy import fuzz
from sklearn.cluster import DBSCAN
import numpy as np

def levenshtein_distance(a, b):
    return 1 - fuzz.ratio(a, b) / 100

def get_iem_names(reviewers):
    iem_names = set()

    for reviewer in reviewers:
        dir_path = f'output/csv/{reviewer}'
        for file_name in os.listdir(dir_path):
            file_name = re.sub(r'\.csv$', '', file_name, flags=re.IGNORECASE)  # Remove file extension
            file_name = file_name.strip()  # Remove leading/trailing spaces
            file_name = file_name.lower()  # Convert to lowercase
            iem_names.add(file_name)

    return list(iem_names)

# Get unique IEM names
iem_names = get_iem_names(reviewers)

# Create a pairwise distance matrix using the Levenshtein distance
distance_matrix = np.zeros((len(iem_names), len(iem_names)))

for i, name_a in enumerate(iem_names):
    for j, name_b in enumerate(iem_names):
        if i == j:
            continue
        distance_matrix[i, j] = levenshtein_distance(name_a, name_b)

# Cluster IEM names using DBSCAN
dbscan = DBSCAN(eps=0.3, min_samples=2, metric="precomputed")
clusters = dbscan.fit_predict(distance_matrix)

# Print clustered IEM names
clustered_iem_names = {}
for iem_name, cluster in zip(iem_names, clusters):
    if cluster not in clustered_iem_names:
        clustered_iem_names[cluster] = []

    clustered_iem_names[cluster].append(iem_name)

for cluster, names in clustered_iem_names.items():
    print(f"Cluster {cluster}:")
    for name in names:
        print(f"  - {name}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18868\2916925051.py in <module>
#      67         if i == j:
#      68             continue
# ---> 69         distance_matrix[i, j] = levenshtein_distance(name_a, name_b)
#      70
#      71 # Cluster IEM names using DBSCAN
#
# ~\AppData\Local\Temp\ipykernel_18868\2916925051.py in levenshtein_distance(a, b)
#       6
#       7 def levenshtein_distance(a, b):
# ----> 8     return 1 - fuzz.ratio(a, b) / 100
#       9
#      10 def get_iem_names(reviewers):
#
# c:\Users\Agnes\anaconda3\lib\site-packages\fuzzywuzzy\utils.py in decorator(*args, **kwargs)
#      32
#      33 def check_for_none(func):
# ---> 34     @functools.wraps(func)
#      35     def decorator(*args, **kwargs):
#      36         if args[0] is None or args[1] is None:
#
# KeyboardInterrupt:

# %%
import os
import re
import spacy
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def preprocess_iem_names(reviewers):
    iem_names = set()

    for reviewer in reviewers:
        dir_path = f'output/csv/{reviewer}'
        for file_name in os.listdir(dir_path):
            file_name = re.sub(r'\.csv$', '', file_name, flags=re.IGNORECASE)  # Remove file extension
            file_name = file_name.strip()  # Remove leading/trailing spaces
            file_name = file_name.lower()  # Convert to lowercase
            iem_names.add(file_name)

    return list(iem_names)

nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

def tokenize(text):
    tokens = [token.text for token in nlp(text)]
    return tokens

# List of reviewers
reviewers = [
    'achoreviews',
    'aftersound',
    'animagus',
    'arn',
    'bedrock',
    'bryaudioreviews',
    'cammyfi',
    'soundjedi',
    'eplv',
    'timmyv',
    'harpo',
    'hbb',
    'cqtek',
    'hobbytalk',
    'ianfann',
    'iemworld',
    'jacstone',
    'kr0mka',
    'kurin',
    'melatonin',
    'nymz', 
    'pw',
    'recode',
    'rg',
    'shortbus',
    'suporsalad',
    'tgx78',
    'vortexreviews',
    'vsg',
    'wdym',
    'akros',
    'data_mrs'
]

# Get unique IEM names
iem_names = preprocess_iem_names(reviewers)

# Tokenize IEM names and compute TF-IDF matrix
vectorizer = TfidfVectorizer(tokenizer=tokenize)
tfidf_matrix = vectorizer.fit_transform(iem_names)

# Compute cosine similarity matrix
similarity_matrix = cosine_similarity(tfidf_matrix)

# Convert similarity matrix to distance matrix
distance_matrix = 1 - similarity_matrix

# Set small negative values to zero
distance_matrix[distance_matrix < 0] = 0

# Cluster IEM names using DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=2, metric="precomputed")
clusters = dbscan.fit_predict(distance_matrix)

# Print clustered IEM names
clustered_iem_names = {}
for iem_name, cluster in zip(iem_names, clusters):
    if cluster not in clustered_iem_names:
        clustered_iem_names[cluster] = []

    clustered_iem_names[cluster].append(iem_name)

for cluster, names in clustered_iem_names.items():
    print(f"Cluster {cluster}:")
    for name in names:
        print(f"  - {name}")
# Out:
# Cluster 0:
#   - lz a7 blue monitor r
#   - dunu talos (s2 on) l
#   - letshuoer galileo (pre-production) r
#   - fiio fd3 (foam tips) l
#   - tanchjim hana r
#   - dunu titan 5 r
#   - tangzu heyday r
#   - moondrop blessing 2 dusk s1 l
#   - supernova final r
#   - moondrop blessing 2 (moondrop filter) l
#   - letshuoer z12 l
#   - cca cra l
#   - tanchjim oxygen l
#   - truthear hola (wide bore silicone tips) r
#   - heart mirror r
#   - tripowin x hbb olina a r
#   - thieaudio oracle mkii r
#   - resolve softears rsv gras l
#   - 64 audio u6t xx (silicon tips wide) r
#   - thieaudio legacy 3 1 on r
#   - etymotic er2xr double r
#   - final audio e500 r
#   - md droplet dsp r
#   - letshuoer z12 (s2) l
#   - md kxxx r
#   - cca cra (1dividedby8 foam) l
#   - sony ier-m7 r
#   - dunu titan tanya l
#   - heart mirror pro l
#   - bqeyz autumn (bass vent, sony import foam) l
#   - fiio fd5 r
#   - mooondrop kato l
#   - bqeyz autumn (y3 wtf inner vent, 2 high-density tuning foam, 500 mesh) r
#   - blon bl max r
#   - moondrop b2 dusk l
#   - bgvp ns9 r
#   - cca cra (filterless + 2 high-density tuning foams) l
#   - nf audio na2+ (tanchjim filter) l
#   - etymotic er2se (autoeq) l
#   - tri starsea l
#   - kz eda balanced l
#   - softears s4 l
#   - thieaudio legacy 4 (spring) r
#   - 7th acoustics stargazer 3 l
#   - kz zs10 pro x l
#   - sony mh755 (s3) r
#   - x2 pro r
#   - 7hz timeless (350 mesh, stock tuning foam sideways, super thin hs foam inner vent) l
#   - lz a7 (pop-red, 30ohm) l
#   - fiio fd3 r
#   - cca cra s2 r
#   - thieaudio oracle mkii l
#   - seeaudio yume midnight (36ohm) l
#   - letshuoer d13 silver nozzle l
#   - kz as10 r
#   - aful performer 5 r
#   - oratory sony wf-1000xm4 l
#   - 64 audio u12t m20 l
#   - truthears hola r
#   - 7hz timeless s2 l
#   - moondrop blessing 2 dusk (orignal silicon) l
#   - 7hz zero (moondrop eartips) l
#   - sony mh755 (s3) l
#   - raptgo hook x (ej07 foam eartips small) l
#   - ikko oh10 (no tip on coupler) r
#   - moondrop aria snow nofoam l
#   - aiderlot m5 treble 30ohm r
#   - fonge x2 pro l
#   - tripowin olina vent covered r
#   - ief comp target
#   - ie600 r
#   - dunu falcon pro ref r
#   - 7hz legato (500 mesh) l
#   - shuoer ej07m filtered l
#   - etymotic er2xr r
#   - tangzu wu zetian heyday r
#   - tinhifi t2 evo r
#   - zero carbotenore l
#   - xenns mangird top l
#   - sony wf-1000xm4 (eq - vocal) l
#   - kiwi cadenza r
#   - 64 audio u12t (filter 3) r
#   - shuoer s12 eru l
#   - moondrop blessing 3 l
#   - tripowin x hbb olina (foam eartips) l
#   - md kxxs l
#   - resolve blessing 2 gras l
#   - qkz x hbb ve adapter l
#   - 55hz fo r
#   - moondrop nekocake (wennebostel) l
#   - sennheiser ie300 (orignal foam) r
#   - 64 audio u18t m20 l
#   - moondrop stardust (s4) r
#   - 55hz t r
#   - thieaudio monarch mkii l
#   - dunu vernus transpa l
#   - thieaudio legacy 5 (s2 15ohm) l
#   - shuoer ej07m stock l
#   - sennheiser ie200 (stock tips) r
#   - lz a4 pro (blue f + red v) l
#   - 5i anc bass r
#   - truthear zero double filter l
#   - kato silver symbio r
#   - dunu sa6 ultra off r
#   - moondrop stellaris (uc) l
#   - letshuoer ej07 l
#   - helios symp l
#   - kz as16 pro tk2 l
#   - thieaudio monarch l
#   - elysian x elise l
#   - moondrop alice tws r
#   - 64 audio u6t m15 (silicon tips) l
#   - sennheiser ie300 (no tip on coupler) r
#   - kz ast r
#   - dunu zen r
#   - moondrop chu mp l
#   - 7hz x crinacle dioko updated l
#   - tinhifi c3 l
#   - dunu talos (hybrid) l
#   - tanchjim echo (tanchjim echo filter + 200 paper vent) l
#   - tangzu shiminli nodamper l
#   - etymotic er2xr (brown) l
#   - kiwiears cadanza l
#   - moondrop s8 l
#   - kz edx ultra r
#   - tinhifi p1 max r
#   - vento conductor t-500pro l
#   - joyodio shine (1010) l
#   - tangzu waner r
#   - animagus preference target
#   - 64 audio u6t m20 (no tip on coupler) r
#   - sony mh750 l
#   - blon a8 prometheus l
#   - if audio 31 r
#   - thieaudio oracle mk2 l
#   - kz dq6s l
#   - sennheiser ie300 (orignal foam) l
#   - kz ast tanya l
#   - tripowin x hbb olina (orignal eartips) r
#   - bqeyz autumn r
#   - tinhifi p1 max giant panda r
#   - kxxs r
#   - fiio fd3 treble l
#   - bqeyz autumn (none) r
#   - sony-xba-z5-r
#   - 64 audio u18t mx l
#   - letshuoer 12 r
#   - moondrop ssp r
#   - oratory 7hz salnotes zero l
#   - kz ast l
#   - ikko oh10 (high-density tuning foams) l
#   - sample 1 l
#   - prisma audio azul (s2) l
#   - stardust r
#   - moondrop sparks (1.1.9 - studio) l
#   - xenns mangird tea 2 (s2) l
#   - sony ier-z1r (s2 - symbio) l
#   - cammyfi neutral target
#   - final audio e3000 (s2) r
#   - softears volume half mp l
#   - 64 audio nio (s1 - mx) l
#   - shuoer ej07m kl l
#   - resolve 7hz salnotes dioko gras l
#   - oratory sony mdr-ex15lp l
#   - simgot ea500 red l
#   - moondrop aria s2 l
#   - tinhifi t4 plus l
#   - moondrop variations springtips l
#   - lz a7 monitor black r
#   - oratory 64 audio a12t (m15 apex module) l
#   - ssr new4 l
#   - dusk r
#   - moondrop kxxs r
#   - seeaudio yume midnight (s2) r
#   - final e4000 l
#   - simgot ea500 blue l
#   - tripowin mele sony r
#   - tangzu waner sg r
#   - sennheiser ie600 final e l
#   - olina l
#   - hisenior mega5p l
#   - seeaudio x crinacle midnight r
#   - 55hz eki fil fo r
#   - sennheiser ie 900 l
#   - xinhs erasmus l
#   - dusk mistip l
#   - moondrop s8 (s2) l
#   - tripowin olina s3 l
#   - moondrop illumination l
#   - yanyin canon mids switch l
#   - super review target
#   - 55hz mystery r
#   - shine standard 1000 l
#   - ks zs10 pro l
#   - 7hz legato (250 mesh) l
#   - tangzu zetian wu r
#   - 64 audio u12t m12 l
#   - bqeyz autumn (y6 wtf inner vent, sony import foam) l
#   - oratory sony ier-m9 l
#   - tanchjim new hana 2021 treble l
#   - 7hz legato (inner vent blutack) l
#   - letshuoer cadenza l
#   - sennheiser ie200 r
#   - simgot ea500 (deep)
#   - xinhs erasmus r
#   - 64 audio u12t sample 2 (m15) l
#   - sample 1 deep l
#   - wgzblon bl-max l
#   - lz ax black off r
#   - thieaudio legacy 4 1 on r
#   - sennheiser momentum 3 (bgvp foam) r
#   - cca cra (500 mesh + 300 paper filter + high-density tuning foam) l
#   - joyodio shine 1111 l
#   - thieaudio monarch mk2 (final eartips) l
#   - 7hz timeless r
#   - tripowin mele naked l
#   - ely-x-effect-gaea-r
#   - thieaudio monarch mk2 (no tip on coupler 8k peak disappeared 87db foam) l
#   - qkz x hbb l
#   - t-force yuan li l
#   - sony mdr-ex15lp (deep) r
#   - shuoer z12 l
#   - 64 audio u6t m15 (silicon tips) r
#   - tripowin x hbb mele l
#   - mangird top l
#   - olina se s2 r
#   - 7hz salnotes dioko r
#   - kz edx pro (low-density tuning foam) l
#   - thieaudio legacy 3 2 on r
#   - shortbus ej07sb l
#   - shine hifi l
#   - moondrop chu (spring tips) l
#   - lz a4 pro nzred fiblu l
#   - shuoer ej07m s2 r
#   - letshuoer tape pro r
#   - tanchjim zero dsp r
#   - cra r
#   - kz eds l
#   - tin hifi t2 dlc r
#   - 7hz zero r
#   - tripowin rhombus r
#   - sony xba-n3 l
#   - heart mirror l
#   - bqeyz autumn (bass vent, high-density tuning foam, cotton filter) l
#   - moondrop lan (orignal silicon) r
#   - 7th acoustics stargazer 3 r
#   - moondrop blessing 2 dusk (orignal silicon) r
#   - bqeyz autumn (500 mesh inner vent, sony import foam) l
#   - moondrop alice (eq vienna) l
#   - tangzu x hbb zetian wu xbass xspace r
#   - shuoer kl 3 r
#   - final audio e4000 l
#   - thieaudio monarch mk2 (foam eartips) l
#   - bqeyz autumn (normal vent, sony import foam, blutack outer vent) l
#   - pre-prod 03 (nozzle b) r
#   - fiio fd5 (narrow + brainwavz) l
#   - softears rsv r
#   - 64 audio u18s l
#   - blessing 2 dusk l
#   - fh5s standard r
#   - 1more triple driver (foam eartips) l
#   - sennheiser ie200 (stock tips) l
#   - tinhifi t3 plus r
#   - oratory akg n400 l
#   - letshuoer d13 gold nozzle l
#   - dusk w1shallow l
#   - lz a7 (monitor-gold) l
#   - hidizs ms5 bal r
#   - harmonicdyne zeus l
#   - joyodio shine (0100) l
#   - qkz x hbb khan l
#   - kz zsn pro (blessing 2 filter) l
#   - tin hifi t3 plus l
#   - moondrop nekocake (nobass) l
#   - dusk bgvpshallow l
#   - tripowin olina us full r
#   - fiio fd3 (blk nozzle) l
#   - sony wf-1000xm4 (ambient on) l
#   - shuoer ej07m kl resin r
#   - zero r
#   - 64 audio u6t l
#   - kz eda resolution r
#   - cca csa l
#   - hidizs ms5 bass (balanced tips) r
#   - moondrop kato non spring (brass) r
#   - kz eda (gold) l
#   - dunu talos off l
#   - p1 max foam l
#   - moondrop nekocake (balanced + anc) l
#   - 7hz dioko r
#   - hzsound heart mirror r
#   - joyodio shine (0110) l
#   - 7hz x crinacle salnotes dioko l
#   - tri kai x hbb l
#   - tin hifi c2 r
#   - moondrop lan (tripowin foam) l
#   - fiio fh5s (111) l
#   - dunu zen (micropore tape mod) l
#   - sony mh755 (vent blu tack) l
#   - shuoer s12 sony deep l
#   - hzsound waistdrum9 r
#   - moondrop ssr (s2) l
#   - moondrop sparks (1.1.7) l
#   - 7hz zero mecha r
#   - 64 audio u6t m20 (silicon tips) l
#   - sample tr b r
#   - cca cra (500 mesh + y3 paper filter) l
#   - tripowin mele s2 r
#   - lz a7 pop gold r
#   - final audio e5000 l
#   - moondrop blessing 2 dusk l
#   - lz a7 pop black foam r
#   - 5i treble l
#   - etymotic er2xr (brown + 2f) l
#   - 7hz salnotes dioko l
#   - symphonium meteor s2 l
#   - tanchjim ola shortbus l
#   - moondrop target
#   - kiwi ears orchestra (sedna short) r
#   - dunu vernus transpa r
#   - kz edx l
#   - hidizs ms5 bass (tripowin foam) r
#   - aful acoustics performer5 (36 ohm) l
#   - elysian diva (blue switch) r
#   - symphonium meteor sample r
#   - sennheiser ie 200 (azla max) r
#   - audiosense t800 (1dividedby16 foam) l
#   - dunu falcon pro (transparent filter, 2 outer vent blutack, low-density tuning foam) l
#   - raptgo x hbb hook-x s2 r
#   - kz zvx iematch l
#   - sony wf-1000xm4 (max - anc off) l
#   - tangzu wu heyday r
#   - bqeyz autumn bass r
#   - tinhifi t2 dlc l
#   - hidizs ms5 balanced (whizzer easytips et100ab) l
#   - letshuoer z12 r
#   - fiio fh7s r
#   - truthear zero (s2 deep) l
#   - oratory moondrop quarks l
#   - tfz t2 galaxy l
#   - moondrop alice (2.0.1 + e-type) l
#   - ikko oh1s sample 2 l
#   - moondrop ssr (deep) l
#   - joyodio shine 1000 r
#   - moondrop ssr l
#   - oratory 1more triple driver ltng l
#   - sennheiser ie800 l
#   - hidizs ms5 high oi l
#   - 64 audio fourte noir r
#   - fiio fhe (s2) r
#   - elysian x r
#   - moondrop aria snow edition r
#   - harman ie 2019 v2 target
#   - kz as06 r
#   - raptgo x hbb hook-x s2 l
#   - 7hz zero (final eartips) l
#   - raptgo hook x hbb r
#   - truthear x crinacle zero (final e eartips) r
#   - shuoer ej07m kl resin l
#   - kz dq6 (micropore+ 1dividedby16foam tips) l
#   - kz dq6 x hbb r
#   - tri starsea (01) r
#   - tripowin x hbb olina (2 filter foam eartips) l
#   - kiwi ears orchestra l
#   - tanchjim oxygen (1dividedby16 foam) l
#   - yanyin mahina r
#   - kiwi ears orchestra lite (25ohm) l
#   - chu foamfilter r
#   - trn kirin atmosphere l
#   - ssr l
#   - moondrop s8 r
#   - empire ears bravado mkii l
#   - yan ult 3 r
#   - 64 audio u12t mx15 r
#   - fiio fh5s r
#   - sony wf-1000xm4 (anc on) l
#   - pre-prod 03 (nozzle b) l
#   - dunu est112 (micropore tape mod) l
#   - lz a6 (yellow filter) l
#   - oratory 7hz timeless l
#   - lz a7 silver pop r
#   - joyodio shine standard r
#   - symphonium meteor s1 l
#   - hzsound heart mirror l
#   - 64 audio nio (s1 - m20) l
#   - nfaudio na2+ l
#   - lz a4 pro nzsil fiblk l
#   - zexpro l
#   - broken variations
#   - softears volume (asgard 3) l
#   - simgot ea500 r
#   - softears volume (atom + y3 paper filter on ba bore) l
#   - trurhear hola r
#   - letshuoer d13 (silver filter) l
#   - tin t3 plus r
#   - shuoer ej09 r
#   - sony mh755 mmcx l
#   - shuoer ej07m r
#   - blon a8 r
#   - resolve oracle mk2 gras l
#   - p1 max h07 l
#   - fiio fd5 small nozzle l
#   - hbb 1 r
#   - 64audio trio l
#   - olina mod mesh r
#   - 64audio trio v2 l
#   - tangzu zetian r
#   - fiio fh5s mids l
#   - letshuoer d13 2nd nozzle r
#   - moondrop alice (2.0.1 + e-type) r
#   - moondrop stellaris (tanchjim filter) l
#   - dunu talos planar mode l
#   - elysian diva bass light l
#   - tin hifi c2 mech warrior l
#   - tripowin x hbb olina (moondrop eartips) l
#   - sennheiser ie600 r
#   - dunu sa6 mk2 (off) l
#   - ikko oh10 (1dividedby16 foam) l
#   - moondrop stardust l
#   - tfz t2 pro r
#   - 5i anc treble l
#   - thieaudio monarch mk2 (orignal silicone eartips) l
#   - mini pro hs anc off l
#   - dunu talos planar+ba l
#   - oratory moondrop chu l
#   - hidizs ms5 treble (whizzer easytips et100ab) r
#   - 64 audio u18s r
#   - tin hifi t1s eq r
#   - quarks dsp l
#   - tri x hbb kai r
#   - blon max l
#   - symphonium meteor sample l
#   - tripowin black 2 r
#   - moondrop alice (eq tokyo) l
#   - symphonium meteor l
#   - dunu talos (on) r
#   - lz a4 pro (blue f + black v) l
#   - oratory akg k3003 l
#   - kz crn l
#   - harman oe target
#   - tri starsea (01) l
#   - sennheiser ie 600 (spinfit) r
#   - supernova mistip r
#   - tripowin tc01 r
#   - hidizs ms5 1ohm l
#   - hidizs mm2 treble l
#   - ief oe target
#   - 7hertz timeless r
#   - moondrop chu (mod) r
#   - tfz live 1 l
#   - sennheiser momentum 3 (softear uc eartips) l
#   - tinhifi t4+ l
#   - sennheiser ie600 aet08 l
#   - joyodio shine 1001 r
#   - sam k r
#   - ikko gems oh1s (s2 + stock foams + micropore mod) l
#   - joyodio shine 3 on r
#   - ief neutral 2020 target
#   - vento conductor t-800 r
#   - 64 audio u12t (filter 1) r
#   - lz z04a (low-density tuning foam) l
#   - moondrop kato brass l
#   - kz as06-2020 l
#   - sample 1 r
#   - yuan li final l
#   - moondrop kato (copper) l
#   - lz a7 (pop-silver) l
#   - sony wf-1000xm4 (tanchjim apb) l
#   - blon bl-03 (mesh mod) l
#   - sennheiser ie 600 (foam) r
#   - moondrop quarks dsp stock tips l
#   - truthear zero (s2) l
#   - oratory tfz t2 galaxy l
#   - ola r
#   - ikko gems oh1s (s2 + stock foams) l
#   - truthear hexa (s2) l
#   - 64 audio u6t m15 (foam) l
#   - tripowin x hbb olina (moondrop eartips) r
#   - tanchjim oxygen set2 r
#   - sony ex800st r
#   - tangzu x hbb zetian wu tape r
#   - moondrop alice (eq munich) l
#   - joyodio shine (0000) l
#   - final e500 l
#   - oratory final audio e4000 l
#   - 55hz r r
#   - 64 audio u4s (fir red) r
#   - quarks dsp deep r
#   - galileo retail r
#   - dunu talos (planar) r
#   - dunu titan 5 l
#   - raptgo hook x l
#   - 55hz osummer r
#   - tripowin olina se l
#   - etymotic erx l
#   - moondrop lan (blu tack) r
#   - 64audio trio r
#   - qkz ak6-aers r
#   - sennheiser momentum 3 (tripowin foam) l
#   - oratory final audio e5000 l
#   - elysian annihilator x r
#   - joyodio shine all on r
#   - tripowin x hbb olina (2 filter orignal eartips) l
#   - hz heartmirror r
#   - kxxs (symbio w peel) r
#   - kz dq6 (low-density tuning foam) l
#   - p1 max sticky red deep r
#   - fiio fh5s l
#   - ms5 treble l
#   - sony xba-z5 l
#   - etymotic er2xr (s2) r
#   - yan mahina 2 r
#   - tripowin cencibel 2x filter mod r
#   - hzsound zero no foam r
#   - tanchjim zero l
#   - kiwi orchestra lite r
#   - 7hz timeless (s2) l
#   - moondrop alice (eq wennebostel) l
#   - tanchjim echo (tanchjim echo filter) l
#   - tri hbb kai s2 l
#   - moondrop aria l
#   - softears target
#   - 64 audio u4s (fir red) l
#   - 64 audio duo r
#   - sony xba-a2 (foamless) l
#   - oratory final audio e500 l
#   - yanyin canon all switches l
#   - moondrop s8 (s2) r
#   - sony ex1000 r
#   - recode warm neutral target
#   - dunu titan s (tanchjim filter) l
#   - softears volume (apple + 36ohm) l
#   - hidizs ms5 bass (bass tips) r
#   - thieaudio v16 divinity l
#   - nf audio na2 l
#   - oratory sony xba-h3 l
#   - effect audio gaea r
#   - ikko oh1s l
#   - lz a7 black monitor r
#   - 64 audio u12t r
#   - mdr-ex15ap r
#   - tinhifi c5 r
#   - blon bl-mini r
#   - blon mini r
#   - zetian wu r
#   - shuoer d13 2 r
#   - 64 audio u18t none r
#   - final audio e1000 l
#   - truthear zero r
#   - sparks david xu 1.2.1 l
#   - thieaudio oracle mk2 r
#   - super 22 target
#   - 7hz salnotes zero r
#   - kz as16 200ω r
#   - softears volume (ef04 muse02 + y2 paper filter on ba bore) l
#   - kiwi ears orchestra (sedna short) l
#   - sparks no bass 1.2.1 l
#   - dunu falcon pro atm r
#   - lz a4 pro black-blue l
#   - letshuoer d13 treble r
#   - etymotic er2xr orange l
#   - 7hz timeless (350 mesh, stock tuning foam, super thin hs foam inner vent) l
#   - fiio fh5s (t1 m0 b0) l
#   - dunu talos (switch on) r
#   - ms5 treble r
#   - dunu est112 l
#   - symphonium helios shallow fit l
#   - sennheiser ie300 (tripowin foam) l
#   - moondrop a8 l
#   - kz pr1 hifi version r
#   - lz a6 (purple filter) l
#   - tin hifi t2 pro (comply) l
#   - xenns top l
#   - mi true wireless earbuds basic 2 l
#   - sennheiser ie300 (orignal silicon) l
#   - sennheiser momentum true wireless 2 r
#   - blon bl-03 (tanchjim filter) l
#   - sony ier-z1r r
#   - final audio e3000 r
#   - softears volume (foam) l
#   - sennheiser ie 200 (spiral dot) l
#   - 55hz eki tune r
#   - sennheiser ie600 (no tip on coupler) r
#   - 64 audio u6t mx (foam) r
#   - oratory moondrop blessing l
#   - final audio e1000 (s2) l
#   - joyodio shine pop r
#   - softears volume (apple + 15ohm) l
#   - sony wf-1000xm4 (eq - excited) l
#   - joyodio shine (1100) l
#   - zero l
#   - hidizs ms5 treble (softear uc tips) r
#   - 64 audio u18t m20 r
#   - moondrop alice l
#   - fiio x crinacle fhe eclipse (foam eartips) l
#   - tanchjim ola bass l
#   - etymotic er4xr foam l
#   - lz a7 pop silver r
#   - hidizs ms5 balanced (tripowin foam) r
#   - moondrop ssr (s4) r
#   - sony ier m7 r
#   - seeaudio midnight r
#   - moondrop chu (vent - tanchjim) l
#   - bgvp es12 (111) r
#   - 64 audio u6t xx (silicon tips wide) l
#   - ssr new1 r
#   - moondrop chu r
#   - cca cra (500 mesh + sony general foam) l
#   - kz eda high r
#   - kz zex pro l
#   - letshuoer s12 (s2) l
#   - ie600 stock
#   - sam kl r
#   - kz zex taped l
#   - elysian diva bass heavy l
#   - lz a7 (pop-black, high-density tuning foams) l
#   - cca cra mod r
#   - resolve truthear hexa gras l
#   - truthear hexa (foam eartips) r
#   - sparks (basshead tuning) l
#   - 64 audio u4s m15 l
#   - fiio fh7s (treble) r
#   - dunu sa6 ultra off l
#   - p1 max stock black l
#   - lz a7 monitor gold r
#   - thieaudio legacy 4 (spring) l
#   - dunu sa6 mk2 on l
#   - pr1 pro l
#   - letshuoer ej07m lava r
#   - kiwi ears orchestra lite l
#   - 64 audio u12t (filter 2) l
#   - kiwiears cadenza r
#   - akros erasmus 11 l
#   - ief target1
#   - blon bl-03 (white fine mesh + micropore tape 2pin vent block) l
#   - 64 audio u18t none l
#   - trn kirin (reference filter) r
#   - thieaudio monarch mkii r
#   - elysian diva (red switch) l
#   - p1 max spring tips r
#   - trn kirin reference l
#   - cca cra (500 mesh + y1 paper filter) l
#   - raptgo huk x r
#   - tri meteor l
#   - oratory t64 audio a12t (m20 apex module) l
#   - binaryacoustic void r
#   - elysian gaea l
#   - tripowin h1 r
#   - joyodio shine 1011 r
#   - hidizs ms5 bass (moondrop spring tips) l
#   - oratory moondrop blessing 2 dusk l
#   - ms5 balanced r
#   - truthears zero r
#   - kz zs10 pro l
#   - hisenior mega5p (foam eartips) r
#   - tfz live 3 l
#   - fiio fh5s (100) l
#   - tripowin black r
#   - tinhifi c2 r
#   - moondrop quarks dsp ultra deep r
#   - thieaudio legacy 5 l
#   - sony mdr-ex15lp r
#   - trn kirin (reference filter) l
#   - t4 plus l
#   - moondrop stardust (s2) l
#   - 64 audio nio (mx) r
#   - lz a7 gold pop r
#   - cca cra+ (stock tips) r
#   - tripowin x hbb olina (2 filter moondrop eartips) r
#   - trn kirin transparency r
#   - moondrop alice (eq in-ear target) l
#   - sennheiser ie 200 (uc tips) r
#   - moondrop kato non spring (steel) l
#   - tangzu audio waner sg r
#   - md b2 l
#   - thieaudio monarch mkii (s2 - spring tips) l
#   - moondrop chu tanya r
#   - 64 audio u4s (m15) r
#   - kz zsn pro (tanchjim filter) l
#   - etymotic er2xr white l
#   - moondrop illumination (spiral dots) l
#   - 64 audio u4s (m20) l
#   - kxxs spring l
#   - lz ax gold r
#   - 7th acoustics proxima l
#   - sennheiser ie 900 (fake) r
#   - aiderlot m5 pro r
#   - 55hz b r
#   - mdr-ex15 (symbio w peel) l
#   - tangzu audio shimin li l
#   - tinhifi t4 plus deep fit l
#   - hidizs ms5 treble r
#   - tangzu shiminli downunder l
#   - mooondrop kato r
#   - vk4 r
#   - oratory moondrop blessing 2 l
#   - tripowin x hbb olina (final eartips) r
#   - moondrop kxxs l
#   - kz zex pro (30ohm) l
#   - yanyin canon dip 2 r
#   - tangzu shiminli r
#   - symphonium audio triton l
#   - final e1000 r
#   - 7hz dioko (bass mod) l
#   - 7hz sample med r
#   - supernova vivid r
#   - elysian diva (blue switch) l
#   - 64 audio u12t sample 3 (m20) l
#   - ikko oh10 r
#   - letshuoer z12 (s2) r
#   - clairvoyance r
#   - truthear hexa l
#   - fh5s mids r
#   - sony ier-m7 l
#   - fiio fh7s bass r
#   - tripowin mele sony l
#   - tripowin x hbb olina l
#   - empire ears valkyrie mkii l
#   - muse power r
#   - kz dq6 x2 r
#   - sennheiser ie 600 (e-type shallow) l
#   - tripowin silver r
#   - moondrop aria snow (spring) l
#   - tripowin h1 r (1)
#   - md b2 dusk r
#   - md kxxx l
#   - dunu falcon pro (transparent filter, 2 outer vent pk foam, low-density tuning foam) l
#   - hidizs md4 balanced l
#   - tangzu wu heyday l
#   - shuoer ej07m s2 l
#   - fiio x crinacle fhe (eclipse) l
#   - thieaudio legacy 4 all on r
#   - tripowin x hbb olina (2 filter moondrop eartips) l
#   - moondrop ssr (final e) l
#   - hidizs ms5 balanced (whizzer easytips et100ab) r
#   - moondrop aria s1 r
#   - letshuoer d13 (pre-prod - nozzle a) l
#   - fiio fd7 (bass) l
#   - kz zs10 pro x r
#   - mdr-ex15 (kxxs) l
#   - 64 audio u12t mx l
#   - kz zs5 old r
#   - tripowin olina dual vent r
#   - dunu talos (planar + ba) (ie600 foam tips) l
#   - tin hifi t2 pro (white grill + comply) l
#   - tin t2 2pin r
#   - moondrop kato (copper) r
#   - kxxs l
#   - ax target
#   - joyodio shine 1010 l
#   - sennheiser ie 600 (spring tips) l
#   - empire ears odin r
#   - yanyin mahina s2 r
#   - kki 1 ba switch 1 l
#   - elysian x l
#   - lz a6 (grey filter) l
#   - tanchjim oxygen set2 l
#   - oratory kz zs10 l
#   - softears volume (ultraclear) r
#   - joyodio shine 0011 l
#   - dunu falcon pro atm l
#   - cvj river r
#   - softears volume es100 tanya l
#   - hidizs ms5 bass (moondrop spring tips) r
#   - 1more evo l
#   - yanyin canon mids switch r
#   - dusk ortofon r
#   - moondrop  starfield r
#   - raptgo hook x (orignal eartips) l
#   - lz a4 pro (gold f + black v) l
#   - tangzu wu zetian r
#   - chu detach r
#   - final e500 autoeq l
#   - 7th acoustics stargazer 3 prototype r
#   - kz eds btx hifi l
#   - oratory sennheiser momentum true wireless l
#   - thieaudio legacy 4 r
#   - mystery 010 r
#   - p1 max xelastec l
#   - shine pop l
#   - tangzu audio zetian wu l
#   - letshuoer kl r
#   - kz zs10 pro r
#   - kiwi ears orchestra lite r
#   - letshuoer ej07m 75ohm r
#   - letshuoer d13 (pre-prod - nozzle b) r
#   - ssr new1 l
#   - zero zircopezzo l
#   - sennheiser momentum 3 (final eartips) r
#   - openheart ie800 l
#   - resolve monarch gras l
#   - kiwi cadenza l
#   - magaosi k5 (15 ohm) l
#   - tforce yuan li modded r
#   - kz zs10 pro foam r
#   - joyodio shine (0010) l
#   - ikko gems oh1s (s2 + stock foams + blutack) l
#   - cca cra (500 mesh) l
#   - kato silver symbio l
#   - soundpeats capsule3 pro l
#   - hidizs ms5 1ohm r
#   - recode neutral target
#   - sony xba-a2 l
#   - dunu falcon pro (reference filter, 2 outer vent blutack, high-density tuning foam) l
#   - fiio fd7 (balanced) r
#   - ief target
#   - monarch r
#   - ssr faudio l
#   - moondrop blessing 2 dusk r
#   - dunu talos ba r
#   - letshuoer d13 stock nozzle l
#   - 64 audio u6t xx (foam) r
#   - kz zsn pro xv2 l
#   - lz a6 (red filter) l
#   - tin hifi p1 l
#   - tin hifi t2 plus l
#   - 7th acoustics supernova (s2) l
#   - moondrop lan (final eartips) l
#   - lz a7 monitor blue r
#   - 7hz x crinacle dioko l
#   - 64 audio u12t non apex l
#   - akg n400 l
#   - vento conductor tony l
#   - crinacle neutral 2023 target
#   - etymotic er4xr (foam) l
#   - kz zvx final tips r
#   - moondrop nekocake (dynamic anc) l
#   - moondrop kato (steel) l
#   - moondrop sparks l
#   - dusk bgvp l
#   - vento conductor t-800 l
#   - etymotic erx (brown) r
#   - moondrop quarks dsp 77db l
#   - 64 audio u4s (fir black) l
#   - letshuoer d13 gold l
#   - 5i treble r
#   - moondrop chu tanya l
#   - moondrop blessing 2 dusk (softear uc eartips) r
#   - 7hz timeless (tanchjim filter, stock tuning foam sideways, super thin hs foam inner vent) l
#   - sample 1 deep r
#   - resolve 7hz tmeless gras l
#   - lz ax silver r
#   - tripowin x hbb olina se r
#   - kz eda (gold) r
#   - sparks balanced 1.2.1 r
#   - etymotic evo l
#   - illu eqharman r
#   - 64 audio fourte l
#   - hbb audio x r
#   - dunu falcon pro (transparent filter, 2 outer vent 500 wtf, 1 inner vent 500 wtf, low-density tuning foam) l
#   - kz zsn pro l
#   - fiio fhe s1 l
#   - tripowin x hbb olina b r
#   - tin p1 r
#   - simgot ea500 classic l
#   - moondrop s8 sample 1 r
#   - seeaudio yume midnight r
#   - vento conductor ethereal r
#   - shine standard l
#   - kiwi ears orchestra (e-type tws) l
#   - er4xr l
#   - moondrop droplet r
#   - lz a7 (monitor-black) l
#   - tinhifi t5 l
#   - moondrop kato r
#   - final e1000 l
#   - bqeyz autumn treb xbassii r
#   - 64 audio u4s (m20) r
#   - lz a4 pro blue-black l
#   - 64audio duo r
#   - aful performer5 r
#   - sony mdr-ex15lp l
#   - tanchjim tanya r
#   - dunu falcon pro (atmospheric immersion) l
#   - sony wf-1000xm4 (eq - relaxed) l
#   - helios 8khz r
#   - moondrop kato (brass) l
#   - old crinacle target
#   - blon bl-03 (high-density tuning foam) l
#   - tri starsea (11) l
#   - sennheiser ie300 (spinfit) l
#   - 64 audio u6t xx (foam) l
#   - etymotic evo r
#   - oratory shouer s12 l
#   - sennheiser ie 600 (foam) l
#   - lz a4 pro black-red l
#   - tanchjim hana (1dividedby8 foam) l
#   - kz dq6 (micropore tape+ 1dividedby16foam mod) l
#   - tripowin olina dual comply l
#   - hidizs mm2 treble r
#   - tin hifi t4 plus l
#   - moondrop sparks (1.1.5) l
#   - sony ier-z1r (s2 - symbio) r
#   - moondrop alice (eq hokkaido) r
#   - sony mdr-ex1000 (1dividedby16 foam) l
#   - kz as10 old r
#   - tangzu shiminli encounter r
#   - moondrop alice (eq wennebostel) r
#   - tin hifi t3 plus (2 high-density tuning foams + tanchjim filter) l
#   - helios l
#   - tinhifi p2 r
#   - raptgo x hbb hook x r
#   - hidizs ms5 bal l
#   - truthear hola (no tip on coupler) r
#   - oratory sennheiser ie 800 l
#   - x2 sport r
#   - if audio d2 r
#   - moondrop void r
#   - dunu sa6 ultra (off) r
#   - thieaudio v16 r
#   - kiwiears orchestra lite l
#   - dusk bgvp r
#   - kz ast stock l
#   - sample 22 r
#   - kz zex pro taped l
#   - oratory sennheiser ie 4 l
#   - z1r epro00m r
#   - fiio fd7 tiny noz r
#   - 7hz x crinacle dioko updated r
#   - bgvp es12 (000) l
#   - qkz vk4 revised l
#   - thieaudio v16 divinity r
#   - olive-welti target
#   - 64 audio fourte blanc l
#   - fiio fhe l
#   - sennheiser momentum 3 (orignal silicon) r
#   - aria snow l
#   - 7hz timeless (moondroop tips) r
#   - bqeyz autumn (none) l
#   - 7hz x crinacle salnotes dioko r
#   - tripowin xhbb olina foam r
#   - hidizs md4 treble r
#   - fiio fd5 (narrow) l
#   - tripowin piccolo r
#   - sennheiser momentum true wireless 3 r
#   - bqeyz autumn (y3 wtf inner vent, sony import foam) l
#   - fiio fd7 (treble) l
#   - thieaudio monarch mk2 r
#   - fiio fh5s (tanchjim filter) l
#   - sam z r
#   - blon t1 l
#   - tin t2 plus l
#   - 7th proxima l
#   - bgvp ns9 (black tips + no mesh) l
#   - aful band 8 r
#   - waner r
#   - tangzu zetianwu hayday l
#   - blon x hbb z300 r
#   - moondrop blessing 2 dusk s2 l
#   - hidizs ms5 bass (tripowin foam) l
#   - bgvp dh3 (02) l
#   - hisenior t2 classic r
#   - cca cra s2 l
#   - hidizs ms5 balanced (balanced tips) r
#   - oratory shuoer tape l
#   - softears volume (fiio q3) l
#   - lz a4 pro (a7 red f + black v) l
#   - tangzu x hbb zetian wu xspace l
#   - tripowin mele s2 l
#   - moondrop the droplet r
#   - moondrop stellaris (uc) r
#   - final b3 (tws) l
#   - hz sound heart mirror r
#   - joyodio shine 1100 l
#   - soundpeats h1 l
#   - 55hz sil r
#   - tin hifi c3 l
#   - kiwi orchestra r
#   - shuoer ej07m kl r
#   - moondrop illumination (filter removed) l
#   - sennheiser momentum true wireless 3 l
#   - moondrop stardust (s3) l
#   - helios r
#   - 7hz sample r
#   - tangzu x hbb zetian wu xbass xspace l
#   - seeaudio x crinacle yume midnight l
#   - moondrop kato (gold) l
#   - vento conductor t-500 pro (1dividedby16 foam) l
#   - kz zs10 l
#   - elysian ann
#   - truthear hexa (s2 - airlocked) l
#   - kz zex pro r
#   - kiwi ears r
#   - kz zs10 pro x sil r
#   - 64 audio u18t m15 r
#   - 64 audio u6t r
#   - vento conductor celestial2 l
#   - softears volume (motherboard + y2 paper filter on ba bore) l
#   - fiio fd5 large nozzle r
#   - letshuoer galileo r
#   - fiio fh5s (t1 m1 b1) l
#   - dunu talos hybrid mode r
#   - bqeyz autumn (normal vent, sony import foam) l
#   - monarch l
#   - z1r aet08m l
#   - tanchjim tanya openback l
#   - hidizs md4 warm r
#   - 7th acoustics supernova (s2) r
#   - kz linlong r
#   - er3xr (68ohm) r
#   - qkz ak6 r
#   - 5i anc treble r
#   - joyodio shine standard l
#   - 64 audio nio (fir black) r
#   - kz edx pro l
#   - trn kirin r
#   - kz asx 2 r
#   - lz a4 pro nzblu fired l
#   - sony xba z5 r
#   - tfz tequila pro r
#   - seeaudio yume ii l
#   - dunu falcon pro reference l
#   - tin t1 plus l
#   - kz pr1 l
#   - 64 audio fourte noir l
#   - etymotic er2se (sample 2) r
#   - dunu sa6 (atmospheric) l
#   - bqeyz autumn treb xbassii l
#   - 64 audio u12t sample 1 (m15) l
#   - moondrop lan (final eartips) r
#   - fiio fd7 (bass) r
#   - kz as16 pro btx l
#   - 7hz sample shal
#   - letshuoer s12 (post) l
#   - bgvp dh3 01 r
#   - letshuoer ej09 l
#   - aiderlot m5 (treble + 500 mesh) l
#   - md kxxs r
#   - tin hifi tin buds 3 r
#   - 5i transparency r
#   - letshuoer d13 stock nozzle r
#   - 7hz legato r
#   - letshuoer d13 (pre-prod - nozzle a) r
#   - diy e3000 r
#   - 7hz salnotes zero s2 l
#   - kxxs (cp 100) l
#   - tripowin x hbb olina double filter r
#   - tripowin leá l
#   - hidizs ms5 treble headamp l
#   - cammyfi target
#   - trn t300 l
#   - 64 audio u4s (m12) r
#   - bqeyz autumn shortbus l
#   - yanyin canon dip 3 r
#   - sennheiser ie300 (orignal silicon) r
#   - letshuoer galileo 75 l
#   - letshuoer d13 (silver) r
#   - aful acoustics performer5 r
#   - moondrop stellaris fo r
#   - moondrop chu (vent - blutack) l
#   - elysian gaea r
#   - hidizs ms5 bass (balanced tips) l
#   - tripowin olina us half naked r
#   - sony ier z1r l
#   - raptgo x hbb hook-x r
#   - hidizs ms5 2ohm l
#   - resolve sennheiser ie600 gras l
#   - sony ier z1r r
#   - moondrop chu (spring tips) r
#   - kz dq6 (hana filter) l
#   - tangzu x hbb zetian wu xbass r
#   - erasmus 00 r
#   - joyodio shine 1000 l
#   - truthear zero 75ohm l
#   - erasmus 11 r
#   - letshuoer d13 silver r
#   - shortbus autumn l
#   - raptgo hook-x deep fit l
#   - sony xba-a2 (high-density tuning foam) l
#   - 64 audio u4s m12 r
#   - tangzu wan er sg l
#   - hidizs mermaid mm2 l
#   - kz as10 30ohm r
#   - hidizs ms5 balanced (final e tips) r
#   - raptgo hook r
#   - resolve monarch mk2 gras l
#   - cca cra+ (stock filter + 350 mesh) l
#   - hexa l
#   - tin hifi t2 plus r
#   - oratory etymotic evo l
#   - tin hifi p2 r
#   - dunu sa6 on r
#   - dunu est112 (1dividedby16 foam) l
#   - tripowin lea l
#   - 64 audio u18s (m20) l
#   - moondrop quarks (s2) l
#   - kz zvx l
#   - joyodio shine 0111 r
#   - thieaudio v16 l
#   - elysian annihilator l
#   - thieaudio legacy 2 l
#   - akg n5005 (high) r
#   - hidizs ms5 bass (whizzer easytips et100ab) l
#   - dunu sa6 r
#   - bqeyz autumn (treble) r
#   - shuoer ej07m kl resin com l
#   - mangird r
#   - moondrop quarks dsp stock tips r
#   - tanchjim hana v2 r
#   - kz eda hires l
#   - 7hz zero (final eartips) r
#   - sennheiser ie 600 (sedna) l
#   - 64 audio u6t m15 (foam) r
#   - ie200 less bass r
#   - blon bl-03 (cotton filter + high-density tuning foam + micropore tape 2pin vent block) l
#   - if audio 51 r
#   - jvc 1100 r
#   - moondrop alice (eq berlin) l
#   - 64 audio u12t sample 3 (m15) r
#   - kato max l
#   - sennheiser ie600 aet08 r
#   - kz zexpro l
#   - oratory thieaudio monarch l
#   - bqeyz autumn normal r
#   - 64 audio u6t m20 (no tip on coupler) l
#   - moondrop a8 r
#   - mangird xenns up l
#   - lz a4 pro nzsil fired l
#   - hidizs ms5 treble 18ohm l
#   - resolve moondrop kxxx gras l
#   - shuoer ej07m s2 tanya l
#   - moondrop blessing 2 dusk (softear uc eartips)c l
#   - lz a4 pro (black f + blue v) l
#   - nfaudio nm2 l
#   - tripowin olina l
#   - letshuoer d13 silver l
#   - moondrop aria r
#   - ianfann
#   - shuoer ej07m kl comply l
#   - bgvp ns9 (gray) l
#   - supernova stock l
#   - joyodio shine (1000) l
#   - tanchjim ola (s2 - filterless) l
#   - letshuoer d13 (gold) l
#   - moondrop variations r
#   - hidizs mm2 ref l
#   - bqeyz autumn treble r
#   - 64 audio u4s m20 r
#   - 64 audio u4s (mx) r
#   - shuoer conductor r
#   - dunu talos (planar + ba) l
#   - truthear zero 220ohm + filter mod l
#   - sample tr r
#   - letshuoer ej07m r
#   - shozy 11 r
#   - sennheiser momentum 3 (no tip on coupler) r
#   - shuoer ej07 r(1)
#   - tri hbb kai l
#   - openheart a2 r
#   - tripowin r
#   - hidizs mm2 treble olina l
#   - thieaudio legacy 5 (75 ohm) l
#   - final audio e1000 (micropore mod) l
#   - tinhifi t2 dlc r
#   - 64 audio nio (m20) r
#   - oratory etymotic er2xr l
#   - sony mdr-ex15lp (deep) l
#   - sony xba-a2 (sony general foam) l
#   - tripowin olina 6 r
#   - empire ears odin sample 1 l
#   - dunu falcon pro tran l
#   - hidizs ms5 treble (whizzer easytips et100ab) l
#   - dunu talos planar r
#   - tin hifi t3 l
#   - tripowin x hbb loki r
#   - sparks balanced 1.2.1 l
#   - aria r
#   - sennheiser ie 200 (spiral dot) r
#   - kz dq6 (sony import foam) l
#   - cca csn r
#   - simgot ea500 black r
#   - kz pr1 stock tips l
#   - effect audio axiom l
#   - tanchjim zero dsp l
#   - shuoer tape (1dividedby16 foam) l
#   - letshuoer galileo l
#   - sony wf-1000xm4 (fw 1.1.15) l
#   - tripowin olina s2 r
#   - sennheiser ie300 (final eartips) r
#   - kiwi ears cadenza r
#   - etymotic er2xr orange r
#   - shuoer s12 xbassii r
#   - kz zs10 pro new l
#   - moondrop lan (softear uc eartips) r
#   - nf audio na2+ (balanced tips) l
#   - tinhifi c5 prototype r
#   - tinhifi p1 plus l
#   - bqeyz autumn (treble) l
#   - oracle mkii r
#   - 64 audio nio (mx) l
#   - fiio fh7s (treble) l
#   - thieaudio oracle l
#   - 64 audio u4s (s1 - mx) l
#   - akros erasmus l
#   - dunu falcon pro atmospheric r
#   - seeaudio yume midnight (s2) l
#   - dunu falcon pro (experimental) r
#   - tangzu x hbb zetian wu xspace r
#   - tripowin tc019 l
#   - moondrop aria snow edition l
#   - shine standard w l
#   - moondrop alice (2.0.1) l
#   - 7hz timeless (final tips) r
#   - akg n5005 (bass) l
#   - fiio fd5 large nozzle l
#   - 7hz timeless (sony import foam) l
#   - letshuoer ej09 r
#   - chu fullinsertion l
#   - sennheiser ie 300 (autoeq) l
#   - blon bl-a8 l
#   - kxxs (bgvp w01) l
#   - 64 audio u4s m20 l
#   - tinhifi c5 l
#   - lz a4 pro nzblu fiblu l
#   - moondrop nekocake (wennebostel anc) l
#   - moondrop ssr r
#   - shuoer tape pro l
#   - sennheiser ie 600 (spinfit) l
#   - truthear zero 2 r
#   - nf audio n2+ r
#   - truthear hola (foam eartips) l
#   - quarks dsp spring tips deep l
#   - chu r
#   - sony wf-1000xm4 (max - fw 1.2.6) l
#   - helios ortofon l
#   - moondrop chu (sf 145) r
#   - thieaudio monarch 2 r
#   - hisenior mega5p (no tip on coupler 8k peak disappeared foam) r
#   - simgot ea500 red bandaid l
#   - shine pop w l
#   - truthear hola (no tip on coupler) l
#   - tin t1s l
#   - etymotic er2xr double l
#   - oratory sony ier-m7 l
#   - lz a4 pro (red f + red v) l
#   - moondrop lan r
#   - tin t2+ r
#   - tangzu z r
#   - aful band 5 r
#   - dunu sa6 mk2 on r
#   - yanyin canon no switches l
#   - tripowin olina dual vent l
#   - truthear hola (wide bore silicone tips) l
#   - tri starsea (12) r
#   - sennheiser ie800 r
#   - xenns mangird tea l
#   - fiio fh5s (110) l
#   - 64 audio duo l
#   - truthear x crinacle zero (orignal silicone eartips) r
#   - thieaudio monarch mkii imr cable l
#   - lz a4 pro silver r
#   - shortbus autumn r
#   - kz eda (green) l
#   - shortbus eru l
#   - tangzu wan-er s.g l
#   - dusk mistip r
#   - moondrop variations manufacturer measurment r
#   - dunu falcon pro tran r
#   - dunu falcon pro (transparency) r
#   - nf  na2 plus r
#   - 1more quad driver r
#   - aful performer5 l
#   - tri starsea (11) r
#   - moondrop blessing 2 dusk (tripowin foam) r
#   - mh755 fake l
#   - resolve thieaudio oracle gras l
#   - ikko gems oh1s (s2 + etype tips) l
#   - kz eda balance l
#   - moondrop sparks r
#   - ie200 less bass s2 l
#   - aful perf 5 r
#   - hidizs ms5 balanced (balanced tips) l
#   - sony wf-1000xm4 (max - xm3 silicone) l
#   - softears rsv gryphon r
#   - sony wf-1000xm4 (max - eq - bright) l
#   - 7hz timeless s2 25ohm r
#   - truthear hexa cp100+ r
#   - shuoer ej07 l
#   - mangird tea l
#   - joyodio shine 4 on r
#   - thieaudio clairvoyance r
#   - vento conductor t-500 pro (high-density tuning foams + tanchjim tanya filter) l
#   - tripowin olina 1tanya l
#   - tripowin x hbb olina (orignal eartips) l
#   - sony mh755 l
#   - 64 audio u6t xx (no tip on coupler) r
#   - thieaudio legacy 4 l
#   - tangzu fo r
#   - raptgo hook-x r
#   - elysian diva (red switch) r
#   - hidizs ms5 balanced (no tip on coupler 8k) l
#   - trn kirin transparency l
#   - sennheiser ie 600 (e-type) r
#   - letshuoer d13 mbp l
#   - zex pro l
#   - resolve dunu sa6 ultras gras l
#   - kz eda (green) r
#   - kz asx 25ohm l
#   - softears volume gryphon r
#   - tinhifi p1 max l
#   - tripowin cencibel l
#   - prisma azul r
#   - dunu falcon pro transparency r
#   - tanchjim ola (s2 - filterless) r
#   - simgot 2000 blue r
#   - trn kirin atmosphere r
#   - blon bl-03 r
#   - shuoer s12 pro r
#   - tinhifi t2 + r
#   - resolve dunu titan s foam gras l
#   - tin hifi c2 mech warrior r
#   - yanyin canon no switches r
#   - tripowin olina tanyaolina l
#   - tangzu zetianwu l
#   - tfz live 3 r
#   - oratory akg n20 l
#   - tanchjim hana 2021 l
#   - qkz x hbb khan 75ohm r
#   - 5i bass r
#   - moondrop ssp l
#   - 7th supernova l
#   - sony wf-1000xm4 (eq - bright) l
#   - tripowin olina us full naked r
#   - letshuoer ej07m l
#   - truthear hexa (no tip on coupler) l
#   - oratory tin hifi t2 plus l
#   - raptgo hbb hook-x r
#   - 7hz salnotes zero v2 r
#   - tforce audio yuan li r
#   - iec711 comp target
#   - lz a4 pro nzblk fiblk l
#   - tripowin olina dual r
#   - truthear zero 220ohm + filter mod r
#   - muse hifi power sample 1 l
#   - nf audio na2+ l
#   - tangzu heydey l
#   - sony mdr-ex800st l
#   - sony mh755 r
#   - qkz x hbb1 r
#   - oratory tin hifi t2 l
#   - aria l
#   - sample 3 r
#   - mr water aria l
#   - lz a4 pro (gold f + red v) l
#   - 64 audio u6t mx (silicon tips wide) r
#   - kz zex r
#   - softears volume es100_75ohm l
#   - dunu falcon pro riku r
#   - seeaudio x crinacle yume midnight r
#   - kz zs7 (1dividedby16 foam) l
#   - soundpeats h1 r
#   - illu r
#   - 55hz see r
#   - tin t2 plus r
#   - thieaudio monarch mkii imr cable r
#   - fiio fd7 balanced l
#   - dunu falcon pro (atmospheric) r
#   - moondrop ssr (sedna) l
#   - softears rsv gryphon l
#   - cca cra (200 mesh) l
#   - bqeyz autumn (bass vent, filterless) l
#   - etymotic er2xr foams r
#   - tinhifi p1 r
#   - 7hz salnotes zero tape r
#   - tanchjim oxygen (foam eartips) r
#   - 64 audio u12t mx r
#   - moondrop blessing 2 target
#   - moondrop ssr (s2 + tanchjim filter) l
#   - shuoer s12 (ej07 foam eartips) r
#   - lz a6 (silver filter) l
#   - muse hifi power r
#   - tin hifi p1 max r
#   - 55hz hbb maka r
#   - raptgo hook x (ej07 foam eartips small) r
#   - oratory sony ier-z1r l
#   - softears volume (foam) r
#   - tripowin olina dual l
#   - kz linlong l
#   - hidizs ms5 balanced (bass tips) r
#   - trn kirin atmospheric r
#   - softears rsv comply l
#   - kz as16 75ω r
#   - aiderlot m5 pro modded l
#   - shuoer kinda lava 2 r
#   - dummy mangird top r
#   - tinhifi t4 pluss l
#   - resolve 7hz salnotes zero gras l
#   - tin hifi t1s l
#   - letshuoer d13 (silver) l
#   - 64 audio u18t (m15) l
#   - letshuoer ej07m kinda lava (modded) l
#   - 7hz timeless (foam tips) r
#   - yanyin canon all switches r
#   - olive-welti harman bass target
#   - moondrop blessing 2 l
#   - moondrop kato non spring (brass) l
#   - kz pr1 r
#   - 7hz salnotes zero tape 500damper r
#   - moondrop b2 r
#   - hidizs ms5 treble (no tip on coupler 8k) l
#   - er3xr l
#   - kato vivid r
#   - sennheiser ie 40 pro l
#   - mdr-ex15 (bgvp w01) l
#   - sparks (stock tuning) l
#   - lz a7 gold monitor r
#   - illu l
#   - seeaudio yume 2 r
#   - dioko spring r
#   - tri starsea (10) l
#   - moondrop illumination (final e) l
#   - kiwi orchestra l
#   - tripowin olina filter mod r
#   - fiio fd3 (vocal tips) l
#   - letshuoer conductor l
#   - dunu est112 (30ohm) l
#   - final b3 (e-type) l
#   - moondrop ssr (s3) l
#   - aful acoustics performer 5 r
#   - mdr-ex15 cp100 r
#   - yanyin sample 2 r
#   - 64 audio u4s (s1 - m15) l
#   - illu shallowfit l
#   - moondrop blessing 2 dusk (final eartips) r
#   - lz a7 monitor black foam r
#   - a2
#   - dunu talos hybrid mode l
#   - illumination r
#   - kiwi ears orchestra lite deep fit l
#   - dunu talos (s2 off) r
#   - chu 9khz l
#   - zero carbotenore r
#   - 64 audio u6t xx (silicon tips) r
#   - yanyin canon 100 r
#   - qkz ak6-zeus r
#   - etymotic er2xr tip r
#   - sennheiser ie200 l
#   - sennheiser ie 900 (final) l
#   - xenns mangird tea 2 r
#   - dunu sa6 ultra (on) l
#   - tinhifi meca c2 r
#   - animagus neutral target
#   - thieaudio monarch mkii (s2 - spring tips) r
#   - fiio fh15 (balanced) r
#   - lz a7 (pop-blue) l
#   - hidizs ms5 treble (bass tips) r
#   - cra spring r
#   - t-force yuan li (pre final) r
#   - shu z12 r
#   - sennheiser momentum 3 (final eartips) l
#   - dunu zen (high-density tuning foams inside tips) l
#   - truthear crin zero r
#   - kz as16 l
#   - moondrop blessing 2 (e-type) l
#   - symphonium audio meteor r
#   - lz a4 pro nzblu fiblk l
#   - hidizs ms5 treble (vocal tips) l
#   - kz eda highresolution r
#   - sony wf-1000xm4 (max - ambient on) l
#   - moondrop stellaris (foam) r
#   - ikko oh10 (high-density tuning foams, tanchjim filters) l
#   - mystery iem l
#   - sennheiser ie 600 (sedna) r
#   - yuan li final r
#   - tripowin xs l r
#   - raptgo hook-x deep fit r
#   - etymotic er2xr brown l
#   - sennheiser ie 300 (final e) l
#   - shuoer s12 eru r
#   - hidizs ms5 balanced (softear uc tips) l
#   - 64 audio fourte r
#   - tripowin lea' r
#   - etymotic er4xr (2f) l
#   - nf audio nm2+ l
#   - tripowin x hbb olina (final eartips) l
#   - dunu titan s pre-production r
#   - lz a6 mini (red filter) l
#   - 55hz 1 r
#   - fh5s treble r
#   - moondrop chu (tanchjim filter) r
#   - drop x etymotic erx r
#   - shuoer ej07m l
#   - blon bl-03 (tanchjim filter + blutack 2pin vent block) l
#   - letshuoer galileo (retail) r
#   - symphonium meteor s2 r
#   - dioko r
#   - tin buds 3 l
#   - letshuoer ej07 r
#   - 1more triple driver (orignal silicone eartips) r
#   - kxxs (bgvp w01) r
#   - elysian ann l
#   - tanchjim hana l
#   - nf audio na2+ r
#   - chu foamfilter l
#   - moondrop kato (brass) r
#   - raptgo hook x hbb l
#   - bqeyz autumn (normal) r
#   - blon x hbb z300 l
#   - oratory sony mh750 l
#   - 64 audio u4s m15 r
#   - moondrop kxxx l
#   - elysian diva l
#   - 64audio u12t l
#   - fiio fh7s treble r
#   - shuoer s12 (orignal eartips) r
#   - shuoer s12 pro l
#   - tripowin x hbb olina (2 filter foam eartips) r
#   - fiio fhe eclipse l
#   - joyodio shine 1110 l
#   - etymotic er2xr tip l
#   - kz zs5 l
#   - final e1000 (sedna) l
#   - kz eda (silver) r
#   - tangzu zetianwu r
#   - lz a7 (monitor-silver) l
#   - sennheiser ie300 r
#   - dunu titan s (pre) l
#   - 64 audio u4s (m12) l
#   - lz a7 black monitor l
#   - hidizs ms5 balanced (no tip on coupler 8k) r
#   - 64 audio u6t mx (silicon tips) l
#   - seeaudio yume 2 l
#   - soundpeats capsule3 pro r
#   - dunu talos on l
#   - simgot ea500 classic r
#   - kz ast 25ohm l
#   - fiio fh7s (bass) l
#   - symphonium helios l
#   - symphonium meteor (inverted) l
#   - dunu falcon pro (transparency) l
#   - crinacle ief-neutral target
#   - 7hz dioko (pre-op) r
#   - dunu vernus atmos l
#   - u18s l
#   - 64audio u12t r
#   - 64 audio u6t (m15) r
#   - moondrop variations (s2) l
#   - softears volume (atom + y6 paper filter on ba bore) l
#   - ola l
#   - yanyin m r
#   - tripowin x hbb olina (2 filter orignal eartips) r
#   - tripowin olina (tanya filter) l
#   - truthear zero double filter r
#   - hidizs ms5 balanced 18ohm l
#   - tinhifi t4 plus deep fit r
#   - cvj shine r
#   - etymotic er2xr l
#   - kiwi ears orchestra r
#   - u18s r
#   - lz a7 blue pop r
#   - shuoer galileo l
#   - moondrop kato (gold, sony import foam) l
#   - fiio fd7 (treble) r
#   - fiio fhe r
#   - 64 audio nio (m15) l
#   - symphonium audio meteor l
#   - tangzu shimin li l
#   - bqeyz autumn treb tanya l
#   - yanyin canon 010 r
#   - tin hifi t5 l
#   - 7hz zero mecha l
#   - ief neutral 2023 target
#   - tanchjim oxygen (no tip on coupler) r
#   - oratory sony xba-n1 l
#   - truthear hexa (s2 - airlocked) r
#   - cvj csk l
#   - joyodio shine 0000 l
#   - edifier normal r
#   - 64 audio tia trio l
#   - tin c2 mech warrior l
#   - truthear zero 80ohm l
#   - vento conductor celestial l
#   - oratory final audio e3000 l
#   - dunu zen pro l
#   - supernova w1 l
#   - fiio fhe s2 l
#   - hidizs mm2 ref r
#   - illu ortofon r
#   - bgvp ns9 l
#   - sennheiser ie 600 (spring tips) r
#   - 7hz zero tape r
#   - moondrop blessing 2 dusk (bgvp foam) r
#   - moondrop ssr (micro pore) l
#   - oratory sennheiser ie 40 pro l
#   - 64 audio u12t non apex r
#   - tangzu audio shimin li r
#   - hz heartmirror pro r
#   - letshuoer s12 foam r
#   - simgot ea500 (red) r
#   - kz zs10 r
#   - dunu sa6 ultra r
#   - lz a2 pro r
#   - raptgo hook x (orignal eartips) r
#   - thieaudio oracle 2 r
#   - fiio fd7 (balanced) l
#   - yanyin canon dip 1 r
#   - zex pro r
#   - harman 2019 in-ear target
#   - empire ears esr mkii l
#   - kz tc10 a r
#   - kiwiears cadenza l
#   - final audio b3 l
#   - tangzu encounter r
#   - lz a4 pro nzblk fired l
#   - salnotes dioko r
#   - kz edx pro (high-density tuning foam) l
#   - zetian wu l
#   - simgot ea500 harman l
#   - tangzu waner frontvent l
#   - tinhifi p1 l
#   - kxxs spring r
#   - etymotic er2xr comply r
#   - tripowin olina se r
#   - tangzu x hbb wu heyday r
#   - dunu sa6 ultra (off) l
#   - hidizs mm2 balance l
#   - seeaudio yume (moondrop eartips) l
#   - hidizs ms5 bass (no tip on coupler 8k) r
#   - hidizs ms5 bass (vocal tips) r
#   - kz ba10 r
#   - hidizs ms5 balanced (moondrop spring tips) r
#   - lz a6 (blue filter) l
#   - elysian diva (white switch) l
#   - blon bl-a8 r
#   - symphonium meteor (inverted) r
#   - vento conductor t-1000 r
#   - kz dq6 (micropore tape mod) l
#   - hifiman edition xs l
#   - shortbus prometheus l
#   - ie600 l
#   - tin hifi p1 plus l
#   - sony mh755 (s2) l
#   - 7hz zero (red orignal eartips) r
#   - elysian diva treb r
#   - 5i anc bass l
#   - dunu talos on r
#   - 64 audio u12t (mx) l
#   - zs10 pro l
#   - erasmus 01 r
#   - truthear hexa (foam eartips) l
#   - lz a4 pro (red f + blue v) l
#   - thieaudio monarch r
#   - kz eds btx l
#   - trio r
#   - moondrop alice (eq hokkaido) l
#   - tripowin leá r
#   - dunu falcon pro (reference) r
#   - sennheiser ie300 (tripowin foam) r
#   - tangzu wan er r
#   - tinhifi p1 max tape mod l
#   - letshuoer s12 (post) r
#   - dunu titan s (500 mesh) l
#   - hidizs ms5 balanced (bass tips) l
#   - sennheiser ie 600 (e-type) l
#   - joyodio shine pop l
#   - hbb olina se l
#   - cca cra (filterless + high-density tuning foams) l
#   - kki 1 ba switch 3 l
#   - aiderlot m5 (bass) l
#   - moondrop chu (sf 145) l
#   - truthear hexa (s2) r
#   - tanchjim new hana 2021 treble r
#   - kz pr1 stock tips r
#   - vento conductor t-500 pro l
#   - tin hifi t1s eq l
#   - lz a7 black pop r
#   - ikko asgard l
#   - letshuoer ej07m kinda lava (modded) r
#   - thieaudio oracle r
#   - final audio e500 l
#   - lz a4 pro (black f + black v) l
#   - dunu falcon pro (reference) l
#   - tripowin olina us half tan l
#   - letshuoer d13 gold nozzle r
#   - hidizs ms5 l
#   - dunu zen foam r
#   - hz sound pro r
#   - resolve moondrop kato gras l
#   - tin hifi p1 (vent blocked) l
#   - dunu falcon pro (transparent filter, 2 outer vent blutack, high-density tuning foam) l
#   - cvj shine l
#   - hz sound heart mirror pro r
#   - cca cra (350 mesh) l
#   - 55hz osun sil r
#   - oratory sennheiser ie 80 s l
#   - 64 audio u12t (no filter) l
#   - tfz t2 pro l
#   - kz tc10 r
#   - thieaudio monarch mk2 (no tip on coupler 8k peak disappeared 95db foam) r
#   - fiio fhe (franken) l
#   - hidizs mm2 bass l
#   - seeaudio yume (olina wide pore silicone eartips) r
#   - letshuoer ej07m kinda lava r
#   - cca cra plus r
#   - tripowin olina us full naked l
#   - md droplet dsp l
#   - tanchjim ola (vent tanchjim filter) l
#   - thieaudio legacy 3 all on r
#   - ssr faudio r
#   - moondrop nekocake (classic) l
#   - joyodio shine 1100 r
#   - bgvp es12 (100) r
#   - tforce yuan li r
#   - moondrop blessing 2 dusk (bgvp foam) l
#   - hidizs mm2 bass r
#   - kz zsn pro r
#   - tin hifi c2 l
#   - moondrop nekocake l
#   - prisma azul l
#   - truthears zero l
#   - shine classical w l
#   - kz zsn pro x l
#   - ikko gems oh1s l
#   - sony xba-n3 r
#   - tinhifi c3 r
#   - 64audio trio v2 r
#   - tripowin mele r
#   - thieaudio monarch mk2 (softears uc eartips) l
#   - moondrop aria s1 l
#   - lz a7 monitor silver r
#   - akg n5005 (mid high) l
#   - hzsound waistdrum9 l
#   - tangzu wan'er (foam eartips) l
#   - tripowin olina us half l
#   - dunu sa6 ultra on r
#   - tfz live 1 r
#   - tanchjim tanya openback olina l
#   - kz x hbb dq6s l
#   - dunu zen l
#   - illu ortofon l
#   - tripowin olina comply l
#   - qkz x hbb tape mod l
#   - oratory bgvp dmg (foam eartips) l
#   - raptgo x hbb hook-x 75 l
#   - hidizs ms5 balanced (moondrop spring tips) l
#   - joyodio shine classical l
#   - hzsound heartmirror l
#   - nf audio na1 l
#   - moondrop nekocake (anc off) l
#   - hidizs ms5 balanced (softear uc tips) r
#   - truthear zero filter mod l
#   - moondrop ssr (vent blocked) l
#   - fiio fd7 (40 hrs) l
#   - cca cra+ r
#   - xenns up sample 2 l
#   - oratory bgvp dmg l
#   - truthear zero 220ohm l
#   - tri hbb kai s2 r
#   - simgot ea500 boom l
#   - moondrop alice r
#   - sennheiser ie300 (no tip on coupler) l
#   - pre-prod 03 (nozzle a) l
#   - lz a7 pop black r
#   - trn reference r
#   - harman 2017v2 target
#   - kz edx pro r
#   - empire ears evo r
#   - vento conductor tony r
# ...
#   - sd251-bt l
# Cluster 606:
#   - bgvp dm8 l
#   - bgvp dm8 r
# Cluster 607:
#   - philips fidelio x3 l
#   - philips fidelio x3 r
#   - philips fidelio x2hr l
#   - philips fidelio x2hr r
# Cluster 608:
#   - hifiman tws800 l
#   - hifiman tws800 r
# Cluster 609:
#   - sam rxcap 2 da r
#   - sam rxcap r
# Cluster 610:
#   - wemlik misty 1 r
#   - wemlik misty 2 r
# Cluster 611:
#   - sj01 l
#   - sj01 r
# Cluster 612:
#   - ikko oh1 l
#   - oratory ikko oh1 l
# Cluster 613:
#   - kimafun r
#   - kimafun l
# Cluster 614:
#   - simgot ew100p l
#   - simgot ew100p r
# Cluster 615:
#   - smabat m2 pro r
#   - smabat m2 pro l
# Cluster 616:
#   - blon b60 r
#   - blon b60 l
#   - blon b60 tape r
# Cluster 617:
#   - mackie mp-460 r
#   - mackie mp-460 l
# Cluster 618:
#   - bqeyz topaz l
#   - bqeyz topaz r
# Cluster 619:
#   - earbuds - lbbs r
#   - earbuds - lbbs l
# Cluster 620:
#   - vsonic vs7 l
#   - oratory vsonic vs7 l
# Cluster 621:
#   - tago t3-02 l
#   - tago t3-02 r
# Cluster 622:
#   - oratory audeze isine 10 l
#   - oratory audeze isine 20 l
#   - audeze isine lx (spinfit) l
# Cluster 623:
#   - oriolus trailli l
#   - oriolus trailli r
# Cluster 624:
#   - sennheiser cx80s r
#   - sennheiser cx80s l
# Cluster 625:
#   - moondrop kanas pro l
#   - moondrop kanas pro r
# Cluster 626:
#   - acoustune rs1 r
#   - acoustune rs1 l
# Cluster 627:
#   - simgot em2r9 l
#   - simgot em2r9 r
# Cluster 628:
#   - 1more colorbuds 2 r
#   - 1more colorbuds 2 l
# Cluster 629:
#   - z1r stockms r
#   - z1r stockms l
# Cluster 630:
#   - guideray gr-i18 r
#   - gr-i18 r
#   - guideray gr-i18 l
# Cluster 631:
#   - qdc gemini l
#   - qdc gemini (bass) r
#   - qdc gemini r
#   - qdc gemini (bass off) l
#   - qdc gemini (bass off) r
#   - qdc gemini (bass) l
# Cluster 632:
#   - meze 99 neo dekoni r
#   - meze 99 neo dekoni l
#   - meze 99 neo l
#   - meze 99 neo r
# Cluster 633:
#   - kz dfi uduu r
#   - kz dfi uduu l
# Cluster 634:
#   - revonext rx8 r
#   - revonext rx8 l
# Cluster 635:
#   - oratory periodic audio carbon l
#   - oratory periodic audio be l
# Cluster 636:
#   - earfun free pro oluv edition l
#   - oratory earfun free pro (oluv edition) l
#   - resolve earfun free pro oluv edition gras l
#   - earfun free pro oluv edition (anc) l
# Cluster 637:
#   - zar r
#   - kz zar r
#   - zar l
#   - kz zar l
# Cluster 638:
#   - jbuds pro l
#   - jbuds pro r
# Cluster 639:
#   - sennheiser hd 598 r
#   - sennheiser hd 598 l
# Cluster 640:
#   - tfz no.3 l
#   - tfz no.3 r
# Cluster 641:
#   - kz vxs r
#   - kz vxs l
# Cluster 642:
#   - ezear x12 r
#   - ezear x12 l
# Cluster 643:
#   - audiosense aq0 r
#   - audiosense aq0 l
# Cluster 644:
#   - qdc folk r
#   - qdc folk l
# Cluster 645:
#   - innerfidelity id target
#   - innerfidelity target
# Cluster 646:
#   - faaeal hibiscus r
#   - faaeal hibiscus l
# Cluster 647:
#   - aroma thunder harmony mode
#   - aroma thunder focus mode r
#   - aroma thunder harmony mode r
#   - aroma thunder focus mode
# Cluster 648:
#   - velodyne pink l
#   - velodyne pink r
# Cluster 649:
#   - thinksound rain3 l
#   - thinksound rain3 r
# Cluster 650:
#   - hidition violet l
#   - hidition violet r
# Cluster 651:
#   - lypertek mevi l
#   - lypertek mevi r
# Cluster 652:
#   - oratory fiio fh1 l
#   - fiio fh1 l
#   - fiio fh1 r
# Cluster 653:
#   - carot one r
#   - carot one l
#   - carot one (s2) r
#   - carot one (s2) l
# Cluster 654:
#   - softears turii ti l
#   - moondrop turii ti r
#   - softears turii ti r
# Cluster 655:
#   - campfire audio pathfinder r
#   - ak pathfinder r
#   - ak pathfinder l
#   - campfire audio pathfinder l
# Cluster 656:
#   - oriolus percivali l
#   - oriolus percivali r
# Cluster 657:
#   - oratory final audio heaven v l
#   - oratory final audio heaven iv l
# Cluster 658:
#   - simgot em2r l
#   - simgot em2r r
# Cluster 659:
#   - jbl endurancerun l
#   - jbl endurancerun r
# Cluster 660:
#   - soundpeats free2 classic r
#   - soundpeats free2 classic l
# Cluster 661:
#   - dbe pr500 r
#   - dbe pr500 l
# Cluster 662:
#   - tipsy ttromso l
#   - tipsy ttromso pine stone sea l
# Cluster 663:
#   - knd l
#   - knd r
# Cluster 664:
#   - ie200 spinfit cp100 plus tips r
#   - ie200 spinfit cp100 plus tips l
# Cluster 665:
#   - tfz essence
#   - tfz essence r
# Cluster 666:
#   - dunu dm-480 r
#   - dunu dm-480 l
# Cluster 667:
#   - z1r azlavivid9khz l
#   - z1r azlavivid9khz r
# Cluster 668:
#   - asura r
#   - asura l
# Cluster 669:
#   - v20 l
#   - v20 r
# Cluster 670:
#   - kz zsr r
#   - kz zsr l
# Cluster 671:
#   - kinera freya l
#   - kinera freya r
# Cluster 672:
#   - nicehck traceless r
#   - nicehck traceless l
# Cluster 673:
#   - um mcbeth l
#   - um mcbeth r
# Cluster 674:
#   - 710 btnc (active, anc off) l
#   - 710 btnc (passive) l
#   - 710 btnc (active, anc on) l
# Cluster 675:
#   - kotori dauntless l
#   - kotori dauntless r
# Cluster 676:
#   - fir audio m5 r
#   - fir audio m5 l
# Cluster 677:
#   - kbear qinglong l
#   - kbear qinglong r
# Cluster 678:
#   - audio hekili l
#   - hekili l
#   - audio hekili r
# Cluster 679:
#   - audeze crbn r
#   - audeze crbn l
# Cluster 680:
#   - ry4s mmcx plus 32 l
#   - ry4s mmcx plus 32 r
# Cluster 681:
#   - kz zs4 r
#   - kz zs4 l
# Cluster 682:
#   - trn mt1 l
#   - trn mt1 pro r
#   - trn mt1 pro l
#   - trn mt1 r
# Cluster 683:
#   - reecho sg-03 l
#   - reecho sg-03 r
# Cluster 684:
#   - artio cr-s1 r
#   - artio cr-s1 l
# Cluster 685:
#   - fiio fh3 r
#   - oratory fiio fh3 l
#   - fiio fh3 (spring) l
#   - fiio fh3 l
# Cluster 686:
#   - nagaoka p609 r
#   - nagaoka p609 l
# Cluster 687:
#   - g-most e89 l
#   - g l
#   - g r
#   - mee audio m6 pro 2g l
#   - g-most e89 r
# Cluster 688:
#   - inkd 2.0 r
#   - inkd 2.0 l
# Cluster 689:
#   - rose mini2 mkii 2.0 l
#   - rose mini2 mkii 2.0 r
# Cluster 690:
#   - strauss em205 r
#   - strauss em205 l
#   - strauss and wagner em205 l
# Cluster 691:
#   - goldplanar gl12 filter l
#   - goldplanar gl12 r
#   - goldplanar gl12 l
# Cluster 692:
#   - pmv pp l
#   - pmv pp r
# Cluster 693:
#   - bqeyz k1 l
#   - bqeyz k1 r
# Cluster 694:
#   - audiosense t180 pro l
#   - audiosense t180 l
# Cluster 695:
#   - drop + dan clark audio aeon closed x 1-notch white filter l
#   - drop + dan clark audio aeon closed x l
#   - drop + dan clark audio aeon closed x r
# Cluster 696:
#   - tri ｍeteor r
#   - tri ｍeteor l
# Cluster 697:
#   - moondrop crescent r
#   - oratory moondrop crescent l
#   - moondrop crescent l
# Cluster 698:
#   - tansio mirai tsmr - 4 pro (120 + 1dividedby16 foam) l
#   - tansio mirai tsmr - 4 pro (120 + 0.15ohm cable) l
#   - tansio mirai tsmr - 4 pro (120 + 0.46ohm cable) l
#   - tansio mirai tsmr - 4 pro (120 + 80ohm) l
#   - tansio mirai tsmr - 4 pro (120) l
# Cluster 699:
#   - lenovo hf130 r
#   - lenovo hf130 l
# Cluster 700:
#   - final audio f3100 l
#   - oratory final audio f3100 l
# Cluster 701:
#   - oratory softears cerberus l
#   - softears cerberus r
#   - softears cerberus l
# Cluster 702:
#   - sm2 r
#   - sm2 l
# Cluster 703:
#   - nicehck db3 l
#   - nicehck db3 r
# Cluster 704:
#   - ashida ea-hf1 l
#   - ashida ea-hf1 r
# Cluster 705:
#   - fender puresonicwireless r
#   - fender puresonicwireless l
# Cluster 706:
#   - oratory auglamour f300 l
#   - auglamour f300 l
# Cluster 707:
#   - simgot em1 l
#   - simgot em1 r
# Cluster 708:
#   - g1 l
#   - g1 r
# Cluster 709:
#   - nicehck youth r
#   - nicehck youth l
# Cluster 710:
#   - campfire audio saber foam r
#   - campfire saber r
#   - campfire audio saber l
#   - campfire saber l
#   - campfire audio saber foam l
#   - campfire audio saber r
# Cluster 711:
#   - intime sora29 l
#   - intime sora29 r
# Cluster 712:
#   - kz dqs l
#   - kz dqs r
# Cluster 713:
#   - campfire audio ara l
#   - campfire audio ara r
# Cluster 714:
#   - uncjc irock9 l
#   - uncjc irock9 r
# Cluster 715:
#   - ath clr100 l
#   - ath clr100 r
# Cluster 716:
#   - shanling me80 l
#   - shanling me80 r
# Cluster 717:
#   - gs audio gd11 (40h) l
#   - gs audio gd11 (85h) r
#   - gs audio gd11 (85h) l
#   - gs audio gd11 l
# Cluster 718:
#   - sennheiser x drop hd 6xx l
#   - sennheiser x drop hd 6xx r
# Cluster 719:
#   - audiosense t8009 r
#   - audiosense t8009 l
# Cluster 720:
#   - acoustine rs one (foam) r
#   - acoustune rs one r
#   - acoustune rs one l
# Cluster 721:
#   - campfire audio onyx r
#   - campfire audio onyx l
# Cluster 722:
#   - altec im716hd r
#   - altec im716hd l
# Cluster 723:
#   - t20 raw r
#   - t20 mod 3 r
# Cluster 724:
#   - bgvp dh5 r
#   - bgvp dh5 l
# Cluster 725:
#   - nicehck db1 r
#   - nicehck db1 l
# Cluster 726:
#   - trn v90 l
#   - trn v90 r
# Cluster 727:
#   - ambient dynamics ad-006 r
#   - ambient dynamics ad-006 l
# Cluster 728:
#   - kinera tyr9 l
#   - kinera tyr9 r
# Cluster 729:
#   - at1 l
#   - at1 r
# Cluster 730:
#   - subtonic storm 004 r
#   - subtonic storm 004 l
# Cluster 731:
#   - fw10k r
#   - fw10k l
# Cluster 732:
#   - glidic tw-5100 r
#   - glidic tw-5100 l
# Cluster 733:
#   - meizu live (white) l
#   - meizu live (blue) l
#   - meizu live (black) l
# Cluster 734:
#   - oratory akoustyx r-220 l
#   - akoustyx r-220 l
# Cluster 735:
#   - kbear larkearly9 r
#   - kbear larkearly9 l
# Cluster 736:
#   - daiso al-001 r
#   - daiso al-001 l
# Cluster 737:
#   - kz esx9 l
#   - kz esx9 r
# Cluster 738:
#   - avid l
#   - avid r
# Cluster 739:
#   - qoa affinity r
#   - qoa affinity l
# Cluster 740:
#   - 1 custom pm-01 l
#   - 1 custom pm-01 r
# Cluster 741:
#   - augl f300light l
#   - augl f300light r
# Cluster 742:
#   - gs audio gd5 l
#   - gs audio gd5 r
# Cluster 743:
#   - brainwavz koel l
#   - oratory brainwavz m5 l
# Cluster 744:
#   - trn v80 l
#   - trn v80 r
# Cluster 745:
#   - tanchjim 02 r
#   - not 02 l
# Cluster 746:
#   - nicehck m6 l
#   - nicehck m6 r
# Cluster 747:
#   - hidizs ms2 r
#   - hidizs ms2 l
# Cluster 748:
#   - penon fan l
#   - penon fan 2 r
#   - penon fan r
# Cluster 749:
#   - ovidius rx-100 l
#   - ovidius rx-100 r
# Cluster 750:
#   - vientocp155 r
#   - vientocp155 l
# Cluster 751:
#   - moondrop spaceship l
#   - moondrop spaceship r
# Cluster 752:
#   - penon orb r
#   - penon orb l
# Cluster 753:
#   - df tilt 711 ref target
#   - df tilt 711 ref
# Cluster 754:
#   - nagaoka p905 r
#   - nagaoka p905 l
# Cluster 755:
#   - shozy ceres r
#   - shozy ceres l
# Cluster 756:
#   - trn ta3 l
#   - trn ta3 r
# Cluster 757:
#   - etymotic er4s r
#   - etymotic er4s l
# Cluster 758:
#   - rp-hje125e-k l
#   - rp-hje125e-k r
# Cluster 759:
#   - 7a pro1stock r
#   - 7a pro1stock l
# Cluster 760:
#   - shuoer ogk l
#   - shuoer ogk r
# Cluster 761:
#   - tinhifi t59 l
#   - tinhifi t59 r
# Cluster 762:
#   - tangzu ze tian wu l
#   - tangzu ze tian wu r
# Cluster 763:
#   - apexti r
#   - apexti l
# Cluster 764:
#   - thor mjölnir mkii l
#   - thor mjölnir mkii r
# Cluster 765:
#   - supertfz force king r
#   - supertfz force king l
# Cluster 766:
#   - kz dfi dduu l
#   - kz dfi dduu r
# Cluster 767:
#   - ve sun copper r
#   - sun copper r
# Cluster 768:
#   - shozy neo bg l
#   - shozy neo bg r
# Cluster 769:
#   - penon globe l
#   - penon globe r
# Cluster 770:
#   - fostex te02n r
#   - fostex te02n l
# Cluster 771:
#   - alpex hse-a20009 l
#   - alpex hse-a20009 r
# Cluster 772:
#   - madoo type 512 r
#   - madoo type 512 l
# Cluster 773:
#   - jpride 1984premium r
#   - jpride 1984premium l
# Cluster 774:
#   - oratory fiio fa9 l
#   - fiio fa9 pro r
# Cluster 775:
#   - kz zst r
#   - kz zst x l
#   - kz zst l
#   - oratory kz zst l
#   - kz zst x r
# Cluster 776:
#   - profundo focus01 r
#   - profundo focus01 l
# Cluster 777:
#   - hifiman re2000 pro gold l
#   - hifiman re2000 pro gold r
# Cluster 778:
#   - kz dfi duuu l
#   - kz dfi duuu r
# Cluster 779:
#   - ostry kc06a l
#   - ostry kc06a r
# Cluster 780:
#   - oxy r
#   - oxy l
# Cluster 781:
#   - blon bl-05 r
#   - blon bl-05 l
# Cluster 782:
#   - earbuds - bgvp dx6 l
#   - earbuds - bgvp dx6 r
# Cluster 783:
#   - bonako royole r
#   - bonako royole l
# Cluster 784:
#   - z1r radiuss l
#   - z1r radiuss r
# Cluster 785:
#   - kz h10 l
#   - kz h10 r
# Cluster 786:
#   - earbuds - hzsound bell rhyme r
#   - earbuds - hzsound bell rhyme l
# Cluster 787:
#   - campfire audio mammoth r
#   - campfire audio mammoth l
# Cluster 788:
#   - totem p3 r
#   - totem r
# Cluster 789:
#   - z1r azlavivid l
#   - z1r azlavivid r
# Cluster 790:
#   - ecci yst-02 l
#   - ecci yst-02 r
# Cluster 791:
#   - fender nine l
#   - fender nine r
# Cluster 792:
#   - lypertek bevi r
#   - lypertek bevi l
# Cluster 793:
#   - oriolus traillii r
#   - oriolus traillii l
# Cluster 794:
#   - campfire audio satsuma r
#   - campfire audio satsuma l
# Cluster 795:
#   - harmonicdyne pd1 r
#   - harmonicdyne pd1 l
# Cluster 796:
#   - diy sk846 l
#   - diy sk846 r
# Cluster 797:
#   - soundpeats t3on l
#   - soundpeats t3on r
# Cluster 798:
#   - roset qtx r
#   - roset qtx l
# Cluster 799:
#   - kz edcx l
#   - kz edcx r
# Cluster 800:
#   - edifier w240tn l
#   - edifier w240tn r
# Cluster 801:
#   - dunu sa03 l
#   - dunu sa03 r
# Cluster 802:
#   - z1r sonyhybridm r
#   - z1r sonyhybridm l
# Cluster 803:
#   - radius nef 31 l
#   - radius nef 31 r
# Cluster 804:
#   - kbear neon+100ohm l
#   - kbear neon+100ohm r
# Cluster 805:
#   - hear+hi acuity duo r
#   - hear+hi acuity duo l
# Cluster 806:
#   - sk7 l
#   - sk7 r
# Cluster 807:
#   - colorfly quintet r
#   - colorfly quintet l
# Cluster 808:
#   - harmonicdyne p.d.1 l
#   - harmonicdyne p.d.1 r
# Cluster 809:
#   - roset qt7 pro 2 r
#   - roset qt7 pro 2 l
# Cluster 810:
#   - z1r cp800 r
#   - z1r cp800 l
# Cluster 811:
#   - stg8p l
#   - stg8p r
# Cluster 812:
#   - whizzer he01 l
#   - whizzer he01 r
# Cluster 813:
#   - kinera nanna 2.1 z-tune edition r
#   - kinera nanna 2.1 z-tune edition l
# Cluster 814:
#   - 2p l
#   - 2p r
# Cluster 815:
#   - sho l
#   - sho r
# Cluster 816:
#   - cca fla l
#   - cca fla r
# Cluster 817:
#   - yuanli l
#   - yuanli r
# Cluster 818:
#   - audiosense dt100s l
#   - audiosense dt100s r
# Cluster 819:
#   - eo-ic100 r
#   - eo-ic100 l
# Cluster 820:
#   - tanchjim hana21 r
#   - tanchjim hana21 l
# Cluster 821:
#   - trn st2 r
#   - trn st2 l
# Cluster 822:
#   - blon fatgirl9 r
#   - blon fatgirl9 l
# Cluster 823:
#   - um 3dt l
#   - um 3dt r
# Cluster 824:
#   - harmonicdyne poseidon l
#   - harmonicdyne poseidon r
# Cluster 825:
#   - dqsm hermit l
#   - dqsm hermit r
# Cluster 826:
#   - hzhm l
#   - hzhm r
# Cluster 827:
#   - seeaudio yumemidnight l
#   - seeaudio yumemidnight r
# Cluster 828:
#   - smabat st-10s r
#   - smabat st-10s l
# Cluster 829:
#   - isn h40 r
#   - isn h40 l
# Cluster 830:
#   - odin fix r
#   - odin fix l
# Cluster 831:
#   - supernova cp155sdeep r
#   - supernova cp155sdeep l
# Cluster 832:
#   - qdc 8ss l
#   - qdc 8ss r
# Cluster 833:
#   - axs audio pro earbuds r
#   - axs audio pro earbuds l
# Cluster 834:
#   - secret t 422 r
#   - secret t 422
# Cluster 835:
#   - kinden ue r
#   - kinden ue l
# Cluster 836:
#   - ezaudio x3 l
#   - ezaudio x3 r
# Cluster 837:
#   - daiso al-002 l
#   - daiso al-002 r
# Cluster 838:
#   - bry audio reviews target
#   - acho reviews target
# Cluster 839:
#   - haylou gt2 l
#   - haylou gt2 r
# Cluster 840:
#   - kotori vampire pre-release r
#   - kotori vampire pre-release l
# Cluster 841:
#   - intime soralight2019 l
#   - intime soralight2019 r
# Cluster 842:
#   - cyberdrive impdurbass9 l
#   - cyberdrive impdurbass9 r
# Cluster 843:
#   - kz as12r22 r
#   - kz as12r22 l
# Cluster 844:
#   - mestjp r
#   - mestjp l
# Cluster 845:
#   - fatfreq harmony r
#   - fatfreq harmony l
# Cluster 846:
#   - blon bl03v2 stock l
#   - blon bl03v2 stock r
# Cluster 847:
#   - anew u1 r
#   - anew u1 l
# Cluster 848:
#   - okcsc ed10 r
#   - okcsc ed10 l
# Cluster 849:
#   - mackie mp-320 r
#   - mackie mp-320 l
# Cluster 850:
#   - cca c12 l
#   - cca c12 r
# Cluster 851:
#   - campfire audio trifecta r
#   - campfire audio trifecta l
# Cluster 852:
#   - hiby lasya r
#   - hiby lasya l
# Cluster 853:
#   - cat ear meow r
#   - cat ear meow l
# Cluster 854:
#   - sivga robin (sv021) l
#   - sivga robin (sv021) r
# Cluster 855:
#   - sennheiser mtw2 l
#   - sennheiser mtw2 (he) l
# Cluster 856:
#   - kz edahi r
#   - kz edahi l
# Cluster 857:
#   - seeaudio anoujp r
#   - seeaudio anoujp l
# Cluster 858:
#   - dzat df-10 l
#   - dzat df-10 r
# Cluster 859:
#   - fiio fa7s r
#   - fiio fa7s l
# Cluster 860:
#   - cvj angel wings r
#   - cvj angel wings l
# Cluster 861:
#   - altec im716bass l
#   - altec im716bass r
# Cluster 862:
#   - 1more comfobudsprooff r
#   - 1more comfobudsprooff l
# Cluster 863:
#   - z1r azlavivid8khz l
#   - z1r azlavivid8khz r
# Cluster 864:
#   - hzsound waist drum l
#   - hzsound waist drum r
# Cluster 865:
#   - plussound allegro l
#   - plussound allegro r
# Cluster 866:
#   - nicehck x49 r
#   - nicehck x49 l
# Cluster 867:
#   - ana airline freebud r
#   - ana airline freebud l
# Cluster 868:
#   - sivga sv023 l
#   - sivga sv023 r
# Cluster 869:
#   - hidizs ms4 r
#   - hidizs ms4 l
# Cluster 870:
#   - beyerdynamic xelento 2. gen r
#   - oratory beyerdynamic xelento l
# Cluster 871:
#   - dressage 6+1 r
#   - dressage 6+1 l
# Cluster 872:
#   - trn emx r
#   - trn emx l
# Cluster 873:
#   - bgvp sgz-dn1s l
#   - bgvp sgz-dn1s r
# Cluster 874:
#   - dkm l
#   - dkm r
# Cluster 875:
#   - smabat m0+super point l
#   - smabat m0+super point r
# Cluster 876:
#   - qoa magarita r
#   - qoa magarita l
# Cluster 877:
#   - audiosense aq7 r
#   - audiosense aq7 l
# Cluster 878:
#   - earsonics onyx r
#   - earsonics onyx l

# %%
import os
import re
import numpy as np
from sklearn.cluster import DBSCAN
import textdistance

def preprocess_iem_names(reviewers):
    iem_names = set()

    for reviewer in reviewers:
        dir_path = f'output/csv/{reviewer}'
        for file_name in os.listdir(dir_path):
            file_name = re.sub(r'\.csv$', '', file_name, flags=re.IGNORECASE)  # Remove file extension
            file_name = file_name.strip()  # Remove leading/trailing spaces
            file_name = file_name.lower()  # Convert to lowercase
            iem_names.add(file_name)

    return list(iem_names)

# List of reviewers
reviewers = [
    'achoreviews',
    'aftersound',
    'animagus',
    'arn',
    'bedrock',
    'bryaudioreviews',
    'cammyfi',
    'soundjedi',
    'eplv',
    'timmyv',
    'harpo',
    'hbb',
    'cqtek',
    'hobbytalk',
    'ianfann',
    'iemworld',
    'jacstone',
    'kr0mka',
    'kurin',
    'melatonin',
    'nymz', 
    'pw',
    'recode',
    'rg',
    'shortbus',
    'suporsalad',
    'tgx78',
    'vortexreviews',
    'vsg',
    'wdym',
    'akros',
    'data_mrs'
]

# Get unique IEM names
iem_names = preprocess_iem_names(reviewers)

# Compute the Levenshtein distance matrix
distance_matrix = np.zeros((len(iem_names), len(iem_names)))
for i, name1 in enumerate(iem_names):
    for j, name2 in enumerate(iem_names):
        distance_matrix[i, j] = textdistance.levenshtein.normalized_distance(name1, name2)

# Cluster IEM names using DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=2, metric="precomputed")
clusters = dbscan.fit_predict(distance_matrix)

# Print clustered IEM names
clustered_iem_names = {}
for iem_name, cluster in zip(iem_names, clusters):
    if cluster not in clustered_iem_names:
        clustered_iem_names[cluster] = []

    clustered_iem_names[cluster].append(iem_name)

for cluster, names in clustered_iem_names.items():
    print(f"Cluster {cluster}:")
    for name in names:
        print(f"  - {name}")
# Out:
# Cluster 0:
#   - tripowin x hbb olina (moondrop eartips) r
#   - trn mt1 r
#   - hidizs ms5 treble tk2 l
#   - mim dark magician l
#   - shuoer z12 l
#   - tri meteor r
#   - rikudougoku_target
#   - 7a est7 l
#   - akoustyx s-6 (tanchjim) l
#   - mestjp l
#   - tanchjim cora l
#   - kinera celest pandamon l
#   - intime sora29 l
#   - geek wold gk80 mic r
#   - gs audio gd5 l
#   - thieaudio wraith pad a r
#   - kxxs (symbio w peel) r
#   - kz dq6 xl r
#   - meizu live (blue) l
#   - vision ears elysium r
#   - celest pandamon l
#   - audiosense dt600 (stock) r
#   - qdc v14 standard r
#   - letshuoer d13 stock nozzle l
#   - thieaudio legacy 5 (75 ohm) l
#   - trn bax r
#   - harmonicdyne g200 flannel l
#   - final audio a4000 v2 r
#   - final e2000 (s2) r
#   - aiderlot m5 (treble + sony import foam) l
#   - calcini sweatpro 3 l
#   - joyodio shine all on r
#   - final ze3000 s2 l
#   - trn reference r
#   - qoa magarita r
#   - tinhifi p1 max giant panda r
#   - madoo type 512 r
#   - softears volume (ef04 muse02 + hidizs sonata hd + y2 paper filter on ba bore) l
#   - trn cs1 l
#   - fir audio xenon xe6 r
#   - hifiman sundara 2022 r
#   - bgvp dh3 (10) l
#   - kb ear diamond r
#   - df tilt 711 ref target
#   - kz pr1 l
#   - moondrop blessing 2 dusk (bgvp foam) r
#   - moondrop quarks (s3) r
#   - bqeyz autumn (none) r
#   - z1r stockms r
#   - xenns mangird tea r
#   - apple airpods pro 2 l
#   - fiio fd5 (balanced filter) l
#   - letshuoer ej07m kinda lava l
#   - shortbus prometheus l
#   - hidizs ms5 r
#   - final a4000 r
#   - jbl endurance run l
#   - lz a7 monitor gold r
#   - fiio fh15 (balanced) l
#   - diy 846 4ba1dd r
#   - etymotic er2xr orange r
#   - simgot en700 pro l
#   - blon miniv2 l
#   - kz linlong mp l
#   - fiio fh5s mids l
#   - anker life note 3i l
#   - qkz x hbb1 r
#   - xinhs erasmus l
#   - apple powerbeats pro r
#   - kz zsn pro (starfield filter) l
#   - oratory thieaudio monarch l
#   - tinhifi t4 l
#   - edifier w240tn l
#   - moondrop void r
#   - kxxs (bgvp w01) r
#   - dbe pr500 r
#   - markanini target
#   - effect audio axiom r
#   - thieaudio monarch mk2 (orignal silicone eartips) l
#   - kz s1 l
#   - nothing ear 2 (voice) r
#   - zs10 l
#   - sony ier m9 l
#   - ie600 stock
#   - moondrop s8 (precog) l
#   - bgvp dh5 r
#   - edifier neobuds pro l
#   - tripowin olina tanya l
#   - tinhifi t4 plus deep fit r
#   - gk gst l
#   - ief comp target
#   - kz zsn pro (blessing 2 filter) l
#   - tripowin olina s2 l
#   - yuanli l
#   - ssr l
#   - hidizs ms5 bass (no tip on coupler 8k) l
#   - kz crn r
#   - jvc fdx1 blue l
#   - sennheiser momentum 3 (softear uc eartips) r
#   - jbl endurancerun r
#   - lz a4 pro nzblk fiblu l
#   - sparks (basshead tuning) l
#   - 7hz timeless (foam tips) r
#   - xenns mangird tea 2 r
#   - artio cr-s1 l
#   - dunu sa6 mk2 (off) r
#   - seeaudio yume midnight (s2) l
#   - qkz ak6 max l
#   - zephone tiger l
#   - kz zs10 pro foam r
#   - mestjp r
#   - nicehck nx7mk3 blue filter r
#   - etymotic er2xr (s2) r
#   - oratory samsung galaxy buds2 l
#   - samsung galaxy buds2 pro (anc off) l
#   - 7hz zero s1 r
#   - yanyin canon no switches r
#   - bgvp es12 (111) l
#   - symphonium audio meteor l
#   - oratory sennheiser momentum true wireless 2 l
#   - audio-technica ath-anc300tw l
#   - vision ears elysium l
#   - smabat m2 pro l
#   - proto1 green gold yes r
#   - edc3 r
#   - nicehck m5 red r
#   - working 001 target
#   - lg hbs800 r
#   - intime sora2fixed r
#   - heart mirror l
#   - 64 audio u12t (no filter) r
#   - mr lee 5+2 l
#   - bgvp melody (balanced) r
#   - oratory final audio e5000 l
#   - shuoer s12 r
#   - ezaudio d4 (modded) r
#   - kz asxv2 l
#   - thhifi face red (wide bore) l
#   - tanchjim_tanya l
#   - letshuoer d13 treble r
#   - senfer dt6 l
#   - kiwiears orchestra lite r
#   - seeaudio rinko l
#   - enco x2 - simple and clear r
#   - tripowin x hbb mele r
#   - harmonicdyne new r
#   - truthear hexa (final e tips) l
#   - head corded earbuds l
#   - 7hz zero (final eartips) l
#   - ve phonix2 l
#   - fiio fh7s bass r
#   - raptgo gr-2cp r
#   - kbear robin l
#   - truthear zero double filter l
#   - thhifi face red r
#   - jvc fdx1 green r
#   - moondrop blessing 2 dusk s2 r
#   - catear hitam preproduction r
#   - moondrop blessing 2 dusk (bgvp foam) l
#   - moondrop droplet r
#   - final audio a4000 l
#   - fiio jd3 black r
#   - fiio fhe s1 l
#   - dm l
#   - qdc gemini r
#   - z1r cp800 r
#   - seeaudio x crinacle yume midnight r
#   - cca ca2v2 l
#   - tksilver target
#   - bqeyz k2 l
#   - lz a4 pro (black f + red v) l
#   - shanling me800 (12) r
#   - ep05 r
#   - blon bl-05s l
#   - jvc fdx1 (f100) l
#   - soundpeats minipro l
#   - illu ortofon l
#   - westone mach 80 l
#   - vento conductor t-800 l
#   - whizzer he1 l
#   - tin hifi t2 plus l
#   - truthear zero 80ohm r
#   - fiio fd7 (40 hrs) l
#   - cca cra (500 mesh + high-density tuning foam) l
#   - letshuoer d13 l
#   - softears rs10 l
#   - fiio fd7 (bass) l
#   - fir audio xe6 gold atom r
#   - kxxs r
#   - bgvp ns9 def filter r
#   - qoa margarita r
#   - sony mh1c l
#   - 7hz legato l
#   - kz dq6 (hana filter) l
#   - resolution target
#   - ana airline freebud r
#   - kbear ormosia l
#   - 64 audio u6t m20 (silicon tips wide) r
#   - kz dfi uuuu l
#   - kiwiears cadanza l
#   - kz as16 200ω r
#   - redeyes target
#   - symphonium meteor s2 r
#   - ikko opal oh02 l
#   - shortbus eru r
#   - paiaduio dr2 r
#   - co-donguri brass l
#   - custom art fibae 5 (filter) r
#   - nicehck f1 black l
#   - shuoer s12 pro r
#   - moondrop stardust (s4) l
#   - 64 audio u12t (filter 2) l
#   - cca nra r
#   - md kxxs l
#   - moondrop b2d l
#   - tanchjim tanya l
#   - dunu titan r
#   - hidizs ms5 balanced (softear uc tips) r
#   - bqeyz autumn (bass vent, high-density tuning foam) l
#   - blon z200 l
#   - lz a7 (pop-red, 30ohm) l
#   - sk7 r
#   - etymotic er2xr comply p r
#   - totem r
#   - j1234s r
#   - hidizs ms5 bass r
#   - hz heartmirror pro r
#   - willsound dewa copper r
#   - elysian x r
#   - shuoer tape9 l
#   - kz hbb dq6s r
#   - ve bie l
#   - tinhifi p1max l
#   - blon bl-03 l
#   - oratory lz hi-fi audio z05a l
#   - hidizs ms5 treble (moondrop spring tips) r
#   - kz dfi duuu r
#   - moondrop aria snow (spring) l
#   - fiio fd5 (narrow + brainwavz) l
#   - ttr co-donguribrass9 l
#   - sivga sv023 r
#   - sgor venus l
#   - vento conductor t-500 pro (high-density tuning foams + tanchjim tanya filter) l
#   - raptgo hook l
#   - oratory sennheiser momentum true wireless 3 l
#   - ccz plume l
#   - sony mdr-as800 l
#   - carot one (s2) r
#   - trn kirin (transparency filter) r
#   - hifiman he-r10p r
#   - kz dfi dddu l
#   - 64 audio u4s mx l
#   - cat ears mia r
#   - hidizs ms4 r
#   - unique melody fabled sound r
#   - focus edm r
#   - kbear qinglong l
#   - kato gold symbio l
#   - kiwi ears cadenza r
#   - totem p3 r
#   - ezaudio d4 (modded) l
#   - tangzu zetian wu r
#   - tri starsea (11) l
#   - jq 4u l
#   - nice hck f1 r
#   - kz vxs r
#   - sony mdr-ex1000 (1dividedby16 foam) l
#   - moondrop blessing 2 dusk (final eartips) l
#   - audiosense dt600 l
#   - cleer flow ii anc l
#   - harman ie 2016 target
#   - seeaudio yume l
#   - flc 8p (gold-white-transparent) l
#   - 64 audio u6t m15 (no tip on coupler) l
#   - bad guy 2022 target
#   - lz a7 pop black r
#   - nicehck m6 r
#   - tri star river bass r
#   - bqeyz k1 l
#   - sennheiser ie300 (orignal foam) l
#   - moondrop ssr (s2) l
#   - tanchjim ola (s2 - filterless) l
#   - raptgo hook-x r
#   - fiio fa1j l
#   - joyodio shine (0000) l
#   - roset qt9 mk2 r
#   - thhifi face red (wide bore) r
#   - chu l
#   - stardust l
#   - lz a4 pro (blue f + blue v) l
#   - joyodio shine rnb rock l
#   - oratory shure se535 l
#   - kz pr1 hifi r
#   - fiio fa9 pro r
#   - moondrop stellaris nofoam l
#   - samsung galaxy buds2 pro (anc off) r
#   - kz d-fi r
#   - 7hz zero mecha l
#   - qdc gemini (bass off) r
#   - qdc gemini (bass) r
#   - shozy pola39 l
#   - sennheiser ie600 final e l
#   - glidic tw-5100 l
#   - ff gm 1 r
#   - earbuds - bgvp dx6 l
#   - fiio em5 l
#   - moondrop void s2 l
#   - tinhifi t2plus l
#   - qkz x hbb r
#   - cvj mirror l
#   - z1r azlavivid9khz r
#   - hidizs mm2 ref l
#   - harmonicdyne devil r
#   - bgvp scale pro r
#   - stg8p r
#   - acoustune hs1670ss r
#   - bgvp vg4 on-on-off l
#   - final audio vr3000 r
#   - rose mini2 mkii 2.0 r
#   - monoprice m1070c lambskin l
#   - phonak audeo pfe 112 r
#   - fiio jd7 l
#   - thieaudio monarch mk2 (softears uc eartips) l
#   - penon serial w01 r
#   - sennheiser hd 598 r
#   - etymotic evo r
#   - fat freq mae see r
#   - thieaudio l4 (00) l
#   - hzsound heart mirror r
#   - co-donguri shizuku l
#   - oratory final audio a8000 l
#   - moondrop ssp l
#   - dunu talos (planar only) l
#   - cca cra l
#   - fiio fh3 r
#   - cca cra+ (stock tips) r
#   - empire ears odin sample 2 l
#   - fearless provence r
#   - 7hz timeless og l
#   - sony wf-1000xm4 (eq - bass boost) l
#   - elysian diva (white switch) l
#   - 7th acoustics supernova (s2) r
#   - whizzer he01 l
#   - tri i4 r
#   - kz dfi duud r
#   - kinera yh802 anc l
#   - enco x2 eq punchy l
#   - at1 l
#   - 7hz dioko (post-op) r
#   - sennheiser ie300 (final eartips) l
#   - sample 4 l
#   - shozy cp l
#   - bqeyz autumn norm tanya r
#   - aroma thunder harmony mode r
#   - fiio fh15 (bass) r
#   - asf flat r
#   - moondrop kato (gold) r
#   - harman 2017 target
#   - kiwiears cadanza r
#   - tin c2 mech warror r
#   - gs audio se11 l
#   - dunu titans r
#   - fir audio xe6 silver atom l
#   - 64 audio u6t m20 (no tip on coupler) r
#   - oratory hidition viento (bass) l
#   - kz as06 30ohm r
#   - tripowin piccolo l
#   - focal utopia 2022 l
#   - bqeyz winter morebass l
#   - tripowin olina us half tan r
#   - nicehck nx7mk3 blue filter l
#   - te0 narrow l
#   - kz zs6 l
#   - oriolus reborn l
#   - sony wf-1000xm4 (ambient on) l
#   - diy 8ba l
#   - ciem anni l3
#   - 64 audio u12t (filter 1) r
#   - kiwiears orchestra lite l
#   - fiio fh15 (bass) l
#   - 64 audio nio (m15) r
#   - 7hz zero r
#   - hzsound waistdrum9 r
#   - lz ax gold off r
#   - kz vx10 tanya l
#   - audiosense dt100s l
#   - 7hz timeless og r
#   - cca cra (filterless + 2 high-density tuning foams) l
#   - hs2000mx l
#   - lz ax blue r
#   - letshuoer ej09 75ohm l
#   - stardust r
#   - dunu falcon pro reference r
#   - aria snow l
#   - fiio fa7s l
#   - unique melody mest indigo l
#   - md b2 dusk r
#   - qkz zxn r
#   - fiio fh15 (balanced) r
#   - tangzu wu heyday r
#   - kz as16 75ω r
#   - proto1 green silver no l
#   - thieaudio legacy 5 (s1 seized) l
#   - dunu talos (hybrid) l
#   - lypertek bevi r
#   - resolve earfun free pro oluv edition gras l
#   - proto1 green silver yes l
#   - kz asx l
#   - er4sr l
#   - 7hz salnotes zero v2 l
#   - g2 l
#   - moondrop kato brass l
#   - lz a7 silver pop r
#   - fiio fd3 (blk nozzle) l
#   - joyodio shine (1000) l
#   - letshuoer galileo (pre-production) r
#   - campfire audio satsuma l
#   - hbb olina se l
#   - olina1dot r
#   - tri star river ii r
#   - oratory qkz vk4 l
#   - co-donguri brass (1dividedby4 foam_nozzle) l
#   - sample 1 r
#   - fiio x crinacle fhe eclipse (foam eartips) r
#   - thieaudio oracle 2 r
#   - xe6 r
#   - tripowin tc01 l
#   - kbear lark (s2) l
#   - shozy 11 r
#   - timmkoo c6109 l
#   - hidizs ms5 bass (whizzer easytips et100ab) l
#   - fiil t1 pro r
#   - 4acoustic symphonie all on r
#   - trn v90 r
#   - kbear believe l
#   - harmonicdyne pd1 l
#   - letshuoer s12 pro r
#   - tin hifi t3 l
#   - aful acoustics performer 5 r
#   - hifiman he-r9 bluemini r
#   - moondrop alice (eq in-ear target) r
#   - 4acoustic symphonie 1 on r
#   - campfire audio solaris stellar horizon r
#   - bqeyz autumn (bass) r
#   - sparks wennebostel 1.2.1 l
#   - kz as16pro22 l
#   - cca cra (sony import foam) l
#   - kbear st1 l
#   - cwu22 l
#   - dunu vulkan (s2) l
#   - 64 audio nio (fir red) r
#   - 64 audio nio (m20) r
#   - tripowin black 2 r
#   - cca lyra y2 l
#   - sennheiser ie300 (orignal silicon) r
#   - proto1 green gold no l
#   - dunu talos on r
#   - cca a10 30ohm r
#   - cca c10 pro r
#   - okcsc ed10 l
#   - ikko oh10 l
#   - westone mach 80 r
#   - samsung galaxy buds2 pro (clear) l
#   - oratory sony ier-z1r l
#   - oratory brainwavz m5 l
#   - hpdc 14db tilt kemar df 100hz target
#   - gs audio gd3c r
#   - t-force yuan li r
#   - dunu falcon pro (transparent filter, 2 outer vent pk foam, high-density tuning foam) l
#   - audiosense dt200 r
#   - tripowin x hbb olina l
#   - sony wf-1000xm4 (max - sedna light short) l
#   - kz eda bass l
#   - zex pro l
#   - hifiman he-r9 l
#   - effect audio gaea l
#   - shanling mtw300 l
#   - hidizs ms5 treble (no tip on coupler 8k) l
#   - qkz ak6 pro l
#   - mim dark magician revised l
#   - 7hz zero tape l
#   - dunu falcon pro (experimental) r
#   - dunu falcon pro ref r
#   - oratory tin hifi p1 l
#   - aur audio neon l
#   - blon bl03 l
#   - elysian annihilator r
#   - kbear lark4k l
#   - tripowin x hbb olina (2 filter foam eartips) l
#   - bgvp melody (hifi) r
#   - 1more triple driver (no tip on coupler 8k peak disappeared foam) r
#   - tin hifi t2 plus (sedna light) l
#   - blon bl-01 r
#   - campfire audio dorado 2020 r
#   - earfun free pro oluv edition l
#   - nicehck db39 r
#   - oratory ie target
#   - moondrop alice (eq brooklyn) r
#   - lz a4 pro (a7 gold f + black v) l
#   - tansio mirai spark (111) l
#   - kinera bd005pro l
#   - bgvp dm8 r
#   - peacock flight l
#   - proto1 red gold yes1 l
#   - sennheiser ie 900 (final) l
#   - dunu sa6 ultra (off) r
#   - westone mach 60 r
#   - mdr-ex15 (bgvp w01) l
#   - yanyin aladdin r
#   - trn ta2 r
#   - kz edx pro (high-density tuning foam) l
#   - ttr co-donguribrass9 r
#   - xenns mangird tea2 l
#   - dunu talos planar mode r
#   - sony wf-1000xm4 (max - eq - mellow) l
#   - kz eda high r
#   - supertfz force king l
#   - tin t4 plus l
#   - hifiman re2000 pro gold l
#   - moondrop kanas pro l
#   - audeze lcd-2 classic r
#   - samsung buds2 pro (passive) l
#   - fiio fd5 small nozzle l
#   - tri ｍeteor r
#   - 7hz timeless (sony import foam) l
#   - tangzu shiminli encounter r
#   - tanchjim ola l
#   - hidizs md4 warm l
#   - oratory campfire audio io l
#   - oratory kz ate l
#   - tangzu audio waner sg l
#   - dunu talos (s2 off) r
#   - gs audio sd9 l
#   - kiwiears cadenza r
#   - 64 audio fourte blanc l
#   - tinhifi p1 max tape mod l
#   - g-most e89 l
#   - seeaudio yume r
#   - kato vivid r
#   - campfire audio honeydew l
#   - sennheiser ie600 s1 r
#   - fiil t1 lite (bass) l
#   - aful soloist l
#   - openheart resin l
#   - etymotic er2xr (s2) l
#   - ej07_custom l
#   - oratory etymotic er2xr l
#   - mystery iem l
#   - kz dfi uudd l
#   - mangird r
#   - kz dq6 (tanchjim filter) l
#   - kinera bd005 r
#   - nf audio n2+ r
#   - mdr-ex15 (symbio w peel) l
#   - 7hertz timeless r
#   - cca cra (500 mesh + sony general foam) l
#   - acoustune rs1 l
#   - dunu falcon pro (atmospheric immersion filter) l
#   - thie or r r
#   - elysian diva (blue switch) l
#   - j1s r
#   - cca cra (nylon filter) l
#   - shuoer ej07m (30ohm) l
#   - moondrop starfield r
#   - moondrop alice (eq vienna) l
#   - auglamour t100 r
#   - te0 wide r
#   - lz a7 monitor blue r
#   - shozy neo bg r
#   - fatfreq maestro se r
#   - tfz live x l
#   - socl300 r
#   - tansio mirai rgb bass r
#   - 64 audio u12t m12 l
#   - sony ier-nw510n l
#   - vsonic vs7 l
#   - mangird tea l
#   - sony mh755v2 l
#   - blon headphones r
#   - joyodio shine pop r
#   - lz a7 silver monitor r
#   - ssr foamdamper l
#   - cvj river r
#   - rose qt9 mk2s r
#   - tinhifi p1 max prototype l
#   - trn cs2 l
#   - hifiman bolt l
#   - lz a7 pop blue foam r
#   - moondrop variations r
#   - fiio fw5 r
#   - z1r symbiofoamlesss l
#   - geek wold gk10 (0.86ohm cable) l
#   - smabat x1 l
#   - sony mdr-ex1000 l
#   - nf  na2 plus l
#   - erasmus 10 r
#   - tanchjim hana (y6 paper vent + 350 mesh) l
#   - etymotic er2se (autoeq) l
#   - sony wf-1000xm4 (max - xm3 silicone) l
#   - massdropxnoble univ r
#   - kiiboom evoke l
#   - dunu titan s pre-production l
#   - letshuoer cadenza 12 r
#   - hs audio tech r
#   - penon orb l
#   - mystery iem (rew) l
#   - fiio fh7 (red) l
#   - radius nef 31 r
#   - sample 1 deep l
#   - supernova stock l
#   - trn stm gold l
#   - tripowin lea' r
#   - kinera hodur l
#   - simphoniom helious r
#   - chu 9khz l
#   - audiosense aq4 l
#   - hidizs ms5 treble (whizzer easytips et100ab) l
#   - proto1 red red yes r
#   - fidue sirius r
#   - tronsmart onyx pure pure l
#   - sony wf-1000xm4 (tanchjim apb) l
#   - ssr new3 l
#   - 7hz zero (ej07 foam eartips) l
#   - 7hz timeless s2 r
#   - gs audio gt12x r
#   - ee odin 2 r
#   - moondrop blessing 2 dusk s2 l
#   - letshuoer conductor 75ohm r
#   - 64 audio u6t m20 (foam) r
#   - tri star river treble r
#   - moondrop kato non spring (steel) l
#   - oratory akg k3003 l
#   - proto1 green red yes r
#   - ath clr100 l
#   - hidizs ms5 treble r
#   - hidition viento-b l
#   - tforce yuan li r
#   - cvj csa r
#   - etymotic er2xr double l
#   - kz eda hires l
#   - moondrop kato (gold, sony general foam) l
#   - jvc fdx1 (f100) r
#   - target 8
#   - tripowin olina us full r
#   - raptgo leaf l
#   - illumination r
#   - empire ears legend x r
#   - blon bl01v2 l
#   - daiso al-003 l
#   - letshuoer d13 (pre-prod - nozzle a) r
#   - kz h10 r
#   - ksound ep-k05 l
#   - goldplanar amt stock r
#   - campfire audio mammoth r
#   - soundpeats capsule3 pro l
#   - cca hm20 foam r
#   - simgot ea2000 n3a000 r
#   - kinera baldr r
#   - dunu falcon pro (experimental) l
#   - kz as10 30ohm r
#   - tin hifi t2 plus r
#   - kbear neon 75ohm r
#   - lz a4 pro nzblk fired l
#   - kz dfi dduu r
#   - oratory etymotic er3xr l
#   - moondrop ssp (vent blocked) l
#   - agent 007 r
#   - diy e3000 l
#   - joyodio shine 0011 l
#   - kbear believe new filter l
#   - chu t300t r
#   - mangird xenns up l
#   - truthear hexa (s2) l
#   - trn kirin transparency r
#   - kz dfi ddud r
#   - smabat x1 r
#   - fiio fd7 (treble) r
#   - tfz king 2 r
#   - qkz qkz x hbb r
#   - tangzu audio shimin li l
#   - dunu talos off l
#   - revonext rh-215 l
#   - bqeyz autumn treb xbassii r
#   - erasmus 00 r
#   - soundpeats truedot r
#   - kz pr1 hifi l
#   - hidizs ms5 balanced r
#   - diy e4000 r
#   - kz dq6 (micropore tape+ 1dividedby16foam mod) l
#   - tanchjim hana 2021 l
#   - simgot ea500 (red) l
#   - reecho gy09s l
#   - custom art fibae 3x3 r
#   - lz a4 pro (blue f + red v) l
#   - jvc fdx1 white l
#   - fir audio m4 r
#   - 5i treble l
#   - 7hz zero (final eartips) r
#   - hzsound waist drum r
#   - 7a est7 r
#   - onyx free l
#   - tin hifi t5 l
#   - bonako royole r
#   - seeaudio midnight r
#   - akg n5005 (bass) r
#   - mr lee arouse d8 r
#   - qoa magarita l
#   - tfz live 1 r
#   - aful performer 5 l
#   - ms5 treble l
#   - moondrop nekocake l
#   - bqeyz autumn l
#   - yinyoo ash l
#   - geek world gk10 l
#   - thieaudio legacy 3 2 on r
#   - jvc fd02 l
#   - kz zs7 (1dividedby16 foam) l
#   - hidizs ms5 treble (vocal tips) l
#   - eono eonobuds2 r
#   - tri x hbb kai r
#   - bqeyz k1 r
#   - nf audio nm2 l
#   - sony wf-1000xm4 (eq - relaxed) l
#   - ve phonix2 r
#   - harman oe target
#   - trn kirin r
#   - qdc anole v14 (0010) l
#   - kz dfi uuud l
#   - fir audio ne4 black atom l
#   - nicehck n3 r
#   - bqeyz topaz r
#   - supernova cp155eq l
#   - samsung galaxy buds2 pro (treble boost) l
#   - blon bl-03 (500 mesh + micropore tape 2pin vent block) l
#   - akoustyx s-6 (s2) l
#   - fir audio rn6 r
#   - samsung buds2 pro (anc) r
#   - joyodio shine rnb rock r
#   - sennhieser ie80 r
#   - zexpro r
#   - chu 9khz r
#   - 64 audio nio (fir black) l
#   - oratory noble audio k10 ciem l
#   - hidizs ms5 bass (vocal tips) r
#   - j1b r
#   - kbear f1 l
#   - hobby talk target
#   - kinden ue r
#   - geek world gk10 r
#   - md kxxs r
#   - seeaudio neo l
#   - letshuoer tape pro l
#   - moondrop ssr (deep) r
#   - hisenior b5+ r
#   - mh755 fake r
#   - mim dark magician og r
#   - sony ex800 taped vent r
#   - tansio mirai sands 020 r
#   - softears twilight l
#   - thieaudio l3 (12) r
#   - tinhifi t2+ no filter r
#   - toneking p10 r
#   - fiio fd5 (1dividedby16 foam) l
#   - blon bl-a8 l
#   - 64 audio u18t m15 r
#   - jade audio ea3 r
#   - oratory jabra elite 75t l
#   - sennheiser ie600 l
#   - trn vxpro9 l
#   - oratory final audio e4000 l
#   - sennheiser mtw2 l
#   - twilight l
#   - kz eda balanced 300 l
#   - banbeucmas target
#   - oratory moondrop blessing 2 l
#   - trn emx l
#   - 64 audio u18t m20 l
#   - etymotic er4xr foam l
#   - geekwold gk10 l
#   - mim dm softears r
#   - blon mini r
#   - kxxs (cp 100) l
#   - etymotic er2xr double r
#   - harmonicdyne athena r
#   - oriveti ov800 01 r
#   - bqeyz topaz l
#   - yanyin_m l
#   - shuoer galileo r
#   - tanchjim echo l
#   - kb ear robin r
#   - lz a4 pro (red f + black v) l
#   - 7th acoustics proxima r
#   - tanchjim ola bass l
#   - tripowin olina vent covered r
#   - tri kai r
#   - yinyoo ash r
#   - 64 audio u6t xx (no tip on coupler) l
#   - thieaudio clair l
#   - soundpeats mini pro hs r
#   - sennheiser ie 900 (fake) l
#   - mystery 010 r
#   - thieaudio monarch mk2 (softears uc eartips) r
#   - tkzk ouranos r
#   - tanchjim echo (tanchjim echo filter + y6 paper vent) l
#   - oratory sony wf-1000x l
#   - moondrop aria snow (spring) r
#   - softears rsv comply l
#   - lz a7 (pop-black) l
#   - etymotic er2se (sample 2) r
#   - truthear hola (wide bore silicone tips) l
#   - westone mach 20 l
#   - tri ione mp l
#   - dn3 l
#   - rtings target
#   - 7 hertz timeless l
#   - ovidius rx-100 l
#   - simgot em2r l
#   - xenns mangird tea2 r
#   - moondrop nekocake (anc on) l
#   - kz ba10 30ohm r
#   - tanchjim ola (s2 - filterless - taped) r
#   - thieaudio monarch mk2 (final eartips) r
#   - campfire audio onyx r
#   - kz zex pro l
#   - audiosense t8009 r
#   - kz zsx l
#   - 64 audio u18s l
#   - sony wf-1000xm4 (max - mrs config) l
#   - sony ex1000 r
#   - resolve dunu est112 gras l
#   - mackie mp-320 l
#   - 64 audio u12t sample 3 (m20) r
#   - z1r azlavivid r
#   - zetian wu r
#   - indigo r
#   - tri hbb kai r
#   - hisenior mega5p (foam eartips) r
#   - shuoer ej07m kl resin com r
#   - joyodio shine (1010) l
#   - unique melody maven pro r
#   - dunu sa6 mk2 on r
#   - westone mach 30 l
#   - tin c2 mech warrior l
#   - oratory anker soundcore liberty air 2 l
#   - mdplus l
#   - harman combined over-ear target
#   - trn kirin transparent l
#   - moondrop stardust (s3) r
#   - tripowin mele l
#   - shuoer ej07m kl resin l
#   - s12 l
#   - kz zes r
#   - thieaudio l3 r
#   - tanchjim oxygen o2
#   - juzear 41t l
#   - moondrop aria snow l
#   - kz zs10 r
#   - hifiman shangri-la jr l
#   - hexa r
#   - letshuoer d13 (silver filter) l
#   - muse hifi power sample 2 l
#   - leisurely audio l8 r
#   - softears rs10 foam r
#   - antdroid target
#   - 1more triple driver (no tip on coupler 8k peak disappeared foam) l
#   - soundpeats free2 classic l
#   - ikko oh1 l
#   - yanyin canon 100 r
#   - gs audio gt12x l
#   - cat ear meow r
#   - tripowin olina l
#   - 710 btnc (passive) l
#   - tripowin x hbb olina (2 filter final eartips) l
#   - cca cra (sony general foam) l
#   - kiwi ears orchestra (e-type tws) r
#   - 7hz timeless s2 l
#   - tinhifi t4plus r
#   - kz dfi duud l
#   - du b r
#   - bgvp ns10 gold r
#   - 7hz timeless l
#   - mdr-ex15 (bgvp w01) r
#   - stakk target
#   - sho l
#   - senfer mt300 r
#   - dunu est 112 (spinfit) l
#   - yan ult 2 r
#   - joyodio shine 1110 r
#   - kz dfi dddu r
#   - smabat m0 r
#   - tinhifi t4 plus deep fit l
#   - thhifi character l
#   - trn vx9 l
#   - elysian diva mid r
#   - bqeyz autumn (500 mesh inner vent, sony import foam) l
#   - 55hz 350 r
#   - raycon e25 l
#   - moondrop blessing2 r
#   - tinhifi t4+ r
#   - fiio fd7 balanced l
#   - moondrop kato (gold, sony import foam) l
#   - kz eda highresolution l
#   - z1r epro00m l
#   - westone mach 20 r
#   - bgvp scale 2dd l
#   - soundpeats t3off r
#   - ttr co-dongurishizuku9 l
#   - roset qt7 pro 2 l
#   - blon mini l
#   - sony wf-1000xm4 (max - eq - bright) l
#   - smabat m2s+gold r
#   - moondrop alice (eq austria) r
#   - super 21 target
#   - sennheiser momentum 3 (softear uc eartips) l
#   - koss keb90 r
#   - sony mdr-ex800st (filterless) l
#   - bgvp ns9 (black tips + no mesh) l
#   - dunu sa6 ultra (on) l
#   - tinhifi p1 l
#   - 7hz zero (red orignal eartips) l
#   - tangzu shiminli downunder l
#   - nymz target
#   - tri star river (natural) l
#   - sony mdrex15 r
#   - thieaudio l3 (10) l
#   - dunu talos planar+ba r
#   - cayin yb04 r
#   - asf 3ba 2way r
#   - tripowin x hbb olina (2 filter final eartips) r
#   - kbear robin r
#   - dunu sa6 on l
#   - daiso ev-001 r
#   - sony ex800st r
#   - vsonic gr07 (bass) l
#   - tanchjim prism r
#   - p1 max stock black l
#   - sennheiser momentum 3 (orignal silicon) r
#   - tin t3 buds l
#   - oratory jbl free x l
#   - p1 max xelastec l
#   - echobox nomadn1bk l
#   - truthear zero filter mod l
#   - hz sound pro r
#   - harman 2018 over-ear target
#   - softears rsv tk2 l
#   - vento conductor celestial r
#   - blon bl-03 (micropore tape 2pin vent block) l
#   - sony wf-1000xm4 (max - eq - treble boost) l
#   - qdc anole vx l
#   - harman2019v2 target
#   - softears volume tanya 2 holes l
#   - hifiman he-r10p bluemini l
#   - qdc anole vx (010) l
#   - kz zsn r
#   - kbear diamondv2 l
#   - bravery l
#   - dunu titan l
#   - fiio fd5 (micropore tape mod) l
#   - moondrop stellaris l
#   - gaea r
#   - bqeyz autumn (normal vent, sony import foam, blutack outer vent) l
#   - naga audio sirius r
#   - moondrop kxxx l
#   - penon globe l
#   - oratory jvc ha-fw1800 l
#   - tin hifi c5 l
#   - qkz ak6 r
#   - bgvp dh3 (00) l
#   - ns audio ns3 l
#   - yanyin canon 000 r
#   - empire ears odin r
#   - thieaudio monarch mk2 (foam eartips) l
#   - bgvp dmgbk9 r
#   - 2p l
#   - letshuoer x gizaudio galileo l
#   - tago t3-02 l
#   - seeaudio yume midnight (75ohm) l
#   - sony wf-1000xm4 (eq - custom) l
#   - elysian diva bass light r
#   - tronsmart apollo bold l
#   - hidizs ms5 treble (moondrop spring tips) l
#   - shine standard wmp l
#   - intime sora light (vent mod) l
#   - acoustune hs2000mx mkii l
#   - tripowin x hbb olina (final eartips) r
#   - dunu talos r
#   - tinhifi c5 prototype r
#   - ie200 less bass r
#   - olive-welti target
#   - nicehck traceless r
#   - sivga phoenix r
#   - tkzk ouranos l
#   - enco x2 - real r
#   - 5i anc r
#   - tin hifi t2 pro (white grill + comply) l
#   - bgvp dn2 l
#   - seeaudio bravery ale l 2
#   - hidition viento b r
#   - moondrop a8 r
#   - bgvp ns9 l
#   - mim dm l
#   - reecho sg-01 l
#   - ms5 bass r
#   - thhifi character (wide bore) r
#   - qkz x hbb tape mod l
#   - 7hz zero mecha r
#   - haylou gt1plus r
#   - oratory kz zs10 l
#   - recode neutral target
#   - ety er-4s l
#   - zero zircopezzo r
#   - kz edx l
#   - trn ba8 l
#   - campfire audio holocene l
#   - sony ier-z1r (s2 - symbio) l
#   - shortbus olina l
#   - aful acoustics performer5 (36 ohm) l
#   - dunu falcon pro (reference) l
#   - oriolus trailli r
#   - qkzxhbb foam r
#   - hekili l
#   - oratory v-moda zn l
#   - nostalgia audio camelot l
#   - dunu 380 r
#   - mim dm xd-05 l
#   - aful acoustics performer5 r
#   - ezaudio x3 r
#   - jvc ha-a50toff l
#   - tinhifi t4 plus l
#   - oratory fiio fh5 l
#   - resolve dunu sa6 gras l
#   - fiio fd3 l
#   - sennheiser ie300 (orignal silicon) l
#   - tinhifi t2 + r
#   - moondrop ssr (deep) l
#   - shozy b2 r
#   - nf audio na3 l
#   - raptgo hook x (ej07 foam eartips small) r
#   - md droplet dsp r
#   - thieaudio wraith r
#   - seekreal airship l
#   - qkz khan r
#   - fiio fd7 (bass + spinfit) r
#   - kz dq6v2 l
#   - etymotic er2xr tip r
#   - dunu falcon pro (reference filter, 2 outer vent pk foam) l
#   - fiio fhe r
#   - 7hz salnotes dioko tapedvent l
#   - supernova mistip l
#   - moondrop the droplet r
#   - oriolus 2nd gen l
#   - aful soloist r
#   - moondrop aria snow nofoam mp l
#   - jcally jc10 r
#   - final b3 (e-type) l
#   - audeze lcd-x (2021) r
#   - bqeyz spring 1 l
#   - nicehck f1 silver l
#   - thieaudio l4 (02) l
#   - lg hbs800 (anc off) r
#   - kinera celest gumiho 36ohm l
#   - tozo golden x1 r
#   - ikko oh10 (no tip on coupler) l
#   - oratory mackie mp-360 l
#   - ikko gems oh1s (s2 + etype tips) l
#   - kz zsx r
#   - tri star river (natural) r
#   - ttr co-dongurishizuku9 r
#   - tinhifi t2d silicon r
#   - oratory shuoer tape l
#   - tanchjim oxygen (foam eartips) l
#   - cca ca16 pro r
#   - tinhifi t2 plus l
#   - lz a4 pro nzred fiblk l
#   - 7hz salnotes zero v2 r
#   - sam k r
#   - sncp100 l
#   - shuoer s12 l
#   - hessian tws7 l
#   - eva2020 x final l
#   - cleer flow ii ambient l
#   - vento conductor t-500 pro l
#   - moondrop ssr (final e) l
#   - simgot em1 r
#   - letshuoer d13 (silver) l
#   - kinera tyr r
#   - z1r azlavividdeep r
#   - ccz melody l
#   - joyodio shine (1100) l
#   - oratory kz zsn pro l
#   - dunu est112 r
#   - kz zs10 pro x sil r
#   - proto1 red gold no r
#   - nicehck db1 r
#   - seeaudio anoujp l
#   - mdr-ex15 cp100 r
#   - oratory vision ears erlkonig l
#   - letshuoer d13 2nd nozzle r
#   - letshuoer d13 stock nozzle r
#   - fiio fhe s2 r
#   - final audio e2000 l
#   - truthear hola (no tip on coupler) l
#   - isn h50 l
#   - westone mach 50 r
#   - sm2 l
#   - kz edx ultra r
#   - kz pr1 pro l
#   - sony mdr-ex15lp l
#   - g1 r
#   - ua complimentary 1 r
#   - shuoer ej07m kl comply l
#   - letshuoer galileo (pre-production) l
#   - tri starsea (12) r
#   - moondrop sparks (1.1.9 - no bass) l
#   - animagus preference target
#   - nd nsk r
#   - ve azure l
#   - simgot ea500 red bandaid l
#   - secret t 422 r
#   - tangzu x hbb zetian wu xbass xspace r
#   - sg airline iem r
#   - truthear zero 80ohm l
#   - variations_sb4 l
#   - softears volume gryphon l
#   - bgvp dn2 r
#   - mdr-ex15 (kxxs) r
#   - campfire audio satsuma r
#   - tangzu audio zetian wu l
#   - aune jasper l
#   - 7a pro1 l
#   - zs5v1 l
#   - moondrop kxxs (new filters) l
#   - edifier neobuds s dynamic r
#   - qoa affinity r
#   - sony wf-1000xm4 (eq - bright) l
#   - sivga robin (sv021) r
#   - soundpeats capsule3 pro r
#   - 64 audio u4s (fir black) r
#   - truthear zero 75ohm r
#   - focal bathys r
#   - db monroe l
#   - qoa sunrise r
#   - diy 8ba r
#   - haylou gt1 l
#   - lz a6 (dark blue filter) l
#   - campfire saber l
#   - moondrop aria s1 r
#   - aur audio neon r
#   - thhifi character (small bore) l
#   - 55hz fo r
#   - moondrop blessing 2 dusk (no tip on coupler 8k) r
#   - mackie mp-320 r
#   - fiio fh5s (200 hrs + fd5 cable) l
#   - bgvp vg4 off-off-off l
#   - kz d-fi dddu l
#   - earbuds - bgvp dx6 r
#   - tanchjim oxygen microporevent set2 l
#   - aiderlot m5 pro modded l
#   - 1more quad driver r
#   - diy 846 4ba l
#   - lz a4 pro nzsil fired l
#   - kemar df target
#   - joyodio shine 1111 l
#   - simgot ea500 harman l
#   - kinera urd r
#   - letshuoer d13 gold nozzle r
#   - musehifi power l
#   - fz audio liberty z2 l
#   - tripowin olina dual l
#   - apexti l
#   - cca cra (1dividedby8 foam) l
#   - tin hifi t5 (comply waxguard) l
#   - shozy elsa r
#   - moondrop twilight r
#   - moondrop nekocake (balanced) l
#   - t160 r
#   - thieaudio oracle mk2 r
#   - tenhz p4 pro l
#   - bgvp ns9 (gray) l
#   - dunu titans l
#   - sennheiser momentum 3 (orignal silicon) l
#   - tin hifi p1 max l
#   - seeaudio bravery l
#   - 64 audio u18t none l
#   - sony mh1c r
#   - ve sun copper r
#   - tangzu shiminli nodamper l
#   - trn im2 l
#   - 55hz osun sil r
#   - limeears anima l
#   - dusk bgvpshallow l
#   - oratory sony mdr-xb50 l
#   - qdc v14 acg r
#   - kz zsn pro x r
#   - akoustyx r-220 l
#   - tangzu waner sg l
#   - resolve symphonium helios gras l
#   - sennheiser momentum 3 (no tip on coupler) l
#   - blon bl-03 (cotton filter + micropore tape 2pin vent block) l
#   - fir audio xe6 black atom r
#   - tgx78 tofino r
#   - ssr new4 r
#   - kbear f1 r
#   - 7hz zero (moondrop eartips) l
#   - hidizs ms5 treble (tripowin foam) l
#   - tripowin x hbb olina (2 filter orignal eartips) r
#   - gr-i18 r
#   - tangzu zetianwu hayday r
#   - supernova w1deep r
#   - etymotic evo (2f) l
#   - oratory campfire audio andromeda l
#   - campfire audio pathfinder l
#   - truthear hola (foam eartips) r
#   - oratory ns audio ns3 l
#   - oratory sennheiser cx 400bt l
#   - sony wf-1000xm4 (max - anc on) l
#   - rose qt9 mk2 r
#   - sonarworks target
#   - tri i3 pro (micropore-vent) l
#   - kimafun r
#   - trn ba5 r
#   - qkz x hbb khan l
#   - fearless audio dawn r
#   - jvc fw10000 l
#   - magaosi k3 (f1) r
#   - moondrop kato (steel) l
#   - kb ear diamond l
#   - trn kirin (transparency filter) l
#   - cca nra (0.66ohm) r
#   - audeze lcd-5 old headband r
#   - simgot ea500 harman r
#   - shozy 14 r
#   - audiosense dt300+36 r
#   - trn kirin (atmospheric filter) r
#   - moondrop ix r
#   - bonako royole l
#   - samsung galaxy buds pro r
#   - blon bl03v2 stock r
#   - kz zs5 l
#   - pro1 r
#   - tantan r
#   - cca hm20 r
#   - ezear x12 r
#   - tangzu heyday micropore l
#   - mdr-ex15ap l
#   - 55hz eki r
#   - tinhifi p1 max l
#   - jbuds pro l
#   - tripowin mele sony l
#   - aurisonics asg 2 r
#   - letshuoer galileo (retail) l
#   - hidizs ms5 treble 18ohm l
#   - tangzu zetianwu r
#   - kz zsa9 l
#   - tripowin lea l
#   - illu symbio r
#   - soundpeats air 3 pro l
#   - 64 audio trio l
#   - hz sound heart mirror pro r
#   - 64 audio u12t (m20) l
#   - dunu sa6 mk2 (on) l
#   - tanchjim oxygen (no tip on coupler) r
#   - test l
#   - jq 4upro r
#   - bgvp ne5 (grey filter) l
#   - edifier wh950nb bluetooth l
#   - kiwi cadenza r
#   - crin neutral
#   - simgot em1 l
#   - tangzu shimin li encounter r
#   - pro1 spring l
#   - harman iem target
#   - tinhifi p1max tape l
#   - sony ier-z1r (s3) r
#   - qoa mojito r
#   - moondrop blessing 2 dusk (spinfit) l
#   - tanchjim hana v2 r
#   - kz as16r22 l
#   - ihip anzu l
#   - proto3ba r
#   - thieaudio wraith pad b l
#   - blon b60 tape r
#   - lypertek mevi l
#   - simgot ea2000 r
#   - tangzu wu zetian heyday r
#   - raptgo hook x hbb l
#   - oratory earfun free pro (oluv edition) l
#   - shuoer s12 (orignal eartips) r
#   - geek wold gk80 mic l
#   - simgot ew100 r
#   - fat freq r
#   - resolve truthear zero gras l
#   - thieaudio monarch mk2 (orignal silicone eartips) r
#   - tinhifi meca c2 r
#   - simgot ea 500 r
#   - lz a4 pro nzblu fired l
#   - innerfidelity id target
#   - shozy elsa l
#   - nicehck topguy l
#   - kz zex pro taped l
#   - resolve tangzu zetian wu gras l
#   - socl300 l
#   - fiio fh5 l
#   - open audio mercury r
#   - oratory sony wf-c500 l
#   - geek wold gk10 no tape l
#   - moondrop chu (vent - tanchjim) r
#   - moondrop void s1 r
#   - hidizs ms5 high oi r
#   - echobox travelert1 l
#   - trn mt3 r
#   - xenns top l
#   - moondrop kato (gold) l
#   - prisma audio azul (spiral dot) l
#   - lza4 pro blue r
#   - jh audio layla (min) l
#   - etymotic er2se l
#   - truthear hexa cp100+ l
#   - bqeyz autumn bass tanya l
#   - dunu sa3 l
#   - truthear zero (s2) l
#   - vientocp155 r
#   - kz dfi uddd r
#   - sony xba-n3 s2 r
#   - 64 audio u12t non apex l
#   - status audio iem-2x l
#   - pusheen buds l
#   - joyodio shine standard r
#   - toneking_bl1 l
#   - bgvp es12 (110) r
#   - 5i treble r
#   - tgx78 tofino l
#   - yanyin x hbb mahina r
#   - ssr new2 l
#   - kz eda (gold) r
#   - kbear neon mod r
#   - tin t3plus l
#   - heart mirror pro l
#   - trn ta1 max r
#   - proto1 red red yes l
#   - sennheiser ie 300 l
#   - super bass target
#   - thor mjölnir mkii l
#   - trn stm (gold) r
#   - sony xba-a3 r
#   - fiio x crinacle fhe r
#   - 64 audio u6t m20 (silicon tips) l
#   - kz zsxv2 l
#   - aria l
#   - thieaudio monarch mk2 (bgvp memory cotton) r
#   - etymotic er2xr triple r
#   - trn st2 r
#   - dt200 r
#   - anew u1 l
#   - thieaudio legacy 2 r
#   - seeaudio yume midnight r
#   - sennheiser ie600 (foam eartips) r
#   - 64 audio u4s m20 l
#   - moondrop lan (final eartips) r
#   - oratory huawei freebuds 4i l
#   - proto1 red silver yes r
#   - intime sora 2 l
#   - sam rxcap r
#   - dunu zen r
#   - 64 audio u4s (fir black) l
#   - tripowin olina se l
#   - 64 audio u6t mx (foam) r
#   - 7th proxima l
#   - resolve thieaudio clairvoyance gras l
#   - etymotic er4s l
#   - tgx78 target
#   - dunu falcon pro (reference filter, 2 outer vent pk foam, high-density tuning foam) l
#   - acoustune rs one l
#   - oratory 7hz timeless l
#   - kbear ks1 l
#   - kz edx ultra l
#   - trn ba59 l
#   - bqeyz autumn (bass vent, filterless) l
#   - tripowin olina dual vent l
#   - fiil t1 lite tws r
#   - softears volume l
#   - resolve truthear hexa gras l
#   - lenovo xt98 r
#   - p1 max sticky red l
#   - df tilt 711 ref
#   - u18t r
#   - proto1 green gold no r
#   - daiso ev-001 l
#   - v4 r
#   - cambridge audio melomania 1+ l
#   - bqeyz autumn (500 mesh inner vent, sony import foam, blutack outer vent) l
#   - mest mk ii r
#   - lz a4 pro black-black l
#   - goldpl filt 1 r
#   - z1r radiuss r
#   - kemar df 1.3 bass target
#   - kiwi ears orchestra lite deep fit l
#   - vento conductor ethereal r
#   - fiio fd5 (narrow + shure) l
#   - sample r
#   - tangzu x hbb wu heyday l
#   - asx 10ba 2way l
#   - sennheiser ie200 r
#   - moondrop aria snow nofoam l
#   - thieaudio l5 l
#   - pro1 8k l
#   - blon bl-05 l
#   - kbear believe new filter r
#   - daiso al-002 l
#   - kb ear aurora l
#   - sam z r
#   - lz a4 pro (black f + blue v) l
#   - kz zs7 r
#   - koast audio mithi l
#   - gk gs10 r
#   - truthear zero 2 r
#   - bqeyz autumn bass r
#   - timmy target
#   - 4acoustic symphonie all off r
#   - hifiman re600 v2 l
#   - um mest mk1 l
#   - er3xr (68ohm) r
#   - hidizs ms5 treble (bass tips) r
#   - kz dfi uddu l
#   - blon bl-mini l
#   - tronsmart onyx prime default l
#   - kz ate r
#   - thhifi character (small bore) r
#   - kz as06-2020 l
#   - cca cra s2 r
#   - unique melody mest mk2 r
#   - fiio ft3 suede r
#   - tronsmart apollo bold classic r
#   - fender nine r
#   - hifiman svanar l
#   - tri star river natural r
#   - dunu talos (planar + ba) (ie600 foam tips) l
#   - lz a4 pro nzsil fiblu l
#   - 64 audio u12t m15 l
#   - trn ta3 r
#   - trn stm (blue) r
#   - sgor venus r
#   - letshuoer kl l
#   - elysian accoustic annihilator 2021 r
#   - nicehck m5 red l
#   - raptgo hbb hook-x l
#   - audio lokahi 7bav2 l
#   - nagaoka p608 r
#   - lz a4 pro nzred fired l
#   - bqeyz kb19 r
#   - dt200 spring l
#   - er3xr r
#   - 64 audio u6t mx (no tip on coupler) r
#   - hidizs ms5 bass (final e tips) l
#   - oratory obravo cupid l
#   - kz zar r
#   - rose mini2 mkii 2.0 l
#   - tri star river (vocal) r
#   - sennheiser ie600 (foam eartips) l
#   - moondrop void s2 r
#   - campfire audio trifecta r
#   - onyx free r
#   - blon a8 l
#   - crinacle target
#   - nicehck nx7 mk4 gold l
#   - hifiman arya stealth r
#   - joyodio shine 0011 r
#   - dusk r
#   - shuoer ej07m kl r
#   - kz zse l
#   - trn stm r
#   - simgot ea500 black r
#   - 64 audio duo l
#   - kz eda highresolution r
#   - whizzer he03d l
#   - yanyin canon dip 2 r
#   - raptgo hook x (ej07 foam eartips larg) r
#   - bgvp ne5 (champagne filter) l
#   - monarch l
#   - kz zex (vent blocked) l
#   - sony mdr-ex15lp (deep) r
#   - sennheiser cx true wireless r
#   - ve bie pro r
#   - bgvp es12 (111) r
#   - 7hz timeless (moondroop tips) r
#   - dunu talos (switch on) r
#   - 64 audio u6t mx (no tip on coupler) l
#   - openheart a2 r
#   - tripowin olina se r
#   - shuoer s12 eru l
#   - kinera norn l
#   - 7hz salnotes zero tape 500damper r
#   - lz a7 blue pop r
#   - simgot em2r9 r
#   - dusk ortofon l
#   - tangzu wan'er l
#   - xenns mangird tea l
#   - hifiman tws800 r
#   - daiso al-005 l
#   - apple airpods pro 2 r
#   - truthear hexa r
#   - shuoer ej09 r
#   - sennheiser ie 300 (autoeq) l
#   - nfaudio na2+ l
#   - revonext rx8 l
#   - tangzu wan er l
#   - sam 250 r
#   - ddhifi janus 2 l
#   - 64 audio u6t mx (silicon tips wide) r
#   - gs audio gd11 (85h) r
#   - openheart resin r
#   - moondrop variations (s2) l
#   - kz dfi uudu r
#   - seeaudio yume midnight (15ohm) l
#   - kiwi ears orchestra l
#   - sample hb r
#   - urbanfun iss014 l
#   - cca cx10 l
#   - geek wold gk10 l
#   - 64 audio u4s (s1 - m12) r
#   - final audio b3 r
#   - anker life dot 3i r
#   - seekreal dawn r
#   - meze liric l
#   - elex (elear pads) l
#   - hisenior mega5p l
#   - supernova cp155sdeep l
#   - jvc fwx1 r
#   - tri ione r
#   - oratory beats powerbeats pro l
#   - bad guy target
#   - thieaudio legacy 4 2 on r
#   - moondrop nekocake (wennebostel anc) l
#   - trn kirin atmosphere l
#   - tin t2plus r
#   - nf audio nm2+ l
#   - tangzu waner sg r
#   - usound1v1 oratory 1990 target
#   - lz a7 (pop-black, high-density tuning foams) l
#   - olina mod mesh r
#   - revonext rh-215 r
#   - blon a72 r
#   - supernova vivid r
#   - 1more comfobudsprooff l
#   - seeaudio x z review rinko 75 l
#   - oratory sennheiser ie 80 s l
#   - elysian diva treb r
#   - trzr wave olina r
#   - dunu talos (s2 on) l
#   - voyager3 l
#   - brainwavz koel l
#   - final audio a4000 v2 l
#   - sennheiser ie600 aet08 r
#   - oratory sony ier-m9 l
#   - thieaudio clair r
#   - 710 btnc (active, anc off) l
#   - akg eo r
#   - fiio fd3 (foam tips) l
#   - flare audio flares pro r
#   - sg8 l
#   - pre-prod 03 (nozzle a) r
#   - cca pla s r
#   - lg hbs800 l
#   - tansio mirai tsmr - 4 pro (120) l
#   - augl f300light l
#   - sony mdr-ex800st (low-density tuning foams) l
#   - 7hz timeless r
#   - sennheiser ie 200 (azla max) r
#   - ola r
#   - etymotic er4xr l
#   - sample 11 r
#   - lz a7 pop blue r
#   - a4k l
#   - moondrop void l
#   - hzsound waistdrum9 l
#   - moondrop ssr (s3) l
#   - moondrop variations cp100+ l
#   - tin t2 2pin r
#   - kz dfi udud r
#   - seeaudio yume (final eartips) r
#   - blon a8 r
#   - sony mh755 mmcx l
#   - tin t2 2pin l
#   - tri starshine r
#   - oratory sennheiser ie 40 pro l
#   - akg n5005 (bass) l
#   - kz ed16 l
#   - supertfz force king r
#   - z1r aet08m r
#   - ezear x12 l
#   - kz zexpro r
#   - sony wf-1000xm4 (max - fw 1.1.15) l
#   - etymotic er2xr orange l
#   - resolve 7hz salnotes dioko gras l
#   - x target
#   - cca cra (500 mesh + 350 paper filter) l
#   - sennheiser mtw2 (he) l
#   - sennheiser ie 200 (d2) l
#   - cca nra stock l
#   - etymotic er2xr comply l
#   - bonus ie pro r
#   - seek real dawn r
#   - lz a6 (blue filter) l
#   - vento conductor celestial2 r
#   - etymotic er2xr (brown + 2f) l
#   - knd l
#   - lime ears aether r (bass on) l
#   - fiio fa1j r
#   - cca cra (500 mesh + y6 paper filter) l
#   - custom art fibae 7 l
#   - bravery r
#   - ve ext r
#   - truthear x crinacle zero r
#   - miku buds l
#   - 64 audio u6t r
#   - 7hz timeless (s2) r
#   - goldpl cus r
#   - pmv pp l
#   - jbl endurancerun l
#   - mim dark magician v2 l
#   - samsung galaxy buds plus l
#   - tinhifi t1s r
#   - avara av3 r
#   - thieaudio monarch mk2 (no tip on coupler 8k peak disappeared 95db foam) l
#   - yanyin canon no switches l
#   - final ze8000 1.8.0 l
#   - yanyin moonlight r
#   - shanling me80 l
#   - tri star river (enhanced treble) l
#   - galileo retail l
#   - harman 2017v2 target
#   - asg 25 r
#   - sony wf-1000xm4 l
#   - moondrop blessing 2 dusk (softear uc eartips)c l
#   - sennheiser ie 600 (spinfit) l
#   - tin p1 max l
#   - qkz x hbb khan 75ohm xbass l
#   - kiwi orchestra lite l
#   - crinacle neutral 2023 target
#   - qkz x hbb khan 75ohm r
#   - cfa andromeda 2020 l
#   - tin hifi t4 plus l
#   - letshuoer d13 mbp r
#   - mim dark magician tape l
#   - ns audio ns3 r
#   - trn kirin transparency l
#   - 4ss r
#   - audiosense dt600 (stock) l
#   - moondrop nekocake (anc on) r
#   - moondrop s8 (s2) l
#   - hidizs ms5 2ohm l
#   - fir ne4 r
#   - 64 audio u4s (s1 - m20) r
#   - cca cxs l
#   - dusk l
#   - lz a6 (purple filter) l
#   - tfz live 1 l
#   - tiolake sr2 l
#   - noble audio viking ragnar r
#   - vento conductor t-800 r
#   - moondrop variations manufacturer measurment r
#   - hisenior t2c r
#   - tronsmart apollo air+ l
#   - tri star river oi l
#   - isn d10 l
#   - raptgo hook r
#   - 64audio trio l
#   - dunu titan s r
#   - thieaudio monarch r
#   - samsung buds2 pro (passive) r
#   - sample 7 r
#   - sivga oriole r
#   - 7 hertz timeless r
#   - sample 2 l
#   - daiso al-003 r
#   - resolve letshouer z12 gras l
#   - cwu22 r
#   - qdc anole vx (100) l
#   - tripowin tc-01 l
#   - joyaudio shine r
#   - bqeyz autumn (normal) l
#   - hidizs ms5 bass (moondrop spring tips) r
#   - edifier wh950nb bluetooth r
#   - kz zst x r
#   - oratory meze rai penta l
#   - lypertek pureplay z3 l
#   - earbuds - lbbs r
#   - rikudogoku target
#   - 64 audio nio (fir black) r
#   - kz as16pro l
#   - supernova cp155 r
#   - mr water aria r
#   - nostalgia audio camelot r
#   - lz a6 (red filter) l
#   - oratory oppo enco x2 l
#   - hidizs mm2 balanced l
#   - elysian ann
#   - 7hz timeless (final tips) r
#   - kz zas l
#   - sennheiser ie600 (stock silicone) l
#   - 64 audio u12t mx20 r
#   - audeze lcd-xc (2021) l
#   - bad guy target v2
#   - hidizs ms5 treble (balanced tips) r
#   - kxxs spring l
#   - kiwi orchestra lite r
#   - aiderlot m5 reference r
#   - shuoer s12 (orignal eartips) l
#   - final b3 (tws) l
#   - hidizs ms5 treble (final e tips) l
#   - tangzu wan er r
#   - elex (stock pads) l
#   - 64 audio duo r
#   - sennheiser ie600 final e r
#   - sennheiser ie600 r
#   - sj01 l
#   - oratory westone um3x l
#   - supernova final l
#   - letshuoer d13 (treble nozzle) l
#   - variations_sb l
#   - audeze lcd-x (2021) l
#   - audiosense aq0 r
#   - tangzu x hbb zetian wu tape r
#   - sony ier-m7 l
#   - dunu falcon pro (reference filter) l
#   - velodyne pink r
#   - truthear x crinacle zero (final e eartips) l
#   - custom art fibae 5 (filter) l
#   - unique melody mest l
#   - diy sk846 r
#   - tin t2 evo r
#   - moondrop droplet l
#   - penon impact l
#   - 64 audio u12t mx15 r
#   - xenns up sample 2 l
#   - seeaudio bravery ale 2 r
#   - wf1000xm4 r
#   - seeaudio yume (silicone eartips) r
#   - madoo type 512 l
#   - final eva2020 l
#   - smabat nco r
#   - empire ears evo l
#   - moondrop kato (steel) r
#   - thieaudio monarch mk2 (no tip on coupler 8k peak disappeared 87db foam) l
#   - sennheiser ie 200 (d2) r
#   - tin hifi t2 evo r
#   - dunu sa6 bass mk2 r
#   - lime ears pneuma r
#   - trn rosefinch r
#   - t-force yuan li l
#   - hbb audio x r
#   - kz asx 2 r
#   - vision ears phonix r
#   - tri i3 pro (88h) l
#   - moondrop illumination (final e) l
#   - sony mdr-ex800st (filterless, 4mm mesh) l
#   - iec711 comp target
#   - tipsy tromso l
#   - qkz vk4 revised l
#   - soundpeats life l
#   - sample 42 r
#   - shuoer s12 (moondrop eartips) l
#   - moondrop aria snow edition r
#   - fiio fd3 treble l
#   - lypertek pureplay z5 anc l
#   - tripowin olina (s2) r
#   - moondrop blessing 2 dusk (final eartips) r
#   - madoo t711 r
#   - oratory final audio heaven iv l
#   - lz z05a l
#   - vientocp155 l
#   - basn bmaster 2nd l
#   - 7a sg1 l
#   - sony wf-1000xm4 (max - eq - excited) l
#   - final audio b3 l
#   - beats powerbeats pro r
#   - softears volume (ef04 muse02 + y2 paper filter on ba bore) l
#   - flare audio flares pro l
#   - koss kph40 l
#   - trn kirin (atmospheric filter) l
#   - ciem anni l2
#   - aune jasper r
#   - md b2 dusk l
#   - kz zs10 pro new r
#   - kz d-fi dddd r
#   - 7hz x crinacle dioko updated r
#   - yinfu md51 l
#   - supernova ortofon r
#   - kz zs79 r
#   - fiio jd7 r
#   - sennheiser hd600 r
#   - z1r azlavivid8khz l
#   - coda target
#   - chu detach r
#   - raptgo x hbb hook-x s2 r
#   - roset qt7 pro 2 r
#   - aful acoustics performer 5 l
#   - thieaudio ghost r
#   - akros erasmus l
#   - kz dfi uuud r
#   - kato gold symbio r
#   - 64 audio u18t none r
#   - oratory fiio fh1 l
#   - moondrop quarks dsp ultra deep l
#   - dunu sa6 ultra (off) l
#   - oratory bose quietcomfort 20 l
#   - kz zst r
#   - jaybird x3 l
#   - kinera pandamon r
#   - wdym target
#   - 64 audio u18t (m15) l
#   - bqeyz spring 2 (modded) l
#   - 7hz dioko (pre-op) r
#   - dunu falcon pro (atmospheric) l
#   - not project red r
#   - tanchjim 02 r
#   - bgvp melody (hifi) l
#   - oratory westone w10 l
#   - erasmus 11 r
#   - moondrop blessing 3 r
#   - custom art fibae 5 filter l
#   - smabat m4 ba l
#   - dunu titan 5 l
#   - softears rsv gryphon r
#   - kz zs10 prov2 l
#   - t-force yuan li (pre final) l
#   - tangzu heyday wu r
#   - bgvp sgz-dn1s r
#   - campfire audio honeydew r
#   - kz zsn pro (1-8 foam) l
#   - pro1 spring r
#   - catear hitam r
#   - kz d-fi ddud r
#   - oratory sony mh755 l
#   - thieaudio l3 (02) l
#   - qdc v14 rock r
#   - tripowin olina highdensity foam olinad l
#   - softears volume (atom) r
#   - 64 audio u4s (s1 - m15) r
#   - custom art fibae go 1 r
#   - harpo target
#   - simgot en700 pro (tanchjim) l
#   - z1r max r
#   - nicehck m5 grey l
#   - panasonic rp-hje150 l
#   - if audio d5 r
#   - kbear neon+100ohm l
#   - intime sorati3 r
#   - tangzu heydey r
#   - tin hifi t1 plus l
#   - tin t2+ r
#   - ikko opal oh2 l
#   - hexa l
#   - kz edc l
#   - tofino pro r
#   - fiio fhe s2 l
#   - oratory final audio ux3000 (b, anc on) l
#   - oratory nuforce edc3 l
#   - p1 max foam l
#   - aful performer5 l
#   - thieaudio legacy 5 (s2 15ohm) l
#   - jomo gt600 r
#   - hidizs ms5 bal r
#   - thieaudio l2 r
#   - 64 audio u6t m20 (no tip on coupler) l
#   - blessing2_dusk r
#   - tri starsea (11) r
#   - kz as16prohi-imp r
#   - tfz t2 pro l
#   - kinera nanna2 r
#   - hidizs ms5 balanced (no tip on coupler 8k) r
#   - oratory inear prophile-8 l
#   - kz zex pro (30ohm) l
#   - audiosense t180 l
#   - thieaudio monarch mkii l
#   - tripowin x hbb mele blue r
#   - campfire audio trifecta l
#   - seeaudio yume2 l
#   - bqeyz kb100 r
#   - fir audio vxv r
#   - timmkoo c6109 r
#   - m - audio q40 r
#   - p1 max sticky red deep l
#   - truthears zero r
#   - 1more triple driver (orignal silicone eartips) l
#   - oratory massdrop plus universal iem l
#   - ola_olina_200 r
#   - oriveti ov800 00 r
#   - jh trifi r
#   - fender nine l
#   - nice hck f1 black r
#   - aful acoustics performer5 (75 ohm) r
#   - fatfreq maestro se l
#   - soundpeats minipro r
#   - 64 audio u6t m15 (silicon tips) r
#   - fz audio liberty max r
#   - sony ier z1r l
#   - bqeyz autumn normal l
#   - fiio fh5 r
#   - jvc ha-fx6 r
#   - venture ie mod r
#   - raptgo hook x (orignal eartips) r
#   - harmonicdyne g200 flannel r
#   - thieaudio legacy 2 l
#   - joyodio shine 0000 r
#   - raycon e25 r
#   - tripowin h1 r
#   - sony ier m9 r
#   - akros erasmus r
#   - tforce audio yuan li r
#   - cca cra s2 l
#   - fiio fh5s (111) l
#   - variations_sb5 l
#   - 55hz 1 r
#   - mdr-ex15ap r
#   - aroma jewel l
#   - trurhear hola l
#   - ddhifi janus r
#   - qkz zx2 r
#   - letshuoer z12 l
#   - sennheiser cx 400bt tws r
#   - lz ax red r
#   - softears volume (motherboard + y2 paper filter on ba bore) l
#   - skald s11 r
#   - kbear st19 l
#   - sennheiser ie300 (no tip on coupler) l
#   - sennheiser momentum tw3 r
#   - nicehck n3 l
#   - z1r aet06s l
#   - truthear hexa l
#   - penon fan l
#   - oratory qudelix qx-over l
#   - cca c12 r
#   - thhifi face red (small bore) r
#   - kiwiears cadenza l
#   - mh755 l
#   - sony xba-n3 (s2) r
#   - tansio mirai 5 r
#   - supernova w1shallow l
#   - ssr new3 r
# ...
#   - ks zs10 pro l
#   - shuoer kinda lava 2 r
#   - kinera pandamon l
#   - dunu zen pro l
#   - 7hz zero (moondrop eartips) r
#   - truthear crin zero r
#   - hidizs ms5 high oi l
#   - shuoer conductor r
#   - symphonium meteor s2 l
#   - monarch r
#   - kb ear believe l
#   - moondrop nekocake (dynamic anc) l
#   - 64 audio nio (m12) r
#   - qdc anole vx 3 on r
#   - illu l
#   - qkz x hbb l
#   - zs5v1 r
#   - hifiman arya (2021 stealth magnets) r
#   - tri hbb kai l
#   - tin hifi p1 (vent blocked) l
#   - jvc fdx1 (f050) r
#   - sennheiser momentum 3 (bgvp foam) l
#   - penon sphere r
#   - tantalus l
#   - moondrop quarks (s2) r
#   - 64 audio nio (m20) l
#   - isn rambo ii r
#   - intime sora light 2019 l
#   - shuoer ej07 r(1)
#   - final ze3000 s1 l
#   - 7hz timeless (no filter) r
#   - plextone rx1 r
#   - s12_sb l
#   - thieaudio elixir r
#   - kz edx pro (low-density tuning foam) l
#   - moondrop alice (eq wennebostel) r
#   - oratory final audio e1000 l
#   - intime sora light 2019 (s2) r
#   - 55hz eki tune r
#   - oratory tin hifi t2 plus l
#   - nicehck db3 r
#   - dynamicears target
#   - final audio e4000 l
#   - seek real airship l
#   - flc 8p (silver-gray-gunmetal) l
#   - thieaudio legacy 4 1 on r
#   - lz a7 (pop-blue) l
#   - akg n5005 ref (no tip on coupler 8k) l
#   - kz sa08 l
#   - joyodio shine 3 on r
#   - blon bl max r
#   - akg n5005 ref (no tip on coupler 8k) r
#   - tansio mirai tsmr - 4 pro (120 + 1dividedby16 foam) l
#   - 55hz qkz sil r
#   - shure se215 r
#   - cca lyra y1 l
#   - bgvp ns9 r
#   - fir audio xe6 gold atom l
#   - rose technic photon r
#   - thieaudio legacy 4 (spring) r
#   - tripowin mele sony r
#   - oratory moondrop blessing 2 dusk l
#   - air canada earphones l
#   - fir audio kr5 silver atom r
#   - kz eds btx hifi l
#   - hz heartmirror pro l
#   - 64 audio u12t fir red r
#   - dunu vernus reference l
#   - tripowin olina (tanya filter) l
#   - rs10 l
#   - fir audio ne4 black atom r
#   - dunu titan s (y6 paper filter) l
#   - hidizs md4 balanced l
#   - kz dfi dddd l
#   - bgvp ns10 red r
#   - tfz tequila 1 r
#   - intime sora l
#   - edifier normal r
#   - moondrop chu tanya l
#   - campfire audio orbit r
#   - 64 audio u18s (m20) l
#   - ovidius tx-901 l
#   - oratory samsung eo-ig955 l
#   - moondrop chu l
#   - qkz qkz x hbb l
#   - kz linglong r
#   - lz a6 (black filter) l
#   - 7a pro1stock l
#   - variations_sb8 l
#   - cca cra (tanchjim filter) l
#   - kinera skuld r
#   - custom art fibae 7u r
#   - kz dfi uduu l
#   - trn st5 r
#   - tin t2 dlc l
#   - supernova w1shallow r
#   - moondrop illumination (filter removed) l
#   - hifiman susvara r
#   - simgot ea500 (black) r
#   - qcy t1c l
#   - humka hamlet r
#   - joyodio shine 0000 l
#   - thieaudio v16 l
#   - moondrop nekocake (nobass) l
#   - salnotes zero r
#   - cca cs16 l
#   - tforce audio yuan li l
#   - 64 audio u4s (s1 - mx) r
#   - inear pro mission x l
#   - asura r
#   - fiio fd5 small nozzle r
#   - vento conductor t-1000 r
#   - bqeyz kc2 r
#   - moondrop s8 sample 2 r
#   - moondrop variations manufacturer measurment l
#   - thieaudio monarch mk2 r
#   - ssp r
#   - v20 r
#   - mackie mp-460 l
#   - 7hz zero l
#   - quarks dsp deep r
#   - cayin fantasy l
#   - final audio e3000 (s2) r
#   - moondrop ssr r
#   - cca ca16 l
#   - fiio fh5s (t0 m0 b0) l
#   - t60rp mkiii r
#   - tanchjim hana21 l
#   - bose qc30 r
#   - thieaudio elixir shallow fit l
#   - blon b20 l
#   - tri starsea (00) r
#   - letshuoer galileo 75 l
#   - thor mojinhor r
#   - bt l
#   - dunu talos planar l
#   - oratory moondrop starfield l
#   - shuoer ej07m s2 tanya r
#   - juzear 41t r
#   - turiiti l
#   - tangzu wan er sg l
#   - kz eds r
#   - kz edahi r
#   - letshuoer s12 (front vent blocked) l
#   - oriolus traillii l
#   - moondrop illumination (spiral dots) l
#   - tripowin x hbb olina (foam eartips) l
#   - shanling me800 (10) l
#   - tanchjim oxygen set2 l
#   - softears_rsv l
#   - penon fan r
#   - 7hz salnotes zero nogrill l
#   - bqeyz autumn (y3 wtf inner vent, 2 high-density tuning foam, 500 mesh) r
#   - tin hifi c2 l
#   - jvc fdx1 (f000) r
#   - ej target
#   - tinhifi c2 l
#   - softears volume (apple + 75ohm) l
#   - hidizs md4 balanced r
#   - shuoer ej07m filtered l
#   - oratory fiio fa7 l
#   - ex1000 r
#   - oriolus percivali l
#   - avara av3 l
#   - shuoer ej07m kl resin com l
#   - dusk w1 r
#   - advanced s20009 r
#   - blon bl05v2 l
#   - geek wold gk10 tape r
#   - thieaudio l4 (10) l
#   - cca c16 l
#   - blur mx64 r
#   - moondrop alice (eq wennebostel) l
#   - fiio fd5 l
#   - cfa andromeda 2020 r
#   - sony xba-n3 s2 l
#   - softears volume (atom) l
#   - 5i anc treble r
#   - 7th acoustics stargazer 3 l
#   - akg n5005 (high) r
#   - oratory etymotic evo l
#   - kz edx pro l
#   - tripowin olina r
#   - joyodio shine (0100) l
#   - echobox finderx1 r
#   - fiio x crinacle fhe eclipse (no tip on coupler) l
#   - resolve monarch mk2 gras l
#   - asf flat l
#   - letshuoer d13 silver nozzle r
#   - edifier neobuds s r
#   - ety er-4s r
#   - truthear hola (no tip on coupler) r
#   - sony xba-a3 l
#   - tri star river treble l
#   - sony xba-a2 (foamless) l
#   - harpo_v2 target
#   - noble sultan r
#   - samsung galaxy buds2 pro (bass boost) r
#   - nfaudio nm2+ l
#   - moondrop chu (tanchjim filter) r
#   - cca csn r
#   - jvc fx7 r
#   - j3s r
#   - anole vx 003 r
#   - sennheiser x drop hd 6xx r
#   - aful acoustics performer5 (15 ohm) l
#   - tinhifi t1s l
#   - seeaudio yume 2 l
#   - oratory light harmonic mera l
#   - shine pop l
#   - ibasso it04 r
#   - unknown amazon iem l
#   - p1 max foam deep l
#   - ve bie r
#   - custom art fibae 7u ciem r
#   - sk7 l
#   - te0 narrow r
#   - symphonium triton l
#   - lz ax black off r
#   - bqeyz autumn treb xbassii l
#   - z1r aet06s r
#   - tripowin xhbb olina foamz r
#   - vk4 r
#   - kinera nanna 2.0 r
#   - audeze lcd-5 old headband l
#   - dunu titan s (tanchjim filter) l
#   - bgvp dm6 r
#   - diy 846 k5ba r
#   - philips fidelio x3 l
#   - hisenior fe3u l
#   - jvc fd02 r
#   - kz zvx l
#   - final ze3000 s1 r
#   - soundpeats mini pro hs l
#   - supernova cp155eq r
#   - fir kr5 s2 l
#   - sony xba-a2 l
#   - kiiboom allure l
#   - graph x r
#   - tfz t2 galaxy l
#   - kiwi ears orchestra lite deep fit r
#   - sennheiser ie 600 (sedna) l
#   - nicehck nx7mk3 red filter l
#   - fiio f1 l
#   - tanchjim zero r
#   - soundpeats life tws l
#   - hifiman r800 r
#   - 4acoustic symphonie 2 on r
#   - blon aa r
#   - qdc anole vx 110 l
#   - kz as16 pro btx l
#   - 64 audio u12t fir black r
#   - apple airpods pro 2 (anc mode) r
#   - qkz hbb r
#   - dunu talos hybrid r
#   - qdc anole vx 111 r
#   - tanchjim zero dsp l
#   - tanchjim tanya r
#   - dunu sa6 ultra off l
#   - cvj shine l
#   - letshuoer d13 (gold) l
#   - kz as16pro r
#   - lz a4 pro (red f + red v) l
#   - penon vortex r
#   - final audio e1000 (s2) r
#   - moondrop sparks (1.1.7) l
#   - thieaudio voyager 3 (10) l
#   - 64 audio nio (mx) l
#   - tripowin olina dual comply l
#   - z1r dqsms l
#   - campfire audio saber l
#   - akoustyx s-6 l
#   - jq audio 4u r
#   - tinhifi t2 l
#   - moondrop lan (bgvp foam) l
#   - hidition violet l
#   - rikudougoku target
#   - blon x hbb z300 r
#   - geek wold gk3 l
#   - supernova cp155s l
#   - ie200 less bass s2 l
#   - tangzu wan'er (wide bore silicone tips) r
#   - dunu vernus atmos r
#   - kbear ks2v2 l
#   - elysian annihilator l
#   - anker life note 3i r
#   - rose technic aura evo l
#   - hidizs ms5 treble (tripowin foam) r
#   - sennheiser ie300 (tripowin foam) r
#   - oratory jabra elite 7 pro l
#   - acoustine rs one (foam) r
#   - sennheiser momentum 3 (tripowin foam) r
#   - cra spring r
#   - anima l
#   - kinera bd005 pro r
#   - unique melody mest mkii r
#   - moondrop chu r
#   - blon bl-03 (450 mesh + micropore tape 2pin vent block) l
#   - tangzu wan-er s.g l
#   - unique melody mext l
#   - 64 audio u4s (m20) l
#   - penon vortex eq r
#   - zs5v1 47r oi r
#   - sony ier m7 r
#   - thieaudio oracle mk2 l
#   - tfz tequila pro l
#   - tin t5 l
#   - samsung galaxy buds pro (dynamic preset) l
#   - audeze crbn r
#   - oratory ultimate ears reference monitor l
#   - bqeyz autumn (normal vent, sony import foam) l
#   - 7hz dioko r
#   - 4ss l
#   - truthear zero r
#   - bgvp vg4 off-off-on l
#   - oratory final audio adagio iii l
#   - plateada l
#   - tripowin piccolo r
#   - moondrop aria (old) l
#   - softears volume (apple dongle) l
#   - paulwasabii target
#   - vsg target
#   - yanyin canon all switches r
#   - dt200 spring r
#   - dunu sa6 mk2 (off) l
#   - ezaudio x3 l
#   - letshuoer s12 (post) l
#   - tgxear tiolake red r
#   - tronsmart onyx prime hifi l
#   - kz pr1 balanced version r
#   - shuoer ej07m kl resin r
#   - tronsmart onyx pure normal l
#   - bqeyz k2 r
#   - moondrop illumination r
#   - hookx l
#   - enco x2 - classic r
#   - hidizs md4 treble l
#   - audiosense dt600 r
#   - shanling me800 clear r
#   - floaudio lily  l
#   - tri i3 pro (micropore-vent) r
#   - ssr foamdamper r
#   - soundpeats mini pro l
#   - vision ears ve7 r
#   - hidizs md4 treble r
#   - dunu sa6 ultra r
#   - simgot ea500 olina l
#   - tinhifi t1s9 l
#   - moondrop stardust (s2) l
#   - mackie mp-460 r
#   - oratory vision ears elysium l
#   - cca ca24 r
#   - qdc 8ss l
#   - tri star river all off l
#   - u18s l
#   - moondrop alice r
#   - fearless audio s8f r
#   - hiby lasya l
#   - cca cst l
#   - tripowin cencibel 2x filter mod r
#   - pre-prod 03 (nozzle a) l
#   - proto1 red silver yes l
#   - kbear neon+100ohm r
#   - catear hitam l
#   - bgvp ns9 (red) l
#   - hidizs md4 bass l
#   - shine pop w l
#   - intime sora light l
#   - 7hz salnotes zero tape r
#   - tin hifi c3 l
#   - kbear ks1v2 l
#   - proto1 red red no r
#   - thieaudio legacy 3 off l
#   - letshuoer z12 (s2) l
#   - harman in room target
#   - truthears hexa r
# Cluster 1:
#   - fifine h6 movie eq r
#   - fifine h6 music eq r
#   - fifine h6 gaming eq l
#   - fifine h6 music eq l
#   - fifine h6 gaming eq r
#   - fifine h6 movie eq l
# Cluster 2:
#   - astell n kern uw100 r
#   - astell n kern ak zero1 r
#   - astell kern odyssey l
#   - astell n kern ak zero1 l
#   - astell n kern uw100 l
#   - astell & kern solaris x r
#   - astell kern odyssey r
# Cluster -1:
#   - semkarch cnt r
#   - z_isolation comparison free field l
#   - excalibur r
#   - jh jolene r
#   - ely-x-effect-gaea-r
#   - sendy peacock r
#   - stagesound stage magic plus l
#   - volume 01-23 r
#   - little dot gyfu raw r
#   - allway oe10 l
#   - devialet gemini flat r
#   - aaw halycon r
#   - klipsch s4 l
#   - harpo v4 target (11.03.2023 02-43-36)
#   - oratory apple me186 in-ear headphones l
#   - swd2le
#   - average reviewer
#   - binaryacoustic void r
#   - mi true wireless earbuds basic 2 l
#   - aaw mockingbird r
#   - heartfield deer l
#   - oneplus bullets 2 l
#   - oratory bowers & wilkins c5 series 2 l
#   - creative aurvana trio ls r
#   - oratory stax sr-003mk2 (ces-a1 closedback adapter) l
#   - itk unknown l
#   - elex (dekoni elite fenestrated sheepskin pads) l
#   - tranya t10 upgraded l
# Cluster 3:
#   - kki 1 ba switch 1 r
#   - kki 1 ba switch 2 l
#   - kki 1 ba switch 3 l
#   - kki 1 ba switch 1 l
#   - kki 1 ba switch 2 r
#   - kki 1 ba switch 3 r
# Cluster 4:
#   - ie200 spinfit cp100 plus tips r
#   - ie200 spinfit cp100 plus tips l
# Cluster 5:
#   - dressage 6+1 r
#   - dressage 6+1 l
# Cluster 6:
#   - at ath-sport5tw r
#   - at ath-sport5tw l
# Cluster 7:
#   - apollo bold default anc off l
#   - apollo bold rock anc on l
#   - apollo bold classical anc off l
#   - apollo bold rock anc off l
#   - apollo bold classical anc on l
#   - apollo bold jazz anc on l
#   - apollo bold jazz anc off l
#   - apollo bold default anc on l
#   - apollo bold pop anc off l
#   - apollo bold pop anc on l
# Cluster 8:
#   - ha-fr15-h l
#   - ha-fr15-h r
# Cluster 9:
#   - mmr thummim l
#   - mmr thummim r
# Cluster 10:
#   - antlion kimura solo r
#   - antlion kimura duo r
#   - antlion kimura duo l
#   - antlion kimura solo l
# Cluster 11:
#   - nokia e35119 r
#   - nokia e35119 l
# Cluster 12:
#   - burson_pm2_loopback l
#   - xduoo_ta20_loopback l
#   - motu_calibrated_loopback l
# Cluster 13:
#   - kotori vampire pre-release r
#   - kotori vampire pre-release l
# Cluster 14:
#   - nectar hivex (sponge insert) r
#   - nectar hivex (no sponge insert) r
#   - nectar hivex (no sponge insert) l
#   - nectar hivex (sponge insert) l
# Cluster 15:
#   - drop + dan clark audio aeon closed x 1-notch white filter l
#   - drop + dan clark audio aeon closed x l
#   - drop + dan clark audio aeon closed x r
# Cluster 16:
#   - edifier stax spirit s3 mesh bt l
#   - edifier stax spirit s3 mesh wired l
#   - edifier stax spirit s3 lambskin bt r
#   - edifier stax spirit s3 lambskin wired r
#   - edifier stax spirit s3 lambskin wired l
#   - edifier stax spirit s3 mesh wired r
#   - edifier stax spirit s3 lambskin bt l
#   - edifier stax spirit s3 mesh bt r
# Cluster 17:
#   - rp-hje270e l
#   - rp-hje125e-k l
#   - rp-hje270e r
#   - rp-hje125e-k r
# Cluster 18:
#   - urbanutility uehe-ep2 l
#   - urbanutility uehe-ep2 r
# Cluster 19:
#   - subtonic storm 004 r
#   - subtonic storm 004 l
# Cluster 20:
#   - padmate pamu z1 r
#   - padmate pamu z1 l
# Cluster 21:
#   - elecom ehp-gb10a r
#   - elecom ehp-ch30009 l
#   - elecom ehp-ch1000 r
#   - elecom ehp-gb2000 r
#   - elecom ehp-gb2000 l
#   - elecom ehp-ch1000 l
#   - elecom ehp-gb10a l
#   - elecom ehp-cs200a l
#   - elecom ehp-cs200a r
#   - elecom ehp-ch30009 r
# Cluster 22:
#   - 1 custom pm-01 r
#   - 1 custom pm-01 l
# Cluster 23:
#   - obravo ra 21 c-cu l
#   - obravo ra 21 c-cu r
# Cluster 24:
#   - mini pro hs anc off l
#   - mini pro hs anc off r
#   - mini pro hs anc on l
#   - mini pro hs anc on r
# Cluster 25:
#   - ccz coffee beanv2 l
#   - ccz coffeebean r
#   - ccz coffeebean l
#   - ccz coffee bean l
#   - ccz coffee bean r
# Cluster 26:
#   - atq at-es11 r
#   - atq at-es11 l
# Cluster 27:
#   - kbear neon (stock type e deep 80ohm) l
#   - kbear neon (a3 type e deep) l
#   - kbear neon (stock type e avg) r
#   - kbear neon (stock type e deep 80ohm) r
#   - kbear neon (stock type e deep) l
#   - kbear neon (stock type e avg) l
#   - kbear neon (a3 type e deep) r
#   - kbear neon (stock type e deep) r
# Cluster 28:
#   - jpride 1984premium r
#   - jpride 1984premium l
# Cluster 29:
#   - ue ue18+ pro (2nd gen) l
#   - ue ue18+ pro (2nd gen) r
# Cluster 30:
#   - ry4s mmcx plus 32 r
#   - ry4s mmcx plus 32 l
# Cluster 31:
#   - chu fullinsertion l
#   - chu fullinsertion r
# Cluster 32:
#   - guideray gr-i18 r
#   - guideray gr-i18 l
# Cluster 33:
#   - zhulinniao jinghong mp r
#   - zhulinniao jinghong r
#   - zhulinniao jinghong l
# Cluster 34:
#   - ashida ea-hf1 r
#   - ashida ea-hf1 l
# Cluster 35:
#   - apple ma850ga r
#   - apple ma850ga l
# Cluster 36:
#   - altec im716hd l
#   - altec im716hd r
#   - altec im716bass r
#   - altec im716bass l
# Cluster 37:
#   - hear+hi acuity duo l
#   - hear+hi acuity duo r
# Cluster 38:
#   - venture electronics bonus ie pro r
#   - venture electronics grand duke l
#   - venture electronics bonus ie r
# Cluster 39:
#   - 10mm bio v3 r
#   - 10mm bio v2 r
#   - 10mm bio v5 r
#   - 10mm bio v1 r
#   - 10mm bio v4 r
# Cluster 40:
#   - diy846 wooeasy ee846 l
#   - diy846 wooeasy ee846 r
# Cluster 41:
#   - cyberdrive impdurbass9 r
#   - cyberdrive impdurbass9 l
# Cluster 42:
#   - pioneer se-cl20 r
#   - pioneer se-cl20 l
# Cluster 43:
#   - se846-5ba diy r
#   - se846-5ba diy l
# Cluster 44:
#   - shozy black hole mini stainless steel version r
#   - shozy black hole mini stainless steel version l
# Cluster 45:
#   - faaeal hibiscus r
#   - faaeal hibiscus l
#   - faaeal poppy l
#   - faaeal poppy r
# Cluster 46:
#   - notbrand notblon l
#   - notbrand notblon r
# Cluster 47:
#   - beemix pisces r
#   - beemix pisces l
# Cluster 48:
#   - oratory 64 audio a12t (m15 apex module) l
#   - oratory t64 audio a12t (m20 apex module) l
# Cluster 49:
#   - strauss em205 l
#   - strauss and wagner em205 l
#   - strauss em205 r
# Cluster 50:
#   - chikyu-sekai 2cosmos l
#   - chikyu-sekai 2cosmos r
# Cluster 51:
#   - fender puresonicwireless r
#   - fender puresonicwireless l
# Cluster 52:
#   - uncjc irock9 l
#   - uncjc irock9 r
# Cluster 53:
#   - bang & olufsen beoplay h95 anc r
#   - bang & olufsen beoplay h95 anc l
#   - bang & olufsen beoplay h95 r
#   - bang & olufsen beoplay h95 l
# Cluster 54:
#   - dita perpetua r
#   - dita perpetua l
# Cluster 55:
#   - operafactory om01 r
#   - whizzer opera factory om3 r
#   - whizzer opera factory om3 l
# Cluster 56:
#   - creative ep-6309 r
#   - creative ep-6309 l
# Cluster 57:
#   - skullcandy dime l
#   - skullcandy dime r
# Cluster 58:
#   - cvj angel wings l
#   - cvj angel wings r
# Cluster 59:
#   - earbuds - hzsound bell rhyme r
#   - earbuds - hzsound bell rhyme l
# Cluster 60:
#   - fitear mh335 dw l
#   - fitear mh335 dw r
# Cluster 61:
#   - dqsm hermit l
#   - dqsm hermit r
# Cluster 62:
#   - mulazo bt1019-m l
#   - mulazo bt1019-m r
# Cluster 63:
#   - z1r sonyhybridm l
#   - z1r sonyhybridm r
# Cluster 64:
#   - colorfly quintet r
#   - colorfly quintet l
